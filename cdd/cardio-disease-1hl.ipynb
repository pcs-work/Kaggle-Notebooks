# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torch.nn.utils import weight_norm as WN

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# %% [markdown]
# ### **Utilities and Constants**

# %%
SEED = 42


def breaker(num: int = 50, char: str = "*") -> None:
    print("\n" + num*char + "\n")

    
def show_graphs(L: list, A: list) -> None:
    TL, VL, TA, VA = [], [], [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 HL: list = [],
                 DP: float = 0.0,
                 use_WN: bool = False,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 patience: int = 5,
                 eps: float = 1e-8
                 ):
        
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.DP = DP
        self.use_WN = use_WN
        self.HL = HL
        
        if len(self.HL) > 3:raise NotImplementedError("Only supports a maximum of 3 hidden layers")
        
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.read_path = "../input/cardiovascular-disease-dataset/cardio_train.csv"
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)

cfg = CFG(seed=SEED)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(self, features: np.ndarray, labels: np.ndarray=None):
        self.features = features
        self.labels = labels
    
    def __len__(self):
        return self.features.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is not None:
            return torch.FloatTensor(self.features[idx]), torch.FloatTensor(self.labels[idx])
        return torch.FloatTensor(self.features[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, IL: int, HL: list, DP: float=None, use_WN: bool=False):
        
        super(Model, self).__init__()
        
        self.model = nn.Sequential()
        if len(HL) == 0:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN:
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=1)))
            else:
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=1))

        elif len(HL) == 1:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN:
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else:
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=1)))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=1))

        elif len(HL) == 2:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN:
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else:
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=1)))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=1))
                
        elif len(HL) == 3:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=HL[2])))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=HL[2]))
            if isinstance(DP, float):
                self.model.add_module("DP3", nn.Dropout(p=DP))
            self.model.add_module("AN3", nn.ReLU())
            self.model.add_module("BN4", nn.BatchNorm1d(num_features=HL[2], eps=1e-5))
            if use_WN:
                self.model.add_module("FC4", WN(nn.Linear(in_features=HL[2], out_features=1)))
            else:
                self.model.add_module("FC4", nn.Linear(in_features=HL[2], out_features=1))

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### **Fit and Predict Helper**

# %%
def fit(model=None, 
        optimizer=None,
        scheduler_rlrop=None,
        scheduler_oclr=None, 
        epochs=None, 
        early_stopping_patience=None, 
        dataloaders=None, 
        fold=None, 
        save_path=None, 
        device=None,
        verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.sigmoid(y_pred)
        
        y_pred[y_pred > 0.5] = 1
        y_pred[y_pred <= 0.5] = 0
        
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, LRs, Accuracies = [], [], []
    if fold: name = f"state_fold_{fold}.pt"
    else: name = "state.pt"
        
    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []

            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.BCEWithLogitsLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict"     : model.state_dict(),
                            "optim_state_dict"     : optimizer.state_dict()},
                           os.path.join(save_path, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save({"model_state_dict"     : model.state_dict(),
                        "optim_state_dict"     : optimizer.state_dict()},
                        os.path.join(save_path, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} | Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, epochLoss["train"], epochLoss["valid"], epochAccs["train"], epochAccs["valid"], time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, BLE, BAE, name


def predict(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.sigmoid(model(X))
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <= 0.5] = 0
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
fold = 1
BLEs, BAEs = [], []


df = pd.read_csv(cfg.read_path, delimiter=";")
df = df.drop(columns=["id"])

features = df.iloc[:, :-1].copy().values
labels   = df.iloc[:, -1].copy().values

for tr_idx, va_idx in KFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(features):
    tr_features, va_features, tr_labels, va_labels = features[tr_idx], features[va_idx], labels[tr_idx], labels[va_idx]

    tr_data_setup = DS(tr_features, tr_labels.reshape(-1, 1))
    va_data_setup = DS(va_features, va_labels.reshape(-1, 1))

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
        "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
    }

    cfg = CFG(epochs=500, lr=1e-4, wd=1e-5, early_stopping=50, batch_size=512, HL=[32], DP=0.5, use_WN=True)

    torch.manual_seed(cfg.seed)
    model = Model(IL=tr_features.shape[1], HL=cfg.HL, DP=cfg.DP, use_WN=cfg.use_WN).to(cfg.device)
    optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    
    # scheduler_oclr = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, 
    #                                          max_lr=cfg.max_lr, 
    #                                          epochs=cfg.epochs, 
    #                                          steps_per_epoch=cfg.steps_per_epoch,
    #                                          pct_start=cfg.pct_start, 
    #                                          div_factor=cfg.div_factor, 
    #                                          final_div_factor=cfg.final_div_factor)
    # scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, patience=cfg.patience, eps=cfg.eps, verbose=True)
    
    scheduler_rlrop = None
    scheduler_oclr = None
    
    L, A, LRs, BLE, BAE, name = fit(model=model, 
                                    optimizer=optimizer, 
                                    scheduler_rlrop=scheduler_rlrop,
                                    scheduler_oclr=scheduler_oclr, 
                                    epochs=cfg.epochs, 
                                    early_stopping_patience=cfg.early_stopping, 
                                    dataloaders=dataloaders, 
                                    device=cfg.device,
                                    save_path=cfg.save_path,
                                    fold=fold,
                                    verbose=True)

    breaker()
    show_graphs(L, A)
    
    BLEs.append(BLE)
    BAEs.append(BAE)

    fold += 1
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 0.61686 | Valid Loss: 0.58339 | Train Accs: 0.66387 | Valid Accs: 0.72364 | Time: 9.77 seconds
# Epoch: 2 | Train Loss: 0.59174 | Valid Loss: 0.58009 | Train Accs: 0.69641 | Valid Accs: 0.72771 | Time: 9.81 seconds
# Epoch: 3 | Train Loss: 0.58659 | Valid Loss: 0.57974 | Train Accs: 0.70034 | Valid Accs: 0.72921 | Time: 9.86 seconds
# Epoch: 4 | Train Loss: 0.58244 | Valid Loss: 0.57589 | Train Accs: 0.70498 | Valid Accs: 0.72800 | Time: 9.99 seconds
# Epoch: 5 | Train Loss: 0.58166 | Valid Loss: 0.60304 | Train Accs: 0.70693 | Valid Accs: 0.70336 | Time: 9.77 seconds
# Epoch: 6 | Train Loss: 0.57895 | Valid Loss: 0.57978 | Train Accs: 0.70927 | Valid Accs: 0.72657 | Time: 9.81 seconds
# Epoch: 7 | Train Loss: 0.57830 | Valid Loss: 0.57809 | Train Accs: 0.70979 | Valid Accs: 0.72900 | Time: 9.94 seconds
# Epoch: 8 | Train Loss: 0.57635 | Valid Loss: 0.60443 | Train Accs: 0.71175 | Valid Accs: 0.69850 | Time: 9.70 seconds
# Epoch: 9 | Train Loss: 0.57614 | Valid Loss: 0.57361 | Train Accs: 0.71246 | Valid Accs: 0.72907 | Time: 9.65 seconds
# Epoch: 10 | Train Loss: 0.57794 | Valid Loss: 0.57410 | Train Accs: 0.70995 | Valid Accs: 0.73064 | Time: 10.17 seconds
# Epoch: 11 | Train Loss: 0.57616 | Valid Loss: 0.57772 | Train Accs: 0.71211 | Valid Accs: 0.72864 | Time: 9.83 seconds
# Epoch: 12 | Train Loss: 0.57513 | Valid Loss: 0.57360 | Train Accs: 0.71200 | Valid Accs: 0.72893 | Time: 9.61 seconds
# Epoch: 13 | Train Loss: 0.57744 | Valid Loss: 0.59174 | Train Accs: 0.71084 | Valid Accs: 0.71807 | Time: 9.62 seconds
# Epoch: 14 | Train Loss: 0.57660 | Valid Loss: 0.60432 | Train Accs: 0.71223 | Valid Accs: 0.69964 | Time: 9.96 seconds
# Epoch: 15 | Train Loss: 0.57206 | Valid Loss: 0.57561 | Train Accs: 0.71480 | Valid Accs: 0.72557 | Time: 9.69 seconds
# Epoch: 16 | Train Loss: 0.57419 | Valid Loss: 0.60556 | Train Accs: 0.71162 | Valid Accs: 0.69593 | Time: 9.79 seconds
# Epoch: 17 | Train Loss: 0.57492 | Valid Loss: 0.57365 | Train Accs: 0.71389 | Valid Accs: 0.72814 | Time: 9.90 seconds
# Epoch: 18 | Train Loss: 0.57136 | Valid Loss: 0.57875 | Train Accs: 0.71600 | Valid Accs: 0.72443 | Time: 9.68 seconds
# Epoch: 19 | Train Loss: 0.57218 | Valid Loss: 0.57320 | Train Accs: 0.71546 | Valid Accs: 0.72893 | Time: 9.74 seconds
# Epoch: 20 | Train Loss: 0.57318 | Valid Loss: 0.57182 | Train Accs: 0.71266 | Valid Accs: 0.73207 | Time: 9.91 seconds
# Epoch: 21 | Train Loss: 0.57322 | Valid Loss: 0.57733 | Train Accs: 0.71420 | Valid Accs: 0.72871 | Time: 9.77 seconds
# Epoch: 22 | Train Loss: 0.57381 | Valid Loss: 0.57417 | Train Accs: 0.71280 | Valid Accs: 0.72671 | Time: 9.73 seconds
# Epoch: 23 | Train Loss: 0.57414 | Valid Loss: 0.57132 | Train Accs: 0.71375 | Valid Accs: 0.73214 | Time: 9.75 seconds
# Epoch: 24 | Train Loss: 0.57305 | Valid Loss: 0.57741 | Train Accs: 0.71539 | Valid Accs: 0.72586 | Time: 9.81 seconds
# Epoch: 25 | Train Loss: 0.57342 | Valid Loss: 0.62499 | Train Accs: 0.71243 | Valid Accs: 0.67286 | Time: 9.71 seconds
# Epoch: 26 | Train Loss: 0.57296 | Valid Loss: 0.57149 | Train Accs: 0.71434 | Valid Accs: 0.73414 | Time: 9.69 seconds
# Epoch: 27 | Train Loss: 0.57316 | Valid Loss: 0.57136 | Train Accs: 0.71325 | Valid Accs: 0.73357 | Time: 9.94 seconds
# Epoch: 28 | Train Loss: 0.57280 | Valid Loss: 0.62616 | Train Accs: 0.71596 | Valid Accs: 0.66921 | Time: 9.61 seconds
# Epoch: 29 | Train Loss: 0.57218 | Valid Loss: 0.57046 | Train Accs: 0.71443 | Valid Accs: 0.73436 | Time: 9.70 seconds
# Epoch: 30 | Train Loss: 0.57167 | Valid Loss: 0.57135 | Train Accs: 0.71668 | Valid Accs: 0.73400 | Time: 9.92 seconds
# Epoch: 31 | Train Loss: 0.57356 | Valid Loss: 0.57255 | Train Accs: 0.71477 | Valid Accs: 0.73257 | Time: 9.66 seconds
# Epoch: 32 | Train Loss: 0.57371 | Valid Loss: 0.57115 | Train Accs: 0.71520 | Valid Accs: 0.73257 | Time: 9.79 seconds
# Epoch: 33 | Train Loss: 0.57300 | Valid Loss: 0.57128 | Train Accs: 0.71341 | Valid Accs: 0.73400 | Time: 10.08 seconds
# Epoch: 34 | Train Loss: 0.57368 | Valid Loss: 0.57276 | Train Accs: 0.71341 | Valid Accs: 0.73343 | Time: 9.58 seconds
# Epoch: 35 | Train Loss: 0.57108 | Valid Loss: 0.56993 | Train Accs: 0.71534 | Valid Accs: 0.73479 | Time: 9.54 seconds
# Epoch: 36 | Train Loss: 0.57188 | Valid Loss: 0.57079 | Train Accs: 0.71562 | Valid Accs: 0.73386 | Time: 9.58 seconds
# Epoch: 37 | Train Loss: 0.57044 | Valid Loss: 0.57113 | Train Accs: 0.71509 | Valid Accs: 0.73471 | Time: 9.86 seconds
# Epoch: 38 | Train Loss: 0.57309 | Valid Loss: 0.57045 | Train Accs: 0.71407 | Valid Accs: 0.73286 | Time: 9.97 seconds
# Epoch: 39 | Train Loss: 0.57382 | Valid Loss: 0.57011 | Train Accs: 0.71489 | Valid Accs: 0.73307 | Time: 9.74 seconds
# Epoch: 40 | Train Loss: 0.57199 | Valid Loss: 0.57754 | Train Accs: 0.71484 | Valid Accs: 0.72457 | Time: 9.99 seconds
# Epoch: 41 | Train Loss: 0.57203 | Valid Loss: 0.59908 | Train Accs: 0.71493 | Valid Accs: 0.70993 | Time: 9.63 seconds
# Epoch: 42 | Train Loss: 0.57254 | Valid Loss: 0.58454 | Train Accs: 0.71654 | Valid Accs: 0.72043 | Time: 9.62 seconds
# Epoch: 43 | Train Loss: 0.57213 | Valid Loss: 0.57008 | Train Accs: 0.71398 | Valid Accs: 0.73457 | Time: 9.79 seconds
# Epoch: 44 | Train Loss: 0.57325 | Valid Loss: 0.58196 | Train Accs: 0.71405 | Valid Accs: 0.72000 | Time: 9.60 seconds
# Epoch: 45 | Train Loss: 0.57231 | Valid Loss: 0.57206 | Train Accs: 0.71421 | Valid Accs: 0.73264 | Time: 9.55 seconds
# Epoch: 46 | Train Loss: 0.57328 | Valid Loss: 0.57182 | Train Accs: 0.71513 | Valid Accs: 0.73314 | Time: 9.59 seconds
# Epoch: 47 | Train Loss: 0.57294 | Valid Loss: 0.57044 | Train Accs: 0.71541 | Valid Accs: 0.73379 | Time: 9.97 seconds
# Epoch: 48 | Train Loss: 0.57192 | Valid Loss: 0.57159 | Train Accs: 0.71445 | Valid Accs: 0.73436 | Time: 9.68 seconds
# Epoch: 49 | Train Loss: 0.57209 | Valid Loss: 0.56968 | Train Accs: 0.71714 | Valid Accs: 0.73350 | Time: 9.69 seconds
# Epoch: 50 | Train Loss: 0.57260 | Valid Loss: 0.57219 | Train Accs: 0.71470 | Valid Accs: 0.73107 | Time: 9.92 seconds
# Epoch: 51 | Train Loss: 0.57187 | Valid Loss: 0.57717 | Train Accs: 0.71598 | Valid Accs: 0.72871 | Time: 9.59 seconds
# Epoch: 52 | Train Loss: 0.57245 | Valid Loss: 0.56918 | Train Accs: 0.71562 | Valid Accs: 0.73400 | Time: 9.64 seconds
# Epoch: 53 | Train Loss: 0.57220 | Valid Loss: 0.59767 | Train Accs: 0.71343 | Valid Accs: 0.70521 | Time: 9.79 seconds
# Epoch: 54 | Train Loss: 0.57258 | Valid Loss: 0.61891 | Train Accs: 0.71545 | Valid Accs: 0.67807 | Time: 9.60 seconds
# Epoch: 55 | Train Loss: 0.57276 | Valid Loss: 0.58322 | Train Accs: 0.71695 | Valid Accs: 0.72286 | Time: 9.55 seconds
# Epoch: 56 | Train Loss: 0.57174 | Valid Loss: 0.57019 | Train Accs: 0.71493 | Valid Accs: 0.73436 | Time: 9.68 seconds
# Epoch: 57 | Train Loss: 0.57244 | Valid Loss: 0.58739 | Train Accs: 0.71582 | Valid Accs: 0.71821 | Time: 9.88 seconds
# Epoch: 58 | Train Loss: 0.57251 | Valid Loss: 0.57293 | Train Accs: 0.71652 | Valid Accs: 0.73186 | Time: 9.71 seconds
# Epoch: 59 | Train Loss: 0.57209 | Valid Loss: 0.57071 | Train Accs: 0.71568 | Valid Accs: 0.73436 | Time: 9.59 seconds
# Epoch: 60 | Train Loss: 0.57009 | Valid Loss: 0.57172 | Train Accs: 0.71661 | Valid Accs: 0.73171 | Time: 9.84 seconds
# Epoch: 61 | Train Loss: 0.57330 | Valid Loss: 0.57203 | Train Accs: 0.71396 | Valid Accs: 0.73107 | Time: 9.66 seconds
# Epoch: 62 | Train Loss: 0.57463 | Valid Loss: 0.57060 | Train Accs: 0.71284 | Valid Accs: 0.73436 | Time: 9.66 seconds
# Epoch: 63 | Train Loss: 0.57289 | Valid Loss: 0.58797 | Train Accs: 0.71264 | Valid Accs: 0.71643 | Time: 10.00 seconds
# Epoch: 64 | Train Loss: 0.57232 | Valid Loss: 0.57147 | Train Accs: 0.71471 | Valid Accs: 0.73314 | Time: 9.91 seconds
# Epoch: 65 | Train Loss: 0.57266 | Valid Loss: 0.56954 | Train Accs: 0.71584 | Valid Accs: 0.73543 | Time: 9.62 seconds
# Epoch: 66 | Train Loss: 0.57167 | Valid Loss: 0.57472 | Train Accs: 0.71702 | Valid Accs: 0.72757 | Time: 9.61 seconds
# Epoch: 67 | Train Loss: 0.57258 | Valid Loss: 0.57053 | Train Accs: 0.71486 | Valid Accs: 0.73329 | Time: 9.80 seconds
# Epoch: 68 | Train Loss: 0.57362 | Valid Loss: 0.56845 | Train Accs: 0.71652 | Valid Accs: 0.73464 | Time: 9.53 seconds
# Epoch: 69 | Train Loss: 0.57219 | Valid Loss: 0.56859 | Train Accs: 0.71454 | Valid Accs: 0.73600 | Time: 9.65 seconds
# Epoch: 70 | Train Loss: 0.57244 | Valid Loss: 0.57085 | Train Accs: 0.71593 | Valid Accs: 0.73221 | Time: 9.78 seconds
# Epoch: 71 | Train Loss: 0.57101 | Valid Loss: 0.56902 | Train Accs: 0.71613 | Valid Accs: 0.73150 | Time: 9.60 seconds
# Epoch: 72 | Train Loss: 0.57381 | Valid Loss: 0.56977 | Train Accs: 0.71420 | Valid Accs: 0.73500 | Time: 9.65 seconds
# Epoch: 73 | Train Loss: 0.57136 | Valid Loss: 0.63067 | Train Accs: 0.71523 | Valid Accs: 0.65471 | Time: 9.84 seconds
# Epoch: 74 | Train Loss: 0.57245 | Valid Loss: 0.59167 | Train Accs: 0.71388 | Valid Accs: 0.71714 | Time: 9.63 seconds
# Epoch: 75 | Train Loss: 0.57165 | Valid Loss: 0.62489 | Train Accs: 0.71423 | Valid Accs: 0.66864 | Time: 9.62 seconds
# Epoch: 76 | Train Loss: 0.57264 | Valid Loss: 0.57027 | Train Accs: 0.71377 | Valid Accs: 0.73471 | Time: 9.66 seconds
# Epoch: 77 | Train Loss: 0.57255 | Valid Loss: 0.56884 | Train Accs: 0.71441 | Valid Accs: 0.73543 | Time: 9.82 seconds
# Epoch: 78 | Train Loss: 0.57350 | Valid Loss: 0.56844 | Train Accs: 0.71682 | Valid Accs: 0.73443 | Time: 9.59 seconds
# Epoch: 79 | Train Loss: 0.57123 | Valid Loss: 0.56798 | Train Accs: 0.71645 | Valid Accs: 0.73457 | Time: 9.56 seconds
# Epoch: 80 | Train Loss: 0.57127 | Valid Loss: 0.56898 | Train Accs: 0.71702 | Valid Accs: 0.73579 | Time: 9.78 seconds
# Epoch: 81 | Train Loss: 0.57278 | Valid Loss: 0.61475 | Train Accs: 0.71500 | Valid Accs: 0.68143 | Time: 9.58 seconds
# Epoch: 82 | Train Loss: 0.57112 | Valid Loss: 0.62706 | Train Accs: 0.71571 | Valid Accs: 0.66150 | Time: 9.65 seconds
# Epoch: 83 | Train Loss: 0.57175 | Valid Loss: 0.60812 | Train Accs: 0.71596 | Valid Accs: 0.69329 | Time: 9.93 seconds
# Epoch: 84 | Train Loss: 0.57219 | Valid Loss: 0.57222 | Train Accs: 0.71377 | Valid Accs: 0.73093 | Time: 9.93 seconds
# Epoch: 85 | Train Loss: 0.57287 | Valid Loss: 0.56932 | Train Accs: 0.71254 | Valid Accs: 0.73457 | Time: 9.62 seconds
# Epoch: 86 | Train Loss: 0.57265 | Valid Loss: 0.57194 | Train Accs: 0.71330 | Valid Accs: 0.72843 | Time: 9.60 seconds
# Epoch: 87 | Train Loss: 0.57303 | Valid Loss: 0.58400 | Train Accs: 0.71300 | Valid Accs: 0.72229 | Time: 9.82 seconds
# Epoch: 88 | Train Loss: 0.57085 | Valid Loss: 0.57207 | Train Accs: 0.71514 | Valid Accs: 0.73164 | Time: 9.68 seconds
# Epoch: 89 | Train Loss: 0.57230 | Valid Loss: 0.56925 | Train Accs: 0.71384 | Valid Accs: 0.73421 | Time: 9.57 seconds
# Epoch: 90 | Train Loss: 0.57008 | Valid Loss: 0.56963 | Train Accs: 0.71523 | Valid Accs: 0.73264 | Time: 9.96 seconds
# Epoch: 91 | Train Loss: 0.57136 | Valid Loss: 0.59013 | Train Accs: 0.71695 | Valid Accs: 0.71707 | Time: 9.59 seconds
# Epoch: 92 | Train Loss: 0.57394 | Valid Loss: 0.56889 | Train Accs: 0.71337 | Valid Accs: 0.73457 | Time: 9.63 seconds
# Epoch: 93 | Train Loss: 0.57278 | Valid Loss: 0.56955 | Train Accs: 0.71350 | Valid Accs: 0.73243 | Time: 9.81 seconds
# Epoch: 94 | Train Loss: 0.57133 | Valid Loss: 0.56869 | Train Accs: 0.71875 | Valid Accs: 0.73479 | Time: 9.74 seconds
# Epoch: 95 | Train Loss: 0.57264 | Valid Loss: 0.57095 | Train Accs: 0.71630 | Valid Accs: 0.73271 | Time: 9.68 seconds
# Epoch: 96 | Train Loss: 0.57144 | Valid Loss: 0.56854 | Train Accs: 0.71511 | Valid Accs: 0.73486 | Time: 9.57 seconds
# Epoch: 97 | Train Loss: 0.57256 | Valid Loss: 0.57220 | Train Accs: 0.71362 | Valid Accs: 0.73250 | Time: 9.90 seconds
# Epoch: 98 | Train Loss: 0.57262 | Valid Loss: 0.56900 | Train Accs: 0.71375 | Valid Accs: 0.73379 | Time: 9.68 seconds
# Epoch: 99 | Train Loss: 0.57135 | Valid Loss: 0.57094 | Train Accs: 0.71461 | Valid Accs: 0.73393 | Time: 9.65 seconds
# Epoch: 100 | Train Loss: 0.57156 | Valid Loss: 0.56957 | Train Accs: 0.71568 | Valid Accs: 0.73393 | Time: 9.93 seconds
# Epoch: 101 | Train Loss: 0.57225 | Valid Loss: 0.59620 | Train Accs: 0.71450 | Valid Accs: 0.70886 | Time: 9.91 seconds
# Epoch: 102 | Train Loss: 0.57257 | Valid Loss: 0.56810 | Train Accs: 0.71571 | Valid Accs: 0.73543 | Time: 9.64 seconds
# Epoch: 103 | Train Loss: 0.57101 | Valid Loss: 0.58201 | Train Accs: 0.71682 | Valid Accs: 0.72357 | Time: 9.87 seconds
# Epoch: 104 | Train Loss: 0.57092 | Valid Loss: 0.60458 | Train Accs: 0.71509 | Valid Accs: 0.69721 | Time: 9.58 seconds
# Epoch: 105 | Train Loss: 0.57121 | Valid Loss: 0.56962 | Train Accs: 0.71804 | Valid Accs: 0.73207 | Time: 9.65 seconds
# Epoch: 106 | Train Loss: 0.57287 | Valid Loss: 0.57050 | Train Accs: 0.71477 | Valid Accs: 0.73593 | Time: 9.63 seconds
# Epoch: 107 | Train Loss: 0.57161 | Valid Loss: 0.62948 | Train Accs: 0.71537 | Valid Accs: 0.66507 | Time: 9.82 seconds
# Epoch: 108 | Train Loss: 0.57147 | Valid Loss: 0.57068 | Train Accs: 0.71507 | Valid Accs: 0.73293 | Time: 9.65 seconds
# Epoch: 109 | Train Loss: 0.57193 | Valid Loss: 0.56812 | Train Accs: 0.71539 | Valid Accs: 0.73429 | Time: 9.59 seconds
# Epoch: 110 | Train Loss: 0.57235 | Valid Loss: 0.57056 | Train Accs: 0.71491 | Valid Accs: 0.73493 | Time: 9.85 seconds
# Epoch: 111 | Train Loss: 0.57211 | Valid Loss: 0.56905 | Train Accs: 0.71525 | Valid Accs: 0.73514 | Time: 9.62 seconds
# Epoch: 112 | Train Loss: 0.57215 | Valid Loss: 0.56853 | Train Accs: 0.71516 | Valid Accs: 0.73507 | Time: 9.63 seconds
# Epoch: 113 | Train Loss: 0.57091 | Valid Loss: 0.56799 | Train Accs: 0.71470 | Valid Accs: 0.73607 | Time: 9.95 seconds
# Epoch: 114 | Train Loss: 0.57357 | Valid Loss: 0.56889 | Train Accs: 0.71634 | Valid Accs: 0.73400 | Time: 9.50 seconds
# Epoch: 115 | Train Loss: 0.57072 | Valid Loss: 0.56817 | Train Accs: 0.71602 | Valid Accs: 0.73371 | Time: 9.64 seconds
# Epoch: 116 | Train Loss: 0.57200 | Valid Loss: 0.56891 | Train Accs: 0.71382 | Valid Accs: 0.73479 | Time: 9.61 seconds
# Epoch: 117 | Train Loss: 0.57027 | Valid Loss: 0.56848 | Train Accs: 0.71659 | Valid Accs: 0.73414 | Time: 10.22 seconds
# Epoch: 118 | Train Loss: 0.57262 | Valid Loss: 0.58873 | Train Accs: 0.71489 | Valid Accs: 0.71800 | Time: 9.55 seconds
# Epoch: 119 | Train Loss: 0.57192 | Valid Loss: 0.56962 | Train Accs: 0.71482 | Valid Accs: 0.73479 | Time: 9.59 seconds
# Epoch: 120 | Train Loss: 0.57137 | Valid Loss: 0.59272 | Train Accs: 0.71579 | Valid Accs: 0.71336 | Time: 9.80 seconds
# Epoch: 121 | Train Loss: 0.57221 | Valid Loss: 0.63189 | Train Accs: 0.71784 | Valid Accs: 0.65693 | Time: 9.68 seconds
# Epoch: 122 | Train Loss: 0.57201 | Valid Loss: 0.58505 | Train Accs: 0.71737 | Valid Accs: 0.71907 | Time: 9.70 seconds
# Epoch: 123 | Train Loss: 0.57226 | Valid Loss: 0.57655 | Train Accs: 0.71471 | Valid Accs: 0.72764 | Time: 9.72 seconds
# Epoch: 124 | Train Loss: 0.57132 | Valid Loss: 0.57331 | Train Accs: 0.71755 | Valid Accs: 0.73114 | Time: 9.58 seconds
# Epoch: 125 | Train Loss: 0.57162 | Valid Loss: 0.57183 | Train Accs: 0.71705 | Valid Accs: 0.73021 | Time: 9.61 seconds
# Epoch: 126 | Train Loss: 0.57200 | Valid Loss: 0.57134 | Train Accs: 0.71429 | Valid Accs: 0.73421 | Time: 9.61 seconds
# Epoch: 127 | Train Loss: 0.57311 | Valid Loss: 0.56929 | Train Accs: 0.71539 | Valid Accs: 0.73486 | Time: 9.81 seconds
# Epoch: 128 | Train Loss: 0.57261 | Valid Loss: 0.57187 | Train Accs: 0.71361 | Valid Accs: 0.72929 | Time: 9.68 seconds
# Epoch: 129 | Train Loss: 0.57170 | Valid Loss: 0.56815 | Train Accs: 0.71648 | Valid Accs: 0.73300 | Time: 9.67 seconds
#
# Early Stopping at Epoch 130
#
# **************************************************
#
# Best Validation Loss at Epoch 79
#
# **************************************************
#
# Best Validation Accs at Epoch 113
#
# **************************************************
#
# Time Taken [130 Epochs] : 21.09 minutes
#
# **************************************************
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 0.66646 | Valid Loss: 0.65081 | Train Accs: 0.59498 | Valid Accs: 0.64203 | Time: 1.89 seconds
# Epoch: 2 | Train Loss: 0.64994 | Valid Loss: 0.64844 | Train Accs: 0.62486 | Valid Accs: 0.63180 | Time: 1.86 seconds
# Epoch: 3 | Train Loss: 0.63826 | Valid Loss: 0.64257 | Train Accs: 0.64138 | Valid Accs: 0.64052 | Time: 1.87 seconds
# Epoch: 4 | Train Loss: 0.62703 | Valid Loss: 0.63224 | Train Accs: 0.65675 | Valid Accs: 0.65313 | Time: 1.98 seconds
# Epoch: 5 | Train Loss: 0.62144 | Valid Loss: 0.63102 | Train Accs: 0.66184 | Valid Accs: 0.65091 | Time: 2.01 seconds
# Epoch: 6 | Train Loss: 0.61523 | Valid Loss: 0.62730 | Train Accs: 0.67008 | Valid Accs: 0.65552 | Time: 1.84 seconds
# Epoch: 7 | Train Loss: 0.60997 | Valid Loss: 0.62609 | Train Accs: 0.67844 | Valid Accs: 0.65510 | Time: 1.85 seconds
# Epoch: 8 | Train Loss: 0.60678 | Valid Loss: 0.62384 | Train Accs: 0.68055 | Valid Accs: 0.65650 | Time: 1.86 seconds
# Epoch: 9 | Train Loss: 0.60301 | Valid Loss: 0.62289 | Train Accs: 0.68600 | Valid Accs: 0.65671 | Time: 1.96 seconds
# Epoch: 10 | Train Loss: 0.60225 | Valid Loss: 0.61086 | Train Accs: 0.68683 | Valid Accs: 0.67282 | Time: 1.98 seconds
# Epoch: 11 | Train Loss: 0.59889 | Valid Loss: 0.61098 | Train Accs: 0.68913 | Valid Accs: 0.67172 | Time: 1.88 seconds
# Epoch: 12 | Train Loss: 0.59775 | Valid Loss: 0.62517 | Train Accs: 0.69239 | Valid Accs: 0.65187 | Time: 1.87 seconds
# Epoch: 13 | Train Loss: 0.59532 | Valid Loss: 0.61963 | Train Accs: 0.69428 | Valid Accs: 0.66085 | Time: 1.94 seconds
# Epoch: 14 | Train Loss: 0.59403 | Valid Loss: 0.61240 | Train Accs: 0.69550 | Valid Accs: 0.66914 | Time: 1.85 seconds
# Epoch: 15 | Train Loss: 0.59263 | Valid Loss: 0.61871 | Train Accs: 0.69718 | Valid Accs: 0.66175 | Time: 1.97 seconds
# Epoch: 16 | Train Loss: 0.59240 | Valid Loss: 0.61627 | Train Accs: 0.69894 | Valid Accs: 0.66642 | Time: 1.83 seconds
# Epoch: 17 | Train Loss: 0.58961 | Valid Loss: 0.60392 | Train Accs: 0.70105 | Valid Accs: 0.68481 | Time: 2.06 seconds
# Epoch: 18 | Train Loss: 0.58973 | Valid Loss: 0.60913 | Train Accs: 0.70011 | Valid Accs: 0.67435 | Time: 1.97 seconds
# Epoch: 19 | Train Loss: 0.58770 | Valid Loss: 0.61755 | Train Accs: 0.70421 | Valid Accs: 0.66350 | Time: 1.84 seconds
# Epoch: 20 | Train Loss: 0.58922 | Valid Loss: 0.62005 | Train Accs: 0.70450 | Valid Accs: 0.65967 | Time: 1.96 seconds
# Epoch: 21 | Train Loss: 0.58613 | Valid Loss: 0.61535 | Train Accs: 0.70468 | Valid Accs: 0.66643 | Time: 1.84 seconds
# Epoch: 22 | Train Loss: 0.58708 | Valid Loss: 0.60593 | Train Accs: 0.70597 | Valid Accs: 0.68342 | Time: 1.85 seconds
# Epoch: 23 | Train Loss: 0.58501 | Valid Loss: 0.61618 | Train Accs: 0.70730 | Valid Accs: 0.66636 | Time: 2.00 seconds
# Epoch: 24 | Train Loss: 0.58579 | Valid Loss: 0.61519 | Train Accs: 0.70743 | Valid Accs: 0.66608 | Time: 1.86 seconds
# Epoch: 25 | Train Loss: 0.58451 | Valid Loss: 0.60545 | Train Accs: 0.70777 | Valid Accs: 0.68223 | Time: 1.99 seconds
# Epoch: 26 | Train Loss: 0.58653 | Valid Loss: 0.58889 | Train Accs: 0.70605 | Valid Accs: 0.70488 | Time: 1.85 seconds
# Epoch: 27 | Train Loss: 0.58409 | Valid Loss: 0.61676 | Train Accs: 0.70830 | Valid Accs: 0.66685 | Time: 1.90 seconds
# Epoch: 28 | Train Loss: 0.58340 | Valid Loss: 0.59841 | Train Accs: 0.70940 | Valid Accs: 0.69505 | Time: 2.00 seconds
# Epoch: 29 | Train Loss: 0.58385 | Valid Loss: 0.59639 | Train Accs: 0.71022 | Valid Accs: 0.69700 | Time: 1.88 seconds
# Epoch: 30 | Train Loss: 0.58210 | Valid Loss: 0.60984 | Train Accs: 0.71212 | Valid Accs: 0.68056 | Time: 2.00 seconds
# Epoch: 31 | Train Loss: 0.58165 | Valid Loss: 0.61657 | Train Accs: 0.70987 | Valid Accs: 0.66574 | Time: 1.85 seconds
# Epoch: 32 | Train Loss: 0.58141 | Valid Loss: 0.60072 | Train Accs: 0.71183 | Valid Accs: 0.69520 | Time: 1.84 seconds
# Epoch: 33 | Train Loss: 0.58020 | Valid Loss: 0.61406 | Train Accs: 0.71300 | Valid Accs: 0.67166 | Time: 1.96 seconds
# Epoch: 34 | Train Loss: 0.58138 | Valid Loss: 0.61230 | Train Accs: 0.71075 | Valid Accs: 0.67277 | Time: 2.05 seconds
# Epoch: 35 | Train Loss: 0.57879 | Valid Loss: 0.61302 | Train Accs: 0.71315 | Valid Accs: 0.67006 | Time: 1.95 seconds
# Epoch: 36 | Train Loss: 0.57981 | Valid Loss: 0.61822 | Train Accs: 0.71235 | Valid Accs: 0.66609 | Time: 1.83 seconds
# Epoch: 37 | Train Loss: 0.57904 | Valid Loss: 0.59464 | Train Accs: 0.71355 | Valid Accs: 0.70279 | Time: 1.86 seconds
# Epoch: 38 | Train Loss: 0.57872 | Valid Loss: 0.61723 | Train Accs: 0.71416 | Valid Accs: 0.66609 | Time: 1.97 seconds
# Epoch: 39 | Train Loss: 0.57755 | Valid Loss: 0.61252 | Train Accs: 0.71279 | Valid Accs: 0.67403 | Time: 1.86 seconds
# Epoch: 40 | Train Loss: 0.57798 | Valid Loss: 0.61248 | Train Accs: 0.71309 | Valid Accs: 0.67605 | Time: 2.00 seconds
# Epoch: 41 | Train Loss: 0.57912 | Valid Loss: 0.61737 | Train Accs: 0.71409 | Valid Accs: 0.66558 | Time: 1.85 seconds
# Epoch: 42 | Train Loss: 0.57755 | Valid Loss: 0.61553 | Train Accs: 0.71590 | Valid Accs: 0.67083 | Time: 1.84 seconds
# Epoch: 43 | Train Loss: 0.57732 | Valid Loss: 0.61451 | Train Accs: 0.71547 | Valid Accs: 0.67153 | Time: 1.99 seconds
# Epoch: 44 | Train Loss: 0.57786 | Valid Loss: 0.61265 | Train Accs: 0.71425 | Valid Accs: 0.67745 | Time: 1.86 seconds
# Epoch: 45 | Train Loss: 0.57657 | Valid Loss: 0.60955 | Train Accs: 0.71247 | Valid Accs: 0.67981 | Time: 1.97 seconds
# Epoch: 46 | Train Loss: 0.57720 | Valid Loss: 0.60929 | Train Accs: 0.71420 | Valid Accs: 0.68079 | Time: 1.85 seconds
# Epoch: 47 | Train Loss: 0.57699 | Valid Loss: 0.61803 | Train Accs: 0.71471 | Valid Accs: 0.66706 | Time: 1.83 seconds
# Epoch: 48 | Train Loss: 0.57722 | Valid Loss: 0.61734 | Train Accs: 0.71630 | Valid Accs: 0.66781 | Time: 1.97 seconds
# Epoch: 49 | Train Loss: 0.57680 | Valid Loss: 0.61484 | Train Accs: 0.71482 | Valid Accs: 0.66929 | Time: 1.85 seconds
# Epoch: 50 | Train Loss: 0.57622 | Valid Loss: 0.60252 | Train Accs: 0.71641 | Valid Accs: 0.69413 | Time: 2.04 seconds
# Epoch: 51 | Train Loss: 0.57642 | Valid Loss: 0.60990 | Train Accs: 0.71568 | Valid Accs: 0.68001 | Time: 1.96 seconds
# Epoch: 52 | Train Loss: 0.57709 | Valid Loss: 0.61303 | Train Accs: 0.71730 | Valid Accs: 0.67485 | Time: 1.89 seconds
# Epoch: 53 | Train Loss: 0.57526 | Valid Loss: 0.61312 | Train Accs: 0.71797 | Valid Accs: 0.67221 | Time: 2.00 seconds
# Epoch: 54 | Train Loss: 0.57440 | Valid Loss: 0.61375 | Train Accs: 0.71848 | Valid Accs: 0.67291 | Time: 1.98 seconds
# Epoch: 55 | Train Loss: 0.57645 | Valid Loss: 0.61102 | Train Accs: 0.71603 | Valid Accs: 0.67889 | Time: 1.87 seconds
# Epoch: 56 | Train Loss: 0.57779 | Valid Loss: 0.59278 | Train Accs: 0.71592 | Valid Accs: 0.70426 | Time: 1.88 seconds
# Epoch: 57 | Train Loss: 0.57526 | Valid Loss: 0.59961 | Train Accs: 0.71731 | Valid Accs: 0.69770 | Time: 1.88 seconds
# Epoch: 58 | Train Loss: 0.57403 | Valid Loss: 0.59609 | Train Accs: 0.71484 | Valid Accs: 0.70321 | Time: 1.96 seconds
# Epoch: 59 | Train Loss: 0.57433 | Valid Loss: 0.61401 | Train Accs: 0.71697 | Valid Accs: 0.67472 | Time: 1.99 seconds
# Epoch: 60 | Train Loss: 0.57411 | Valid Loss: 0.61417 | Train Accs: 0.71799 | Valid Accs: 0.67416 | Time: 1.85 seconds
# Epoch: 61 | Train Loss: 0.57465 | Valid Loss: 0.61158 | Train Accs: 0.71738 | Valid Accs: 0.67756 | Time: 1.87 seconds
# Epoch: 62 | Train Loss: 0.57386 | Valid Loss: 0.59148 | Train Accs: 0.71788 | Valid Accs: 0.70502 | Time: 1.95 seconds
# Epoch: 63 | Train Loss: 0.57351 | Valid Loss: 0.60857 | Train Accs: 0.71801 | Valid Accs: 0.68426 | Time: 1.87 seconds
# Epoch: 64 | Train Loss: 0.57455 | Valid Loss: 0.61318 | Train Accs: 0.71734 | Valid Accs: 0.67360 | Time: 1.99 seconds
# Epoch: 65 | Train Loss: 0.57299 | Valid Loss: 0.60916 | Train Accs: 0.71642 | Valid Accs: 0.68328 | Time: 1.86 seconds
# Epoch: 66 | Train Loss: 0.57439 | Valid Loss: 0.61585 | Train Accs: 0.71661 | Valid Accs: 0.67096 | Time: 1.85 seconds
# Epoch: 67 | Train Loss: 0.57443 | Valid Loss: 0.61176 | Train Accs: 0.71764 | Valid Accs: 0.67889 | Time: 2.02 seconds
# Epoch: 68 | Train Loss: 0.57420 | Valid Loss: 0.61217 | Train Accs: 0.71779 | Valid Accs: 0.67785 | Time: 1.87 seconds
# Epoch: 69 | Train Loss: 0.57395 | Valid Loss: 0.60429 | Train Accs: 0.71933 | Valid Accs: 0.69053 | Time: 2.01 seconds
# Epoch: 70 | Train Loss: 0.57303 | Valid Loss: 0.59562 | Train Accs: 0.71898 | Valid Accs: 0.70266 | Time: 1.84 seconds
# Epoch: 71 | Train Loss: 0.57372 | Valid Loss: 0.61145 | Train Accs: 0.72074 | Valid Accs: 0.67862 | Time: 1.82 seconds
# Epoch: 72 | Train Loss: 0.57529 | Valid Loss: 0.60183 | Train Accs: 0.71759 | Valid Accs: 0.69423 | Time: 1.94 seconds
# Epoch: 73 | Train Loss: 0.57383 | Valid Loss: 0.61604 | Train Accs: 0.71871 | Valid Accs: 0.67213 | Time: 1.83 seconds
# Epoch: 74 | Train Loss: 0.57318 | Valid Loss: 0.61897 | Train Accs: 0.71879 | Valid Accs: 0.66551 | Time: 2.03 seconds
# Epoch: 75 | Train Loss: 0.57324 | Valid Loss: 0.60148 | Train Accs: 0.71934 | Valid Accs: 0.69118 | Time: 1.85 seconds
# Epoch: 76 | Train Loss: 0.57204 | Valid Loss: 0.59812 | Train Accs: 0.71957 | Valid Accs: 0.70160 | Time: 1.86 seconds
#
# Early Stopping at Epoch 77
#
# **************************************************
#
# Best Validation Loss at Epoch 26
#
# **************************************************
#
# Best Validation Accs at Epoch 62
#
# **************************************************
#
# Time Taken [77 Epochs] : 2.46 minutes
#
# **************************************************
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 0.66545 | Valid Loss: 0.66106 | Train Accs: 0.59837 | Valid Accs: 0.61895 | Time: 1.89 seconds
# Epoch: 2 | Train Loss: 0.64782 | Valid Loss: 0.64940 | Train Accs: 0.62673 | Valid Accs: 0.64062 | Time: 2.00 seconds
# Epoch: 3 | Train Loss: 0.63657 | Valid Loss: 0.64470 | Train Accs: 0.64153 | Valid Accs: 0.64395 | Time: 1.91 seconds
# Epoch: 4 | Train Loss: 0.62521 | Valid Loss: 0.62889 | Train Accs: 0.65532 | Valid Accs: 0.67300 | Time: 1.87 seconds
# Epoch: 5 | Train Loss: 0.61663 | Valid Loss: 0.63551 | Train Accs: 0.66871 | Valid Accs: 0.65201 | Time: 2.00 seconds
# Epoch: 6 | Train Loss: 0.61153 | Valid Loss: 0.62868 | Train Accs: 0.67444 | Valid Accs: 0.66115 | Time: 1.88 seconds
# Epoch: 7 | Train Loss: 0.60909 | Valid Loss: 0.62512 | Train Accs: 0.67784 | Valid Accs: 0.66547 | Time: 2.06 seconds
# Epoch: 8 | Train Loss: 0.60455 | Valid Loss: 0.62500 | Train Accs: 0.68447 | Valid Accs: 0.66366 | Time: 1.88 seconds
# Epoch: 9 | Train Loss: 0.60091 | Valid Loss: 0.60545 | Train Accs: 0.68813 | Valid Accs: 0.70101 | Time: 1.89 seconds
# Epoch: 10 | Train Loss: 0.59746 | Valid Loss: 0.62114 | Train Accs: 0.69060 | Valid Accs: 0.66792 | Time: 2.00 seconds
# Epoch: 11 | Train Loss: 0.59652 | Valid Loss: 0.60437 | Train Accs: 0.69168 | Valid Accs: 0.70103 | Time: 1.87 seconds
# Epoch: 12 | Train Loss: 0.59339 | Valid Loss: 0.61466 | Train Accs: 0.69510 | Valid Accs: 0.67970 | Time: 1.96 seconds
# Epoch: 13 | Train Loss: 0.59299 | Valid Loss: 0.61414 | Train Accs: 0.69669 | Valid Accs: 0.67929 | Time: 1.88 seconds
# Epoch: 14 | Train Loss: 0.59043 | Valid Loss: 0.59883 | Train Accs: 0.69811 | Valid Accs: 0.71290 | Time: 1.90 seconds
# Epoch: 15 | Train Loss: 0.58769 | Valid Loss: 0.60997 | Train Accs: 0.70100 | Valid Accs: 0.68640 | Time: 1.99 seconds
# Epoch: 16 | Train Loss: 0.58904 | Valid Loss: 0.61392 | Train Accs: 0.70169 | Valid Accs: 0.68075 | Time: 1.84 seconds
# Epoch: 17 | Train Loss: 0.58858 | Valid Loss: 0.61715 | Train Accs: 0.70195 | Valid Accs: 0.67198 | Time: 1.97 seconds
# Epoch: 18 | Train Loss: 0.58467 | Valid Loss: 0.62263 | Train Accs: 0.70618 | Valid Accs: 0.66123 | Time: 1.88 seconds
# Epoch: 19 | Train Loss: 0.58507 | Valid Loss: 0.60816 | Train Accs: 0.70610 | Valid Accs: 0.69031 | Time: 1.85 seconds
# Epoch: 20 | Train Loss: 0.58564 | Valid Loss: 0.62061 | Train Accs: 0.70698 | Valid Accs: 0.66689 | Time: 2.02 seconds
# Epoch: 21 | Train Loss: 0.58239 | Valid Loss: 0.60924 | Train Accs: 0.71064 | Valid Accs: 0.68988 | Time: 2.01 seconds
# Epoch: 22 | Train Loss: 0.58483 | Valid Loss: 0.61034 | Train Accs: 0.70946 | Valid Accs: 0.68688 | Time: 1.89 seconds
# Epoch: 23 | Train Loss: 0.58292 | Valid Loss: 0.61481 | Train Accs: 0.70974 | Valid Accs: 0.68088 | Time: 1.90 seconds
# Epoch: 24 | Train Loss: 0.58119 | Valid Loss: 0.61662 | Train Accs: 0.71109 | Valid Accs: 0.67747 | Time: 2.08 seconds
# Epoch: 25 | Train Loss: 0.58102 | Valid Loss: 0.61197 | Train Accs: 0.71084 | Valid Accs: 0.68836 | Time: 2.16 seconds
# Epoch: 26 | Train Loss: 0.58082 | Valid Loss: 0.62206 | Train Accs: 0.71109 | Valid Accs: 0.66619 | Time: 2.06 seconds
# Epoch: 27 | Train Loss: 0.57967 | Valid Loss: 0.59653 | Train Accs: 0.71045 | Valid Accs: 0.71841 | Time: 1.85 seconds
# Epoch: 28 | Train Loss: 0.58022 | Valid Loss: 0.61867 | Train Accs: 0.71187 | Valid Accs: 0.67616 | Time: 1.86 seconds
# Epoch: 29 | Train Loss: 0.57830 | Valid Loss: 0.59867 | Train Accs: 0.71293 | Valid Accs: 0.71173 | Time: 2.00 seconds
# Epoch: 30 | Train Loss: 0.57788 | Valid Loss: 0.61741 | Train Accs: 0.71469 | Valid Accs: 0.67560 | Time: 1.85 seconds
# Epoch: 31 | Train Loss: 0.57794 | Valid Loss: 0.62001 | Train Accs: 0.71497 | Valid Accs: 0.67275 | Time: 2.02 seconds
# Epoch: 32 | Train Loss: 0.57768 | Valid Loss: 0.59827 | Train Accs: 0.71553 | Valid Accs: 0.72282 | Time: 1.85 seconds
# Epoch: 33 | Train Loss: 0.57662 | Valid Loss: 0.60357 | Train Accs: 0.71397 | Valid Accs: 0.70364 | Time: 1.88 seconds
# Epoch: 34 | Train Loss: 0.57634 | Valid Loss: 0.60463 | Train Accs: 0.71350 | Valid Accs: 0.70189 | Time: 1.97 seconds
# Epoch: 35 | Train Loss: 0.57411 | Valid Loss: 0.60729 | Train Accs: 0.71640 | Valid Accs: 0.69581 | Time: 1.88 seconds
# Epoch: 36 | Train Loss: 0.57782 | Valid Loss: 0.61787 | Train Accs: 0.71512 | Valid Accs: 0.67922 | Time: 1.99 seconds
# Epoch: 37 | Train Loss: 0.57564 | Valid Loss: 0.61523 | Train Accs: 0.71574 | Valid Accs: 0.68144 | Time: 1.92 seconds
# Epoch: 38 | Train Loss: 0.57501 | Valid Loss: 0.61323 | Train Accs: 0.71785 | Valid Accs: 0.68543 | Time: 1.85 seconds
# Epoch: 39 | Train Loss: 0.57649 | Valid Loss: 0.61335 | Train Accs: 0.71545 | Valid Accs: 0.68815 | Time: 1.98 seconds
# Epoch: 40 | Train Loss: 0.57476 | Valid Loss: 0.60946 | Train Accs: 0.71774 | Valid Accs: 0.69533 | Time: 1.97 seconds
# Epoch: 41 | Train Loss: 0.57452 | Valid Loss: 0.62133 | Train Accs: 0.71760 | Valid Accs: 0.66927 | Time: 2.01 seconds
# Epoch: 42 | Train Loss: 0.57475 | Valid Loss: 0.61655 | Train Accs: 0.71713 | Valid Accs: 0.68033 | Time: 1.85 seconds
# Epoch: 43 | Train Loss: 0.57367 | Valid Loss: 0.61676 | Train Accs: 0.71803 | Valid Accs: 0.68179 | Time: 1.88 seconds
# Epoch: 44 | Train Loss: 0.57446 | Valid Loss: 0.60905 | Train Accs: 0.71622 | Valid Accs: 0.69282 | Time: 1.99 seconds
# Epoch: 45 | Train Loss: 0.57466 | Valid Loss: 0.59953 | Train Accs: 0.71742 | Valid Accs: 0.70602 | Time: 1.84 seconds
# Epoch: 46 | Train Loss: 0.57342 | Valid Loss: 0.61854 | Train Accs: 0.71612 | Valid Accs: 0.67902 | Time: 2.00 seconds
# Epoch: 47 | Train Loss: 0.57187 | Valid Loss: 0.61973 | Train Accs: 0.71952 | Valid Accs: 0.67323 | Time: 1.89 seconds
# Epoch: 48 | Train Loss: 0.57350 | Valid Loss: 0.60617 | Train Accs: 0.71902 | Valid Accs: 0.69889 | Time: 1.93 seconds
# Epoch: 49 | Train Loss: 0.57406 | Valid Loss: 0.59581 | Train Accs: 0.71967 | Valid Accs: 0.71668 | Time: 2.19 seconds
# Epoch: 50 | Train Loss: 0.57188 | Valid Loss: 0.61704 | Train Accs: 0.72001 | Valid Accs: 0.68396 | Time: 1.93 seconds
# Epoch: 51 | Train Loss: 0.57354 | Valid Loss: 0.61274 | Train Accs: 0.71705 | Valid Accs: 0.68815 | Time: 2.01 seconds
# Epoch: 52 | Train Loss: 0.57235 | Valid Loss: 0.60855 | Train Accs: 0.71915 | Valid Accs: 0.69875 | Time: 1.88 seconds
# Epoch: 53 | Train Loss: 0.57239 | Valid Loss: 0.60066 | Train Accs: 0.71975 | Valid Accs: 0.70817 | Time: 1.91 seconds
# Epoch: 54 | Train Loss: 0.57257 | Valid Loss: 0.60407 | Train Accs: 0.71970 | Valid Accs: 0.70287 | Time: 2.04 seconds
# Epoch: 55 | Train Loss: 0.57105 | Valid Loss: 0.59525 | Train Accs: 0.71976 | Valid Accs: 0.72093 | Time: 1.87 seconds
# Epoch: 56 | Train Loss: 0.57014 | Valid Loss: 0.60861 | Train Accs: 0.72067 | Valid Accs: 0.70013 | Time: 1.96 seconds
# Epoch: 57 | Train Loss: 0.57279 | Valid Loss: 0.61593 | Train Accs: 0.71876 | Valid Accs: 0.68187 | Time: 2.01 seconds
# Epoch: 58 | Train Loss: 0.57123 | Valid Loss: 0.59684 | Train Accs: 0.72085 | Valid Accs: 0.71612 | Time: 1.87 seconds
# Epoch: 59 | Train Loss: 0.57114 | Valid Loss: 0.60346 | Train Accs: 0.71969 | Valid Accs: 0.70405 | Time: 1.98 seconds
# Epoch: 60 | Train Loss: 0.57178 | Valid Loss: 0.61024 | Train Accs: 0.71876 | Valid Accs: 0.69560 | Time: 1.90 seconds
# Epoch: 61 | Train Loss: 0.57060 | Valid Loss: 0.59526 | Train Accs: 0.72010 | Valid Accs: 0.71383 | Time: 1.97 seconds
# Epoch: 62 | Train Loss: 0.57182 | Valid Loss: 0.61209 | Train Accs: 0.72057 | Valid Accs: 0.69358 | Time: 1.85 seconds
# Epoch: 63 | Train Loss: 0.57126 | Valid Loss: 0.60833 | Train Accs: 0.72187 | Valid Accs: 0.69623 | Time: 1.86 seconds
# Epoch: 64 | Train Loss: 0.57086 | Valid Loss: 0.60736 | Train Accs: 0.72144 | Valid Accs: 0.69623 | Time: 2.01 seconds
# Epoch: 65 | Train Loss: 0.57073 | Valid Loss: 0.61756 | Train Accs: 0.72052 | Valid Accs: 0.67769 | Time: 1.90 seconds
# Epoch: 66 | Train Loss: 0.57017 | Valid Loss: 0.59535 | Train Accs: 0.72074 | Valid Accs: 0.71751 | Time: 2.01 seconds
# Epoch: 67 | Train Loss: 0.56945 | Valid Loss: 0.61774 | Train Accs: 0.72318 | Valid Accs: 0.67888 | Time: 1.87 seconds
# Epoch: 68 | Train Loss: 0.57153 | Valid Loss: 0.60648 | Train Accs: 0.72222 | Valid Accs: 0.70106 | Time: 1.87 seconds
# Epoch: 69 | Train Loss: 0.56967 | Valid Loss: 0.61677 | Train Accs: 0.72124 | Valid Accs: 0.68137 | Time: 2.02 seconds
# Epoch: 70 | Train Loss: 0.57011 | Valid Loss: 0.60385 | Train Accs: 0.71952 | Valid Accs: 0.70426 | Time: 2.00 seconds
# Epoch: 71 | Train Loss: 0.56971 | Valid Loss: 0.61426 | Train Accs: 0.72177 | Valid Accs: 0.68208 | Time: 1.93 seconds
# Epoch: 72 | Train Loss: 0.57053 | Valid Loss: 0.61567 | Train Accs: 0.72097 | Valid Accs: 0.68229 | Time: 1.93 seconds
# Epoch: 73 | Train Loss: 0.57000 | Valid Loss: 0.61519 | Train Accs: 0.72068 | Valid Accs: 0.68528 | Time: 1.93 seconds
# Epoch: 74 | Train Loss: 0.57163 | Valid Loss: 0.60350 | Train Accs: 0.71911 | Valid Accs: 0.70496 | Time: 2.14 seconds
# Epoch: 75 | Train Loss: 0.57165 | Valid Loss: 0.60929 | Train Accs: 0.71950 | Valid Accs: 0.69490 | Time: 2.01 seconds
# Epoch: 76 | Train Loss: 0.57183 | Valid Loss: 0.61420 | Train Accs: 0.72213 | Valid Accs: 0.68229 | Time: 1.89 seconds
# Epoch: 77 | Train Loss: 0.56840 | Valid Loss: 0.60549 | Train Accs: 0.72127 | Valid Accs: 0.69973 | Time: 1.89 seconds
# Epoch: 78 | Train Loss: 0.56915 | Valid Loss: 0.60979 | Train Accs: 0.72093 | Valid Accs: 0.69685 | Time: 1.85 seconds
# Epoch: 79 | Train Loss: 0.57069 | Valid Loss: 0.60923 | Train Accs: 0.72153 | Valid Accs: 0.69637 | Time: 1.97 seconds
# Epoch: 80 | Train Loss: 0.57113 | Valid Loss: 0.62031 | Train Accs: 0.72050 | Valid Accs: 0.67106 | Time: 2.00 seconds
# Epoch: 81 | Train Loss: 0.56994 | Valid Loss: 0.60977 | Train Accs: 0.72170 | Valid Accs: 0.69526 | Time: 1.86 seconds
# Epoch: 82 | Train Loss: 0.57163 | Valid Loss: 0.59339 | Train Accs: 0.72126 | Valid Accs: 0.72093 | Time: 1.89 seconds
# Epoch: 83 | Train Loss: 0.57018 | Valid Loss: 0.59845 | Train Accs: 0.72078 | Valid Accs: 0.71270 | Time: 1.95 seconds
# Epoch: 84 | Train Loss: 0.56998 | Valid Loss: 0.61988 | Train Accs: 0.72008 | Valid Accs: 0.67581 | Time: 1.85 seconds
# Epoch: 85 | Train Loss: 0.56907 | Valid Loss: 0.61162 | Train Accs: 0.72246 | Valid Accs: 0.69232 | Time: 1.98 seconds
# Epoch: 86 | Train Loss: 0.56930 | Valid Loss: 0.61305 | Train Accs: 0.72078 | Valid Accs: 0.68765 | Time: 1.84 seconds
# Epoch: 87 | Train Loss: 0.56878 | Valid Loss: 0.61327 | Train Accs: 0.72232 | Valid Accs: 0.68786 | Time: 1.88 seconds
# Epoch: 88 | Train Loss: 0.56911 | Valid Loss: 0.61520 | Train Accs: 0.72196 | Valid Accs: 0.68604 | Time: 2.07 seconds
# Epoch: 89 | Train Loss: 0.56864 | Valid Loss: 0.61497 | Train Accs: 0.72212 | Valid Accs: 0.68040 | Time: 1.87 seconds
# Epoch: 90 | Train Loss: 0.56825 | Valid Loss: 0.59341 | Train Accs: 0.72143 | Valid Accs: 0.71841 | Time: 2.01 seconds
# Epoch: 91 | Train Loss: 0.56856 | Valid Loss: 0.60392 | Train Accs: 0.72318 | Valid Accs: 0.70496 | Time: 2.03 seconds
# Epoch: 92 | Train Loss: 0.57056 | Valid Loss: 0.62295 | Train Accs: 0.72031 | Valid Accs: 0.66640 | Time: 1.87 seconds
# Epoch: 93 | Train Loss: 0.56976 | Valid Loss: 0.60998 | Train Accs: 0.72157 | Valid Accs: 0.69378 | Time: 2.01 seconds
# Epoch: 94 | Train Loss: 0.56934 | Valid Loss: 0.60429 | Train Accs: 0.72324 | Valid Accs: 0.70342 | Time: 1.91 seconds
# Epoch: 95 | Train Loss: 0.56938 | Valid Loss: 0.60953 | Train Accs: 0.72253 | Valid Accs: 0.69610 | Time: 1.97 seconds
# Epoch: 96 | Train Loss: 0.56705 | Valid Loss: 0.62051 | Train Accs: 0.72161 | Valid Accs: 0.67366 | Time: 1.87 seconds
# Epoch: 97 | Train Loss: 0.56710 | Valid Loss: 0.60517 | Train Accs: 0.72395 | Valid Accs: 0.70154 | Time: 1.87 seconds
# Epoch: 98 | Train Loss: 0.56764 | Valid Loss: 0.60954 | Train Accs: 0.72182 | Valid Accs: 0.69694 | Time: 1.97 seconds
# Epoch: 99 | Train Loss: 0.56873 | Valid Loss: 0.60816 | Train Accs: 0.72252 | Valid Accs: 0.69826 | Time: 1.92 seconds
# Epoch: 100 | Train Loss: 0.56895 | Valid Loss: 0.60258 | Train Accs: 0.72294 | Valid Accs: 0.70958 | Time: 2.00 seconds
# Epoch: 101 | Train Loss: 0.56816 | Valid Loss: 0.60262 | Train Accs: 0.72261 | Valid Accs: 0.70637 | Time: 1.85 seconds
# Epoch: 102 | Train Loss: 0.56832 | Valid Loss: 0.61739 | Train Accs: 0.72232 | Valid Accs: 0.68174 | Time: 1.84 seconds
# Epoch: 103 | Train Loss: 0.56810 | Valid Loss: 0.61205 | Train Accs: 0.72173 | Valid Accs: 0.68896 | Time: 1.99 seconds
# Epoch: 104 | Train Loss: 0.56609 | Valid Loss: 0.59917 | Train Accs: 0.72488 | Valid Accs: 0.71153 | Time: 1.84 seconds
# Epoch: 105 | Train Loss: 0.56743 | Valid Loss: 0.60818 | Train Accs: 0.72118 | Valid Accs: 0.69645 | Time: 2.09 seconds
# Epoch: 106 | Train Loss: 0.56870 | Valid Loss: 0.61647 | Train Accs: 0.72183 | Valid Accs: 0.67847 | Time: 2.05 seconds
# Epoch: 107 | Train Loss: 0.56828 | Valid Loss: 0.60748 | Train Accs: 0.72330 | Valid Accs: 0.69650 | Time: 1.94 seconds
# Epoch: 108 | Train Loss: 0.56799 | Valid Loss: 0.60335 | Train Accs: 0.72279 | Valid Accs: 0.70574 | Time: 2.00 seconds
# Epoch: 109 | Train Loss: 0.56902 | Valid Loss: 0.61514 | Train Accs: 0.72196 | Valid Accs: 0.68091 | Time: 1.89 seconds
# Epoch: 110 | Train Loss: 0.56600 | Valid Loss: 0.59160 | Train Accs: 0.72464 | Valid Accs: 0.72177 | Time: 2.00 seconds
# Epoch: 111 | Train Loss: 0.56718 | Valid Loss: 0.59357 | Train Accs: 0.72198 | Valid Accs: 0.72093 | Time: 1.96 seconds
# Epoch: 112 | Train Loss: 0.56788 | Valid Loss: 0.61041 | Train Accs: 0.72209 | Valid Accs: 0.69784 | Time: 1.89 seconds
# Epoch: 113 | Train Loss: 0.56698 | Valid Loss: 0.60002 | Train Accs: 0.72298 | Valid Accs: 0.70782 | Time: 2.00 seconds
# Epoch: 114 | Train Loss: 0.56652 | Valid Loss: 0.61481 | Train Accs: 0.72441 | Valid Accs: 0.68006 | Time: 1.89 seconds
# Epoch: 115 | Train Loss: 0.56587 | Valid Loss: 0.59780 | Train Accs: 0.72453 | Valid Accs: 0.71285 | Time: 1.99 seconds
# Epoch: 116 | Train Loss: 0.56835 | Valid Loss: 0.61957 | Train Accs: 0.72103 | Valid Accs: 0.67357 | Time: 1.90 seconds
# Epoch: 117 | Train Loss: 0.56608 | Valid Loss: 0.59138 | Train Accs: 0.72235 | Valid Accs: 0.72162 | Time: 1.87 seconds
# Epoch: 118 | Train Loss: 0.56929 | Valid Loss: 0.61118 | Train Accs: 0.72286 | Valid Accs: 0.68927 | Time: 2.00 seconds
# Epoch: 119 | Train Loss: 0.56761 | Valid Loss: 0.59210 | Train Accs: 0.72247 | Valid Accs: 0.72345 | Time: 1.87 seconds
# Epoch: 120 | Train Loss: 0.56621 | Valid Loss: 0.61007 | Train Accs: 0.72376 | Valid Accs: 0.69791 | Time: 1.97 seconds
# Epoch: 121 | Train Loss: 0.56728 | Valid Loss: 0.60211 | Train Accs: 0.72208 | Valid Accs: 0.70692 | Time: 1.86 seconds
# Epoch: 122 | Train Loss: 0.56737 | Valid Loss: 0.59128 | Train Accs: 0.72379 | Valid Accs: 0.72164 | Time: 1.91 seconds
# Epoch: 123 | Train Loss: 0.56704 | Valid Loss: 0.60892 | Train Accs: 0.72323 | Valid Accs: 0.69673 | Time: 1.96 seconds
# Epoch: 124 | Train Loss: 0.56639 | Valid Loss: 0.60247 | Train Accs: 0.72469 | Valid Accs: 0.70798 | Time: 2.08 seconds
# Epoch: 125 | Train Loss: 0.56659 | Valid Loss: 0.61077 | Train Accs: 0.72347 | Valid Accs: 0.69247 | Time: 1.85 seconds
# Epoch: 126 | Train Loss: 0.56812 | Valid Loss: 0.60341 | Train Accs: 0.72447 | Valid Accs: 0.70467 | Time: 1.88 seconds
# Epoch: 127 | Train Loss: 0.56609 | Valid Loss: 0.60234 | Train Accs: 0.72378 | Valid Accs: 0.70503 | Time: 1.86 seconds
# Epoch: 128 | Train Loss: 0.56736 | Valid Loss: 0.59572 | Train Accs: 0.72351 | Valid Accs: 0.71362 | Time: 2.04 seconds
# Epoch: 129 | Train Loss: 0.56495 | Valid Loss: 0.60348 | Train Accs: 0.72496 | Valid Accs: 0.70488 | Time: 2.01 seconds
# Epoch: 130 | Train Loss: 0.56710 | Valid Loss: 0.61173 | Train Accs: 0.72193 | Valid Accs: 0.68633 | Time: 1.88 seconds
# Epoch: 131 | Train Loss: 0.56791 | Valid Loss: 0.60247 | Train Accs: 0.72409 | Valid Accs: 0.70552 | Time: 1.90 seconds
# Epoch: 132 | Train Loss: 0.56660 | Valid Loss: 0.60747 | Train Accs: 0.72391 | Valid Accs: 0.69952 | Time: 2.01 seconds
# Epoch: 133 | Train Loss: 0.56797 | Valid Loss: 0.60192 | Train Accs: 0.72501 | Valid Accs: 0.70818 | Time: 1.98 seconds
# Epoch: 134 | Train Loss: 0.56621 | Valid Loss: 0.61483 | Train Accs: 0.72359 | Valid Accs: 0.68584 | Time: 2.03 seconds
# Epoch: 135 | Train Loss: 0.56681 | Valid Loss: 0.59582 | Train Accs: 0.72304 | Valid Accs: 0.71279 | Time: 1.88 seconds
# Epoch: 136 | Train Loss: 0.56585 | Valid Loss: 0.59099 | Train Accs: 0.72369 | Valid Accs: 0.72289 | Time: 1.87 seconds
# Epoch: 137 | Train Loss: 0.56703 | Valid Loss: 0.58891 | Train Accs: 0.72402 | Valid Accs: 0.72429 | Time: 1.99 seconds
# Epoch: 138 | Train Loss: 0.56694 | Valid Loss: 0.60805 | Train Accs: 0.72366 | Valid Accs: 0.69777 | Time: 1.87 seconds
# Epoch: 139 | Train Loss: 0.56763 | Valid Loss: 0.59092 | Train Accs: 0.72299 | Valid Accs: 0.72044 | Time: 1.99 seconds
# Epoch: 140 | Train Loss: 0.56717 | Valid Loss: 0.61454 | Train Accs: 0.72403 | Valid Accs: 0.68410 | Time: 1.87 seconds
# Epoch: 141 | Train Loss: 0.56710 | Valid Loss: 0.60289 | Train Accs: 0.72481 | Valid Accs: 0.70474 | Time: 2.01 seconds
# Epoch: 142 | Train Loss: 0.56659 | Valid Loss: 0.60883 | Train Accs: 0.72352 | Valid Accs: 0.69435 | Time: 1.99 seconds
# Epoch: 143 | Train Loss: 0.56773 | Valid Loss: 0.60784 | Train Accs: 0.72301 | Valid Accs: 0.69701 | Time: 1.85 seconds
# Epoch: 144 | Train Loss: 0.56697 | Valid Loss: 0.60953 | Train Accs: 0.72315 | Valid Accs: 0.69296 | Time: 1.97 seconds
# Epoch: 145 | Train Loss: 0.56633 | Valid Loss: 0.60869 | Train Accs: 0.72400 | Valid Accs: 0.69025 | Time: 1.91 seconds
# Epoch: 146 | Train Loss: 0.56637 | Valid Loss: 0.59834 | Train Accs: 0.72403 | Valid Accs: 0.70950 | Time: 1.85 seconds
# Epoch: 147 | Train Loss: 0.56455 | Valid Loss: 0.61400 | Train Accs: 0.72612 | Valid Accs: 0.68571 | Time: 2.02 seconds
# Epoch: 148 | Train Loss: 0.56616 | Valid Loss: 0.59782 | Train Accs: 0.72402 | Valid Accs: 0.71321 | Time: 1.89 seconds
# Epoch: 149 | Train Loss: 0.56498 | Valid Loss: 0.59287 | Train Accs: 0.72535 | Valid Accs: 0.72086 | Time: 1.99 seconds
# Epoch: 150 | Train Loss: 0.56616 | Valid Loss: 0.61356 | Train Accs: 0.72477 | Valid Accs: 0.68761 | Time: 1.95 seconds
# Epoch: 151 | Train Loss: 0.56706 | Valid Loss: 0.60619 | Train Accs: 0.72394 | Valid Accs: 0.70119 | Time: 1.88 seconds
# Epoch: 152 | Train Loss: 0.56633 | Valid Loss: 0.60443 | Train Accs: 0.72236 | Valid Accs: 0.70287 | Time: 2.00 seconds
# Epoch: 153 | Train Loss: 0.56545 | Valid Loss: 0.60917 | Train Accs: 0.72406 | Valid Accs: 0.69868 | Time: 1.89 seconds
# Epoch: 154 | Train Loss: 0.56587 | Valid Loss: 0.59553 | Train Accs: 0.72431 | Valid Accs: 0.71278 | Time: 1.98 seconds
# Epoch: 155 | Train Loss: 0.56609 | Valid Loss: 0.59373 | Train Accs: 0.72446 | Valid Accs: 0.71800 | Time: 1.86 seconds
# Epoch: 156 | Train Loss: 0.56645 | Valid Loss: 0.59364 | Train Accs: 0.72379 | Valid Accs: 0.72184 | Time: 1.88 seconds
# Epoch: 157 | Train Loss: 0.56558 | Valid Loss: 0.61179 | Train Accs: 0.72510 | Valid Accs: 0.68947 | Time: 2.08 seconds
# Epoch: 158 | Train Loss: 0.56611 | Valid Loss: 0.61739 | Train Accs: 0.72399 | Valid Accs: 0.67930 | Time: 1.88 seconds
# Epoch: 159 | Train Loss: 0.56708 | Valid Loss: 0.61567 | Train Accs: 0.72422 | Valid Accs: 0.67806 | Time: 1.99 seconds
# Epoch: 160 | Train Loss: 0.56581 | Valid Loss: 0.59285 | Train Accs: 0.72419 | Valid Accs: 0.72073 | Time: 1.86 seconds
# Epoch: 161 | Train Loss: 0.56560 | Valid Loss: 0.59037 | Train Accs: 0.72570 | Valid Accs: 0.72338 | Time: 1.86 seconds
# Epoch: 162 | Train Loss: 0.56508 | Valid Loss: 0.59433 | Train Accs: 0.72415 | Valid Accs: 0.72030 | Time: 2.00 seconds
# Epoch: 163 | Train Loss: 0.56578 | Valid Loss: 0.59398 | Train Accs: 0.72335 | Valid Accs: 0.71612 | Time: 1.84 seconds
# Epoch: 164 | Train Loss: 0.56457 | Valid Loss: 0.60907 | Train Accs: 0.72356 | Valid Accs: 0.69450 | Time: 1.95 seconds
# Epoch: 165 | Train Loss: 0.56431 | Valid Loss: 0.59778 | Train Accs: 0.72448 | Valid Accs: 0.70992 | Time: 1.89 seconds
# Epoch: 166 | Train Loss: 0.56527 | Valid Loss: 0.60699 | Train Accs: 0.72430 | Valid Accs: 0.69267 | Time: 1.88 seconds
# Epoch: 167 | Train Loss: 0.56439 | Valid Loss: 0.61398 | Train Accs: 0.72499 | Valid Accs: 0.68118 | Time: 2.01 seconds
# Epoch: 168 | Train Loss: 0.56696 | Valid Loss: 0.60102 | Train Accs: 0.72262 | Valid Accs: 0.70864 | Time: 1.85 seconds
# Epoch: 169 | Train Loss: 0.56572 | Valid Loss: 0.58899 | Train Accs: 0.72434 | Valid Accs: 0.72463 | Time: 1.95 seconds
# Epoch: 170 | Train Loss: 0.56481 | Valid Loss: 0.61372 | Train Accs: 0.72630 | Valid Accs: 0.68661 | Time: 1.88 seconds
# Epoch: 171 | Train Loss: 0.56688 | Valid Loss: 0.60245 | Train Accs: 0.72452 | Valid Accs: 0.70345 | Time: 1.85 seconds
# Epoch: 172 | Train Loss: 0.56550 | Valid Loss: 0.61509 | Train Accs: 0.72457 | Valid Accs: 0.67723 | Time: 1.96 seconds
# Epoch: 173 | Train Loss: 0.56733 | Valid Loss: 0.61061 | Train Accs: 0.72443 | Valid Accs: 0.68579 | Time: 2.01 seconds
# Epoch: 174 | Train Loss: 0.56658 | Valid Loss: 0.61476 | Train Accs: 0.72408 | Valid Accs: 0.67992 | Time: 2.02 seconds
# Epoch: 175 | Train Loss: 0.56611 | Valid Loss: 0.60151 | Train Accs: 0.72588 | Valid Accs: 0.70678 | Time: 1.85 seconds
# Epoch: 176 | Train Loss: 0.56421 | Valid Loss: 0.59458 | Train Accs: 0.72512 | Valid Accs: 0.71508 | Time: 1.85 seconds
# Epoch: 177 | Train Loss: 0.56380 | Valid Loss: 0.58961 | Train Accs: 0.72348 | Valid Accs: 0.72408 | Time: 1.96 seconds
# Epoch: 178 | Train Loss: 0.56540 | Valid Loss: 0.59408 | Train Accs: 0.72578 | Valid Accs: 0.71557 | Time: 1.99 seconds
# Epoch: 179 | Train Loss: 0.56501 | Valid Loss: 0.59319 | Train Accs: 0.72461 | Valid Accs: 0.72045 | Time: 1.90 seconds
# Epoch: 180 | Train Loss: 0.56473 | Valid Loss: 0.61181 | Train Accs: 0.72637 | Valid Accs: 0.69246 | Time: 1.86 seconds
# Epoch: 181 | Train Loss: 0.56572 | Valid Loss: 0.59349 | Train Accs: 0.72426 | Valid Accs: 0.71772 | Time: 1.85 seconds
# Epoch: 182 | Train Loss: 0.56481 | Valid Loss: 0.59282 | Train Accs: 0.72487 | Valid Accs: 0.72888 | Time: 2.00 seconds
# Epoch: 183 | Train Loss: 0.56462 | Valid Loss: 0.61621 | Train Accs: 0.72554 | Valid Accs: 0.67855 | Time: 2.02 seconds
# Epoch: 184 | Train Loss: 0.56540 | Valid Loss: 0.58867 | Train Accs: 0.72608 | Valid Accs: 0.72304 | Time: 1.89 seconds
# Epoch: 185 | Train Loss: 0.56751 | Valid Loss: 0.59151 | Train Accs: 0.72279 | Valid Accs: 0.72464 | Time: 1.93 seconds
# Epoch: 186 | Train Loss: 0.56322 | Valid Loss: 0.60838 | Train Accs: 0.72611 | Valid Accs: 0.69366 | Time: 2.02 seconds
# Epoch: 187 | Train Loss: 0.56449 | Valid Loss: 0.60664 | Train Accs: 0.72422 | Valid Accs: 0.70036 | Time: 1.88 seconds
# Epoch: 188 | Train Loss: 0.56673 | Valid Loss: 0.60876 | Train Accs: 0.72511 | Valid Accs: 0.69268 | Time: 2.00 seconds
# ...
# Epoch: 54 | Train Loss: 0.57364 | Valid Loss: 0.61868 | Train Accs: 0.71887 | Valid Accs: 0.67659 | Time: 1.97 seconds
# Epoch: 55 | Train Loss: 0.57263 | Valid Loss: 0.60815 | Train Accs: 0.71961 | Valid Accs: 0.69758 | Time: 1.98 seconds
# Epoch: 56 | Train Loss: 0.57177 | Valid Loss: 0.62569 | Train Accs: 0.71848 | Valid Accs: 0.66525 | Time: 1.98 seconds
# Epoch: 57 | Train Loss: 0.57369 | Valid Loss: 0.60619 | Train Accs: 0.71889 | Valid Accs: 0.70232 | Time: 2.04 seconds
# Epoch: 58 | Train Loss: 0.57231 | Valid Loss: 0.62037 | Train Accs: 0.72008 | Valid Accs: 0.67624 | Time: 1.88 seconds
# Epoch: 59 | Train Loss: 0.57210 | Valid Loss: 0.62121 | Train Accs: 0.71968 | Valid Accs: 0.67213 | Time: 1.99 seconds
# Epoch: 60 | Train Loss: 0.57192 | Valid Loss: 0.60381 | Train Accs: 0.71958 | Valid Accs: 0.70720 | Time: 2.00 seconds
# Epoch: 61 | Train Loss: 0.57157 | Valid Loss: 0.60237 | Train Accs: 0.71889 | Valid Accs: 0.70829 | Time: 1.90 seconds
# Epoch: 62 | Train Loss: 0.57129 | Valid Loss: 0.60832 | Train Accs: 0.72046 | Valid Accs: 0.69681 | Time: 1.90 seconds
# Epoch: 63 | Train Loss: 0.57316 | Valid Loss: 0.61809 | Train Accs: 0.72073 | Valid Accs: 0.67855 | Time: 1.95 seconds
# Epoch: 64 | Train Loss: 0.57331 | Valid Loss: 0.59860 | Train Accs: 0.71902 | Valid Accs: 0.71782 | Time: 1.86 seconds
# Epoch: 65 | Train Loss: 0.57303 | Valid Loss: 0.60721 | Train Accs: 0.71968 | Valid Accs: 0.70030 | Time: 1.97 seconds
# Epoch: 66 | Train Loss: 0.57091 | Valid Loss: 0.62105 | Train Accs: 0.72083 | Valid Accs: 0.67471 | Time: 1.89 seconds
# Epoch: 67 | Train Loss: 0.57428 | Valid Loss: 0.62040 | Train Accs: 0.71810 | Valid Accs: 0.67290 | Time: 1.90 seconds
# Epoch: 68 | Train Loss: 0.57153 | Valid Loss: 0.61572 | Train Accs: 0.72046 | Valid Accs: 0.68176 | Time: 1.95 seconds
# Epoch: 69 | Train Loss: 0.57256 | Valid Loss: 0.61776 | Train Accs: 0.71986 | Valid Accs: 0.67855 | Time: 1.87 seconds
# Epoch: 70 | Train Loss: 0.57207 | Valid Loss: 0.61162 | Train Accs: 0.72001 | Valid Accs: 0.69075 | Time: 1.97 seconds
# Epoch: 71 | Train Loss: 0.57284 | Valid Loss: 0.59786 | Train Accs: 0.72022 | Valid Accs: 0.71739 | Time: 1.85 seconds
# Epoch: 72 | Train Loss: 0.57096 | Valid Loss: 0.61804 | Train Accs: 0.72031 | Valid Accs: 0.67501 | Time: 1.84 seconds
# Epoch: 73 | Train Loss: 0.57132 | Valid Loss: 0.61920 | Train Accs: 0.72093 | Valid Accs: 0.67326 | Time: 1.98 seconds
# Epoch: 74 | Train Loss: 0.57157 | Valid Loss: 0.61085 | Train Accs: 0.72061 | Valid Accs: 0.68824 | Time: 1.85 seconds
# Epoch: 75 | Train Loss: 0.57143 | Valid Loss: 0.61147 | Train Accs: 0.72061 | Valid Accs: 0.69451 | Time: 1.95 seconds
# Epoch: 76 | Train Loss: 0.57201 | Valid Loss: 0.61611 | Train Accs: 0.71988 | Valid Accs: 0.67877 | Time: 1.85 seconds
# Epoch: 77 | Train Loss: 0.57051 | Valid Loss: 0.61192 | Train Accs: 0.72032 | Valid Accs: 0.68991 | Time: 1.85 seconds
# Epoch: 78 | Train Loss: 0.57031 | Valid Loss: 0.61582 | Train Accs: 0.72019 | Valid Accs: 0.68016 | Time: 2.08 seconds
# Epoch: 79 | Train Loss: 0.57085 | Valid Loss: 0.60576 | Train Accs: 0.72127 | Valid Accs: 0.69905 | Time: 1.90 seconds
# Epoch: 80 | Train Loss: 0.56998 | Valid Loss: 0.61918 | Train Accs: 0.72211 | Valid Accs: 0.67618 | Time: 1.96 seconds
# Epoch: 81 | Train Loss: 0.56993 | Valid Loss: 0.61926 | Train Accs: 0.72253 | Valid Accs: 0.67584 | Time: 1.85 seconds
# Epoch: 82 | Train Loss: 0.57137 | Valid Loss: 0.61734 | Train Accs: 0.72053 | Valid Accs: 0.67912 | Time: 1.86 seconds
# Epoch: 83 | Train Loss: 0.57008 | Valid Loss: 0.61037 | Train Accs: 0.72148 | Valid Accs: 0.68921 | Time: 1.99 seconds
# Epoch: 84 | Train Loss: 0.57038 | Valid Loss: 0.59803 | Train Accs: 0.72148 | Valid Accs: 0.72281 | Time: 1.89 seconds
# Epoch: 85 | Train Loss: 0.57105 | Valid Loss: 0.60938 | Train Accs: 0.72125 | Valid Accs: 0.69786 | Time: 2.02 seconds
# Epoch: 86 | Train Loss: 0.56912 | Valid Loss: 0.61308 | Train Accs: 0.72304 | Valid Accs: 0.68623 | Time: 1.87 seconds
# Epoch: 87 | Train Loss: 0.57032 | Valid Loss: 0.60828 | Train Accs: 0.72278 | Valid Accs: 0.69494 | Time: 1.86 seconds
# Epoch: 88 | Train Loss: 0.56934 | Valid Loss: 0.60753 | Train Accs: 0.72151 | Valid Accs: 0.69940 | Time: 1.99 seconds
# Epoch: 89 | Train Loss: 0.56945 | Valid Loss: 0.60479 | Train Accs: 0.72072 | Valid Accs: 0.69857 | Time: 1.87 seconds
# Epoch: 90 | Train Loss: 0.56973 | Valid Loss: 0.59651 | Train Accs: 0.71976 | Valid Accs: 0.72994 | Time: 2.01 seconds
# Epoch: 91 | Train Loss: 0.56906 | Valid Loss: 0.61279 | Train Accs: 0.72231 | Valid Accs: 0.68512 | Time: 1.85 seconds
# Epoch: 92 | Train Loss: 0.56983 | Valid Loss: 0.60090 | Train Accs: 0.72087 | Valid Accs: 0.71093 | Time: 1.86 seconds
# Epoch: 93 | Train Loss: 0.57091 | Valid Loss: 0.60796 | Train Accs: 0.72090 | Valid Accs: 0.69682 | Time: 1.97 seconds
# Epoch: 94 | Train Loss: 0.56917 | Valid Loss: 0.60239 | Train Accs: 0.72027 | Valid Accs: 0.71012 | Time: 1.85 seconds
# Epoch: 95 | Train Loss: 0.57002 | Valid Loss: 0.61645 | Train Accs: 0.72267 | Valid Accs: 0.67743 | Time: 2.07 seconds
# Epoch: 96 | Train Loss: 0.56896 | Valid Loss: 0.61798 | Train Accs: 0.72134 | Valid Accs: 0.67722 | Time: 1.87 seconds
# Epoch: 97 | Train Loss: 0.56901 | Valid Loss: 0.61238 | Train Accs: 0.72272 | Valid Accs: 0.68442 | Time: 1.84 seconds
# Epoch: 98 | Train Loss: 0.57029 | Valid Loss: 0.59577 | Train Accs: 0.71970 | Valid Accs: 0.72463 | Time: 2.01 seconds
# Epoch: 99 | Train Loss: 0.56958 | Valid Loss: 0.60942 | Train Accs: 0.72211 | Valid Accs: 0.69004 | Time: 1.85 seconds
# Epoch: 100 | Train Loss: 0.56946 | Valid Loss: 0.59856 | Train Accs: 0.72133 | Valid Accs: 0.71526 | Time: 1.96 seconds
# Epoch: 101 | Train Loss: 0.56890 | Valid Loss: 0.61780 | Train Accs: 0.72124 | Valid Accs: 0.67980 | Time: 1.89 seconds
# Epoch: 102 | Train Loss: 0.56974 | Valid Loss: 0.60683 | Train Accs: 0.72085 | Valid Accs: 0.69653 | Time: 1.91 seconds
# Epoch: 103 | Train Loss: 0.56848 | Valid Loss: 0.60977 | Train Accs: 0.72223 | Valid Accs: 0.69403 | Time: 1.99 seconds
# Epoch: 104 | Train Loss: 0.56971 | Valid Loss: 0.61395 | Train Accs: 0.72167 | Valid Accs: 0.68260 | Time: 2.01 seconds
# Epoch: 105 | Train Loss: 0.56954 | Valid Loss: 0.61114 | Train Accs: 0.72214 | Valid Accs: 0.68775 | Time: 1.90 seconds
# Epoch: 106 | Train Loss: 0.56777 | Valid Loss: 0.59459 | Train Accs: 0.72308 | Valid Accs: 0.72213 | Time: 1.87 seconds
# Epoch: 107 | Train Loss: 0.56871 | Valid Loss: 0.61879 | Train Accs: 0.72065 | Valid Accs: 0.67534 | Time: 1.91 seconds
# Epoch: 108 | Train Loss: 0.56772 | Valid Loss: 0.60556 | Train Accs: 0.72336 | Valid Accs: 0.69945 | Time: 2.03 seconds
# Epoch: 109 | Train Loss: 0.56793 | Valid Loss: 0.61458 | Train Accs: 0.72206 | Valid Accs: 0.68120 | Time: 2.00 seconds
# Epoch: 110 | Train Loss: 0.56861 | Valid Loss: 0.60828 | Train Accs: 0.72174 | Valid Accs: 0.69681 | Time: 1.87 seconds
# Epoch: 111 | Train Loss: 0.56814 | Valid Loss: 0.60725 | Train Accs: 0.72245 | Valid Accs: 0.69737 | Time: 1.92 seconds
# Epoch: 112 | Train Loss: 0.56890 | Valid Loss: 0.60393 | Train Accs: 0.72270 | Valid Accs: 0.70113 | Time: 2.00 seconds
# Epoch: 113 | Train Loss: 0.56836 | Valid Loss: 0.60562 | Train Accs: 0.72116 | Valid Accs: 0.69478 | Time: 2.09 seconds
# Epoch: 114 | Train Loss: 0.56901 | Valid Loss: 0.60660 | Train Accs: 0.72173 | Valid Accs: 0.69931 | Time: 2.14 seconds
# Epoch: 115 | Train Loss: 0.56909 | Valid Loss: 0.60516 | Train Accs: 0.72169 | Valid Accs: 0.69757 | Time: 1.87 seconds
# Epoch: 116 | Train Loss: 0.56885 | Valid Loss: 0.60851 | Train Accs: 0.72209 | Valid Accs: 0.69367 | Time: 1.85 seconds
# Epoch: 117 | Train Loss: 0.56760 | Valid Loss: 0.61561 | Train Accs: 0.72340 | Valid Accs: 0.68087 | Time: 1.97 seconds
# Epoch: 118 | Train Loss: 0.56720 | Valid Loss: 0.61355 | Train Accs: 0.72322 | Valid Accs: 0.68233 | Time: 1.86 seconds
# Epoch: 119 | Train Loss: 0.56879 | Valid Loss: 0.60707 | Train Accs: 0.72143 | Valid Accs: 0.69750 | Time: 2.00 seconds
# Epoch: 120 | Train Loss: 0.56871 | Valid Loss: 0.61325 | Train Accs: 0.72118 | Valid Accs: 0.68455 | Time: 1.85 seconds
# Epoch: 121 | Train Loss: 0.56783 | Valid Loss: 0.60881 | Train Accs: 0.72116 | Valid Accs: 0.69332 | Time: 1.86 seconds
# Epoch: 122 | Train Loss: 0.56764 | Valid Loss: 0.60898 | Train Accs: 0.72228 | Valid Accs: 0.69604 | Time: 1.97 seconds
# Epoch: 123 | Train Loss: 0.56867 | Valid Loss: 0.61613 | Train Accs: 0.72245 | Valid Accs: 0.68044 | Time: 1.86 seconds
# Epoch: 124 | Train Loss: 0.56712 | Valid Loss: 0.59555 | Train Accs: 0.72358 | Valid Accs: 0.72777 | Time: 1.99 seconds
# Epoch: 125 | Train Loss: 0.56609 | Valid Loss: 0.61432 | Train Accs: 0.72471 | Valid Accs: 0.68244 | Time: 1.87 seconds
# Epoch: 126 | Train Loss: 0.56818 | Valid Loss: 0.60348 | Train Accs: 0.72308 | Valid Accs: 0.70267 | Time: 1.88 seconds
# Epoch: 127 | Train Loss: 0.56709 | Valid Loss: 0.60161 | Train Accs: 0.72169 | Valid Accs: 0.70517 | Time: 2.01 seconds
# Epoch: 128 | Train Loss: 0.56747 | Valid Loss: 0.61018 | Train Accs: 0.72398 | Valid Accs: 0.69359 | Time: 1.94 seconds
# Epoch: 129 | Train Loss: 0.56683 | Valid Loss: 0.60890 | Train Accs: 0.72395 | Valid Accs: 0.69283 | Time: 1.99 seconds
# Epoch: 130 | Train Loss: 0.56890 | Valid Loss: 0.62049 | Train Accs: 0.72392 | Valid Accs: 0.67096 | Time: 1.94 seconds
# Epoch: 131 | Train Loss: 0.56691 | Valid Loss: 0.60098 | Train Accs: 0.72334 | Valid Accs: 0.70748 | Time: 1.90 seconds
# Epoch: 132 | Train Loss: 0.56711 | Valid Loss: 0.60514 | Train Accs: 0.72229 | Valid Accs: 0.70323 | Time: 2.02 seconds
# Epoch: 133 | Train Loss: 0.56536 | Valid Loss: 0.59346 | Train Accs: 0.72402 | Valid Accs: 0.72581 | Time: 1.89 seconds
# Epoch: 134 | Train Loss: 0.56832 | Valid Loss: 0.61252 | Train Accs: 0.72336 | Valid Accs: 0.68691 | Time: 1.98 seconds
# Epoch: 135 | Train Loss: 0.56699 | Valid Loss: 0.61065 | Train Accs: 0.72355 | Valid Accs: 0.68824 | Time: 1.86 seconds
# Epoch: 136 | Train Loss: 0.56634 | Valid Loss: 0.59594 | Train Accs: 0.72304 | Valid Accs: 0.71810 | Time: 1.91 seconds
# Epoch: 137 | Train Loss: 0.56890 | Valid Loss: 0.60628 | Train Accs: 0.72230 | Valid Accs: 0.69924 | Time: 1.97 seconds
# Epoch: 138 | Train Loss: 0.56780 | Valid Loss: 0.60847 | Train Accs: 0.72243 | Valid Accs: 0.69117 | Time: 1.84 seconds
# Epoch: 139 | Train Loss: 0.56672 | Valid Loss: 0.60375 | Train Accs: 0.72251 | Valid Accs: 0.70385 | Time: 1.96 seconds
# Epoch: 140 | Train Loss: 0.56664 | Valid Loss: 0.59778 | Train Accs: 0.72454 | Valid Accs: 0.71664 | Time: 1.83 seconds
# Epoch: 141 | Train Loss: 0.56732 | Valid Loss: 0.61448 | Train Accs: 0.72431 | Valid Accs: 0.68363 | Time: 1.85 seconds
# Epoch: 142 | Train Loss: 0.56491 | Valid Loss: 0.59740 | Train Accs: 0.72491 | Valid Accs: 0.71623 | Time: 2.01 seconds
# Epoch: 143 | Train Loss: 0.56662 | Valid Loss: 0.59432 | Train Accs: 0.72425 | Valid Accs: 0.72734 | Time: 1.85 seconds
# Epoch: 144 | Train Loss: 0.56762 | Valid Loss: 0.60423 | Train Accs: 0.72378 | Valid Accs: 0.70176 | Time: 2.00 seconds
# Epoch: 145 | Train Loss: 0.56779 | Valid Loss: 0.61136 | Train Accs: 0.72373 | Valid Accs: 0.68491 | Time: 1.94 seconds
# Epoch: 146 | Train Loss: 0.56665 | Valid Loss: 0.59856 | Train Accs: 0.72389 | Valid Accs: 0.71729 | Time: 1.97 seconds
# Epoch: 147 | Train Loss: 0.56651 | Valid Loss: 0.61425 | Train Accs: 0.72213 | Valid Accs: 0.68113 | Time: 2.04 seconds
# Epoch: 148 | Train Loss: 0.56851 | Valid Loss: 0.61466 | Train Accs: 0.72346 | Valid Accs: 0.68892 | Time: 1.86 seconds
# Epoch: 149 | Train Loss: 0.56685 | Valid Loss: 0.61706 | Train Accs: 0.72383 | Valid Accs: 0.67711 | Time: 2.00 seconds
# Epoch: 150 | Train Loss: 0.56690 | Valid Loss: 0.60406 | Train Accs: 0.72226 | Valid Accs: 0.70371 | Time: 1.91 seconds
# Epoch: 151 | Train Loss: 0.56511 | Valid Loss: 0.59632 | Train Accs: 0.72509 | Valid Accs: 0.71978 | Time: 1.86 seconds
# Epoch: 152 | Train Loss: 0.56476 | Valid Loss: 0.61000 | Train Accs: 0.72473 | Valid Accs: 0.69143 | Time: 1.99 seconds
# Epoch: 153 | Train Loss: 0.56627 | Valid Loss: 0.60808 | Train Accs: 0.72364 | Valid Accs: 0.69437 | Time: 1.90 seconds
# Epoch: 154 | Train Loss: 0.56797 | Valid Loss: 0.61292 | Train Accs: 0.72315 | Valid Accs: 0.68908 | Time: 1.96 seconds
# Epoch: 155 | Train Loss: 0.56652 | Valid Loss: 0.60459 | Train Accs: 0.72348 | Valid Accs: 0.69926 | Time: 1.86 seconds
# Epoch: 156 | Train Loss: 0.56818 | Valid Loss: 0.59701 | Train Accs: 0.72190 | Valid Accs: 0.71692 | Time: 1.83 seconds
# Epoch: 157 | Train Loss: 0.56742 | Valid Loss: 0.61548 | Train Accs: 0.72377 | Valid Accs: 0.67932 | Time: 1.96 seconds
# Epoch: 158 | Train Loss: 0.56563 | Valid Loss: 0.61393 | Train Accs: 0.72396 | Valid Accs: 0.68213 | Time: 1.97 seconds
# Epoch: 159 | Train Loss: 0.56750 | Valid Loss: 0.61183 | Train Accs: 0.72154 | Valid Accs: 0.68468 | Time: 1.87 seconds
# Epoch: 160 | Train Loss: 0.56921 | Valid Loss: 0.60591 | Train Accs: 0.72279 | Valid Accs: 0.70314 | Time: 1.86 seconds
# Epoch: 161 | Train Loss: 0.56814 | Valid Loss: 0.60781 | Train Accs: 0.72218 | Valid Accs: 0.69772 | Time: 1.86 seconds
# Epoch: 162 | Train Loss: 0.56638 | Valid Loss: 0.60895 | Train Accs: 0.72367 | Valid Accs: 0.69124 | Time: 1.99 seconds
# Epoch: 163 | Train Loss: 0.56562 | Valid Loss: 0.59827 | Train Accs: 0.72499 | Valid Accs: 0.71638 | Time: 2.00 seconds
# Epoch: 164 | Train Loss: 0.56598 | Valid Loss: 0.60989 | Train Accs: 0.72285 | Valid Accs: 0.69555 | Time: 1.92 seconds
# Epoch: 165 | Train Loss: 0.56644 | Valid Loss: 0.60354 | Train Accs: 0.72367 | Valid Accs: 0.70512 | Time: 1.91 seconds
# Epoch: 166 | Train Loss: 0.56627 | Valid Loss: 0.60757 | Train Accs: 0.72402 | Valid Accs: 0.70657 | Time: 2.22 seconds
# Epoch: 167 | Train Loss: 0.56667 | Valid Loss: 0.59578 | Train Accs: 0.72509 | Valid Accs: 0.72171 | Time: 2.02 seconds
# Epoch: 168 | Train Loss: 0.56483 | Valid Loss: 0.60053 | Train Accs: 0.72514 | Valid Accs: 0.70881 | Time: 2.11 seconds
# Epoch: 169 | Train Loss: 0.56626 | Valid Loss: 0.60444 | Train Accs: 0.72365 | Valid Accs: 0.70323 | Time: 1.90 seconds
# Epoch: 170 | Train Loss: 0.56570 | Valid Loss: 0.59785 | Train Accs: 0.72463 | Valid Accs: 0.71686 | Time: 1.89 seconds
# Epoch: 171 | Train Loss: 0.56688 | Valid Loss: 0.59885 | Train Accs: 0.72501 | Valid Accs: 0.71396 | Time: 1.98 seconds
# Epoch: 172 | Train Loss: 0.56767 | Valid Loss: 0.60104 | Train Accs: 0.72292 | Valid Accs: 0.70694 | Time: 1.86 seconds
# Epoch: 173 | Train Loss: 0.56627 | Valid Loss: 0.60908 | Train Accs: 0.72584 | Valid Accs: 0.69353 | Time: 1.97 seconds
# Epoch: 174 | Train Loss: 0.56705 | Valid Loss: 0.60728 | Train Accs: 0.72340 | Valid Accs: 0.69987 | Time: 1.85 seconds
# Epoch: 175 | Train Loss: 0.56658 | Valid Loss: 0.60909 | Train Accs: 0.72435 | Valid Accs: 0.69326 | Time: 1.84 seconds
# Epoch: 176 | Train Loss: 0.56630 | Valid Loss: 0.60008 | Train Accs: 0.72368 | Valid Accs: 0.70624 | Time: 1.98 seconds
# Epoch: 177 | Train Loss: 0.56507 | Valid Loss: 0.60108 | Train Accs: 0.72550 | Valid Accs: 0.71311 | Time: 1.86 seconds
# Epoch: 178 | Train Loss: 0.56660 | Valid Loss: 0.61244 | Train Accs: 0.72296 | Valid Accs: 0.68900 | Time: 1.99 seconds
# Epoch: 179 | Train Loss: 0.56543 | Valid Loss: 0.61086 | Train Accs: 0.72471 | Valid Accs: 0.68720 | Time: 1.85 seconds
# Epoch: 180 | Train Loss: 0.56612 | Valid Loss: 0.59726 | Train Accs: 0.72360 | Valid Accs: 0.71541 | Time: 1.84 seconds
# Epoch: 181 | Train Loss: 0.56638 | Valid Loss: 0.61173 | Train Accs: 0.72427 | Valid Accs: 0.68525 | Time: 1.99 seconds
# Epoch: 182 | Train Loss: 0.56669 | Valid Loss: 0.61200 | Train Accs: 0.72572 | Valid Accs: 0.68754 | Time: 1.87 seconds
# Epoch: 183 | Train Loss: 0.56726 | Valid Loss: 0.60923 | Train Accs: 0.72396 | Valid Accs: 0.69132 | Time: 2.07 seconds
#
# Early Stopping at Epoch 184
#
# **************************************************
#
# Best Validation Loss at Epoch 133
#
# **************************************************
#
# Best Validation Accs at Epoch 90
#
# **************************************************
#
# Time Taken [184 Epochs] : 5.91 minutes
#
# **************************************************

# %%
# test_df = pd.read_csv("")

# test_features = test_df.iloc[:, :].copy().values

# ts_data_setup = DS(test_features, None)
# ts_data = DL(ts_data_setup, batch_size=cfg.batch_size, shuffle=False)

best_fold = BLEs.index(min(BLEs)) + 1
model_path = f"saves/state_fold_{best_fold}.pt"
# y_pred = predict(model=Model().to(cfg.device), dataloader=ts_data, path=model_path, device=cfg.device)

# accuracy, auc, precision, recall, f_score = get_scores(test_labels, y_pred)

breaker()
print(f"Best Fold : {best_fold}")
breaker()
# print_scores(accuracy, auc, precision, recall, f_score)
# breaker()
# print(classification_report(test_labels, y_pred))
# breaker()
# print(confusion_matrix(test_labels, y_pred))
# breaker()
# Out:
# **************************************************
#
# Best Fold : 2
#
# **************************************************
