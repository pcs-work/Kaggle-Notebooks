# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from scipy import stats
from typing import Union
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import models, transforms

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Helpers**

# %%
SEED: int = 42

def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def get_image(path: str, size: int=224) -> np.ndarray:
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
    return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_AREA)


def show_loss_graphs(L: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()

    
def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(A)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()
    

def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 ):
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.train_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49085, 0.48537, 0.45057], [0.24560, 0.24165, 0.26213]),
            transforms.RandomAffine(degrees=(-45, 45), translate=(0.15, 0.15), scale=(0.5, 1.5)),
            transforms.RandomHorizontalFlip(p=0.25),
            transforms.RandomVerticalFlip(p=0.25),
        ])
        self.valid_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49085, 0.48537, 0.45057], [0.24560, 0.24165, 0.26213]),
        ]) 
                                
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
    
cfg = CFG(
    seed=SEED, 
)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(
        self, 
        images: np.ndarray,
        labels: Union[np.ndarray, None]=None, 
        transform=None
    ):
        
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is None:
            return self.transform(self.images[idx])
        return self.transform(self.images[idx]), torch.LongTensor(self.labels[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, filter_sizes: list=[64, 128, 256, 512], HLs: list=[], DP: float=None):

        super(Model, self).__init__()

        self.encoder = nn.Sequential()
        self.encoder.add_module("CN1", nn.Conv2d(in_channels=3, out_channels=filter_sizes[0], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN1", nn.BatchNorm2d(num_features=filter_sizes[0], eps=1e-5))
        self.encoder.add_module("AN1", nn.ReLU())
        self.encoder.add_module("MP1", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN2", nn.Conv2d(in_channels=filter_sizes[0], out_channels=filter_sizes[1], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN2", nn.BatchNorm2d(num_features=filter_sizes[1], eps=1e-5))
        self.encoder.add_module("AN2", nn.ReLU())
        self.encoder.add_module("MP2", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN3", nn.Conv2d(in_channels=filter_sizes[1], out_channels=filter_sizes[2], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN3", nn.BatchNorm2d(num_features=filter_sizes[2], eps=1e-5))
        self.encoder.add_module("AN3", nn.ReLU())
        self.encoder.add_module("MP3", nn.MaxPool2d(kernel_size=(2, 2)))

        self.classifier = nn.Sequential()
        if len(HLs) == 0:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[2]*4*4, out_features=5))
        elif len(HLs) == 1:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[2]*4*4, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=5))
        elif len(HLs) == 2:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[2]*4*4, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=HLs[1]))
            self.classifier.add_module("AN2", nn.ReLU())
            if DP:
                self.classifier.add_module("DP2", nn.Dropout(p=DP))
            self.classifier.add_module("FC3", nn.Linear(in_features=HLs[1], out_features=5))
    
    def forward(self, x):
        x = self.encoder(x)
        x = x.view(x.shape[0], -1)
        return nn.LogSoftmax(dim=1)(self.classifier(x))

# %% [markdown]
# ### **Fit and Predict**

# %%
def fit(
    model=None,
    optimizer=None, 
    scheduler_rlrop=None,
    scheduler_oclr=None,
    epochs=None, 
    early_stopping_patience=None, 
    dataloaders=None, 
    fold=None, 
    save_path=None,
    device=None,
    verbose=False
) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss: dict = {"train" : np.inf, "valid" : np.inf} 
    bestAccs: dict = {"train" : 0.0, "valid" : 0.0}
        
    Losses: list = []
    Accuracies: list = [] 
    LRs: list = []
        
    if fold: 
        ble_name = f"ble_state_fold_{fold}.pt"
        bae_name = f"bae_state_fold_{fold}.pt"
    else: 
        ble_name = f"ble_state.pt"
        bae_name = f"bae_state.pt"
    
    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss: dict = {"train" : 0.0, "valid" : 0.0} 
        epochAccs: dict = {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass: list = []
            accsPerPass: list = []
                
            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
    
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, ble_name))
                torch.save(save_dict, os.path.join(save_path, bae_name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, ble_name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
            torch.save(save_dict,os.path.join(save_path, bae_name))
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
 Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                        epochLoss["train"], epochLoss["valid"], 
                                                                        epochAccs["train"], epochAccs["valid"], 
                                                                        time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, bestLoss, bestAccs, BLE, BAE, ble_name, bae_name


def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.argmax(torch.exp(model(X)), dim=1)
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
images = np.load("../input/icc-ml-2022a/DATA/TaskA/train_images_A.npy")
labels = np.load("../input/icc-ml-2022a/DATA/TaskA/train_labels_A.npy")

# %%
fold: int = 1
BLs: list = []
BAs: list = []

# # Test 
# cfg.epochs = 2
# cfg.n_splits = 3

cfg.batch_size = 64
    
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(images, labels):

    tr_images, va_images = images[tr_idx], images[va_idx] 
    tr_labels, va_labels = labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(
        images=tr_images, 
        labels=tr_labels.reshape(-1, 1),
        transform=cfg.train_transform
    )
    
    va_data_setup = DS(
        images=va_images, 
        labels=va_labels.reshape(-1, 1),
        transform=cfg.valid_transform
    )

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
        "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
    }

    cfg.steps_per_epoch = len(dataloaders["train"])
    
    torch.manual_seed(cfg.seed)
    model = Model(filter_sizes=[64, 128, 256]).to(cfg.device)

    optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.AdamW([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.SGD([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd, momentum=0.9)
    
    scheduler_oclr = optim.lr_scheduler.OneCycleLR(
        optimizer=optimizer, 
        max_lr=cfg.max_lr, 
        epochs=cfg.epochs, 
        steps_per_epoch=cfg.steps_per_epoch,
        pct_start=cfg.pct_start, 
        div_factor=cfg.div_factor, 
        final_div_factor=cfg.final_div_factor
    )

    # scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(
    #     optimizer=optimizer,
    #     patience=cfg.patience,
    #     eps=cfg.eps,
    #     verbose=True
    # )

    # scheduler_oclr = None
    scheduler_rlrop = None
    
    L, A, LR, BL, BA, _, _, _, _ = fit(
        model=model, 
        optimizer=optimizer, 
        scheduler_oclr=scheduler_oclr,
        scheduler_rlrop=scheduler_rlrop,
        epochs=cfg.epochs, 
        early_stopping_patience=cfg.early_stopping, 
        dataloaders=dataloaders, 
        device=cfg.device,
        save_path=cfg.save_path,
        fold=fold,
        verbose=True
    )
    
    breaker()
    show_loss_graphs(L)
    breaker()
    show_accuracy_graphs(A)
    breaker()
    if scheduler_oclr:
        show_lr_graph(LR)
        breaker()
    
    BLs.append(BL)
    BAs.append(BA)
    
    fold += 1
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.42210 | Valid Loss: 1.08886 | Train Accs: 0.37595 | Valid Accs: 0.56388 | Time: 22.13 seconds
# Epoch: 2 | Train Loss: 1.19075 | Valid Loss: 0.98641 | Train Accs: 0.50849 | Valid Accs: 0.59513 | Time: 14.61 seconds
# Epoch: 3 | Train Loss: 1.15929 | Valid Loss: 0.88349 | Train Accs: 0.52960 | Valid Accs: 0.65566 | Time: 15.41 seconds
# Epoch: 4 | Train Loss: 1.12015 | Valid Loss: 0.96967 | Train Accs: 0.54992 | Valid Accs: 0.61234 | Time: 14.79 seconds
# Epoch: 5 | Train Loss: 1.07124 | Valid Loss: 0.79859 | Train Accs: 0.57498 | Valid Accs: 0.68513 | Time: 15.41 seconds
# Epoch: 6 | Train Loss: 1.01156 | Valid Loss: 0.79283 | Train Accs: 0.60254 | Valid Accs: 0.68612 | Time: 15.53 seconds
# Epoch: 7 | Train Loss: 0.97195 | Valid Loss: 0.71634 | Train Accs: 0.62036 | Valid Accs: 0.72468 | Time: 14.70 seconds
# Epoch: 8 | Train Loss: 0.93638 | Valid Loss: 0.77155 | Train Accs: 0.63414 | Valid Accs: 0.70352 | Time: 15.71 seconds
# Epoch: 9 | Train Loss: 0.91039 | Valid Loss: 0.68128 | Train Accs: 0.64472 | Valid Accs: 0.74130 | Time: 15.45 seconds
# Epoch: 10 | Train Loss: 0.88162 | Valid Loss: 0.79531 | Train Accs: 0.65815 | Valid Accs: 0.70332 | Time: 16.56 seconds
# Epoch: 11 | Train Loss: 0.85102 | Valid Loss: 0.63796 | Train Accs: 0.67292 | Valid Accs: 0.76503 | Time: 16.31 seconds
# Epoch: 12 | Train Loss: 0.82091 | Valid Loss: 0.57579 | Train Accs: 0.68640 | Valid Accs: 0.79055 | Time: 16.31 seconds
# Epoch: 13 | Train Loss: 0.80711 | Valid Loss: 0.63668 | Train Accs: 0.68930 | Valid Accs: 0.76998 | Time: 16.16 seconds
# Epoch: 14 | Train Loss: 0.78700 | Valid Loss: 0.55679 | Train Accs: 0.70088 | Valid Accs: 0.79767 | Time: 16.40 seconds
# Epoch: 15 | Train Loss: 0.77299 | Valid Loss: 0.53462 | Train Accs: 0.70887 | Valid Accs: 0.80360 | Time: 16.27 seconds
# Epoch: 16 | Train Loss: 0.74762 | Valid Loss: 0.53983 | Train Accs: 0.71730 | Valid Accs: 0.80281 | Time: 15.29 seconds
# Epoch: 17 | Train Loss: 0.73453 | Valid Loss: 0.56306 | Train Accs: 0.72359 | Valid Accs: 0.79964 | Time: 15.48 seconds
# Epoch: 18 | Train Loss: 0.71903 | Valid Loss: 0.52331 | Train Accs: 0.72983 | Valid Accs: 0.81032 | Time: 15.12 seconds
# Epoch: 19 | Train Loss: 0.69315 | Valid Loss: 0.50225 | Train Accs: 0.74206 | Valid Accs: 0.81863 | Time: 15.41 seconds
# Epoch: 20 | Train Loss: 0.68965 | Valid Loss: 0.48418 | Train Accs: 0.74406 | Valid Accs: 0.82100 | Time: 15.79 seconds
# Epoch: 21 | Train Loss: 0.66798 | Valid Loss: 0.48578 | Train Accs: 0.75165 | Valid Accs: 0.82377 | Time: 15.16 seconds
# Epoch: 22 | Train Loss: 0.66168 | Valid Loss: 0.48889 | Train Accs: 0.75324 | Valid Accs: 0.82397 | Time: 15.93 seconds
# Epoch: 23 | Train Loss: 0.65346 | Valid Loss: 0.47504 | Train Accs: 0.75909 | Valid Accs: 0.82931 | Time: 15.19 seconds
# Epoch: 24 | Train Loss: 0.64920 | Valid Loss: 0.48018 | Train Accs: 0.75729 | Valid Accs: 0.82773 | Time: 15.87 seconds
# Epoch: 25 | Train Loss: 0.64265 | Valid Loss: 0.47660 | Train Accs: 0.76298 | Valid Accs: 0.82852 | Time: 14.94 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.60 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.42277 | Valid Loss: 1.07589 | Train Accs: 0.37061 | Valid Accs: 0.56290 | Time: 15.92 seconds
# Epoch: 2 | Train Loss: 1.18934 | Valid Loss: 0.96544 | Train Accs: 0.50963 | Valid Accs: 0.62282 | Time: 14.91 seconds
# Epoch: 3 | Train Loss: 1.17012 | Valid Loss: 0.93126 | Train Accs: 0.52057 | Valid Accs: 0.62421 | Time: 15.68 seconds
# Epoch: 4 | Train Loss: 1.11948 | Valid Loss: 0.81607 | Train Accs: 0.55177 | Valid Accs: 0.68869 | Time: 15.40 seconds
# Epoch: 5 | Train Loss: 1.07892 | Valid Loss: 0.77986 | Train Accs: 0.57014 | Valid Accs: 0.69324 | Time: 15.65 seconds
# Epoch: 6 | Train Loss: 1.01829 | Valid Loss: 0.79739 | Train Accs: 0.59849 | Valid Accs: 0.67820 | Time: 15.13 seconds
# Epoch: 7 | Train Loss: 0.97387 | Valid Loss: 0.73024 | Train Accs: 0.61991 | Valid Accs: 0.72172 | Time: 15.55 seconds
# Epoch: 8 | Train Loss: 0.94101 | Valid Loss: 0.72628 | Train Accs: 0.62989 | Valid Accs: 0.72627 | Time: 15.58 seconds
# Epoch: 9 | Train Loss: 0.90727 | Valid Loss: 0.59967 | Train Accs: 0.64726 | Valid Accs: 0.78461 | Time: 16.73 seconds
# Epoch: 10 | Train Loss: 0.88498 | Valid Loss: 0.61649 | Train Accs: 0.65939 | Valid Accs: 0.76286 | Time: 15.31 seconds
# Epoch: 11 | Train Loss: 0.85175 | Valid Loss: 0.69204 | Train Accs: 0.67183 | Valid Accs: 0.72725 | Time: 16.15 seconds
# Epoch: 12 | Train Loss: 0.83571 | Valid Loss: 0.57319 | Train Accs: 0.68036 | Valid Accs: 0.78323 | Time: 15.35 seconds
# Epoch: 13 | Train Loss: 0.81819 | Valid Loss: 0.67771 | Train Accs: 0.68545 | Valid Accs: 0.75435 | Time: 15.96 seconds
# Epoch: 14 | Train Loss: 0.79805 | Valid Loss: 0.66377 | Train Accs: 0.69718 | Valid Accs: 0.75376 | Time: 15.10 seconds
# Epoch: 15 | Train Loss: 0.77225 | Valid Loss: 0.57584 | Train Accs: 0.70697 | Valid Accs: 0.78283 | Time: 15.72 seconds
# Epoch: 16 | Train Loss: 0.75842 | Valid Loss: 0.54029 | Train Accs: 0.70996 | Valid Accs: 0.79846 | Time: 15.56 seconds
# Epoch: 17 | Train Loss: 0.74699 | Valid Loss: 0.48530 | Train Accs: 0.71600 | Valid Accs: 0.82338 | Time: 15.73 seconds
# Epoch: 18 | Train Loss: 0.72600 | Valid Loss: 0.49147 | Train Accs: 0.72529 | Valid Accs: 0.81507 | Time: 15.37 seconds
# Epoch: 19 | Train Loss: 0.70766 | Valid Loss: 0.45948 | Train Accs: 0.73273 | Valid Accs: 0.83386 | Time: 15.62 seconds
# Epoch: 20 | Train Loss: 0.68903 | Valid Loss: 0.46896 | Train Accs: 0.74211 | Valid Accs: 0.83010 | Time: 15.07 seconds
# Epoch: 21 | Train Loss: 0.67225 | Valid Loss: 0.46493 | Train Accs: 0.74586 | Valid Accs: 0.83129 | Time: 15.95 seconds
# Epoch: 22 | Train Loss: 0.66341 | Valid Loss: 0.46734 | Train Accs: 0.75454 | Valid Accs: 0.83228 | Time: 14.91 seconds
# Epoch: 23 | Train Loss: 0.66286 | Valid Loss: 0.44000 | Train Accs: 0.75439 | Valid Accs: 0.83979 | Time: 15.95 seconds
# Epoch: 24 | Train Loss: 0.65813 | Valid Loss: 0.44182 | Train Accs: 0.75634 | Valid Accs: 0.84217 | Time: 15.15 seconds
# Epoch: 25 | Train Loss: 0.64779 | Valid Loss: 0.44189 | Train Accs: 0.76328 | Valid Accs: 0.84157 | Time: 15.14 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.48 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.42944 | Valid Loss: 1.10739 | Train Accs: 0.36836 | Valid Accs: 0.56586 | Time: 14.70 seconds
# Epoch: 2 | Train Loss: 1.20489 | Valid Loss: 1.00781 | Train Accs: 0.50180 | Valid Accs: 0.59672 | Time: 15.68 seconds
# Epoch: 3 | Train Loss: 1.16070 | Valid Loss: 0.98439 | Train Accs: 0.52801 | Valid Accs: 0.60938 | Time: 15.43 seconds
# Epoch: 4 | Train Loss: 1.13817 | Valid Loss: 0.78399 | Train Accs: 0.54263 | Valid Accs: 0.69798 | Time: 15.84 seconds
# Epoch: 5 | Train Loss: 1.07235 | Valid Loss: 0.85681 | Train Accs: 0.57179 | Valid Accs: 0.66337 | Time: 15.22 seconds
# Epoch: 6 | Train Loss: 1.02171 | Valid Loss: 0.71499 | Train Accs: 0.59969 | Valid Accs: 0.73714 | Time: 15.58 seconds
# Epoch: 7 | Train Loss: 0.97831 | Valid Loss: 0.77186 | Train Accs: 0.61362 | Valid Accs: 0.69739 | Time: 15.07 seconds
# Epoch: 8 | Train Loss: 0.94049 | Valid Loss: 0.66529 | Train Accs: 0.63548 | Valid Accs: 0.75158 | Time: 15.84 seconds
# Epoch: 9 | Train Loss: 0.91034 | Valid Loss: 0.75226 | Train Accs: 0.64472 | Valid Accs: 0.71638 | Time: 15.22 seconds
# Epoch: 10 | Train Loss: 0.88315 | Valid Loss: 0.70174 | Train Accs: 0.65994 | Valid Accs: 0.74506 | Time: 15.56 seconds
# Epoch: 11 | Train Loss: 0.85004 | Valid Loss: 0.58037 | Train Accs: 0.67197 | Valid Accs: 0.79193 | Time: 14.71 seconds
# Epoch: 12 | Train Loss: 0.84618 | Valid Loss: 0.60210 | Train Accs: 0.67302 | Valid Accs: 0.78263 | Time: 15.65 seconds
# Epoch: 13 | Train Loss: 0.81071 | Valid Loss: 0.57161 | Train Accs: 0.69199 | Valid Accs: 0.78916 | Time: 15.17 seconds
# Epoch: 14 | Train Loss: 0.80297 | Valid Loss: 0.62884 | Train Accs: 0.69574 | Valid Accs: 0.77057 | Time: 15.44 seconds
# Epoch: 15 | Train Loss: 0.77639 | Valid Loss: 0.61846 | Train Accs: 0.70847 | Valid Accs: 0.75415 | Time: 15.02 seconds
# Epoch: 16 | Train Loss: 0.76081 | Valid Loss: 0.50211 | Train Accs: 0.71186 | Valid Accs: 0.81863 | Time: 15.85 seconds
# Epoch: 17 | Train Loss: 0.74443 | Valid Loss: 0.51532 | Train Accs: 0.71835 | Valid Accs: 0.81369 | Time: 15.09 seconds
# Epoch: 18 | Train Loss: 0.72781 | Valid Loss: 0.47715 | Train Accs: 0.72489 | Valid Accs: 0.82892 | Time: 15.72 seconds
# Epoch: 19 | Train Loss: 0.70741 | Valid Loss: 0.47055 | Train Accs: 0.73213 | Valid Accs: 0.83010 | Time: 14.73 seconds
# Epoch: 20 | Train Loss: 0.69159 | Valid Loss: 0.48340 | Train Accs: 0.74101 | Valid Accs: 0.81922 | Time: 15.05 seconds
# Epoch: 21 | Train Loss: 0.68737 | Valid Loss: 0.45478 | Train Accs: 0.74361 | Valid Accs: 0.83366 | Time: 15.09 seconds
# Epoch: 22 | Train Loss: 0.67189 | Valid Loss: 0.43672 | Train Accs: 0.74925 | Valid Accs: 0.84375 | Time: 15.19 seconds
# Epoch: 23 | Train Loss: 0.65664 | Valid Loss: 0.43779 | Train Accs: 0.75674 | Valid Accs: 0.84355 | Time: 15.62 seconds
# Epoch: 24 | Train Loss: 0.65093 | Valid Loss: 0.43577 | Train Accs: 0.75614 | Valid Accs: 0.83979 | Time: 15.20 seconds
# Epoch: 25 | Train Loss: 0.65298 | Valid Loss: 0.43635 | Train Accs: 0.75734 | Valid Accs: 0.84039 | Time: 15.38 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 22
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.38 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 4...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.41993 | Valid Loss: 1.14402 | Train Accs: 0.37520 | Valid Accs: 0.51523 | Time: 15.22 seconds
# Epoch: 2 | Train Loss: 1.20172 | Valid Loss: 0.93729 | Train Accs: 0.50230 | Valid Accs: 0.64003 | Time: 15.34 seconds
# Epoch: 3 | Train Loss: 1.15085 | Valid Loss: 0.98867 | Train Accs: 0.53195 | Valid Accs: 0.60324 | Time: 14.64 seconds
# Epoch: 4 | Train Loss: 1.12852 | Valid Loss: 1.05820 | Train Accs: 0.55616 | Valid Accs: 0.61313 | Time: 15.14 seconds
# Epoch: 5 | Train Loss: 1.07735 | Valid Loss: 1.03747 | Train Accs: 0.57034 | Valid Accs: 0.57753 | Time: 14.83 seconds
# Epoch: 6 | Train Loss: 1.01908 | Valid Loss: 0.75718 | Train Accs: 0.59974 | Valid Accs: 0.72033 | Time: 15.34 seconds
# Epoch: 7 | Train Loss: 0.97442 | Valid Loss: 0.70126 | Train Accs: 0.61307 | Valid Accs: 0.73655 | Time: 15.05 seconds
# Epoch: 8 | Train Loss: 0.93815 | Valid Loss: 0.75824 | Train Accs: 0.63623 | Valid Accs: 0.70866 | Time: 15.21 seconds
# Epoch: 9 | Train Loss: 0.90317 | Valid Loss: 0.73955 | Train Accs: 0.65211 | Valid Accs: 0.72468 | Time: 14.87 seconds
# Epoch: 10 | Train Loss: 0.88060 | Valid Loss: 0.80315 | Train Accs: 0.65775 | Valid Accs: 0.69996 | Time: 15.42 seconds
# Epoch: 11 | Train Loss: 0.85748 | Valid Loss: 0.65579 | Train Accs: 0.67033 | Valid Accs: 0.75989 | Time: 14.99 seconds
# Epoch: 12 | Train Loss: 0.83088 | Valid Loss: 0.60603 | Train Accs: 0.67936 | Valid Accs: 0.77314 | Time: 15.08 seconds
# Epoch: 13 | Train Loss: 0.80955 | Valid Loss: 0.59641 | Train Accs: 0.68695 | Valid Accs: 0.77868 | Time: 14.80 seconds
# Epoch: 14 | Train Loss: 0.80606 | Valid Loss: 0.59148 | Train Accs: 0.69214 | Valid Accs: 0.78066 | Time: 15.36 seconds
# Epoch: 15 | Train Loss: 0.77632 | Valid Loss: 0.58868 | Train Accs: 0.70582 | Valid Accs: 0.78085 | Time: 14.61 seconds
# Epoch: 16 | Train Loss: 0.76581 | Valid Loss: 0.53223 | Train Accs: 0.70672 | Valid Accs: 0.81428 | Time: 14.86 seconds
# Epoch: 17 | Train Loss: 0.73562 | Valid Loss: 0.50744 | Train Accs: 0.72020 | Valid Accs: 0.81764 | Time: 14.99 seconds
# Epoch: 18 | Train Loss: 0.71699 | Valid Loss: 0.53166 | Train Accs: 0.73143 | Valid Accs: 0.81606 | Time: 15.04 seconds
# Epoch: 19 | Train Loss: 0.70072 | Valid Loss: 0.49494 | Train Accs: 0.73752 | Valid Accs: 0.82041 | Time: 14.90 seconds
# Epoch: 20 | Train Loss: 0.69318 | Valid Loss: 0.48658 | Train Accs: 0.73767 | Valid Accs: 0.82694 | Time: 15.11 seconds
# Epoch: 21 | Train Loss: 0.67074 | Valid Loss: 0.47362 | Train Accs: 0.75155 | Valid Accs: 0.83307 | Time: 14.65 seconds
# Epoch: 22 | Train Loss: 0.65917 | Valid Loss: 0.46963 | Train Accs: 0.75324 | Valid Accs: 0.83465 | Time: 14.36 seconds
# Epoch: 23 | Train Loss: 0.65863 | Valid Loss: 0.46528 | Train Accs: 0.75629 | Valid Accs: 0.83584 | Time: 15.57 seconds
# Epoch: 24 | Train Loss: 0.64668 | Valid Loss: 0.46309 | Train Accs: 0.75948 | Valid Accs: 0.83683 | Time: 14.49 seconds
# Epoch: 25 | Train Loss: 0.63987 | Valid Loss: 0.46632 | Train Accs: 0.76288 | Valid Accs: 0.83386 | Time: 14.88 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.25 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 5...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.42397 | Valid Loss: 1.11896 | Train Accs: 0.37255 | Valid Accs: 0.52294 | Time: 14.63 seconds
# Epoch: 2 | Train Loss: 1.18982 | Valid Loss: 1.10019 | Train Accs: 0.51043 | Valid Accs: 0.55261 | Time: 15.06 seconds
# Epoch: 3 | Train Loss: 1.15763 | Valid Loss: 0.97142 | Train Accs: 0.53130 | Valid Accs: 0.60759 | Time: 14.71 seconds
# Epoch: 4 | Train Loss: 1.12888 | Valid Loss: 0.77645 | Train Accs: 0.55072 | Valid Accs: 0.70471 | Time: 14.79 seconds
# Epoch: 5 | Train Loss: 1.06660 | Valid Loss: 0.79348 | Train Accs: 0.57812 | Valid Accs: 0.68691 | Time: 14.53 seconds
# Epoch: 6 | Train Loss: 1.02452 | Valid Loss: 0.73346 | Train Accs: 0.59954 | Valid Accs: 0.71816 | Time: 14.96 seconds
# Epoch: 7 | Train Loss: 0.96170 | Valid Loss: 0.72135 | Train Accs: 0.62370 | Valid Accs: 0.72449 | Time: 14.66 seconds
# Epoch: 8 | Train Loss: 0.93776 | Valid Loss: 0.64043 | Train Accs: 0.63463 | Valid Accs: 0.75910 | Time: 14.89 seconds
# Epoch: 9 | Train Loss: 0.90957 | Valid Loss: 0.97875 | Train Accs: 0.64447 | Valid Accs: 0.62658 | Time: 14.76 seconds
# Epoch: 10 | Train Loss: 0.87193 | Valid Loss: 0.61511 | Train Accs: 0.66349 | Valid Accs: 0.76503 | Time: 14.64 seconds
# Epoch: 11 | Train Loss: 0.84750 | Valid Loss: 0.60133 | Train Accs: 0.67232 | Valid Accs: 0.77176 | Time: 14.59 seconds
# Epoch: 12 | Train Loss: 0.82951 | Valid Loss: 0.68333 | Train Accs: 0.68161 | Valid Accs: 0.74209 | Time: 15.16 seconds
# Epoch: 13 | Train Loss: 0.81483 | Valid Loss: 0.56385 | Train Accs: 0.68690 | Valid Accs: 0.79628 | Time: 14.73 seconds
# Epoch: 14 | Train Loss: 0.78740 | Valid Loss: 0.54212 | Train Accs: 0.70038 | Valid Accs: 0.80419 | Time: 14.67 seconds
# Epoch: 15 | Train Loss: 0.77011 | Valid Loss: 0.52908 | Train Accs: 0.70592 | Valid Accs: 0.80320 | Time: 15.16 seconds
# Epoch: 16 | Train Loss: 0.75451 | Valid Loss: 0.52801 | Train Accs: 0.71486 | Valid Accs: 0.80459 | Time: 14.44 seconds
# Epoch: 17 | Train Loss: 0.73958 | Valid Loss: 0.52473 | Train Accs: 0.72244 | Valid Accs: 0.80617 | Time: 15.00 seconds
# Epoch: 18 | Train Loss: 0.71812 | Valid Loss: 0.50758 | Train Accs: 0.73103 | Valid Accs: 0.81191 | Time: 14.86 seconds
# Epoch: 19 | Train Loss: 0.70863 | Valid Loss: 0.46842 | Train Accs: 0.73767 | Valid Accs: 0.83109 | Time: 15.16 seconds
# Epoch: 20 | Train Loss: 0.68623 | Valid Loss: 0.48062 | Train Accs: 0.74556 | Valid Accs: 0.82516 | Time: 14.52 seconds
# Epoch: 21 | Train Loss: 0.67025 | Valid Loss: 0.48375 | Train Accs: 0.74740 | Valid Accs: 0.82338 | Time: 14.93 seconds
# Epoch: 22 | Train Loss: 0.66861 | Valid Loss: 0.45999 | Train Accs: 0.75025 | Valid Accs: 0.83327 | Time: 14.35 seconds
# Epoch: 23 | Train Loss: 0.66105 | Valid Loss: 0.45991 | Train Accs: 0.75559 | Valid Accs: 0.83267 | Time: 15.20 seconds
# Epoch: 24 | Train Loss: 0.64649 | Valid Loss: 0.45209 | Train Accs: 0.75953 | Valid Accs: 0.83307 | Time: 14.21 seconds
# Epoch: 25 | Train Loss: 0.65048 | Valid Loss: 0.45542 | Train Accs: 0.76113 | Valid Accs: 0.83426 | Time: 14.44 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 25
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.15 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************

# %% [markdown]
# ### **Best Model**

# %%
BL = np.inf
for i in range(len(BLs)):
    if BLs[i]["valid"] < BL:
        BL = BLs[i]["valid"]
        best_loss_index = i

        
BA = 0.0
for i in range(len(BAs)):
    if BAs[i]["valid"] > BA:
        BA = BAs[i]["valid"]
        best_accs_index = i

breaker()
print(f"Best Loss Model Fold     : {best_loss_index + 1}")
print(f"Best Accuracy Model Fold : {best_accs_index + 1}")
breaker()
# Out:
# **************************************************
#
# Best Loss Model Fold     : 3
# Best Accuracy Model Fold : 3
#
# **************************************************
