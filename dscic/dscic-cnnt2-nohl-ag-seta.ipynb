# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from scipy import stats
from typing import Union
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import models, transforms

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Helpers**

# %%
SEED: int = 42

def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def get_image(path: str, size: int=224) -> np.ndarray:
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
    return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_AREA)


def show_loss_graphs(L: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()

    
def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(A)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()
    

def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 ):
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.train_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49085, 0.48537, 0.45057], [0.24560, 0.24165, 0.26213]),
            transforms.RandomAffine(degrees=(-45, 45), translate=(0.15, 0.15), scale=(0.5, 1.5)),
            transforms.RandomHorizontalFlip(p=0.25),
            transforms.RandomVerticalFlip(p=0.25),
        ])
        self.valid_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49085, 0.48537, 0.45057], [0.24560, 0.24165, 0.26213]),
        ]) 
                                
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
    
cfg = CFG(
    seed=SEED, 
)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(
        self, 
        images: np.ndarray,
        labels: Union[np.ndarray, None]=None, 
        transform=None
    ):
        
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is None:
            return self.transform(self.images[idx])
        return self.transform(self.images[idx]), torch.LongTensor(self.labels[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, filter_sizes: list=[64, 128, 256, 512], HLs: list=[], DP: float=None):

        super(Model, self).__init__()

        self.encoder = nn.Sequential()
        self.encoder.add_module("CN1", nn.Conv2d(in_channels=3, out_channels=filter_sizes[0], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN1", nn.BatchNorm2d(num_features=filter_sizes[0], eps=1e-5))
        self.encoder.add_module("AN1", nn.ReLU())
        self.encoder.add_module("MP1", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN2", nn.Conv2d(in_channels=filter_sizes[0], out_channels=filter_sizes[1], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN2", nn.BatchNorm2d(num_features=filter_sizes[1], eps=1e-5))
        self.encoder.add_module("AN2", nn.ReLU())
        self.encoder.add_module("MP2", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN3", nn.Conv2d(in_channels=filter_sizes[1], out_channels=filter_sizes[2], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN3", nn.BatchNorm2d(num_features=filter_sizes[2], eps=1e-5))
        self.encoder.add_module("AN3", nn.ReLU())
        self.encoder.add_module("MP3", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN4", nn.Conv2d(in_channels=filter_sizes[2], out_channels=filter_sizes[3], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN4", nn.BatchNorm2d(num_features=filter_sizes[3], eps=1e-5))
        self.encoder.add_module("AN4", nn.ReLU())
        self.encoder.add_module("MP4", nn.MaxPool2d(kernel_size=(2, 2)))

        self.classifier = nn.Sequential()
        if len(HLs) == 0:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=5))
        elif len(HLs) == 1:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=5))
        elif len(HLs) == 2:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=HLs[1]))
            self.classifier.add_module("AN2", nn.ReLU())
            if DP:
                self.classifier.add_module("DP2", nn.Dropout(p=DP))
            self.classifier.add_module("FC3", nn.Linear(in_features=HLs[1], out_features=5))
    
    def forward(self, x):
        x = self.encoder(x)
        x = x.view(x.shape[0], -1)
        return nn.LogSoftmax(dim=1)(self.classifier(x))

# %% [markdown]
# ### **Fit and Predict**

# %%
def fit(
    model=None,
    optimizer=None, 
    scheduler_rlrop=None,
    scheduler_oclr=None,
    epochs=None, 
    early_stopping_patience=None, 
    dataloaders=None, 
    fold=None, 
    save_path=None,
    device=None,
    verbose=False
) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss: dict = {"train" : np.inf, "valid" : np.inf} 
    bestAccs: dict = {"train" : 0.0, "valid" : 0.0}
        
    Losses: list = []
    Accuracies: list = [] 
    LRs: list = []
        
    if fold: 
        ble_name = f"ble_state_fold_{fold}.pt"
        bae_name = f"bae_state_fold_{fold}.pt"
    else: 
        ble_name = f"ble_state.pt"
        bae_name = f"bae_state.pt"
    
    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss: dict = {"train" : 0.0, "valid" : 0.0} 
        epochAccs: dict = {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass: list = []
            accsPerPass: list = []
                
            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
    
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, ble_name))
                torch.save(save_dict, os.path.join(save_path, bae_name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, ble_name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
            torch.save(save_dict,os.path.join(save_path, bae_name))
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
 Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                        epochLoss["train"], epochLoss["valid"], 
                                                                        epochAccs["train"], epochAccs["valid"], 
                                                                        time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, bestLoss, bestAccs, BLE, BAE, ble_name, bae_name


def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.argmax(torch.exp(model(X)), dim=1)
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
images = np.load("../input/icc-ml-2022a/DATA/TaskA/train_images_A.npy")
labels = np.load("../input/icc-ml-2022a/DATA/TaskA/train_labels_A.npy")

# %%
fold: int = 1
BLs: list = []
BAs: list = []

# # Test 
# cfg.epochs = 2
# cfg.n_splits = 3

cfg.batch_size = 64
    
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(images, labels):

    tr_images, va_images = images[tr_idx], images[va_idx] 
    tr_labels, va_labels = labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(
        images=tr_images, 
        labels=tr_labels.reshape(-1, 1),
        transform=cfg.train_transform
    )
    
    va_data_setup = DS(
        images=va_images, 
        labels=va_labels.reshape(-1, 1),
        transform=cfg.valid_transform
    )

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
        "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
    }

    cfg.steps_per_epoch = len(dataloaders["train"])
    
    torch.manual_seed(cfg.seed)
    model = Model(filter_sizes=[64, 128, 256, 512]).to(cfg.device)

    optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.AdamW([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.SGD([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd, momentum=0.9)
    
    scheduler_oclr = optim.lr_scheduler.OneCycleLR(
        optimizer=optimizer, 
        max_lr=cfg.max_lr, 
        epochs=cfg.epochs, 
        steps_per_epoch=cfg.steps_per_epoch,
        pct_start=cfg.pct_start, 
        div_factor=cfg.div_factor, 
        final_div_factor=cfg.final_div_factor
    )

    # scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(
    #     optimizer=optimizer,
    #     patience=cfg.patience,
    #     eps=cfg.eps,
    #     verbose=True
    # )

    # scheduler_oclr = None
    scheduler_rlrop = None
    
    L, A, LR, BL, BA, _, _, _, _ = fit(
        model=model, 
        optimizer=optimizer, 
        scheduler_oclr=scheduler_oclr,
        scheduler_rlrop=scheduler_rlrop,
        epochs=cfg.epochs, 
        early_stopping_patience=cfg.early_stopping, 
        dataloaders=dataloaders, 
        device=cfg.device,
        save_path=cfg.save_path,
        fold=fold,
        verbose=True
    )
    
    breaker()
    show_loss_graphs(L)
    breaker()
    show_accuracy_graphs(A)
    breaker()
    if scheduler_oclr:
        show_lr_graph(LR)
        breaker()
    
    BLs.append(BL)
    BAs.append(BA)
    
    fold += 1
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.36978 | Valid Loss: 1.15972 | Train Accs: 0.40415 | Valid Accs: 0.53085 | Time: 23.20 seconds
# Epoch: 2 | Train Loss: 1.15359 | Valid Loss: 0.88988 | Train Accs: 0.52726 | Valid Accs: 0.65032 | Time: 16.40 seconds
# Epoch: 3 | Train Loss: 1.09235 | Valid Loss: 1.09329 | Train Accs: 0.55786 | Valid Accs: 0.59652 | Time: 16.59 seconds
# Epoch: 4 | Train Loss: 1.03700 | Valid Loss: 0.77682 | Train Accs: 0.58486 | Valid Accs: 0.69680 | Time: 16.93 seconds
# Epoch: 5 | Train Loss: 0.99302 | Valid Loss: 0.77671 | Train Accs: 0.60523 | Valid Accs: 0.70530 | Time: 15.84 seconds
# Epoch: 6 | Train Loss: 0.94650 | Valid Loss: 0.73190 | Train Accs: 0.62645 | Valid Accs: 0.71242 | Time: 16.89 seconds
# Epoch: 7 | Train Loss: 0.89587 | Valid Loss: 0.62606 | Train Accs: 0.65340 | Valid Accs: 0.76305 | Time: 16.00 seconds
# Epoch: 8 | Train Loss: 0.84053 | Valid Loss: 0.68374 | Train Accs: 0.67487 | Valid Accs: 0.73892 | Time: 16.01 seconds
# Epoch: 9 | Train Loss: 0.82266 | Valid Loss: 0.67559 | Train Accs: 0.68336 | Valid Accs: 0.75316 | Time: 15.74 seconds
# Epoch: 10 | Train Loss: 0.80331 | Valid Loss: 0.57801 | Train Accs: 0.69209 | Valid Accs: 0.78145 | Time: 16.22 seconds
# Epoch: 11 | Train Loss: 0.76699 | Valid Loss: 0.67220 | Train Accs: 0.70677 | Valid Accs: 0.74980 | Time: 15.84 seconds
# Epoch: 12 | Train Loss: 0.75234 | Valid Loss: 0.59356 | Train Accs: 0.71156 | Valid Accs: 0.78145 | Time: 16.06 seconds
# Epoch: 13 | Train Loss: 0.73529 | Valid Loss: 0.59578 | Train Accs: 0.72199 | Valid Accs: 0.77690 | Time: 16.36 seconds
# Epoch: 14 | Train Loss: 0.70902 | Valid Loss: 0.57862 | Train Accs: 0.73472 | Valid Accs: 0.77927 | Time: 15.92 seconds
# Epoch: 15 | Train Loss: 0.69949 | Valid Loss: 0.62495 | Train Accs: 0.73433 | Valid Accs: 0.75989 | Time: 16.16 seconds
# Epoch: 16 | Train Loss: 0.68693 | Valid Loss: 0.50717 | Train Accs: 0.74032 | Valid Accs: 0.81566 | Time: 16.08 seconds
# Epoch: 17 | Train Loss: 0.66124 | Valid Loss: 0.46888 | Train Accs: 0.75110 | Valid Accs: 0.82872 | Time: 16.15 seconds
# Epoch: 18 | Train Loss: 0.63519 | Valid Loss: 0.46586 | Train Accs: 0.76088 | Valid Accs: 0.83109 | Time: 16.30 seconds
# Epoch: 19 | Train Loss: 0.62608 | Valid Loss: 0.43488 | Train Accs: 0.76632 | Valid Accs: 0.84019 | Time: 16.28 seconds
# Epoch: 20 | Train Loss: 0.61101 | Valid Loss: 0.42885 | Train Accs: 0.77286 | Valid Accs: 0.84197 | Time: 16.41 seconds
# Epoch: 21 | Train Loss: 0.59471 | Valid Loss: 0.42962 | Train Accs: 0.78045 | Valid Accs: 0.84711 | Time: 16.47 seconds
# Epoch: 22 | Train Loss: 0.58033 | Valid Loss: 0.42171 | Train Accs: 0.78464 | Valid Accs: 0.84850 | Time: 16.35 seconds
# Epoch: 23 | Train Loss: 0.57127 | Valid Loss: 0.41560 | Train Accs: 0.79208 | Valid Accs: 0.84869 | Time: 16.00 seconds
# Epoch: 24 | Train Loss: 0.56338 | Valid Loss: 0.41544 | Train Accs: 0.79148 | Valid Accs: 0.85028 | Time: 16.46 seconds
# Epoch: 25 | Train Loss: 0.55989 | Valid Loss: 0.41424 | Train Accs: 0.79418 | Valid Accs: 0.85008 | Time: 15.68 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 25
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.87 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.36531 | Valid Loss: 1.06394 | Train Accs: 0.40954 | Valid Accs: 0.57536 | Time: 16.62 seconds
# Epoch: 2 | Train Loss: 1.14282 | Valid Loss: 0.92875 | Train Accs: 0.53190 | Valid Accs: 0.62045 | Time: 15.53 seconds
# Epoch: 3 | Train Loss: 1.10154 | Valid Loss: 0.94033 | Train Accs: 0.55960 | Valid Accs: 0.64755 | Time: 16.46 seconds
# Epoch: 4 | Train Loss: 1.05179 | Valid Loss: 1.19011 | Train Accs: 0.58686 | Valid Accs: 0.52611 | Time: 15.66 seconds
# Epoch: 5 | Train Loss: 0.99402 | Valid Loss: 0.79817 | Train Accs: 0.60653 | Valid Accs: 0.69225 | Time: 16.42 seconds
# Epoch: 6 | Train Loss: 0.93642 | Valid Loss: 0.99791 | Train Accs: 0.62994 | Valid Accs: 0.61294 | Time: 15.52 seconds
# Epoch: 7 | Train Loss: 0.89361 | Valid Loss: 0.63919 | Train Accs: 0.65076 | Valid Accs: 0.76068 | Time: 16.26 seconds
# Epoch: 8 | Train Loss: 0.85938 | Valid Loss: 0.61678 | Train Accs: 0.66509 | Valid Accs: 0.77433 | Time: 15.59 seconds
# Epoch: 9 | Train Loss: 0.83559 | Valid Loss: 0.58936 | Train Accs: 0.67876 | Valid Accs: 0.78560 | Time: 16.42 seconds
# Epoch: 10 | Train Loss: 0.80819 | Valid Loss: 0.65088 | Train Accs: 0.68725 | Valid Accs: 0.75752 | Time: 15.56 seconds
# Epoch: 11 | Train Loss: 0.79250 | Valid Loss: 0.64411 | Train Accs: 0.69319 | Valid Accs: 0.74169 | Time: 16.07 seconds
# Epoch: 12 | Train Loss: 0.76824 | Valid Loss: 0.50883 | Train Accs: 0.70961 | Valid Accs: 0.81547 | Time: 15.90 seconds
# Epoch: 13 | Train Loss: 0.72914 | Valid Loss: 0.55387 | Train Accs: 0.72219 | Valid Accs: 0.78718 | Time: 16.11 seconds
# Epoch: 14 | Train Loss: 0.72564 | Valid Loss: 0.48212 | Train Accs: 0.72359 | Valid Accs: 0.82061 | Time: 15.90 seconds
# Epoch: 15 | Train Loss: 0.70367 | Valid Loss: 0.49102 | Train Accs: 0.73343 | Valid Accs: 0.82081 | Time: 16.02 seconds
# Epoch: 16 | Train Loss: 0.67684 | Valid Loss: 0.45844 | Train Accs: 0.74546 | Valid Accs: 0.82634 | Time: 16.11 seconds
# Epoch: 17 | Train Loss: 0.66293 | Valid Loss: 0.43618 | Train Accs: 0.75135 | Valid Accs: 0.83999 | Time: 15.89 seconds
# Epoch: 18 | Train Loss: 0.64786 | Valid Loss: 0.43181 | Train Accs: 0.75749 | Valid Accs: 0.84672 | Time: 16.28 seconds
# Epoch: 19 | Train Loss: 0.62741 | Valid Loss: 0.42046 | Train Accs: 0.76398 | Valid Accs: 0.85305 | Time: 15.44 seconds
# Epoch: 20 | Train Loss: 0.61040 | Valid Loss: 0.41885 | Train Accs: 0.77281 | Valid Accs: 0.85008 | Time: 16.24 seconds
# Epoch: 21 | Train Loss: 0.59103 | Valid Loss: 0.41154 | Train Accs: 0.78065 | Valid Accs: 0.84949 | Time: 15.87 seconds
# Epoch: 22 | Train Loss: 0.57779 | Valid Loss: 0.39665 | Train Accs: 0.78534 | Valid Accs: 0.85661 | Time: 16.04 seconds
# Epoch: 23 | Train Loss: 0.56811 | Valid Loss: 0.39705 | Train Accs: 0.78924 | Valid Accs: 0.85720 | Time: 15.62 seconds
# Epoch: 24 | Train Loss: 0.56317 | Valid Loss: 0.39988 | Train Accs: 0.79278 | Valid Accs: 0.85403 | Time: 16.05 seconds
# Epoch: 25 | Train Loss: 0.55737 | Valid Loss: 0.39366 | Train Accs: 0.79618 | Valid Accs: 0.85680 | Time: 16.14 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 25
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.66 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.36054 | Valid Loss: 1.06701 | Train Accs: 0.40935 | Valid Accs: 0.56962 | Time: 15.97 seconds
# Epoch: 2 | Train Loss: 1.16049 | Valid Loss: 0.92281 | Train Accs: 0.51872 | Valid Accs: 0.63924 | Time: 15.89 seconds
# Epoch: 3 | Train Loss: 1.08820 | Valid Loss: 0.82044 | Train Accs: 0.56075 | Valid Accs: 0.68908 | Time: 16.05 seconds
# Epoch: 4 | Train Loss: 1.03226 | Valid Loss: 0.85176 | Train Accs: 0.58936 | Valid Accs: 0.66851 | Time: 15.84 seconds
# Epoch: 5 | Train Loss: 0.99590 | Valid Loss: 0.75501 | Train Accs: 0.60318 | Valid Accs: 0.72053 | Time: 15.96 seconds
# Epoch: 6 | Train Loss: 0.93986 | Valid Loss: 0.67718 | Train Accs: 0.62939 | Valid Accs: 0.74150 | Time: 15.76 seconds
# Epoch: 7 | Train Loss: 0.89383 | Valid Loss: 0.67714 | Train Accs: 0.64826 | Valid Accs: 0.75079 | Time: 15.93 seconds
# Epoch: 8 | Train Loss: 0.86680 | Valid Loss: 0.62267 | Train Accs: 0.66024 | Valid Accs: 0.77453 | Time: 15.50 seconds
# Epoch: 9 | Train Loss: 0.83674 | Valid Loss: 0.66690 | Train Accs: 0.67567 | Valid Accs: 0.75020 | Time: 16.92 seconds
# Epoch: 10 | Train Loss: 0.80522 | Valid Loss: 0.52329 | Train Accs: 0.68690 | Valid Accs: 0.80914 | Time: 15.92 seconds
# Epoch: 11 | Train Loss: 0.77932 | Valid Loss: 0.52610 | Train Accs: 0.70243 | Valid Accs: 0.80637 | Time: 16.27 seconds
# Epoch: 12 | Train Loss: 0.76560 | Valid Loss: 0.50136 | Train Accs: 0.70457 | Valid Accs: 0.81903 | Time: 15.67 seconds
# Epoch: 13 | Train Loss: 0.74907 | Valid Loss: 0.49247 | Train Accs: 0.71206 | Valid Accs: 0.81863 | Time: 16.48 seconds
# Epoch: 14 | Train Loss: 0.72555 | Valid Loss: 0.57194 | Train Accs: 0.72484 | Valid Accs: 0.78105 | Time: 15.67 seconds
# Epoch: 15 | Train Loss: 0.70322 | Valid Loss: 0.47024 | Train Accs: 0.73118 | Valid Accs: 0.83267 | Time: 16.36 seconds
# Epoch: 16 | Train Loss: 0.68240 | Valid Loss: 0.45320 | Train Accs: 0.74221 | Valid Accs: 0.83544 | Time: 15.58 seconds
# Epoch: 17 | Train Loss: 0.66309 | Valid Loss: 0.45269 | Train Accs: 0.74990 | Valid Accs: 0.83347 | Time: 16.40 seconds
# Epoch: 18 | Train Loss: 0.65498 | Valid Loss: 0.45354 | Train Accs: 0.75305 | Valid Accs: 0.82931 | Time: 15.70 seconds
# Epoch: 19 | Train Loss: 0.63710 | Valid Loss: 0.42094 | Train Accs: 0.76268 | Valid Accs: 0.84533 | Time: 16.60 seconds
# Epoch: 20 | Train Loss: 0.61309 | Valid Loss: 0.41862 | Train Accs: 0.77301 | Valid Accs: 0.84988 | Time: 15.45 seconds
# Epoch: 21 | Train Loss: 0.60068 | Valid Loss: 0.40297 | Train Accs: 0.78060 | Valid Accs: 0.85839 | Time: 16.02 seconds
# Epoch: 22 | Train Loss: 0.58435 | Valid Loss: 0.39689 | Train Accs: 0.78529 | Valid Accs: 0.85621 | Time: 15.97 seconds
# Epoch: 23 | Train Loss: 0.57171 | Valid Loss: 0.39062 | Train Accs: 0.79049 | Valid Accs: 0.86551 | Time: 16.09 seconds
# Epoch: 24 | Train Loss: 0.57249 | Valid Loss: 0.39243 | Train Accs: 0.78914 | Valid Accs: 0.86491 | Time: 15.63 seconds
# Epoch: 25 | Train Loss: 0.56256 | Valid Loss: 0.39185 | Train Accs: 0.79203 | Valid Accs: 0.86274 | Time: 16.21 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.66 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 4...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.36275 | Valid Loss: 1.07851 | Train Accs: 0.40865 | Valid Accs: 0.55281 | Time: 15.64 seconds
# Epoch: 2 | Train Loss: 1.15164 | Valid Loss: 0.97521 | Train Accs: 0.52706 | Valid Accs: 0.61650 | Time: 15.89 seconds
# Epoch: 3 | Train Loss: 1.09356 | Valid Loss: 0.87796 | Train Accs: 0.55381 | Valid Accs: 0.66080 | Time: 15.78 seconds
# Epoch: 4 | Train Loss: 1.03615 | Valid Loss: 0.88060 | Train Accs: 0.58287 | Valid Accs: 0.66436 | Time: 15.89 seconds
# Epoch: 5 | Train Loss: 0.99467 | Valid Loss: 0.77143 | Train Accs: 0.60628 | Valid Accs: 0.71321 | Time: 15.73 seconds
# Epoch: 6 | Train Loss: 0.92740 | Valid Loss: 0.83852 | Train Accs: 0.63443 | Valid Accs: 0.70550 | Time: 16.17 seconds
# Epoch: 7 | Train Loss: 0.89518 | Valid Loss: 0.66176 | Train Accs: 0.64861 | Valid Accs: 0.75890 | Time: 15.41 seconds
# Epoch: 8 | Train Loss: 0.85404 | Valid Loss: 0.61697 | Train Accs: 0.66598 | Valid Accs: 0.76681 | Time: 16.08 seconds
# Epoch: 9 | Train Loss: 0.81890 | Valid Loss: 0.62920 | Train Accs: 0.68436 | Valid Accs: 0.76780 | Time: 15.82 seconds
# Epoch: 10 | Train Loss: 0.80639 | Valid Loss: 0.58617 | Train Accs: 0.69089 | Valid Accs: 0.78501 | Time: 16.11 seconds
# Epoch: 11 | Train Loss: 0.78871 | Valid Loss: 0.57884 | Train Accs: 0.69798 | Valid Accs: 0.79411 | Time: 15.65 seconds
# Epoch: 12 | Train Loss: 0.76110 | Valid Loss: 0.56177 | Train Accs: 0.70872 | Valid Accs: 0.79094 | Time: 16.32 seconds
# Epoch: 13 | Train Loss: 0.73945 | Valid Loss: 0.57954 | Train Accs: 0.71885 | Valid Accs: 0.78580 | Time: 15.45 seconds
# Epoch: 14 | Train Loss: 0.71529 | Valid Loss: 0.54801 | Train Accs: 0.73083 | Valid Accs: 0.79688 | Time: 15.89 seconds
# Epoch: 15 | Train Loss: 0.69967 | Valid Loss: 0.54864 | Train Accs: 0.73233 | Valid Accs: 0.79984 | Time: 15.75 seconds
# Epoch: 16 | Train Loss: 0.67480 | Valid Loss: 0.49947 | Train Accs: 0.74646 | Valid Accs: 0.82160 | Time: 16.07 seconds
# Epoch: 17 | Train Loss: 0.65180 | Valid Loss: 0.55091 | Train Accs: 0.75584 | Valid Accs: 0.79945 | Time: 15.62 seconds
# Epoch: 18 | Train Loss: 0.64582 | Valid Loss: 0.45537 | Train Accs: 0.75659 | Valid Accs: 0.83485 | Time: 15.82 seconds
# Epoch: 19 | Train Loss: 0.62141 | Valid Loss: 0.44288 | Train Accs: 0.76737 | Valid Accs: 0.84059 | Time: 15.87 seconds
# Epoch: 20 | Train Loss: 0.60113 | Valid Loss: 0.43170 | Train Accs: 0.77776 | Valid Accs: 0.84335 | Time: 15.95 seconds
# Epoch: 21 | Train Loss: 0.58879 | Valid Loss: 0.42124 | Train Accs: 0.78165 | Valid Accs: 0.84909 | Time: 15.57 seconds
# Epoch: 22 | Train Loss: 0.57934 | Valid Loss: 0.41137 | Train Accs: 0.78634 | Valid Accs: 0.85502 | Time: 16.26 seconds
# Epoch: 23 | Train Loss: 0.56627 | Valid Loss: 0.41733 | Train Accs: 0.78834 | Valid Accs: 0.85522 | Time: 15.42 seconds
# Epoch: 24 | Train Loss: 0.55315 | Valid Loss: 0.41078 | Train Accs: 0.79628 | Valid Accs: 0.85759 | Time: 16.68 seconds
# Epoch: 25 | Train Loss: 0.55553 | Valid Loss: 0.41171 | Train Accs: 0.79478 | Valid Accs: 0.85641 | Time: 15.34 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.60 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 5...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.36024 | Valid Loss: 1.07026 | Train Accs: 0.41529 | Valid Accs: 0.56962 | Time: 16.30 seconds
# Epoch: 2 | Train Loss: 1.14768 | Valid Loss: 0.97868 | Train Accs: 0.53190 | Valid Accs: 0.60403 | Time: 15.75 seconds
# Epoch: 3 | Train Loss: 1.09155 | Valid Loss: 0.85693 | Train Accs: 0.56140 | Valid Accs: 0.66733 | Time: 16.13 seconds
# Epoch: 4 | Train Loss: 1.03623 | Valid Loss: 0.84909 | Train Accs: 0.58961 | Valid Accs: 0.68078 | Time: 15.22 seconds
# Epoch: 5 | Train Loss: 0.99042 | Valid Loss: 0.74474 | Train Accs: 0.61032 | Valid Accs: 0.70115 | Time: 16.24 seconds
# Epoch: 6 | Train Loss: 0.93326 | Valid Loss: 0.67002 | Train Accs: 0.63543 | Valid Accs: 0.74169 | Time: 15.49 seconds
# Epoch: 7 | Train Loss: 0.88199 | Valid Loss: 0.81876 | Train Accs: 0.65910 | Valid Accs: 0.69146 | Time: 16.16 seconds
# Epoch: 8 | Train Loss: 0.85481 | Valid Loss: 0.67061 | Train Accs: 0.66344 | Valid Accs: 0.74565 | Time: 15.69 seconds
# Epoch: 9 | Train Loss: 0.82018 | Valid Loss: 0.59970 | Train Accs: 0.68246 | Valid Accs: 0.77373 | Time: 16.09 seconds
# Epoch: 10 | Train Loss: 0.81082 | Valid Loss: 0.68115 | Train Accs: 0.68730 | Valid Accs: 0.74031 | Time: 15.63 seconds
# Epoch: 11 | Train Loss: 0.78193 | Valid Loss: 0.54337 | Train Accs: 0.70093 | Valid Accs: 0.79826 | Time: 16.28 seconds
# Epoch: 12 | Train Loss: 0.75137 | Valid Loss: 0.54825 | Train Accs: 0.71246 | Valid Accs: 0.80024 | Time: 15.56 seconds
# Epoch: 13 | Train Loss: 0.73776 | Valid Loss: 0.61451 | Train Accs: 0.71815 | Valid Accs: 0.77413 | Time: 16.19 seconds
# Epoch: 14 | Train Loss: 0.72415 | Valid Loss: 0.60358 | Train Accs: 0.72674 | Valid Accs: 0.77907 | Time: 15.93 seconds
# Epoch: 15 | Train Loss: 0.70054 | Valid Loss: 0.47426 | Train Accs: 0.73837 | Valid Accs: 0.82832 | Time: 16.43 seconds
# Epoch: 16 | Train Loss: 0.67528 | Valid Loss: 0.45390 | Train Accs: 0.74511 | Valid Accs: 0.83584 | Time: 16.12 seconds
# Epoch: 17 | Train Loss: 0.65626 | Valid Loss: 0.45907 | Train Accs: 0.75285 | Valid Accs: 0.83267 | Time: 15.83 seconds
# Epoch: 18 | Train Loss: 0.64515 | Valid Loss: 0.49096 | Train Accs: 0.76053 | Valid Accs: 0.82318 | Time: 16.04 seconds
# Epoch: 19 | Train Loss: 0.62235 | Valid Loss: 0.44621 | Train Accs: 0.77142 | Valid Accs: 0.83900 | Time: 15.88 seconds
# Epoch: 20 | Train Loss: 0.61001 | Valid Loss: 0.44665 | Train Accs: 0.77431 | Valid Accs: 0.83782 | Time: 16.10 seconds
# Epoch: 21 | Train Loss: 0.58678 | Valid Loss: 0.43254 | Train Accs: 0.78340 | Valid Accs: 0.83999 | Time: 15.79 seconds
# Epoch: 22 | Train Loss: 0.57673 | Valid Loss: 0.42317 | Train Accs: 0.78774 | Valid Accs: 0.84731 | Time: 15.80 seconds
# Epoch: 23 | Train Loss: 0.56817 | Valid Loss: 0.42513 | Train Accs: 0.79063 | Valid Accs: 0.84256 | Time: 15.52 seconds
# Epoch: 24 | Train Loss: 0.55980 | Valid Loss: 0.41052 | Train Accs: 0.79458 | Valid Accs: 0.84949 | Time: 16.02 seconds
# Epoch: 25 | Train Loss: 0.56335 | Valid Loss: 0.41428 | Train Accs: 0.79183 | Valid Accs: 0.84988 | Time: 15.98 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 25
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.64 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************

# %% [markdown]
# ### **Best Model**

# %%
BL = np.inf
for i in range(len(BLs)):
    if BLs[i]["valid"] < BL:
        BL = BLs[i]["valid"]
        best_loss_index = i

        
BA = 0.0
for i in range(len(BAs)):
    if BAs[i]["valid"] > BA:
        BA = BAs[i]["valid"]
        best_accs_index = i

breaker()
print(f"Best Loss Model Fold     : {best_loss_index + 1}")
print(f"Best Accuracy Model Fold : {best_accs_index + 1}")
breaker()
# Out:
# **************************************************
#
# Best Loss Model Fold     : 3
# Best Accuracy Model Fold : 3
#
# **************************************************
