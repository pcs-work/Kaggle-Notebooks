# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from scipy import stats
from typing import Union
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import models, transforms

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Helpers**

# %%
SEED: int = 42

def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def get_image(path: str, size: int=224) -> np.ndarray:
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
    return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_AREA)


def show_loss_graphs(L: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()

    
def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(A)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()
    

def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 ):
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.train_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49217, 0.47873, 0.44228], [0.24861, 0.24540, 0.26107]),
            transforms.RandomAffine(degrees=(-45, 45), translate=(0.15, 0.15), scale=(0.5, 1.5)),
            transforms.RandomHorizontalFlip(p=0.25),
            transforms.RandomVerticalFlip(p=0.25),
        ])
        self.valid_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.49217, 0.47873, 0.44228], [0.24861, 0.24540, 0.26107]),
        ]) 
                                
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
    
cfg = CFG(
    seed=SEED, 
)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(
        self, 
        images: np.ndarray,
        labels: Union[np.ndarray, None]=None, 
        transform=None
    ):
        
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is None:
            return self.transform(self.images[idx])
        return self.transform(self.images[idx]), torch.LongTensor(self.labels[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, filter_sizes: list=[64, 128, 256, 512], HLs: list=[], DP: float=None):

        super(Model, self).__init__()

        self.encoder = nn.Sequential()
        self.encoder.add_module("CN1", nn.Conv2d(in_channels=3, out_channels=filter_sizes[0], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN1", nn.BatchNorm2d(num_features=filter_sizes[0], eps=1e-5))
        self.encoder.add_module("AN1", nn.ReLU())
        self.encoder.add_module("MP1", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN2", nn.Conv2d(in_channels=filter_sizes[0], out_channels=filter_sizes[1], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN2", nn.BatchNorm2d(num_features=filter_sizes[1], eps=1e-5))
        self.encoder.add_module("AN2", nn.ReLU())
        self.encoder.add_module("MP2", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN3", nn.Conv2d(in_channels=filter_sizes[1], out_channels=filter_sizes[2], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN3", nn.BatchNorm2d(num_features=filter_sizes[2], eps=1e-5))
        self.encoder.add_module("AN3", nn.ReLU())
        self.encoder.add_module("MP3", nn.MaxPool2d(kernel_size=(2, 2)))
        self.encoder.add_module("CN4", nn.Conv2d(in_channels=filter_sizes[2], out_channels=filter_sizes[3], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.encoder.add_module("BN4", nn.BatchNorm2d(num_features=filter_sizes[3], eps=1e-5))
        self.encoder.add_module("AN4", nn.ReLU())
        self.encoder.add_module("MP4", nn.MaxPool2d(kernel_size=(2, 2)))

        self.classifier = nn.Sequential()
        if len(HLs) == 0:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=5))
        elif len(HLs) == 1:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=5))
        elif len(HLs) == 2:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*2*2, out_features=HLs[0]))
            self.classifier.add_module("AN1", nn.ReLU())
            if DP:
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("FC2", nn.Linear(in_features=HLs[0], out_features=HLs[1]))
            self.classifier.add_module("AN2", nn.ReLU())
            if DP:
                self.classifier.add_module("DP2", nn.Dropout(p=DP))
            self.classifier.add_module("FC3", nn.Linear(in_features=HLs[1], out_features=5))
    
    def forward(self, x):
        x = self.encoder(x)
        x = x.view(x.shape[0], -1)
        return nn.LogSoftmax(dim=1)(self.classifier(x))

# %% [markdown]
# ### **Fit and Predict**

# %%
def fit(
    model=None,
    optimizer=None, 
    scheduler_rlrop=None,
    scheduler_oclr=None,
    epochs=None, 
    early_stopping_patience=None, 
    dataloaders=None, 
    fold=None, 
    save_path=None,
    device=None,
    verbose=False
) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss: dict = {"train" : np.inf, "valid" : np.inf} 
    bestAccs: dict = {"train" : 0.0, "valid" : 0.0}
        
    Losses: list = []
    Accuracies: list = [] 
    LRs: list = []
        
    if fold: 
        ble_name = f"ble_state_fold_{fold}.pt"
        bae_name = f"bae_state_fold_{fold}.pt"
    else: 
        ble_name = f"ble_state.pt"
        bae_name = f"bae_state.pt"
    
    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss: dict = {"train" : 0.0, "valid" : 0.0} 
        epochAccs: dict = {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass: list = []
            accsPerPass: list = []
                
            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
    
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, ble_name))
                torch.save(save_dict, os.path.join(save_path, bae_name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, ble_name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
            torch.save(save_dict,os.path.join(save_path, bae_name))
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
 Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                        epochLoss["train"], epochLoss["valid"], 
                                                                        epochAccs["train"], epochAccs["valid"], 
                                                                        time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, bestLoss, bestAccs, BLE, BAE, ble_name, bae_name


def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.argmax(torch.exp(model(X)), dim=1)
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
images = np.load("../input/icc-ml-2022a/DATA/TaskB/train_images_B.npy")
labels = np.load("../input/icc-ml-2022a/DATA/TaskB/train_labels_B.npy")

# %%
fold: int = 1
BLs: list = []
BAs: list = []

# # Test 
# cfg.epochs = 2
# cfg.n_splits = 3

cfg.batch_size = 64
    
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(images, labels):

    tr_images, va_images = images[tr_idx], images[va_idx] 
    tr_labels, va_labels = labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(
        images=tr_images, 
        labels=tr_labels.reshape(-1, 1),
        transform=cfg.train_transform
    )
    
    va_data_setup = DS(
        images=va_images, 
        labels=va_labels.reshape(-1, 1),
        transform=cfg.valid_transform
    )

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
        "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
    }

    cfg.steps_per_epoch = len(dataloaders["train"])
    
    torch.manual_seed(cfg.seed)
    model = Model(filter_sizes=[64, 128, 256, 512]).to(cfg.device)

    optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.AdamW([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.SGD([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd, momentum=0.9)
    
    scheduler_oclr = optim.lr_scheduler.OneCycleLR(
        optimizer=optimizer, 
        max_lr=cfg.max_lr, 
        epochs=cfg.epochs, 
        steps_per_epoch=cfg.steps_per_epoch,
        pct_start=cfg.pct_start, 
        div_factor=cfg.div_factor, 
        final_div_factor=cfg.final_div_factor
    )

    # scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(
    #     optimizer=optimizer,
    #     patience=cfg.patience,
    #     eps=cfg.eps,
    #     verbose=True
    # )

    # scheduler_oclr = None
    scheduler_rlrop = None
    
    L, A, LR, BL, BA, _, _, _, _ = fit(
        model=model, 
        optimizer=optimizer, 
        scheduler_oclr=scheduler_oclr,
        scheduler_rlrop=scheduler_rlrop,
        epochs=cfg.epochs, 
        early_stopping_patience=cfg.early_stopping, 
        dataloaders=dataloaders, 
        device=cfg.device,
        save_path=cfg.save_path,
        fold=fold,
        verbose=True
    )
    
    breaker()
    show_loss_graphs(L)
    breaker()
    show_accuracy_graphs(A)
    breaker()
    if scheduler_oclr:
        show_lr_graph(LR)
        breaker()
    
    BLs.append(BL)
    BAs.append(BA)
    
    fold += 1
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.33063 | Valid Loss: 0.86031 | Train Accs: 0.44529 | Valid Accs: 0.68928 | Time: 22.08 seconds
# Epoch: 2 | Train Loss: 1.06729 | Valid Loss: 0.88497 | Train Accs: 0.58751 | Valid Accs: 0.68275 | Time: 16.06 seconds
# Epoch: 3 | Train Loss: 1.00095 | Valid Loss: 0.87548 | Train Accs: 0.62176 | Valid Accs: 0.67900 | Time: 15.95 seconds
# Epoch: 4 | Train Loss: 0.97079 | Valid Loss: 0.70885 | Train Accs: 0.63898 | Valid Accs: 0.75415 | Time: 15.76 seconds
# Epoch: 5 | Train Loss: 0.89784 | Valid Loss: 0.75709 | Train Accs: 0.66638 | Valid Accs: 0.72389 | Time: 15.62 seconds
# Epoch: 6 | Train Loss: 0.84154 | Valid Loss: 0.78063 | Train Accs: 0.69539 | Valid Accs: 0.71499 | Time: 15.62 seconds
# Epoch: 7 | Train Loss: 0.81461 | Valid Loss: 0.70517 | Train Accs: 0.70288 | Valid Accs: 0.76206 | Time: 15.78 seconds
# Epoch: 8 | Train Loss: 0.77431 | Valid Loss: 0.61081 | Train Accs: 0.71805 | Valid Accs: 0.77749 | Time: 15.94 seconds
# Epoch: 9 | Train Loss: 0.74870 | Valid Loss: 0.61805 | Train Accs: 0.73398 | Valid Accs: 0.77690 | Time: 15.49 seconds
# Epoch: 10 | Train Loss: 0.71595 | Valid Loss: 0.50295 | Train Accs: 0.74081 | Valid Accs: 0.83208 | Time: 16.37 seconds
# Epoch: 11 | Train Loss: 0.69884 | Valid Loss: 0.54481 | Train Accs: 0.75250 | Valid Accs: 0.81408 | Time: 15.46 seconds
# Epoch: 12 | Train Loss: 0.68281 | Valid Loss: 0.62776 | Train Accs: 0.75814 | Valid Accs: 0.78323 | Time: 16.38 seconds
# Epoch: 13 | Train Loss: 0.66799 | Valid Loss: 0.59492 | Train Accs: 0.76373 | Valid Accs: 0.79411 | Time: 15.20 seconds
# Epoch: 14 | Train Loss: 0.64342 | Valid Loss: 0.51045 | Train Accs: 0.77381 | Valid Accs: 0.82911 | Time: 16.48 seconds
# Epoch: 15 | Train Loss: 0.62032 | Valid Loss: 0.58933 | Train Accs: 0.78290 | Valid Accs: 0.80538 | Time: 15.55 seconds
# Epoch: 16 | Train Loss: 0.60347 | Valid Loss: 0.43278 | Train Accs: 0.78799 | Valid Accs: 0.85819 | Time: 16.35 seconds
# Epoch: 17 | Train Loss: 0.57846 | Valid Loss: 0.47264 | Train Accs: 0.79727 | Valid Accs: 0.84494 | Time: 15.28 seconds
# Epoch: 18 | Train Loss: 0.57045 | Valid Loss: 0.47798 | Train Accs: 0.80187 | Valid Accs: 0.84474 | Time: 16.19 seconds
# Epoch: 19 | Train Loss: 0.54685 | Valid Loss: 0.44581 | Train Accs: 0.81325 | Valid Accs: 0.85403 | Time: 15.54 seconds
# Epoch: 20 | Train Loss: 0.53771 | Valid Loss: 0.42046 | Train Accs: 0.81699 | Valid Accs: 0.85918 | Time: 16.27 seconds
# Epoch: 21 | Train Loss: 0.51260 | Valid Loss: 0.42908 | Train Accs: 0.82248 | Valid Accs: 0.85878 | Time: 15.72 seconds
# Epoch: 22 | Train Loss: 0.50821 | Valid Loss: 0.40155 | Train Accs: 0.82618 | Valid Accs: 0.86926 | Time: 16.00 seconds
# Epoch: 23 | Train Loss: 0.50230 | Valid Loss: 0.40462 | Train Accs: 0.82917 | Valid Accs: 0.86590 | Time: 15.63 seconds
# Epoch: 24 | Train Loss: 0.48983 | Valid Loss: 0.39361 | Train Accs: 0.83491 | Valid Accs: 0.87263 | Time: 16.50 seconds
# Epoch: 25 | Train Loss: 0.49222 | Valid Loss: 0.39739 | Train Accs: 0.83187 | Valid Accs: 0.86986 | Time: 16.01 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.72 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.31962 | Valid Loss: 0.96807 | Train Accs: 0.45168 | Valid Accs: 0.64498 | Time: 15.69 seconds
# Epoch: 2 | Train Loss: 1.06357 | Valid Loss: 0.80362 | Train Accs: 0.58926 | Valid Accs: 0.70352 | Time: 16.14 seconds
# Epoch: 3 | Train Loss: 1.00297 | Valid Loss: 0.85628 | Train Accs: 0.62026 | Valid Accs: 0.67959 | Time: 15.50 seconds
# Epoch: 4 | Train Loss: 0.94929 | Valid Loss: 0.86918 | Train Accs: 0.64392 | Valid Accs: 0.67840 | Time: 16.23 seconds
# Epoch: 5 | Train Loss: 0.90028 | Valid Loss: 0.79004 | Train Accs: 0.67008 | Valid Accs: 0.71578 | Time: 16.28 seconds
# Epoch: 6 | Train Loss: 0.85958 | Valid Loss: 0.67216 | Train Accs: 0.68416 | Valid Accs: 0.76760 | Time: 16.36 seconds
# Epoch: 7 | Train Loss: 0.80473 | Valid Loss: 0.70667 | Train Accs: 0.70657 | Valid Accs: 0.76464 | Time: 15.67 seconds
# Epoch: 8 | Train Loss: 0.77086 | Valid Loss: 0.67449 | Train Accs: 0.72369 | Valid Accs: 0.76523 | Time: 15.79 seconds
# Epoch: 9 | Train Loss: 0.73355 | Valid Loss: 0.56443 | Train Accs: 0.73852 | Valid Accs: 0.81072 | Time: 15.80 seconds
# Epoch: 10 | Train Loss: 0.72241 | Valid Loss: 0.70356 | Train Accs: 0.74191 | Valid Accs: 0.74802 | Time: 15.73 seconds
# Epoch: 11 | Train Loss: 0.69998 | Valid Loss: 0.56397 | Train Accs: 0.75245 | Valid Accs: 0.80518 | Time: 15.67 seconds
# Epoch: 12 | Train Loss: 0.67616 | Valid Loss: 0.55498 | Train Accs: 0.75754 | Valid Accs: 0.80993 | Time: 15.80 seconds
# Epoch: 13 | Train Loss: 0.65627 | Valid Loss: 0.62009 | Train Accs: 0.76897 | Valid Accs: 0.78817 | Time: 15.14 seconds
# Epoch: 14 | Train Loss: 0.63629 | Valid Loss: 0.50252 | Train Accs: 0.77676 | Valid Accs: 0.82476 | Time: 15.78 seconds
# Epoch: 15 | Train Loss: 0.62270 | Valid Loss: 0.52106 | Train Accs: 0.78010 | Valid Accs: 0.82733 | Time: 15.24 seconds
# Epoch: 16 | Train Loss: 0.59785 | Valid Loss: 0.46405 | Train Accs: 0.78979 | Valid Accs: 0.84316 | Time: 16.18 seconds
# Epoch: 17 | Train Loss: 0.58976 | Valid Loss: 0.56768 | Train Accs: 0.79717 | Valid Accs: 0.81112 | Time: 15.02 seconds
# Epoch: 18 | Train Loss: 0.56671 | Valid Loss: 0.46606 | Train Accs: 0.80072 | Valid Accs: 0.84434 | Time: 15.78 seconds
# Epoch: 19 | Train Loss: 0.54516 | Valid Loss: 0.43168 | Train Accs: 0.81205 | Valid Accs: 0.86234 | Time: 15.21 seconds
# Epoch: 20 | Train Loss: 0.52674 | Valid Loss: 0.43224 | Train Accs: 0.81674 | Valid Accs: 0.85641 | Time: 15.28 seconds
# Epoch: 21 | Train Loss: 0.51521 | Valid Loss: 0.42366 | Train Accs: 0.82333 | Valid Accs: 0.86432 | Time: 15.47 seconds
# Epoch: 22 | Train Loss: 0.50576 | Valid Loss: 0.41855 | Train Accs: 0.83042 | Valid Accs: 0.86452 | Time: 15.16 seconds
# Epoch: 23 | Train Loss: 0.48989 | Valid Loss: 0.40313 | Train Accs: 0.83297 | Valid Accs: 0.87559 | Time: 15.84 seconds
# Epoch: 24 | Train Loss: 0.48884 | Valid Loss: 0.40967 | Train Accs: 0.83626 | Valid Accs: 0.87065 | Time: 15.46 seconds
# Epoch: 25 | Train Loss: 0.48323 | Valid Loss: 0.41003 | Train Accs: 0.83831 | Valid Accs: 0.86966 | Time: 15.08 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.52 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.32094 | Valid Loss: 0.89138 | Train Accs: 0.45298 | Valid Accs: 0.68038 | Time: 15.33 seconds
# Epoch: 2 | Train Loss: 1.07518 | Valid Loss: 0.80163 | Train Accs: 0.58766 | Valid Accs: 0.70847 | Time: 15.59 seconds
# Epoch: 3 | Train Loss: 1.01756 | Valid Loss: 0.84672 | Train Accs: 0.61452 | Valid Accs: 0.71183 | Time: 15.48 seconds
# Epoch: 4 | Train Loss: 0.95054 | Valid Loss: 0.68879 | Train Accs: 0.64652 | Valid Accs: 0.75138 | Time: 15.40 seconds
# Epoch: 5 | Train Loss: 0.90936 | Valid Loss: 0.64789 | Train Accs: 0.66224 | Valid Accs: 0.77611 | Time: 15.13 seconds
# Epoch: 6 | Train Loss: 0.85394 | Valid Loss: 0.70233 | Train Accs: 0.68700 | Valid Accs: 0.75316 | Time: 15.73 seconds
# Epoch: 7 | Train Loss: 0.81387 | Valid Loss: 1.00393 | Train Accs: 0.70437 | Valid Accs: 0.64873 | Time: 14.96 seconds
# Epoch: 8 | Train Loss: 0.77078 | Valid Loss: 0.85408 | Train Accs: 0.72279 | Valid Accs: 0.69343 | Time: 15.35 seconds
# Epoch: 9 | Train Loss: 0.75742 | Valid Loss: 0.66174 | Train Accs: 0.72669 | Valid Accs: 0.78066 | Time: 15.02 seconds
# Epoch: 10 | Train Loss: 0.72366 | Valid Loss: 0.57707 | Train Accs: 0.73837 | Valid Accs: 0.79589 | Time: 15.74 seconds
# Epoch: 11 | Train Loss: 0.70183 | Valid Loss: 0.54023 | Train Accs: 0.75160 | Valid Accs: 0.81626 | Time: 15.43 seconds
# Epoch: 12 | Train Loss: 0.68400 | Valid Loss: 0.49729 | Train Accs: 0.75854 | Valid Accs: 0.83287 | Time: 15.47 seconds
# Epoch: 13 | Train Loss: 0.66891 | Valid Loss: 0.53692 | Train Accs: 0.76343 | Valid Accs: 0.82259 | Time: 15.49 seconds
# Epoch: 14 | Train Loss: 0.64664 | Valid Loss: 0.45397 | Train Accs: 0.77177 | Valid Accs: 0.85107 | Time: 15.65 seconds
# Epoch: 15 | Train Loss: 0.62674 | Valid Loss: 0.46258 | Train Accs: 0.77865 | Valid Accs: 0.84335 | Time: 15.23 seconds
# Epoch: 16 | Train Loss: 0.59731 | Valid Loss: 0.45769 | Train Accs: 0.79178 | Valid Accs: 0.84810 | Time: 15.86 seconds
# Epoch: 17 | Train Loss: 0.59091 | Valid Loss: 0.42258 | Train Accs: 0.79293 | Valid Accs: 0.86412 | Time: 15.44 seconds
# Epoch: 18 | Train Loss: 0.56949 | Valid Loss: 0.43725 | Train Accs: 0.80277 | Valid Accs: 0.85186 | Time: 15.84 seconds
# Epoch: 19 | Train Loss: 0.55220 | Valid Loss: 0.43975 | Train Accs: 0.80866 | Valid Accs: 0.85720 | Time: 15.16 seconds
# Epoch: 20 | Train Loss: 0.53802 | Valid Loss: 0.41434 | Train Accs: 0.81445 | Valid Accs: 0.86511 | Time: 15.30 seconds
# Epoch: 21 | Train Loss: 0.51609 | Valid Loss: 0.40532 | Train Accs: 0.82283 | Valid Accs: 0.86808 | Time: 15.79 seconds
# Epoch: 22 | Train Loss: 0.50688 | Valid Loss: 0.39265 | Train Accs: 0.82718 | Valid Accs: 0.87203 | Time: 15.76 seconds
# Epoch: 23 | Train Loss: 0.49509 | Valid Loss: 0.40263 | Train Accs: 0.83432 | Valid Accs: 0.86946 | Time: 15.27 seconds
# Epoch: 24 | Train Loss: 0.49487 | Valid Loss: 0.39437 | Train Accs: 0.83182 | Valid Accs: 0.87520 | Time: 15.16 seconds
# Epoch: 25 | Train Loss: 0.48737 | Valid Loss: 0.39267 | Train Accs: 0.83646 | Valid Accs: 0.87460 | Time: 15.07 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 22
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.43 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 4...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.33264 | Valid Loss: 0.90246 | Train Accs: 0.44429 | Valid Accs: 0.66772 | Time: 15.66 seconds
# Epoch: 2 | Train Loss: 1.07767 | Valid Loss: 0.95829 | Train Accs: 0.57817 | Valid Accs: 0.64458 | Time: 14.92 seconds
# Epoch: 3 | Train Loss: 1.00566 | Valid Loss: 0.77790 | Train Accs: 0.61861 | Valid Accs: 0.72172 | Time: 15.52 seconds
# Epoch: 4 | Train Loss: 0.95598 | Valid Loss: 0.69022 | Train Accs: 0.64307 | Valid Accs: 0.75910 | Time: 15.21 seconds
# Epoch: 5 | Train Loss: 0.90022 | Valid Loss: 0.72140 | Train Accs: 0.67138 | Valid Accs: 0.74644 | Time: 14.85 seconds
# Epoch: 6 | Train Loss: 0.85346 | Valid Loss: 0.66261 | Train Accs: 0.68755 | Valid Accs: 0.77215 | Time: 15.24 seconds
# Epoch: 7 | Train Loss: 0.79949 | Valid Loss: 0.58003 | Train Accs: 0.70996 | Valid Accs: 0.80973 | Time: 15.16 seconds
# Epoch: 8 | Train Loss: 0.78665 | Valid Loss: 0.73697 | Train Accs: 0.71116 | Valid Accs: 0.75534 | Time: 15.41 seconds
# Epoch: 9 | Train Loss: 0.74845 | Valid Loss: 0.61530 | Train Accs: 0.73213 | Valid Accs: 0.78204 | Time: 15.78 seconds
# Epoch: 10 | Train Loss: 0.72522 | Valid Loss: 0.54313 | Train Accs: 0.74012 | Valid Accs: 0.81626 | Time: 15.13 seconds
# Epoch: 11 | Train Loss: 0.70437 | Valid Loss: 0.61451 | Train Accs: 0.74910 | Valid Accs: 0.79193 | Time: 15.66 seconds
# Epoch: 12 | Train Loss: 0.67901 | Valid Loss: 0.50270 | Train Accs: 0.75963 | Valid Accs: 0.83742 | Time: 15.69 seconds
# Epoch: 13 | Train Loss: 0.66163 | Valid Loss: 0.53863 | Train Accs: 0.76722 | Valid Accs: 0.82021 | Time: 15.59 seconds
# Epoch: 14 | Train Loss: 0.64156 | Valid Loss: 0.56259 | Train Accs: 0.77471 | Valid Accs: 0.80538 | Time: 14.96 seconds
# Epoch: 15 | Train Loss: 0.62636 | Valid Loss: 0.55030 | Train Accs: 0.77955 | Valid Accs: 0.80538 | Time: 14.87 seconds
# Epoch: 16 | Train Loss: 0.60503 | Valid Loss: 0.54270 | Train Accs: 0.78779 | Valid Accs: 0.82219 | Time: 15.12 seconds
# Epoch: 17 | Train Loss: 0.58369 | Valid Loss: 0.50850 | Train Accs: 0.79668 | Valid Accs: 0.83287 | Time: 14.95 seconds
# Epoch: 18 | Train Loss: 0.56543 | Valid Loss: 0.46010 | Train Accs: 0.80396 | Valid Accs: 0.84751 | Time: 14.70 seconds
# Epoch: 19 | Train Loss: 0.55374 | Valid Loss: 0.43420 | Train Accs: 0.80746 | Valid Accs: 0.86116 | Time: 14.72 seconds
# Epoch: 20 | Train Loss: 0.52646 | Valid Loss: 0.44181 | Train Accs: 0.82054 | Valid Accs: 0.85799 | Time: 15.02 seconds
# Epoch: 21 | Train Loss: 0.52246 | Valid Loss: 0.44999 | Train Accs: 0.82233 | Valid Accs: 0.85621 | Time: 14.45 seconds
# Epoch: 22 | Train Loss: 0.50648 | Valid Loss: 0.40620 | Train Accs: 0.83007 | Valid Accs: 0.87480 | Time: 15.38 seconds
# Epoch: 23 | Train Loss: 0.49589 | Valid Loss: 0.39915 | Train Accs: 0.83117 | Valid Accs: 0.87540 | Time: 14.72 seconds
# Epoch: 24 | Train Loss: 0.48706 | Valid Loss: 0.39522 | Train Accs: 0.83566 | Valid Accs: 0.87896 | Time: 15.70 seconds
# Epoch: 25 | Train Loss: 0.48859 | Valid Loss: 0.39563 | Train Accs: 0.83571 | Valid Accs: 0.87856 | Time: 14.51 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.32 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 5...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.32351 | Valid Loss: 0.91658 | Train Accs: 0.44679 | Valid Accs: 0.67069 | Time: 15.10 seconds
# Epoch: 2 | Train Loss: 1.07451 | Valid Loss: 0.93153 | Train Accs: 0.58217 | Valid Accs: 0.65823 | Time: 14.81 seconds
# Epoch: 3 | Train Loss: 0.98693 | Valid Loss: 0.75709 | Train Accs: 0.62425 | Valid Accs: 0.72271 | Time: 14.99 seconds
# Epoch: 4 | Train Loss: 0.93694 | Valid Loss: 0.66103 | Train Accs: 0.64766 | Valid Accs: 0.76543 | Time: 14.73 seconds
# Epoch: 5 | Train Loss: 0.90182 | Valid Loss: 0.69715 | Train Accs: 0.66758 | Valid Accs: 0.74743 | Time: 15.11 seconds
# Epoch: 6 | Train Loss: 0.84036 | Valid Loss: 0.85371 | Train Accs: 0.69079 | Valid Accs: 0.70372 | Time: 14.25 seconds
# Epoch: 7 | Train Loss: 0.81231 | Valid Loss: 0.64800 | Train Accs: 0.70233 | Valid Accs: 0.76859 | Time: 15.96 seconds
# Epoch: 8 | Train Loss: 0.77695 | Valid Loss: 0.64860 | Train Accs: 0.71935 | Valid Accs: 0.77611 | Time: 14.25 seconds
# Epoch: 9 | Train Loss: 0.74950 | Valid Loss: 0.64341 | Train Accs: 0.73418 | Valid Accs: 0.78540 | Time: 14.97 seconds
# Epoch: 10 | Train Loss: 0.72035 | Valid Loss: 0.59132 | Train Accs: 0.74576 | Valid Accs: 0.80044 | Time: 14.55 seconds
# Epoch: 11 | Train Loss: 0.70785 | Valid Loss: 0.51589 | Train Accs: 0.74760 | Valid Accs: 0.82278 | Time: 15.25 seconds
# Epoch: 12 | Train Loss: 0.68048 | Valid Loss: 0.51839 | Train Accs: 0.76318 | Valid Accs: 0.82002 | Time: 14.54 seconds
# Epoch: 13 | Train Loss: 0.66431 | Valid Loss: 0.53628 | Train Accs: 0.76538 | Valid Accs: 0.82437 | Time: 15.12 seconds
# Epoch: 14 | Train Loss: 0.64478 | Valid Loss: 0.48701 | Train Accs: 0.77401 | Valid Accs: 0.83999 | Time: 14.57 seconds
# Epoch: 15 | Train Loss: 0.62808 | Valid Loss: 0.48989 | Train Accs: 0.78050 | Valid Accs: 0.83940 | Time: 14.65 seconds
# Epoch: 16 | Train Loss: 0.60090 | Valid Loss: 0.45172 | Train Accs: 0.78789 | Valid Accs: 0.85680 | Time: 15.23 seconds
# Epoch: 17 | Train Loss: 0.58580 | Valid Loss: 0.43102 | Train Accs: 0.79288 | Valid Accs: 0.85898 | Time: 14.64 seconds
# Epoch: 18 | Train Loss: 0.56694 | Valid Loss: 0.46782 | Train Accs: 0.80356 | Valid Accs: 0.84494 | Time: 15.05 seconds
# Epoch: 19 | Train Loss: 0.55370 | Valid Loss: 0.42770 | Train Accs: 0.81440 | Valid Accs: 0.86313 | Time: 14.44 seconds
# Epoch: 20 | Train Loss: 0.52737 | Valid Loss: 0.41686 | Train Accs: 0.81954 | Valid Accs: 0.86254 | Time: 14.84 seconds
# Epoch: 21 | Train Loss: 0.51930 | Valid Loss: 0.41521 | Train Accs: 0.82618 | Valid Accs: 0.86472 | Time: 14.56 seconds
# Epoch: 22 | Train Loss: 0.50633 | Valid Loss: 0.40197 | Train Accs: 0.82763 | Valid Accs: 0.86986 | Time: 15.19 seconds
# Epoch: 23 | Train Loss: 0.49594 | Valid Loss: 0.40187 | Train Accs: 0.83192 | Valid Accs: 0.86966 | Time: 14.60 seconds
# Epoch: 24 | Train Loss: 0.49167 | Valid Loss: 0.39732 | Train Accs: 0.83362 | Valid Accs: 0.87104 | Time: 15.40 seconds
# Epoch: 25 | Train Loss: 0.49058 | Valid Loss: 0.39945 | Train Accs: 0.83661 | Valid Accs: 0.87065 | Time: 14.51 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 24
#
# **************************************************
#
# Time Taken [25 Epochs] : 6.19 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************

# %% [markdown]
# ### **Best Model**

# %%
BL = np.inf
for i in range(len(BLs)):
    if BLs[i]["valid"] < BL:
        BL = BLs[i]["valid"]
        best_loss_index = i

        
BA = 0.0
for i in range(len(BAs)):
    if BAs[i]["valid"] > BA:
        BA = BAs[i]["valid"]
        best_accs_index = i

breaker()
print(f"Best Loss Model Fold     : {best_loss_index + 1}")
print(f"Best Accuracy Model Fold : {best_accs_index + 1}")
breaker()
# Out:
# **************************************************
#
# Best Loss Model Fold     : 3
# Best Accuracy Model Fold : 4
#
# **************************************************
