# %% [markdown]
# ##### **Library Imports**

# %%
import os
import re
import cv2
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from typing import Union
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
SEED: int = 42
    

def breaker(num: int=50, char: str="*") -> None: print("\n" + num*char + "\n")
    

def get_image(path: str) -> np.ndarray:
    return cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    
def show_loss_graphs(L: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()
    

def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(A)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()
    

def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %%
class CFG(object):
    def __init__(
        self,
        seed: int = 42,
        n_splits: int = 5,
        batch_size: int = 16,
        epochs: int = 25,
        early_stopping: int = 5,
        lr: float = 1e-4,
        wd: float = 0.0,
        max_lr: float = 1e-3,
        pct_start: float = 0.2,
        steps_per_epoch: int = 100,
        div_factor: int = 1e3, 
        final_div_factor: float = 1e3,
        filter_sizes: list = [64, 128, 256, 512],
        HL: list = [1024]
     ):
        
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.filter_sizes = filter_sizes
        self.HL = HL
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.train_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.50699], [0.21214]),
            transforms.RandomAffine(degrees=(-45, 45), translate=(0.15, 0.15), scale=(0.5, 1.5)),
            transforms.RandomHorizontalFlip(p=0.25),
            transforms.RandomVerticalFlip(p=0.25),
        ])
        self.valid_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.50699], [0.21214]),
        ])
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)


cfg = CFG(
    seed=SEED, 
)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(
        self, 
        filepaths: np.ndarray, 
        labels: Union[np.ndarray, None]=None, 
        transform=None
    ):
        
        self.filepaths = filepaths
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.filepaths.shape[0]
    
    def __getitem__(self, idx):
        image = get_image(self.filepaths[idx])
        if self.labels is None:
            return self.transform(image)
        return self.transform(image), torch.LongTensor(self.labels[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, filter_sizes: list, HL: list, DP: Union[float, None]=None):
        
        super(Model, self).__init__()
        
        self.features = nn.Sequential()
        self.features.add_module("CN1", nn.Conv2d(in_channels=1, out_channels=filter_sizes[0], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.features.add_module("BN1", nn.BatchNorm2d(num_features=filter_sizes[0], eps=1e-5))
        self.features.add_module("AN1", nn.ReLU())
        self.features.add_module("MP1", nn.MaxPool2d(kernel_size=(2, 2)))
        self.features.add_module("CN2", nn.Conv2d(in_channels=filter_sizes[0], out_channels=filter_sizes[1], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.features.add_module("BN2", nn.BatchNorm2d(num_features=filter_sizes[1], eps=1e-5))
        self.features.add_module("AN2", nn.ReLU())
        self.features.add_module("MP2", nn.MaxPool2d(kernel_size=(2, 2)))
        self.features.add_module("CN3", nn.Conv2d(in_channels=filter_sizes[1], out_channels=filter_sizes[2], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.features.add_module("BN3", nn.BatchNorm2d(num_features=filter_sizes[2], eps=1e-5))
        self.features.add_module("AN3", nn.ReLU())
        self.features.add_module("MP3", nn.MaxPool2d(kernel_size=(2, 2))) 
        self.features.add_module("CN4", nn.Conv2d(in_channels=filter_sizes[2], out_channels=filter_sizes[3], kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.features.add_module("BN4", nn.BatchNorm2d(num_features=filter_sizes[3], eps=1e-5))
        self.features.add_module("AN4", nn.ReLU())
        self.features.add_module("MP4", nn.MaxPool2d(kernel_size=(2, 2))) 
         
        self.classifier = nn.Sequential()
        if len(HL) == 0:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*3*3, out_features=10))
        elif len(HL) == 1:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*3*3, out_features=HL[0]))
            if isinstance(DP, float):
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("AN1", nn.ReLU())
            self.classifier.add_module("FC2", nn.Linear(in_features=HL[0], out_features=10))
        elif len(HL) == 2:
            self.classifier.add_module("FC1", nn.Linear(in_features=filter_sizes[3]*3*3, out_features=HL[0]))
            if isinstance(DP, float):
                self.classifier.add_module("DP1", nn.Dropout(p=DP))
            self.classifier.add_module("AN1", nn.ReLU())
            self.classifier.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.classifier.add_module("DP2", nn.Dropout(p=DP))
            self.classifier.add_module("AN2", nn.ReLU())
            self.classifier.add_module("FC3", nn.Linear(in_features=HL[1], out_features=10))
        self.classifier.add_module("Final Activation", nn.LogSoftmax(dim=1))
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        return self.classifier(x)

# %% [markdown]
# ### **Fit and Predict**

# %%
def fit(
    model=None,
    optimizer=None, 
    scheduler_rlrop=None,
    scheduler_oclr=None,
    epochs=None, 
    early_stopping_patience=None, 
    dataloaders=None, 
    fold=None, 
    save_path=None,
    device=None,
    verbose=False
) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss: dict = {"train" : np.inf, "valid" : np.inf} 
    bestAccs: dict = {"train" : 0.0, "valid" : 0.0}
        
    Losses: list = []
    Accuracies: list = [] 
    LRs: list = []
        
    if fold: 
        ble_name = f"ble_state_fold_{fold}.pt"
        bae_name = f"bae_state_fold_{fold}.pt"
    else: 
        ble_name = f"ble_state.pt"
        bae_name = f"bae_state.pt"
        
    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss: dict = {"train" : 0.0, "valid" : 0.0} 
        epochAccs: dict = {"train" : 0.0, "valid" : 0.0}
            
        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass: list = []
            accsPerPass: list = []
                
            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)
                
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, ble_name))
                torch.save(save_dict, os.path.join(save_path, bae_name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, ble_name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
            torch.save(save_dict,os.path.join(save_path, bae_name))
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
 Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(
                e+1, 
                epochLoss["train"], epochLoss["valid"], 
                epochAccs["train"], epochAccs["valid"], 
                time()-e_st)
            )
        
    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, bestLoss, bestAccs, BLE, BAE, ble_name, bae_name


# def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
#     model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
#     model.to(device)    
#     model.eval()
    
#     y_pred = torch.zeros(1, 1).to(device)
    
#     for X in dataloader:
#         X = X.to(device)
#         with torch.no_grad():
#             output = torch.argmax(torch.exp(model(X)), dim=1)
#         y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
#     return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
df = pd.read_csv("/kaggle/input/fee-dataframe/train.csv")

filepaths = df.filepaths.copy().values
labels = df.labels.copy().values

# %%
fold: int = 1
BLs: list = []
BAs: list = []
    
cfg.batch_size = 64
cfg.epochs = 25
    
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(filepaths, labels):

    tr_filepaths, va_filepaths = filepaths[tr_idx], filepaths[va_idx] 
    tr_labels, va_labels       = labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(
        filepaths=tr_filepaths, 
        labels=tr_labels.reshape(-1, 1),
        transform=cfg.train_transform
    )

    va_data_setup = DS(
        filepaths=va_filepaths, 
        labels=va_labels.reshape(-1, 1),
        transform=cfg.valid_transform
    )

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
        "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
    }

    cfg.steps_per_epoch=len(dataloaders["train"])
    
    torch.manual_seed(cfg.seed)
    model = Model(filter_sizes=cfg.filter_sizes, HL=cfg.HL).to(cfg.device)

    optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.AdamW([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
    # optimizer = optim.SGD([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd, momentum=0.9)

    scheduler_oclr = optim.lr_scheduler.OneCycleLR(
        optimizer=optimizer, 
        max_lr=cfg.max_lr, 
        epochs=cfg.epochs, 
        steps_per_epoch=cfg.steps_per_epoch,
        pct_start=cfg.pct_start, 
        div_factor=cfg.div_factor, 
        final_div_factor=cfg.final_div_factor
    )
    
    # scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(
    #     optimizer=optimizer,
    #     patience=cfg.patience,
    #     eps=cfg.eps,
    #     verbose=True
    # )

    # scheduler_oclr = None
    scheduler_rlrop = None
    
    L, A, LR, BL, BA, _, _, _, _ = fit(
        model=model, 
        optimizer=optimizer, 
        scheduler_oclr=scheduler_oclr,
        scheduler_rlrop=scheduler_rlrop,
        epochs=cfg.epochs, 
        early_stopping_patience=cfg.early_stopping, 
        dataloaders=dataloaders, 
        device=cfg.device,
        save_path=cfg.save_path,
        fold=fold,
        verbose=True
    )


    breaker()
    show_loss_graphs(L)
    breaker()
    show_accuracy_graphs(A)
    breaker()
    if scheduler_oclr:
        show_lr_graph(LR)
        breaker()
    
    BLs.append(BL)
    BAs.append(BA)

    fold += 1
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.86065 | Valid Loss: 1.76057 | Train Accs: 0.23801 | Valid Accs: 0.26277 | Time: 218.64 seconds
# Epoch: 2 | Train Loss: 1.79636 | Valid Loss: 1.74012 | Train Accs: 0.25571 | Valid Accs: 0.29025 | Time: 63.43 seconds
# Epoch: 3 | Train Loss: 1.74289 | Valid Loss: 1.68867 | Train Accs: 0.28670 | Valid Accs: 0.32991 | Time: 64.78 seconds
# Epoch: 4 | Train Loss: 1.70647 | Valid Loss: 1.58159 | Train Accs: 0.30605 | Valid Accs: 0.38458 | Time: 63.44 seconds
# Epoch: 5 | Train Loss: 1.65597 | Valid Loss: 1.68428 | Train Accs: 0.33605 | Valid Accs: 0.35100 | Time: 60.10 seconds
# Epoch: 6 | Train Loss: 1.60932 | Valid Loss: 1.42890 | Train Accs: 0.35648 | Valid Accs: 0.43403 | Time: 60.40 seconds
# Epoch: 7 | Train Loss: 1.56356 | Valid Loss: 1.40979 | Train Accs: 0.38422 | Valid Accs: 0.46748 | Time: 59.68 seconds
# Epoch: 8 | Train Loss: 1.52564 | Valid Loss: 1.39314 | Train Accs: 0.39924 | Valid Accs: 0.48719 | Time: 61.64 seconds
# Epoch: 9 | Train Loss: 1.48912 | Valid Loss: 1.48364 | Train Accs: 0.41763 | Valid Accs: 0.45666 | Time: 60.91 seconds
# Epoch: 10 | Train Loss: 1.46282 | Valid Loss: 1.24746 | Train Accs: 0.42962 | Valid Accs: 0.52682 | Time: 61.18 seconds
# Epoch: 11 | Train Loss: 1.43907 | Valid Loss: 1.23766 | Train Accs: 0.43958 | Valid Accs: 0.52957 | Time: 61.54 seconds
# Epoch: 12 | Train Loss: 1.41109 | Valid Loss: 1.23387 | Train Accs: 0.44810 | Valid Accs: 0.52943 | Time: 61.22 seconds
# Epoch: 13 | Train Loss: 1.39341 | Valid Loss: 1.27479 | Train Accs: 0.45806 | Valid Accs: 0.51806 | Time: 62.61 seconds
# Epoch: 14 | Train Loss: 1.37037 | Valid Loss: 1.20156 | Train Accs: 0.46672 | Valid Accs: 0.53781 | Time: 60.35 seconds
# Epoch: 15 | Train Loss: 1.35015 | Valid Loss: 1.17346 | Train Accs: 0.47749 | Valid Accs: 0.55416 | Time: 59.22 seconds
# Epoch: 16 | Train Loss: 1.33397 | Valid Loss: 1.14087 | Train Accs: 0.48702 | Valid Accs: 0.56120 | Time: 59.99 seconds
# Epoch: 17 | Train Loss: 1.30899 | Valid Loss: 1.16360 | Train Accs: 0.49364 | Valid Accs: 0.55639 | Time: 58.78 seconds
# Epoch: 18 | Train Loss: 1.29217 | Valid Loss: 1.14538 | Train Accs: 0.50532 | Valid Accs: 0.56817 | Time: 57.87 seconds
# Epoch: 19 | Train Loss: 1.27685 | Valid Loss: 1.14783 | Train Accs: 0.50580 | Valid Accs: 0.56820 | Time: 58.57 seconds
# Epoch: 20 | Train Loss: 1.25538 | Valid Loss: 1.10889 | Train Accs: 0.51095 | Valid Accs: 0.57819 | Time: 57.69 seconds
# Epoch: 21 | Train Loss: 1.25188 | Valid Loss: 1.12417 | Train Accs: 0.51355 | Valid Accs: 0.57970 | Time: 58.48 seconds
# Epoch: 22 | Train Loss: 1.23625 | Valid Loss: 1.11162 | Train Accs: 0.52091 | Valid Accs: 0.58177 | Time: 57.41 seconds
# Epoch: 23 | Train Loss: 1.23120 | Valid Loss: 1.09951 | Train Accs: 0.52264 | Valid Accs: 0.58245 | Time: 58.34 seconds
# Epoch: 24 | Train Loss: 1.22722 | Valid Loss: 1.09839 | Train Accs: 0.52316 | Valid Accs: 0.58812 | Time: 64.01 seconds
# Epoch: 25 | Train Loss: 1.22451 | Valid Loss: 1.09410 | Train Accs: 0.52909 | Valid Accs: 0.58915 | Time: 64.47 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 25
#
# **************************************************
#
# Best Validation Accs at Epoch 25
#
# **************************************************
#
# Time Taken [25 Epochs] : 27.91 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.86023 | Valid Loss: 1.75867 | Train Accs: 0.23951 | Valid Accs: 0.27627 | Time: 59.85 seconds
# Epoch: 2 | Train Loss: 1.79966 | Valid Loss: 1.70377 | Train Accs: 0.25466 | Valid Accs: 0.30924 | Time: 58.61 seconds
# Epoch: 3 | Train Loss: 1.74721 | Valid Loss: 1.62202 | Train Accs: 0.28204 | Valid Accs: 0.36848 | Time: 57.91 seconds
# Epoch: 4 | Train Loss: 1.70373 | Valid Loss: 1.56255 | Train Accs: 0.30656 | Valid Accs: 0.38753 | Time: 61.17 seconds
# Epoch: 5 | Train Loss: 1.65765 | Valid Loss: 1.89635 | Train Accs: 0.33411 | Valid Accs: 0.29069 | Time: 58.90 seconds
# Epoch: 6 | Train Loss: 1.60732 | Valid Loss: 1.65052 | Train Accs: 0.36579 | Valid Accs: 0.39543 | Time: 58.53 seconds
# Epoch: 7 | Train Loss: 1.55993 | Valid Loss: 1.42418 | Train Accs: 0.38659 | Valid Accs: 0.44505 | Time: 58.56 seconds
# Epoch: 8 | Train Loss: 1.51998 | Valid Loss: 1.30299 | Train Accs: 0.40290 | Valid Accs: 0.49468 | Time: 58.99 seconds
# Epoch: 9 | Train Loss: 1.48400 | Valid Loss: 1.65934 | Train Accs: 0.42390 | Valid Accs: 0.38942 | Time: 59.20 seconds
# Epoch: 10 | Train Loss: 1.45740 | Valid Loss: 1.28088 | Train Accs: 0.43370 | Valid Accs: 0.51339 | Time: 59.33 seconds
# Epoch: 11 | Train Loss: 1.43180 | Valid Loss: 1.30048 | Train Accs: 0.44216 | Valid Accs: 0.50017 | Time: 58.66 seconds
# Epoch: 12 | Train Loss: 1.40794 | Valid Loss: 1.24276 | Train Accs: 0.45375 | Valid Accs: 0.52696 | Time: 58.96 seconds
# Epoch: 13 | Train Loss: 1.38530 | Valid Loss: 1.28534 | Train Accs: 0.46374 | Valid Accs: 0.51374 | Time: 57.07 seconds
# Epoch: 14 | Train Loss: 1.36592 | Valid Loss: 1.16988 | Train Accs: 0.46879 | Valid Accs: 0.55065 | Time: 58.81 seconds
# Epoch: 15 | Train Loss: 1.34732 | Valid Loss: 1.17117 | Train Accs: 0.47425 | Valid Accs: 0.54997 | Time: 60.00 seconds
# Epoch: 16 | Train Loss: 1.32684 | Valid Loss: 1.16169 | Train Accs: 0.48506 | Valid Accs: 0.54842 | Time: 59.50 seconds
# Epoch: 17 | Train Loss: 1.30668 | Valid Loss: 1.12311 | Train Accs: 0.49397 | Valid Accs: 0.57005 | Time: 58.95 seconds
# Epoch: 18 | Train Loss: 1.28599 | Valid Loss: 1.12744 | Train Accs: 0.50231 | Valid Accs: 0.56611 | Time: 57.42 seconds
# Epoch: 19 | Train Loss: 1.27290 | Valid Loss: 1.13329 | Train Accs: 0.50765 | Valid Accs: 0.57143 | Time: 57.05 seconds
# Epoch: 20 | Train Loss: 1.25775 | Valid Loss: 1.10554 | Train Accs: 0.51732 | Valid Accs: 0.57881 | Time: 59.42 seconds
# Epoch: 21 | Train Loss: 1.24307 | Valid Loss: 1.09821 | Train Accs: 0.52440 | Valid Accs: 0.57761 | Time: 58.38 seconds
# Epoch: 22 | Train Loss: 1.23288 | Valid Loss: 1.09287 | Train Accs: 0.52551 | Valid Accs: 0.57847 | Time: 57.59 seconds
# Epoch: 23 | Train Loss: 1.22929 | Valid Loss: 1.08417 | Train Accs: 0.52770 | Valid Accs: 0.58602 | Time: 57.16 seconds
# Epoch: 24 | Train Loss: 1.22288 | Valid Loss: 1.08736 | Train Accs: 0.52740 | Valid Accs: 0.58293 | Time: 57.58 seconds
# Epoch: 25 | Train Loss: 1.21970 | Valid Loss: 1.08583 | Train Accs: 0.52761 | Valid Accs: 0.58328 | Time: 58.14 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 24.43 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.85646 | Valid Loss: 1.74085 | Train Accs: 0.24110 | Valid Accs: 0.28537 | Time: 61.42 seconds
# Epoch: 2 | Train Loss: 1.79999 | Valid Loss: 1.72806 | Train Accs: 0.25548 | Valid Accs: 0.29791 | Time: 59.17 seconds
# Epoch: 3 | Train Loss: 1.75044 | Valid Loss: 1.85257 | Train Accs: 0.28137 | Valid Accs: 0.27198 | Time: 58.41 seconds
# Epoch: 4 | Train Loss: 1.70857 | Valid Loss: 1.71004 | Train Accs: 0.30363 | Valid Accs: 0.32332 | Time: 60.59 seconds
# Epoch: 5 | Train Loss: 1.66519 | Valid Loss: 1.78284 | Train Accs: 0.32943 | Valid Accs: 0.34049 | Time: 59.65 seconds
# Epoch: 6 | Train Loss: 1.61570 | Valid Loss: 1.48066 | Train Accs: 0.35431 | Valid Accs: 0.44128 | Time: 59.63 seconds
# Epoch: 7 | Train Loss: 1.57911 | Valid Loss: 1.37650 | Train Accs: 0.37708 | Valid Accs: 0.47407 | Time: 58.41 seconds
# Epoch: 8 | Train Loss: 1.53179 | Valid Loss: 1.42778 | Train Accs: 0.39643 | Valid Accs: 0.48163 | Time: 58.28 seconds
# Epoch: 9 | Train Loss: 1.49323 | Valid Loss: 1.32942 | Train Accs: 0.41801 | Valid Accs: 0.50086 | Time: 58.11 seconds
# Epoch: 10 | Train Loss: 1.46751 | Valid Loss: 1.30715 | Train Accs: 0.42838 | Valid Accs: 0.49639 | Time: 57.18 seconds
# Epoch: 11 | Train Loss: 1.43785 | Valid Loss: 1.23886 | Train Accs: 0.43958 | Valid Accs: 0.53314 | Time: 58.04 seconds
# Epoch: 12 | Train Loss: 1.41254 | Valid Loss: 1.22926 | Train Accs: 0.44787 | Valid Accs: 0.53571 | Time: 60.76 seconds
# Epoch: 13 | Train Loss: 1.39337 | Valid Loss: 1.23386 | Train Accs: 0.45779 | Valid Accs: 0.52473 | Time: 65.67 seconds
# Epoch: 14 | Train Loss: 1.37174 | Valid Loss: 1.24148 | Train Accs: 0.46935 | Valid Accs: 0.52078 | Time: 60.31 seconds
# Epoch: 15 | Train Loss: 1.34577 | Valid Loss: 1.19679 | Train Accs: 0.48119 | Valid Accs: 0.54808 | Time: 58.49 seconds
# Epoch: 16 | Train Loss: 1.32591 | Valid Loss: 1.13740 | Train Accs: 0.48568 | Valid Accs: 0.57452 | Time: 59.95 seconds
# Epoch: 17 | Train Loss: 1.31353 | Valid Loss: 1.11794 | Train Accs: 0.49122 | Valid Accs: 0.56902 | Time: 58.50 seconds
# Epoch: 18 | Train Loss: 1.28636 | Valid Loss: 1.10368 | Train Accs: 0.50063 | Valid Accs: 0.57057 | Time: 58.89 seconds
# Epoch: 19 | Train Loss: 1.27442 | Valid Loss: 1.09313 | Train Accs: 0.50480 | Valid Accs: 0.58723 | Time: 58.88 seconds
# Epoch: 20 | Train Loss: 1.26208 | Valid Loss: 1.08742 | Train Accs: 0.51331 | Valid Accs: 0.58225 | Time: 59.52 seconds
# Epoch: 21 | Train Loss: 1.24441 | Valid Loss: 1.07653 | Train Accs: 0.52229 | Valid Accs: 0.58929 | Time: 58.45 seconds
# Epoch: 22 | Train Loss: 1.23819 | Valid Loss: 1.06940 | Train Accs: 0.52039 | Valid Accs: 0.59667 | Time: 61.67 seconds
# Epoch: 23 | Train Loss: 1.23297 | Valid Loss: 1.06070 | Train Accs: 0.52171 | Valid Accs: 0.59478 | Time: 61.26 seconds
# Epoch: 24 | Train Loss: 1.22454 | Valid Loss: 1.06035 | Train Accs: 0.52669 | Valid Accs: 0.59461 | Time: 58.34 seconds
# Epoch: 25 | Train Loss: 1.21889 | Valid Loss: 1.06340 | Train Accs: 0.53010 | Valid Accs: 0.59427 | Time: 65.55 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 22
#
# **************************************************
#
# Time Taken [25 Epochs] : 24.92 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 4...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.85707 | Valid Loss: 1.74658 | Train Accs: 0.24003 | Valid Accs: 0.28486 | Time: 62.13 seconds
# Epoch: 2 | Train Loss: 1.80024 | Valid Loss: 1.69892 | Train Accs: 0.25769 | Valid Accs: 0.30615 | Time: 60.76 seconds
# Epoch: 3 | Train Loss: 1.74780 | Valid Loss: 1.63914 | Train Accs: 0.28372 | Valid Accs: 0.35920 | Time: 60.02 seconds
# Epoch: 4 | Train Loss: 1.70896 | Valid Loss: 1.66242 | Train Accs: 0.30348 | Valid Accs: 0.35388 | Time: 58.42 seconds
# Epoch: 5 | Train Loss: 1.65768 | Valid Loss: 1.63178 | Train Accs: 0.32882 | Valid Accs: 0.36641 | Time: 58.66 seconds
# Epoch: 6 | Train Loss: 1.60923 | Valid Loss: 1.76702 | Train Accs: 0.35891 | Valid Accs: 0.37277 | Time: 58.19 seconds
# Epoch: 7 | Train Loss: 1.55928 | Valid Loss: 1.41804 | Train Accs: 0.38435 | Valid Accs: 0.46257 | Time: 59.22 seconds
# Epoch: 8 | Train Loss: 1.52190 | Valid Loss: 1.38423 | Train Accs: 0.40288 | Valid Accs: 0.48661 | Time: 59.71 seconds
# Epoch: 9 | Train Loss: 1.49163 | Valid Loss: 1.29503 | Train Accs: 0.41805 | Valid Accs: 0.50343 | Time: 60.48 seconds
# Epoch: 10 | Train Loss: 1.46170 | Valid Loss: 1.26542 | Train Accs: 0.43045 | Valid Accs: 0.50687 | Time: 60.59 seconds
# Epoch: 11 | Train Loss: 1.43740 | Valid Loss: 1.27088 | Train Accs: 0.43713 | Valid Accs: 0.52404 | Time: 62.07 seconds
# Epoch: 12 | Train Loss: 1.41002 | Valid Loss: 1.26051 | Train Accs: 0.45085 | Valid Accs: 0.53228 | Time: 62.10 seconds
# Epoch: 13 | Train Loss: 1.38527 | Valid Loss: 1.22616 | Train Accs: 0.46119 | Valid Accs: 0.52833 | Time: 60.10 seconds
# Epoch: 14 | Train Loss: 1.35996 | Valid Loss: 1.23085 | Train Accs: 0.47420 | Valid Accs: 0.53589 | Time: 60.71 seconds
# Epoch: 15 | Train Loss: 1.33809 | Valid Loss: 1.18554 | Train Accs: 0.48464 | Valid Accs: 0.55271 | Time: 60.42 seconds
# Epoch: 16 | Train Loss: 1.32236 | Valid Loss: 1.21285 | Train Accs: 0.49089 | Valid Accs: 0.54001 | Time: 59.83 seconds
# Epoch: 17 | Train Loss: 1.30195 | Valid Loss: 1.16937 | Train Accs: 0.49845 | Valid Accs: 0.55632 | Time: 59.00 seconds
# Epoch: 18 | Train Loss: 1.28090 | Valid Loss: 1.15219 | Train Accs: 0.50676 | Valid Accs: 0.55477 | Time: 58.95 seconds
# Epoch: 19 | Train Loss: 1.26344 | Valid Loss: 1.17321 | Train Accs: 0.51431 | Valid Accs: 0.56061 | Time: 58.88 seconds
# Epoch: 20 | Train Loss: 1.25044 | Valid Loss: 1.13244 | Train Accs: 0.52062 | Valid Accs: 0.56679 | Time: 58.83 seconds
# Epoch: 21 | Train Loss: 1.24313 | Valid Loss: 1.13299 | Train Accs: 0.52187 | Valid Accs: 0.56611 | Time: 58.67 seconds
# Epoch: 22 | Train Loss: 1.23008 | Valid Loss: 1.13120 | Train Accs: 0.52659 | Valid Accs: 0.57126 | Time: 58.58 seconds
# Epoch: 23 | Train Loss: 1.22464 | Valid Loss: 1.11846 | Train Accs: 0.53190 | Valid Accs: 0.57555 | Time: 60.69 seconds
# Epoch: 24 | Train Loss: 1.21799 | Valid Loss: 1.12572 | Train Accs: 0.53247 | Valid Accs: 0.57143 | Time: 64.90 seconds
# Epoch: 25 | Train Loss: 1.21293 | Valid Loss: 1.12481 | Train Accs: 0.53483 | Valid Accs: 0.56902 | Time: 62.33 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 23
#
# **************************************************
#
# Best Validation Accs at Epoch 23
#
# **************************************************
#
# Time Taken [25 Epochs] : 25.07 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
#
#
# **************************************************
#
# Training Fold 5...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 1.85815 | Valid Loss: 1.76030 | Train Accs: 0.24101 | Valid Accs: 0.27558 | Time: 57.15 seconds
# Epoch: 2 | Train Loss: 1.79827 | Valid Loss: 1.70820 | Train Accs: 0.25551 | Valid Accs: 0.29018 | Time: 56.88 seconds
# Epoch: 3 | Train Loss: 1.74608 | Valid Loss: 1.75633 | Train Accs: 0.28126 | Valid Accs: 0.31250 | Time: 60.04 seconds
# Epoch: 4 | Train Loss: 1.71459 | Valid Loss: 1.56467 | Train Accs: 0.30217 | Valid Accs: 0.37740 | Time: 56.31 seconds
# Epoch: 5 | Train Loss: 1.66548 | Valid Loss: 1.72608 | Train Accs: 0.32935 | Valid Accs: 0.32744 | Time: 56.57 seconds
# Epoch: 6 | Train Loss: 1.60557 | Valid Loss: 1.71551 | Train Accs: 0.36057 | Valid Accs: 0.39921 | Time: 61.12 seconds
# Epoch: 7 | Train Loss: 1.56114 | Valid Loss: 1.37459 | Train Accs: 0.38038 | Valid Accs: 0.48575 | Time: 64.22 seconds
# Epoch: 8 | Train Loss: 1.52051 | Valid Loss: 1.31226 | Train Accs: 0.40333 | Valid Accs: 0.49536 | Time: 57.09 seconds
# Epoch: 9 | Train Loss: 1.49210 | Valid Loss: 1.29386 | Train Accs: 0.41599 | Valid Accs: 0.50876 | Time: 57.01 seconds
# Epoch: 10 | Train Loss: 1.46242 | Valid Loss: 1.27241 | Train Accs: 0.42376 | Valid Accs: 0.52696 | Time: 57.51 seconds
# Epoch: 11 | Train Loss: 1.42904 | Valid Loss: 1.23723 | Train Accs: 0.44703 | Valid Accs: 0.53125 | Time: 64.32 seconds
# Epoch: 12 | Train Loss: 1.40981 | Valid Loss: 1.26755 | Train Accs: 0.45248 | Valid Accs: 0.52696 | Time: 60.60 seconds
# Epoch: 13 | Train Loss: 1.39011 | Valid Loss: 1.19797 | Train Accs: 0.46219 | Valid Accs: 0.54018 | Time: 57.62 seconds
# Epoch: 14 | Train Loss: 1.36637 | Valid Loss: 1.22233 | Train Accs: 0.47024 | Valid Accs: 0.54275 | Time: 58.02 seconds
# Epoch: 15 | Train Loss: 1.34122 | Valid Loss: 1.16453 | Train Accs: 0.48190 | Valid Accs: 0.57177 | Time: 57.84 seconds
# Epoch: 16 | Train Loss: 1.32673 | Valid Loss: 1.12607 | Train Accs: 0.49000 | Valid Accs: 0.57109 | Time: 57.01 seconds
# Epoch: 17 | Train Loss: 1.31029 | Valid Loss: 1.10491 | Train Accs: 0.49364 | Valid Accs: 0.58156 | Time: 57.07 seconds
# Epoch: 18 | Train Loss: 1.28880 | Valid Loss: 1.12038 | Train Accs: 0.49833 | Valid Accs: 0.57744 | Time: 59.55 seconds
# Epoch: 19 | Train Loss: 1.27076 | Valid Loss: 1.10719 | Train Accs: 0.50719 | Valid Accs: 0.58104 | Time: 56.00 seconds
# Epoch: 20 | Train Loss: 1.25746 | Valid Loss: 1.09546 | Train Accs: 0.51501 | Valid Accs: 0.59014 | Time: 56.76 seconds
# Epoch: 21 | Train Loss: 1.24824 | Valid Loss: 1.07786 | Train Accs: 0.51966 | Valid Accs: 0.58997 | Time: 54.10 seconds
# Epoch: 22 | Train Loss: 1.23556 | Valid Loss: 1.08524 | Train Accs: 0.52929 | Valid Accs: 0.59375 | Time: 55.36 seconds
# Epoch: 23 | Train Loss: 1.22761 | Valid Loss: 1.07444 | Train Accs: 0.52390 | Valid Accs: 0.59392 | Time: 55.64 seconds
# Epoch: 24 | Train Loss: 1.22616 | Valid Loss: 1.07357 | Train Accs: 0.52593 | Valid Accs: 0.59547 | Time: 56.50 seconds
# Epoch: 25 | Train Loss: 1.22890 | Valid Loss: 1.07473 | Train Accs: 0.52690 | Valid Accs: 0.59718 | Time: 54.58 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 24
#
# **************************************************
#
# Best Validation Accs at Epoch 25
#
# **************************************************
#
# Time Taken [25 Epochs] : 24.08 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************

# %%
BL = np.inf
for i in range(len(BLs)):
    if BLs[i]["valid"] < BL:
        BL = BLs[i]["valid"]
        best_loss_index = i

        
BA = 0.0
for i in range(len(BAs)):
    if BAs[i]["valid"] > BA:
        BA = BAs[i]["valid"]
        best_accs_index = i

breaker()
print(f"Best Loss Model Fold     : {best_loss_index + 1}")
print(f"Best Accuracy Model Fold : {best_accs_index + 1}")
breaker()
# Out:
# **************************************************
#
# Best Loss Model Fold     : 3
# Best Accuracy Model Fold : 5
#
# **************************************************
