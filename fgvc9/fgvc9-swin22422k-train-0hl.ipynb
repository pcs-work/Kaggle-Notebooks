# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
import torch
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torch.nn.utils import weight_norm as WN

from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Constants**

# %%
SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

FEATURE_PATH = "../input/fgvc9-swinb22422k"

SAVE_PATH = "saves"
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# %%
def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def show_graphs(L: list, A: list) -> None:
    TL, VL, TA, VA = [], [], [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()

# %% [markdown]
# ### **Dataset Templatea**

# %%
class FEDS(Dataset):
    def __init__(self, base_path: str, filenames: np.ndarray, transform):
        self.base_path = base_path
        self.filenames = filenames
        self.transform = transform
    
    def __len__(self):
        return self.filenames.shape[0]
    
    def __getitem__(self, idx):
        return self.transform(get_image(os.path.join(self.base_path, self.filenames[idx])))


class DS(Dataset):
    def __init__(self, X=None, y=None, mode="train"):
        self.mode = mode

        assert(re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE) or re.match(r"test", self.mode, re.IGNORECASE))

        self.X = X
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            self.y = y
    
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            return torch.FloatTensor(self.X[idx]), torch.LongTensor(self.y[idx])
        else:
            return torch.FloatTensor(self.X[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, IL: int=None, HL: list=None, DP: float=None, use_WN: bool=False):
        super(Model, self).__init__()

        self.model = nn.Sequential()
        
        if len(HL) == 0:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=100)))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=100))

        elif len(HL) == 1:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=100)))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=100))

        
        elif len(HL) == 2:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=100)))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=100))
        
        elif len(HL) == 3:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=HL[2])))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=HL[2]))
            if isinstance(DP, float):
                self.model.add_module("DP3", nn.Dropout(p=DP))
            self.model.add_module("AN3", nn.ReLU())
            self.model.add_module("BN4", nn.BatchNorm1d(num_features=HL[2], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC4", WN(nn.Linear(in_features=HL[2], out_features=100)))
            else:
                self.model.add_module("FC4", nn.Linear(in_features=HL[2], out_features=100))
    
    def get_optimizer(self, lr=1e-3, wd=0.0):
        return optim.Adam(self.parameters(), lr=lr, weight_decay=wd)

    def get_plateau_scheduler(self, optimizer=None, patience=5, eps=1e-8):
        return optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, patience=patience, eps=eps)
    
    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helper**

# %%
def fit(model=None, optimizer=None, scheduler=None, epochs=None, early_stopping_patience=None, dataloaders=None, fold=None, verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        print(f"Training Fold {fold}...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies = [], []
    name = f"state_fold_{fold}.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []
            
            for X, y in dataloaders[phase]:
                X, y = X.to(DEVICE), y.to(DEVICE).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict": model.state_dict(),
                            "optim_state_dict": optimizer.state_dict()},
                           os.path.join(SAVE_PATH, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save({"model_state_dict" : model.state_dict(),
                        "optim_state_dict" : optimizer.state_dict()},
                        os.path.join(SAVE_PATH, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler:
            scheduler.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, BLE, BAE, name


# def predict(model=None, dataloader=None, path=None) -> np.ndarray:
#     model.load_state_dict(torch.load(path, map_location=DEVICE)["model_state_dict"])
#     model.to(DEVICE)    
#     model.eval()
    
#     y_pred = torch.zeros(1, 1).to(DEVICE)
    
#     for X in dataloader:
#         X = X.to(DEVICE)
#         with torch.no_grad():
#             output = torch.argmax(torch.exp(model(X)), dim=1)
#         y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
#     return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Load Data**

# %%
features = np.load(os.path.join(FEATURE_PATH, "features.npy"))
labels   = np.load(os.path.join(FEATURE_PATH, "labels.npy"))

# %% [markdown]
# ### **Params**

# %%
DEBUG: bool = False
    
if DEBUG:
    n_splits = 3
    epochs = 2
    HL = [4]
else:
    n_splits = 5
    epochs = 5000
    HL = []

batch_size = 512
lr = 1e-6
wd = 1e-5
early_stopping = 50
patience = None
eps = None

# %% [markdown]
# ### **Train**

# %%
fold = 1

start_time = time()
for tr_idx, va_idx in StratifiedKFold(n_splits=n_splits, random_state=SEED, shuffle=True).split(features, labels):
    tr_features, va_features, tr_labels, va_labels = features[tr_idx], features[va_idx], labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(tr_features, tr_labels.reshape(-1, 1), "train")
    va_data_setup = DS(va_features, va_labels.reshape(-1, 1), "valid")

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=batch_size, shuffle=True, generator=torch.manual_seed(SEED)),
        "valid" : DL(va_data_setup, batch_size=batch_size, shuffle=False),
    }

    torch.manual_seed(SEED)
    model = Model(IL=tr_features.shape[1], HL=HL, DP=0.25, use_WN=True).to(DEVICE)
    optimizer = model.get_optimizer(lr=lr, wd=wd)
    scheduler = None
    if isinstance(patience, int) and isinstance(eps, float):
        scheduler = get_plateau_scheduler(optimizer=optimizer, patience=patience, eps=eps)
    
    L, A, BLE, BAE, name = fit(model=model, optimizer=optimizer, scheduler=scheduler, 
                           epochs=epochs, early_stopping_patience=early_stopping, 
                           dataloaders=dataloaders, fold=fold, verbose=True)

    breaker()
    show_graphs(L, A)
    fold += 1

breaker()
print(f"Total Time Taken for {n_splits}-Fold CV : {(time()-start_time)/60:.2f} minutes")
breaker()
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.75285 | Valid Loss: 4.73869 |Train Accs: 0.01094 | Valid Accs: 0.00900 | Time: 1.66 seconds
# Epoch: 2 | Train Loss: 4.74823 | Valid Loss: 4.75176 |Train Accs: 0.01183 | Valid Accs: 0.01009 | Time: 0.48 seconds
# Epoch: 3 | Train Loss: 4.74517 | Valid Loss: 4.75227 |Train Accs: 0.01160 | Valid Accs: 0.01009 | Time: 0.41 seconds
# Epoch: 4 | Train Loss: 4.74193 | Valid Loss: 4.74927 |Train Accs: 0.01149 | Valid Accs: 0.01074 | Time: 0.41 seconds
# Epoch: 5 | Train Loss: 4.73805 | Valid Loss: 4.74310 |Train Accs: 0.01302 | Valid Accs: 0.01052 | Time: 0.41 seconds
# Epoch: 6 | Train Loss: 4.73436 | Valid Loss: 4.73979 |Train Accs: 0.01272 | Valid Accs: 0.01052 | Time: 0.41 seconds
# Epoch: 7 | Train Loss: 4.73155 | Valid Loss: 4.73388 |Train Accs: 0.01241 | Valid Accs: 0.01052 | Time: 0.53 seconds
# Epoch: 8 | Train Loss: 4.72865 | Valid Loss: 4.73472 |Train Accs: 0.01255 | Valid Accs: 0.01074 | Time: 0.41 seconds
# Epoch: 9 | Train Loss: 4.72467 | Valid Loss: 4.72666 |Train Accs: 0.01335 | Valid Accs: 0.01139 | Time: 0.58 seconds
# Epoch: 10 | Train Loss: 4.72043 | Valid Loss: 4.72747 |Train Accs: 0.01280 | Valid Accs: 0.01150 | Time: 0.49 seconds
# Epoch: 11 | Train Loss: 4.71763 | Valid Loss: 4.72174 |Train Accs: 0.01311 | Valid Accs: 0.01150 | Time: 0.41 seconds
# Epoch: 12 | Train Loss: 4.71473 | Valid Loss: 4.72043 |Train Accs: 0.01372 | Valid Accs: 0.01160 | Time: 0.41 seconds
# Epoch: 13 | Train Loss: 4.71093 | Valid Loss: 4.71599 |Train Accs: 0.01398 | Valid Accs: 0.01225 | Time: 0.41 seconds
# Epoch: 14 | Train Loss: 4.70827 | Valid Loss: 4.71270 |Train Accs: 0.01398 | Valid Accs: 0.01204 | Time: 0.41 seconds
# Epoch: 15 | Train Loss: 4.70366 | Valid Loss: 4.71270 |Train Accs: 0.01434 | Valid Accs: 0.01247 | Time: 0.41 seconds
# Epoch: 16 | Train Loss: 4.70189 | Valid Loss: 4.70529 |Train Accs: 0.01462 | Valid Accs: 0.01247 | Time: 0.51 seconds
# Epoch: 17 | Train Loss: 4.69799 | Valid Loss: 4.70441 |Train Accs: 0.01573 | Valid Accs: 0.01290 | Time: 0.41 seconds
# Epoch: 18 | Train Loss: 4.69405 | Valid Loss: 4.70279 |Train Accs: 0.01525 | Valid Accs: 0.01356 | Time: 0.41 seconds
# Epoch: 19 | Train Loss: 4.69139 | Valid Loss: 4.70074 |Train Accs: 0.01660 | Valid Accs: 0.01334 | Time: 0.41 seconds
# Epoch: 20 | Train Loss: 4.68782 | Valid Loss: 4.69784 |Train Accs: 0.01564 | Valid Accs: 0.01421 | Time: 0.42 seconds
# Epoch: 21 | Train Loss: 4.68515 | Valid Loss: 4.69127 |Train Accs: 0.01643 | Valid Accs: 0.01410 | Time: 0.42 seconds
# Epoch: 22 | Train Loss: 4.68269 | Valid Loss: 4.69296 |Train Accs: 0.01668 | Valid Accs: 0.01453 | Time: 0.52 seconds
# Epoch: 23 | Train Loss: 4.67856 | Valid Loss: 4.68853 |Train Accs: 0.01732 | Valid Accs: 0.01529 | Time: 0.43 seconds
# Epoch: 24 | Train Loss: 4.67510 | Valid Loss: 4.68463 |Train Accs: 0.01732 | Valid Accs: 0.01464 | Time: 0.42 seconds
# Epoch: 25 | Train Loss: 4.67232 | Valid Loss: 4.68019 |Train Accs: 0.01726 | Valid Accs: 0.01551 | Time: 0.42 seconds
# Epoch: 26 | Train Loss: 4.66865 | Valid Loss: 4.68147 |Train Accs: 0.01732 | Valid Accs: 0.01572 | Time: 0.42 seconds
# Epoch: 27 | Train Loss: 4.66540 | Valid Loss: 4.67589 |Train Accs: 0.01849 | Valid Accs: 0.01551 | Time: 0.42 seconds
# Epoch: 28 | Train Loss: 4.66197 | Valid Loss: 4.67395 |Train Accs: 0.01885 | Valid Accs: 0.01616 | Time: 0.42 seconds
# Epoch: 29 | Train Loss: 4.65998 | Valid Loss: 4.67012 |Train Accs: 0.01824 | Valid Accs: 0.01681 | Time: 0.42 seconds
# Epoch: 30 | Train Loss: 4.65696 | Valid Loss: 4.66894 |Train Accs: 0.01841 | Valid Accs: 0.01681 | Time: 0.41 seconds
# Epoch: 31 | Train Loss: 4.65367 | Valid Loss: 4.66528 |Train Accs: 0.01868 | Valid Accs: 0.01713 | Time: 0.52 seconds
# Epoch: 32 | Train Loss: 4.65036 | Valid Loss: 4.66168 |Train Accs: 0.01944 | Valid Accs: 0.01735 | Time: 0.43 seconds
# Epoch: 33 | Train Loss: 4.64731 | Valid Loss: 4.66078 |Train Accs: 0.02027 | Valid Accs: 0.01800 | Time: 0.42 seconds
# Epoch: 34 | Train Loss: 4.64449 | Valid Loss: 4.65627 |Train Accs: 0.02025 | Valid Accs: 0.01800 | Time: 0.55 seconds
# Epoch: 35 | Train Loss: 4.64156 | Valid Loss: 4.65423 |Train Accs: 0.02005 | Valid Accs: 0.01822 | Time: 0.51 seconds
# Epoch: 36 | Train Loss: 4.63903 | Valid Loss: 4.64732 |Train Accs: 0.02055 | Valid Accs: 0.01897 | Time: 0.42 seconds
# Epoch: 37 | Train Loss: 4.63516 | Valid Loss: 4.64747 |Train Accs: 0.02072 | Valid Accs: 0.01984 | Time: 0.51 seconds
# Epoch: 38 | Train Loss: 4.63256 | Valid Loss: 4.64537 |Train Accs: 0.02164 | Valid Accs: 0.01919 | Time: 0.42 seconds
# Epoch: 39 | Train Loss: 4.62871 | Valid Loss: 4.64450 |Train Accs: 0.02206 | Valid Accs: 0.01995 | Time: 0.42 seconds
# Epoch: 40 | Train Loss: 4.62689 | Valid Loss: 4.63866 |Train Accs: 0.02137 | Valid Accs: 0.02017 | Time: 0.41 seconds
# Epoch: 41 | Train Loss: 4.62333 | Valid Loss: 4.63801 |Train Accs: 0.02315 | Valid Accs: 0.02049 | Time: 0.42 seconds
# Epoch: 42 | Train Loss: 4.62021 | Valid Loss: 4.63299 |Train Accs: 0.02287 | Valid Accs: 0.02027 | Time: 0.41 seconds
# Epoch: 43 | Train Loss: 4.61858 | Valid Loss: 4.63078 |Train Accs: 0.02362 | Valid Accs: 0.02092 | Time: 0.41 seconds
# Epoch: 44 | Train Loss: 4.61515 | Valid Loss: 4.63040 |Train Accs: 0.02440 | Valid Accs: 0.02125 | Time: 0.41 seconds
# Epoch: 45 | Train Loss: 4.61197 | Valid Loss: 4.62735 |Train Accs: 0.02398 | Valid Accs: 0.02233 | Time: 0.41 seconds
# Epoch: 46 | Train Loss: 4.60912 | Valid Loss: 4.62420 |Train Accs: 0.02479 | Valid Accs: 0.02255 | Time: 0.53 seconds
# Epoch: 47 | Train Loss: 4.60634 | Valid Loss: 4.62209 |Train Accs: 0.02507 | Valid Accs: 0.02212 | Time: 0.43 seconds
# Epoch: 48 | Train Loss: 4.60352 | Valid Loss: 4.61829 |Train Accs: 0.02479 | Valid Accs: 0.02168 | Time: 0.42 seconds
# Epoch: 49 | Train Loss: 4.60140 | Valid Loss: 4.61806 |Train Accs: 0.02541 | Valid Accs: 0.02277 | Time: 0.42 seconds
# Epoch: 50 | Train Loss: 4.59768 | Valid Loss: 4.61519 |Train Accs: 0.02619 | Valid Accs: 0.02374 | Time: 0.42 seconds
# Epoch: 51 | Train Loss: 4.59452 | Valid Loss: 4.61193 |Train Accs: 0.02619 | Valid Accs: 0.02385 | Time: 0.43 seconds
# Epoch: 52 | Train Loss: 4.59180 | Valid Loss: 4.60740 |Train Accs: 0.02697 | Valid Accs: 0.02364 | Time: 0.52 seconds
# Epoch: 53 | Train Loss: 4.58933 | Valid Loss: 4.60742 |Train Accs: 0.02666 | Valid Accs: 0.02439 | Time: 0.41 seconds
# Epoch: 54 | Train Loss: 4.58608 | Valid Loss: 4.60556 |Train Accs: 0.02785 | Valid Accs: 0.02439 | Time: 0.41 seconds
# Epoch: 55 | Train Loss: 4.58381 | Valid Loss: 4.60096 |Train Accs: 0.02747 | Valid Accs: 0.02515 | Time: 0.42 seconds
# Epoch: 56 | Train Loss: 4.58028 | Valid Loss: 4.59826 |Train Accs: 0.02853 | Valid Accs: 0.02570 | Time: 0.43 seconds
# Epoch: 57 | Train Loss: 4.57820 | Valid Loss: 4.59715 |Train Accs: 0.02856 | Valid Accs: 0.02624 | Time: 0.42 seconds
# Epoch: 58 | Train Loss: 4.57492 | Valid Loss: 4.59088 |Train Accs: 0.02845 | Valid Accs: 0.02624 | Time: 0.43 seconds
# Epoch: 59 | Train Loss: 4.57293 | Valid Loss: 4.59188 |Train Accs: 0.02929 | Valid Accs: 0.02624 | Time: 0.53 seconds
# Epoch: 60 | Train Loss: 4.56959 | Valid Loss: 4.58814 |Train Accs: 0.02979 | Valid Accs: 0.02710 | Time: 0.65 seconds
# Epoch: 61 | Train Loss: 4.56777 | Valid Loss: 4.58634 |Train Accs: 0.03031 | Valid Accs: 0.02732 | Time: 0.42 seconds
# Epoch: 62 | Train Loss: 4.56474 | Valid Loss: 4.58410 |Train Accs: 0.03054 | Valid Accs: 0.02754 | Time: 0.42 seconds
# Epoch: 63 | Train Loss: 4.56129 | Valid Loss: 4.58135 |Train Accs: 0.03126 | Valid Accs: 0.02819 | Time: 0.42 seconds
# Epoch: 64 | Train Loss: 4.55929 | Valid Loss: 4.57876 |Train Accs: 0.03085 | Valid Accs: 0.02841 | Time: 0.42 seconds
# Epoch: 65 | Train Loss: 4.55575 | Valid Loss: 4.57607 |Train Accs: 0.03180 | Valid Accs: 0.02841 | Time: 0.42 seconds
# Epoch: 66 | Train Loss: 4.55406 | Valid Loss: 4.57351 |Train Accs: 0.03182 | Valid Accs: 0.02884 | Time: 0.52 seconds
# Epoch: 67 | Train Loss: 4.55056 | Valid Loss: 4.56985 |Train Accs: 0.03241 | Valid Accs: 0.02862 | Time: 0.43 seconds
# Epoch: 68 | Train Loss: 4.54788 | Valid Loss: 4.56880 |Train Accs: 0.03263 | Valid Accs: 0.02927 | Time: 0.42 seconds
# Epoch: 69 | Train Loss: 4.54540 | Valid Loss: 4.56582 |Train Accs: 0.03335 | Valid Accs: 0.02927 | Time: 0.42 seconds
# Epoch: 70 | Train Loss: 4.54244 | Valid Loss: 4.56457 |Train Accs: 0.03378 | Valid Accs: 0.02971 | Time: 0.43 seconds
# Epoch: 71 | Train Loss: 4.53968 | Valid Loss: 4.56142 |Train Accs: 0.03489 | Valid Accs: 0.03014 | Time: 0.41 seconds
# Epoch: 72 | Train Loss: 4.53789 | Valid Loss: 4.55859 |Train Accs: 0.03522 | Valid Accs: 0.03058 | Time: 0.42 seconds
# Epoch: 73 | Train Loss: 4.53470 | Valid Loss: 4.55741 |Train Accs: 0.03542 | Valid Accs: 0.03058 | Time: 0.41 seconds
# Epoch: 74 | Train Loss: 4.53198 | Valid Loss: 4.55462 |Train Accs: 0.03673 | Valid Accs: 0.03101 | Time: 0.45 seconds
# Epoch: 75 | Train Loss: 4.53005 | Valid Loss: 4.55328 |Train Accs: 0.03581 | Valid Accs: 0.03133 | Time: 0.76 seconds
# Epoch: 76 | Train Loss: 4.52746 | Valid Loss: 4.54922 |Train Accs: 0.03707 | Valid Accs: 0.03210 | Time: 0.51 seconds
# Epoch: 77 | Train Loss: 4.52436 | Valid Loss: 4.54731 |Train Accs: 0.03623 | Valid Accs: 0.03307 | Time: 0.42 seconds
# Epoch: 78 | Train Loss: 4.52171 | Valid Loss: 4.54564 |Train Accs: 0.03744 | Valid Accs: 0.03264 | Time: 0.41 seconds
# Epoch: 79 | Train Loss: 4.51916 | Valid Loss: 4.54294 |Train Accs: 0.03862 | Valid Accs: 0.03340 | Time: 0.41 seconds
# Epoch: 80 | Train Loss: 4.51673 | Valid Loss: 4.54069 |Train Accs: 0.03813 | Valid Accs: 0.03448 | Time: 0.41 seconds
# Epoch: 81 | Train Loss: 4.51476 | Valid Loss: 4.53854 |Train Accs: 0.03902 | Valid Accs: 0.03470 | Time: 0.52 seconds
# Epoch: 82 | Train Loss: 4.51141 | Valid Loss: 4.53613 |Train Accs: 0.03925 | Valid Accs: 0.03480 | Time: 0.42 seconds
# Epoch: 83 | Train Loss: 4.50910 | Valid Loss: 4.53432 |Train Accs: 0.03975 | Valid Accs: 0.03513 | Time: 0.55 seconds
# Epoch: 84 | Train Loss: 4.50602 | Valid Loss: 4.53219 |Train Accs: 0.03949 | Valid Accs: 0.03578 | Time: 0.49 seconds
# Epoch: 85 | Train Loss: 4.50489 | Valid Loss: 4.52980 |Train Accs: 0.04053 | Valid Accs: 0.03578 | Time: 0.42 seconds
# Epoch: 86 | Train Loss: 4.50124 | Valid Loss: 4.52772 |Train Accs: 0.04064 | Valid Accs: 0.03643 | Time: 0.41 seconds
# Epoch: 87 | Train Loss: 4.49824 | Valid Loss: 4.52525 |Train Accs: 0.04261 | Valid Accs: 0.03686 | Time: 0.42 seconds
# Epoch: 88 | Train Loss: 4.49595 | Valid Loss: 4.52247 |Train Accs: 0.04155 | Valid Accs: 0.03708 | Time: 0.41 seconds
# Epoch: 89 | Train Loss: 4.49374 | Valid Loss: 4.52013 |Train Accs: 0.04164 | Valid Accs: 0.03817 | Time: 0.41 seconds
# Epoch: 90 | Train Loss: 4.49165 | Valid Loss: 4.51825 |Train Accs: 0.04325 | Valid Accs: 0.03763 | Time: 0.51 seconds
# Epoch: 91 | Train Loss: 4.48844 | Valid Loss: 4.51652 |Train Accs: 0.04361 | Valid Accs: 0.03838 | Time: 0.41 seconds
# Epoch: 92 | Train Loss: 4.48663 | Valid Loss: 4.51395 |Train Accs: 0.04287 | Valid Accs: 0.03817 | Time: 0.44 seconds
# Epoch: 93 | Train Loss: 4.48430 | Valid Loss: 4.51103 |Train Accs: 0.04429 | Valid Accs: 0.03936 | Time: 0.41 seconds
# Epoch: 94 | Train Loss: 4.48180 | Valid Loss: 4.50952 |Train Accs: 0.04365 | Valid Accs: 0.03968 | Time: 0.41 seconds
# Epoch: 95 | Train Loss: 4.47860 | Valid Loss: 4.50692 |Train Accs: 0.04502 | Valid Accs: 0.03990 | Time: 0.42 seconds
# Epoch: 96 | Train Loss: 4.47659 | Valid Loss: 4.50512 |Train Accs: 0.04560 | Valid Accs: 0.04077 | Time: 0.42 seconds
# Epoch: 97 | Train Loss: 4.47387 | Valid Loss: 4.50256 |Train Accs: 0.04627 | Valid Accs: 0.04055 | Time: 0.52 seconds
# Epoch: 98 | Train Loss: 4.47172 | Valid Loss: 4.50048 |Train Accs: 0.04613 | Valid Accs: 0.04098 | Time: 0.43 seconds
# Epoch: 99 | Train Loss: 4.46804 | Valid Loss: 4.49851 |Train Accs: 0.04619 | Valid Accs: 0.04164 | Time: 0.42 seconds
# Epoch: 100 | Train Loss: 4.46672 | Valid Loss: 4.49592 |Train Accs: 0.04728 | Valid Accs: 0.04229 | Time: 0.41 seconds
# Epoch: 101 | Train Loss: 4.46463 | Valid Loss: 4.49406 |Train Accs: 0.04711 | Valid Accs: 0.04164 | Time: 0.42 seconds
# Epoch: 102 | Train Loss: 4.46167 | Valid Loss: 4.49187 |Train Accs: 0.04806 | Valid Accs: 0.04326 | Time: 0.42 seconds
# Epoch: 103 | Train Loss: 4.45997 | Valid Loss: 4.48972 |Train Accs: 0.04811 | Valid Accs: 0.04240 | Time: 0.41 seconds
# Epoch: 104 | Train Loss: 4.45735 | Valid Loss: 4.48785 |Train Accs: 0.04817 | Valid Accs: 0.04283 | Time: 0.41 seconds
# Epoch: 105 | Train Loss: 4.45489 | Valid Loss: 4.48520 |Train Accs: 0.04901 | Valid Accs: 0.04315 | Time: 0.52 seconds
# Epoch: 106 | Train Loss: 4.45246 | Valid Loss: 4.48289 |Train Accs: 0.04903 | Valid Accs: 0.04391 | Time: 0.41 seconds
# Epoch: 107 | Train Loss: 4.45061 | Valid Loss: 4.48142 |Train Accs: 0.04889 | Valid Accs: 0.04554 | Time: 0.42 seconds
# Epoch: 108 | Train Loss: 4.44724 | Valid Loss: 4.47931 |Train Accs: 0.05004 | Valid Accs: 0.04543 | Time: 0.52 seconds
# Epoch: 109 | Train Loss: 4.44527 | Valid Loss: 4.47672 |Train Accs: 0.04984 | Valid Accs: 0.04521 | Time: 0.54 seconds
# Epoch: 110 | Train Loss: 4.44219 | Valid Loss: 4.47478 |Train Accs: 0.05053 | Valid Accs: 0.04651 | Time: 0.41 seconds
# Epoch: 111 | Train Loss: 4.44126 | Valid Loss: 4.47309 |Train Accs: 0.05160 | Valid Accs: 0.04717 | Time: 0.51 seconds
# Epoch: 112 | Train Loss: 4.43837 | Valid Loss: 4.47079 |Train Accs: 0.05224 | Valid Accs: 0.04749 | Time: 0.41 seconds
# Epoch: 113 | Train Loss: 4.43540 | Valid Loss: 4.46879 |Train Accs: 0.05215 | Valid Accs: 0.04684 | Time: 0.42 seconds
# Epoch: 114 | Train Loss: 4.43373 | Valid Loss: 4.46645 |Train Accs: 0.05174 | Valid Accs: 0.04727 | Time: 0.41 seconds
# Epoch: 115 | Train Loss: 4.43131 | Valid Loss: 4.46467 |Train Accs: 0.05255 | Valid Accs: 0.04803 | Time: 0.42 seconds
# Epoch: 116 | Train Loss: 4.42909 | Valid Loss: 4.46224 |Train Accs: 0.05319 | Valid Accs: 0.04923 | Time: 0.41 seconds
# Epoch: 117 | Train Loss: 4.42706 | Valid Loss: 4.46041 |Train Accs: 0.05380 | Valid Accs: 0.04836 | Time: 0.41 seconds
# Epoch: 118 | Train Loss: 4.42498 | Valid Loss: 4.45851 |Train Accs: 0.05330 | Valid Accs: 0.04966 | Time: 0.41 seconds
# Epoch: 119 | Train Loss: 4.42236 | Valid Loss: 4.45646 |Train Accs: 0.05408 | Valid Accs: 0.04923 | Time: 0.41 seconds
# Epoch: 120 | Train Loss: 4.41962 | Valid Loss: 4.45437 |Train Accs: 0.05469 | Valid Accs: 0.04999 | Time: 0.51 seconds
# Epoch: 121 | Train Loss: 4.41801 | Valid Loss: 4.45226 |Train Accs: 0.05439 | Valid Accs: 0.04944 | Time: 0.42 seconds
# Epoch: 122 | Train Loss: 4.41523 | Valid Loss: 4.45027 |Train Accs: 0.05508 | Valid Accs: 0.05042 | Time: 0.41 seconds
# Epoch: 123 | Train Loss: 4.41277 | Valid Loss: 4.44792 |Train Accs: 0.05459 | Valid Accs: 0.05053 | Time: 0.41 seconds
# Epoch: 124 | Train Loss: 4.41119 | Valid Loss: 4.44642 |Train Accs: 0.05554 | Valid Accs: 0.05053 | Time: 0.42 seconds
# Epoch: 125 | Train Loss: 4.40834 | Valid Loss: 4.44459 |Train Accs: 0.05579 | Valid Accs: 0.05064 | Time: 0.42 seconds
# Epoch: 126 | Train Loss: 4.40590 | Valid Loss: 4.44230 |Train Accs: 0.05656 | Valid Accs: 0.05150 | Time: 0.52 seconds
# Epoch: 127 | Train Loss: 4.40408 | Valid Loss: 4.43995 |Train Accs: 0.05609 | Valid Accs: 0.05161 | Time: 0.42 seconds
# Epoch: 128 | Train Loss: 4.40282 | Valid Loss: 4.43856 |Train Accs: 0.05696 | Valid Accs: 0.05216 | Time: 0.45 seconds
# Epoch: 129 | Train Loss: 4.39990 | Valid Loss: 4.43618 |Train Accs: 0.05790 | Valid Accs: 0.05107 | Time: 0.41 seconds
# Epoch: 130 | Train Loss: 4.39674 | Valid Loss: 4.43420 |Train Accs: 0.05768 | Valid Accs: 0.05346 | Time: 0.41 seconds
# Epoch: 131 | Train Loss: 4.39518 | Valid Loss: 4.43177 |Train Accs: 0.05957 | Valid Accs: 0.05259 | Time: 0.42 seconds
# Epoch: 132 | Train Loss: 4.39264 | Valid Loss: 4.43002 |Train Accs: 0.05916 | Valid Accs: 0.05324 | Time: 0.41 seconds
# Epoch: 133 | Train Loss: 4.39035 | Valid Loss: 4.42777 |Train Accs: 0.05910 | Valid Accs: 0.05346 | Time: 0.48 seconds
# Epoch: 134 | Train Loss: 4.38847 | Valid Loss: 4.42649 |Train Accs: 0.06060 | Valid Accs: 0.05378 | Time: 0.58 seconds
# Epoch: 135 | Train Loss: 4.38593 | Valid Loss: 4.42448 |Train Accs: 0.06050 | Valid Accs: 0.05411 | Time: 0.52 seconds
# Epoch: 136 | Train Loss: 4.38298 | Valid Loss: 4.42166 |Train Accs: 0.06041 | Valid Accs: 0.05541 | Time: 0.42 seconds
# Epoch: 137 | Train Loss: 4.38199 | Valid Loss: 4.42054 |Train Accs: 0.06054 | Valid Accs: 0.05487 | Time: 0.43 seconds
# Epoch: 138 | Train Loss: 4.37957 | Valid Loss: 4.41840 |Train Accs: 0.06078 | Valid Accs: 0.05617 | Time: 0.41 seconds
# Epoch: 139 | Train Loss: 4.37740 | Valid Loss: 4.41588 |Train Accs: 0.06183 | Valid Accs: 0.05563 | Time: 0.41 seconds
# Epoch: 140 | Train Loss: 4.37560 | Valid Loss: 4.41424 |Train Accs: 0.06105 | Valid Accs: 0.05649 | Time: 0.41 seconds
# Epoch: 141 | Train Loss: 4.37327 | Valid Loss: 4.41305 |Train Accs: 0.06192 | Valid Accs: 0.05725 | Time: 0.41 seconds
# Epoch: 142 | Train Loss: 4.37144 | Valid Loss: 4.41031 |Train Accs: 0.06371 | Valid Accs: 0.05704 | Time: 0.53 seconds
# Epoch: 143 | Train Loss: 4.36894 | Valid Loss: 4.40919 |Train Accs: 0.06333 | Valid Accs: 0.05736 | Time: 0.41 seconds
# Epoch: 144 | Train Loss: 4.36605 | Valid Loss: 4.40691 |Train Accs: 0.06382 | Valid Accs: 0.05845 | Time: 0.42 seconds
# Epoch: 145 | Train Loss: 4.36470 | Valid Loss: 4.40569 |Train Accs: 0.06532 | Valid Accs: 0.05845 | Time: 0.41 seconds
# Epoch: 146 | Train Loss: 4.36236 | Valid Loss: 4.40299 |Train Accs: 0.06532 | Valid Accs: 0.05953 | Time: 0.41 seconds
# Epoch: 147 | Train Loss: 4.36041 | Valid Loss: 4.40108 |Train Accs: 0.06420 | Valid Accs: 0.05845 | Time: 0.41 seconds
# Epoch: 148 | Train Loss: 4.35776 | Valid Loss: 4.39928 |Train Accs: 0.06469 | Valid Accs: 0.05769 | Time: 0.43 seconds
# Epoch: 149 | Train Loss: 4.35665 | Valid Loss: 4.39740 |Train Accs: 0.06538 | Valid Accs: 0.05953 | Time: 0.64 seconds
# Epoch: 150 | Train Loss: 4.35403 | Valid Loss: 4.39586 |Train Accs: 0.06538 | Valid Accs: 0.05975 | Time: 0.69 seconds
# Epoch: 151 | Train Loss: 4.35256 | Valid Loss: 4.39320 |Train Accs: 0.06605 | Valid Accs: 0.05953 | Time: 0.41 seconds
# Epoch: 152 | Train Loss: 4.35088 | Valid Loss: 4.39117 |Train Accs: 0.06728 | Valid Accs: 0.05996 | Time: 0.41 seconds
# Epoch: 153 | Train Loss: 4.34763 | Valid Loss: 4.38996 |Train Accs: 0.06764 | Valid Accs: 0.05986 | Time: 0.42 seconds
# Epoch: 154 | Train Loss: 4.34510 | Valid Loss: 4.38721 |Train Accs: 0.06808 | Valid Accs: 0.06083 | Time: 0.41 seconds
# Epoch: 155 | Train Loss: 4.34297 | Valid Loss: 4.38736 |Train Accs: 0.06931 | Valid Accs: 0.06083 | Time: 0.42 seconds
# Epoch: 156 | Train Loss: 4.34161 | Valid Loss: 4.38445 |Train Accs: 0.06898 | Valid Accs: 0.06127 | Time: 0.51 seconds
# Epoch: 157 | Train Loss: 4.33973 | Valid Loss: 4.38191 |Train Accs: 0.06917 | Valid Accs: 0.06105 | Time: 0.48 seconds
# Epoch: 158 | Train Loss: 4.33708 | Valid Loss: 4.38080 |Train Accs: 0.07018 | Valid Accs: 0.06203 | Time: 0.57 seconds
# Epoch: 159 | Train Loss: 4.33614 | Valid Loss: 4.37918 |Train Accs: 0.07101 | Valid Accs: 0.06279 | Time: 0.42 seconds
# Epoch: 160 | Train Loss: 4.33311 | Valid Loss: 4.37768 |Train Accs: 0.07168 | Valid Accs: 0.06289 | Time: 0.41 seconds
# Epoch: 161 | Train Loss: 4.33074 | Valid Loss: 4.37567 |Train Accs: 0.07188 | Valid Accs: 0.06376 | Time: 0.42 seconds
# Epoch: 162 | Train Loss: 4.32898 | Valid Loss: 4.37386 |Train Accs: 0.07126 | Valid Accs: 0.06333 | Time: 0.42 seconds
# Epoch: 163 | Train Loss: 4.32602 | Valid Loss: 4.37084 |Train Accs: 0.07023 | Valid Accs: 0.06485 | Time: 0.41 seconds
# Epoch: 164 | Train Loss: 4.32453 | Valid Loss: 4.36995 |Train Accs: 0.07272 | Valid Accs: 0.06528 | Time: 0.42 seconds
# Epoch: 165 | Train Loss: 4.32368 | Valid Loss: 4.36683 |Train Accs: 0.07309 | Valid Accs: 0.06463 | Time: 0.52 seconds
# Epoch: 166 | Train Loss: 4.32074 | Valid Loss: 4.36746 |Train Accs: 0.07204 | Valid Accs: 0.06550 | Time: 0.41 seconds
# Epoch: 167 | Train Loss: 4.31877 | Valid Loss: 4.36387 |Train Accs: 0.07252 | Valid Accs: 0.06615 | Time: 0.41 seconds
# Epoch: 168 | Train Loss: 4.31665 | Valid Loss: 4.36290 |Train Accs: 0.07397 | Valid Accs: 0.06723 | Time: 0.41 seconds
# Epoch: 169 | Train Loss: 4.31482 | Valid Loss: 4.36024 |Train Accs: 0.07452 | Valid Accs: 0.06702 | Time: 0.41 seconds
# Epoch: 170 | Train Loss: 4.31297 | Valid Loss: 4.35946 |Train Accs: 0.07400 | Valid Accs: 0.06702 | Time: 0.41 seconds
# Epoch: 171 | Train Loss: 4.30990 | Valid Loss: 4.35708 |Train Accs: 0.07414 | Valid Accs: 0.06702 | Time: 0.51 seconds
# Epoch: 172 | Train Loss: 4.30785 | Valid Loss: 4.35476 |Train Accs: 0.07531 | Valid Accs: 0.06810 | Time: 0.41 seconds
# Epoch: 173 | Train Loss: 4.30698 | Valid Loss: 4.35471 |Train Accs: 0.07569 | Valid Accs: 0.06832 | Time: 0.41 seconds
# Epoch: 174 | Train Loss: 4.30432 | Valid Loss: 4.35194 |Train Accs: 0.07604 | Valid Accs: 0.06788 | Time: 0.41 seconds
# Epoch: 175 | Train Loss: 4.30266 | Valid Loss: 4.34953 |Train Accs: 0.07430 | Valid Accs: 0.07005 | Time: 0.41 seconds
# Epoch: 176 | Train Loss: 4.30114 | Valid Loss: 4.34805 |Train Accs: 0.07701 | Valid Accs: 0.06984 | Time: 0.41 seconds
# Epoch: 177 | Train Loss: 4.29964 | Valid Loss: 4.34658 |Train Accs: 0.07732 | Valid Accs: 0.07049 | Time: 0.41 seconds
# Epoch: 178 | Train Loss: 4.29677 | Valid Loss: 4.34568 |Train Accs: 0.07804 | Valid Accs: 0.07136 | Time: 0.42 seconds
# Epoch: 179 | Train Loss: 4.29470 | Valid Loss: 4.34235 |Train Accs: 0.07784 | Valid Accs: 0.07005 | Time: 0.41 seconds
# Epoch: 180 | Train Loss: 4.29261 | Valid Loss: 4.34126 |Train Accs: 0.07893 | Valid Accs: 0.07092 | Time: 0.51 seconds
# Epoch: 181 | Train Loss: 4.29098 | Valid Loss: 4.34106 |Train Accs: 0.07786 | Valid Accs: 0.07157 | Time: 0.42 seconds
# Epoch: 182 | Train Loss: 4.28855 | Valid Loss: 4.33787 |Train Accs: 0.07954 | Valid Accs: 0.07222 | Time: 0.41 seconds
# Epoch: 183 | Train Loss: 4.28586 | Valid Loss: 4.33608 |Train Accs: 0.08022 | Valid Accs: 0.07201 | Time: 0.63 seconds
# Epoch: 184 | Train Loss: 4.28481 | Valid Loss: 4.33552 |Train Accs: 0.08040 | Valid Accs: 0.07309 | Time: 0.42 seconds
# Epoch: 185 | Train Loss: 4.28186 | Valid Loss: 4.33254 |Train Accs: 0.08040 | Valid Accs: 0.07353 | Time: 0.41 seconds
# Epoch: 186 | Train Loss: 4.28115 | Valid Loss: 4.33155 |Train Accs: 0.08101 | Valid Accs: 0.07309 | Time: 0.41 seconds
# Epoch: 187 | Train Loss: 4.27906 | Valid Loss: 4.33011 |Train Accs: 0.08015 | Valid Accs: 0.07418 | Time: 0.52 seconds
# Epoch: 188 | Train Loss: 4.27744 | Valid Loss: 4.32995 |Train Accs: 0.08111 | Valid Accs: 0.07472 | Time: 0.41 seconds
# Epoch: 189 | Train Loss: 4.27463 | Valid Loss: 4.32623 |Train Accs: 0.08294 | Valid Accs: 0.07309 | Time: 0.42 seconds
# Epoch: 190 | Train Loss: 4.27278 | Valid Loss: 4.32322 |Train Accs: 0.08127 | Valid Accs: 0.07461 | Time: 0.42 seconds
# Epoch: 191 | Train Loss: 4.27074 | Valid Loss: 4.32126 |Train Accs: 0.08136 | Valid Accs: 0.07505 | Time: 0.41 seconds
# Epoch: 192 | Train Loss: 4.26917 | Valid Loss: 4.32040 |Train Accs: 0.08283 | Valid Accs: 0.07505 | Time: 0.41 seconds
# Epoch: 193 | Train Loss: 4.26732 | Valid Loss: 4.31852 |Train Accs: 0.08367 | Valid Accs: 0.07656 | Time: 0.41 seconds
# Epoch: 194 | Train Loss: 4.26432 | Valid Loss: 4.31683 |Train Accs: 0.08147 | Valid Accs: 0.07678 | Time: 0.41 seconds
# Epoch: 195 | Train Loss: 4.26301 | Valid Loss: 4.31458 |Train Accs: 0.08443 | Valid Accs: 0.07634 | Time: 0.53 seconds
# Epoch: 196 | Train Loss: 4.26221 | Valid Loss: 4.31326 |Train Accs: 0.08484 | Valid Accs: 0.07634 | Time: 0.46 seconds
# Epoch: 197 | Train Loss: 4.26031 | Valid Loss: 4.31205 |Train Accs: 0.08449 | Valid Accs: 0.07678 | Time: 0.41 seconds
# Epoch: 198 | Train Loss: 4.25750 | Valid Loss: 4.30860 |Train Accs: 0.08426 | Valid Accs: 0.07808 | Time: 0.41 seconds
# Epoch: 199 | Train Loss: 4.25490 | Valid Loss: 4.30899 |Train Accs: 0.08545 | Valid Accs: 0.07808 | Time: 0.42 seconds
# Epoch: 200 | Train Loss: 4.25384 | Valid Loss: 4.30608 |Train Accs: 0.08595 | Valid Accs: 0.07721 | Time: 0.41 seconds
# Epoch: 201 | Train Loss: 4.25197 | Valid Loss: 4.30629 |Train Accs: 0.08584 | Valid Accs: 0.07721 | Time: 0.51 seconds
# Epoch: 202 | Train Loss: 4.24982 | Valid Loss: 4.30214 |Train Accs: 0.08621 | Valid Accs: 0.07862 | Time: 0.42 seconds
# Epoch: 203 | Train Loss: 4.24816 | Valid Loss: 4.30361 |Train Accs: 0.08681 | Valid Accs: 0.07938 | Time: 0.42 seconds
# Epoch: 204 | Train Loss: 4.24675 | Valid Loss: 4.30042 |Train Accs: 0.08713 | Valid Accs: 0.07830 | Time: 0.41 seconds
# Epoch: 205 | Train Loss: 4.24498 | Valid Loss: 4.29802 |Train Accs: 0.08783 | Valid Accs: 0.07765 | Time: 0.42 seconds
# Epoch: 206 | Train Loss: 4.24288 | Valid Loss: 4.29512 |Train Accs: 0.08805 | Valid Accs: 0.07960 | Time: 0.42 seconds
# Epoch: 207 | Train Loss: 4.24086 | Valid Loss: 4.29605 |Train Accs: 0.08838 | Valid Accs: 0.07971 | Time: 0.41 seconds
# Epoch: 208 | Train Loss: 4.23868 | Valid Loss: 4.29451 |Train Accs: 0.08895 | Valid Accs: 0.07982 | Time: 0.61 seconds
# Epoch: 209 | Train Loss: 4.23582 | Valid Loss: 4.29198 |Train Accs: 0.08956 | Valid Accs: 0.08047 | Time: 0.45 seconds
# Epoch: 210 | Train Loss: 4.23522 | Valid Loss: 4.29283 |Train Accs: 0.08995 | Valid Accs: 0.08025 | Time: 0.51 seconds
# Epoch: 211 | Train Loss: 4.23289 | Valid Loss: 4.28866 |Train Accs: 0.09025 | Valid Accs: 0.08003 | Time: 0.42 seconds
# Epoch: 212 | Train Loss: 4.23109 | Valid Loss: 4.28756 |Train Accs: 0.09000 | Valid Accs: 0.08079 | Time: 0.41 seconds
# Epoch: 213 | Train Loss: 4.22979 | Valid Loss: 4.28451 |Train Accs: 0.09182 | Valid Accs: 0.08166 | Time: 0.41 seconds
# Epoch: 214 | Train Loss: 4.22772 | Valid Loss: 4.28389 |Train Accs: 0.09115 | Valid Accs: 0.08274 | Time: 0.42 seconds
# Epoch: 215 | Train Loss: 4.22593 | Valid Loss: 4.28147 |Train Accs: 0.09204 | Valid Accs: 0.08242 | Time: 0.42 seconds
# Epoch: 216 | Train Loss: 4.22585 | Valid Loss: 4.28069 |Train Accs: 0.09113 | Valid Accs: 0.08231 | Time: 0.52 seconds
# Epoch: 217 | Train Loss: 4.22335 | Valid Loss: 4.28018 |Train Accs: 0.09066 | Valid Accs: 0.08340 | Time: 0.42 seconds
# Epoch: 218 | Train Loss: 4.21983 | Valid Loss: 4.27746 |Train Accs: 0.09349 | Valid Accs: 0.08264 | Time: 0.41 seconds
# Epoch: 219 | Train Loss: 4.21747 | Valid Loss: 4.27603 |Train Accs: 0.09245 | Valid Accs: 0.08340 | Time: 0.42 seconds
# Epoch: 220 | Train Loss: 4.21795 | Valid Loss: 4.27516 |Train Accs: 0.09199 | Valid Accs: 0.08372 | Time: 0.41 seconds
# Epoch: 221 | Train Loss: 4.21582 | Valid Loss: 4.27485 |Train Accs: 0.09505 | Valid Accs: 0.08351 | Time: 0.41 seconds
# Epoch: 222 | Train Loss: 4.21350 | Valid Loss: 4.27069 |Train Accs: 0.09311 | Valid Accs: 0.08394 | Time: 0.42 seconds
# Epoch: 223 | Train Loss: 4.21176 | Valid Loss: 4.26845 |Train Accs: 0.09519 | Valid Accs: 0.08459 | Time: 0.62 seconds
# Epoch: 224 | Train Loss: 4.21006 | Valid Loss: 4.26938 |Train Accs: 0.09528 | Valid Accs: 0.08492 | Time: 0.63 seconds
# Epoch: 225 | Train Loss: 4.20747 | Valid Loss: 4.26623 |Train Accs: 0.09539 | Valid Accs: 0.08546 | Time: 0.56 seconds
# Epoch: 226 | Train Loss: 4.20609 | Valid Loss: 4.26463 |Train Accs: 0.09549 | Valid Accs: 0.08437 | Time: 0.43 seconds
# Epoch: 227 | Train Loss: 4.20433 | Valid Loss: 4.26294 |Train Accs: 0.09617 | Valid Accs: 0.08524 | Time: 0.44 seconds
# Epoch: 228 | Train Loss: 4.20284 | Valid Loss: 4.26211 |Train Accs: 0.09611 | Valid Accs: 0.08589 | Time: 0.42 seconds
# Epoch: 229 | Train Loss: 4.20047 | Valid Loss: 4.26084 |Train Accs: 0.09667 | Valid Accs: 0.08589 | Time: 0.42 seconds
# Epoch: 230 | Train Loss: 4.19989 | Valid Loss: 4.25883 |Train Accs: 0.09690 | Valid Accs: 0.08633 | Time: 0.42 seconds
# Epoch: 231 | Train Loss: 4.19795 | Valid Loss: 4.25862 |Train Accs: 0.09600 | Valid Accs: 0.08676 | Time: 0.42 seconds
# Epoch: 232 | Train Loss: 4.19539 | Valid Loss: 4.25570 |Train Accs: 0.09758 | Valid Accs: 0.08611 | Time: 0.80 seconds
# Epoch: 233 | Train Loss: 4.19372 | Valid Loss: 4.25275 |Train Accs: 0.09757 | Valid Accs: 0.08676 | Time: 0.48 seconds
# Epoch: 234 | Train Loss: 4.19249 | Valid Loss: 4.25542 |Train Accs: 0.09769 | Valid Accs: 0.08654 | Time: 0.45 seconds
# Epoch: 235 | Train Loss: 4.18995 | Valid Loss: 4.25205 |Train Accs: 0.09906 | Valid Accs: 0.08676 | Time: 0.45 seconds
# Epoch: 236 | Train Loss: 4.18888 | Valid Loss: 4.25122 |Train Accs: 0.09892 | Valid Accs: 0.08785 | Time: 0.42 seconds
# Epoch: 237 | Train Loss: 4.18609 | Valid Loss: 4.24815 |Train Accs: 0.10066 | Valid Accs: 0.08763 | Time: 0.42 seconds
# Epoch: 238 | Train Loss: 4.18449 | Valid Loss: 4.24371 |Train Accs: 0.10080 | Valid Accs: 0.08893 | Time: 0.42 seconds
# Epoch: 239 | Train Loss: 4.18352 | Valid Loss: 4.24425 |Train Accs: 0.09999 | Valid Accs: 0.08850 | Time: 0.42 seconds
# Epoch: 240 | Train Loss: 4.18186 | Valid Loss: 4.24479 |Train Accs: 0.10036 | Valid Accs: 0.08796 | Time: 0.52 seconds
# Epoch: 241 | Train Loss: 4.18005 | Valid Loss: 4.24290 |Train Accs: 0.10208 | Valid Accs: 0.08893 | Time: 0.43 seconds
# Epoch: 242 | Train Loss: 4.17808 | Valid Loss: 4.24069 |Train Accs: 0.10181 | Valid Accs: 0.08980 | Time: 0.42 seconds
# Epoch: 243 | Train Loss: 4.17693 | Valid Loss: 4.23810 |Train Accs: 0.10198 | Valid Accs: 0.08893 | Time: 0.42 seconds
# Epoch: 244 | Train Loss: 4.17457 | Valid Loss: 4.23961 |Train Accs: 0.10250 | Valid Accs: 0.08980 | Time: 0.41 seconds
# Epoch: 245 | Train Loss: 4.17335 | Valid Loss: 4.23548 |Train Accs: 0.10284 | Valid Accs: 0.08958 | Time: 0.42 seconds
# Epoch: 246 | Train Loss: 4.17099 | Valid Loss: 4.23513 |Train Accs: 0.10425 | Valid Accs: 0.09023 | Time: 0.52 seconds
# Epoch: 247 | Train Loss: 4.16970 | Valid Loss: 4.23358 |Train Accs: 0.10358 | Valid Accs: 0.08904 | Time: 0.42 seconds
# Epoch: 248 | Train Loss: 4.16818 | Valid Loss: 4.23148 |Train Accs: 0.10512 | Valid Accs: 0.08926 | Time: 0.42 seconds
# Epoch: 249 | Train Loss: 4.16516 | Valid Loss: 4.22694 |Train Accs: 0.10454 | Valid Accs: 0.09099 | Time: 0.43 seconds
# Epoch: 250 | Train Loss: 4.16476 | Valid Loss: 4.22911 |Train Accs: 0.10387 | Valid Accs: 0.09056 | Time: 0.41 seconds
# Epoch: 251 | Train Loss: 4.16196 | Valid Loss: 4.22761 |Train Accs: 0.10587 | Valid Accs: 0.09099 | Time: 0.42 seconds
# Epoch: 252 | Train Loss: 4.16153 | Valid Loss: 4.22745 |Train Accs: 0.10580 | Valid Accs: 0.09143 | Time: 0.43 seconds
# Epoch: 253 | Train Loss: 4.15848 | Valid Loss: 4.22326 |Train Accs: 0.10516 | Valid Accs: 0.09338 | Time: 0.42 seconds
# Epoch: 254 | Train Loss: 4.15734 | Valid Loss: 4.22542 |Train Accs: 0.10726 | Valid Accs: 0.09154 | Time: 0.42 seconds
# Epoch: 255 | Train Loss: 4.15462 | Valid Loss: 4.22061 |Train Accs: 0.10656 | Valid Accs: 0.09208 | Time: 0.51 seconds
# Epoch: 256 | Train Loss: 4.15388 | Valid Loss: 4.22089 |Train Accs: 0.10734 | Valid Accs: 0.09349 | Time: 0.54 seconds
# Epoch: 257 | Train Loss: 4.15268 | Valid Loss: 4.21554 |Train Accs: 0.10739 | Valid Accs: 0.09479 | Time: 0.49 seconds
# Epoch: 258 | Train Loss: 4.15075 | Valid Loss: 4.21554 |Train Accs: 0.10640 | Valid Accs: 0.09382 | Time: 0.41 seconds
# Epoch: 259 | Train Loss: 4.14907 | Valid Loss: 4.21662 |Train Accs: 0.10888 | Valid Accs: 0.09414 | Time: 0.42 seconds
# Epoch: 260 | Train Loss: 4.14797 | Valid Loss: 4.21603 |Train Accs: 0.10720 | Valid Accs: 0.09403 | Time: 0.41 seconds
# Epoch: 261 | Train Loss: 4.14678 | Valid Loss: 4.21213 |Train Accs: 0.11012 | Valid Accs: 0.09544 | Time: 0.52 seconds
# Epoch: 262 | Train Loss: 4.14390 | Valid Loss: 4.21073 |Train Accs: 0.11051 | Valid Accs: 0.09501 | Time: 0.41 seconds
# Epoch: 263 | Train Loss: 4.14341 | Valid Loss: 4.20953 |Train Accs: 0.10996 | Valid Accs: 0.09685 | Time: 0.49 seconds
# Epoch: 264 | Train Loss: 4.14118 | Valid Loss: 4.20891 |Train Accs: 0.11066 | Valid Accs: 0.09685 | Time: 0.41 seconds
# Epoch: 265 | Train Loss: 4.13939 | Valid Loss: 4.20647 |Train Accs: 0.10900 | Valid Accs: 0.09588 | Time: 0.42 seconds
# Epoch: 266 | Train Loss: 4.13859 | Valid Loss: 4.20706 |Train Accs: 0.11073 | Valid Accs: 0.09663 | Time: 0.41 seconds
# Epoch: 267 | Train Loss: 4.13519 | Valid Loss: 4.20231 |Train Accs: 0.11126 | Valid Accs: 0.09837 | Time: 0.42 seconds
# Epoch: 268 | Train Loss: 4.13345 | Valid Loss: 4.20313 |Train Accs: 0.11176 | Valid Accs: 0.09663 | Time: 0.42 seconds
# Epoch: 269 | Train Loss: 4.13239 | Valid Loss: 4.20089 |Train Accs: 0.11207 | Valid Accs: 0.09783 | Time: 0.41 seconds
# Epoch: 270 | Train Loss: 4.13068 | Valid Loss: 4.19778 |Train Accs: 0.11290 | Valid Accs: 0.09837 | Time: 0.52 seconds
# Epoch: 271 | Train Loss: 4.12974 | Valid Loss: 4.19810 |Train Accs: 0.11258 | Valid Accs: 0.09815 | Time: 0.40 seconds
# Epoch: 272 | Train Loss: 4.12788 | Valid Loss: 4.19858 |Train Accs: 0.11297 | Valid Accs: 0.10021 | Time: 0.42 seconds
# Epoch: 273 | Train Loss: 4.12672 | Valid Loss: 4.19477 |Train Accs: 0.11321 | Valid Accs: 0.09934 | Time: 0.41 seconds
# Epoch: 274 | Train Loss: 4.12470 | Valid Loss: 4.19335 |Train Accs: 0.11275 | Valid Accs: 0.09913 | Time: 0.42 seconds
# Epoch: 275 | Train Loss: 4.12342 | Valid Loss: 4.18903 |Train Accs: 0.11439 | Valid Accs: 0.10000 | Time: 0.41 seconds
# Epoch: 276 | Train Loss: 4.12174 | Valid Loss: 4.19089 |Train Accs: 0.11457 | Valid Accs: 0.09891 | Time: 0.41 seconds
# Epoch: 277 | Train Loss: 4.11923 | Valid Loss: 4.18879 |Train Accs: 0.11555 | Valid Accs: 0.10054 | Time: 0.52 seconds
# Epoch: 278 | Train Loss: 4.11829 | Valid Loss: 4.18801 |Train Accs: 0.11449 | Valid Accs: 0.10097 | Time: 0.42 seconds
# Epoch: 279 | Train Loss: 4.11611 | Valid Loss: 4.18768 |Train Accs: 0.11622 | Valid Accs: 0.10021 | Time: 0.42 seconds
# Epoch: 280 | Train Loss: 4.11541 | Valid Loss: 4.18625 |Train Accs: 0.11689 | Valid Accs: 0.10021 | Time: 0.41 seconds
# Epoch: 281 | Train Loss: 4.11394 | Valid Loss: 4.18360 |Train Accs: 0.11562 | Valid Accs: 0.10130 | Time: 0.52 seconds
# Epoch: 282 | Train Loss: 4.11081 | Valid Loss: 4.17986 |Train Accs: 0.11652 | Valid Accs: 0.10162 | Time: 0.52 seconds
# Epoch: 283 | Train Loss: 4.11082 | Valid Loss: 4.18080 |Train Accs: 0.11698 | Valid Accs: 0.10249 | Time: 0.41 seconds
# Epoch: 284 | Train Loss: 4.10922 | Valid Loss: 4.18115 |Train Accs: 0.11723 | Valid Accs: 0.10227 | Time: 0.41 seconds
# Epoch: 285 | Train Loss: 4.10683 | Valid Loss: 4.18151 |Train Accs: 0.11860 | Valid Accs: 0.10347 | Time: 0.50 seconds
# Epoch: 286 | Train Loss: 4.10580 | Valid Loss: 4.17811 |Train Accs: 0.11910 | Valid Accs: 0.10379 | Time: 0.41 seconds
# Epoch: 287 | Train Loss: 4.10359 | Valid Loss: 4.17669 |Train Accs: 0.11764 | Valid Accs: 0.10271 | Time: 0.41 seconds
# Epoch: 288 | Train Loss: 4.10249 | Valid Loss: 4.17320 |Train Accs: 0.11965 | Valid Accs: 0.10401 | Time: 0.41 seconds
# Epoch: 289 | Train Loss: 4.10090 | Valid Loss: 4.17173 |Train Accs: 0.11927 | Valid Accs: 0.10423 | Time: 0.41 seconds
# Epoch: 290 | Train Loss: 4.09883 | Valid Loss: 4.16983 |Train Accs: 0.11948 | Valid Accs: 0.10444 | Time: 0.41 seconds
# Epoch: 291 | Train Loss: 4.09729 | Valid Loss: 4.16894 |Train Accs: 0.11901 | Valid Accs: 0.10575 | Time: 0.52 seconds
# Epoch: 292 | Train Loss: 4.09541 | Valid Loss: 4.17048 |Train Accs: 0.12021 | Valid Accs: 0.10629 | Time: 0.41 seconds
# Epoch: 293 | Train Loss: 4.09518 | Valid Loss: 4.16946 |Train Accs: 0.12097 | Valid Accs: 0.10629 | Time: 0.41 seconds
# Epoch: 294 | Train Loss: 4.09282 | Valid Loss: 4.16675 |Train Accs: 0.12127 | Valid Accs: 0.10596 | Time: 0.41 seconds
# Epoch: 295 | Train Loss: 4.09188 | Valid Loss: 4.16510 |Train Accs: 0.12102 | Valid Accs: 0.10531 | Time: 0.42 seconds
# Epoch: 296 | Train Loss: 4.08942 | Valid Loss: 4.16138 |Train Accs: 0.12154 | Valid Accs: 0.10618 | Time: 0.41 seconds
# Epoch: 297 | Train Loss: 4.08708 | Valid Loss: 4.16502 |Train Accs: 0.12268 | Valid Accs: 0.10683 | Time: 0.52 seconds
# Epoch: 298 | Train Loss: 4.08714 | Valid Loss: 4.16305 |Train Accs: 0.12156 | Valid Accs: 0.10715 | Time: 0.65 seconds
# Epoch: 299 | Train Loss: 4.08488 | Valid Loss: 4.15861 |Train Accs: 0.12128 | Valid Accs: 0.10683 | Time: 0.46 seconds
# Epoch: 300 | Train Loss: 4.08304 | Valid Loss: 4.15950 |Train Accs: 0.12404 | Valid Accs: 0.10759 | Time: 0.52 seconds
# Epoch: 301 | Train Loss: 4.08142 | Valid Loss: 4.15749 |Train Accs: 0.12327 | Valid Accs: 0.10759 | Time: 0.42 seconds
# Epoch: 302 | Train Loss: 4.07954 | Valid Loss: 4.15360 |Train Accs: 0.12328 | Valid Accs: 0.10824 | Time: 0.42 seconds
# Epoch: 303 | Train Loss: 4.07786 | Valid Loss: 4.15350 |Train Accs: 0.12300 | Valid Accs: 0.10932 | Time: 0.42 seconds
# Epoch: 304 | Train Loss: 4.07666 | Valid Loss: 4.15219 |Train Accs: 0.12487 | Valid Accs: 0.10781 | Time: 0.41 seconds
# Epoch: 305 | Train Loss: 4.07502 | Valid Loss: 4.15029 |Train Accs: 0.12442 | Valid Accs: 0.10932 | Time: 0.42 seconds
# Epoch: 306 | Train Loss: 4.07457 | Valid Loss: 4.14871 |Train Accs: 0.12587 | Valid Accs: 0.10911 | Time: 0.73 seconds
# Epoch: 307 | Train Loss: 4.07164 | Valid Loss: 4.15082 |Train Accs: 0.12597 | Valid Accs: 0.10932 | Time: 0.41 seconds
# Epoch: 308 | Train Loss: 4.07161 | Valid Loss: 4.14765 |Train Accs: 0.12615 | Valid Accs: 0.10976 | Time: 0.41 seconds
# Epoch: 309 | Train Loss: 4.06901 | Valid Loss: 4.14591 |Train Accs: 0.12649 | Valid Accs: 0.11019 | Time: 0.41 seconds
# Epoch: 310 | Train Loss: 4.06794 | Valid Loss: 4.14580 |Train Accs: 0.12646 | Valid Accs: 0.11019 | Time: 0.41 seconds
# Epoch: 311 | Train Loss: 4.06615 | Valid Loss: 4.14149 |Train Accs: 0.12724 | Valid Accs: 0.11041 | Time: 0.42 seconds
# Epoch: 312 | Train Loss: 4.06514 | Valid Loss: 4.13922 |Train Accs: 0.12657 | Valid Accs: 0.11084 | Time: 0.41 seconds
# Epoch: 313 | Train Loss: 4.06251 | Valid Loss: 4.14297 |Train Accs: 0.12813 | Valid Accs: 0.11149 | Time: 0.41 seconds
# Epoch: 314 | Train Loss: 4.06219 | Valid Loss: 4.14032 |Train Accs: 0.12824 | Valid Accs: 0.11128 | Time: 0.41 seconds
# Epoch: 315 | Train Loss: 4.05964 | Valid Loss: 4.13633 |Train Accs: 0.12926 | Valid Accs: 0.11149 | Time: 0.51 seconds
# Epoch: 316 | Train Loss: 4.05830 | Valid Loss: 4.13658 |Train Accs: 0.12825 | Valid Accs: 0.11171 | Time: 0.41 seconds
# Epoch: 317 | Train Loss: 4.05837 | Valid Loss: 4.13373 |Train Accs: 0.12995 | Valid Accs: 0.11193 | Time: 0.42 seconds
# Epoch: 318 | Train Loss: 4.05589 | Valid Loss: 4.13808 |Train Accs: 0.12988 | Valid Accs: 0.11193 | Time: 0.41 seconds
# Epoch: 319 | Train Loss: 4.05455 | Valid Loss: 4.13075 |Train Accs: 0.12864 | Valid Accs: 0.11258 | Time: 0.41 seconds
# Epoch: 320 | Train Loss: 4.05259 | Valid Loss: 4.13489 |Train Accs: 0.13136 | Valid Accs: 0.11149 | Time: 0.41 seconds
# Epoch: 321 | Train Loss: 4.05187 | Valid Loss: 4.13204 |Train Accs: 0.13042 | Valid Accs: 0.11236 | Time: 0.41 seconds
# Epoch: 322 | Train Loss: 4.04979 | Valid Loss: 4.12680 |Train Accs: 0.13128 | Valid Accs: 0.11269 | Time: 0.51 seconds
# Epoch: 323 | Train Loss: 4.04818 | Valid Loss: 4.12915 |Train Accs: 0.13134 | Valid Accs: 0.11312 | Time: 0.41 seconds
# Epoch: 324 | Train Loss: 4.04649 | Valid Loss: 4.12786 |Train Accs: 0.13070 | Valid Accs: 0.11269 | Time: 0.41 seconds
# Epoch: 325 | Train Loss: 4.04593 | Valid Loss: 4.12439 |Train Accs: 0.13260 | Valid Accs: 0.11323 | Time: 0.41 seconds
# Epoch: 326 | Train Loss: 4.04384 | Valid Loss: 4.12677 |Train Accs: 0.13153 | Valid Accs: 0.11258 | Time: 0.41 seconds
# Epoch: 327 | Train Loss: 4.04154 | Valid Loss: 4.12268 |Train Accs: 0.13296 | Valid Accs: 0.11334 | Time: 0.41 seconds
# Epoch: 328 | Train Loss: 4.04054 | Valid Loss: 4.12112 |Train Accs: 0.13248 | Valid Accs: 0.11323 | Time: 0.41 seconds
# Epoch: 329 | Train Loss: 4.04053 | Valid Loss: 4.12034 |Train Accs: 0.13262 | Valid Accs: 0.11399 | Time: 0.41 seconds
# Epoch: 330 | Train Loss: 4.03775 | Valid Loss: 4.11854 |Train Accs: 0.13443 | Valid Accs: 0.11355 | Time: 0.51 seconds
# Epoch: 331 | Train Loss: 4.03639 | Valid Loss: 4.11992 |Train Accs: 0.13581 | Valid Accs: 0.11442 | Time: 0.62 seconds
# Epoch: 332 | Train Loss: 4.03579 | Valid Loss: 4.11476 |Train Accs: 0.13299 | Valid Accs: 0.11507 | Time: 0.50 seconds
# Epoch: 333 | Train Loss: 4.03343 | Valid Loss: 4.11759 |Train Accs: 0.13429 | Valid Accs: 0.11464 | Time: 0.43 seconds
# Epoch: 334 | Train Loss: 4.03215 | Valid Loss: 4.11494 |Train Accs: 0.13411 | Valid Accs: 0.11583 | Time: 0.41 seconds
# Epoch: 335 | Train Loss: 4.03180 | Valid Loss: 4.11357 |Train Accs: 0.13355 | Valid Accs: 0.11507 | Time: 0.41 seconds
# Epoch: 336 | Train Loss: 4.02853 | Valid Loss: 4.10968 |Train Accs: 0.13458 | Valid Accs: 0.11583 | Time: 0.51 seconds
# Epoch: 337 | Train Loss: 4.02679 | Valid Loss: 4.11056 |Train Accs: 0.13595 | Valid Accs: 0.11453 | Time: 0.41 seconds
# Epoch: 338 | Train Loss: 4.02608 | Valid Loss: 4.10786 |Train Accs: 0.13471 | Valid Accs: 0.11529 | Time: 0.41 seconds
# Epoch: 339 | Train Loss: 4.02408 | Valid Loss: 4.10710 |Train Accs: 0.13691 | Valid Accs: 0.11550 | Time: 0.43 seconds
# Epoch: 340 | Train Loss: 4.02299 | Valid Loss: 4.10817 |Train Accs: 0.13844 | Valid Accs: 0.11561 | Time: 0.41 seconds
# Epoch: 341 | Train Loss: 4.02173 | Valid Loss: 4.10849 |Train Accs: 0.13650 | Valid Accs: 0.11670 | Time: 0.41 seconds
# Epoch: 342 | Train Loss: 4.02034 | Valid Loss: 4.10359 |Train Accs: 0.13798 | Valid Accs: 0.11648 | Time: 0.41 seconds
# Epoch: 343 | Train Loss: 4.01971 | Valid Loss: 4.10317 |Train Accs: 0.13704 | Valid Accs: 0.11648 | Time: 0.41 seconds
# Epoch: 344 | Train Loss: 4.01805 | Valid Loss: 4.10354 |Train Accs: 0.13754 | Valid Accs: 0.11692 | Time: 0.40 seconds
# Epoch: 345 | Train Loss: 4.01589 | Valid Loss: 4.09760 |Train Accs: 0.13800 | Valid Accs: 0.11681 | Time: 0.52 seconds
# Epoch: 346 | Train Loss: 4.01555 | Valid Loss: 4.10101 |Train Accs: 0.13788 | Valid Accs: 0.11789 | Time: 0.41 seconds
# Epoch: 347 | Train Loss: 4.01441 | Valid Loss: 4.09473 |Train Accs: 0.14029 | Valid Accs: 0.11767 | Time: 0.42 seconds
# Epoch: 348 | Train Loss: 4.01178 | Valid Loss: 4.09746 |Train Accs: 0.13979 | Valid Accs: 0.11789 | Time: 0.41 seconds
# Epoch: 349 | Train Loss: 4.00989 | Valid Loss: 4.09734 |Train Accs: 0.14020 | Valid Accs: 0.11800 | Time: 0.41 seconds
# Epoch: 350 | Train Loss: 4.00972 | Valid Loss: 4.09634 |Train Accs: 0.13849 | Valid Accs: 0.11898 | Time: 0.42 seconds
# Epoch: 351 | Train Loss: 4.00767 | Valid Loss: 4.09501 |Train Accs: 0.14011 | Valid Accs: 0.11844 | Time: 0.51 seconds
# Epoch: 352 | Train Loss: 4.00664 | Valid Loss: 4.09095 |Train Accs: 0.14103 | Valid Accs: 0.12039 | Time: 0.41 seconds
# Epoch: 353 | Train Loss: 4.00434 | Valid Loss: 4.09093 |Train Accs: 0.14016 | Valid Accs: 0.11984 | Time: 0.42 seconds
# Epoch: 354 | Train Loss: 4.00271 | Valid Loss: 4.08806 |Train Accs: 0.14234 | Valid Accs: 0.12006 | Time: 0.41 seconds
# Epoch: 355 | Train Loss: 4.00362 | Valid Loss: 4.08966 |Train Accs: 0.14107 | Valid Accs: 0.11995 | Time: 0.41 seconds
# Epoch: 356 | Train Loss: 4.00153 | Valid Loss: 4.08807 |Train Accs: 0.14154 | Valid Accs: 0.12104 | Time: 0.58 seconds
# Epoch: 357 | Train Loss: 3.99902 | Valid Loss: 4.08810 |Train Accs: 0.14085 | Valid Accs: 0.12179 | Time: 0.47 seconds
# Epoch: 358 | Train Loss: 3.99734 | Valid Loss: 4.08351 |Train Accs: 0.14255 | Valid Accs: 0.12114 | Time: 0.41 seconds
# Epoch: 359 | Train Loss: 3.99640 | Valid Loss: 4.08138 |Train Accs: 0.14312 | Valid Accs: 0.12093 | Time: 0.41 seconds
# Epoch: 360 | Train Loss: 3.99531 | Valid Loss: 4.08176 |Train Accs: 0.14207 | Valid Accs: 0.12245 | Time: 0.50 seconds
# Epoch: 361 | Train Loss: 3.99349 | Valid Loss: 4.08045 |Train Accs: 0.14328 | Valid Accs: 0.12266 | Time: 0.42 seconds
# Epoch: 362 | Train Loss: 3.99169 | Valid Loss: 4.08090 |Train Accs: 0.14541 | Valid Accs: 0.12245 | Time: 0.44 seconds
# Epoch: 363 | Train Loss: 3.99089 | Valid Loss: 4.07846 |Train Accs: 0.14407 | Valid Accs: 0.12179 | Time: 0.42 seconds
# Epoch: 364 | Train Loss: 3.98883 | Valid Loss: 4.07213 |Train Accs: 0.14520 | Valid Accs: 0.12310 | Time: 0.41 seconds
# Epoch: 365 | Train Loss: 3.98818 | Valid Loss: 4.07286 |Train Accs: 0.14392 | Valid Accs: 0.12223 | Time: 0.42 seconds
# Epoch: 366 | Train Loss: 3.98605 | Valid Loss: 4.07372 |Train Accs: 0.14360 | Valid Accs: 0.12342 | Time: 0.41 seconds
# Epoch: 367 | Train Loss: 3.98422 | Valid Loss: 4.07320 |Train Accs: 0.14522 | Valid Accs: 0.12320 | Time: 0.51 seconds
# Epoch: 368 | Train Loss: 3.98388 | Valid Loss: 4.07127 |Train Accs: 0.14469 | Valid Accs: 0.12364 | Time: 0.41 seconds
# Epoch: 369 | Train Loss: 3.98258 | Valid Loss: 4.06908 |Train Accs: 0.14568 | Valid Accs: 0.12299 | Time: 0.45 seconds
# Epoch: 370 | Train Loss: 3.98086 | Valid Loss: 4.06828 |Train Accs: 0.14745 | Valid Accs: 0.12537 | Time: 0.43 seconds
# Epoch: 371 | Train Loss: 3.98085 | Valid Loss: 4.06828 |Train Accs: 0.14571 | Valid Accs: 0.12483 | Time: 0.41 seconds
# Epoch: 372 | Train Loss: 3.97945 | Valid Loss: 4.07039 |Train Accs: 0.14618 | Valid Accs: 0.12494 | Time: 0.61 seconds
# Epoch: 373 | Train Loss: 3.97609 | Valid Loss: 4.06365 |Train Accs: 0.14739 | Valid Accs: 0.12375 | Time: 0.63 seconds
# Epoch: 374 | Train Loss: 3.97589 | Valid Loss: 4.06691 |Train Accs: 0.14699 | Valid Accs: 0.12581 | Time: 0.41 seconds
# Epoch: 375 | Train Loss: 3.97432 | Valid Loss: 4.06866 |Train Accs: 0.14733 | Valid Accs: 0.12711 | Time: 0.51 seconds
# Epoch: 376 | Train Loss: 3.97217 | Valid Loss: 4.06244 |Train Accs: 0.14771 | Valid Accs: 0.12516 | Time: 0.42 seconds
# Epoch: 377 | Train Loss: 3.97164 | Valid Loss: 4.06244 |Train Accs: 0.14787 | Valid Accs: 0.12635 | Time: 0.41 seconds
# Epoch: 378 | Train Loss: 3.96988 | Valid Loss: 4.05946 |Train Accs: 0.15047 | Valid Accs: 0.12602 | Time: 0.42 seconds
# Epoch: 379 | Train Loss: 3.96886 | Valid Loss: 4.05721 |Train Accs: 0.14985 | Valid Accs: 0.12635 | Time: 0.42 seconds
# Epoch: 380 | Train Loss: 3.96839 | Valid Loss: 4.05799 |Train Accs: 0.14967 | Valid Accs: 0.12700 | Time: 0.55 seconds
# Epoch: 381 | Train Loss: 3.96594 | Valid Loss: 4.05627 |Train Accs: 0.15024 | Valid Accs: 0.12722 | Time: 0.60 seconds
# Epoch: 382 | Train Loss: 3.96480 | Valid Loss: 4.06020 |Train Accs: 0.15014 | Valid Accs: 0.12602 | Time: 0.41 seconds
# Epoch: 383 | Train Loss: 3.96332 | Valid Loss: 4.05583 |Train Accs: 0.14967 | Valid Accs: 0.12711 | Time: 0.42 seconds
# Epoch: 384 | Train Loss: 3.96255 | Valid Loss: 4.05552 |Train Accs: 0.14987 | Valid Accs: 0.12689 | Time: 0.42 seconds
# Epoch: 385 | Train Loss: 3.96029 | Valid Loss: 4.05256 |Train Accs: 0.15090 | Valid Accs: 0.12743 | Time: 0.41 seconds
# Epoch: 386 | Train Loss: 3.95961 | Valid Loss: 4.05333 |Train Accs: 0.15179 | Valid Accs: 0.12787 | Time: 0.45 seconds
# Epoch: 387 | Train Loss: 3.95826 | Valid Loss: 4.04918 |Train Accs: 0.15167 | Valid Accs: 0.12787 | Time: 0.42 seconds
# Epoch: 388 | Train Loss: 3.95770 | Valid Loss: 4.05056 |Train Accs: 0.15151 | Valid Accs: 0.12863 | Time: 0.41 seconds
# Epoch: 389 | Train Loss: 3.95589 | Valid Loss: 4.04778 |Train Accs: 0.15229 | Valid Accs: 0.12787 | Time: 0.41 seconds
# Epoch: 390 | Train Loss: 3.95383 | Valid Loss: 4.04784 |Train Accs: 0.15346 | Valid Accs: 0.12928 | Time: 0.52 seconds
# Epoch: 391 | Train Loss: 3.95260 | Valid Loss: 4.04706 |Train Accs: 0.15321 | Valid Accs: 0.12928 | Time: 0.42 seconds
# Epoch: 392 | Train Loss: 3.94995 | Valid Loss: 4.04173 |Train Accs: 0.15277 | Valid Accs: 0.12874 | Time: 0.41 seconds
# Epoch: 393 | Train Loss: 3.94945 | Valid Loss: 4.04140 |Train Accs: 0.15423 | Valid Accs: 0.12993 | Time: 0.41 seconds
# Epoch: 394 | Train Loss: 3.94913 | Valid Loss: 4.04070 |Train Accs: 0.15285 | Valid Accs: 0.13101 | Time: 0.41 seconds
# Epoch: 395 | Train Loss: 3.94713 | Valid Loss: 4.03924 |Train Accs: 0.15384 | Valid Accs: 0.12982 | Time: 0.41 seconds
# Epoch: 396 | Train Loss: 3.94693 | Valid Loss: 4.03747 |Train Accs: 0.15558 | Valid Accs: 0.12885 | Time: 0.51 seconds
# Epoch: 397 | Train Loss: 3.94311 | Valid Loss: 4.03886 |Train Accs: 0.15516 | Valid Accs: 0.13080 | Time: 0.41 seconds
# Epoch: 398 | Train Loss: 3.94307 | Valid Loss: 4.03572 |Train Accs: 0.15491 | Valid Accs: 0.13134 | Time: 0.41 seconds
# Epoch: 399 | Train Loss: 3.94219 | Valid Loss: 4.03363 |Train Accs: 0.15586 | Valid Accs: 0.13026 | Time: 0.41 seconds
# Epoch: 400 | Train Loss: 3.94132 | Valid Loss: 4.03716 |Train Accs: 0.15649 | Valid Accs: 0.13123 | Time: 0.41 seconds
# Epoch: 401 | Train Loss: 3.93919 | Valid Loss: 4.03250 |Train Accs: 0.15652 | Valid Accs: 0.13091 | Time: 0.50 seconds
# Epoch: 402 | Train Loss: 3.93780 | Valid Loss: 4.02757 |Train Accs: 0.15605 | Valid Accs: 0.13177 | Time: 0.42 seconds
# Epoch: 403 | Train Loss: 3.93672 | Valid Loss: 4.03302 |Train Accs: 0.15654 | Valid Accs: 0.13123 | Time: 0.42 seconds
# ...
# Epoch: 4403 | Train Loss: 2.42957 | Valid Loss: 2.88041 |Train Accs: 0.50178 | Valid Accs: 0.35203 | Time: 0.42 seconds
# Epoch: 4404 | Train Loss: 2.42782 | Valid Loss: 2.88372 |Train Accs: 0.50342 | Valid Accs: 0.35290 | Time: 0.42 seconds
# Epoch: 4405 | Train Loss: 2.42857 | Valid Loss: 2.88149 |Train Accs: 0.50156 | Valid Accs: 0.35355 | Time: 0.42 seconds
# Epoch: 4406 | Train Loss: 2.42821 | Valid Loss: 2.88560 |Train Accs: 0.50447 | Valid Accs: 0.35214 | Time: 0.41 seconds
# Epoch: 4407 | Train Loss: 2.42904 | Valid Loss: 2.88168 |Train Accs: 0.50287 | Valid Accs: 0.35203 | Time: 0.42 seconds
# Epoch: 4408 | Train Loss: 2.42901 | Valid Loss: 2.89034 |Train Accs: 0.50105 | Valid Accs: 0.35366 | Time: 0.41 seconds
# Epoch: 4409 | Train Loss: 2.42802 | Valid Loss: 2.88663 |Train Accs: 0.50345 | Valid Accs: 0.35496 | Time: 0.53 seconds
# Epoch: 4410 | Train Loss: 2.42831 | Valid Loss: 2.88070 |Train Accs: 0.50242 | Valid Accs: 0.35453 | Time: 0.42 seconds
# Epoch: 4411 | Train Loss: 2.42859 | Valid Loss: 2.88848 |Train Accs: 0.50366 | Valid Accs: 0.35409 | Time: 0.43 seconds
# Epoch: 4412 | Train Loss: 2.42709 | Valid Loss: 2.88865 |Train Accs: 0.50316 | Valid Accs: 0.35279 | Time: 0.42 seconds
# Epoch: 4413 | Train Loss: 2.42725 | Valid Loss: 2.88590 |Train Accs: 0.50377 | Valid Accs: 0.35387 | Time: 0.42 seconds
# Epoch: 4414 | Train Loss: 2.42819 | Valid Loss: 2.88356 |Train Accs: 0.50322 | Valid Accs: 0.35431 | Time: 0.42 seconds
# Epoch: 4415 | Train Loss: 2.42917 | Valid Loss: 2.89693 |Train Accs: 0.50134 | Valid Accs: 0.35366 | Time: 0.43 seconds
# Epoch: 4416 | Train Loss: 2.42763 | Valid Loss: 2.89713 |Train Accs: 0.50286 | Valid Accs: 0.35377 | Time: 0.53 seconds
# Epoch: 4417 | Train Loss: 2.42672 | Valid Loss: 2.88487 |Train Accs: 0.50230 | Valid Accs: 0.35333 | Time: 0.42 seconds
# Epoch: 4418 | Train Loss: 2.42656 | Valid Loss: 2.88859 |Train Accs: 0.50390 | Valid Accs: 0.35409 | Time: 0.42 seconds
# Epoch: 4419 | Train Loss: 2.42698 | Valid Loss: 2.89069 |Train Accs: 0.50304 | Valid Accs: 0.35366 | Time: 0.42 seconds
# Epoch: 4420 | Train Loss: 2.42682 | Valid Loss: 2.88355 |Train Accs: 0.50383 | Valid Accs: 0.35290 | Time: 0.42 seconds
# Epoch: 4421 | Train Loss: 2.42773 | Valid Loss: 2.88675 |Train Accs: 0.50139 | Valid Accs: 0.35431 | Time: 0.42 seconds
# Epoch: 4422 | Train Loss: 2.42797 | Valid Loss: 2.89375 |Train Accs: 0.50304 | Valid Accs: 0.35453 | Time: 0.49 seconds
# Epoch: 4423 | Train Loss: 2.42639 | Valid Loss: 2.88726 |Train Accs: 0.50280 | Valid Accs: 0.35442 | Time: 0.62 seconds
# Epoch: 4424 | Train Loss: 2.42651 | Valid Loss: 2.88207 |Train Accs: 0.50135 | Valid Accs: 0.35366 | Time: 0.89 seconds
# Epoch: 4425 | Train Loss: 2.42830 | Valid Loss: 2.89131 |Train Accs: 0.50244 | Valid Accs: 0.35442 | Time: 0.42 seconds
# Epoch: 4426 | Train Loss: 2.42543 | Valid Loss: 2.88845 |Train Accs: 0.50295 | Valid Accs: 0.35323 | Time: 0.42 seconds
# Epoch: 4427 | Train Loss: 2.42672 | Valid Loss: 2.89155 |Train Accs: 0.50382 | Valid Accs: 0.35257 | Time: 0.42 seconds
# Epoch: 4428 | Train Loss: 2.42484 | Valid Loss: 2.88876 |Train Accs: 0.50094 | Valid Accs: 0.35279 | Time: 0.42 seconds
# Epoch: 4429 | Train Loss: 2.42638 | Valid Loss: 2.89412 |Train Accs: 0.50248 | Valid Accs: 0.35366 | Time: 0.42 seconds
# Epoch: 4430 | Train Loss: 2.42607 | Valid Loss: 2.88329 |Train Accs: 0.50366 | Valid Accs: 0.35485 | Time: 0.52 seconds
# Epoch: 4431 | Train Loss: 2.42645 | Valid Loss: 2.88280 |Train Accs: 0.50319 | Valid Accs: 0.35290 | Time: 0.42 seconds
# Epoch: 4432 | Train Loss: 2.42594 | Valid Loss: 2.88283 |Train Accs: 0.50307 | Valid Accs: 0.35323 | Time: 0.42 seconds
# Epoch: 4433 | Train Loss: 2.42455 | Valid Loss: 2.87727 |Train Accs: 0.50352 | Valid Accs: 0.35355 | Time: 0.42 seconds
# Epoch: 4434 | Train Loss: 2.42566 | Valid Loss: 2.88158 |Train Accs: 0.50415 | Valid Accs: 0.35355 | Time: 0.42 seconds
# Epoch: 4435 | Train Loss: 2.42335 | Valid Loss: 2.87547 |Train Accs: 0.50313 | Valid Accs: 0.35333 | Time: 0.42 seconds
# Epoch: 4436 | Train Loss: 2.42441 | Valid Loss: 2.88376 |Train Accs: 0.50277 | Valid Accs: 0.35420 | Time: 0.44 seconds
# Epoch: 4437 | Train Loss: 2.42537 | Valid Loss: 2.88739 |Train Accs: 0.50320 | Valid Accs: 0.35420 | Time: 0.42 seconds
# Epoch: 4438 | Train Loss: 2.42371 | Valid Loss: 2.88609 |Train Accs: 0.50195 | Valid Accs: 0.35474 | Time: 0.43 seconds
# Epoch: 4439 | Train Loss: 2.42420 | Valid Loss: 2.88960 |Train Accs: 0.50335 | Valid Accs: 0.35323 | Time: 0.51 seconds
# Epoch: 4440 | Train Loss: 2.42483 | Valid Loss: 2.88950 |Train Accs: 0.50364 | Valid Accs: 0.35398 | Time: 0.43 seconds
# Epoch: 4441 | Train Loss: 2.42435 | Valid Loss: 2.89507 |Train Accs: 0.50268 | Valid Accs: 0.35344 | Time: 0.42 seconds
# Epoch: 4442 | Train Loss: 2.42408 | Valid Loss: 2.88571 |Train Accs: 0.50149 | Valid Accs: 0.35409 | Time: 0.42 seconds
# Epoch: 4443 | Train Loss: 2.42351 | Valid Loss: 2.88316 |Train Accs: 0.50290 | Valid Accs: 0.35388 | Time: 0.43 seconds
# Epoch: 4444 | Train Loss: 2.42498 | Valid Loss: 2.88729 |Train Accs: 0.50426 | Valid Accs: 0.35594 | Time: 0.44 seconds
# Epoch: 4445 | Train Loss: 2.42341 | Valid Loss: 2.88631 |Train Accs: 0.50666 | Valid Accs: 0.35453 | Time: 0.53 seconds
# Epoch: 4446 | Train Loss: 2.42438 | Valid Loss: 2.88908 |Train Accs: 0.50423 | Valid Accs: 0.35442 | Time: 0.42 seconds
# Epoch: 4447 | Train Loss: 2.42306 | Valid Loss: 2.88821 |Train Accs: 0.50052 | Valid Accs: 0.35442 | Time: 0.42 seconds
# Epoch: 4448 | Train Loss: 2.42511 | Valid Loss: 2.89305 |Train Accs: 0.50300 | Valid Accs: 0.35355 | Time: 0.53 seconds
# Epoch: 4449 | Train Loss: 2.42294 | Valid Loss: 2.87734 |Train Accs: 0.50219 | Valid Accs: 0.35496 | Time: 0.52 seconds
# Epoch: 4450 | Train Loss: 2.42363 | Valid Loss: 2.89134 |Train Accs: 0.50207 | Valid Accs: 0.35594 | Time: 0.42 seconds
# Epoch: 4451 | Train Loss: 2.42342 | Valid Loss: 2.89476 |Train Accs: 0.50273 | Valid Accs: 0.35388 | Time: 0.42 seconds
# Epoch: 4452 | Train Loss: 2.42147 | Valid Loss: 2.87638 |Train Accs: 0.50275 | Valid Accs: 0.35463 | Time: 0.42 seconds
# Epoch: 4453 | Train Loss: 2.42368 | Valid Loss: 2.88393 |Train Accs: 0.50369 | Valid Accs: 0.35496 | Time: 0.42 seconds
# Epoch: 4454 | Train Loss: 2.42194 | Valid Loss: 2.88935 |Train Accs: 0.50481 | Valid Accs: 0.35583 | Time: 0.52 seconds
# Epoch: 4455 | Train Loss: 2.42247 | Valid Loss: 2.88447 |Train Accs: 0.50310 | Valid Accs: 0.35496 | Time: 0.45 seconds
# Epoch: 4456 | Train Loss: 2.42326 | Valid Loss: 2.88960 |Train Accs: 0.50456 | Valid Accs: 0.35572 | Time: 0.41 seconds
# Epoch: 4457 | Train Loss: 2.42255 | Valid Loss: 2.87548 |Train Accs: 0.50390 | Valid Accs: 0.35366 | Time: 0.43 seconds
# Epoch: 4458 | Train Loss: 2.42260 | Valid Loss: 2.87812 |Train Accs: 0.50310 | Valid Accs: 0.35409 | Time: 0.42 seconds
# Epoch: 4459 | Train Loss: 2.42129 | Valid Loss: 2.88839 |Train Accs: 0.50476 | Valid Accs: 0.35485 | Time: 0.43 seconds
# Epoch: 4460 | Train Loss: 2.42084 | Valid Loss: 2.88270 |Train Accs: 0.50353 | Valid Accs: 0.35388 | Time: 0.42 seconds
# Epoch: 4461 | Train Loss: 2.42166 | Valid Loss: 2.88385 |Train Accs: 0.50536 | Valid Accs: 0.35507 | Time: 0.52 seconds
# Epoch: 4462 | Train Loss: 2.42284 | Valid Loss: 2.87962 |Train Accs: 0.50172 | Valid Accs: 0.35431 | Time: 0.41 seconds
# Epoch: 4463 | Train Loss: 2.42126 | Valid Loss: 2.88137 |Train Accs: 0.50291 | Valid Accs: 0.35333 | Time: 0.42 seconds
# Epoch: 4464 | Train Loss: 2.42318 | Valid Loss: 2.88496 |Train Accs: 0.50400 | Valid Accs: 0.35409 | Time: 0.42 seconds
# Epoch: 4465 | Train Loss: 2.42068 | Valid Loss: 2.88176 |Train Accs: 0.50468 | Valid Accs: 0.35485 | Time: 0.41 seconds
# Epoch: 4466 | Train Loss: 2.42139 | Valid Loss: 2.88404 |Train Accs: 0.50375 | Valid Accs: 0.35453 | Time: 0.41 seconds
# Epoch: 4467 | Train Loss: 2.42073 | Valid Loss: 2.87801 |Train Accs: 0.50339 | Valid Accs: 0.35312 | Time: 0.42 seconds
# Epoch: 4468 | Train Loss: 2.42161 | Valid Loss: 2.87739 |Train Accs: 0.50467 | Valid Accs: 0.35474 | Time: 0.42 seconds
# Epoch: 4469 | Train Loss: 2.42131 | Valid Loss: 2.89357 |Train Accs: 0.50478 | Valid Accs: 0.35279 | Time: 0.52 seconds
# Epoch: 4470 | Train Loss: 2.42178 | Valid Loss: 2.89277 |Train Accs: 0.50412 | Valid Accs: 0.35258 | Time: 0.42 seconds
# Epoch: 4471 | Train Loss: 2.42064 | Valid Loss: 2.87841 |Train Accs: 0.50380 | Valid Accs: 0.35507 | Time: 0.41 seconds
# Epoch: 4472 | Train Loss: 2.42159 | Valid Loss: 2.88223 |Train Accs: 0.50412 | Valid Accs: 0.35572 | Time: 0.41 seconds
# Epoch: 4473 | Train Loss: 2.42088 | Valid Loss: 2.87556 |Train Accs: 0.50277 | Valid Accs: 0.35485 | Time: 0.53 seconds
# Epoch: 4474 | Train Loss: 2.41943 | Valid Loss: 2.87728 |Train Accs: 0.50410 | Valid Accs: 0.35377 | Time: 0.52 seconds
# Epoch: 4475 | Train Loss: 2.41832 | Valid Loss: 2.88130 |Train Accs: 0.50602 | Valid Accs: 0.35464 | Time: 0.53 seconds
# Epoch: 4476 | Train Loss: 2.41951 | Valid Loss: 2.88403 |Train Accs: 0.50511 | Valid Accs: 0.35540 | Time: 0.43 seconds
# Epoch: 4477 | Train Loss: 2.42021 | Valid Loss: 2.87947 |Train Accs: 0.50517 | Valid Accs: 0.35453 | Time: 0.41 seconds
# Epoch: 4478 | Train Loss: 2.41904 | Valid Loss: 2.88069 |Train Accs: 0.50630 | Valid Accs: 0.35485 | Time: 0.41 seconds
# Epoch: 4479 | Train Loss: 2.42106 | Valid Loss: 2.87998 |Train Accs: 0.50370 | Valid Accs: 0.35388 | Time: 0.42 seconds
# Epoch: 4480 | Train Loss: 2.41932 | Valid Loss: 2.87584 |Train Accs: 0.50457 | Valid Accs: 0.35453 | Time: 0.43 seconds
# Epoch: 4481 | Train Loss: 2.41952 | Valid Loss: 2.87038 |Train Accs: 0.50443 | Valid Accs: 0.35539 | Time: 0.42 seconds
# Epoch: 4482 | Train Loss: 2.42011 | Valid Loss: 2.88612 |Train Accs: 0.50469 | Valid Accs: 0.35464 | Time: 0.45 seconds
# Epoch: 4483 | Train Loss: 2.41851 | Valid Loss: 2.87502 |Train Accs: 0.50382 | Valid Accs: 0.35463 | Time: 0.42 seconds
# Epoch: 4484 | Train Loss: 2.41959 | Valid Loss: 2.87891 |Train Accs: 0.50351 | Valid Accs: 0.35442 | Time: 0.52 seconds
# Epoch: 4485 | Train Loss: 2.41833 | Valid Loss: 2.87390 |Train Accs: 0.50502 | Valid Accs: 0.35637 | Time: 0.41 seconds
# Epoch: 4486 | Train Loss: 2.41973 | Valid Loss: 2.87861 |Train Accs: 0.50264 | Valid Accs: 0.35442 | Time: 0.41 seconds
# Epoch: 4487 | Train Loss: 2.41788 | Valid Loss: 2.88253 |Train Accs: 0.50509 | Valid Accs: 0.35431 | Time: 0.42 seconds
# Epoch: 4488 | Train Loss: 2.41838 | Valid Loss: 2.87875 |Train Accs: 0.50395 | Valid Accs: 0.35550 | Time: 0.42 seconds
# Epoch: 4489 | Train Loss: 2.41788 | Valid Loss: 2.87525 |Train Accs: 0.50580 | Valid Accs: 0.35518 | Time: 0.44 seconds
# Epoch: 4490 | Train Loss: 2.41985 | Valid Loss: 2.88229 |Train Accs: 0.50214 | Valid Accs: 0.35507 | Time: 0.53 seconds
# Epoch: 4491 | Train Loss: 2.41768 | Valid Loss: 2.87648 |Train Accs: 0.50168 | Valid Accs: 0.35529 | Time: 0.42 seconds
# Epoch: 4492 | Train Loss: 2.41852 | Valid Loss: 2.88893 |Train Accs: 0.50414 | Valid Accs: 0.35485 | Time: 0.41 seconds
# Epoch: 4493 | Train Loss: 2.41793 | Valid Loss: 2.87616 |Train Accs: 0.50640 | Valid Accs: 0.35463 | Time: 0.42 seconds
# Epoch: 4494 | Train Loss: 2.41831 | Valid Loss: 2.87601 |Train Accs: 0.50543 | Valid Accs: 0.35409 | Time: 0.46 seconds
# Epoch: 4495 | Train Loss: 2.41745 | Valid Loss: 2.87713 |Train Accs: 0.50640 | Valid Accs: 0.35583 | Time: 0.63 seconds
# Epoch: 4496 | Train Loss: 2.41647 | Valid Loss: 2.87798 |Train Accs: 0.50523 | Valid Accs: 0.35388 | Time: 0.59 seconds
# Epoch: 4497 | Train Loss: 2.41817 | Valid Loss: 2.87918 |Train Accs: 0.50438 | Valid Accs: 0.35735 | Time: 0.59 seconds
# Epoch: 4498 | Train Loss: 2.41747 | Valid Loss: 2.88057 |Train Accs: 0.50518 | Valid Accs: 0.35453 | Time: 0.48 seconds
# Epoch: 4499 | Train Loss: 2.41620 | Valid Loss: 2.88286 |Train Accs: 0.50586 | Valid Accs: 0.35485 | Time: 0.53 seconds
# Epoch: 4500 | Train Loss: 2.41676 | Valid Loss: 2.87700 |Train Accs: 0.50563 | Valid Accs: 0.35518 | Time: 0.42 seconds
# Epoch: 4501 | Train Loss: 2.41697 | Valid Loss: 2.88238 |Train Accs: 0.50345 | Valid Accs: 0.35594 | Time: 0.41 seconds
# Epoch: 4502 | Train Loss: 2.41727 | Valid Loss: 2.87704 |Train Accs: 0.50554 | Valid Accs: 0.35409 | Time: 0.42 seconds
# Epoch: 4503 | Train Loss: 2.41597 | Valid Loss: 2.87145 |Train Accs: 0.50517 | Valid Accs: 0.35496 | Time: 0.43 seconds
# Epoch: 4504 | Train Loss: 2.41661 | Valid Loss: 2.87302 |Train Accs: 0.50459 | Valid Accs: 0.35702 | Time: 0.42 seconds
# Epoch: 4505 | Train Loss: 2.41613 | Valid Loss: 2.87640 |Train Accs: 0.50567 | Valid Accs: 0.35464 | Time: 0.42 seconds
# Epoch: 4506 | Train Loss: 2.41374 | Valid Loss: 2.88144 |Train Accs: 0.50487 | Valid Accs: 0.35615 | Time: 0.76 seconds
# Epoch: 4507 | Train Loss: 2.41609 | Valid Loss: 2.87630 |Train Accs: 0.50525 | Valid Accs: 0.35496 | Time: 0.64 seconds
# Epoch: 4508 | Train Loss: 2.41774 | Valid Loss: 2.87708 |Train Accs: 0.50541 | Valid Accs: 0.35333 | Time: 0.64 seconds
# Epoch: 4509 | Train Loss: 2.41598 | Valid Loss: 2.88214 |Train Accs: 0.50638 | Valid Accs: 0.35496 | Time: 0.66 seconds
# Epoch: 4510 | Train Loss: 2.41559 | Valid Loss: 2.87841 |Train Accs: 0.50588 | Valid Accs: 0.35626 | Time: 0.64 seconds
# Epoch: 4511 | Train Loss: 2.41372 | Valid Loss: 2.87143 |Train Accs: 0.50754 | Valid Accs: 0.35507 | Time: 0.64 seconds
# Epoch: 4512 | Train Loss: 2.41528 | Valid Loss: 2.87566 |Train Accs: 0.50585 | Valid Accs: 0.35539 | Time: 0.66 seconds
# Epoch: 4513 | Train Loss: 2.41575 | Valid Loss: 2.87089 |Train Accs: 0.50386 | Valid Accs: 0.35474 | Time: 0.64 seconds
# Epoch: 4514 | Train Loss: 2.41582 | Valid Loss: 2.87297 |Train Accs: 0.50516 | Valid Accs: 0.35615 | Time: 0.78 seconds
# Epoch: 4515 | Train Loss: 2.41458 | Valid Loss: 2.87394 |Train Accs: 0.50490 | Valid Accs: 0.35464 | Time: 0.64 seconds
# Epoch: 4516 | Train Loss: 2.41563 | Valid Loss: 2.87361 |Train Accs: 0.50496 | Valid Accs: 0.35485 | Time: 0.80 seconds
# Epoch: 4517 | Train Loss: 2.41310 | Valid Loss: 2.87955 |Train Accs: 0.50736 | Valid Accs: 0.35496 | Time: 0.79 seconds
# Epoch: 4518 | Train Loss: 2.41455 | Valid Loss: 2.88345 |Train Accs: 0.50450 | Valid Accs: 0.35247 | Time: 0.64 seconds
# Epoch: 4519 | Train Loss: 2.41484 | Valid Loss: 2.88104 |Train Accs: 0.50626 | Valid Accs: 0.35485 | Time: 0.57 seconds
# Epoch: 4520 | Train Loss: 2.41455 | Valid Loss: 2.88046 |Train Accs: 0.50534 | Valid Accs: 0.35550 | Time: 0.52 seconds
# Epoch: 4521 | Train Loss: 2.41529 | Valid Loss: 2.87650 |Train Accs: 0.50706 | Valid Accs: 0.35518 | Time: 0.42 seconds
# Epoch: 4522 | Train Loss: 2.41444 | Valid Loss: 2.87496 |Train Accs: 0.50727 | Valid Accs: 0.35529 | Time: 0.42 seconds
# Epoch: 4523 | Train Loss: 2.41465 | Valid Loss: 2.87338 |Train Accs: 0.50569 | Valid Accs: 0.35399 | Time: 0.41 seconds
# Epoch: 4524 | Train Loss: 2.41352 | Valid Loss: 2.87836 |Train Accs: 0.50636 | Valid Accs: 0.35507 | Time: 0.42 seconds
# Epoch: 4525 | Train Loss: 2.41580 | Valid Loss: 2.87978 |Train Accs: 0.50643 | Valid Accs: 0.35463 | Time: 0.42 seconds
# Epoch: 4526 | Train Loss: 2.41564 | Valid Loss: 2.87935 |Train Accs: 0.50482 | Valid Accs: 0.35691 | Time: 0.42 seconds
# Epoch: 4527 | Train Loss: 2.41554 | Valid Loss: 2.87828 |Train Accs: 0.50603 | Valid Accs: 0.35637 | Time: 0.42 seconds
# Epoch: 4528 | Train Loss: 2.41346 | Valid Loss: 2.87061 |Train Accs: 0.50571 | Valid Accs: 0.35463 | Time: 0.41 seconds
# Epoch: 4529 | Train Loss: 2.41441 | Valid Loss: 2.88017 |Train Accs: 0.50476 | Valid Accs: 0.35409 | Time: 0.52 seconds
# Epoch: 4530 | Train Loss: 2.41328 | Valid Loss: 2.87665 |Train Accs: 0.50453 | Valid Accs: 0.35626 | Time: 0.42 seconds
# Epoch: 4531 | Train Loss: 2.41295 | Valid Loss: 2.87358 |Train Accs: 0.50715 | Valid Accs: 0.35539 | Time: 0.43 seconds
#
# Early Stopping at Epoch 4532
#
# **************************************************
#
# Best Validation Loss at Epoch 4481
#
# **************************************************
#
# Best Validation Accs at Epoch 4497
#
# **************************************************
#
# Time Taken [4532 Epochs] : 35.57 minutes
#
# **************************************************
# **************************************************
#
# Total Time Taken for 5-Fold CV : 133.19 minutes
#
# **************************************************

# %% [markdown]
# ### **Get SWIN Features for the Test Set**

# %%
# train_df = pd.read_csv("../input/sorghum-id-fgvc-9/train_cultivar_mapping.csv")
# ss_df = pd.read_csv("../input/sorghum-id-fgvc-9/sample_submission.csv")

# broken_images = [filename for filename in train_df.image if filename not in os.listdir("../input/sorghum-id-fgvc-9/train_images")]
# for broken_image in broken_images:
#     index = train_df.index[train_df.image == broken_image]
#     train_df = train_df.drop(index=index)
    
# filenames = train_df.image.copy().values
# labels    = train_df.cultivar.copy().values 

# labels = le.fit_transform(labels)

# ts_filenames = ss_df.filename.copy().values
# ts_features = np.zeros((len(ts_filenames), 1024))

# %%
# model = timm.create_model("swin_base_patch4_window7_224_in22k", pretrained=True).to(DEVICE)
# model = torch.nn.Sequential(*[*model.children()][:-3])

# dataloader_setup = FEDS("../input/sorghum-id-fgvc-9/test", ts_filenames, TRANSFORM)
# dataloader = DL(dataloader_setup, batch_size=64, shuffle=False)

# ts_features = torch.zeros(1, 1024).to(DEVICE)

# for X in dataloader:
#     X = X.to(DEVICE)
#     with torch.no_grad():
#         output = model(X).last_hidden_state
#     ts_features = torch.cat((ts_features, output[:, 0, :]), dim=0)

# ts_features = ts_features[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Submission**

# %%
# ts_data_setup = DS(ts_features, None, "test")
# ts_data = DL(ts_data_setup, batch_size=batch_size, shuffle=False)

# torch.manual_seed(SEED)
# model = Model(IL=ts_features.shape[1], HL=HL, DP=0.25, use_WN=True).to(DEVICE)

# best_model_fold = _____
# y_pred = predict(model=model, dataloader=ts_data, path=os.path.join(CLASSIFIER_HEAD_PATH, f"state_fold_{best_model_fold}.pt"))

# ss_df["cultivar"] = le.inverse_transform(y_pred.astype("uint8"))
# ss_df.to_csv("submission.csv", index=False)
