# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
import torch
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torch.nn.utils import weight_norm as WN

from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Constants**

# %%
SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

FEATURE_PATH = "../input/fgvc9-swinb22422k"

SAVE_PATH = "saves"
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# %%
def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def show_graphs(L: list, A: list) -> None:
    TL, VL, TA, VA = [], [], [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()

# %% [markdown]
# ### **Dataset Templatea**

# %%
class FEDS(Dataset):
    def __init__(self, base_path: str, filenames: np.ndarray, transform):
        self.base_path = base_path
        self.filenames = filenames
        self.transform = transform
    
    def __len__(self):
        return self.filenames.shape[0]
    
    def __getitem__(self, idx):
        return self.transform(get_image(os.path.join(self.base_path, self.filenames[idx])))


class DS(Dataset):
    def __init__(self, X=None, y=None, mode="train"):
        self.mode = mode

        assert(re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE) or re.match(r"test", self.mode, re.IGNORECASE))

        self.X = X
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            self.y = y
    
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            return torch.FloatTensor(self.X[idx]), torch.LongTensor(self.y[idx])
        else:
            return torch.FloatTensor(self.X[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, IL: int=None, HL: list=None, DP: float=None, use_WN: bool=False):
        super(Model, self).__init__()

        self.model = nn.Sequential()

        if len(HL) == 1:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=100)))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=100))

        
        elif len(HL) == 2:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=100)))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=100))
        
        elif len(HL) == 3:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=HL[2])))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=HL[2]))
            if isinstance(DP, float):
                self.model.add_module("DP3", nn.Dropout(p=DP))
            self.model.add_module("AN3", nn.ReLU())
            self.model.add_module("BN4", nn.BatchNorm1d(num_features=HL[2], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC4", WN(nn.Linear(in_features=HL[2], out_features=100)))
            else:
                self.model.add_module("FC4", nn.Linear(in_features=HL[2], out_features=100))
    
    def get_optimizer(self, lr=1e-3, wd=0.0):
        return optim.Adam(self.parameters(), lr=lr, weight_decay=wd)

    def get_plateau_scheduler(self, optimizer=None, patience=5, eps=1e-8):
        return optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, patience=patience, eps=eps)
    
    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helper**

# %%
def fit(model=None, optimizer=None, scheduler=None, epochs=None, early_stopping_patience=None, dataloaders=None, fold=None, verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        print(f"Training Fold {fold}...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies = [], []
    name = f"state_fold_{fold}.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []
            
            for X, y in dataloaders[phase]:
                X, y = X.to(DEVICE), y.to(DEVICE).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict": model.state_dict(),
                            "optim_state_dict": optimizer.state_dict()},
                           os.path.join(SAVE_PATH, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save({"model_state_dict" : model.state_dict(),
                        "optim_state_dict" : optimizer.state_dict()},
                        os.path.join(SAVE_PATH, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler:
            scheduler.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, BLE, BAE, name


# def predict(model=None, dataloader=None, path=None) -> np.ndarray:
#     model.load_state_dict(torch.load(path, map_location=DEVICE)["model_state_dict"])
#     model.to(DEVICE)    
#     model.eval()
    
#     y_pred = torch.zeros(1, 1).to(DEVICE)
    
#     for X in dataloader:
#         X = X.to(DEVICE)
#         with torch.no_grad():
#             output = torch.argmax(torch.exp(model(X)), dim=1)
#         y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
#     return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Load Data**

# %%
features = np.load(os.path.join(FEATURE_PATH, "features.npy"))
labels   = np.load(os.path.join(FEATURE_PATH, "labels.npy"))

# %% [markdown]
# ### **Params**

# %%
DEBUG: bool = False
    
if DEBUG:
    n_splits = 3
    epochs = 2
    HL = [4]
else:
    n_splits = 5
    epochs = 5000
    HL = [1024, 512]

batch_size = 512
lr = 1e-6
wd = 1e-5
early_stopping = 50
patience = None
eps = None

# %% [markdown]
# ### **Train**

# %%
fold = 1

start_time = time()
for tr_idx, va_idx in StratifiedKFold(n_splits=n_splits, random_state=SEED, shuffle=True).split(features, labels):
    tr_features, va_features, tr_labels, va_labels = features[tr_idx], features[va_idx], labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(tr_features, tr_labels.reshape(-1, 1), "train")
    va_data_setup = DS(va_features, va_labels.reshape(-1, 1), "valid")

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=batch_size, shuffle=True, generator=torch.manual_seed(SEED)),
        "valid" : DL(va_data_setup, batch_size=batch_size, shuffle=False),
    }

    torch.manual_seed(SEED)
    model = Model(IL=tr_features.shape[1], HL=HL, DP=0.25, use_WN=True).to(DEVICE)
    optimizer = model.get_optimizer(lr=lr, wd=wd)
    scheduler = None
    if isinstance(patience, int) and isinstance(eps, float):
        scheduler = get_plateau_scheduler(optimizer=optimizer, patience=patience, eps=eps)
    
    L, A, BLE, BAE, name = fit(model=model, optimizer=optimizer, scheduler=scheduler, 
                           epochs=epochs, early_stopping_patience=early_stopping, 
                           dataloaders=dataloaders, fold=fold, verbose=True)

    breaker()
    show_graphs(L, A)
    fold += 1

breaker()
print(f"Total Time Taken for {n_splits}-Fold CV : {(time()-start_time)/60:.2f} minutes")
breaker()
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.76608 | Valid Loss: 4.65671 |Train Accs: 0.00878 | Valid Accs: 0.00889 | Time: 1.49 seconds
# Epoch: 2 | Train Loss: 4.75600 | Valid Loss: 4.67259 |Train Accs: 0.00985 | Valid Accs: 0.00954 | Time: 0.48 seconds
# Epoch: 3 | Train Loss: 4.75638 | Valid Loss: 4.66821 |Train Accs: 0.01113 | Valid Accs: 0.00987 | Time: 0.50 seconds
# Epoch: 4 | Train Loss: 4.74807 | Valid Loss: 4.66512 |Train Accs: 0.01163 | Valid Accs: 0.01128 | Time: 0.52 seconds
# Epoch: 5 | Train Loss: 4.73739 | Valid Loss: 4.66046 |Train Accs: 0.01214 | Valid Accs: 0.01106 | Time: 0.47 seconds
# Epoch: 6 | Train Loss: 4.72847 | Valid Loss: 4.65433 |Train Accs: 0.01177 | Valid Accs: 0.01215 | Time: 0.71 seconds
# Epoch: 7 | Train Loss: 4.72591 | Valid Loss: 4.64939 |Train Accs: 0.01406 | Valid Accs: 0.01280 | Time: 0.70 seconds
# Epoch: 8 | Train Loss: 4.72020 | Valid Loss: 4.64283 |Train Accs: 0.01135 | Valid Accs: 0.01410 | Time: 0.53 seconds
# Epoch: 9 | Train Loss: 4.71055 | Valid Loss: 4.63992 |Train Accs: 0.01294 | Valid Accs: 0.01562 | Time: 0.51 seconds
# Epoch: 10 | Train Loss: 4.71069 | Valid Loss: 4.63473 |Train Accs: 0.01453 | Valid Accs: 0.01529 | Time: 0.51 seconds
# Epoch: 11 | Train Loss: 4.70737 | Valid Loss: 4.63049 |Train Accs: 0.01350 | Valid Accs: 0.01659 | Time: 0.51 seconds
# Epoch: 12 | Train Loss: 4.69767 | Valid Loss: 4.62582 |Train Accs: 0.01288 | Valid Accs: 0.01735 | Time: 0.51 seconds
# Epoch: 13 | Train Loss: 4.69233 | Valid Loss: 4.61932 |Train Accs: 0.01403 | Valid Accs: 0.01757 | Time: 0.55 seconds
# Epoch: 14 | Train Loss: 4.68315 | Valid Loss: 4.61594 |Train Accs: 0.01721 | Valid Accs: 0.01768 | Time: 0.54 seconds
# Epoch: 15 | Train Loss: 4.68170 | Valid Loss: 4.61231 |Train Accs: 0.01545 | Valid Accs: 0.01898 | Time: 0.54 seconds
# Epoch: 16 | Train Loss: 4.67403 | Valid Loss: 4.60599 |Train Accs: 0.01793 | Valid Accs: 0.02017 | Time: 0.61 seconds
# Epoch: 17 | Train Loss: 4.66901 | Valid Loss: 4.60185 |Train Accs: 0.01526 | Valid Accs: 0.02180 | Time: 0.54 seconds
# Epoch: 18 | Train Loss: 4.66314 | Valid Loss: 4.59775 |Train Accs: 0.01818 | Valid Accs: 0.02245 | Time: 0.53 seconds
# Epoch: 19 | Train Loss: 4.65729 | Valid Loss: 4.59367 |Train Accs: 0.01855 | Valid Accs: 0.02386 | Time: 0.53 seconds
# Epoch: 20 | Train Loss: 4.65907 | Valid Loss: 4.58879 |Train Accs: 0.01785 | Valid Accs: 0.02462 | Time: 0.51 seconds
# Epoch: 21 | Train Loss: 4.64726 | Valid Loss: 4.58410 |Train Accs: 0.01941 | Valid Accs: 0.02440 | Time: 0.52 seconds
# Epoch: 22 | Train Loss: 4.64026 | Valid Loss: 4.57951 |Train Accs: 0.02055 | Valid Accs: 0.02571 | Time: 0.62 seconds
# Epoch: 23 | Train Loss: 4.63123 | Valid Loss: 4.57413 |Train Accs: 0.02150 | Valid Accs: 0.02722 | Time: 0.52 seconds
# Epoch: 24 | Train Loss: 4.62982 | Valid Loss: 4.57098 |Train Accs: 0.02240 | Valid Accs: 0.02690 | Time: 0.53 seconds
# Epoch: 25 | Train Loss: 4.62630 | Valid Loss: 4.56589 |Train Accs: 0.02089 | Valid Accs: 0.02820 | Time: 0.54 seconds
# Epoch: 26 | Train Loss: 4.62052 | Valid Loss: 4.56174 |Train Accs: 0.02304 | Valid Accs: 0.02907 | Time: 0.72 seconds
# Epoch: 27 | Train Loss: 4.61642 | Valid Loss: 4.55751 |Train Accs: 0.02385 | Valid Accs: 0.02972 | Time: 0.60 seconds
# Epoch: 28 | Train Loss: 4.60838 | Valid Loss: 4.55326 |Train Accs: 0.02368 | Valid Accs: 0.03037 | Time: 0.53 seconds
# Epoch: 29 | Train Loss: 4.60762 | Valid Loss: 4.54863 |Train Accs: 0.02343 | Valid Accs: 0.03134 | Time: 0.52 seconds
# Epoch: 30 | Train Loss: 4.59915 | Valid Loss: 4.54468 |Train Accs: 0.02560 | Valid Accs: 0.03329 | Time: 0.52 seconds
# Epoch: 31 | Train Loss: 4.59238 | Valid Loss: 4.53894 |Train Accs: 0.02521 | Valid Accs: 0.03265 | Time: 0.62 seconds
# Epoch: 32 | Train Loss: 4.59281 | Valid Loss: 4.53585 |Train Accs: 0.02591 | Valid Accs: 0.03395 | Time: 0.51 seconds
# Epoch: 33 | Train Loss: 4.58387 | Valid Loss: 4.53086 |Train Accs: 0.02717 | Valid Accs: 0.03362 | Time: 0.52 seconds
# Epoch: 34 | Train Loss: 4.57868 | Valid Loss: 4.52704 |Train Accs: 0.02773 | Valid Accs: 0.03449 | Time: 0.54 seconds
# Epoch: 35 | Train Loss: 4.56657 | Valid Loss: 4.52162 |Train Accs: 0.02867 | Valid Accs: 0.03525 | Time: 0.53 seconds
# Epoch: 36 | Train Loss: 4.57300 | Valid Loss: 4.51850 |Train Accs: 0.02889 | Valid Accs: 0.03579 | Time: 0.53 seconds
# Epoch: 37 | Train Loss: 4.55686 | Valid Loss: 4.51367 |Train Accs: 0.02948 | Valid Accs: 0.03720 | Time: 0.67 seconds
# Epoch: 38 | Train Loss: 4.55775 | Valid Loss: 4.50912 |Train Accs: 0.03001 | Valid Accs: 0.03818 | Time: 0.52 seconds
# Epoch: 39 | Train Loss: 4.55500 | Valid Loss: 4.50429 |Train Accs: 0.03118 | Valid Accs: 0.04078 | Time: 0.73 seconds
# Epoch: 40 | Train Loss: 4.54705 | Valid Loss: 4.50055 |Train Accs: 0.03252 | Valid Accs: 0.04002 | Time: 0.69 seconds
# Epoch: 41 | Train Loss: 4.54346 | Valid Loss: 4.49664 |Train Accs: 0.03246 | Valid Accs: 0.04002 | Time: 0.51 seconds
# Epoch: 42 | Train Loss: 4.53194 | Valid Loss: 4.49170 |Train Accs: 0.03353 | Valid Accs: 0.04186 | Time: 0.51 seconds
# Epoch: 43 | Train Loss: 4.53418 | Valid Loss: 4.48786 |Train Accs: 0.03491 | Valid Accs: 0.04262 | Time: 0.52 seconds
# Epoch: 44 | Train Loss: 4.52075 | Valid Loss: 4.48345 |Train Accs: 0.03448 | Valid Accs: 0.04403 | Time: 0.52 seconds
# Epoch: 45 | Train Loss: 4.52679 | Valid Loss: 4.47930 |Train Accs: 0.03512 | Valid Accs: 0.04696 | Time: 0.72 seconds
# Epoch: 46 | Train Loss: 4.51255 | Valid Loss: 4.47503 |Train Accs: 0.03662 | Valid Accs: 0.04533 | Time: 0.63 seconds
# Epoch: 47 | Train Loss: 4.50777 | Valid Loss: 4.47048 |Train Accs: 0.03899 | Valid Accs: 0.04826 | Time: 0.51 seconds
# Epoch: 48 | Train Loss: 4.50629 | Valid Loss: 4.46632 |Train Accs: 0.03919 | Valid Accs: 0.04891 | Time: 0.53 seconds
# Epoch: 49 | Train Loss: 4.50194 | Valid Loss: 4.46246 |Train Accs: 0.04058 | Valid Accs: 0.04815 | Time: 0.52 seconds
# Epoch: 50 | Train Loss: 4.49408 | Valid Loss: 4.45785 |Train Accs: 0.04020 | Valid Accs: 0.04999 | Time: 0.52 seconds
# Epoch: 51 | Train Loss: 4.48548 | Valid Loss: 4.45337 |Train Accs: 0.04183 | Valid Accs: 0.04880 | Time: 0.52 seconds
# Epoch: 52 | Train Loss: 4.48156 | Valid Loss: 4.45003 |Train Accs: 0.04021 | Valid Accs: 0.05206 | Time: 0.61 seconds
# Epoch: 53 | Train Loss: 4.48064 | Valid Loss: 4.44631 |Train Accs: 0.03751 | Valid Accs: 0.05228 | Time: 0.51 seconds
# Epoch: 54 | Train Loss: 4.47476 | Valid Loss: 4.44129 |Train Accs: 0.04259 | Valid Accs: 0.05293 | Time: 0.52 seconds
# Epoch: 55 | Train Loss: 4.46431 | Valid Loss: 4.43734 |Train Accs: 0.04558 | Valid Accs: 0.05455 | Time: 0.52 seconds
# Epoch: 56 | Train Loss: 4.46982 | Valid Loss: 4.43296 |Train Accs: 0.04303 | Valid Accs: 0.05651 | Time: 0.63 seconds
# Epoch: 57 | Train Loss: 4.45741 | Valid Loss: 4.42822 |Train Accs: 0.04689 | Valid Accs: 0.05629 | Time: 0.56 seconds
# Epoch: 58 | Train Loss: 4.45397 | Valid Loss: 4.42332 |Train Accs: 0.04750 | Valid Accs: 0.05716 | Time: 0.53 seconds
# Epoch: 59 | Train Loss: 4.45342 | Valid Loss: 4.41989 |Train Accs: 0.04371 | Valid Accs: 0.05933 | Time: 0.53 seconds
# Epoch: 60 | Train Loss: 4.44584 | Valid Loss: 4.41687 |Train Accs: 0.04738 | Valid Accs: 0.05943 | Time: 0.62 seconds
# Epoch: 61 | Train Loss: 4.44207 | Valid Loss: 4.41149 |Train Accs: 0.04377 | Valid Accs: 0.06052 | Time: 0.51 seconds
# Epoch: 62 | Train Loss: 4.42974 | Valid Loss: 4.40833 |Train Accs: 0.04788 | Valid Accs: 0.06193 | Time: 0.52 seconds
# Epoch: 63 | Train Loss: 4.43162 | Valid Loss: 4.40415 |Train Accs: 0.04965 | Valid Accs: 0.06182 | Time: 0.51 seconds
# Epoch: 64 | Train Loss: 4.41959 | Valid Loss: 4.39994 |Train Accs: 0.05031 | Valid Accs: 0.06388 | Time: 0.51 seconds
# Epoch: 65 | Train Loss: 4.42009 | Valid Loss: 4.39568 |Train Accs: 0.05175 | Valid Accs: 0.06377 | Time: 0.63 seconds
# Epoch: 66 | Train Loss: 4.40719 | Valid Loss: 4.39212 |Train Accs: 0.05282 | Valid Accs: 0.06464 | Time: 0.66 seconds
# Epoch: 67 | Train Loss: 4.41591 | Valid Loss: 4.38823 |Train Accs: 0.05251 | Valid Accs: 0.06497 | Time: 0.62 seconds
# Epoch: 68 | Train Loss: 4.40315 | Valid Loss: 4.38359 |Train Accs: 0.05230 | Valid Accs: 0.06703 | Time: 0.53 seconds
# Epoch: 69 | Train Loss: 4.40194 | Valid Loss: 4.38057 |Train Accs: 0.05282 | Valid Accs: 0.06681 | Time: 0.53 seconds
# Epoch: 70 | Train Loss: 4.39820 | Valid Loss: 4.37552 |Train Accs: 0.05267 | Valid Accs: 0.06789 | Time: 0.52 seconds
# Epoch: 71 | Train Loss: 4.38756 | Valid Loss: 4.37222 |Train Accs: 0.05406 | Valid Accs: 0.06735 | Time: 0.52 seconds
# Epoch: 72 | Train Loss: 4.37926 | Valid Loss: 4.36683 |Train Accs: 0.05805 | Valid Accs: 0.06898 | Time: 0.55 seconds
# Epoch: 73 | Train Loss: 4.37879 | Valid Loss: 4.36291 |Train Accs: 0.05590 | Valid Accs: 0.06985 | Time: 0.52 seconds
# Epoch: 74 | Train Loss: 4.37543 | Valid Loss: 4.35838 |Train Accs: 0.05739 | Valid Accs: 0.07049 | Time: 0.56 seconds
# Epoch: 75 | Train Loss: 4.37084 | Valid Loss: 4.35624 |Train Accs: 0.05661 | Valid Accs: 0.07093 | Time: 0.66 seconds
# Epoch: 76 | Train Loss: 4.36876 | Valid Loss: 4.35173 |Train Accs: 0.05884 | Valid Accs: 0.07180 | Time: 0.53 seconds
# Epoch: 77 | Train Loss: 4.35619 | Valid Loss: 4.34844 |Train Accs: 0.06036 | Valid Accs: 0.07245 | Time: 0.52 seconds
# Epoch: 78 | Train Loss: 4.36031 | Valid Loss: 4.34481 |Train Accs: 0.06180 | Valid Accs: 0.07440 | Time: 0.52 seconds
# Epoch: 79 | Train Loss: 4.35278 | Valid Loss: 4.34000 |Train Accs: 0.06150 | Valid Accs: 0.07527 | Time: 0.52 seconds
# Epoch: 80 | Train Loss: 4.34874 | Valid Loss: 4.33684 |Train Accs: 0.06248 | Valid Accs: 0.07484 | Time: 0.52 seconds
# Epoch: 81 | Train Loss: 4.34541 | Valid Loss: 4.33266 |Train Accs: 0.06365 | Valid Accs: 0.07560 | Time: 0.62 seconds
# Epoch: 82 | Train Loss: 4.34065 | Valid Loss: 4.32857 |Train Accs: 0.06198 | Valid Accs: 0.07776 | Time: 0.52 seconds
# Epoch: 83 | Train Loss: 4.33618 | Valid Loss: 4.32539 |Train Accs: 0.06166 | Valid Accs: 0.07950 | Time: 0.52 seconds
# Epoch: 84 | Train Loss: 4.32824 | Valid Loss: 4.32014 |Train Accs: 0.06515 | Valid Accs: 0.07906 | Time: 0.52 seconds
# Epoch: 85 | Train Loss: 4.33076 | Valid Loss: 4.31823 |Train Accs: 0.06520 | Valid Accs: 0.08036 | Time: 0.71 seconds
# Epoch: 86 | Train Loss: 4.32078 | Valid Loss: 4.31291 |Train Accs: 0.06571 | Valid Accs: 0.08167 | Time: 0.59 seconds
# Epoch: 87 | Train Loss: 4.31953 | Valid Loss: 4.31001 |Train Accs: 0.06470 | Valid Accs: 0.08210 | Time: 0.51 seconds
# Epoch: 88 | Train Loss: 4.31333 | Valid Loss: 4.30678 |Train Accs: 0.06607 | Valid Accs: 0.08372 | Time: 0.51 seconds
# Epoch: 89 | Train Loss: 4.30920 | Valid Loss: 4.30270 |Train Accs: 0.06891 | Valid Accs: 0.08242 | Time: 0.51 seconds
# Epoch: 90 | Train Loss: 4.30526 | Valid Loss: 4.29911 |Train Accs: 0.07032 | Valid Accs: 0.08297 | Time: 0.63 seconds
# Epoch: 91 | Train Loss: 4.29803 | Valid Loss: 4.29366 |Train Accs: 0.06841 | Valid Accs: 0.08351 | Time: 0.51 seconds
# Epoch: 92 | Train Loss: 4.29764 | Valid Loss: 4.29126 |Train Accs: 0.07075 | Valid Accs: 0.08676 | Time: 0.51 seconds
# Epoch: 93 | Train Loss: 4.28926 | Valid Loss: 4.28812 |Train Accs: 0.07215 | Valid Accs: 0.08665 | Time: 0.54 seconds
# Epoch: 94 | Train Loss: 4.29136 | Valid Loss: 4.28447 |Train Accs: 0.06783 | Valid Accs: 0.08513 | Time: 0.58 seconds
# Epoch: 95 | Train Loss: 4.28144 | Valid Loss: 4.27975 |Train Accs: 0.07497 | Valid Accs: 0.08730 | Time: 0.53 seconds
# Epoch: 96 | Train Loss: 4.27416 | Valid Loss: 4.27584 |Train Accs: 0.07230 | Valid Accs: 0.08698 | Time: 0.73 seconds
# Epoch: 97 | Train Loss: 4.27777 | Valid Loss: 4.27275 |Train Accs: 0.07340 | Valid Accs: 0.08871 | Time: 0.80 seconds
# Epoch: 98 | Train Loss: 4.26573 | Valid Loss: 4.26763 |Train Accs: 0.07712 | Valid Accs: 0.08980 | Time: 0.52 seconds
# Epoch: 99 | Train Loss: 4.26588 | Valid Loss: 4.26759 |Train Accs: 0.07593 | Valid Accs: 0.08665 | Time: 0.52 seconds
# Epoch: 100 | Train Loss: 4.26756 | Valid Loss: 4.26130 |Train Accs: 0.07733 | Valid Accs: 0.09153 | Time: 0.51 seconds
# Epoch: 101 | Train Loss: 4.25836 | Valid Loss: 4.25650 |Train Accs: 0.07616 | Valid Accs: 0.09153 | Time: 0.51 seconds
# Epoch: 102 | Train Loss: 4.24551 | Valid Loss: 4.25518 |Train Accs: 0.08250 | Valid Accs: 0.09099 | Time: 0.51 seconds
# Epoch: 103 | Train Loss: 4.24444 | Valid Loss: 4.25065 |Train Accs: 0.07868 | Valid Accs: 0.09294 | Time: 0.56 seconds
# Epoch: 104 | Train Loss: 4.24538 | Valid Loss: 4.24637 |Train Accs: 0.08054 | Valid Accs: 0.09359 | Time: 0.58 seconds
# Epoch: 105 | Train Loss: 4.23747 | Valid Loss: 4.24408 |Train Accs: 0.08197 | Valid Accs: 0.09609 | Time: 0.77 seconds
# Epoch: 106 | Train Loss: 4.23365 | Valid Loss: 4.23903 |Train Accs: 0.08242 | Valid Accs: 0.09555 | Time: 0.52 seconds
# Epoch: 107 | Train Loss: 4.23380 | Valid Loss: 4.23521 |Train Accs: 0.08055 | Valid Accs: 0.09533 | Time: 0.53 seconds
# Epoch: 108 | Train Loss: 4.22797 | Valid Loss: 4.23326 |Train Accs: 0.08356 | Valid Accs: 0.09478 | Time: 0.54 seconds
# Epoch: 109 | Train Loss: 4.21838 | Valid Loss: 4.22864 |Train Accs: 0.08608 | Valid Accs: 0.09695 | Time: 0.52 seconds
# Epoch: 110 | Train Loss: 4.21617 | Valid Loss: 4.22739 |Train Accs: 0.08632 | Valid Accs: 0.09858 | Time: 0.52 seconds
# Epoch: 111 | Train Loss: 4.21429 | Valid Loss: 4.22235 |Train Accs: 0.08755 | Valid Accs: 0.09847 | Time: 0.63 seconds
# Epoch: 112 | Train Loss: 4.21316 | Valid Loss: 4.22019 |Train Accs: 0.08591 | Valid Accs: 0.10010 | Time: 0.56 seconds
# Epoch: 113 | Train Loss: 4.20804 | Valid Loss: 4.21678 |Train Accs: 0.08978 | Valid Accs: 0.10064 | Time: 0.53 seconds
# Epoch: 114 | Train Loss: 4.19966 | Valid Loss: 4.21217 |Train Accs: 0.08618 | Valid Accs: 0.10324 | Time: 0.52 seconds
# Epoch: 115 | Train Loss: 4.20179 | Valid Loss: 4.21019 |Train Accs: 0.08763 | Valid Accs: 0.10227 | Time: 0.52 seconds
# Epoch: 116 | Train Loss: 4.19426 | Valid Loss: 4.20568 |Train Accs: 0.08914 | Valid Accs: 0.10108 | Time: 0.51 seconds
# Epoch: 117 | Train Loss: 4.18893 | Valid Loss: 4.20110 |Train Accs: 0.08973 | Valid Accs: 0.10368 | Time: 0.52 seconds
# Epoch: 118 | Train Loss: 4.18569 | Valid Loss: 4.19978 |Train Accs: 0.09165 | Valid Accs: 0.10628 | Time: 0.52 seconds
# Epoch: 119 | Train Loss: 4.18848 | Valid Loss: 4.19450 |Train Accs: 0.09266 | Valid Accs: 0.10433 | Time: 0.52 seconds
# Epoch: 120 | Train Loss: 4.17776 | Valid Loss: 4.19279 |Train Accs: 0.09068 | Valid Accs: 0.10661 | Time: 0.62 seconds
# Epoch: 121 | Train Loss: 4.17547 | Valid Loss: 4.18848 |Train Accs: 0.09475 | Valid Accs: 0.10715 | Time: 0.54 seconds
# Epoch: 122 | Train Loss: 4.16990 | Valid Loss: 4.18413 |Train Accs: 0.09335 | Valid Accs: 0.10758 | Time: 0.53 seconds
# Epoch: 123 | Train Loss: 4.16519 | Valid Loss: 4.18069 |Train Accs: 0.09583 | Valid Accs: 0.10737 | Time: 0.52 seconds
# Epoch: 124 | Train Loss: 4.16295 | Valid Loss: 4.17893 |Train Accs: 0.09380 | Valid Accs: 0.10845 | Time: 0.59 seconds
# Epoch: 125 | Train Loss: 4.15941 | Valid Loss: 4.17603 |Train Accs: 0.09352 | Valid Accs: 0.10965 | Time: 0.71 seconds
# Epoch: 126 | Train Loss: 4.15366 | Valid Loss: 4.17077 |Train Accs: 0.09318 | Valid Accs: 0.11019 | Time: 0.68 seconds
# Epoch: 127 | Train Loss: 4.14840 | Valid Loss: 4.16826 |Train Accs: 0.09524 | Valid Accs: 0.11182 | Time: 0.57 seconds
# Epoch: 128 | Train Loss: 4.13913 | Valid Loss: 4.16401 |Train Accs: 0.09720 | Valid Accs: 0.11192 | Time: 0.56 seconds
# Epoch: 129 | Train Loss: 4.14244 | Valid Loss: 4.15992 |Train Accs: 0.09933 | Valid Accs: 0.11084 | Time: 0.58 seconds
# Epoch: 130 | Train Loss: 4.13324 | Valid Loss: 4.15906 |Train Accs: 0.10273 | Valid Accs: 0.11344 | Time: 0.56 seconds
# Epoch: 131 | Train Loss: 4.12625 | Valid Loss: 4.15314 |Train Accs: 0.10191 | Valid Accs: 0.11399 | Time: 0.56 seconds
# Epoch: 132 | Train Loss: 4.13307 | Valid Loss: 4.15004 |Train Accs: 0.10298 | Valid Accs: 0.11528 | Time: 0.54 seconds
# Epoch: 133 | Train Loss: 4.12357 | Valid Loss: 4.14898 |Train Accs: 0.10192 | Valid Accs: 0.11453 | Time: 0.53 seconds
# Epoch: 134 | Train Loss: 4.12558 | Valid Loss: 4.14345 |Train Accs: 0.10202 | Valid Accs: 0.11496 | Time: 0.61 seconds
# Epoch: 135 | Train Loss: 4.12015 | Valid Loss: 4.14355 |Train Accs: 0.10305 | Valid Accs: 0.11702 | Time: 0.49 seconds
# Epoch: 136 | Train Loss: 4.10469 | Valid Loss: 4.13801 |Train Accs: 0.10501 | Valid Accs: 0.11648 | Time: 0.52 seconds
# Epoch: 137 | Train Loss: 4.11470 | Valid Loss: 4.13367 |Train Accs: 0.10317 | Valid Accs: 0.11702 | Time: 0.52 seconds
# Epoch: 138 | Train Loss: 4.09877 | Valid Loss: 4.13311 |Train Accs: 0.10853 | Valid Accs: 0.11854 | Time: 0.51 seconds
# Epoch: 139 | Train Loss: 4.10008 | Valid Loss: 4.12778 |Train Accs: 0.10696 | Valid Accs: 0.11876 | Time: 0.51 seconds
# Epoch: 140 | Train Loss: 4.09899 | Valid Loss: 4.12473 |Train Accs: 0.11075 | Valid Accs: 0.11962 | Time: 0.53 seconds
# Epoch: 141 | Train Loss: 4.09661 | Valid Loss: 4.12368 |Train Accs: 0.10608 | Valid Accs: 0.12092 | Time: 0.66 seconds
# Epoch: 142 | Train Loss: 4.09291 | Valid Loss: 4.11990 |Train Accs: 0.11036 | Valid Accs: 0.12038 | Time: 0.52 seconds
# Epoch: 143 | Train Loss: 4.08829 | Valid Loss: 4.11685 |Train Accs: 0.10881 | Valid Accs: 0.12266 | Time: 0.51 seconds
# Epoch: 144 | Train Loss: 4.08190 | Valid Loss: 4.11579 |Train Accs: 0.11129 | Valid Accs: 0.12212 | Time: 0.77 seconds
# Epoch: 145 | Train Loss: 4.07647 | Valid Loss: 4.10986 |Train Accs: 0.11273 | Valid Accs: 0.12320 | Time: 0.52 seconds
# Epoch: 146 | Train Loss: 4.07341 | Valid Loss: 4.10641 |Train Accs: 0.11243 | Valid Accs: 0.12266 | Time: 0.52 seconds
# Epoch: 147 | Train Loss: 4.07113 | Valid Loss: 4.10521 |Train Accs: 0.11242 | Valid Accs: 0.12385 | Time: 0.52 seconds
# Epoch: 148 | Train Loss: 4.06634 | Valid Loss: 4.10136 |Train Accs: 0.11301 | Valid Accs: 0.12569 | Time: 0.54 seconds
# Epoch: 149 | Train Loss: 4.06675 | Valid Loss: 4.09834 |Train Accs: 0.11300 | Valid Accs: 0.12580 | Time: 0.62 seconds
# Epoch: 150 | Train Loss: 4.06239 | Valid Loss: 4.09476 |Train Accs: 0.11627 | Valid Accs: 0.12526 | Time: 0.57 seconds
# Epoch: 151 | Train Loss: 4.05728 | Valid Loss: 4.09009 |Train Accs: 0.11263 | Valid Accs: 0.12764 | Time: 0.54 seconds
# Epoch: 152 | Train Loss: 4.04754 | Valid Loss: 4.09045 |Train Accs: 0.11599 | Valid Accs: 0.12873 | Time: 0.48 seconds
# Epoch: 153 | Train Loss: 4.05153 | Valid Loss: 4.08531 |Train Accs: 0.11614 | Valid Accs: 0.12797 | Time: 0.56 seconds
# Epoch: 154 | Train Loss: 4.04313 | Valid Loss: 4.08253 |Train Accs: 0.11438 | Valid Accs: 0.12710 | Time: 0.77 seconds
# Epoch: 155 | Train Loss: 4.04849 | Valid Loss: 4.07797 |Train Accs: 0.11486 | Valid Accs: 0.12884 | Time: 0.62 seconds
# Epoch: 156 | Train Loss: 4.04107 | Valid Loss: 4.07547 |Train Accs: 0.11750 | Valid Accs: 0.12873 | Time: 0.62 seconds
# Epoch: 157 | Train Loss: 4.03339 | Valid Loss: 4.07240 |Train Accs: 0.11662 | Valid Accs: 0.13003 | Time: 0.59 seconds
# Epoch: 158 | Train Loss: 4.03121 | Valid Loss: 4.06848 |Train Accs: 0.12062 | Valid Accs: 0.13176 | Time: 0.52 seconds
# Epoch: 159 | Train Loss: 4.02520 | Valid Loss: 4.06840 |Train Accs: 0.12057 | Valid Accs: 0.13133 | Time: 0.54 seconds
# Epoch: 160 | Train Loss: 4.02542 | Valid Loss: 4.06267 |Train Accs: 0.12105 | Valid Accs: 0.13296 | Time: 0.52 seconds
# Epoch: 161 | Train Loss: 4.02100 | Valid Loss: 4.05922 |Train Accs: 0.12169 | Valid Accs: 0.13491 | Time: 0.54 seconds
# Epoch: 162 | Train Loss: 4.01807 | Valid Loss: 4.05704 |Train Accs: 0.12047 | Valid Accs: 0.13415 | Time: 0.52 seconds
# Epoch: 163 | Train Loss: 4.01596 | Valid Loss: 4.05791 |Train Accs: 0.12158 | Valid Accs: 0.13241 | Time: 0.61 seconds
# Epoch: 164 | Train Loss: 4.00856 | Valid Loss: 4.05106 |Train Accs: 0.12203 | Valid Accs: 0.13360 | Time: 0.71 seconds
# Epoch: 165 | Train Loss: 4.01263 | Valid Loss: 4.04676 |Train Accs: 0.12077 | Valid Accs: 0.13664 | Time: 0.51 seconds
# Epoch: 166 | Train Loss: 4.00287 | Valid Loss: 4.04697 |Train Accs: 0.12698 | Valid Accs: 0.13523 | Time: 0.49 seconds
# Epoch: 167 | Train Loss: 4.00248 | Valid Loss: 4.04363 |Train Accs: 0.12720 | Valid Accs: 0.13621 | Time: 0.51 seconds
# Epoch: 168 | Train Loss: 3.99542 | Valid Loss: 4.04130 |Train Accs: 0.12648 | Valid Accs: 0.13577 | Time: 0.51 seconds
# Epoch: 169 | Train Loss: 3.99116 | Valid Loss: 4.03697 |Train Accs: 0.12724 | Valid Accs: 0.13729 | Time: 0.54 seconds
# Epoch: 170 | Train Loss: 3.99217 | Valid Loss: 4.03161 |Train Accs: 0.12729 | Valid Accs: 0.13707 | Time: 0.61 seconds
# Epoch: 171 | Train Loss: 3.98639 | Valid Loss: 4.03153 |Train Accs: 0.12729 | Valid Accs: 0.13859 | Time: 0.52 seconds
# Epoch: 172 | Train Loss: 3.97866 | Valid Loss: 4.02817 |Train Accs: 0.13028 | Valid Accs: 0.13838 | Time: 0.51 seconds
# Epoch: 173 | Train Loss: 3.97817 | Valid Loss: 4.02505 |Train Accs: 0.12782 | Valid Accs: 0.13946 | Time: 0.51 seconds
# Epoch: 174 | Train Loss: 3.97192 | Valid Loss: 4.01926 |Train Accs: 0.12682 | Valid Accs: 0.13643 | Time: 0.52 seconds
# Epoch: 175 | Train Loss: 3.97740 | Valid Loss: 4.02216 |Train Accs: 0.13071 | Valid Accs: 0.13881 | Time: 0.49 seconds
# Epoch: 176 | Train Loss: 3.96953 | Valid Loss: 4.01710 |Train Accs: 0.13361 | Valid Accs: 0.14055 | Time: 0.51 seconds
# Epoch: 177 | Train Loss: 3.96416 | Valid Loss: 4.01059 |Train Accs: 0.13220 | Valid Accs: 0.13860 | Time: 0.52 seconds
# Epoch: 178 | Train Loss: 3.96141 | Valid Loss: 4.00959 |Train Accs: 0.13448 | Valid Accs: 0.14185 | Time: 0.52 seconds
# Epoch: 179 | Train Loss: 3.95923 | Valid Loss: 4.00620 |Train Accs: 0.13471 | Valid Accs: 0.14412 | Time: 0.66 seconds
# Epoch: 180 | Train Loss: 3.95218 | Valid Loss: 4.00272 |Train Accs: 0.14132 | Valid Accs: 0.14380 | Time: 0.55 seconds
# Epoch: 181 | Train Loss: 3.95075 | Valid Loss: 4.00293 |Train Accs: 0.13483 | Valid Accs: 0.14195 | Time: 0.48 seconds
# Epoch: 182 | Train Loss: 3.94623 | Valid Loss: 3.99880 |Train Accs: 0.13538 | Valid Accs: 0.14412 | Time: 0.51 seconds
# Epoch: 183 | Train Loss: 3.94956 | Valid Loss: 3.99570 |Train Accs: 0.13427 | Valid Accs: 0.14336 | Time: 0.58 seconds
# Epoch: 184 | Train Loss: 3.94818 | Valid Loss: 3.99284 |Train Accs: 0.13126 | Valid Accs: 0.14423 | Time: 0.68 seconds
# Epoch: 185 | Train Loss: 3.94058 | Valid Loss: 3.98840 |Train Accs: 0.13335 | Valid Accs: 0.14586 | Time: 0.64 seconds
# Epoch: 186 | Train Loss: 3.93772 | Valid Loss: 3.98707 |Train Accs: 0.13976 | Valid Accs: 0.14770 | Time: 0.55 seconds
# Epoch: 187 | Train Loss: 3.93487 | Valid Loss: 3.98315 |Train Accs: 0.13778 | Valid Accs: 0.14618 | Time: 0.51 seconds
# Epoch: 188 | Train Loss: 3.92551 | Valid Loss: 3.98196 |Train Accs: 0.14278 | Valid Accs: 0.14640 | Time: 0.55 seconds
# Epoch: 189 | Train Loss: 3.92569 | Valid Loss: 3.97877 |Train Accs: 0.13867 | Valid Accs: 0.14705 | Time: 0.53 seconds
# Epoch: 190 | Train Loss: 3.92170 | Valid Loss: 3.97481 |Train Accs: 0.13592 | Valid Accs: 0.14814 | Time: 0.51 seconds
# Epoch: 191 | Train Loss: 3.91556 | Valid Loss: 3.97281 |Train Accs: 0.14305 | Valid Accs: 0.14759 | Time: 0.51 seconds
# Epoch: 192 | Train Loss: 3.91071 | Valid Loss: 3.97106 |Train Accs: 0.14395 | Valid Accs: 0.14900 | Time: 0.52 seconds
# Epoch: 193 | Train Loss: 3.90587 | Valid Loss: 3.96988 |Train Accs: 0.14728 | Valid Accs: 0.15009 | Time: 0.51 seconds
# Epoch: 194 | Train Loss: 3.90863 | Valid Loss: 3.96335 |Train Accs: 0.14500 | Valid Accs: 0.15063 | Time: 0.61 seconds
# Epoch: 195 | Train Loss: 3.90164 | Valid Loss: 3.95950 |Train Accs: 0.14317 | Valid Accs: 0.14976 | Time: 0.51 seconds
# Epoch: 196 | Train Loss: 3.90060 | Valid Loss: 3.96013 |Train Accs: 0.14757 | Valid Accs: 0.15118 | Time: 0.48 seconds
# Epoch: 197 | Train Loss: 3.89684 | Valid Loss: 3.95526 |Train Accs: 0.14622 | Valid Accs: 0.15313 | Time: 0.51 seconds
# Epoch: 198 | Train Loss: 3.89556 | Valid Loss: 3.95300 |Train Accs: 0.14636 | Valid Accs: 0.15237 | Time: 0.56 seconds
# Epoch: 199 | Train Loss: 3.89400 | Valid Loss: 3.94900 |Train Accs: 0.14493 | Valid Accs: 0.15486 | Time: 0.53 seconds
# Epoch: 200 | Train Loss: 3.88829 | Valid Loss: 3.94682 |Train Accs: 0.14801 | Valid Accs: 0.15400 | Time: 0.61 seconds
# Epoch: 201 | Train Loss: 3.88611 | Valid Loss: 3.94561 |Train Accs: 0.14858 | Valid Accs: 0.15345 | Time: 0.52 seconds
# Epoch: 202 | Train Loss: 3.88098 | Valid Loss: 3.94381 |Train Accs: 0.14905 | Valid Accs: 0.15476 | Time: 0.52 seconds
# Epoch: 203 | Train Loss: 3.87939 | Valid Loss: 3.93686 |Train Accs: 0.14980 | Valid Accs: 0.15887 | Time: 0.52 seconds
# Epoch: 204 | Train Loss: 3.87058 | Valid Loss: 3.93650 |Train Accs: 0.15336 | Valid Accs: 0.15822 | Time: 0.72 seconds
# Epoch: 205 | Train Loss: 3.87278 | Valid Loss: 3.93189 |Train Accs: 0.15022 | Valid Accs: 0.15758 | Time: 0.55 seconds
# Epoch: 206 | Train Loss: 3.86614 | Valid Loss: 3.93190 |Train Accs: 0.15589 | Valid Accs: 0.16256 | Time: 0.51 seconds
# Epoch: 207 | Train Loss: 3.87052 | Valid Loss: 3.92792 |Train Accs: 0.14919 | Valid Accs: 0.16115 | Time: 0.51 seconds
# Epoch: 208 | Train Loss: 3.86248 | Valid Loss: 3.92626 |Train Accs: 0.15628 | Valid Accs: 0.16039 | Time: 0.58 seconds
# Epoch: 209 | Train Loss: 3.85962 | Valid Loss: 3.92082 |Train Accs: 0.15252 | Valid Accs: 0.16115 | Time: 0.63 seconds
# Epoch: 210 | Train Loss: 3.85342 | Valid Loss: 3.92063 |Train Accs: 0.15697 | Valid Accs: 0.16321 | Time: 0.52 seconds
# Epoch: 211 | Train Loss: 3.85615 | Valid Loss: 3.91721 |Train Accs: 0.15231 | Valid Accs: 0.16148 | Time: 0.60 seconds
# Epoch: 212 | Train Loss: 3.85160 | Valid Loss: 3.91438 |Train Accs: 0.15694 | Valid Accs: 0.16256 | Time: 0.89 seconds
# Epoch: 213 | Train Loss: 3.84317 | Valid Loss: 3.91054 |Train Accs: 0.15640 | Valid Accs: 0.16169 | Time: 0.55 seconds
# Epoch: 214 | Train Loss: 3.83773 | Valid Loss: 3.90862 |Train Accs: 0.15947 | Valid Accs: 0.16354 | Time: 0.53 seconds
# Epoch: 215 | Train Loss: 3.84327 | Valid Loss: 3.91058 |Train Accs: 0.15778 | Valid Accs: 0.16354 | Time: 0.61 seconds
# Epoch: 216 | Train Loss: 3.83437 | Valid Loss: 3.90344 |Train Accs: 0.15956 | Valid Accs: 0.16570 | Time: 0.51 seconds
# Epoch: 217 | Train Loss: 3.83210 | Valid Loss: 3.90276 |Train Accs: 0.15948 | Valid Accs: 0.16657 | Time: 0.54 seconds
# Epoch: 218 | Train Loss: 3.82529 | Valid Loss: 3.89953 |Train Accs: 0.16277 | Valid Accs: 0.16570 | Time: 0.51 seconds
# Epoch: 219 | Train Loss: 3.82930 | Valid Loss: 3.89710 |Train Accs: 0.15869 | Valid Accs: 0.16657 | Time: 0.53 seconds
# Epoch: 220 | Train Loss: 3.82015 | Valid Loss: 3.89616 |Train Accs: 0.15765 | Valid Accs: 0.16701 | Time: 0.51 seconds
# Epoch: 221 | Train Loss: 3.82025 | Valid Loss: 3.88844 |Train Accs: 0.15776 | Valid Accs: 0.16820 | Time: 0.52 seconds
# Epoch: 222 | Train Loss: 3.81850 | Valid Loss: 3.88998 |Train Accs: 0.16179 | Valid Accs: 0.16798 | Time: 0.47 seconds
# Epoch: 223 | Train Loss: 3.81470 | Valid Loss: 3.88615 |Train Accs: 0.16416 | Valid Accs: 0.17015 | Time: 0.72 seconds
# Epoch: 224 | Train Loss: 3.81157 | Valid Loss: 3.88306 |Train Accs: 0.16528 | Valid Accs: 0.17058 | Time: 0.72 seconds
# Epoch: 225 | Train Loss: 3.80975 | Valid Loss: 3.88162 |Train Accs: 0.16230 | Valid Accs: 0.17123 | Time: 0.58 seconds
# Epoch: 226 | Train Loss: 3.80142 | Valid Loss: 3.87757 |Train Accs: 0.16476 | Valid Accs: 0.17167 | Time: 0.60 seconds
# Epoch: 227 | Train Loss: 3.80103 | Valid Loss: 3.87602 |Train Accs: 0.16174 | Valid Accs: 0.17080 | Time: 0.55 seconds
# Epoch: 228 | Train Loss: 3.80611 | Valid Loss: 3.87417 |Train Accs: 0.16567 | Valid Accs: 0.17210 | Time: 0.52 seconds
# Epoch: 229 | Train Loss: 3.79448 | Valid Loss: 3.87033 |Train Accs: 0.16502 | Valid Accs: 0.17254 | Time: 0.52 seconds
# Epoch: 230 | Train Loss: 3.79580 | Valid Loss: 3.86729 |Train Accs: 0.16783 | Valid Accs: 0.17384 | Time: 0.63 seconds
# Epoch: 231 | Train Loss: 3.79172 | Valid Loss: 3.86431 |Train Accs: 0.16793 | Valid Accs: 0.17438 | Time: 0.52 seconds
# Epoch: 232 | Train Loss: 3.77799 | Valid Loss: 3.86088 |Train Accs: 0.16988 | Valid Accs: 0.17416 | Time: 0.54 seconds
# Epoch: 233 | Train Loss: 3.78047 | Valid Loss: 3.86190 |Train Accs: 0.17002 | Valid Accs: 0.17547 | Time: 0.50 seconds
# Epoch: 234 | Train Loss: 3.78097 | Valid Loss: 3.85542 |Train Accs: 0.17179 | Valid Accs: 0.17536 | Time: 0.52 seconds
# Epoch: 235 | Train Loss: 3.78277 | Valid Loss: 3.85225 |Train Accs: 0.17217 | Valid Accs: 0.17709 | Time: 0.54 seconds
# Epoch: 236 | Train Loss: 3.77432 | Valid Loss: 3.85082 |Train Accs: 0.17103 | Valid Accs: 0.17590 | Time: 0.51 seconds
# Epoch: 237 | Train Loss: 3.77319 | Valid Loss: 3.84827 |Train Accs: 0.17184 | Valid Accs: 0.17677 | Time: 0.53 seconds
# Epoch: 238 | Train Loss: 3.76766 | Valid Loss: 3.84745 |Train Accs: 0.17134 | Valid Accs: 0.17948 | Time: 0.51 seconds
# Epoch: 239 | Train Loss: 3.76723 | Valid Loss: 3.84145 |Train Accs: 0.17318 | Valid Accs: 0.17709 | Time: 0.61 seconds
# Epoch: 240 | Train Loss: 3.76023 | Valid Loss: 3.83959 |Train Accs: 0.17628 | Valid Accs: 0.17861 | Time: 0.53 seconds
# Epoch: 241 | Train Loss: 3.75776 | Valid Loss: 3.83523 |Train Accs: 0.17679 | Valid Accs: 0.17742 | Time: 0.54 seconds
# Epoch: 242 | Train Loss: 3.75521 | Valid Loss: 3.83745 |Train Accs: 0.17447 | Valid Accs: 0.17915 | Time: 0.48 seconds
# Epoch: 243 | Train Loss: 3.75407 | Valid Loss: 3.83342 |Train Accs: 0.17649 | Valid Accs: 0.17926 | Time: 0.73 seconds
# Epoch: 244 | Train Loss: 3.74646 | Valid Loss: 3.83044 |Train Accs: 0.17450 | Valid Accs: 0.18013 | Time: 0.52 seconds
# Epoch: 245 | Train Loss: 3.74871 | Valid Loss: 3.82878 |Train Accs: 0.17330 | Valid Accs: 0.18121 | Time: 0.65 seconds
# Epoch: 246 | Train Loss: 3.74742 | Valid Loss: 3.82338 |Train Accs: 0.17674 | Valid Accs: 0.18186 | Time: 0.51 seconds
# Epoch: 247 | Train Loss: 3.73834 | Valid Loss: 3.82035 |Train Accs: 0.17926 | Valid Accs: 0.18165 | Time: 0.54 seconds
# Epoch: 248 | Train Loss: 3.73901 | Valid Loss: 3.81989 |Train Accs: 0.17498 | Valid Accs: 0.18284 | Time: 0.53 seconds
# Epoch: 249 | Train Loss: 3.73753 | Valid Loss: 3.81664 |Train Accs: 0.18101 | Valid Accs: 0.18176 | Time: 0.54 seconds
# Epoch: 250 | Train Loss: 3.72960 | Valid Loss: 3.81576 |Train Accs: 0.18123 | Valid Accs: 0.18371 | Time: 0.53 seconds
# Epoch: 251 | Train Loss: 3.73108 | Valid Loss: 3.81132 |Train Accs: 0.17859 | Valid Accs: 0.18371 | Time: 0.52 seconds
# Epoch: 252 | Train Loss: 3.72751 | Valid Loss: 3.81060 |Train Accs: 0.18141 | Valid Accs: 0.18371 | Time: 0.52 seconds
# Epoch: 253 | Train Loss: 3.72093 | Valid Loss: 3.80616 |Train Accs: 0.18324 | Valid Accs: 0.18252 | Time: 0.52 seconds
# Epoch: 254 | Train Loss: 3.71547 | Valid Loss: 3.80430 |Train Accs: 0.18616 | Valid Accs: 0.18262 | Time: 0.62 seconds
# Epoch: 255 | Train Loss: 3.71889 | Valid Loss: 3.80397 |Train Accs: 0.18145 | Valid Accs: 0.18544 | Time: 0.64 seconds
# Epoch: 256 | Train Loss: 3.70890 | Valid Loss: 3.79865 |Train Accs: 0.18425 | Valid Accs: 0.18598 | Time: 0.52 seconds
# Epoch: 257 | Train Loss: 3.70355 | Valid Loss: 3.79866 |Train Accs: 0.18843 | Valid Accs: 0.18707 | Time: 0.48 seconds
# Epoch: 258 | Train Loss: 3.70618 | Valid Loss: 3.79385 |Train Accs: 0.18187 | Valid Accs: 0.18566 | Time: 0.51 seconds
# Epoch: 259 | Train Loss: 3.70709 | Valid Loss: 3.79210 |Train Accs: 0.18654 | Valid Accs: 0.18707 | Time: 0.52 seconds
# Epoch: 260 | Train Loss: 3.69772 | Valid Loss: 3.79121 |Train Accs: 0.18639 | Valid Accs: 0.18751 | Time: 0.62 seconds
# Epoch: 261 | Train Loss: 3.70113 | Valid Loss: 3.78803 |Train Accs: 0.18691 | Valid Accs: 0.18534 | Time: 0.53 seconds
# Epoch: 262 | Train Loss: 3.69685 | Valid Loss: 3.78417 |Train Accs: 0.18924 | Valid Accs: 0.18826 | Time: 0.52 seconds
# Epoch: 263 | Train Loss: 3.69304 | Valid Loss: 3.78194 |Train Accs: 0.18265 | Valid Accs: 0.18837 | Time: 0.71 seconds
# Epoch: 264 | Train Loss: 3.68734 | Valid Loss: 3.77897 |Train Accs: 0.18740 | Valid Accs: 0.18826 | Time: 0.54 seconds
# Epoch: 265 | Train Loss: 3.68824 | Valid Loss: 3.77818 |Train Accs: 0.19069 | Valid Accs: 0.19032 | Time: 0.52 seconds
# Epoch: 266 | Train Loss: 3.68555 | Valid Loss: 3.77347 |Train Accs: 0.18764 | Valid Accs: 0.18891 | Time: 0.52 seconds
# Epoch: 267 | Train Loss: 3.68190 | Valid Loss: 3.77420 |Train Accs: 0.18855 | Valid Accs: 0.19022 | Time: 0.53 seconds
# Epoch: 268 | Train Loss: 3.67689 | Valid Loss: 3.77011 |Train Accs: 0.19271 | Valid Accs: 0.18924 | Time: 0.61 seconds
# Epoch: 269 | Train Loss: 3.67447 | Valid Loss: 3.76644 |Train Accs: 0.19563 | Valid Accs: 0.18978 | Time: 0.70 seconds
# Epoch: 270 | Train Loss: 3.67088 | Valid Loss: 3.76593 |Train Accs: 0.19239 | Valid Accs: 0.19119 | Time: 0.73 seconds
# Epoch: 271 | Train Loss: 3.67344 | Valid Loss: 3.76161 |Train Accs: 0.19289 | Valid Accs: 0.19282 | Time: 0.52 seconds
# Epoch: 272 | Train Loss: 3.66935 | Valid Loss: 3.75987 |Train Accs: 0.19429 | Valid Accs: 0.19141 | Time: 0.52 seconds
# Epoch: 273 | Train Loss: 3.66448 | Valid Loss: 3.75968 |Train Accs: 0.19187 | Valid Accs: 0.19347 | Time: 0.58 seconds
# Epoch: 274 | Train Loss: 3.66204 | Valid Loss: 3.75743 |Train Accs: 0.19361 | Valid Accs: 0.19433 | Time: 0.53 seconds
# Epoch: 275 | Train Loss: 3.65865 | Valid Loss: 3.75518 |Train Accs: 0.19434 | Valid Accs: 0.19542 | Time: 0.61 seconds
# Epoch: 276 | Train Loss: 3.66234 | Valid Loss: 3.75038 |Train Accs: 0.19363 | Valid Accs: 0.19499 | Time: 0.52 seconds
# Epoch: 277 | Train Loss: 3.65057 | Valid Loss: 3.74701 |Train Accs: 0.19621 | Valid Accs: 0.19455 | Time: 0.51 seconds
# Epoch: 278 | Train Loss: 3.64766 | Valid Loss: 3.74282 |Train Accs: 0.19599 | Valid Accs: 0.19509 | Time: 0.52 seconds
# Epoch: 279 | Train Loss: 3.64952 | Valid Loss: 3.74138 |Train Accs: 0.19911 | Valid Accs: 0.19596 | Time: 0.52 seconds
# Epoch: 280 | Train Loss: 3.64861 | Valid Loss: 3.74018 |Train Accs: 0.19715 | Valid Accs: 0.19835 | Time: 0.52 seconds
# Epoch: 281 | Train Loss: 3.64300 | Valid Loss: 3.73784 |Train Accs: 0.19821 | Valid Accs: 0.19618 | Time: 0.51 seconds
# Epoch: 282 | Train Loss: 3.63471 | Valid Loss: 3.73314 |Train Accs: 0.19937 | Valid Accs: 0.19715 | Time: 0.71 seconds
# Epoch: 283 | Train Loss: 3.64495 | Valid Loss: 3.73506 |Train Accs: 0.19842 | Valid Accs: 0.19770 | Time: 0.68 seconds
# Epoch: 284 | Train Loss: 3.63666 | Valid Loss: 3.73174 |Train Accs: 0.19862 | Valid Accs: 0.19867 | Time: 0.51 seconds
# Epoch: 285 | Train Loss: 3.62572 | Valid Loss: 3.72660 |Train Accs: 0.20010 | Valid Accs: 0.19867 | Time: 0.52 seconds
# Epoch: 286 | Train Loss: 3.62992 | Valid Loss: 3.72449 |Train Accs: 0.20257 | Valid Accs: 0.19900 | Time: 0.51 seconds
# Epoch: 287 | Train Loss: 3.62477 | Valid Loss: 3.72392 |Train Accs: 0.20374 | Valid Accs: 0.19954 | Time: 0.58 seconds
# Epoch: 288 | Train Loss: 3.62316 | Valid Loss: 3.72048 |Train Accs: 0.20107 | Valid Accs: 0.20073 | Time: 0.51 seconds
# Epoch: 289 | Train Loss: 3.61665 | Valid Loss: 3.71851 |Train Accs: 0.20444 | Valid Accs: 0.19998 | Time: 0.53 seconds
# Epoch: 290 | Train Loss: 3.61536 | Valid Loss: 3.71976 |Train Accs: 0.19998 | Valid Accs: 0.20117 | Time: 0.58 seconds
# Epoch: 291 | Train Loss: 3.61260 | Valid Loss: 3.71546 |Train Accs: 0.20432 | Valid Accs: 0.20139 | Time: 0.53 seconds
# Epoch: 292 | Train Loss: 3.60726 | Valid Loss: 3.71026 |Train Accs: 0.20557 | Valid Accs: 0.20356 | Time: 0.51 seconds
# Epoch: 293 | Train Loss: 3.60897 | Valid Loss: 3.70882 |Train Accs: 0.20607 | Valid Accs: 0.20139 | Time: 0.53 seconds
# Epoch: 294 | Train Loss: 3.60286 | Valid Loss: 3.70521 |Train Accs: 0.20624 | Valid Accs: 0.20312 | Time: 0.54 seconds
# Epoch: 295 | Train Loss: 3.59884 | Valid Loss: 3.70320 |Train Accs: 0.20952 | Valid Accs: 0.20410 | Time: 0.52 seconds
# Epoch: 296 | Train Loss: 3.59298 | Valid Loss: 3.70595 |Train Accs: 0.21061 | Valid Accs: 0.20377 | Time: 0.48 seconds
# Epoch: 297 | Train Loss: 3.60003 | Valid Loss: 3.69624 |Train Accs: 0.20737 | Valid Accs: 0.20421 | Time: 0.52 seconds
# Epoch: 298 | Train Loss: 3.59237 | Valid Loss: 3.69607 |Train Accs: 0.20806 | Valid Accs: 0.20746 | Time: 0.62 seconds
# Epoch: 299 | Train Loss: 3.59608 | Valid Loss: 3.69430 |Train Accs: 0.20704 | Valid Accs: 0.20453 | Time: 0.51 seconds
# Epoch: 300 | Train Loss: 3.58660 | Valid Loss: 3.69229 |Train Accs: 0.21089 | Valid Accs: 0.20746 | Time: 0.52 seconds
# Epoch: 301 | Train Loss: 3.58376 | Valid Loss: 3.68916 |Train Accs: 0.20933 | Valid Accs: 0.20626 | Time: 0.52 seconds
# Epoch: 302 | Train Loss: 3.58454 | Valid Loss: 3.68887 |Train Accs: 0.21111 | Valid Accs: 0.20779 | Time: 0.66 seconds
# Epoch: 303 | Train Loss: 3.58547 | Valid Loss: 3.68406 |Train Accs: 0.20475 | Valid Accs: 0.20963 | Time: 0.61 seconds
# Epoch: 304 | Train Loss: 3.57468 | Valid Loss: 3.68447 |Train Accs: 0.21012 | Valid Accs: 0.20768 | Time: 0.47 seconds
# Epoch: 305 | Train Loss: 3.57057 | Valid Loss: 3.67986 |Train Accs: 0.21223 | Valid Accs: 0.21028 | Time: 0.63 seconds
# Epoch: 306 | Train Loss: 3.56272 | Valid Loss: 3.67957 |Train Accs: 0.21533 | Valid Accs: 0.20952 | Time: 0.52 seconds
# Epoch: 307 | Train Loss: 3.56394 | Valid Loss: 3.67314 |Train Accs: 0.21887 | Valid Accs: 0.21039 | Time: 0.51 seconds
# Epoch: 308 | Train Loss: 3.56642 | Valid Loss: 3.67543 |Train Accs: 0.21287 | Valid Accs: 0.21266 | Time: 0.48 seconds
# Epoch: 309 | Train Loss: 3.56289 | Valid Loss: 3.67310 |Train Accs: 0.21633 | Valid Accs: 0.21028 | Time: 0.51 seconds
# Epoch: 310 | Train Loss: 3.55220 | Valid Loss: 3.66950 |Train Accs: 0.21530 | Valid Accs: 0.21136 | Time: 0.51 seconds
# Epoch: 311 | Train Loss: 3.55420 | Valid Loss: 3.66681 |Train Accs: 0.21675 | Valid Accs: 0.21256 | Time: 0.51 seconds
# Epoch: 312 | Train Loss: 3.55172 | Valid Loss: 3.66339 |Train Accs: 0.21995 | Valid Accs: 0.21169 | Time: 0.55 seconds
# Epoch: 313 | Train Loss: 3.55348 | Valid Loss: 3.65984 |Train Accs: 0.21990 | Valid Accs: 0.21299 | Time: 0.63 seconds
# Epoch: 314 | Train Loss: 3.55046 | Valid Loss: 3.65792 |Train Accs: 0.21852 | Valid Accs: 0.21472 | Time: 0.51 seconds
# Epoch: 315 | Train Loss: 3.54587 | Valid Loss: 3.65729 |Train Accs: 0.21721 | Valid Accs: 0.21309 | Time: 0.52 seconds
# Epoch: 316 | Train Loss: 3.53924 | Valid Loss: 3.65487 |Train Accs: 0.22026 | Valid Accs: 0.21473 | Time: 0.52 seconds
# Epoch: 317 | Train Loss: 3.53937 | Valid Loss: 3.65161 |Train Accs: 0.21853 | Valid Accs: 0.21419 | Time: 0.51 seconds
# Epoch: 318 | Train Loss: 3.54253 | Valid Loss: 3.65293 |Train Accs: 0.21671 | Valid Accs: 0.21397 | Time: 0.48 seconds
# Epoch: 319 | Train Loss: 3.53449 | Valid Loss: 3.64711 |Train Accs: 0.21786 | Valid Accs: 0.21581 | Time: 0.61 seconds
# Epoch: 320 | Train Loss: 3.53069 | Valid Loss: 3.64726 |Train Accs: 0.22190 | Valid Accs: 0.21418 | Time: 0.48 seconds
# Epoch: 321 | Train Loss: 3.52926 | Valid Loss: 3.64361 |Train Accs: 0.21881 | Valid Accs: 0.21625 | Time: 0.52 seconds
# Epoch: 322 | Train Loss: 3.53136 | Valid Loss: 3.64322 |Train Accs: 0.22360 | Valid Accs: 0.21592 | Time: 0.54 seconds
# Epoch: 323 | Train Loss: 3.52817 | Valid Loss: 3.63861 |Train Accs: 0.22381 | Valid Accs: 0.21722 | Time: 0.84 seconds
# Epoch: 324 | Train Loss: 3.52234 | Valid Loss: 3.64252 |Train Accs: 0.22197 | Valid Accs: 0.21787 | Time: 0.50 seconds
# Epoch: 325 | Train Loss: 3.52187 | Valid Loss: 3.63436 |Train Accs: 0.22614 | Valid Accs: 0.21798 | Time: 0.51 seconds
# Epoch: 326 | Train Loss: 3.52345 | Valid Loss: 3.63101 |Train Accs: 0.22661 | Valid Accs: 0.21787 | Time: 0.52 seconds
# Epoch: 327 | Train Loss: 3.50819 | Valid Loss: 3.62915 |Train Accs: 0.22437 | Valid Accs: 0.21830 | Time: 0.64 seconds
# Epoch: 328 | Train Loss: 3.51122 | Valid Loss: 3.62867 |Train Accs: 0.22453 | Valid Accs: 0.21884 | Time: 0.88 seconds
# Epoch: 329 | Train Loss: 3.51300 | Valid Loss: 3.62697 |Train Accs: 0.22803 | Valid Accs: 0.21852 | Time: 0.54 seconds
# Epoch: 330 | Train Loss: 3.50945 | Valid Loss: 3.62164 |Train Accs: 0.22795 | Valid Accs: 0.21895 | Time: 0.54 seconds
# Epoch: 331 | Train Loss: 3.49965 | Valid Loss: 3.62249 |Train Accs: 0.22863 | Valid Accs: 0.21950 | Time: 0.50 seconds
# Epoch: 332 | Train Loss: 3.50413 | Valid Loss: 3.61871 |Train Accs: 0.22797 | Valid Accs: 0.22199 | Time: 0.51 seconds
# Epoch: 333 | Train Loss: 3.49677 | Valid Loss: 3.61676 |Train Accs: 0.23174 | Valid Accs: 0.22015 | Time: 0.51 seconds
# Epoch: 334 | Train Loss: 3.49480 | Valid Loss: 3.61674 |Train Accs: 0.23321 | Valid Accs: 0.21993 | Time: 0.65 seconds
# Epoch: 335 | Train Loss: 3.48525 | Valid Loss: 3.61067 |Train Accs: 0.23329 | Valid Accs: 0.21971 | Time: 0.51 seconds
# Epoch: 336 | Train Loss: 3.49183 | Valid Loss: 3.61042 |Train Accs: 0.23205 | Valid Accs: 0.22177 | Time: 0.52 seconds
# Epoch: 337 | Train Loss: 3.48014 | Valid Loss: 3.60843 |Train Accs: 0.23370 | Valid Accs: 0.21961 | Time: 0.51 seconds
# Epoch: 338 | Train Loss: 3.48536 | Valid Loss: 3.60345 |Train Accs: 0.23294 | Valid Accs: 0.22318 | Time: 0.51 seconds
# Epoch: 339 | Train Loss: 3.49012 | Valid Loss: 3.60281 |Train Accs: 0.23170 | Valid Accs: 0.22221 | Time: 0.52 seconds
# Epoch: 340 | Train Loss: 3.48087 | Valid Loss: 3.60099 |Train Accs: 0.23303 | Valid Accs: 0.22286 | Time: 0.56 seconds
# Epoch: 341 | Train Loss: 3.47721 | Valid Loss: 3.59965 |Train Accs: 0.23747 | Valid Accs: 0.22350 | Time: 0.52 seconds
# Epoch: 342 | Train Loss: 3.47694 | Valid Loss: 3.59589 |Train Accs: 0.23470 | Valid Accs: 0.22405 | Time: 0.72 seconds
# Epoch: 343 | Train Loss: 3.46951 | Valid Loss: 3.59608 |Train Accs: 0.23354 | Valid Accs: 0.22502 | Time: 0.63 seconds
# Epoch: 344 | Train Loss: 3.47211 | Valid Loss: 3.59065 |Train Accs: 0.23234 | Valid Accs: 0.22676 | Time: 0.51 seconds
# Epoch: 345 | Train Loss: 3.46223 | Valid Loss: 3.59249 |Train Accs: 0.23942 | Valid Accs: 0.22611 | Time: 0.49 seconds
# Epoch: 346 | Train Loss: 3.46670 | Valid Loss: 3.58887 |Train Accs: 0.23436 | Valid Accs: 0.22644 | Time: 0.53 seconds
# Epoch: 347 | Train Loss: 3.46372 | Valid Loss: 3.58642 |Train Accs: 0.23626 | Valid Accs: 0.22644 | Time: 0.54 seconds
# Epoch: 348 | Train Loss: 3.46086 | Valid Loss: 3.58267 |Train Accs: 0.23858 | Valid Accs: 0.22752 | Time: 0.54 seconds
# Epoch: 349 | Train Loss: 3.45702 | Valid Loss: 3.58145 |Train Accs: 0.23746 | Valid Accs: 0.22697 | Time: 0.62 seconds
# Epoch: 350 | Train Loss: 3.44882 | Valid Loss: 3.58124 |Train Accs: 0.24092 | Valid Accs: 0.22795 | Time: 0.53 seconds
# Epoch: 351 | Train Loss: 3.45046 | Valid Loss: 3.57428 |Train Accs: 0.23969 | Valid Accs: 0.23001 | Time: 0.51 seconds
# Epoch: 352 | Train Loss: 3.44910 | Valid Loss: 3.57603 |Train Accs: 0.24108 | Valid Accs: 0.23001 | Time: 0.50 seconds
# Epoch: 353 | Train Loss: 3.44760 | Valid Loss: 3.57058 |Train Accs: 0.24012 | Valid Accs: 0.22893 | Time: 0.51 seconds
# Epoch: 354 | Train Loss: 3.44287 | Valid Loss: 3.57031 |Train Accs: 0.24128 | Valid Accs: 0.23153 | Time: 0.54 seconds
# Epoch: 355 | Train Loss: 3.44673 | Valid Loss: 3.56910 |Train Accs: 0.23953 | Valid Accs: 0.22925 | Time: 0.51 seconds
# Epoch: 356 | Train Loss: 3.43243 | Valid Loss: 3.56478 |Train Accs: 0.24109 | Valid Accs: 0.23163 | Time: 0.51 seconds
# Epoch: 357 | Train Loss: 3.43187 | Valid Loss: 3.55955 |Train Accs: 0.24622 | Valid Accs: 0.23066 | Time: 0.51 seconds
# Epoch: 358 | Train Loss: 3.43466 | Valid Loss: 3.56096 |Train Accs: 0.24203 | Valid Accs: 0.23262 | Time: 0.59 seconds
# Epoch: 359 | Train Loss: 3.42565 | Valid Loss: 3.56111 |Train Accs: 0.24318 | Valid Accs: 0.23207 | Time: 0.49 seconds
# Epoch: 360 | Train Loss: 3.42578 | Valid Loss: 3.55827 |Train Accs: 0.24585 | Valid Accs: 0.23424 | Time: 0.53 seconds
# Epoch: 361 | Train Loss: 3.42488 | Valid Loss: 3.55291 |Train Accs: 0.24210 | Valid Accs: 0.23391 | Time: 0.53 seconds
# Epoch: 362 | Train Loss: 3.42319 | Valid Loss: 3.55401 |Train Accs: 0.24220 | Valid Accs: 0.23348 | Time: 0.58 seconds
# Epoch: 363 | Train Loss: 3.41919 | Valid Loss: 3.55261 |Train Accs: 0.24439 | Valid Accs: 0.23630 | Time: 0.68 seconds
# Epoch: 364 | Train Loss: 3.41983 | Valid Loss: 3.55064 |Train Accs: 0.24695 | Valid Accs: 0.23608 | Time: 0.63 seconds
# Epoch: 365 | Train Loss: 3.41979 | Valid Loss: 3.54725 |Train Accs: 0.24274 | Valid Accs: 0.23424 | Time: 0.54 seconds
# Epoch: 366 | Train Loss: 3.40970 | Valid Loss: 3.54700 |Train Accs: 0.24822 | Valid Accs: 0.23478 | Time: 0.52 seconds
# Epoch: 367 | Train Loss: 3.41082 | Valid Loss: 3.54517 |Train Accs: 0.24628 | Valid Accs: 0.23641 | Time: 0.55 seconds
# Epoch: 368 | Train Loss: 3.40977 | Valid Loss: 3.53871 |Train Accs: 0.24828 | Valid Accs: 0.23554 | Time: 0.52 seconds
# Epoch: 369 | Train Loss: 3.40369 | Valid Loss: 3.53809 |Train Accs: 0.25041 | Valid Accs: 0.23695 | Time: 0.52 seconds
# Epoch: 370 | Train Loss: 3.40186 | Valid Loss: 3.53518 |Train Accs: 0.24642 | Valid Accs: 0.23652 | Time: 0.56 seconds
# Epoch: 371 | Train Loss: 3.40432 | Valid Loss: 3.53581 |Train Accs: 0.24305 | Valid Accs: 0.23782 | Time: 0.50 seconds
# Epoch: 372 | Train Loss: 3.40162 | Valid Loss: 3.52881 |Train Accs: 0.24885 | Valid Accs: 0.23814 | Time: 0.62 seconds
# Epoch: 373 | Train Loss: 3.39265 | Valid Loss: 3.52994 |Train Accs: 0.25486 | Valid Accs: 0.23858 | Time: 0.48 seconds
# Epoch: 374 | Train Loss: 3.39627 | Valid Loss: 3.52662 |Train Accs: 0.24965 | Valid Accs: 0.23912 | Time: 0.52 seconds
# Epoch: 375 | Train Loss: 3.38815 | Valid Loss: 3.52289 |Train Accs: 0.25320 | Valid Accs: 0.24010 | Time: 0.55 seconds
# Epoch: 376 | Train Loss: 3.38530 | Valid Loss: 3.52060 |Train Accs: 0.25868 | Valid Accs: 0.24031 | Time: 0.54 seconds
# Epoch: 377 | Train Loss: 3.38993 | Valid Loss: 3.51999 |Train Accs: 0.25241 | Valid Accs: 0.23955 | Time: 0.51 seconds
# Epoch: 378 | Train Loss: 3.37586 | Valid Loss: 3.51843 |Train Accs: 0.25386 | Valid Accs: 0.24216 | Time: 0.60 seconds
# Epoch: 379 | Train Loss: 3.38141 | Valid Loss: 3.51604 |Train Accs: 0.25640 | Valid Accs: 0.23988 | Time: 0.63 seconds
# Epoch: 380 | Train Loss: 3.37974 | Valid Loss: 3.51524 |Train Accs: 0.25226 | Valid Accs: 0.24010 | Time: 0.55 seconds
# Epoch: 381 | Train Loss: 3.38157 | Valid Loss: 3.51226 |Train Accs: 0.25270 | Valid Accs: 0.24151 | Time: 0.52 seconds
# Epoch: 382 | Train Loss: 3.36939 | Valid Loss: 3.51128 |Train Accs: 0.25531 | Valid Accs: 0.24216 | Time: 0.72 seconds
# Epoch: 383 | Train Loss: 3.37261 | Valid Loss: 3.50801 |Train Accs: 0.25628 | Valid Accs: 0.24107 | Time: 0.54 seconds
# Epoch: 384 | Train Loss: 3.36351 | Valid Loss: 3.50589 |Train Accs: 0.25390 | Valid Accs: 0.24162 | Time: 0.62 seconds
# Epoch: 385 | Train Loss: 3.36751 | Valid Loss: 3.50354 |Train Accs: 0.25775 | Valid Accs: 0.24129 | Time: 0.82 seconds
# Epoch: 386 | Train Loss: 3.36933 | Valid Loss: 3.50294 |Train Accs: 0.25535 | Valid Accs: 0.24314 | Time: 0.59 seconds
# Epoch: 387 | Train Loss: 3.35821 | Valid Loss: 3.49877 |Train Accs: 0.25744 | Valid Accs: 0.24411 | Time: 0.67 seconds
# Epoch: 388 | Train Loss: 3.35805 | Valid Loss: 3.49872 |Train Accs: 0.25747 | Valid Accs: 0.24433 | Time: 0.54 seconds
# Epoch: 389 | Train Loss: 3.35245 | Valid Loss: 3.49525 |Train Accs: 0.26483 | Valid Accs: 0.24465 | Time: 0.51 seconds
# Epoch: 390 | Train Loss: 3.35240 | Valid Loss: 3.48954 |Train Accs: 0.25971 | Valid Accs: 0.24509 | Time: 0.52 seconds
# Epoch: 391 | Train Loss: 3.35395 | Valid Loss: 3.49646 |Train Accs: 0.25623 | Valid Accs: 0.24541 | Time: 0.48 seconds
# Epoch: 392 | Train Loss: 3.34819 | Valid Loss: 3.49076 |Train Accs: 0.26410 | Valid Accs: 0.24660 | Time: 0.47 seconds
# Epoch: 393 | Train Loss: 3.35047 | Valid Loss: 3.49092 |Train Accs: 0.26028 | Valid Accs: 0.24541 | Time: 0.48 seconds
# Epoch: 394 | Train Loss: 3.34645 | Valid Loss: 3.48484 |Train Accs: 0.26265 | Valid Accs: 0.24660 | Time: 0.62 seconds
# Epoch: 395 | Train Loss: 3.33528 | Valid Loss: 3.48544 |Train Accs: 0.26278 | Valid Accs: 0.24747 | Time: 0.48 seconds
# Epoch: 396 | Train Loss: 3.34055 | Valid Loss: 3.48185 |Train Accs: 0.26178 | Valid Accs: 0.24563 | Time: 0.55 seconds
# Epoch: 397 | Train Loss: 3.33645 | Valid Loss: 3.48207 |Train Accs: 0.26555 | Valid Accs: 0.24715 | Time: 0.50 seconds
# Epoch: 398 | Train Loss: 3.33528 | Valid Loss: 3.47676 |Train Accs: 0.26255 | Valid Accs: 0.24671 | Time: 0.51 seconds
# Epoch: 399 | Train Loss: 3.33299 | Valid Loss: 3.47633 |Train Accs: 0.26638 | Valid Accs: 0.24758 | Time: 0.53 seconds
# Epoch: 400 | Train Loss: 3.33026 | Valid Loss: 3.47293 |Train Accs: 0.26620 | Valid Accs: 0.24769 | Time: 0.52 seconds
# Epoch: 401 | Train Loss: 3.33011 | Valid Loss: 3.47134 |Train Accs: 0.26040 | Valid Accs: 0.24736 | Time: 0.52 seconds
# Epoch: 402 | Train Loss: 3.32501 | Valid Loss: 3.46798 |Train Accs: 0.26471 | Valid Accs: 0.24910 | Time: 0.83 seconds
# Epoch: 403 | Train Loss: 3.32487 | Valid Loss: 3.46828 |Train Accs: 0.26267 | Valid Accs: 0.24899 | Time: 0.48 seconds
# ...
# Epoch: 4872 | Train Loss: 0.42382 | Valid Loss: 1.72378 |Train Accs: 0.95554 | Valid Accs: 0.55338 | Time: 0.48 seconds
# Epoch: 4873 | Train Loss: 0.42719 | Valid Loss: 1.72527 |Train Accs: 0.95449 | Valid Accs: 0.55446 | Time: 0.47 seconds
# Epoch: 4874 | Train Loss: 0.42326 | Valid Loss: 1.72763 |Train Accs: 0.95695 | Valid Accs: 0.55783 | Time: 0.48 seconds
# Epoch: 4875 | Train Loss: 0.42408 | Valid Loss: 1.72568 |Train Accs: 0.95557 | Valid Accs: 0.55457 | Time: 0.48 seconds
# Epoch: 4876 | Train Loss: 0.42373 | Valid Loss: 1.72661 |Train Accs: 0.95711 | Valid Accs: 0.55631 | Time: 0.59 seconds
# Epoch: 4877 | Train Loss: 0.42344 | Valid Loss: 1.72390 |Train Accs: 0.95525 | Valid Accs: 0.55587 | Time: 0.47 seconds
# Epoch: 4878 | Train Loss: 0.42283 | Valid Loss: 1.72372 |Train Accs: 0.95711 | Valid Accs: 0.55718 | Time: 0.48 seconds
# Epoch: 4879 | Train Loss: 0.42400 | Valid Loss: 1.72481 |Train Accs: 0.95476 | Valid Accs: 0.55251 | Time: 0.48 seconds
# Epoch: 4880 | Train Loss: 0.42295 | Valid Loss: 1.72517 |Train Accs: 0.95566 | Valid Accs: 0.55641 | Time: 0.47 seconds
# Epoch: 4881 | Train Loss: 0.42557 | Valid Loss: 1.72361 |Train Accs: 0.95538 | Valid Accs: 0.55501 | Time: 0.48 seconds
# Epoch: 4882 | Train Loss: 0.42438 | Valid Loss: 1.72525 |Train Accs: 0.95667 | Valid Accs: 0.55392 | Time: 0.48 seconds
# Epoch: 4883 | Train Loss: 0.42609 | Valid Loss: 1.72366 |Train Accs: 0.95513 | Valid Accs: 0.55663 | Time: 0.48 seconds
# Epoch: 4884 | Train Loss: 0.42099 | Valid Loss: 1.72567 |Train Accs: 0.95569 | Valid Accs: 0.55587 | Time: 0.49 seconds
# Epoch: 4885 | Train Loss: 0.41695 | Valid Loss: 1.72637 |Train Accs: 0.95772 | Valid Accs: 0.55316 | Time: 0.58 seconds
# Epoch: 4886 | Train Loss: 0.42128 | Valid Loss: 1.72493 |Train Accs: 0.95518 | Valid Accs: 0.55598 | Time: 0.48 seconds
# Epoch: 4887 | Train Loss: 0.41883 | Valid Loss: 1.72644 |Train Accs: 0.95650 | Valid Accs: 0.55489 | Time: 0.47 seconds
# Epoch: 4888 | Train Loss: 0.42373 | Valid Loss: 1.72413 |Train Accs: 0.95683 | Valid Accs: 0.55609 | Time: 0.70 seconds
# Epoch: 4889 | Train Loss: 0.41961 | Valid Loss: 1.72258 |Train Accs: 0.95753 | Valid Accs: 0.55913 | Time: 0.54 seconds
# Epoch: 4890 | Train Loss: 0.42295 | Valid Loss: 1.72391 |Train Accs: 0.95611 | Valid Accs: 0.55793 | Time: 0.48 seconds
# Epoch: 4891 | Train Loss: 0.42475 | Valid Loss: 1.72466 |Train Accs: 0.95496 | Valid Accs: 0.55522 | Time: 0.49 seconds
# Epoch: 4892 | Train Loss: 0.42027 | Valid Loss: 1.72489 |Train Accs: 0.95761 | Valid Accs: 0.55500 | Time: 0.58 seconds
# Epoch: 4893 | Train Loss: 0.42028 | Valid Loss: 1.72169 |Train Accs: 0.95541 | Valid Accs: 0.55522 | Time: 0.52 seconds
# Epoch: 4894 | Train Loss: 0.41555 | Valid Loss: 1.72343 |Train Accs: 0.95912 | Valid Accs: 0.55631 | Time: 0.48 seconds
# Epoch: 4895 | Train Loss: 0.42112 | Valid Loss: 1.72483 |Train Accs: 0.95711 | Valid Accs: 0.55587 | Time: 0.48 seconds
# Epoch: 4896 | Train Loss: 0.42350 | Valid Loss: 1.72551 |Train Accs: 0.95513 | Valid Accs: 0.55208 | Time: 0.48 seconds
# Epoch: 4897 | Train Loss: 0.42425 | Valid Loss: 1.72588 |Train Accs: 0.95499 | Valid Accs: 0.55576 | Time: 0.49 seconds
# Epoch: 4898 | Train Loss: 0.41630 | Valid Loss: 1.72372 |Train Accs: 0.95760 | Valid Accs: 0.55652 | Time: 0.48 seconds
# Epoch: 4899 | Train Loss: 0.42103 | Valid Loss: 1.72315 |Train Accs: 0.95661 | Valid Accs: 0.55555 | Time: 0.48 seconds
# Epoch: 4900 | Train Loss: 0.41823 | Valid Loss: 1.72282 |Train Accs: 0.95653 | Valid Accs: 0.55555 | Time: 0.61 seconds
# Epoch: 4901 | Train Loss: 0.41726 | Valid Loss: 1.72327 |Train Accs: 0.95655 | Valid Accs: 0.55663 | Time: 0.50 seconds
# Epoch: 4902 | Train Loss: 0.41558 | Valid Loss: 1.72538 |Train Accs: 0.95600 | Valid Accs: 0.55555 | Time: 0.47 seconds
# Epoch: 4903 | Train Loss: 0.42008 | Valid Loss: 1.72489 |Train Accs: 0.95599 | Valid Accs: 0.55685 | Time: 0.47 seconds
# Epoch: 4904 | Train Loss: 0.41889 | Valid Loss: 1.72660 |Train Accs: 0.95636 | Valid Accs: 0.55685 | Time: 0.48 seconds
# Epoch: 4905 | Train Loss: 0.41913 | Valid Loss: 1.72318 |Train Accs: 0.95655 | Valid Accs: 0.55815 | Time: 0.48 seconds
# Epoch: 4906 | Train Loss: 0.41486 | Valid Loss: 1.72532 |Train Accs: 0.95909 | Valid Accs: 0.55783 | Time: 0.58 seconds
# Epoch: 4907 | Train Loss: 0.42103 | Valid Loss: 1.72425 |Train Accs: 0.95669 | Valid Accs: 0.55620 | Time: 0.49 seconds
# Epoch: 4908 | Train Loss: 0.41428 | Valid Loss: 1.72298 |Train Accs: 0.95833 | Valid Accs: 0.55663 | Time: 0.47 seconds
# Epoch: 4909 | Train Loss: 0.41926 | Valid Loss: 1.72307 |Train Accs: 0.95691 | Valid Accs: 0.55359 | Time: 0.56 seconds
# Epoch: 4910 | Train Loss: 0.41934 | Valid Loss: 1.72452 |Train Accs: 0.95703 | Valid Accs: 0.55359 | Time: 0.61 seconds
# Epoch: 4911 | Train Loss: 0.41314 | Valid Loss: 1.72316 |Train Accs: 0.95690 | Valid Accs: 0.55620 | Time: 0.48 seconds
# Epoch: 4912 | Train Loss: 0.41597 | Valid Loss: 1.72412 |Train Accs: 0.95638 | Valid Accs: 0.55522 | Time: 0.48 seconds
# Epoch: 4913 | Train Loss: 0.41430 | Valid Loss: 1.72386 |Train Accs: 0.95942 | Valid Accs: 0.55522 | Time: 0.48 seconds
# Epoch: 4914 | Train Loss: 0.41720 | Valid Loss: 1.72325 |Train Accs: 0.95828 | Valid Accs: 0.55652 | Time: 0.71 seconds
# Epoch: 4915 | Train Loss: 0.41753 | Valid Loss: 1.72248 |Train Accs: 0.95519 | Valid Accs: 0.55674 | Time: 0.75 seconds
# Epoch: 4916 | Train Loss: 0.41662 | Valid Loss: 1.72165 |Train Accs: 0.95748 | Valid Accs: 0.55793 | Time: 0.52 seconds
# Epoch: 4917 | Train Loss: 0.41892 | Valid Loss: 1.72290 |Train Accs: 0.95606 | Valid Accs: 0.55511 | Time: 0.48 seconds
# Epoch: 4918 | Train Loss: 0.41756 | Valid Loss: 1.72481 |Train Accs: 0.95769 | Valid Accs: 0.55218 | Time: 0.48 seconds
# Epoch: 4919 | Train Loss: 0.41393 | Valid Loss: 1.72059 |Train Accs: 0.95871 | Valid Accs: 0.55555 | Time: 0.52 seconds
# Epoch: 4920 | Train Loss: 0.41329 | Valid Loss: 1.72488 |Train Accs: 0.95700 | Valid Accs: 0.55565 | Time: 0.48 seconds
# Epoch: 4921 | Train Loss: 0.41479 | Valid Loss: 1.72314 |Train Accs: 0.95770 | Valid Accs: 0.55598 | Time: 0.58 seconds
# Epoch: 4922 | Train Loss: 0.41478 | Valid Loss: 1.72291 |Train Accs: 0.95681 | Valid Accs: 0.55652 | Time: 0.48 seconds
# Epoch: 4923 | Train Loss: 0.41460 | Valid Loss: 1.72317 |Train Accs: 0.95513 | Valid Accs: 0.55316 | Time: 0.47 seconds
# Epoch: 4924 | Train Loss: 0.41035 | Valid Loss: 1.72228 |Train Accs: 0.95882 | Valid Accs: 0.55392 | Time: 0.48 seconds
# Epoch: 4925 | Train Loss: 0.41520 | Valid Loss: 1.72477 |Train Accs: 0.95594 | Valid Accs: 0.55522 | Time: 0.48 seconds
# Epoch: 4926 | Train Loss: 0.41713 | Valid Loss: 1.72269 |Train Accs: 0.95686 | Valid Accs: 0.55728 | Time: 0.49 seconds
# Epoch: 4927 | Train Loss: 0.41229 | Valid Loss: 1.72205 |Train Accs: 0.95739 | Valid Accs: 0.55414 | Time: 0.48 seconds
# Epoch: 4928 | Train Loss: 0.41878 | Valid Loss: 1.72335 |Train Accs: 0.95554 | Valid Accs: 0.55620 | Time: 0.49 seconds
# Epoch: 4929 | Train Loss: 0.41137 | Valid Loss: 1.72449 |Train Accs: 0.95926 | Valid Accs: 0.55457 | Time: 0.48 seconds
# Epoch: 4930 | Train Loss: 0.41306 | Valid Loss: 1.72325 |Train Accs: 0.95773 | Valid Accs: 0.55544 | Time: 0.67 seconds
# Epoch: 4931 | Train Loss: 0.41297 | Valid Loss: 1.72253 |Train Accs: 0.95658 | Valid Accs: 0.55435 | Time: 0.59 seconds
# Epoch: 4932 | Train Loss: 0.41429 | Valid Loss: 1.72352 |Train Accs: 0.95639 | Valid Accs: 0.55717 | Time: 0.48 seconds
# Epoch: 4933 | Train Loss: 0.40942 | Valid Loss: 1.72026 |Train Accs: 0.95822 | Valid Accs: 0.55501 | Time: 0.52 seconds
# Epoch: 4934 | Train Loss: 0.41372 | Valid Loss: 1.72221 |Train Accs: 0.95702 | Valid Accs: 0.55847 | Time: 0.48 seconds
# Epoch: 4935 | Train Loss: 0.41353 | Valid Loss: 1.72254 |Train Accs: 0.95605 | Valid Accs: 0.55500 | Time: 0.48 seconds
# Epoch: 4936 | Train Loss: 0.41162 | Valid Loss: 1.72206 |Train Accs: 0.95859 | Valid Accs: 0.55565 | Time: 0.50 seconds
# Epoch: 4937 | Train Loss: 0.40952 | Valid Loss: 1.72235 |Train Accs: 0.95923 | Valid Accs: 0.55555 | Time: 0.63 seconds
# Epoch: 4938 | Train Loss: 0.40722 | Valid Loss: 1.72125 |Train Accs: 0.95965 | Valid Accs: 0.55588 | Time: 0.48 seconds
# Epoch: 4939 | Train Loss: 0.41157 | Valid Loss: 1.72395 |Train Accs: 0.95580 | Valid Accs: 0.55468 | Time: 0.48 seconds
# Epoch: 4940 | Train Loss: 0.41081 | Valid Loss: 1.72268 |Train Accs: 0.95739 | Valid Accs: 0.55793 | Time: 0.48 seconds
# Epoch: 4941 | Train Loss: 0.40868 | Valid Loss: 1.72168 |Train Accs: 0.95789 | Valid Accs: 0.55425 | Time: 0.48 seconds
# Epoch: 4942 | Train Loss: 0.41079 | Valid Loss: 1.72431 |Train Accs: 0.95897 | Valid Accs: 0.55446 | Time: 0.48 seconds
# Epoch: 4943 | Train Loss: 0.41180 | Valid Loss: 1.72325 |Train Accs: 0.95640 | Valid Accs: 0.55435 | Time: 0.49 seconds
# Epoch: 4944 | Train Loss: 0.41277 | Valid Loss: 1.72263 |Train Accs: 0.95836 | Valid Accs: 0.55652 | Time: 0.49 seconds
# Epoch: 4945 | Train Loss: 0.41229 | Valid Loss: 1.72390 |Train Accs: 0.95756 | Valid Accs: 0.55262 | Time: 0.58 seconds
# Epoch: 4946 | Train Loss: 0.40754 | Valid Loss: 1.72360 |Train Accs: 0.95805 | Valid Accs: 0.55620 | Time: 0.51 seconds
# Epoch: 4947 | Train Loss: 0.41150 | Valid Loss: 1.72240 |Train Accs: 0.95680 | Valid Accs: 0.55739 | Time: 0.47 seconds
# Epoch: 4948 | Train Loss: 0.41143 | Valid Loss: 1.72120 |Train Accs: 0.95811 | Valid Accs: 0.55717 | Time: 0.47 seconds
# Epoch: 4949 | Train Loss: 0.41196 | Valid Loss: 1.72418 |Train Accs: 0.95840 | Valid Accs: 0.55652 | Time: 0.48 seconds
# Epoch: 4950 | Train Loss: 0.41216 | Valid Loss: 1.72252 |Train Accs: 0.95820 | Valid Accs: 0.55782 | Time: 0.51 seconds
# Epoch: 4951 | Train Loss: 0.41193 | Valid Loss: 1.72419 |Train Accs: 0.95981 | Valid Accs: 0.55468 | Time: 0.58 seconds
# Epoch: 4952 | Train Loss: 0.40704 | Valid Loss: 1.72153 |Train Accs: 0.96144 | Valid Accs: 0.55609 | Time: 0.71 seconds
# Epoch: 4953 | Train Loss: 0.40627 | Valid Loss: 1.72172 |Train Accs: 0.95904 | Valid Accs: 0.55511 | Time: 0.48 seconds
# Epoch: 4954 | Train Loss: 0.41160 | Valid Loss: 1.72347 |Train Accs: 0.95730 | Valid Accs: 0.55511 | Time: 0.48 seconds
# Epoch: 4955 | Train Loss: 0.40959 | Valid Loss: 1.72212 |Train Accs: 0.95931 | Valid Accs: 0.55815 | Time: 0.47 seconds
# Epoch: 4956 | Train Loss: 0.40560 | Valid Loss: 1.72028 |Train Accs: 0.95739 | Valid Accs: 0.55587 | Time: 0.47 seconds
# Epoch: 4957 | Train Loss: 0.40840 | Valid Loss: 1.72427 |Train Accs: 0.95764 | Valid Accs: 0.55349 | Time: 0.47 seconds
# Epoch: 4958 | Train Loss: 0.40635 | Valid Loss: 1.72130 |Train Accs: 0.95813 | Valid Accs: 0.55446 | Time: 0.48 seconds
# Epoch: 4959 | Train Loss: 0.41361 | Valid Loss: 1.72267 |Train Accs: 0.95685 | Valid Accs: 0.55392 | Time: 0.48 seconds
# Epoch: 4960 | Train Loss: 0.40897 | Valid Loss: 1.72352 |Train Accs: 0.95708 | Valid Accs: 0.55620 | Time: 0.60 seconds
# Epoch: 4961 | Train Loss: 0.40504 | Valid Loss: 1.72298 |Train Accs: 0.95973 | Valid Accs: 0.55859 | Time: 0.49 seconds
# Epoch: 4962 | Train Loss: 0.40620 | Valid Loss: 1.71847 |Train Accs: 0.95950 | Valid Accs: 0.55674 | Time: 0.52 seconds
# Epoch: 4963 | Train Loss: 0.40479 | Valid Loss: 1.72157 |Train Accs: 0.95982 | Valid Accs: 0.55522 | Time: 0.48 seconds
# Epoch: 4964 | Train Loss: 0.40528 | Valid Loss: 1.72297 |Train Accs: 0.95987 | Valid Accs: 0.55468 | Time: 0.47 seconds
# Epoch: 4965 | Train Loss: 0.40228 | Valid Loss: 1.72224 |Train Accs: 0.95914 | Valid Accs: 0.55706 | Time: 0.63 seconds
# Epoch: 4966 | Train Loss: 0.40450 | Valid Loss: 1.72273 |Train Accs: 0.96062 | Valid Accs: 0.55696 | Time: 0.86 seconds
# Epoch: 4967 | Train Loss: 0.40598 | Valid Loss: 1.72367 |Train Accs: 0.95807 | Valid Accs: 0.55273 | Time: 0.73 seconds
# Epoch: 4968 | Train Loss: 0.40715 | Valid Loss: 1.72167 |Train Accs: 0.95914 | Valid Accs: 0.55598 | Time: 0.73 seconds
# Epoch: 4969 | Train Loss: 0.40713 | Valid Loss: 1.72492 |Train Accs: 0.95711 | Valid Accs: 0.55479 | Time: 0.73 seconds
# Epoch: 4970 | Train Loss: 0.40805 | Valid Loss: 1.72097 |Train Accs: 0.95889 | Valid Accs: 0.55652 | Time: 0.73 seconds
# Epoch: 4971 | Train Loss: 0.40615 | Valid Loss: 1.72143 |Train Accs: 0.96035 | Valid Accs: 0.55457 | Time: 1.07 seconds
# Epoch: 4972 | Train Loss: 0.40439 | Valid Loss: 1.72049 |Train Accs: 0.95806 | Valid Accs: 0.55338 | Time: 1.08 seconds
# Epoch: 4973 | Train Loss: 0.40704 | Valid Loss: 1.72190 |Train Accs: 0.95845 | Valid Accs: 0.55685 | Time: 1.08 seconds
# Epoch: 4974 | Train Loss: 0.40317 | Valid Loss: 1.72081 |Train Accs: 0.95928 | Valid Accs: 0.55750 | Time: 0.73 seconds
# Epoch: 4975 | Train Loss: 0.40302 | Valid Loss: 1.72242 |Train Accs: 0.95870 | Valid Accs: 0.55457 | Time: 0.86 seconds
# Epoch: 4976 | Train Loss: 0.40387 | Valid Loss: 1.72293 |Train Accs: 0.95730 | Valid Accs: 0.55533 | Time: 0.73 seconds
# Epoch: 4977 | Train Loss: 0.40357 | Valid Loss: 1.72152 |Train Accs: 0.96052 | Valid Accs: 0.55598 | Time: 0.74 seconds
# Epoch: 4978 | Train Loss: 0.40419 | Valid Loss: 1.72190 |Train Accs: 0.95775 | Valid Accs: 0.55327 | Time: 0.73 seconds
# Epoch: 4979 | Train Loss: 0.40144 | Valid Loss: 1.72086 |Train Accs: 0.95990 | Valid Accs: 0.55631 | Time: 0.72 seconds
# Epoch: 4980 | Train Loss: 0.40205 | Valid Loss: 1.72185 |Train Accs: 0.95933 | Valid Accs: 0.55707 | Time: 0.72 seconds
# Epoch: 4981 | Train Loss: 0.40438 | Valid Loss: 1.72182 |Train Accs: 0.95961 | Valid Accs: 0.55403 | Time: 0.60 seconds
# Epoch: 4982 | Train Loss: 0.40522 | Valid Loss: 1.72123 |Train Accs: 0.95811 | Valid Accs: 0.55316 | Time: 0.58 seconds
# Epoch: 4983 | Train Loss: 0.39880 | Valid Loss: 1.72137 |Train Accs: 0.95755 | Valid Accs: 0.55620 | Time: 0.48 seconds
# Epoch: 4984 | Train Loss: 0.40279 | Valid Loss: 1.72136 |Train Accs: 0.95826 | Valid Accs: 0.55457 | Time: 0.49 seconds
# Epoch: 4985 | Train Loss: 0.39769 | Valid Loss: 1.72353 |Train Accs: 0.96193 | Valid Accs: 0.55717 | Time: 0.52 seconds
# Epoch: 4986 | Train Loss: 0.40174 | Valid Loss: 1.72221 |Train Accs: 0.95897 | Valid Accs: 0.55533 | Time: 0.65 seconds
# Epoch: 4987 | Train Loss: 0.40277 | Valid Loss: 1.72071 |Train Accs: 0.95983 | Valid Accs: 0.55718 | Time: 0.48 seconds
# Epoch: 4988 | Train Loss: 0.40006 | Valid Loss: 1.72152 |Train Accs: 0.96082 | Valid Accs: 0.55555 | Time: 0.48 seconds
# Epoch: 4989 | Train Loss: 0.40037 | Valid Loss: 1.72266 |Train Accs: 0.95996 | Valid Accs: 0.55848 | Time: 0.48 seconds
# Epoch: 4990 | Train Loss: 0.40246 | Valid Loss: 1.72032 |Train Accs: 0.95777 | Valid Accs: 0.55446 | Time: 0.58 seconds
# Epoch: 4991 | Train Loss: 0.40171 | Valid Loss: 1.72112 |Train Accs: 0.95901 | Valid Accs: 0.55489 | Time: 0.48 seconds
# Epoch: 4992 | Train Loss: 0.39976 | Valid Loss: 1.71967 |Train Accs: 0.96118 | Valid Accs: 0.55555 | Time: 0.48 seconds
# Epoch: 4993 | Train Loss: 0.39914 | Valid Loss: 1.72177 |Train Accs: 0.96060 | Valid Accs: 0.55783 | Time: 0.48 seconds
# Epoch: 4994 | Train Loss: 0.39672 | Valid Loss: 1.71980 |Train Accs: 0.96497 | Valid Accs: 0.55511 | Time: 0.48 seconds
# Epoch: 4995 | Train Loss: 0.39855 | Valid Loss: 1.72237 |Train Accs: 0.96029 | Valid Accs: 0.55468 | Time: 0.49 seconds
# Epoch: 4996 | Train Loss: 0.39874 | Valid Loss: 1.71958 |Train Accs: 0.96070 | Valid Accs: 0.55696 | Time: 0.58 seconds
# Epoch: 4997 | Train Loss: 0.40169 | Valid Loss: 1.72359 |Train Accs: 0.96020 | Valid Accs: 0.55424 | Time: 0.48 seconds
# Epoch: 4998 | Train Loss: 0.40282 | Valid Loss: 1.72083 |Train Accs: 0.95887 | Valid Accs: 0.55414 | Time: 0.48 seconds
# Epoch: 4999 | Train Loss: 0.40093 | Valid Loss: 1.72421 |Train Accs: 0.95963 | Valid Accs: 0.55392 | Time: 0.49 seconds
# Epoch: 5000 | Train Loss: 0.39772 | Valid Loss: 1.72008 |Train Accs: 0.96009 | Valid Accs: 0.55511 | Time: 0.47 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 4962
#
# **************************************************
#
# Best Validation Accs at Epoch 4889
#
# **************************************************
#
# Time Taken [5000 Epochs] : 47.06 minutes
#
# **************************************************
# **************************************************
#
# Total Time Taken for 5-Fold CV : 224.28 minutes
#
# **************************************************

# %% [markdown]
# ### **Get SWIN Features for the Test Set**

# %%
# train_df = pd.read_csv("../input/sorghum-id-fgvc-9/train_cultivar_mapping.csv")
# ss_df = pd.read_csv("../input/sorghum-id-fgvc-9/sample_submission.csv")

# broken_images = [filename for filename in train_df.image if filename not in os.listdir("../input/sorghum-id-fgvc-9/train_images")]
# for broken_image in broken_images:
#     index = train_df.index[train_df.image == broken_image]
#     train_df = train_df.drop(index=index)
    
# filenames = train_df.image.copy().values
# labels    = train_df.cultivar.copy().values 

# labels = le.fit_transform(labels)

# ts_filenames = ss_df.filename.copy().values
# ts_features = np.zeros((len(ts_filenames), 1024))

# %%
# model = timm.create_model("swin_base_patch4_window7_224_in22k", pretrained=True).to(DEVICE)
# model = torch.nn.Sequential(*[*model.children()][:-3])

# dataloader_setup = FEDS("../input/sorghum-id-fgvc-9/test", ts_filenames, TRANSFORM)
# dataloader = DL(dataloader_setup, batch_size=64, shuffle=False)

# ts_features = torch.zeros(1, 1024).to(DEVICE)

# for X in dataloader:
#     X = X.to(DEVICE)
#     with torch.no_grad():
#         output = model(X).last_hidden_state
#     ts_features = torch.cat((ts_features, output[:, 0, :]), dim=0)

# ts_features = ts_features[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Submission**

# %%
# ts_data_setup = DS(ts_features, None, "test")
# ts_data = DL(ts_data_setup, batch_size=batch_size, shuffle=False)

# torch.manual_seed(SEED)
# model = Model(IL=ts_features.shape[1], HL=HL, DP=0.25, use_WN=True).to(DEVICE)

# best_model_fold = _____
# y_pred = predict(model=model, dataloader=ts_data, path=os.path.join(CLASSIFIER_HEAD_PATH, f"state_fold_{best_model_fold}.pt"))

# ss_df["cultivar"] = le.inverse_transform(y_pred.astype("uint8"))
# ss_df.to_csv("submission.csv", index=False)
