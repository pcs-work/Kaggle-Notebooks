# %%
# !pip install --upgrade timm

# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
# import timm
import torch
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torch.nn.utils import weight_norm as WN
# from torchvision import transforms

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Constants**

# %%
SEED = 42
# SIZE = 384
# FV_LENGTH = 1536
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

FEATURE_PATH = "../input/fgvc9-swinl38422k"

# CLASSIFIER_HEAD_PATH = "../input/fgvc9-swin38422k-train/saves"
# TRANSFORM = transforms.Compose([transforms.ToTensor(), 
#                                 transforms.Normalize([0.485, 0.456, 0.406], 
#                                                      [0.229, 0.224, 0.225]),
#                                ])

SAVE_PATH = "saves"
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# %%
def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
# def get_image(path: str, size: int) -> np.ndarray:
#     image = cv2.imread(path, cv2.IMREAD_COLOR)
#     image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
#     return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_AREA)

    
def show_graphs(L: list, A: list) -> None:
    TL, VL, TA, VA = [], [], [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()

# %% [markdown]
# ### **Dataset Templatea**

# %%
# class FEDS(Dataset):
#     def __init__(self, base_path: str, filenames: np.ndarray, transform):
#         self.base_path = base_path
#         self.filenames = filenames
#         self.transform = transform
    
#     def __len__(self):
#         return self.filenames.shape[0]
    
#     def __getitem__(self, idx):
#         return self.transform(get_image(os.path.join(self.base_path, self.filenames[idx])))


class DS(Dataset):
    def __init__(self, X=None, y=None, mode="train"):
        self.mode = mode

        assert(re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE) or re.match(r"test", self.mode, re.IGNORECASE))

        self.X = X
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            self.y = y
    
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            return torch.FloatTensor(self.X[idx]), torch.LongTensor(self.y[idx])
        else:
            return torch.FloatTensor(self.X[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, IL: int=None, HL: list=None, DP: float=None, use_WN: bool=False):
        super(Model, self).__init__()

        self.model = nn.Sequential()

        if len(HL) == 1:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=100)))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=100))

        
        elif len(HL) == 2:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=100)))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=100))
        
        elif len(HL) == 3:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=HL[2])))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=HL[2]))
            if isinstance(DP, float):
                self.model.add_module("DP3", nn.Dropout(p=DP))
            self.model.add_module("AN3", nn.ReLU())
            self.model.add_module("BN4", nn.BatchNorm1d(num_features=HL[2], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC4", WN(nn.Linear(in_features=HL[2], out_features=100)))
            else:
                self.model.add_module("FC4", nn.Linear(in_features=HL[2], out_features=100))
    
    def get_optimizer(self, lr=1e-3, wd=0.0):
        return optim.Adam(self.parameters(), lr=lr, weight_decay=wd)

    def get_plateau_scheduler(self, optimizer=None, patience=5, eps=1e-8):
        return optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, patience=patience, eps=eps)
    
    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helper**

# %%
def fit(model=None, optimizer=None, scheduler=None, epochs=None, early_stopping_patience=None, dataloaders=None, fold=None, verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        print(f"Training Fold {fold}...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies = [], []
    name = f"state_fold_{fold}.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []
            
            for X, y in dataloaders[phase]:
                X, y = X.to(DEVICE), y.to(DEVICE).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict": model.state_dict(),
                            "optim_state_dict": optimizer.state_dict()},
                           os.path.join(SAVE_PATH, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save({"model_state_dict" : model.state_dict(),
                        "optim_state_dict" : optimizer.state_dict()},
                        os.path.join(SAVE_PATH, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler:
            # scheduler.step(epochLoss["valid"])
            scheduler.step()
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, BLE, BAE, name


# def predict(model=None, dataloader=None, path=None) -> np.ndarray:
#     model.load_state_dict(torch.load(path, map_location=DEVICE)["model_state_dict"])
#     model.to(DEVICE)    
#     model.eval()
    
#     y_pred = torch.zeros(1, 1).to(DEVICE)
    
#     for X in dataloader:
#         X = X.to(DEVICE)
#         with torch.no_grad():
#             output = torch.argmax(torch.exp(model(X)), dim=1)
#         y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
#     return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Load Data**

# %%
features = np.load(os.path.join(FEATURE_PATH, "features.npy"))
labels   = np.load(os.path.join(FEATURE_PATH, "labels.npy"))

# %% [markdown]
# ### **Params**

# %%
DEBUG: bool = False
    
if DEBUG:
    n_splits = 3
    epochs = 2
    HL = [4]
else:
    n_splits = 5
    epochs = 500
    HL = [2048, 1024, 512]

batch_size = 1024
lr = 1e-4
wd = 1e-5
early_stopping = 25
patience = None
eps = None

# %% [markdown]
# ### **Train**

# %%
fold = 1

start_time = time()
for tr_idx, va_idx in StratifiedKFold(n_splits=n_splits, random_state=SEED, shuffle=True).split(features, labels):
    tr_features, va_features, tr_labels, va_labels = features[tr_idx], features[va_idx], labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(tr_features, tr_labels.reshape(-1, 1), "train")
    va_data_setup = DS(va_features, va_labels.reshape(-1, 1), "valid")

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=batch_size, shuffle=True, generator=torch.manual_seed(SEED)),
        "valid" : DL(va_data_setup, batch_size=batch_size, shuffle=False),
    }

    torch.manual_seed(SEED)
    model = Model(IL=tr_features.shape[1], HL=HL, DP=0.5, use_WN=True).to(DEVICE)
    optimizer = model.get_optimizer(lr=lr, wd=wd)
    # scheduler = None
    # if isinstance(patience, int) and isinstance(eps, float):
    #    scheduler = get_plateau_scheduler(optimizer=optimizer, patience=patience, eps=eps)
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, max_lr=1e-3, 
                                              epochs=100, steps_per_epoch=len(dataloaders["train"]),
                                              pct_start=0.2, div_factor=1e3, final_div_factor=1e3)
    
    L, A, BLE, BAE, name = fit(model=model, optimizer=optimizer, scheduler=scheduler, 
                           epochs=epochs, early_stopping_patience=early_stopping, 
                           dataloaders=dataloaders, fold=fold, verbose=True)

    breaker()
    show_graphs(L, A)
    fold += 1

breaker()
print(f"Total Time Taken for {n_splits}-Fold CV : {(time()-start_time)/60:.2f} minutes")
breaker()
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.76730 | Valid Loss: 4.61741 |Train Accs: 0.01030 | Valid Accs: 0.01033 | Time: 1.58 seconds
# Epoch: 2 | Train Loss: 4.76788 | Valid Loss: 4.62589 |Train Accs: 0.01051 | Valid Accs: 0.01053 | Time: 0.55 seconds
# Epoch: 3 | Train Loss: 4.76533 | Valid Loss: 4.62592 |Train Accs: 0.01030 | Valid Accs: 0.01073 | Time: 0.54 seconds
# Epoch: 4 | Train Loss: 4.76896 | Valid Loss: 4.62401 |Train Accs: 0.00982 | Valid Accs: 0.01112 | Time: 0.55 seconds
# Epoch: 5 | Train Loss: 4.76702 | Valid Loss: 4.62189 |Train Accs: 0.01100 | Valid Accs: 0.01131 | Time: 0.65 seconds
# Epoch: 6 | Train Loss: 4.75737 | Valid Loss: 4.61923 |Train Accs: 0.01187 | Valid Accs: 0.01112 | Time: 0.54 seconds
# Epoch: 7 | Train Loss: 4.75873 | Valid Loss: 4.61651 |Train Accs: 0.01117 | Valid Accs: 0.01151 | Time: 0.69 seconds
# Epoch: 8 | Train Loss: 4.75515 | Valid Loss: 4.61362 |Train Accs: 0.01193 | Valid Accs: 0.01190 | Time: 0.71 seconds
# Epoch: 9 | Train Loss: 4.75746 | Valid Loss: 4.60955 |Train Accs: 0.01025 | Valid Accs: 0.01229 | Time: 0.96 seconds
# Epoch: 10 | Train Loss: 4.73998 | Valid Loss: 4.60483 |Train Accs: 0.01062 | Valid Accs: 0.01307 | Time: 0.68 seconds
# Epoch: 11 | Train Loss: 4.74450 | Valid Loss: 4.60039 |Train Accs: 0.01182 | Valid Accs: 0.01522 | Time: 0.69 seconds
# Epoch: 12 | Train Loss: 4.73993 | Valid Loss: 4.59465 |Train Accs: 0.01160 | Valid Accs: 0.01737 | Time: 0.73 seconds
# Epoch: 13 | Train Loss: 4.73372 | Valid Loss: 4.58820 |Train Accs: 0.00976 | Valid Accs: 0.01737 | Time: 0.90 seconds
# Epoch: 14 | Train Loss: 4.72331 | Valid Loss: 4.58083 |Train Accs: 0.01111 | Valid Accs: 0.02068 | Time: 0.99 seconds
# Epoch: 15 | Train Loss: 4.71336 | Valid Loss: 4.57270 |Train Accs: 0.01382 | Valid Accs: 0.02283 | Time: 0.75 seconds
# Epoch: 16 | Train Loss: 4.70160 | Valid Loss: 4.56388 |Train Accs: 0.01263 | Valid Accs: 0.02712 | Time: 0.94 seconds
# Epoch: 17 | Train Loss: 4.69405 | Valid Loss: 4.55387 |Train Accs: 0.01405 | Valid Accs: 0.03064 | Time: 0.78 seconds
# Epoch: 18 | Train Loss: 4.68280 | Valid Loss: 4.54271 |Train Accs: 0.01367 | Valid Accs: 0.03590 | Time: 0.68 seconds
# Epoch: 19 | Train Loss: 4.66227 | Valid Loss: 4.53049 |Train Accs: 0.01539 | Valid Accs: 0.04019 | Time: 0.69 seconds
# Epoch: 20 | Train Loss: 4.65795 | Valid Loss: 4.51710 |Train Accs: 0.01712 | Valid Accs: 0.04625 | Time: 0.79 seconds
# Epoch: 21 | Train Loss: 4.64041 | Valid Loss: 4.50232 |Train Accs: 0.01925 | Valid Accs: 0.05269 | Time: 0.69 seconds
# Epoch: 22 | Train Loss: 4.62647 | Valid Loss: 4.48625 |Train Accs: 0.02103 | Valid Accs: 0.05952 | Time: 0.68 seconds
# Epoch: 23 | Train Loss: 4.60862 | Valid Loss: 4.46878 |Train Accs: 0.02038 | Valid Accs: 0.06577 | Time: 1.64 seconds
# Epoch: 24 | Train Loss: 4.58745 | Valid Loss: 4.44937 |Train Accs: 0.02428 | Valid Accs: 0.07357 | Time: 0.68 seconds
# Epoch: 25 | Train Loss: 4.56559 | Valid Loss: 4.42841 |Train Accs: 0.02520 | Valid Accs: 0.08118 | Time: 0.69 seconds
# Epoch: 26 | Train Loss: 4.54949 | Valid Loss: 4.40531 |Train Accs: 0.02917 | Valid Accs: 0.08704 | Time: 0.93 seconds
# Epoch: 27 | Train Loss: 4.51584 | Valid Loss: 4.38005 |Train Accs: 0.03202 | Valid Accs: 0.09620 | Time: 0.68 seconds
# Epoch: 28 | Train Loss: 4.49855 | Valid Loss: 4.35304 |Train Accs: 0.03421 | Valid Accs: 0.10186 | Time: 0.68 seconds
# Epoch: 29 | Train Loss: 4.47050 | Valid Loss: 4.32313 |Train Accs: 0.03865 | Valid Accs: 0.10888 | Time: 1.35 seconds
# Epoch: 30 | Train Loss: 4.44540 | Valid Loss: 4.29176 |Train Accs: 0.03973 | Valid Accs: 0.11727 | Time: 0.78 seconds
# Epoch: 31 | Train Loss: 4.40717 | Valid Loss: 4.25914 |Train Accs: 0.04777 | Valid Accs: 0.12937 | Time: 0.69 seconds
# Epoch: 32 | Train Loss: 4.37347 | Valid Loss: 4.22465 |Train Accs: 0.05306 | Valid Accs: 0.13835 | Time: 0.68 seconds
# Epoch: 33 | Train Loss: 4.33877 | Valid Loss: 4.18812 |Train Accs: 0.05655 | Valid Accs: 0.14810 | Time: 0.78 seconds
# Epoch: 34 | Train Loss: 4.29327 | Valid Loss: 4.15015 |Train Accs: 0.06463 | Valid Accs: 0.15843 | Time: 0.69 seconds
# Epoch: 35 | Train Loss: 4.25024 | Valid Loss: 4.11028 |Train Accs: 0.06886 | Valid Accs: 0.16839 | Time: 1.40 seconds
# Epoch: 36 | Train Loss: 4.21505 | Valid Loss: 4.06952 |Train Accs: 0.07513 | Valid Accs: 0.17991 | Time: 0.68 seconds
# Epoch: 37 | Train Loss: 4.17710 | Valid Loss: 4.02510 |Train Accs: 0.07981 | Valid Accs: 0.18870 | Time: 0.68 seconds
# Epoch: 38 | Train Loss: 4.12209 | Valid Loss: 3.98081 |Train Accs: 0.09059 | Valid Accs: 0.19631 | Time: 0.67 seconds
# Epoch: 39 | Train Loss: 4.09030 | Valid Loss: 3.93173 |Train Accs: 0.09758 | Valid Accs: 0.20451 | Time: 0.96 seconds
# Epoch: 40 | Train Loss: 4.03041 | Valid Loss: 3.87938 |Train Accs: 0.10896 | Valid Accs: 0.21465 | Time: 0.67 seconds
# Epoch: 41 | Train Loss: 3.97612 | Valid Loss: 3.83074 |Train Accs: 0.11764 | Valid Accs: 0.22558 | Time: 1.35 seconds
# Epoch: 42 | Train Loss: 3.93712 | Valid Loss: 3.77193 |Train Accs: 0.12346 | Valid Accs: 0.23826 | Time: 0.68 seconds
# Epoch: 43 | Train Loss: 3.87110 | Valid Loss: 3.71182 |Train Accs: 0.13601 | Valid Accs: 0.24743 | Time: 0.81 seconds
# Epoch: 44 | Train Loss: 3.81350 | Valid Loss: 3.65015 |Train Accs: 0.15206 | Valid Accs: 0.26147 | Time: 0.68 seconds
# Epoch: 45 | Train Loss: 3.75422 | Valid Loss: 3.58412 |Train Accs: 0.16021 | Valid Accs: 0.27377 | Time: 0.68 seconds
# Epoch: 46 | Train Loss: 3.68543 | Valid Loss: 3.51741 |Train Accs: 0.17407 | Valid Accs: 0.28159 | Time: 0.80 seconds
# Epoch: 47 | Train Loss: 3.62489 | Valid Loss: 3.45183 |Train Accs: 0.18500 | Valid Accs: 0.29290 | Time: 1.36 seconds
# Epoch: 48 | Train Loss: 3.55473 | Valid Loss: 3.38573 |Train Accs: 0.19939 | Valid Accs: 0.30773 | Time: 0.69 seconds
# Epoch: 49 | Train Loss: 3.48562 | Valid Loss: 3.31329 |Train Accs: 0.20932 | Valid Accs: 0.32332 | Time: 0.68 seconds
# Epoch: 50 | Train Loss: 3.41948 | Valid Loss: 3.24106 |Train Accs: 0.22231 | Valid Accs: 0.33776 | Time: 0.69 seconds
# Epoch: 51 | Train Loss: 3.35327 | Valid Loss: 3.17612 |Train Accs: 0.23741 | Valid Accs: 0.35376 | Time: 0.69 seconds
# Epoch: 52 | Train Loss: 3.28594 | Valid Loss: 3.09996 |Train Accs: 0.25274 | Valid Accs: 0.36176 | Time: 0.92 seconds
# Epoch: 53 | Train Loss: 3.21480 | Valid Loss: 3.03167 |Train Accs: 0.26061 | Valid Accs: 0.37542 | Time: 1.43 seconds
# Epoch: 54 | Train Loss: 3.14878 | Valid Loss: 2.96200 |Train Accs: 0.27963 | Valid Accs: 0.38809 | Time: 0.71 seconds
# Epoch: 55 | Train Loss: 3.07743 | Valid Loss: 2.88817 |Train Accs: 0.29848 | Valid Accs: 0.40214 | Time: 0.71 seconds
# Epoch: 56 | Train Loss: 3.00527 | Valid Loss: 2.82099 |Train Accs: 0.31697 | Valid Accs: 0.41852 | Time: 0.83 seconds
# Epoch: 57 | Train Loss: 2.93406 | Valid Loss: 2.75207 |Train Accs: 0.33056 | Valid Accs: 0.43101 | Time: 0.68 seconds
# Epoch: 58 | Train Loss: 2.86842 | Valid Loss: 2.68227 |Train Accs: 0.34696 | Valid Accs: 0.45188 | Time: 0.69 seconds
# Epoch: 59 | Train Loss: 2.80131 | Valid Loss: 2.61592 |Train Accs: 0.35529 | Valid Accs: 0.46066 | Time: 1.36 seconds
# Epoch: 60 | Train Loss: 2.73506 | Valid Loss: 2.55284 |Train Accs: 0.37123 | Valid Accs: 0.47141 | Time: 0.69 seconds
# Epoch: 61 | Train Loss: 2.66942 | Valid Loss: 2.48681 |Train Accs: 0.38769 | Valid Accs: 0.48838 | Time: 0.67 seconds
# Epoch: 62 | Train Loss: 2.59720 | Valid Loss: 2.42661 |Train Accs: 0.40619 | Valid Accs: 0.50127 | Time: 0.66 seconds
# Epoch: 63 | Train Loss: 2.53136 | Valid Loss: 2.35913 |Train Accs: 0.42318 | Valid Accs: 0.51569 | Time: 0.68 seconds
# Epoch: 64 | Train Loss: 2.45742 | Valid Loss: 2.30202 |Train Accs: 0.44106 | Valid Accs: 0.52604 | Time: 0.68 seconds
# Epoch: 65 | Train Loss: 2.41024 | Valid Loss: 2.23879 |Train Accs: 0.45034 | Valid Accs: 0.53678 | Time: 0.79 seconds
# Epoch: 66 | Train Loss: 2.33675 | Valid Loss: 2.18307 |Train Accs: 0.47080 | Valid Accs: 0.55159 | Time: 1.34 seconds
# Epoch: 67 | Train Loss: 2.28353 | Valid Loss: 2.12667 |Train Accs: 0.48333 | Valid Accs: 0.56292 | Time: 0.69 seconds
# Epoch: 68 | Train Loss: 2.21967 | Valid Loss: 2.06952 |Train Accs: 0.49752 | Valid Accs: 0.57092 | Time: 0.70 seconds
# Epoch: 69 | Train Loss: 2.15937 | Valid Loss: 2.01750 |Train Accs: 0.50960 | Valid Accs: 0.58145 | Time: 0.80 seconds
# Epoch: 70 | Train Loss: 2.11805 | Valid Loss: 1.96289 |Train Accs: 0.51453 | Valid Accs: 0.59082 | Time: 0.69 seconds
# Epoch: 71 | Train Loss: 2.04876 | Valid Loss: 1.91522 |Train Accs: 0.53750 | Valid Accs: 0.60096 | Time: 0.67 seconds
# Epoch: 72 | Train Loss: 1.99377 | Valid Loss: 1.86415 |Train Accs: 0.55108 | Valid Accs: 0.60858 | Time: 1.47 seconds
# Epoch: 73 | Train Loss: 1.93559 | Valid Loss: 1.81694 |Train Accs: 0.56669 | Valid Accs: 0.61716 | Time: 0.67 seconds
# Epoch: 74 | Train Loss: 1.87745 | Valid Loss: 1.77324 |Train Accs: 0.57746 | Valid Accs: 0.62671 | Time: 0.68 seconds
# Epoch: 75 | Train Loss: 1.83430 | Valid Loss: 1.72909 |Train Accs: 0.58986 | Valid Accs: 0.63685 | Time: 0.68 seconds
# Epoch: 76 | Train Loss: 1.77799 | Valid Loss: 1.69018 |Train Accs: 0.59725 | Valid Accs: 0.63882 | Time: 0.67 seconds
# Epoch: 77 | Train Loss: 1.72785 | Valid Loss: 1.64326 |Train Accs: 0.61780 | Valid Accs: 0.64818 | Time: 0.68 seconds
# Epoch: 78 | Train Loss: 1.66392 | Valid Loss: 1.60552 |Train Accs: 0.63384 | Valid Accs: 0.65228 | Time: 0.78 seconds
# Epoch: 79 | Train Loss: 1.61994 | Valid Loss: 1.56461 |Train Accs: 0.63955 | Valid Accs: 0.66515 | Time: 1.65 seconds
# Epoch: 80 | Train Loss: 1.56926 | Valid Loss: 1.52804 |Train Accs: 0.64934 | Valid Accs: 0.66106 | Time: 0.69 seconds
# Epoch: 81 | Train Loss: 1.53176 | Valid Loss: 1.49110 |Train Accs: 0.65876 | Valid Accs: 0.67471 | Time: 0.70 seconds
# Epoch: 82 | Train Loss: 1.48386 | Valid Loss: 1.46145 |Train Accs: 0.67365 | Valid Accs: 0.67608 | Time: 0.77 seconds
# Epoch: 83 | Train Loss: 1.42911 | Valid Loss: 1.43320 |Train Accs: 0.68733 | Valid Accs: 0.68115 | Time: 0.68 seconds
# Epoch: 84 | Train Loss: 1.39731 | Valid Loss: 1.39531 |Train Accs: 0.69523 | Valid Accs: 0.69013 | Time: 0.68 seconds
# Epoch: 85 | Train Loss: 1.34750 | Valid Loss: 1.36473 |Train Accs: 0.70369 | Valid Accs: 0.68761 | Time: 1.35 seconds
# Epoch: 86 | Train Loss: 1.30671 | Valid Loss: 1.33461 |Train Accs: 0.71446 | Valid Accs: 0.69462 | Time: 0.69 seconds
# Epoch: 87 | Train Loss: 1.27403 | Valid Loss: 1.31204 |Train Accs: 0.71835 | Valid Accs: 0.70047 | Time: 0.68 seconds
# Epoch: 88 | Train Loss: 1.22116 | Valid Loss: 1.27987 |Train Accs: 0.73705 | Valid Accs: 0.70126 | Time: 0.67 seconds
# Epoch: 89 | Train Loss: 1.18805 | Valid Loss: 1.25119 |Train Accs: 0.74516 | Valid Accs: 0.71160 | Time: 0.70 seconds
# Epoch: 90 | Train Loss: 1.13848 | Valid Loss: 1.23621 |Train Accs: 0.76098 | Valid Accs: 0.71179 | Time: 0.67 seconds
# Epoch: 91 | Train Loss: 1.10422 | Valid Loss: 1.20837 |Train Accs: 0.76114 | Valid Accs: 0.71454 | Time: 0.77 seconds
# Epoch: 92 | Train Loss: 1.06293 | Valid Loss: 1.18096 |Train Accs: 0.77454 | Valid Accs: 0.71298 | Time: 1.70 seconds
# Epoch: 93 | Train Loss: 1.01988 | Valid Loss: 1.15913 |Train Accs: 0.78564 | Valid Accs: 0.71415 | Time: 0.70 seconds
# Epoch: 94 | Train Loss: 0.99255 | Valid Loss: 1.14075 |Train Accs: 0.78999 | Valid Accs: 0.71980 | Time: 0.67 seconds
# Epoch: 95 | Train Loss: 0.95555 | Valid Loss: 1.12380 |Train Accs: 0.79920 | Valid Accs: 0.71999 | Time: 0.78 seconds
# Epoch: 96 | Train Loss: 0.91967 | Valid Loss: 1.10400 |Train Accs: 0.80457 | Valid Accs: 0.72274 | Time: 0.68 seconds
# Epoch: 97 | Train Loss: 0.89739 | Valid Loss: 1.08257 |Train Accs: 0.81288 | Valid Accs: 0.73033 | Time: 0.68 seconds
# Epoch: 98 | Train Loss: 0.86063 | Valid Loss: 1.06947 |Train Accs: 0.82223 | Valid Accs: 0.72526 | Time: 1.35 seconds
# Epoch: 99 | Train Loss: 0.83010 | Valid Loss: 1.04755 |Train Accs: 0.82929 | Valid Accs: 0.73346 | Time: 0.68 seconds
# Epoch: 100 | Train Loss: 0.79755 | Valid Loss: 1.02528 |Train Accs: 0.83931 | Valid Accs: 0.73951 | Time: 0.68 seconds
# Epoch: 101 | Train Loss: 0.76937 | Valid Loss: 1.01421 |Train Accs: 0.84544 | Valid Accs: 0.73678 | Time: 0.68 seconds
# Epoch: 102 | Train Loss: 0.74209 | Valid Loss: 1.01450 |Train Accs: 0.85016 | Valid Accs: 0.73423 | Time: 0.55 seconds
# Epoch: 103 | Train Loss: 0.71524 | Valid Loss: 0.99343 |Train Accs: 0.85679 | Valid Accs: 0.73834 | Time: 0.68 seconds
# Epoch: 104 | Train Loss: 0.69639 | Valid Loss: 0.99243 |Train Accs: 0.85776 | Valid Accs: 0.73348 | Time: 0.78 seconds
# Epoch: 105 | Train Loss: 0.65711 | Valid Loss: 0.97069 |Train Accs: 0.87255 | Valid Accs: 0.74633 | Time: 1.42 seconds
# Epoch: 106 | Train Loss: 0.64040 | Valid Loss: 0.96416 |Train Accs: 0.87515 | Valid Accs: 0.74264 | Time: 0.78 seconds
# Epoch: 107 | Train Loss: 0.60581 | Valid Loss: 0.95104 |Train Accs: 0.88135 | Valid Accs: 0.74400 | Time: 0.68 seconds
# Epoch: 108 | Train Loss: 0.58287 | Valid Loss: 0.94180 |Train Accs: 0.88822 | Valid Accs: 0.73951 | Time: 0.79 seconds
# Epoch: 109 | Train Loss: 0.57263 | Valid Loss: 0.94632 |Train Accs: 0.88948 | Valid Accs: 0.73893 | Time: 0.58 seconds
# Epoch: 110 | Train Loss: 0.54578 | Valid Loss: 0.93134 |Train Accs: 0.89306 | Valid Accs: 0.74478 | Time: 0.65 seconds
# Epoch: 111 | Train Loss: 0.51939 | Valid Loss: 0.90889 |Train Accs: 0.90057 | Valid Accs: 0.74751 | Time: 1.18 seconds
# Epoch: 112 | Train Loss: 0.49672 | Valid Loss: 0.90609 |Train Accs: 0.90611 | Valid Accs: 0.74478 | Time: 0.69 seconds
# Epoch: 113 | Train Loss: 0.48166 | Valid Loss: 0.90190 |Train Accs: 0.90811 | Valid Accs: 0.75141 | Time: 0.68 seconds
# Epoch: 114 | Train Loss: 0.45574 | Valid Loss: 0.89721 |Train Accs: 0.91643 | Valid Accs: 0.75123 | Time: 0.67 seconds
# Epoch: 115 | Train Loss: 0.44279 | Valid Loss: 0.89378 |Train Accs: 0.91707 | Valid Accs: 0.74985 | Time: 0.67 seconds
# Epoch: 116 | Train Loss: 0.42433 | Valid Loss: 0.89527 |Train Accs: 0.92091 | Valid Accs: 0.74654 | Time: 0.56 seconds
# Epoch: 117 | Train Loss: 0.42085 | Valid Loss: 0.87756 |Train Accs: 0.92173 | Valid Accs: 0.75063 | Time: 0.76 seconds
# Epoch: 118 | Train Loss: 0.40015 | Valid Loss: 0.86142 |Train Accs: 0.92795 | Valid Accs: 0.75708 | Time: 1.37 seconds
# Epoch: 119 | Train Loss: 0.38834 | Valid Loss: 0.88648 |Train Accs: 0.92833 | Valid Accs: 0.74966 | Time: 0.58 seconds
# Epoch: 120 | Train Loss: 0.37834 | Valid Loss: 0.87167 |Train Accs: 0.92721 | Valid Accs: 0.75296 | Time: 0.72 seconds
# Epoch: 121 | Train Loss: 0.36723 | Valid Loss: 0.88624 |Train Accs: 0.93089 | Valid Accs: 0.74615 | Time: 0.63 seconds
# Epoch: 122 | Train Loss: 0.36190 | Valid Loss: 0.87353 |Train Accs: 0.93419 | Valid Accs: 0.75027 | Time: 0.54 seconds
# Epoch: 123 | Train Loss: 0.34003 | Valid Loss: 0.87540 |Train Accs: 0.93814 | Valid Accs: 0.74422 | Time: 0.54 seconds
# Epoch: 124 | Train Loss: 0.33753 | Valid Loss: 0.85648 |Train Accs: 0.93495 | Valid Accs: 0.75590 | Time: 0.90 seconds
# Epoch: 125 | Train Loss: 0.32763 | Valid Loss: 0.86364 |Train Accs: 0.93841 | Valid Accs: 0.75435 | Time: 0.55 seconds
# Epoch: 126 | Train Loss: 0.31376 | Valid Loss: 0.87336 |Train Accs: 0.94383 | Valid Accs: 0.75396 | Time: 0.56 seconds
# Epoch: 127 | Train Loss: 0.31137 | Valid Loss: 0.87379 |Train Accs: 0.94103 | Valid Accs: 0.75182 | Time: 0.53 seconds
# Epoch: 128 | Train Loss: 0.30490 | Valid Loss: 0.88229 |Train Accs: 0.94204 | Valid Accs: 0.74929 | Time: 0.53 seconds
# Epoch: 129 | Train Loss: 0.28896 | Valid Loss: 0.86717 |Train Accs: 0.94671 | Valid Accs: 0.75533 | Time: 0.53 seconds
# Epoch: 130 | Train Loss: 0.27377 | Valid Loss: 0.85913 |Train Accs: 0.94705 | Valid Accs: 0.75552 | Time: 0.64 seconds
# Epoch: 131 | Train Loss: 0.28053 | Valid Loss: 0.86776 |Train Accs: 0.94476 | Valid Accs: 0.74753 | Time: 0.54 seconds
# Epoch: 132 | Train Loss: 0.27195 | Valid Loss: 0.84966 |Train Accs: 0.94818 | Valid Accs: 0.75650 | Time: 0.69 seconds
# Epoch: 133 | Train Loss: 0.27122 | Valid Loss: 0.87653 |Train Accs: 0.94720 | Valid Accs: 0.74713 | Time: 0.54 seconds
# Epoch: 134 | Train Loss: 0.26126 | Valid Loss: 0.87197 |Train Accs: 0.94991 | Valid Accs: 0.74929 | Time: 0.65 seconds
# Epoch: 135 | Train Loss: 0.26019 | Valid Loss: 0.87442 |Train Accs: 0.94644 | Valid Accs: 0.74576 | Time: 0.55 seconds
# Epoch: 136 | Train Loss: 0.26163 | Valid Loss: 0.87007 |Train Accs: 0.94666 | Valid Accs: 0.75104 | Time: 0.54 seconds
# Epoch: 137 | Train Loss: 0.24989 | Valid Loss: 0.87357 |Train Accs: 0.95094 | Valid Accs: 0.74986 | Time: 0.84 seconds
# Epoch: 138 | Train Loss: 0.25170 | Valid Loss: 0.86868 |Train Accs: 0.95045 | Valid Accs: 0.75199 | Time: 0.87 seconds
# Epoch: 139 | Train Loss: 0.25493 | Valid Loss: 0.89434 |Train Accs: 0.94813 | Valid Accs: 0.74441 | Time: 0.55 seconds
# Epoch: 140 | Train Loss: 0.25376 | Valid Loss: 0.86306 |Train Accs: 0.94710 | Valid Accs: 0.75376 | Time: 0.54 seconds
# Epoch: 141 | Train Loss: 0.24148 | Valid Loss: 0.86980 |Train Accs: 0.95246 | Valid Accs: 0.74947 | Time: 0.52 seconds
# Epoch: 142 | Train Loss: 0.23448 | Valid Loss: 0.88803 |Train Accs: 0.95154 | Valid Accs: 0.73953 | Time: 0.53 seconds
# Epoch: 143 | Train Loss: 0.24113 | Valid Loss: 0.86771 |Train Accs: 0.94743 | Valid Accs: 0.74870 | Time: 0.64 seconds
# Epoch: 144 | Train Loss: 0.23604 | Valid Loss: 0.86737 |Train Accs: 0.94991 | Valid Accs: 0.75162 | Time: 0.53 seconds
# Epoch: 145 | Train Loss: 0.22974 | Valid Loss: 0.90160 |Train Accs: 0.95122 | Valid Accs: 0.74188 | Time: 0.54 seconds
# Epoch: 146 | Train Loss: 0.22950 | Valid Loss: 0.89571 |Train Accs: 0.95127 | Valid Accs: 0.74420 | Time: 0.53 seconds
# Epoch: 147 | Train Loss: 0.22758 | Valid Loss: 0.89431 |Train Accs: 0.95229 | Valid Accs: 0.74597 | Time: 0.63 seconds
# Epoch: 148 | Train Loss: 0.21953 | Valid Loss: 0.89512 |Train Accs: 0.95183 | Valid Accs: 0.74499 | Time: 0.54 seconds
# Epoch: 149 | Train Loss: 0.22172 | Valid Loss: 0.88376 |Train Accs: 0.95171 | Valid Accs: 0.74287 | Time: 0.54 seconds
# Epoch: 150 | Train Loss: 0.23019 | Valid Loss: 0.89820 |Train Accs: 0.94743 | Valid Accs: 0.73292 | Time: 0.66 seconds
# Epoch: 151 | Train Loss: 0.23098 | Valid Loss: 0.91944 |Train Accs: 0.94482 | Valid Accs: 0.74049 | Time: 0.54 seconds
# Epoch: 152 | Train Loss: 0.22955 | Valid Loss: 0.90691 |Train Accs: 0.94607 | Valid Accs: 0.73934 | Time: 0.53 seconds
# Epoch: 153 | Train Loss: 0.22052 | Valid Loss: 0.90103 |Train Accs: 0.95327 | Valid Accs: 0.74129 | Time: 0.53 seconds
# Epoch: 154 | Train Loss: 0.21398 | Valid Loss: 0.87878 |Train Accs: 0.95062 | Valid Accs: 0.74772 | Time: 0.54 seconds
# Epoch: 155 | Train Loss: 0.21723 | Valid Loss: 0.89016 |Train Accs: 0.94976 | Valid Accs: 0.74849 | Time: 0.54 seconds
# Epoch: 156 | Train Loss: 0.22140 | Valid Loss: 0.89244 |Train Accs: 0.94786 | Valid Accs: 0.74401 | Time: 0.63 seconds
# Epoch: 157 | Train Loss: 0.21871 | Valid Loss: 0.90874 |Train Accs: 0.94851 | Valid Accs: 0.74304 | Time: 0.77 seconds
#
# Early Stopping at Epoch 158
#
# **************************************************
#
# Best Validation Loss at Epoch 132
#
# **************************************************
#
# Best Validation Accs at Epoch 118
#
# **************************************************
#
# Time Taken [158 Epochs] : 2.00 minutes
#
# **************************************************
# **************************************************
#
# Training Fold 2...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.76639 | Valid Loss: 4.61564 |Train Accs: 0.01002 | Valid Accs: 0.01034 | Time: 0.74 seconds
# Epoch: 2 | Train Loss: 4.76646 | Valid Loss: 4.62345 |Train Accs: 0.00970 | Valid Accs: 0.01170 | Time: 0.53 seconds
# Epoch: 3 | Train Loss: 4.76471 | Valid Loss: 4.62368 |Train Accs: 0.00970 | Valid Accs: 0.01151 | Time: 0.54 seconds
# Epoch: 4 | Train Loss: 4.75836 | Valid Loss: 4.62183 |Train Accs: 0.01094 | Valid Accs: 0.01209 | Time: 0.55 seconds
# Epoch: 5 | Train Loss: 4.76570 | Valid Loss: 4.61946 |Train Accs: 0.01019 | Valid Accs: 0.01268 | Time: 0.65 seconds
# Epoch: 6 | Train Loss: 4.76115 | Valid Loss: 4.61707 |Train Accs: 0.00976 | Valid Accs: 0.01248 | Time: 0.53 seconds
# Epoch: 7 | Train Loss: 4.75802 | Valid Loss: 4.61394 |Train Accs: 0.01203 | Valid Accs: 0.01307 | Time: 0.70 seconds
# Epoch: 8 | Train Loss: 4.75957 | Valid Loss: 4.61102 |Train Accs: 0.01084 | Valid Accs: 0.01326 | Time: 0.71 seconds
# Epoch: 9 | Train Loss: 4.74167 | Valid Loss: 4.60700 |Train Accs: 0.01133 | Valid Accs: 0.01385 | Time: 0.79 seconds
# Epoch: 10 | Train Loss: 4.74605 | Valid Loss: 4.60226 |Train Accs: 0.01085 | Valid Accs: 0.01483 | Time: 0.67 seconds
# Epoch: 11 | Train Loss: 4.73613 | Valid Loss: 4.59767 |Train Accs: 0.01280 | Valid Accs: 0.01561 | Time: 0.70 seconds
# Epoch: 12 | Train Loss: 4.73481 | Valid Loss: 4.59185 |Train Accs: 0.01301 | Valid Accs: 0.01639 | Time: 0.68 seconds
# Epoch: 13 | Train Loss: 4.72465 | Valid Loss: 4.58586 |Train Accs: 0.01199 | Valid Accs: 0.01737 | Time: 0.82 seconds
# Epoch: 14 | Train Loss: 4.71385 | Valid Loss: 4.57854 |Train Accs: 0.01333 | Valid Accs: 0.02010 | Time: 0.69 seconds
# Epoch: 15 | Train Loss: 4.70348 | Valid Loss: 4.57014 |Train Accs: 0.01231 | Valid Accs: 0.02283 | Time: 1.72 seconds
# Epoch: 16 | Train Loss: 4.70111 | Valid Loss: 4.56134 |Train Accs: 0.01350 | Valid Accs: 0.02595 | Time: 0.69 seconds
# Epoch: 17 | Train Loss: 4.69421 | Valid Loss: 4.55128 |Train Accs: 0.01496 | Valid Accs: 0.03181 | Time: 0.83 seconds
# Epoch: 18 | Train Loss: 4.68627 | Valid Loss: 4.54047 |Train Accs: 0.01360 | Valid Accs: 0.03708 | Time: 0.68 seconds
# Epoch: 19 | Train Loss: 4.68206 | Valid Loss: 4.52818 |Train Accs: 0.01610 | Valid Accs: 0.04293 | Time: 0.67 seconds
# Epoch: 20 | Train Loss: 4.66076 | Valid Loss: 4.51436 |Train Accs: 0.01621 | Valid Accs: 0.04839 | Time: 0.68 seconds
# Epoch: 21 | Train Loss: 4.64403 | Valid Loss: 4.49981 |Train Accs: 0.01936 | Valid Accs: 0.05327 | Time: 0.82 seconds
# Epoch: 22 | Train Loss: 4.62143 | Valid Loss: 4.48341 |Train Accs: 0.02142 | Valid Accs: 0.06049 | Time: 0.74 seconds
# Epoch: 23 | Train Loss: 4.60776 | Valid Loss: 4.46549 |Train Accs: 0.02136 | Valid Accs: 0.06654 | Time: 0.68 seconds
# Epoch: 24 | Train Loss: 4.58354 | Valid Loss: 4.44587 |Train Accs: 0.02315 | Valid Accs: 0.07493 | Time: 0.84 seconds
# Epoch: 25 | Train Loss: 4.56456 | Valid Loss: 4.42461 |Train Accs: 0.02905 | Valid Accs: 0.08332 | Time: 0.70 seconds
# Epoch: 26 | Train Loss: 4.55409 | Valid Loss: 4.40173 |Train Accs: 0.02937 | Valid Accs: 0.09190 | Time: 0.71 seconds
# Epoch: 27 | Train Loss: 4.52991 | Valid Loss: 4.37603 |Train Accs: 0.03220 | Valid Accs: 0.09873 | Time: 0.72 seconds
# Epoch: 28 | Train Loss: 4.50241 | Valid Loss: 4.34766 |Train Accs: 0.03297 | Valid Accs: 0.10517 | Time: 1.76 seconds
# Epoch: 29 | Train Loss: 4.46767 | Valid Loss: 4.31778 |Train Accs: 0.03973 | Valid Accs: 0.11277 | Time: 0.77 seconds
# Epoch: 30 | Train Loss: 4.43752 | Valid Loss: 4.28714 |Train Accs: 0.04357 | Valid Accs: 0.11844 | Time: 0.78 seconds
# Epoch: 31 | Train Loss: 4.40757 | Valid Loss: 4.25285 |Train Accs: 0.04669 | Valid Accs: 0.12838 | Time: 0.70 seconds
# Epoch: 32 | Train Loss: 4.36894 | Valid Loss: 4.21946 |Train Accs: 0.04971 | Valid Accs: 0.13911 | Time: 0.71 seconds
# Epoch: 33 | Train Loss: 4.33720 | Valid Loss: 4.18260 |Train Accs: 0.05496 | Valid Accs: 0.15139 | Time: 0.66 seconds
# Epoch: 34 | Train Loss: 4.30406 | Valid Loss: 4.14424 |Train Accs: 0.05926 | Valid Accs: 0.15920 | Time: 1.46 seconds
# Epoch: 35 | Train Loss: 4.26019 | Valid Loss: 4.10390 |Train Accs: 0.07004 | Valid Accs: 0.16699 | Time: 0.73 seconds
# Epoch: 36 | Train Loss: 4.21971 | Valid Loss: 4.06132 |Train Accs: 0.07227 | Valid Accs: 0.17695 | Time: 0.69 seconds
# Epoch: 37 | Train Loss: 4.18106 | Valid Loss: 4.01701 |Train Accs: 0.08301 | Valid Accs: 0.19236 | Time: 0.82 seconds
# Epoch: 38 | Train Loss: 4.13838 | Valid Loss: 3.97100 |Train Accs: 0.08982 | Valid Accs: 0.19725 | Time: 0.73 seconds
# Epoch: 39 | Train Loss: 4.08236 | Valid Loss: 3.92230 |Train Accs: 0.10099 | Valid Accs: 0.20915 | Time: 0.66 seconds
# Epoch: 40 | Train Loss: 4.02989 | Valid Loss: 3.87117 |Train Accs: 0.10452 | Valid Accs: 0.22106 | Time: 1.47 seconds
# Epoch: 41 | Train Loss: 3.98533 | Valid Loss: 3.81547 |Train Accs: 0.11346 | Valid Accs: 0.22810 | Time: 0.83 seconds
# Epoch: 42 | Train Loss: 3.92989 | Valid Loss: 3.75929 |Train Accs: 0.12281 | Valid Accs: 0.24175 | Time: 0.70 seconds
# Epoch: 43 | Train Loss: 3.88193 | Valid Loss: 3.69761 |Train Accs: 0.13497 | Valid Accs: 0.25364 | Time: 0.75 seconds
# Epoch: 44 | Train Loss: 3.82122 | Valid Loss: 3.63399 |Train Accs: 0.14563 | Valid Accs: 0.26885 | Time: 0.74 seconds
# Epoch: 45 | Train Loss: 3.75574 | Valid Loss: 3.56777 |Train Accs: 0.15886 | Valid Accs: 0.28134 | Time: 0.70 seconds
# Epoch: 46 | Train Loss: 3.70054 | Valid Loss: 3.50148 |Train Accs: 0.16857 | Valid Accs: 0.29519 | Time: 1.35 seconds
# Epoch: 47 | Train Loss: 3.64074 | Valid Loss: 3.43333 |Train Accs: 0.17838 | Valid Accs: 0.30651 | Time: 0.84 seconds
# Epoch: 48 | Train Loss: 3.56530 | Valid Loss: 3.36495 |Train Accs: 0.19653 | Valid Accs: 0.32017 | Time: 0.68 seconds
# Epoch: 49 | Train Loss: 3.49200 | Valid Loss: 3.29633 |Train Accs: 0.20991 | Valid Accs: 0.33538 | Time: 0.71 seconds
# Epoch: 50 | Train Loss: 3.41940 | Valid Loss: 3.22633 |Train Accs: 0.22987 | Valid Accs: 0.34144 | Time: 0.78 seconds
# Epoch: 51 | Train Loss: 3.35372 | Valid Loss: 3.15486 |Train Accs: 0.23918 | Valid Accs: 0.35510 | Time: 0.70 seconds
# Epoch: 52 | Train Loss: 3.29504 | Valid Loss: 3.08512 |Train Accs: 0.25086 | Valid Accs: 0.36623 | Time: 1.36 seconds
# Epoch: 53 | Train Loss: 3.22239 | Valid Loss: 3.01502 |Train Accs: 0.26443 | Valid Accs: 0.37638 | Time: 0.76 seconds
# Epoch: 54 | Train Loss: 3.15522 | Valid Loss: 2.94210 |Train Accs: 0.27900 | Valid Accs: 0.38828 | Time: 0.81 seconds
# Epoch: 55 | Train Loss: 3.08196 | Valid Loss: 2.87240 |Train Accs: 0.29381 | Valid Accs: 0.40624 | Time: 0.69 seconds
# Epoch: 56 | Train Loss: 3.01455 | Valid Loss: 2.80533 |Train Accs: 0.31045 | Valid Accs: 0.41951 | Time: 0.81 seconds
# Epoch: 57 | Train Loss: 2.94145 | Valid Loss: 2.73988 |Train Accs: 0.32784 | Valid Accs: 0.43629 | Time: 0.72 seconds
# Epoch: 58 | Train Loss: 2.86935 | Valid Loss: 2.67025 |Train Accs: 0.34764 | Valid Accs: 0.45228 | Time: 0.71 seconds
# Epoch: 59 | Train Loss: 2.80112 | Valid Loss: 2.60589 |Train Accs: 0.35859 | Valid Accs: 0.46613 | Time: 0.68 seconds
# Epoch: 60 | Train Loss: 2.73769 | Valid Loss: 2.54186 |Train Accs: 0.37463 | Valid Accs: 0.48096 | Time: 0.81 seconds
# Epoch: 61 | Train Loss: 2.66889 | Valid Loss: 2.47651 |Train Accs: 0.39238 | Valid Accs: 0.49228 | Time: 0.68 seconds
# Epoch: 62 | Train Loss: 2.61047 | Valid Loss: 2.41306 |Train Accs: 0.40076 | Valid Accs: 0.50651 | Time: 0.68 seconds
# Epoch: 63 | Train Loss: 2.53663 | Valid Loss: 2.35419 |Train Accs: 0.42124 | Valid Accs: 0.52173 | Time: 0.79 seconds
# Epoch: 64 | Train Loss: 2.47053 | Valid Loss: 2.28901 |Train Accs: 0.43402 | Valid Accs: 0.53345 | Time: 0.70 seconds
# Epoch: 65 | Train Loss: 2.41428 | Valid Loss: 2.22992 |Train Accs: 0.44666 | Valid Accs: 0.54594 | Time: 1.64 seconds
# Epoch: 66 | Train Loss: 2.34475 | Valid Loss: 2.17605 |Train Accs: 0.46584 | Valid Accs: 0.55687 | Time: 0.85 seconds
# Epoch: 67 | Train Loss: 2.28138 | Valid Loss: 2.11730 |Train Accs: 0.48110 | Valid Accs: 0.56994 | Time: 1.18 seconds
# Epoch: 68 | Train Loss: 2.22617 | Valid Loss: 2.06050 |Train Accs: 0.49682 | Valid Accs: 0.58029 | Time: 0.71 seconds
# Epoch: 69 | Train Loss: 2.16322 | Valid Loss: 2.00658 |Train Accs: 0.51081 | Valid Accs: 0.58849 | Time: 0.84 seconds
# Epoch: 70 | Train Loss: 2.09942 | Valid Loss: 1.95340 |Train Accs: 0.52626 | Valid Accs: 0.60507 | Time: 1.08 seconds
# Epoch: 71 | Train Loss: 2.03420 | Valid Loss: 1.90943 |Train Accs: 0.54547 | Valid Accs: 0.61151 | Time: 0.69 seconds
# Epoch: 72 | Train Loss: 1.98647 | Valid Loss: 1.85565 |Train Accs: 0.55291 | Valid Accs: 0.61892 | Time: 0.70 seconds
# Epoch: 73 | Train Loss: 1.93092 | Valid Loss: 1.80707 |Train Accs: 0.56813 | Valid Accs: 0.63395 | Time: 0.80 seconds
# Epoch: 74 | Train Loss: 1.87308 | Valid Loss: 1.76123 |Train Accs: 0.58015 | Valid Accs: 0.63650 | Time: 0.74 seconds
# Epoch: 75 | Train Loss: 1.82179 | Valid Loss: 1.71588 |Train Accs: 0.59199 | Valid Accs: 0.64390 | Time: 0.68 seconds
# Epoch: 76 | Train Loss: 1.77502 | Valid Loss: 1.67535 |Train Accs: 0.60240 | Valid Accs: 0.64702 | Time: 0.81 seconds
# Epoch: 77 | Train Loss: 1.71593 | Valid Loss: 1.63347 |Train Accs: 0.61887 | Valid Accs: 0.66203 | Time: 1.41 seconds
# Epoch: 78 | Train Loss: 1.66799 | Valid Loss: 1.59477 |Train Accs: 0.62985 | Valid Accs: 0.66515 | Time: 0.69 seconds
# Epoch: 79 | Train Loss: 1.61983 | Valid Loss: 1.55464 |Train Accs: 0.64024 | Valid Accs: 0.67238 | Time: 0.69 seconds
# Epoch: 80 | Train Loss: 1.57014 | Valid Loss: 1.52090 |Train Accs: 0.65230 | Valid Accs: 0.67902 | Time: 0.91 seconds
# Epoch: 81 | Train Loss: 1.52108 | Valid Loss: 1.48108 |Train Accs: 0.66717 | Valid Accs: 0.68214 | Time: 0.71 seconds
# Epoch: 82 | Train Loss: 1.47599 | Valid Loss: 1.44787 |Train Accs: 0.67163 | Valid Accs: 0.68857 | Time: 0.76 seconds
# Epoch: 83 | Train Loss: 1.42852 | Valid Loss: 1.41723 |Train Accs: 0.68454 | Valid Accs: 0.69131 | Time: 1.38 seconds
# Epoch: 84 | Train Loss: 1.38590 | Valid Loss: 1.38277 |Train Accs: 0.69762 | Valid Accs: 0.69462 | Time: 0.69 seconds
# Epoch: 85 | Train Loss: 1.34786 | Valid Loss: 1.35622 |Train Accs: 0.70510 | Valid Accs: 0.69600 | Time: 0.69 seconds
# Epoch: 86 | Train Loss: 1.29879 | Valid Loss: 1.32596 |Train Accs: 0.71507 | Valid Accs: 0.70867 | Time: 0.79 seconds
# Epoch: 87 | Train Loss: 1.25706 | Valid Loss: 1.29933 |Train Accs: 0.72286 | Valid Accs: 0.70965 | Time: 0.68 seconds
# Epoch: 88 | Train Loss: 1.22281 | Valid Loss: 1.28118 |Train Accs: 0.73561 | Valid Accs: 0.70848 | Time: 0.68 seconds
# Epoch: 89 | Train Loss: 1.17285 | Valid Loss: 1.24775 |Train Accs: 0.75002 | Valid Accs: 0.71843 | Time: 1.45 seconds
# Epoch: 90 | Train Loss: 1.13331 | Valid Loss: 1.21832 |Train Accs: 0.75941 | Valid Accs: 0.71842 | Time: 0.69 seconds
# Epoch: 91 | Train Loss: 1.10324 | Valid Loss: 1.19814 |Train Accs: 0.76251 | Valid Accs: 0.72214 | Time: 0.69 seconds
# Epoch: 92 | Train Loss: 1.07312 | Valid Loss: 1.17409 |Train Accs: 0.76935 | Valid Accs: 0.72389 | Time: 0.70 seconds
# Epoch: 93 | Train Loss: 1.02320 | Valid Loss: 1.16390 |Train Accs: 0.78218 | Valid Accs: 0.71962 | Time: 0.89 seconds
# Epoch: 94 | Train Loss: 0.99851 | Valid Loss: 1.13798 |Train Accs: 0.79146 | Valid Accs: 0.73014 | Time: 0.72 seconds
# Epoch: 95 | Train Loss: 0.95180 | Valid Loss: 1.12451 |Train Accs: 0.80223 | Valid Accs: 0.72956 | Time: 0.79 seconds
# Epoch: 96 | Train Loss: 0.91557 | Valid Loss: 1.09421 |Train Accs: 0.81173 | Valid Accs: 0.73816 | Time: 0.70 seconds
# Epoch: 97 | Train Loss: 0.89080 | Valid Loss: 1.08791 |Train Accs: 0.81591 | Valid Accs: 0.73230 | Time: 0.71 seconds
# Epoch: 98 | Train Loss: 0.86044 | Valid Loss: 1.06406 |Train Accs: 0.82024 | Valid Accs: 0.73541 | Time: 0.69 seconds
# Epoch: 99 | Train Loss: 0.83116 | Valid Loss: 1.04819 |Train Accs: 0.82588 | Valid Accs: 0.73660 | Time: 0.78 seconds
# Epoch: 100 | Train Loss: 0.78993 | Valid Loss: 1.03559 |Train Accs: 0.83771 | Valid Accs: 0.73795 | Time: 0.71 seconds
# Epoch: 101 | Train Loss: 0.75927 | Valid Loss: 1.02012 |Train Accs: 0.85006 | Valid Accs: 0.74460 | Time: 0.66 seconds
# Epoch: 102 | Train Loss: 0.74059 | Valid Loss: 1.00057 |Train Accs: 0.85321 | Valid Accs: 0.74927 | Time: 1.64 seconds
# Epoch: 103 | Train Loss: 0.70778 | Valid Loss: 1.00096 |Train Accs: 0.85964 | Valid Accs: 0.74011 | Time: 0.58 seconds
# Epoch: 104 | Train Loss: 0.68379 | Valid Loss: 0.98792 |Train Accs: 0.86459 | Valid Accs: 0.74693 | Time: 0.66 seconds
# Epoch: 105 | Train Loss: 0.65322 | Valid Loss: 0.97204 |Train Accs: 0.87202 | Valid Accs: 0.74947 | Time: 0.68 seconds
# Epoch: 106 | Train Loss: 0.62797 | Valid Loss: 0.95241 |Train Accs: 0.87862 | Valid Accs: 0.75356 | Time: 0.81 seconds
# Epoch: 107 | Train Loss: 0.59959 | Valid Loss: 0.95458 |Train Accs: 0.88285 | Valid Accs: 0.74869 | Time: 1.07 seconds
# Epoch: 108 | Train Loss: 0.57199 | Valid Loss: 0.94224 |Train Accs: 0.89346 | Valid Accs: 0.75611 | Time: 0.83 seconds
# Epoch: 109 | Train Loss: 0.55029 | Valid Loss: 0.94110 |Train Accs: 0.89452 | Valid Accs: 0.74889 | Time: 0.69 seconds
# Epoch: 110 | Train Loss: 0.53071 | Valid Loss: 0.92605 |Train Accs: 0.89916 | Valid Accs: 0.75473 | Time: 0.74 seconds
# Epoch: 111 | Train Loss: 0.50990 | Valid Loss: 0.91995 |Train Accs: 0.90172 | Valid Accs: 0.75318 | Time: 0.74 seconds
# Epoch: 112 | Train Loss: 0.49207 | Valid Loss: 0.91148 |Train Accs: 0.90802 | Valid Accs: 0.75608 | Time: 0.81 seconds
# Epoch: 113 | Train Loss: 0.47041 | Valid Loss: 0.91075 |Train Accs: 0.91296 | Valid Accs: 0.75512 | Time: 0.66 seconds
# Epoch: 114 | Train Loss: 0.45477 | Valid Loss: 0.89644 |Train Accs: 0.91695 | Valid Accs: 0.75629 | Time: 0.69 seconds
# Epoch: 115 | Train Loss: 0.43600 | Valid Loss: 0.89481 |Train Accs: 0.92027 | Valid Accs: 0.75707 | Time: 0.79 seconds
# Epoch: 116 | Train Loss: 0.42704 | Valid Loss: 0.89978 |Train Accs: 0.92176 | Valid Accs: 0.75453 | Time: 0.55 seconds
# Epoch: 117 | Train Loss: 0.41245 | Valid Loss: 0.87360 |Train Accs: 0.92422 | Valid Accs: 0.76312 | Time: 1.09 seconds
# Epoch: 118 | Train Loss: 0.39140 | Valid Loss: 0.88462 |Train Accs: 0.92806 | Valid Accs: 0.75942 | Time: 0.56 seconds
# Epoch: 119 | Train Loss: 0.38169 | Valid Loss: 0.88454 |Train Accs: 0.93246 | Valid Accs: 0.75592 | Time: 0.54 seconds
# Epoch: 120 | Train Loss: 0.36403 | Valid Loss: 0.87956 |Train Accs: 0.93516 | Valid Accs: 0.76254 | Time: 0.53 seconds
# Epoch: 121 | Train Loss: 0.35860 | Valid Loss: 0.87329 |Train Accs: 0.93603 | Valid Accs: 0.76058 | Time: 0.80 seconds
# Epoch: 122 | Train Loss: 0.35909 | Valid Loss: 0.89513 |Train Accs: 0.93300 | Valid Accs: 0.75726 | Time: 0.66 seconds
# Epoch: 123 | Train Loss: 0.34480 | Valid Loss: 0.89379 |Train Accs: 0.93640 | Valid Accs: 0.75687 | Time: 0.60 seconds
# Epoch: 124 | Train Loss: 0.32877 | Valid Loss: 0.87691 |Train Accs: 0.93808 | Valid Accs: 0.75980 | Time: 0.57 seconds
# Epoch: 125 | Train Loss: 0.32226 | Valid Loss: 0.87347 |Train Accs: 0.94080 | Valid Accs: 0.75629 | Time: 0.63 seconds
# Epoch: 126 | Train Loss: 0.30897 | Valid Loss: 0.86053 |Train Accs: 0.94262 | Valid Accs: 0.76585 | Time: 0.66 seconds
# Epoch: 127 | Train Loss: 0.30532 | Valid Loss: 0.87041 |Train Accs: 0.94315 | Valid Accs: 0.75825 | Time: 0.56 seconds
# Epoch: 128 | Train Loss: 0.29927 | Valid Loss: 0.87798 |Train Accs: 0.94368 | Valid Accs: 0.75825 | Time: 0.64 seconds
# Epoch: 129 | Train Loss: 0.29665 | Valid Loss: 0.88716 |Train Accs: 0.94363 | Valid Accs: 0.75221 | Time: 0.53 seconds
# Epoch: 130 | Train Loss: 0.28585 | Valid Loss: 0.88413 |Train Accs: 0.94784 | Valid Accs: 0.75708 | Time: 0.53 seconds
# Epoch: 131 | Train Loss: 0.28711 | Valid Loss: 0.86689 |Train Accs: 0.94187 | Valid Accs: 0.75611 | Time: 0.53 seconds
# Epoch: 132 | Train Loss: 0.26789 | Valid Loss: 0.86896 |Train Accs: 0.94885 | Valid Accs: 0.75550 | Time: 0.53 seconds
# Epoch: 133 | Train Loss: 0.28190 | Valid Loss: 0.87199 |Train Accs: 0.94313 | Valid Accs: 0.75472 | Time: 0.53 seconds
# Epoch: 134 | Train Loss: 0.26639 | Valid Loss: 0.87871 |Train Accs: 0.94586 | Valid Accs: 0.75317 | Time: 0.64 seconds
# Epoch: 135 | Train Loss: 0.26526 | Valid Loss: 0.89435 |Train Accs: 0.94711 | Valid Accs: 0.75180 | Time: 0.53 seconds
# Epoch: 136 | Train Loss: 0.26684 | Valid Loss: 0.87854 |Train Accs: 0.94584 | Valid Accs: 0.75610 | Time: 0.59 seconds
# Epoch: 137 | Train Loss: 0.26638 | Valid Loss: 0.87575 |Train Accs: 0.94542 | Valid Accs: 0.75922 | Time: 0.59 seconds
# Epoch: 138 | Train Loss: 0.25446 | Valid Loss: 0.89076 |Train Accs: 0.94920 | Valid Accs: 0.76018 | Time: 0.69 seconds
# Epoch: 139 | Train Loss: 0.25144 | Valid Loss: 0.88091 |Train Accs: 0.94770 | Valid Accs: 0.75648 | Time: 0.57 seconds
# Epoch: 140 | Train Loss: 0.25210 | Valid Loss: 0.90931 |Train Accs: 0.94899 | Valid Accs: 0.75084 | Time: 0.54 seconds
# Epoch: 141 | Train Loss: 0.24559 | Valid Loss: 0.87891 |Train Accs: 0.94787 | Valid Accs: 0.75338 | Time: 0.80 seconds
# Epoch: 142 | Train Loss: 0.23921 | Valid Loss: 0.86364 |Train Accs: 0.94959 | Valid Accs: 0.75863 | Time: 0.53 seconds
# Epoch: 143 | Train Loss: 0.23719 | Valid Loss: 0.88864 |Train Accs: 0.94975 | Valid Accs: 0.75766 | Time: 0.53 seconds
# Epoch: 144 | Train Loss: 0.23193 | Valid Loss: 0.90024 |Train Accs: 0.95128 | Valid Accs: 0.75278 | Time: 0.53 seconds
# Epoch: 145 | Train Loss: 0.22691 | Valid Loss: 0.89925 |Train Accs: 0.95310 | Valid Accs: 0.75493 | Time: 0.53 seconds
# Epoch: 146 | Train Loss: 0.22315 | Valid Loss: 0.88851 |Train Accs: 0.95416 | Valid Accs: 0.75708 | Time: 0.53 seconds
# Epoch: 147 | Train Loss: 0.22078 | Valid Loss: 0.88868 |Train Accs: 0.95171 | Valid Accs: 0.75199 | Time: 0.64 seconds
# Epoch: 148 | Train Loss: 0.22501 | Valid Loss: 0.89446 |Train Accs: 0.95100 | Valid Accs: 0.75512 | Time: 0.53 seconds
# Epoch: 149 | Train Loss: 0.21248 | Valid Loss: 0.89599 |Train Accs: 0.95456 | Valid Accs: 0.75394 | Time: 0.53 seconds
# Epoch: 150 | Train Loss: 0.21196 | Valid Loss: 0.90434 |Train Accs: 0.95338 | Valid Accs: 0.74909 | Time: 0.54 seconds
# Epoch: 151 | Train Loss: 0.21719 | Valid Loss: 0.89105 |Train Accs: 0.95191 | Valid Accs: 0.75649 | Time: 0.64 seconds
#
# Early Stopping at Epoch 152
#
# **************************************************
#
# Best Validation Loss at Epoch 126
#
# **************************************************
#
# Best Validation Accs at Epoch 126
#
# **************************************************
#
# Time Taken [152 Epochs] : 1.92 minutes
#
# **************************************************
# **************************************************
#
# Training Fold 3...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.76722 | Valid Loss: 4.61721 |Train Accs: 0.00965 | Valid Accs: 0.01035 | Time: 0.67 seconds
# Epoch: 2 | Train Loss: 4.77120 | Valid Loss: 4.62459 |Train Accs: 0.00819 | Valid Accs: 0.01073 | Time: 0.64 seconds
# Epoch: 3 | Train Loss: 4.76755 | Valid Loss: 4.62410 |Train Accs: 0.00937 | Valid Accs: 0.01190 | Time: 0.53 seconds
# Epoch: 4 | Train Loss: 4.76636 | Valid Loss: 4.62252 |Train Accs: 0.01036 | Valid Accs: 0.01092 | Time: 0.54 seconds
# Epoch: 5 | Train Loss: 4.75822 | Valid Loss: 4.62053 |Train Accs: 0.01149 | Valid Accs: 0.01229 | Time: 0.54 seconds
# Epoch: 6 | Train Loss: 4.75792 | Valid Loss: 4.61767 |Train Accs: 0.01008 | Valid Accs: 0.01249 | Time: 0.61 seconds
# Epoch: 7 | Train Loss: 4.75323 | Valid Loss: 4.61503 |Train Accs: 0.00955 | Valid Accs: 0.01268 | Time: 1.34 seconds
# Epoch: 8 | Train Loss: 4.75106 | Valid Loss: 4.61157 |Train Accs: 0.01214 | Valid Accs: 0.01327 | Time: 0.78 seconds
# Epoch: 9 | Train Loss: 4.74743 | Valid Loss: 4.60792 |Train Accs: 0.01128 | Valid Accs: 0.01366 | Time: 0.70 seconds
# Epoch: 10 | Train Loss: 4.74147 | Valid Loss: 4.60324 |Train Accs: 0.01149 | Valid Accs: 0.01424 | Time: 0.71 seconds
# Epoch: 11 | Train Loss: 4.73768 | Valid Loss: 4.59839 |Train Accs: 0.01166 | Valid Accs: 0.01483 | Time: 0.69 seconds
# Epoch: 12 | Train Loss: 4.74384 | Valid Loss: 4.59252 |Train Accs: 0.01009 | Valid Accs: 0.01697 | Time: 0.79 seconds
# Epoch: 13 | Train Loss: 4.72961 | Valid Loss: 4.58691 |Train Accs: 0.01117 | Valid Accs: 0.01990 | Time: 0.68 seconds
# Epoch: 14 | Train Loss: 4.71967 | Valid Loss: 4.57966 |Train Accs: 0.01198 | Valid Accs: 0.02049 | Time: 0.70 seconds
# Epoch: 15 | Train Loss: 4.71081 | Valid Loss: 4.57122 |Train Accs: 0.01279 | Valid Accs: 0.02263 | Time: 0.70 seconds
# Epoch: 16 | Train Loss: 4.70135 | Valid Loss: 4.56245 |Train Accs: 0.01480 | Valid Accs: 0.02595 | Time: 1.72 seconds
# Epoch: 17 | Train Loss: 4.69807 | Valid Loss: 4.55271 |Train Accs: 0.01242 | Valid Accs: 0.02966 | Time: 0.70 seconds
# Epoch: 18 | Train Loss: 4.68603 | Valid Loss: 4.54166 |Train Accs: 0.01502 | Valid Accs: 0.03414 | Time: 0.71 seconds
# Epoch: 19 | Train Loss: 4.67501 | Valid Loss: 4.52944 |Train Accs: 0.01573 | Valid Accs: 0.04078 | Time: 0.71 seconds
# Epoch: 20 | Train Loss: 4.64959 | Valid Loss: 4.51672 |Train Accs: 0.01670 | Valid Accs: 0.04293 | Time: 0.97 seconds
# Epoch: 21 | Train Loss: 4.64417 | Valid Loss: 4.50202 |Train Accs: 0.01811 | Valid Accs: 0.04898 | Time: 0.71 seconds
# Epoch: 22 | Train Loss: 4.63353 | Valid Loss: 4.48572 |Train Accs: 0.02012 | Valid Accs: 0.05346 | Time: 1.37 seconds
# Epoch: 23 | Train Loss: 4.59678 | Valid Loss: 4.46854 |Train Accs: 0.02310 | Valid Accs: 0.06165 | Time: 0.70 seconds
# Epoch: 24 | Train Loss: 4.58811 | Valid Loss: 4.44895 |Train Accs: 0.02483 | Valid Accs: 0.06634 | Time: 0.81 seconds
# Epoch: 25 | Train Loss: 4.56783 | Valid Loss: 4.42842 |Train Accs: 0.02634 | Valid Accs: 0.07415 | Time: 0.71 seconds
# Epoch: 26 | Train Loss: 4.54299 | Valid Loss: 4.40546 |Train Accs: 0.02841 | Valid Accs: 0.07923 | Time: 0.70 seconds
# Epoch: 27 | Train Loss: 4.51949 | Valid Loss: 4.38038 |Train Accs: 0.03210 | Valid Accs: 0.08898 | Time: 0.67 seconds
# Epoch: 28 | Train Loss: 4.49163 | Valid Loss: 4.35307 |Train Accs: 0.03517 | Valid Accs: 0.09816 | Time: 1.42 seconds
# Epoch: 29 | Train Loss: 4.46850 | Valid Loss: 4.32324 |Train Accs: 0.03940 | Valid Accs: 0.10868 | Time: 0.69 seconds
# Epoch: 30 | Train Loss: 4.43540 | Valid Loss: 4.29124 |Train Accs: 0.04413 | Valid Accs: 0.11512 | Time: 0.69 seconds
# Epoch: 31 | Train Loss: 4.40580 | Valid Loss: 4.25987 |Train Accs: 0.04922 | Valid Accs: 0.12117 | Time: 0.69 seconds
# Epoch: 32 | Train Loss: 4.36714 | Valid Loss: 4.22520 |Train Accs: 0.05491 | Valid Accs: 0.13054 | Time: 0.80 seconds
# Epoch: 33 | Train Loss: 4.34146 | Valid Loss: 4.18897 |Train Accs: 0.05990 | Valid Accs: 0.14010 | Time: 0.82 seconds
# Epoch: 34 | Train Loss: 4.30375 | Valid Loss: 4.14968 |Train Accs: 0.06221 | Valid Accs: 0.15083 | Time: 1.31 seconds
# Epoch: 35 | Train Loss: 4.25233 | Valid Loss: 4.11167 |Train Accs: 0.06843 | Valid Accs: 0.15960 | Time: 0.70 seconds
# Epoch: 36 | Train Loss: 4.22555 | Valid Loss: 4.06909 |Train Accs: 0.07423 | Valid Accs: 0.17013 | Time: 0.81 seconds
# Epoch: 37 | Train Loss: 4.17333 | Valid Loss: 4.02622 |Train Accs: 0.08100 | Valid Accs: 0.18027 | Time: 0.68 seconds
# Epoch: 38 | Train Loss: 4.13174 | Valid Loss: 3.98128 |Train Accs: 0.08815 | Valid Accs: 0.18711 | Time: 0.68 seconds
# Epoch: 39 | Train Loss: 4.08567 | Valid Loss: 3.93079 |Train Accs: 0.09878 | Valid Accs: 0.19627 | Time: 0.68 seconds
# Epoch: 40 | Train Loss: 4.02924 | Valid Loss: 3.88274 |Train Accs: 0.11151 | Valid Accs: 0.20311 | Time: 1.47 seconds
# Epoch: 41 | Train Loss: 3.98723 | Valid Loss: 3.82784 |Train Accs: 0.11909 | Valid Accs: 0.21832 | Time: 0.70 seconds
# Epoch: 42 | Train Loss: 3.92493 | Valid Loss: 3.76930 |Train Accs: 0.12792 | Valid Accs: 0.23002 | Time: 0.71 seconds
# Epoch: 43 | Train Loss: 3.87996 | Valid Loss: 3.70962 |Train Accs: 0.13587 | Valid Accs: 0.24017 | Time: 0.68 seconds
# Epoch: 44 | Train Loss: 3.81131 | Valid Loss: 3.64835 |Train Accs: 0.14820 | Valid Accs: 0.25753 | Time: 0.79 seconds
# Epoch: 45 | Train Loss: 3.75462 | Valid Loss: 3.58255 |Train Accs: 0.15786 | Valid Accs: 0.27119 | Time: 0.75 seconds
# Epoch: 46 | Train Loss: 3.69244 | Valid Loss: 3.51700 |Train Accs: 0.17132 | Valid Accs: 0.28212 | Time: 1.51 seconds
# Epoch: 47 | Train Loss: 3.62446 | Valid Loss: 3.44743 |Train Accs: 0.18296 | Valid Accs: 0.29441 | Time: 0.69 seconds
# Epoch: 48 | Train Loss: 3.56121 | Valid Loss: 3.37602 |Train Accs: 0.19579 | Valid Accs: 0.30981 | Time: 0.79 seconds
# Epoch: 49 | Train Loss: 3.49752 | Valid Loss: 3.31020 |Train Accs: 0.20957 | Valid Accs: 0.32172 | Time: 0.69 seconds
# Epoch: 50 | Train Loss: 3.42084 | Valid Loss: 3.23849 |Train Accs: 0.22416 | Valid Accs: 0.33751 | Time: 0.69 seconds
# Epoch: 51 | Train Loss: 3.35624 | Valid Loss: 3.16805 |Train Accs: 0.23819 | Valid Accs: 0.35216 | Time: 0.69 seconds
# Epoch: 52 | Train Loss: 3.28018 | Valid Loss: 3.09599 |Train Accs: 0.25242 | Valid Accs: 0.36406 | Time: 1.36 seconds
# Epoch: 53 | Train Loss: 3.21472 | Valid Loss: 3.02689 |Train Accs: 0.26945 | Valid Accs: 0.37713 | Time: 0.70 seconds
# Epoch: 54 | Train Loss: 3.14873 | Valid Loss: 2.95497 |Train Accs: 0.28563 | Valid Accs: 0.38572 | Time: 0.70 seconds
# Epoch: 55 | Train Loss: 3.06869 | Valid Loss: 2.88461 |Train Accs: 0.30373 | Valid Accs: 0.39647 | Time: 0.79 seconds
# Epoch: 56 | Train Loss: 3.00671 | Valid Loss: 2.82052 |Train Accs: 0.30813 | Valid Accs: 0.40935 | Time: 0.70 seconds
# Epoch: 57 | Train Loss: 2.93864 | Valid Loss: 2.74742 |Train Accs: 0.33108 | Valid Accs: 0.42574 | Time: 0.69 seconds
# Epoch: 58 | Train Loss: 2.87744 | Valid Loss: 2.68008 |Train Accs: 0.33776 | Valid Accs: 0.44390 | Time: 1.43 seconds
# Epoch: 59 | Train Loss: 2.80431 | Valid Loss: 2.61428 |Train Accs: 0.35369 | Valid Accs: 0.45755 | Time: 0.96 seconds
# Epoch: 60 | Train Loss: 2.74546 | Valid Loss: 2.54929 |Train Accs: 0.36702 | Valid Accs: 0.46633 | Time: 0.72 seconds
# Epoch: 61 | Train Loss: 2.67576 | Valid Loss: 2.48571 |Train Accs: 0.38972 | Valid Accs: 0.47725 | Time: 0.83 seconds
# Epoch: 62 | Train Loss: 2.60508 | Valid Loss: 2.42210 |Train Accs: 0.40433 | Valid Accs: 0.49169 | Time: 0.73 seconds
# Epoch: 63 | Train Loss: 2.53361 | Valid Loss: 2.35940 |Train Accs: 0.42399 | Valid Accs: 0.50535 | Time: 0.69 seconds
# Epoch: 64 | Train Loss: 2.47235 | Valid Loss: 2.30086 |Train Accs: 0.44051 | Valid Accs: 0.51628 | Time: 1.36 seconds
# Epoch: 65 | Train Loss: 2.40211 | Valid Loss: 2.23575 |Train Accs: 0.45765 | Valid Accs: 0.52370 | Time: 0.86 seconds
# Epoch: 66 | Train Loss: 2.34933 | Valid Loss: 2.17836 |Train Accs: 0.46547 | Valid Accs: 0.53931 | Time: 0.71 seconds
# Epoch: 67 | Train Loss: 2.28013 | Valid Loss: 2.11859 |Train Accs: 0.48954 | Valid Accs: 0.55160 | Time: 0.68 seconds
# Epoch: 68 | Train Loss: 2.21866 | Valid Loss: 2.06513 |Train Accs: 0.49171 | Valid Accs: 0.56780 | Time: 0.81 seconds
# Epoch: 69 | Train Loss: 2.16556 | Valid Loss: 2.01398 |Train Accs: 0.51198 | Valid Accs: 0.57463 | Time: 0.66 seconds
# Epoch: 70 | Train Loss: 2.10295 | Valid Loss: 1.95807 |Train Accs: 0.51999 | Valid Accs: 0.59120 | Time: 1.35 seconds
# Epoch: 71 | Train Loss: 2.04079 | Valid Loss: 1.90742 |Train Accs: 0.54433 | Valid Accs: 0.60505 | Time: 0.76 seconds
# Epoch: 72 | Train Loss: 1.99317 | Valid Loss: 1.86080 |Train Accs: 0.54988 | Valid Accs: 0.61287 | Time: 0.89 seconds
# Epoch: 73 | Train Loss: 1.93407 | Valid Loss: 1.81375 |Train Accs: 0.56687 | Valid Accs: 0.61989 | Time: 0.70 seconds
# Epoch: 74 | Train Loss: 1.88399 | Valid Loss: 1.76954 |Train Accs: 0.57591 | Valid Accs: 0.63023 | Time: 0.80 seconds
# Epoch: 75 | Train Loss: 1.82697 | Valid Loss: 1.72598 |Train Accs: 0.59659 | Valid Accs: 0.64036 | Time: 0.66 seconds
# Epoch: 76 | Train Loss: 1.77259 | Valid Loss: 1.68060 |Train Accs: 0.60405 | Valid Accs: 0.64798 | Time: 1.08 seconds
# Epoch: 77 | Train Loss: 1.72459 | Valid Loss: 1.63477 |Train Accs: 0.61695 | Valid Accs: 0.65637 | Time: 0.71 seconds
# Epoch: 78 | Train Loss: 1.67074 | Valid Loss: 1.59949 |Train Accs: 0.62940 | Valid Accs: 0.66183 | Time: 0.83 seconds
# Epoch: 79 | Train Loss: 1.62197 | Valid Loss: 1.56126 |Train Accs: 0.64012 | Valid Accs: 0.66455 | Time: 0.71 seconds
# Epoch: 80 | Train Loss: 1.56390 | Valid Loss: 1.52386 |Train Accs: 0.65534 | Valid Accs: 0.67470 | Time: 0.66 seconds
# Epoch: 81 | Train Loss: 1.53052 | Valid Loss: 1.48565 |Train Accs: 0.65940 | Valid Accs: 0.68134 | Time: 0.90 seconds
# Epoch: 82 | Train Loss: 1.47768 | Valid Loss: 1.45377 |Train Accs: 0.67495 | Valid Accs: 0.68952 | Time: 1.70 seconds
# Epoch: 83 | Train Loss: 1.43372 | Valid Loss: 1.41966 |Train Accs: 0.68480 | Valid Accs: 0.69499 | Time: 0.73 seconds
# Epoch: 84 | Train Loss: 1.38663 | Valid Loss: 1.38808 |Train Accs: 0.69775 | Valid Accs: 0.69364 | Time: 1.16 seconds
# Epoch: 85 | Train Loss: 1.34556 | Valid Loss: 1.35570 |Train Accs: 0.70612 | Valid Accs: 0.69638 | Time: 0.86 seconds
# Epoch: 86 | Train Loss: 1.30404 | Valid Loss: 1.32981 |Train Accs: 0.72099 | Valid Accs: 0.70280 | Time: 0.69 seconds
# Epoch: 87 | Train Loss: 1.25815 | Valid Loss: 1.30144 |Train Accs: 0.72829 | Valid Accs: 0.70672 | Time: 1.09 seconds
# Epoch: 88 | Train Loss: 1.21257 | Valid Loss: 1.28120 |Train Accs: 0.74102 | Valid Accs: 0.71236 | Time: 0.74 seconds
# Epoch: 89 | Train Loss: 1.18160 | Valid Loss: 1.25056 |Train Accs: 0.74243 | Valid Accs: 0.71257 | Time: 0.66 seconds
# ...
# Epoch: 38 | Train Loss: 4.12581 | Valid Loss: 3.98600 |Train Accs: 0.08847 | Valid Accs: 0.19289 | Time: 0.68 seconds
# Epoch: 39 | Train Loss: 4.08088 | Valid Loss: 3.93676 |Train Accs: 0.09752 | Valid Accs: 0.20226 | Time: 0.83 seconds
# Epoch: 40 | Train Loss: 4.03515 | Valid Loss: 3.88493 |Train Accs: 0.10635 | Valid Accs: 0.20968 | Time: 0.72 seconds
# Epoch: 41 | Train Loss: 3.98184 | Valid Loss: 3.83525 |Train Accs: 0.11605 | Valid Accs: 0.21827 | Time: 0.71 seconds
# Epoch: 42 | Train Loss: 3.92578 | Valid Loss: 3.77801 |Train Accs: 0.12819 | Valid Accs: 0.23175 | Time: 1.37 seconds
# Epoch: 43 | Train Loss: 3.87216 | Valid Loss: 3.71767 |Train Accs: 0.13941 | Valid Accs: 0.24307 | Time: 0.85 seconds
# Epoch: 44 | Train Loss: 3.81241 | Valid Loss: 3.65966 |Train Accs: 0.14756 | Valid Accs: 0.25888 | Time: 0.69 seconds
# Epoch: 45 | Train Loss: 3.75036 | Valid Loss: 3.59497 |Train Accs: 0.16243 | Valid Accs: 0.26787 | Time: 0.72 seconds
# Epoch: 46 | Train Loss: 3.68524 | Valid Loss: 3.52658 |Train Accs: 0.17821 | Valid Accs: 0.27509 | Time: 0.67 seconds
# Epoch: 47 | Train Loss: 3.62196 | Valid Loss: 3.46027 |Train Accs: 0.18375 | Valid Accs: 0.28407 | Time: 0.81 seconds
# Epoch: 48 | Train Loss: 3.54370 | Valid Loss: 3.39571 |Train Accs: 0.20178 | Valid Accs: 0.30047 | Time: 1.37 seconds
# Epoch: 49 | Train Loss: 3.47918 | Valid Loss: 3.32709 |Train Accs: 0.21617 | Valid Accs: 0.31297 | Time: 0.72 seconds
# Epoch: 50 | Train Loss: 3.41653 | Valid Loss: 3.25404 |Train Accs: 0.22393 | Valid Accs: 0.32800 | Time: 0.81 seconds
# Epoch: 51 | Train Loss: 3.34564 | Valid Loss: 3.18620 |Train Accs: 0.24012 | Valid Accs: 0.33972 | Time: 0.85 seconds
# Epoch: 52 | Train Loss: 3.28226 | Valid Loss: 3.11614 |Train Accs: 0.25630 | Valid Accs: 0.35279 | Time: 0.68 seconds
# Epoch: 53 | Train Loss: 3.20823 | Valid Loss: 3.04953 |Train Accs: 0.26687 | Valid Accs: 0.36705 | Time: 0.70 seconds
# Epoch: 54 | Train Loss: 3.14023 | Valid Loss: 2.97945 |Train Accs: 0.28191 | Valid Accs: 0.37955 | Time: 0.90 seconds
# Epoch: 55 | Train Loss: 3.06493 | Valid Loss: 2.91239 |Train Accs: 0.30427 | Valid Accs: 0.39067 | Time: 0.74 seconds
# Epoch: 56 | Train Loss: 2.99381 | Valid Loss: 2.84368 |Train Accs: 0.31606 | Valid Accs: 0.40609 | Time: 0.67 seconds
# Epoch: 57 | Train Loss: 2.93355 | Valid Loss: 2.77542 |Train Accs: 0.33138 | Valid Accs: 0.41819 | Time: 0.69 seconds
# Epoch: 58 | Train Loss: 2.86189 | Valid Loss: 2.70640 |Train Accs: 0.34673 | Valid Accs: 0.43245 | Time: 0.73 seconds
# Epoch: 59 | Train Loss: 2.79693 | Valid Loss: 2.63777 |Train Accs: 0.36051 | Valid Accs: 0.44924 | Time: 0.67 seconds
# Epoch: 60 | Train Loss: 2.72284 | Valid Loss: 2.57373 |Train Accs: 0.37567 | Valid Accs: 0.45959 | Time: 0.81 seconds
# Epoch: 61 | Train Loss: 2.67000 | Valid Loss: 2.50736 |Train Accs: 0.39243 | Valid Accs: 0.47364 | Time: 1.74 seconds
# Epoch: 62 | Train Loss: 2.59450 | Valid Loss: 2.44525 |Train Accs: 0.40676 | Valid Accs: 0.48927 | Time: 0.82 seconds
# Epoch: 63 | Train Loss: 2.53044 | Valid Loss: 2.38358 |Train Accs: 0.42116 | Valid Accs: 0.50352 | Time: 0.79 seconds
# Epoch: 64 | Train Loss: 2.46792 | Valid Loss: 2.31934 |Train Accs: 0.43554 | Valid Accs: 0.52070 | Time: 0.78 seconds
# Epoch: 65 | Train Loss: 2.40454 | Valid Loss: 2.25797 |Train Accs: 0.44791 | Valid Accs: 0.53047 | Time: 0.72 seconds
# Epoch: 66 | Train Loss: 2.34527 | Valid Loss: 2.20001 |Train Accs: 0.46222 | Valid Accs: 0.54491 | Time: 0.66 seconds
# Epoch: 67 | Train Loss: 2.28821 | Valid Loss: 2.14396 |Train Accs: 0.47760 | Valid Accs: 0.55526 | Time: 1.36 seconds
# Epoch: 68 | Train Loss: 2.22279 | Valid Loss: 2.09054 |Train Accs: 0.49397 | Valid Accs: 0.56932 | Time: 0.72 seconds
# Epoch: 69 | Train Loss: 2.16221 | Valid Loss: 2.03550 |Train Accs: 0.50557 | Valid Accs: 0.58083 | Time: 0.70 seconds
# Epoch: 70 | Train Loss: 2.09367 | Valid Loss: 1.98464 |Train Accs: 0.52699 | Valid Accs: 0.58865 | Time: 0.69 seconds
# Epoch: 71 | Train Loss: 2.03831 | Valid Loss: 1.93230 |Train Accs: 0.53668 | Valid Accs: 0.59528 | Time: 0.70 seconds
# Epoch: 72 | Train Loss: 1.98361 | Valid Loss: 1.88345 |Train Accs: 0.55146 | Valid Accs: 0.60310 | Time: 0.83 seconds
# Epoch: 73 | Train Loss: 1.93124 | Valid Loss: 1.82858 |Train Accs: 0.56645 | Valid Accs: 0.61481 | Time: 1.45 seconds
# Epoch: 74 | Train Loss: 1.87820 | Valid Loss: 1.78954 |Train Accs: 0.57661 | Valid Accs: 0.62809 | Time: 0.81 seconds
# Epoch: 75 | Train Loss: 1.81742 | Valid Loss: 1.74118 |Train Accs: 0.59788 | Valid Accs: 0.63628 | Time: 0.70 seconds
# Epoch: 76 | Train Loss: 1.76878 | Valid Loss: 1.70381 |Train Accs: 0.60799 | Valid Accs: 0.63980 | Time: 0.70 seconds
# Epoch: 77 | Train Loss: 1.71267 | Valid Loss: 1.65688 |Train Accs: 0.62036 | Valid Accs: 0.65151 | Time: 0.82 seconds
# Epoch: 78 | Train Loss: 1.66851 | Valid Loss: 1.62354 |Train Accs: 0.62896 | Valid Accs: 0.65405 | Time: 0.71 seconds
# Epoch: 79 | Train Loss: 1.60906 | Valid Loss: 1.58594 |Train Accs: 0.64466 | Valid Accs: 0.66264 | Time: 1.35 seconds
# Epoch: 80 | Train Loss: 1.57414 | Valid Loss: 1.53570 |Train Accs: 0.64771 | Valid Accs: 0.66947 | Time: 0.82 seconds
# Epoch: 81 | Train Loss: 1.52599 | Valid Loss: 1.50778 |Train Accs: 0.65876 | Valid Accs: 0.67806 | Time: 0.69 seconds
# Epoch: 82 | Train Loss: 1.47991 | Valid Loss: 1.47113 |Train Accs: 0.67489 | Valid Accs: 0.68080 | Time: 0.72 seconds
# Epoch: 83 | Train Loss: 1.43004 | Valid Loss: 1.43864 |Train Accs: 0.68652 | Valid Accs: 0.68743 | Time: 0.70 seconds
# Epoch: 84 | Train Loss: 1.38125 | Valid Loss: 1.40617 |Train Accs: 0.69693 | Valid Accs: 0.69153 | Time: 0.67 seconds
# Epoch: 85 | Train Loss: 1.33467 | Valid Loss: 1.37955 |Train Accs: 0.70882 | Valid Accs: 0.68665 | Time: 1.42 seconds
# Epoch: 86 | Train Loss: 1.29579 | Valid Loss: 1.34909 |Train Accs: 0.71809 | Valid Accs: 0.69427 | Time: 0.94 seconds
# Epoch: 87 | Train Loss: 1.26325 | Valid Loss: 1.32658 |Train Accs: 0.73013 | Valid Accs: 0.69954 | Time: 0.89 seconds
# Epoch: 88 | Train Loss: 1.21820 | Valid Loss: 1.29082 |Train Accs: 0.73498 | Valid Accs: 0.70520 | Time: 0.69 seconds
# Epoch: 89 | Train Loss: 1.17741 | Valid Loss: 1.26403 |Train Accs: 0.74693 | Valid Accs: 0.70695 | Time: 0.69 seconds
# Epoch: 90 | Train Loss: 1.13292 | Valid Loss: 1.24661 |Train Accs: 0.75684 | Valid Accs: 0.71028 | Time: 0.79 seconds
# Epoch: 91 | Train Loss: 1.10057 | Valid Loss: 1.22126 |Train Accs: 0.76575 | Valid Accs: 0.71126 | Time: 1.36 seconds
# Epoch: 92 | Train Loss: 1.06643 | Valid Loss: 1.20500 |Train Accs: 0.77495 | Valid Accs: 0.71086 | Time: 0.72 seconds
# Epoch: 93 | Train Loss: 1.02258 | Valid Loss: 1.18309 |Train Accs: 0.78433 | Valid Accs: 0.71945 | Time: 0.82 seconds
# Epoch: 94 | Train Loss: 0.99626 | Valid Loss: 1.15793 |Train Accs: 0.79088 | Valid Accs: 0.71770 | Time: 0.70 seconds
# Epoch: 95 | Train Loss: 0.94589 | Valid Loss: 1.13674 |Train Accs: 0.80258 | Valid Accs: 0.72921 | Time: 0.67 seconds
# Epoch: 96 | Train Loss: 0.91860 | Valid Loss: 1.11627 |Train Accs: 0.81144 | Valid Accs: 0.73293 | Time: 0.73 seconds
# Epoch: 97 | Train Loss: 0.89112 | Valid Loss: 1.10068 |Train Accs: 0.81183 | Valid Accs: 0.73175 | Time: 1.39 seconds
# Epoch: 98 | Train Loss: 0.87001 | Valid Loss: 1.08453 |Train Accs: 0.81442 | Valid Accs: 0.73097 | Time: 0.70 seconds
# Epoch: 99 | Train Loss: 0.83517 | Valid Loss: 1.07202 |Train Accs: 0.82758 | Valid Accs: 0.73176 | Time: 1.02 seconds
# Epoch: 100 | Train Loss: 0.78141 | Valid Loss: 1.05084 |Train Accs: 0.84555 | Valid Accs: 0.73098 | Time: 0.74 seconds
# Epoch: 101 | Train Loss: 0.75686 | Valid Loss: 1.03364 |Train Accs: 0.84623 | Valid Accs: 0.73449 | Time: 0.71 seconds
# Epoch: 102 | Train Loss: 0.73094 | Valid Loss: 1.02377 |Train Accs: 0.85546 | Valid Accs: 0.73664 | Time: 0.67 seconds
# Epoch: 103 | Train Loss: 0.70004 | Valid Loss: 1.02134 |Train Accs: 0.86110 | Valid Accs: 0.74113 | Time: 1.36 seconds
# Epoch: 104 | Train Loss: 0.67236 | Valid Loss: 1.00079 |Train Accs: 0.86822 | Valid Accs: 0.74444 | Time: 0.69 seconds
# Epoch: 105 | Train Loss: 0.65300 | Valid Loss: 0.99151 |Train Accs: 0.87245 | Valid Accs: 0.74094 | Time: 0.74 seconds
# Epoch: 106 | Train Loss: 0.61497 | Valid Loss: 0.97946 |Train Accs: 0.88162 | Valid Accs: 0.74561 | Time: 0.84 seconds
# Epoch: 107 | Train Loss: 0.60282 | Valid Loss: 0.96465 |Train Accs: 0.88179 | Valid Accs: 0.74718 | Time: 0.69 seconds
# Epoch: 108 | Train Loss: 0.57149 | Valid Loss: 0.95957 |Train Accs: 0.89066 | Valid Accs: 0.74874 | Time: 0.69 seconds
# Epoch: 109 | Train Loss: 0.55245 | Valid Loss: 0.94881 |Train Accs: 0.89387 | Valid Accs: 0.74523 | Time: 1.36 seconds
# Epoch: 110 | Train Loss: 0.52879 | Valid Loss: 0.94943 |Train Accs: 0.90083 | Valid Accs: 0.74933 | Time: 0.57 seconds
# Epoch: 111 | Train Loss: 0.51292 | Valid Loss: 0.95633 |Train Accs: 0.90412 | Valid Accs: 0.74094 | Time: 0.72 seconds
# Epoch: 112 | Train Loss: 0.49962 | Valid Loss: 0.93569 |Train Accs: 0.90363 | Valid Accs: 0.75011 | Time: 1.08 seconds
# Epoch: 113 | Train Loss: 0.47685 | Valid Loss: 0.93254 |Train Accs: 0.91139 | Valid Accs: 0.74582 | Time: 0.78 seconds
# Epoch: 114 | Train Loss: 0.45600 | Valid Loss: 0.91453 |Train Accs: 0.91573 | Valid Accs: 0.74913 | Time: 0.78 seconds
# Epoch: 115 | Train Loss: 0.43845 | Valid Loss: 0.91228 |Train Accs: 0.91940 | Valid Accs: 0.74815 | Time: 0.72 seconds
# Epoch: 116 | Train Loss: 0.42615 | Valid Loss: 0.91050 |Train Accs: 0.92071 | Valid Accs: 0.75498 | Time: 0.84 seconds
# Epoch: 117 | Train Loss: 0.41693 | Valid Loss: 0.91258 |Train Accs: 0.92149 | Valid Accs: 0.74289 | Time: 0.54 seconds
# Epoch: 118 | Train Loss: 0.39834 | Valid Loss: 0.90218 |Train Accs: 0.92561 | Valid Accs: 0.75519 | Time: 0.69 seconds
# Epoch: 119 | Train Loss: 0.39163 | Valid Loss: 0.89946 |Train Accs: 0.92646 | Valid Accs: 0.75070 | Time: 0.81 seconds
# Epoch: 120 | Train Loss: 0.37759 | Valid Loss: 0.88965 |Train Accs: 0.92949 | Valid Accs: 0.75401 | Time: 0.70 seconds
# Epoch: 121 | Train Loss: 0.36204 | Valid Loss: 0.89458 |Train Accs: 0.93438 | Valid Accs: 0.74933 | Time: 0.54 seconds
# Epoch: 122 | Train Loss: 0.34493 | Valid Loss: 0.90408 |Train Accs: 0.93783 | Valid Accs: 0.75440 | Time: 0.53 seconds
# Epoch: 123 | Train Loss: 0.33883 | Valid Loss: 0.89331 |Train Accs: 0.93708 | Valid Accs: 0.74699 | Time: 0.54 seconds
# Epoch: 124 | Train Loss: 0.31877 | Valid Loss: 0.88665 |Train Accs: 0.94530 | Valid Accs: 0.75205 | Time: 0.67 seconds
# Epoch: 125 | Train Loss: 0.31408 | Valid Loss: 0.87262 |Train Accs: 0.94225 | Valid Accs: 0.75733 | Time: 0.88 seconds
# Epoch: 126 | Train Loss: 0.30911 | Valid Loss: 0.89139 |Train Accs: 0.94293 | Valid Accs: 0.75186 | Time: 0.71 seconds
# Epoch: 127 | Train Loss: 0.31539 | Valid Loss: 0.87943 |Train Accs: 0.93952 | Valid Accs: 0.75342 | Time: 0.53 seconds
# Epoch: 128 | Train Loss: 0.30970 | Valid Loss: 0.88325 |Train Accs: 0.94093 | Valid Accs: 0.74815 | Time: 0.62 seconds
# Epoch: 129 | Train Loss: 0.29599 | Valid Loss: 0.89606 |Train Accs: 0.94464 | Valid Accs: 0.74718 | Time: 0.73 seconds
# Epoch: 130 | Train Loss: 0.28901 | Valid Loss: 0.89513 |Train Accs: 0.94493 | Valid Accs: 0.74952 | Time: 0.54 seconds
# Epoch: 131 | Train Loss: 0.29004 | Valid Loss: 0.89263 |Train Accs: 0.94184 | Valid Accs: 0.75342 | Time: 0.54 seconds
# Epoch: 132 | Train Loss: 0.27814 | Valid Loss: 0.90060 |Train Accs: 0.94651 | Valid Accs: 0.74737 | Time: 0.64 seconds
# Epoch: 133 | Train Loss: 0.26547 | Valid Loss: 0.89205 |Train Accs: 0.94688 | Valid Accs: 0.75381 | Time: 0.53 seconds
# Epoch: 134 | Train Loss: 0.26512 | Valid Loss: 0.89301 |Train Accs: 0.94793 | Valid Accs: 0.75147 | Time: 0.55 seconds
# Epoch: 135 | Train Loss: 0.25896 | Valid Loss: 0.91489 |Train Accs: 0.94992 | Valid Accs: 0.74698 | Time: 0.53 seconds
# Epoch: 136 | Train Loss: 0.24725 | Valid Loss: 0.89730 |Train Accs: 0.95132 | Valid Accs: 0.74484 | Time: 0.53 seconds
# Epoch: 137 | Train Loss: 0.24205 | Valid Loss: 0.87976 |Train Accs: 0.95056 | Valid Accs: 0.75869 | Time: 0.56 seconds
# Epoch: 138 | Train Loss: 0.24427 | Valid Loss: 0.86783 |Train Accs: 0.95220 | Valid Accs: 0.75869 | Time: 0.81 seconds
# Epoch: 139 | Train Loss: 0.24035 | Valid Loss: 0.89326 |Train Accs: 0.95073 | Valid Accs: 0.75341 | Time: 0.54 seconds
# Epoch: 140 | Train Loss: 0.24025 | Valid Loss: 0.91698 |Train Accs: 0.95257 | Valid Accs: 0.74424 | Time: 0.53 seconds
# Epoch: 141 | Train Loss: 0.23862 | Valid Loss: 0.88695 |Train Accs: 0.95166 | Valid Accs: 0.74815 | Time: 0.53 seconds
# Epoch: 142 | Train Loss: 0.24113 | Valid Loss: 0.86681 |Train Accs: 0.95113 | Valid Accs: 0.75830 | Time: 0.80 seconds
# Epoch: 143 | Train Loss: 0.23677 | Valid Loss: 0.90119 |Train Accs: 0.94922 | Valid Accs: 0.75147 | Time: 0.59 seconds
# Epoch: 144 | Train Loss: 0.23340 | Valid Loss: 0.90639 |Train Accs: 0.94906 | Valid Accs: 0.74894 | Time: 0.54 seconds
# Epoch: 145 | Train Loss: 0.23472 | Valid Loss: 0.90302 |Train Accs: 0.94959 | Valid Accs: 0.74679 | Time: 0.64 seconds
# Epoch: 146 | Train Loss: 0.22264 | Valid Loss: 0.88794 |Train Accs: 0.95305 | Valid Accs: 0.75206 | Time: 0.54 seconds
# Epoch: 147 | Train Loss: 0.21396 | Valid Loss: 0.88673 |Train Accs: 0.95568 | Valid Accs: 0.75284 | Time: 0.72 seconds
# Epoch: 148 | Train Loss: 0.22624 | Valid Loss: 0.91046 |Train Accs: 0.95083 | Valid Accs: 0.74912 | Time: 0.57 seconds
# Epoch: 149 | Train Loss: 0.22681 | Valid Loss: 0.89955 |Train Accs: 0.94963 | Valid Accs: 0.74776 | Time: 0.53 seconds
# Epoch: 150 | Train Loss: 0.22204 | Valid Loss: 0.90947 |Train Accs: 0.95123 | Valid Accs: 0.74893 | Time: 0.53 seconds
# Epoch: 151 | Train Loss: 0.22023 | Valid Loss: 0.90357 |Train Accs: 0.95015 | Valid Accs: 0.74386 | Time: 0.65 seconds
# Epoch: 152 | Train Loss: 0.22786 | Valid Loss: 0.90212 |Train Accs: 0.94765 | Valid Accs: 0.75459 | Time: 0.54 seconds
# Epoch: 153 | Train Loss: 0.21669 | Valid Loss: 0.92512 |Train Accs: 0.95159 | Valid Accs: 0.73898 | Time: 0.54 seconds
# Epoch: 154 | Train Loss: 0.21032 | Valid Loss: 0.94978 |Train Accs: 0.95237 | Valid Accs: 0.73976 | Time: 0.54 seconds
# Epoch: 155 | Train Loss: 0.21387 | Valid Loss: 0.94008 |Train Accs: 0.95079 | Valid Accs: 0.74288 | Time: 0.64 seconds
# Epoch: 156 | Train Loss: 0.21926 | Valid Loss: 0.91825 |Train Accs: 0.94959 | Valid Accs: 0.74659 | Time: 0.54 seconds
# Epoch: 157 | Train Loss: 0.22029 | Valid Loss: 0.90966 |Train Accs: 0.94829 | Valid Accs: 0.74659 | Time: 0.54 seconds
# Epoch: 158 | Train Loss: 0.22024 | Valid Loss: 0.92270 |Train Accs: 0.94770 | Valid Accs: 0.74424 | Time: 0.65 seconds
# Epoch: 159 | Train Loss: 0.21240 | Valid Loss: 0.91294 |Train Accs: 0.95051 | Valid Accs: 0.75127 | Time: 0.55 seconds
# Epoch: 160 | Train Loss: 0.20284 | Valid Loss: 0.92043 |Train Accs: 0.95090 | Valid Accs: 0.74288 | Time: 0.55 seconds
# Epoch: 161 | Train Loss: 0.20169 | Valid Loss: 0.91360 |Train Accs: 0.95370 | Valid Accs: 0.74484 | Time: 0.53 seconds
# Epoch: 162 | Train Loss: 0.20433 | Valid Loss: 0.92901 |Train Accs: 0.94873 | Valid Accs: 0.74522 | Time: 0.53 seconds
# Epoch: 163 | Train Loss: 0.20744 | Valid Loss: 0.91050 |Train Accs: 0.94792 | Valid Accs: 0.75400 | Time: 0.71 seconds
# Epoch: 164 | Train Loss: 0.19060 | Valid Loss: 0.90734 |Train Accs: 0.95603 | Valid Accs: 0.74971 | Time: 0.77 seconds
# Epoch: 165 | Train Loss: 0.18796 | Valid Loss: 0.91501 |Train Accs: 0.95481 | Valid Accs: 0.74132 | Time: 0.65 seconds
# Epoch: 166 | Train Loss: 0.19097 | Valid Loss: 0.94344 |Train Accs: 0.95568 | Valid Accs: 0.73917 | Time: 0.63 seconds
# Epoch: 167 | Train Loss: 0.19678 | Valid Loss: 0.94387 |Train Accs: 0.95200 | Valid Accs: 0.73976 | Time: 0.53 seconds
#
# Early Stopping at Epoch 168
#
# **************************************************
#
# Best Validation Loss at Epoch 142
#
# **************************************************
#
# Best Validation Accs at Epoch 137
#
# **************************************************
#
# Time Taken [168 Epochs] : 2.13 minutes
#
# **************************************************
# **************************************************
#
# Total Time Taken for 5-Fold CV : 10.13 minutes
#
# **************************************************

# %% [markdown]
# ### **Get SWIN Features for the Test Set**

# %%
# train_df = pd.read_csv("../input/sorghum-id-fgvc-9/train_cultivar_mapping.csv")
# ss_df = pd.read_csv("../input/sorghum-id-fgvc-9/sample_submission.csv")

# broken_images = [filename for filename in train_df.image if filename not in os.listdir("../input/sorghum-id-fgvc-9/train_images")]
# for broken_image in broken_images:
#     index = train_df.index[train_df.image == broken_image]
#     train_df = train_df.drop(index=index)
    
# filenames = train_df.image.copy().values
# labels    = train_df.cultivar.copy().values 

# labels = le.fit_transform(labels)

# ts_filenames = ss_df.filename.copy().values
# ts_features = np.zeros((len(ts_filenames), FV_LENGTH))

# %%
# model = timm.create_model("swin_base_patch4_window7_384_in22k", pretrained=True).to(DEVICE)
# model = torch.nn.Sequential(*[*model.children()][:-3])

# dataloader_setup = FEDS("../input/sorghum-id-fgvc-9/test", ts_filenames, TRANSFORM)
# dataloader = DL(dataloader_setup, batch_size=64, shuffle=False)

# ts_features = torch.zeros(1, FV_LENGTH).to(DEVICE)

# for X in dataloader:
#     X = X.to(DEVICE)
#     with torch.no_grad():
#         output = model(X).last_hidden_state
#     ts_features = torch.cat((ts_features, output[:, 0, :]), dim=0)

# ts_features = ts_features[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Submission**

# %%
# ts_data_setup = DS(ts_features, None, "test")
# ts_data = DL(ts_data_setup, batch_size=batch_size, shuffle=False)

# torch.manual_seed(SEED)
# model = Model(IL=ts_features.shape[1], HL=HL, DP=0.5, use_WN=True).to(DEVICE)

# best_model_fold = _____
# y_pred = predict(model=model, dataloader=ts_data, path=os.path.join(CLASSIFIER_HEAD_PATH, f"state_fold_{best_model_fold}.pt"))

# ss_df["cultivar"] = le.inverse_transform(y_pred.astype("uint8"))
# ss_df.to_csv("submission.csv", index=False)
