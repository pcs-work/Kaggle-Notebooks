# %%
# !pip install --upgrade timm

# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import cv2
# import timm
import torch
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torch.nn.utils import weight_norm as WN
# from torchvision import transforms

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### **Utilities and Constants**

# %%
SEED = 42
# SIZE = 384
# FV_LENGTH = 1536
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

FEATURE_PATH = "../input/fgvc9-swinl38422k"

# CLASSIFIER_HEAD_PATH = "../input/fgvc9-swin38422k-train/saves"
# TRANSFORM = transforms.Compose([transforms.ToTensor(), 
#                                 transforms.Normalize([0.485, 0.456, 0.406], 
#                                                      [0.229, 0.224, 0.225]),
#                                ])

SAVE_PATH = "saves"
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# %%
def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
# def get_image(path: str, size: int) -> np.ndarray:
#     image = cv2.imread(path, cv2.IMREAD_COLOR)
#     image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
#     return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_AREA)

    
def show_graphs(L: list, A: list) -> None:
    TL, VL, TA, VA = [], [], [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()

# %% [markdown]
# ### **Dataset Templatea**

# %%
# class FEDS(Dataset):
#     def __init__(self, base_path: str, filenames: np.ndarray, transform):
#         self.base_path = base_path
#         self.filenames = filenames
#         self.transform = transform
    
#     def __len__(self):
#         return self.filenames.shape[0]
    
#     def __getitem__(self, idx):
#         return self.transform(get_image(os.path.join(self.base_path, self.filenames[idx])))


class DS(Dataset):
    def __init__(self, X=None, y=None, mode="train"):
        self.mode = mode

        assert(re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE) or re.match(r"test", self.mode, re.IGNORECASE))

        self.X = X
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            self.y = y
    
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        if re.match(r"train", self.mode, re.IGNORECASE) or re.match(r"valid", self.mode, re.IGNORECASE):
            return torch.FloatTensor(self.X[idx]), torch.LongTensor(self.y[idx])
        else:
            return torch.FloatTensor(self.X[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self, IL: int=None, HL: list=None, DP: float=None, use_WN: bool=False):
        super(Model, self).__init__()

        self.model = nn.Sequential()

        if len(HL) == 1:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=100)))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=100))

        
        elif len(HL) == 2:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=100)))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=100))
        
        elif len(HL) == 3:
            self.model.add_module("BN1", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            if use_WN: 
                self.model.add_module("FC1", WN(nn.Linear(in_features=IL, out_features=HL[0])))
            else: 
                self.model.add_module("FC1", nn.Linear(in_features=IL, out_features=HL[0]))
            if isinstance(DP, float):
                self.model.add_module("DP1", nn.Dropout(p=DP))
            self.model.add_module("AN1", nn.ReLU())
            self.model.add_module("BN2", nn.BatchNorm1d(num_features=HL[0], eps=1e-5))
            if use_WN:
                self.model.add_module("FC2", WN(nn.Linear(in_features=HL[0], out_features=HL[1])))
            else:
                self.model.add_module("FC2", nn.Linear(in_features=HL[0], out_features=HL[1]))
            if isinstance(DP, float):
                self.model.add_module("DP2", nn.Dropout(p=DP))
            self.model.add_module("AN2", nn.ReLU())
            self.model.add_module("BN3", nn.BatchNorm1d(num_features=HL[1], eps=1e-5))
            if use_WN:
                self.model.add_module("FC3", WN(nn.Linear(in_features=HL[1], out_features=HL[2])))
            else:
                self.model.add_module("FC3", nn.Linear(in_features=HL[1], out_features=HL[2]))
            if isinstance(DP, float):
                self.model.add_module("DP3", nn.Dropout(p=DP))
            self.model.add_module("AN3", nn.ReLU())
            self.model.add_module("BN4", nn.BatchNorm1d(num_features=HL[2], eps=1e-5))
            if use_WN: 
                self.model.add_module("FC4", WN(nn.Linear(in_features=HL[2], out_features=100)))
            else:
                self.model.add_module("FC4", nn.Linear(in_features=HL[2], out_features=100))
    
    def get_optimizer(self, lr=1e-3, wd=0.0):
        return optim.Adam(self.parameters(), lr=lr, weight_decay=wd)

    def get_plateau_scheduler(self, optimizer=None, patience=5, eps=1e-8):
        return optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, patience=patience, eps=eps)
    
    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helper**

# %%
def fit(model=None, optimizer=None, scheduler=None, epochs=None, early_stopping_patience=None, dataloaders=None, fold=None, verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        print(f"Training Fold {fold}...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies = [], []
    name = f"state_fold_{fold}.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []
            
            for X, y in dataloaders[phase]:
                X, y = X.to(DEVICE), y.to(DEVICE).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict": model.state_dict(),
                            "optim_state_dict": optimizer.state_dict()},
                           os.path.join(SAVE_PATH, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save({"model_state_dict" : model.state_dict(),
                        "optim_state_dict" : optimizer.state_dict()},
                        os.path.join(SAVE_PATH, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler:
            scheduler.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, BLE, BAE, name


# def predict(model=None, dataloader=None, path=None) -> np.ndarray:
#     model.load_state_dict(torch.load(path, map_location=DEVICE)["model_state_dict"])
#     model.to(DEVICE)    
#     model.eval()
    
#     y_pred = torch.zeros(1, 1).to(DEVICE)
    
#     for X in dataloader:
#         X = X.to(DEVICE)
#         with torch.no_grad():
#             output = torch.argmax(torch.exp(model(X)), dim=1)
#         y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
#     return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Load Data**

# %%
features = np.load(os.path.join(FEATURE_PATH, "features.npy"))
labels   = np.load(os.path.join(FEATURE_PATH, "labels.npy"))

# %% [markdown]
# ### **Params**

# %%
DEBUG: bool = False
    
if DEBUG:
    n_splits = 3
    epochs = 2
    HL = [4]
else:
    n_splits = 5
    epochs = 5000
    HL = [2048, 1024, 512]

batch_size = 512
lr = 1e-6
wd = 1e-5
early_stopping = 50
patience = None
eps = None

# %% [markdown]
# ### **Train**

# %%
fold = 1

start_time = time()
for tr_idx, va_idx in StratifiedKFold(n_splits=n_splits, random_state=SEED, shuffle=True).split(features, labels):
    tr_features, va_features, tr_labels, va_labels = features[tr_idx], features[va_idx], labels[tr_idx], labels[va_idx]
    
    tr_data_setup = DS(tr_features, tr_labels.reshape(-1, 1), "train")
    va_data_setup = DS(va_features, va_labels.reshape(-1, 1), "valid")

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=batch_size, shuffle=True, generator=torch.manual_seed(SEED)),
        "valid" : DL(va_data_setup, batch_size=batch_size, shuffle=False),
    }

    torch.manual_seed(SEED)
    model = Model(IL=tr_features.shape[1], HL=HL, DP=0.5, use_WN=True).to(DEVICE)
    optimizer = model.get_optimizer(lr=lr, wd=wd)
    scheduler = None
    if isinstance(patience, int) and isinstance(eps, float):
        scheduler = get_plateau_scheduler(optimizer=optimizer, patience=patience, eps=eps)
    
    L, A, BLE, BAE, name = fit(model=model, optimizer=optimizer, scheduler=scheduler, 
                           epochs=epochs, early_stopping_patience=early_stopping, 
                           dataloaders=dataloaders, fold=fold, verbose=True)

    breaker()
    show_graphs(L, A)
    fold += 1

breaker()
print(f"Total Time Taken for {n_splits}-Fold CV : {(time()-start_time)/60:.2f} minutes")
breaker()
# Out:
# **************************************************
#
# Training Fold 1...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 4.76855 | Valid Loss: 4.62635 |Train Accs: 0.00985 | Valid Accs: 0.01095 | Time: 1.76 seconds
# Epoch: 2 | Train Loss: 4.77120 | Valid Loss: 4.62701 |Train Accs: 0.00979 | Valid Accs: 0.01084 | Time: 0.60 seconds
# Epoch: 3 | Train Loss: 4.76600 | Valid Loss: 4.62457 |Train Accs: 0.00962 | Valid Accs: 0.01095 | Time: 0.76 seconds
# Epoch: 4 | Train Loss: 4.76694 | Valid Loss: 4.62190 |Train Accs: 0.01116 | Valid Accs: 0.01041 | Time: 0.76 seconds
# Epoch: 5 | Train Loss: 4.75544 | Valid Loss: 4.61956 |Train Accs: 0.01149 | Valid Accs: 0.01236 | Time: 0.94 seconds
# Epoch: 6 | Train Loss: 4.75813 | Valid Loss: 4.61687 |Train Accs: 0.01021 | Valid Accs: 0.01139 | Time: 0.79 seconds
# Epoch: 7 | Train Loss: 4.75021 | Valid Loss: 4.61442 |Train Accs: 0.01121 | Valid Accs: 0.01084 | Time: 0.85 seconds
# Epoch: 8 | Train Loss: 4.75088 | Valid Loss: 4.61206 |Train Accs: 0.01035 | Valid Accs: 0.01204 | Time: 0.92 seconds
# Epoch: 9 | Train Loss: 4.75735 | Valid Loss: 4.60915 |Train Accs: 0.01038 | Valid Accs: 0.01290 | Time: 0.75 seconds
# Epoch: 10 | Train Loss: 4.74506 | Valid Loss: 4.60705 |Train Accs: 0.01071 | Valid Accs: 0.01160 | Time: 0.73 seconds
# Epoch: 11 | Train Loss: 4.74246 | Valid Loss: 4.60457 |Train Accs: 0.01027 | Valid Accs: 0.01225 | Time: 0.74 seconds
# Epoch: 12 | Train Loss: 4.74829 | Valid Loss: 4.60222 |Train Accs: 0.01004 | Valid Accs: 0.01377 | Time: 0.75 seconds
# Epoch: 13 | Train Loss: 4.74537 | Valid Loss: 4.59978 |Train Accs: 0.01104 | Valid Accs: 0.01399 | Time: 0.73 seconds
# Epoch: 14 | Train Loss: 4.73129 | Valid Loss: 4.59715 |Train Accs: 0.01144 | Valid Accs: 0.01518 | Time: 0.74 seconds
# Epoch: 15 | Train Loss: 4.72556 | Valid Loss: 4.59465 |Train Accs: 0.01280 | Valid Accs: 0.01648 | Time: 0.73 seconds
# Epoch: 16 | Train Loss: 4.73068 | Valid Loss: 4.59254 |Train Accs: 0.01144 | Valid Accs: 0.01670 | Time: 1.64 seconds
# Epoch: 17 | Train Loss: 4.73191 | Valid Loss: 4.59001 |Train Accs: 0.01054 | Valid Accs: 0.01768 | Time: 0.73 seconds
# Epoch: 18 | Train Loss: 4.72599 | Valid Loss: 4.58756 |Train Accs: 0.01105 | Valid Accs: 0.01909 | Time: 0.89 seconds
# Epoch: 19 | Train Loss: 4.71470 | Valid Loss: 4.58505 |Train Accs: 0.01289 | Valid Accs: 0.01952 | Time: 0.72 seconds
# Epoch: 20 | Train Loss: 4.71999 | Valid Loss: 4.58265 |Train Accs: 0.01144 | Valid Accs: 0.01930 | Time: 0.73 seconds
# Epoch: 21 | Train Loss: 4.72167 | Valid Loss: 4.58037 |Train Accs: 0.01372 | Valid Accs: 0.02180 | Time: 0.76 seconds
# Epoch: 22 | Train Loss: 4.71143 | Valid Loss: 4.57789 |Train Accs: 0.01389 | Valid Accs: 0.02136 | Time: 0.91 seconds
# Epoch: 23 | Train Loss: 4.71412 | Valid Loss: 4.57532 |Train Accs: 0.01305 | Valid Accs: 0.02180 | Time: 0.74 seconds
# Epoch: 24 | Train Loss: 4.70817 | Valid Loss: 4.57275 |Train Accs: 0.01300 | Valid Accs: 0.02342 | Time: 0.73 seconds
# Epoch: 25 | Train Loss: 4.70759 | Valid Loss: 4.57051 |Train Accs: 0.01408 | Valid Accs: 0.02375 | Time: 0.74 seconds
# Epoch: 26 | Train Loss: 4.70456 | Valid Loss: 4.56803 |Train Accs: 0.01338 | Valid Accs: 0.02516 | Time: 0.74 seconds
# Epoch: 27 | Train Loss: 4.70615 | Valid Loss: 4.56533 |Train Accs: 0.01406 | Valid Accs: 0.02711 | Time: 0.73 seconds
# Epoch: 28 | Train Loss: 4.69329 | Valid Loss: 4.56276 |Train Accs: 0.01381 | Valid Accs: 0.02787 | Time: 0.74 seconds
# Epoch: 29 | Train Loss: 4.69764 | Valid Loss: 4.56090 |Train Accs: 0.01601 | Valid Accs: 0.02831 | Time: 1.64 seconds
# Epoch: 30 | Train Loss: 4.69170 | Valid Loss: 4.55831 |Train Accs: 0.01473 | Valid Accs: 0.02917 | Time: 0.84 seconds
# Epoch: 31 | Train Loss: 4.69027 | Valid Loss: 4.55600 |Train Accs: 0.01416 | Valid Accs: 0.03080 | Time: 0.90 seconds
# Epoch: 32 | Train Loss: 4.69654 | Valid Loss: 4.55306 |Train Accs: 0.01411 | Valid Accs: 0.03189 | Time: 0.74 seconds
# Epoch: 33 | Train Loss: 4.68836 | Valid Loss: 4.55045 |Train Accs: 0.01525 | Valid Accs: 0.03091 | Time: 0.95 seconds
# Epoch: 34 | Train Loss: 4.68366 | Valid Loss: 4.54837 |Train Accs: 0.01520 | Valid Accs: 0.03351 | Time: 1.03 seconds
# Epoch: 35 | Train Loss: 4.68819 | Valid Loss: 4.54580 |Train Accs: 0.01515 | Valid Accs: 0.03438 | Time: 0.73 seconds
# Epoch: 36 | Train Loss: 4.67572 | Valid Loss: 4.54335 |Train Accs: 0.01631 | Valid Accs: 0.03503 | Time: 0.73 seconds
# Epoch: 37 | Train Loss: 4.67488 | Valid Loss: 4.54098 |Train Accs: 0.01581 | Valid Accs: 0.03492 | Time: 0.83 seconds
# Epoch: 38 | Train Loss: 4.66837 | Valid Loss: 4.53850 |Train Accs: 0.01559 | Valid Accs: 0.03731 | Time: 0.72 seconds
# Epoch: 39 | Train Loss: 4.67288 | Valid Loss: 4.53612 |Train Accs: 0.01724 | Valid Accs: 0.03785 | Time: 0.72 seconds
# Epoch: 40 | Train Loss: 4.67234 | Valid Loss: 4.53382 |Train Accs: 0.01573 | Valid Accs: 0.03763 | Time: 0.73 seconds
# Epoch: 41 | Train Loss: 4.67041 | Valid Loss: 4.53127 |Train Accs: 0.01573 | Valid Accs: 0.04067 | Time: 1.63 seconds
# Epoch: 42 | Train Loss: 4.66577 | Valid Loss: 4.52872 |Train Accs: 0.01704 | Valid Accs: 0.04034 | Time: 0.73 seconds
# Epoch: 43 | Train Loss: 4.66111 | Valid Loss: 4.52620 |Train Accs: 0.01710 | Valid Accs: 0.04045 | Time: 0.76 seconds
# Epoch: 44 | Train Loss: 4.65682 | Valid Loss: 4.52387 |Train Accs: 0.01643 | Valid Accs: 0.04457 | Time: 0.91 seconds
# Epoch: 45 | Train Loss: 4.65423 | Valid Loss: 4.52101 |Train Accs: 0.01584 | Valid Accs: 0.04555 | Time: 0.82 seconds
# Epoch: 46 | Train Loss: 4.66614 | Valid Loss: 4.51874 |Train Accs: 0.01523 | Valid Accs: 0.04717 | Time: 0.73 seconds
# Epoch: 47 | Train Loss: 4.65251 | Valid Loss: 4.51590 |Train Accs: 0.01706 | Valid Accs: 0.04804 | Time: 0.79 seconds
# Epoch: 48 | Train Loss: 4.64956 | Valid Loss: 4.51380 |Train Accs: 0.01796 | Valid Accs: 0.04772 | Time: 0.73 seconds
# Epoch: 49 | Train Loss: 4.64990 | Valid Loss: 4.51100 |Train Accs: 0.01824 | Valid Accs: 0.05065 | Time: 0.75 seconds
# Epoch: 50 | Train Loss: 4.64165 | Valid Loss: 4.50851 |Train Accs: 0.01905 | Valid Accs: 0.05010 | Time: 0.73 seconds
# Epoch: 51 | Train Loss: 4.64531 | Valid Loss: 4.50598 |Train Accs: 0.01844 | Valid Accs: 0.05292 | Time: 0.72 seconds
# Epoch: 52 | Train Loss: 4.64142 | Valid Loss: 4.50315 |Train Accs: 0.01765 | Valid Accs: 0.05228 | Time: 0.83 seconds
# Epoch: 53 | Train Loss: 4.63537 | Valid Loss: 4.50127 |Train Accs: 0.01883 | Valid Accs: 0.05325 | Time: 0.76 seconds
# Epoch: 54 | Train Loss: 4.63918 | Valid Loss: 4.49865 |Train Accs: 0.01704 | Valid Accs: 0.05444 | Time: 1.55 seconds
# Epoch: 55 | Train Loss: 4.62937 | Valid Loss: 4.49629 |Train Accs: 0.01916 | Valid Accs: 0.05542 | Time: 0.73 seconds
# Epoch: 56 | Train Loss: 4.62779 | Valid Loss: 4.49411 |Train Accs: 0.01994 | Valid Accs: 0.05574 | Time: 0.73 seconds
# Epoch: 57 | Train Loss: 4.61941 | Valid Loss: 4.49086 |Train Accs: 0.02120 | Valid Accs: 0.05911 | Time: 0.91 seconds
# Epoch: 58 | Train Loss: 4.62672 | Valid Loss: 4.48815 |Train Accs: 0.02031 | Valid Accs: 0.05933 | Time: 0.73 seconds
# Epoch: 59 | Train Loss: 4.62197 | Valid Loss: 4.48593 |Train Accs: 0.02112 | Valid Accs: 0.06052 | Time: 0.74 seconds
# Epoch: 60 | Train Loss: 4.61151 | Valid Loss: 4.48296 |Train Accs: 0.02126 | Valid Accs: 0.06149 | Time: 1.35 seconds
# Epoch: 61 | Train Loss: 4.61258 | Valid Loss: 4.48072 |Train Accs: 0.02304 | Valid Accs: 0.06074 | Time: 0.74 seconds
# Epoch: 62 | Train Loss: 4.61227 | Valid Loss: 4.47842 |Train Accs: 0.02209 | Valid Accs: 0.06214 | Time: 0.72 seconds
# Epoch: 63 | Train Loss: 4.60256 | Valid Loss: 4.47544 |Train Accs: 0.02284 | Valid Accs: 0.06442 | Time: 0.74 seconds
# Epoch: 64 | Train Loss: 4.60264 | Valid Loss: 4.47313 |Train Accs: 0.02114 | Valid Accs: 0.06366 | Time: 0.73 seconds
# Epoch: 65 | Train Loss: 4.60383 | Valid Loss: 4.47081 |Train Accs: 0.02145 | Valid Accs: 0.06540 | Time: 0.73 seconds
# Epoch: 66 | Train Loss: 4.59564 | Valid Loss: 4.46740 |Train Accs: 0.02409 | Valid Accs: 0.06746 | Time: 1.35 seconds
# Epoch: 67 | Train Loss: 4.59841 | Valid Loss: 4.46527 |Train Accs: 0.02281 | Valid Accs: 0.06779 | Time: 0.87 seconds
# Epoch: 68 | Train Loss: 4.59589 | Valid Loss: 4.46219 |Train Accs: 0.02307 | Valid Accs: 0.06920 | Time: 0.75 seconds
# Epoch: 69 | Train Loss: 4.59036 | Valid Loss: 4.46029 |Train Accs: 0.02393 | Valid Accs: 0.06865 | Time: 0.72 seconds
# Epoch: 70 | Train Loss: 4.58761 | Valid Loss: 4.45780 |Train Accs: 0.02507 | Valid Accs: 0.07191 | Time: 0.88 seconds
# Epoch: 71 | Train Loss: 4.58424 | Valid Loss: 4.45484 |Train Accs: 0.02427 | Valid Accs: 0.07234 | Time: 0.73 seconds
# Epoch: 72 | Train Loss: 4.58271 | Valid Loss: 4.45213 |Train Accs: 0.02544 | Valid Accs: 0.07321 | Time: 1.36 seconds
# Epoch: 73 | Train Loss: 4.58086 | Valid Loss: 4.44958 |Train Accs: 0.02627 | Valid Accs: 0.07353 | Time: 0.73 seconds
# Epoch: 74 | Train Loss: 4.57585 | Valid Loss: 4.44714 |Train Accs: 0.02321 | Valid Accs: 0.07397 | Time: 0.72 seconds
# Epoch: 75 | Train Loss: 4.58608 | Valid Loss: 4.44521 |Train Accs: 0.02577 | Valid Accs: 0.07549 | Time: 0.82 seconds
# Epoch: 76 | Train Loss: 4.57775 | Valid Loss: 4.44212 |Train Accs: 0.02446 | Valid Accs: 0.07624 | Time: 0.72 seconds
# Epoch: 77 | Train Loss: 4.56765 | Valid Loss: 4.43965 |Train Accs: 0.02558 | Valid Accs: 0.07614 | Time: 0.73 seconds
# Epoch: 78 | Train Loss: 4.56946 | Valid Loss: 4.43736 |Train Accs: 0.02731 | Valid Accs: 0.07646 | Time: 1.36 seconds
# Epoch: 79 | Train Loss: 4.57039 | Valid Loss: 4.43312 |Train Accs: 0.02566 | Valid Accs: 0.07972 | Time: 0.75 seconds
# Epoch: 80 | Train Loss: 4.56091 | Valid Loss: 4.43162 |Train Accs: 0.02555 | Valid Accs: 0.07896 | Time: 0.75 seconds
# Epoch: 81 | Train Loss: 4.55874 | Valid Loss: 4.42970 |Train Accs: 0.02742 | Valid Accs: 0.07939 | Time: 0.86 seconds
# Epoch: 82 | Train Loss: 4.55624 | Valid Loss: 4.42649 |Train Accs: 0.02769 | Valid Accs: 0.07961 | Time: 0.73 seconds
# Epoch: 83 | Train Loss: 4.55571 | Valid Loss: 4.42370 |Train Accs: 0.02920 | Valid Accs: 0.08102 | Time: 0.91 seconds
# Epoch: 84 | Train Loss: 4.54915 | Valid Loss: 4.42149 |Train Accs: 0.03110 | Valid Accs: 0.08178 | Time: 0.80 seconds
# Epoch: 85 | Train Loss: 4.54388 | Valid Loss: 4.41834 |Train Accs: 0.03143 | Valid Accs: 0.08405 | Time: 0.76 seconds
# Epoch: 86 | Train Loss: 4.55085 | Valid Loss: 4.41575 |Train Accs: 0.02914 | Valid Accs: 0.08601 | Time: 0.76 seconds
# Epoch: 87 | Train Loss: 4.54120 | Valid Loss: 4.41270 |Train Accs: 0.02935 | Valid Accs: 0.08698 | Time: 0.77 seconds
# Epoch: 88 | Train Loss: 4.55229 | Valid Loss: 4.40965 |Train Accs: 0.02878 | Valid Accs: 0.08720 | Time: 0.77 seconds
# Epoch: 89 | Train Loss: 4.54050 | Valid Loss: 4.40621 |Train Accs: 0.02720 | Valid Accs: 0.08731 | Time: 0.78 seconds
# Epoch: 90 | Train Loss: 4.54342 | Valid Loss: 4.40415 |Train Accs: 0.02862 | Valid Accs: 0.08818 | Time: 0.83 seconds
# Epoch: 91 | Train Loss: 4.52991 | Valid Loss: 4.40206 |Train Accs: 0.03227 | Valid Accs: 0.08872 | Time: 1.63 seconds
# Epoch: 92 | Train Loss: 4.53708 | Valid Loss: 4.39940 |Train Accs: 0.03065 | Valid Accs: 0.08980 | Time: 0.74 seconds
# Epoch: 93 | Train Loss: 4.52709 | Valid Loss: 4.39623 |Train Accs: 0.03137 | Valid Accs: 0.09013 | Time: 0.73 seconds
# Epoch: 94 | Train Loss: 4.53321 | Valid Loss: 4.39380 |Train Accs: 0.03149 | Valid Accs: 0.09099 | Time: 0.73 seconds
# Epoch: 95 | Train Loss: 4.52860 | Valid Loss: 4.39113 |Train Accs: 0.03202 | Valid Accs: 0.09197 | Time: 0.73 seconds
# Epoch: 96 | Train Loss: 4.51517 | Valid Loss: 4.38858 |Train Accs: 0.03045 | Valid Accs: 0.09338 | Time: 1.05 seconds
# Epoch: 97 | Train Loss: 4.51455 | Valid Loss: 4.38555 |Train Accs: 0.03252 | Valid Accs: 0.09262 | Time: 0.88 seconds
# Epoch: 98 | Train Loss: 4.50743 | Valid Loss: 4.38207 |Train Accs: 0.03194 | Valid Accs: 0.09425 | Time: 0.73 seconds
# Epoch: 99 | Train Loss: 4.50690 | Valid Loss: 4.38030 |Train Accs: 0.03517 | Valid Accs: 0.09404 | Time: 0.73 seconds
# Epoch: 100 | Train Loss: 4.50305 | Valid Loss: 4.37627 |Train Accs: 0.03807 | Valid Accs: 0.09393 | Time: 0.73 seconds
# Epoch: 101 | Train Loss: 4.50067 | Valid Loss: 4.37490 |Train Accs: 0.03545 | Valid Accs: 0.09512 | Time: 0.73 seconds
# Epoch: 102 | Train Loss: 4.50622 | Valid Loss: 4.37102 |Train Accs: 0.03523 | Valid Accs: 0.09631 | Time: 0.73 seconds
# Epoch: 103 | Train Loss: 4.49835 | Valid Loss: 4.36894 |Train Accs: 0.03559 | Valid Accs: 0.09674 | Time: 0.73 seconds
# Epoch: 104 | Train Loss: 4.49508 | Valid Loss: 4.36649 |Train Accs: 0.03528 | Valid Accs: 0.09718 | Time: 1.64 seconds
# Epoch: 105 | Train Loss: 4.49560 | Valid Loss: 4.36403 |Train Accs: 0.03738 | Valid Accs: 0.09783 | Time: 0.87 seconds
# Epoch: 106 | Train Loss: 4.49172 | Valid Loss: 4.36142 |Train Accs: 0.03514 | Valid Accs: 0.09751 | Time: 0.73 seconds
# Epoch: 107 | Train Loss: 4.49523 | Valid Loss: 4.35885 |Train Accs: 0.03275 | Valid Accs: 0.09978 | Time: 0.74 seconds
# Epoch: 108 | Train Loss: 4.48632 | Valid Loss: 4.35591 |Train Accs: 0.03667 | Valid Accs: 0.10152 | Time: 0.72 seconds
# Epoch: 109 | Train Loss: 4.48724 | Valid Loss: 4.35219 |Train Accs: 0.03553 | Valid Accs: 0.10086 | Time: 0.90 seconds
# Epoch: 110 | Train Loss: 4.47741 | Valid Loss: 4.34939 |Train Accs: 0.03971 | Valid Accs: 0.10227 | Time: 1.37 seconds
# Epoch: 111 | Train Loss: 4.47660 | Valid Loss: 4.34704 |Train Accs: 0.03780 | Valid Accs: 0.10228 | Time: 0.84 seconds
# Epoch: 112 | Train Loss: 4.47638 | Valid Loss: 4.34380 |Train Accs: 0.03751 | Valid Accs: 0.10466 | Time: 0.72 seconds
# Epoch: 113 | Train Loss: 4.47441 | Valid Loss: 4.34185 |Train Accs: 0.03779 | Valid Accs: 0.10292 | Time: 0.73 seconds
# Epoch: 114 | Train Loss: 4.46844 | Valid Loss: 4.33866 |Train Accs: 0.03929 | Valid Accs: 0.10477 | Time: 0.72 seconds
# Epoch: 115 | Train Loss: 4.46270 | Valid Loss: 4.33657 |Train Accs: 0.03972 | Valid Accs: 0.10596 | Time: 0.73 seconds
# Epoch: 116 | Train Loss: 4.46582 | Valid Loss: 4.33306 |Train Accs: 0.03967 | Valid Accs: 0.10553 | Time: 1.35 seconds
# Epoch: 117 | Train Loss: 4.45652 | Valid Loss: 4.32898 |Train Accs: 0.04080 | Valid Accs: 0.10846 | Time: 0.72 seconds
# Epoch: 118 | Train Loss: 4.45362 | Valid Loss: 4.32788 |Train Accs: 0.04086 | Valid Accs: 0.11008 | Time: 0.72 seconds
# Epoch: 119 | Train Loss: 4.45483 | Valid Loss: 4.32536 |Train Accs: 0.03944 | Valid Accs: 0.10932 | Time: 0.79 seconds
# Epoch: 120 | Train Loss: 4.45566 | Valid Loss: 4.32217 |Train Accs: 0.03944 | Valid Accs: 0.10986 | Time: 0.85 seconds
# Epoch: 121 | Train Loss: 4.44816 | Valid Loss: 4.31960 |Train Accs: 0.04047 | Valid Accs: 0.11008 | Time: 0.76 seconds
# Epoch: 122 | Train Loss: 4.44638 | Valid Loss: 4.31685 |Train Accs: 0.04409 | Valid Accs: 0.10965 | Time: 1.31 seconds
# Epoch: 123 | Train Loss: 4.43889 | Valid Loss: 4.31317 |Train Accs: 0.04278 | Valid Accs: 0.11138 | Time: 0.75 seconds
# Epoch: 124 | Train Loss: 4.44726 | Valid Loss: 4.31130 |Train Accs: 0.04179 | Valid Accs: 0.11431 | Time: 0.78 seconds
# Epoch: 125 | Train Loss: 4.43440 | Valid Loss: 4.30679 |Train Accs: 0.04309 | Valid Accs: 0.11301 | Time: 0.74 seconds
# Epoch: 126 | Train Loss: 4.43457 | Valid Loss: 4.30617 |Train Accs: 0.04449 | Valid Accs: 0.11399 | Time: 0.83 seconds
# Epoch: 127 | Train Loss: 4.43703 | Valid Loss: 4.30370 |Train Accs: 0.04298 | Valid Accs: 0.11485 | Time: 0.73 seconds
# Epoch: 128 | Train Loss: 4.42892 | Valid Loss: 4.29976 |Train Accs: 0.04206 | Valid Accs: 0.11431 | Time: 1.36 seconds
# Epoch: 129 | Train Loss: 4.42961 | Valid Loss: 4.29601 |Train Accs: 0.04457 | Valid Accs: 0.11691 | Time: 0.74 seconds
# Epoch: 130 | Train Loss: 4.42362 | Valid Loss: 4.29375 |Train Accs: 0.04527 | Valid Accs: 0.11908 | Time: 0.75 seconds
# Epoch: 131 | Train Loss: 4.41916 | Valid Loss: 4.29159 |Train Accs: 0.04406 | Valid Accs: 0.11843 | Time: 0.79 seconds
# Epoch: 132 | Train Loss: 4.42015 | Valid Loss: 4.28778 |Train Accs: 0.04440 | Valid Accs: 0.11767 | Time: 0.78 seconds
# Epoch: 133 | Train Loss: 4.42136 | Valid Loss: 4.28620 |Train Accs: 0.04577 | Valid Accs: 0.11995 | Time: 0.73 seconds
# Epoch: 134 | Train Loss: 4.41529 | Valid Loss: 4.28450 |Train Accs: 0.04459 | Valid Accs: 0.12038 | Time: 1.03 seconds
# Epoch: 135 | Train Loss: 4.41252 | Valid Loss: 4.28038 |Train Accs: 0.04627 | Valid Accs: 0.12114 | Time: 0.83 seconds
# Epoch: 136 | Train Loss: 4.40876 | Valid Loss: 4.27768 |Train Accs: 0.04772 | Valid Accs: 0.12353 | Time: 0.75 seconds
# Epoch: 137 | Train Loss: 4.40429 | Valid Loss: 4.27656 |Train Accs: 0.04884 | Valid Accs: 0.12157 | Time: 0.73 seconds
# Epoch: 138 | Train Loss: 4.40451 | Valid Loss: 4.27222 |Train Accs: 0.04851 | Valid Accs: 0.12483 | Time: 0.77 seconds
# Epoch: 139 | Train Loss: 4.40025 | Valid Loss: 4.26928 |Train Accs: 0.04889 | Valid Accs: 0.12635 | Time: 0.75 seconds
# Epoch: 140 | Train Loss: 4.39862 | Valid Loss: 4.26417 |Train Accs: 0.04804 | Valid Accs: 0.12537 | Time: 0.73 seconds
# Epoch: 141 | Train Loss: 4.39178 | Valid Loss: 4.26399 |Train Accs: 0.04825 | Valid Accs: 0.12624 | Time: 1.50 seconds
# Epoch: 142 | Train Loss: 4.39293 | Valid Loss: 4.26145 |Train Accs: 0.04814 | Valid Accs: 0.12863 | Time: 0.75 seconds
# Epoch: 143 | Train Loss: 4.38712 | Valid Loss: 4.25881 |Train Accs: 0.05001 | Valid Accs: 0.13058 | Time: 0.74 seconds
# Epoch: 144 | Train Loss: 4.37746 | Valid Loss: 4.25631 |Train Accs: 0.05221 | Valid Accs: 0.13036 | Time: 0.73 seconds
# Epoch: 145 | Train Loss: 4.38074 | Valid Loss: 4.25377 |Train Accs: 0.05188 | Valid Accs: 0.13329 | Time: 0.74 seconds
# Epoch: 146 | Train Loss: 4.37785 | Valid Loss: 4.24968 |Train Accs: 0.05196 | Valid Accs: 0.13416 | Time: 0.76 seconds
# Epoch: 147 | Train Loss: 4.37818 | Valid Loss: 4.24774 |Train Accs: 0.05458 | Valid Accs: 0.13394 | Time: 1.45 seconds
# Epoch: 148 | Train Loss: 4.37334 | Valid Loss: 4.24398 |Train Accs: 0.05143 | Valid Accs: 0.13600 | Time: 1.28 seconds
# Epoch: 149 | Train Loss: 4.36119 | Valid Loss: 4.24314 |Train Accs: 0.05227 | Valid Accs: 0.13578 | Time: 0.87 seconds
# Epoch: 150 | Train Loss: 4.36958 | Valid Loss: 4.23945 |Train Accs: 0.05269 | Valid Accs: 0.13795 | Time: 0.71 seconds
# Epoch: 151 | Train Loss: 4.36936 | Valid Loss: 4.23607 |Train Accs: 0.05107 | Valid Accs: 0.13665 | Time: 0.75 seconds
# Epoch: 152 | Train Loss: 4.36745 | Valid Loss: 4.23347 |Train Accs: 0.05250 | Valid Accs: 0.13969 | Time: 1.08 seconds
# Epoch: 153 | Train Loss: 4.35957 | Valid Loss: 4.23126 |Train Accs: 0.05299 | Valid Accs: 0.13752 | Time: 0.75 seconds
# Epoch: 154 | Train Loss: 4.35804 | Valid Loss: 4.22786 |Train Accs: 0.05405 | Valid Accs: 0.14207 | Time: 0.74 seconds
# Epoch: 155 | Train Loss: 4.34589 | Valid Loss: 4.22406 |Train Accs: 0.05425 | Valid Accs: 0.14110 | Time: 0.74 seconds
# Epoch: 156 | Train Loss: 4.35707 | Valid Loss: 4.22251 |Train Accs: 0.05394 | Valid Accs: 0.14055 | Time: 0.84 seconds
# Epoch: 157 | Train Loss: 4.34336 | Valid Loss: 4.22063 |Train Accs: 0.05453 | Valid Accs: 0.14175 | Time: 0.79 seconds
# Epoch: 158 | Train Loss: 4.34876 | Valid Loss: 4.21777 |Train Accs: 0.05506 | Valid Accs: 0.14262 | Time: 1.43 seconds
# Epoch: 159 | Train Loss: 4.34205 | Valid Loss: 4.21406 |Train Accs: 0.05593 | Valid Accs: 0.14402 | Time: 0.93 seconds
# Epoch: 160 | Train Loss: 4.34405 | Valid Loss: 4.21311 |Train Accs: 0.05419 | Valid Accs: 0.14402 | Time: 0.75 seconds
# Epoch: 161 | Train Loss: 4.34181 | Valid Loss: 4.20866 |Train Accs: 0.05620 | Valid Accs: 0.14554 | Time: 0.74 seconds
# Epoch: 162 | Train Loss: 4.33492 | Valid Loss: 4.20737 |Train Accs: 0.05743 | Valid Accs: 0.14696 | Time: 0.74 seconds
# Epoch: 163 | Train Loss: 4.34211 | Valid Loss: 4.20627 |Train Accs: 0.05546 | Valid Accs: 0.14457 | Time: 0.75 seconds
# Epoch: 164 | Train Loss: 4.32585 | Valid Loss: 4.20131 |Train Accs: 0.05483 | Valid Accs: 0.14598 | Time: 1.36 seconds
# Epoch: 165 | Train Loss: 4.32588 | Valid Loss: 4.20053 |Train Accs: 0.05859 | Valid Accs: 0.14793 | Time: 0.77 seconds
# Epoch: 166 | Train Loss: 4.32382 | Valid Loss: 4.19523 |Train Accs: 0.05894 | Valid Accs: 0.14880 | Time: 0.73 seconds
# Epoch: 167 | Train Loss: 4.32018 | Valid Loss: 4.19297 |Train Accs: 0.06156 | Valid Accs: 0.14782 | Time: 0.76 seconds
# Epoch: 168 | Train Loss: 4.31115 | Valid Loss: 4.19176 |Train Accs: 0.06156 | Valid Accs: 0.14836 | Time: 0.78 seconds
# Epoch: 169 | Train Loss: 4.31992 | Valid Loss: 4.18846 |Train Accs: 0.05949 | Valid Accs: 0.14923 | Time: 0.74 seconds
# Epoch: 170 | Train Loss: 4.31804 | Valid Loss: 4.18511 |Train Accs: 0.05843 | Valid Accs: 0.15021 | Time: 0.88 seconds
# Epoch: 171 | Train Loss: 4.30974 | Valid Loss: 4.18361 |Train Accs: 0.06271 | Valid Accs: 0.15227 | Time: 0.74 seconds
# Epoch: 172 | Train Loss: 4.31044 | Valid Loss: 4.17988 |Train Accs: 0.06220 | Valid Accs: 0.15086 | Time: 0.84 seconds
# Epoch: 173 | Train Loss: 4.30262 | Valid Loss: 4.17579 |Train Accs: 0.06217 | Valid Accs: 0.15368 | Time: 0.82 seconds
# Epoch: 174 | Train Loss: 4.29784 | Valid Loss: 4.17479 |Train Accs: 0.06314 | Valid Accs: 0.15390 | Time: 0.77 seconds
# Epoch: 175 | Train Loss: 4.30165 | Valid Loss: 4.17067 |Train Accs: 0.06106 | Valid Accs: 0.15422 | Time: 0.73 seconds
# Epoch: 176 | Train Loss: 4.29071 | Valid Loss: 4.16925 |Train Accs: 0.06390 | Valid Accs: 0.15520 | Time: 0.81 seconds
# Epoch: 177 | Train Loss: 4.29732 | Valid Loss: 4.16563 |Train Accs: 0.06052 | Valid Accs: 0.15509 | Time: 1.31 seconds
# Epoch: 178 | Train Loss: 4.28520 | Valid Loss: 4.16377 |Train Accs: 0.06616 | Valid Accs: 0.15574 | Time: 0.74 seconds
# Epoch: 179 | Train Loss: 4.28509 | Valid Loss: 4.16209 |Train Accs: 0.06443 | Valid Accs: 0.15715 | Time: 0.84 seconds
# Epoch: 180 | Train Loss: 4.28626 | Valid Loss: 4.15724 |Train Accs: 0.06373 | Valid Accs: 0.15867 | Time: 0.74 seconds
# Epoch: 181 | Train Loss: 4.28167 | Valid Loss: 4.15523 |Train Accs: 0.06150 | Valid Accs: 0.15780 | Time: 0.74 seconds
# Epoch: 182 | Train Loss: 4.28257 | Valid Loss: 4.15206 |Train Accs: 0.06613 | Valid Accs: 0.15748 | Time: 0.75 seconds
# Epoch: 183 | Train Loss: 4.27893 | Valid Loss: 4.14848 |Train Accs: 0.06479 | Valid Accs: 0.15997 | Time: 1.36 seconds
# Epoch: 184 | Train Loss: 4.27679 | Valid Loss: 4.14928 |Train Accs: 0.06866 | Valid Accs: 0.15943 | Time: 0.64 seconds
# Epoch: 185 | Train Loss: 4.26151 | Valid Loss: 4.14581 |Train Accs: 0.06869 | Valid Accs: 0.15964 | Time: 1.09 seconds
# Epoch: 186 | Train Loss: 4.26706 | Valid Loss: 4.14258 |Train Accs: 0.06705 | Valid Accs: 0.16127 | Time: 1.19 seconds
# Epoch: 187 | Train Loss: 4.27379 | Valid Loss: 4.13910 |Train Accs: 0.06752 | Valid Accs: 0.16171 | Time: 0.84 seconds
# Epoch: 188 | Train Loss: 4.26671 | Valid Loss: 4.13791 |Train Accs: 0.06955 | Valid Accs: 0.16528 | Time: 0.82 seconds
# Epoch: 189 | Train Loss: 4.25773 | Valid Loss: 4.13335 |Train Accs: 0.06979 | Valid Accs: 0.16496 | Time: 0.74 seconds
# Epoch: 190 | Train Loss: 4.25969 | Valid Loss: 4.13091 |Train Accs: 0.06680 | Valid Accs: 0.16561 | Time: 0.78 seconds
# Epoch: 191 | Train Loss: 4.25570 | Valid Loss: 4.12946 |Train Accs: 0.06689 | Valid Accs: 0.16778 | Time: 0.75 seconds
# Epoch: 192 | Train Loss: 4.24933 | Valid Loss: 4.12660 |Train Accs: 0.07203 | Valid Accs: 0.16723 | Time: 0.75 seconds
# Epoch: 193 | Train Loss: 4.24943 | Valid Loss: 4.12380 |Train Accs: 0.06710 | Valid Accs: 0.16843 | Time: 0.73 seconds
# Epoch: 194 | Train Loss: 4.24392 | Valid Loss: 4.11915 |Train Accs: 0.07262 | Valid Accs: 0.16897 | Time: 0.84 seconds
# Epoch: 195 | Train Loss: 4.24826 | Valid Loss: 4.11858 |Train Accs: 0.07162 | Valid Accs: 0.16919 | Time: 1.64 seconds
# Epoch: 196 | Train Loss: 4.24769 | Valid Loss: 4.11629 |Train Accs: 0.06947 | Valid Accs: 0.17081 | Time: 0.75 seconds
# Epoch: 197 | Train Loss: 4.24002 | Valid Loss: 4.11122 |Train Accs: 0.06873 | Valid Accs: 0.17190 | Time: 0.81 seconds
# Epoch: 198 | Train Loss: 4.23391 | Valid Loss: 4.10785 |Train Accs: 0.07327 | Valid Accs: 0.17212 | Time: 0.85 seconds
# Epoch: 199 | Train Loss: 4.23336 | Valid Loss: 4.10698 |Train Accs: 0.07172 | Valid Accs: 0.17504 | Time: 0.73 seconds
# Epoch: 200 | Train Loss: 4.23396 | Valid Loss: 4.10492 |Train Accs: 0.07110 | Valid Accs: 0.17364 | Time: 0.86 seconds
# Epoch: 201 | Train Loss: 4.22542 | Valid Loss: 4.10168 |Train Accs: 0.07335 | Valid Accs: 0.17570 | Time: 1.35 seconds
# Epoch: 202 | Train Loss: 4.22362 | Valid Loss: 4.09598 |Train Accs: 0.07807 | Valid Accs: 0.17559 | Time: 0.74 seconds
# Epoch: 203 | Train Loss: 4.21318 | Valid Loss: 4.09731 |Train Accs: 0.07510 | Valid Accs: 0.18014 | Time: 0.62 seconds
# Epoch: 204 | Train Loss: 4.21733 | Valid Loss: 4.09339 |Train Accs: 0.07330 | Valid Accs: 0.17602 | Time: 0.74 seconds
# Epoch: 205 | Train Loss: 4.22108 | Valid Loss: 4.08990 |Train Accs: 0.07350 | Valid Accs: 0.17895 | Time: 0.79 seconds
# Epoch: 206 | Train Loss: 4.21806 | Valid Loss: 4.08889 |Train Accs: 0.07456 | Valid Accs: 0.17917 | Time: 0.83 seconds
# Epoch: 207 | Train Loss: 4.20623 | Valid Loss: 4.08716 |Train Accs: 0.07825 | Valid Accs: 0.17992 | Time: 0.76 seconds
# Epoch: 208 | Train Loss: 4.20701 | Valid Loss: 4.08197 |Train Accs: 0.07826 | Valid Accs: 0.18145 | Time: 0.73 seconds
# Epoch: 209 | Train Loss: 4.20729 | Valid Loss: 4.08179 |Train Accs: 0.07767 | Valid Accs: 0.18275 | Time: 0.85 seconds
# Epoch: 210 | Train Loss: 4.20288 | Valid Loss: 4.07787 |Train Accs: 0.07485 | Valid Accs: 0.18232 | Time: 0.74 seconds
# Epoch: 211 | Train Loss: 4.19402 | Valid Loss: 4.07525 |Train Accs: 0.07823 | Valid Accs: 0.18296 | Time: 1.03 seconds
# Epoch: 212 | Train Loss: 4.19791 | Valid Loss: 4.07165 |Train Accs: 0.07800 | Valid Accs: 0.18351 | Time: 0.78 seconds
# Epoch: 213 | Train Loss: 4.19371 | Valid Loss: 4.06875 |Train Accs: 0.07879 | Valid Accs: 0.18589 | Time: 1.40 seconds
# Epoch: 214 | Train Loss: 4.20309 | Valid Loss: 4.06321 |Train Accs: 0.07799 | Valid Accs: 0.18654 | Time: 0.75 seconds
# Epoch: 215 | Train Loss: 4.19060 | Valid Loss: 4.06446 |Train Accs: 0.07497 | Valid Accs: 0.18600 | Time: 0.72 seconds
# Epoch: 216 | Train Loss: 4.18332 | Valid Loss: 4.06222 |Train Accs: 0.08505 | Valid Accs: 0.18860 | Time: 0.75 seconds
# Epoch: 217 | Train Loss: 4.18094 | Valid Loss: 4.06002 |Train Accs: 0.08002 | Valid Accs: 0.18697 | Time: 0.75 seconds
# Epoch: 218 | Train Loss: 4.18538 | Valid Loss: 4.05606 |Train Accs: 0.07768 | Valid Accs: 0.18719 | Time: 0.74 seconds
# Epoch: 219 | Train Loss: 4.17675 | Valid Loss: 4.05441 |Train Accs: 0.08111 | Valid Accs: 0.18849 | Time: 1.06 seconds
# Epoch: 220 | Train Loss: 4.17647 | Valid Loss: 4.05201 |Train Accs: 0.08281 | Valid Accs: 0.19066 | Time: 0.74 seconds
# Epoch: 221 | Train Loss: 4.17703 | Valid Loss: 4.04741 |Train Accs: 0.08202 | Valid Accs: 0.19034 | Time: 0.72 seconds
# Epoch: 222 | Train Loss: 4.16986 | Valid Loss: 4.04606 |Train Accs: 0.08443 | Valid Accs: 0.19196 | Time: 0.74 seconds
# Epoch: 223 | Train Loss: 4.16383 | Valid Loss: 4.04406 |Train Accs: 0.08398 | Valid Accs: 0.19261 | Time: 0.74 seconds
# Epoch: 224 | Train Loss: 4.17178 | Valid Loss: 4.03909 |Train Accs: 0.08484 | Valid Accs: 0.19337 | Time: 1.57 seconds
# Epoch: 225 | Train Loss: 4.16354 | Valid Loss: 4.03754 |Train Accs: 0.08367 | Valid Accs: 0.19250 | Time: 1.12 seconds
# Epoch: 226 | Train Loss: 4.16107 | Valid Loss: 4.03732 |Train Accs: 0.08562 | Valid Accs: 0.19359 | Time: 0.74 seconds
# Epoch: 227 | Train Loss: 4.15807 | Valid Loss: 4.03291 |Train Accs: 0.08509 | Valid Accs: 0.19521 | Time: 0.76 seconds
# Epoch: 228 | Train Loss: 4.15207 | Valid Loss: 4.02885 |Train Accs: 0.08634 | Valid Accs: 0.19424 | Time: 0.73 seconds
# Epoch: 229 | Train Loss: 4.15577 | Valid Loss: 4.02604 |Train Accs: 0.08640 | Valid Accs: 0.19619 | Time: 0.74 seconds
# Epoch: 230 | Train Loss: 4.14799 | Valid Loss: 4.02510 |Train Accs: 0.08839 | Valid Accs: 0.19413 | Time: 0.86 seconds
# Epoch: 231 | Train Loss: 4.14767 | Valid Loss: 4.02148 |Train Accs: 0.08462 | Valid Accs: 0.19803 | Time: 1.34 seconds
# Epoch: 232 | Train Loss: 4.15229 | Valid Loss: 4.01854 |Train Accs: 0.08462 | Valid Accs: 0.19598 | Time: 0.76 seconds
# Epoch: 233 | Train Loss: 4.13795 | Valid Loss: 4.01553 |Train Accs: 0.09007 | Valid Accs: 0.19749 | Time: 0.73 seconds
# Epoch: 234 | Train Loss: 4.14110 | Valid Loss: 4.01151 |Train Accs: 0.08681 | Valid Accs: 0.19609 | Time: 0.74 seconds
# Epoch: 235 | Train Loss: 4.13526 | Valid Loss: 4.01073 |Train Accs: 0.08790 | Valid Accs: 0.19890 | Time: 0.75 seconds
# Epoch: 236 | Train Loss: 4.13607 | Valid Loss: 4.00571 |Train Accs: 0.08947 | Valid Accs: 0.19641 | Time: 0.92 seconds
# Epoch: 237 | Train Loss: 4.13389 | Valid Loss: 4.00354 |Train Accs: 0.09026 | Valid Accs: 0.19944 | Time: 1.27 seconds
# Epoch: 238 | Train Loss: 4.12657 | Valid Loss: 4.00263 |Train Accs: 0.09302 | Valid Accs: 0.19988 | Time: 0.74 seconds
# Epoch: 239 | Train Loss: 4.11911 | Valid Loss: 4.00130 |Train Accs: 0.09282 | Valid Accs: 0.19912 | Time: 0.86 seconds
# Epoch: 240 | Train Loss: 4.11804 | Valid Loss: 3.99575 |Train Accs: 0.09221 | Valid Accs: 0.19858 | Time: 0.73 seconds
# Epoch: 241 | Train Loss: 4.11911 | Valid Loss: 3.99411 |Train Accs: 0.08896 | Valid Accs: 0.20107 | Time: 0.74 seconds
# Epoch: 242 | Train Loss: 4.11442 | Valid Loss: 3.99075 |Train Accs: 0.09360 | Valid Accs: 0.20031 | Time: 0.79 seconds
# Epoch: 243 | Train Loss: 4.11517 | Valid Loss: 3.98993 |Train Accs: 0.09090 | Valid Accs: 0.19934 | Time: 0.78 seconds
# Epoch: 244 | Train Loss: 4.11353 | Valid Loss: 3.98551 |Train Accs: 0.09354 | Valid Accs: 0.20194 | Time: 0.74 seconds
# Epoch: 245 | Train Loss: 4.10330 | Valid Loss: 3.98272 |Train Accs: 0.09614 | Valid Accs: 0.20031 | Time: 0.88 seconds
# Epoch: 246 | Train Loss: 4.10684 | Valid Loss: 3.98017 |Train Accs: 0.09571 | Valid Accs: 0.20270 | Time: 0.76 seconds
# Epoch: 247 | Train Loss: 4.10669 | Valid Loss: 3.97607 |Train Accs: 0.09170 | Valid Accs: 0.20248 | Time: 0.83 seconds
# Epoch: 248 | Train Loss: 4.11261 | Valid Loss: 3.97367 |Train Accs: 0.09526 | Valid Accs: 0.20313 | Time: 0.72 seconds
# Epoch: 249 | Train Loss: 4.09905 | Valid Loss: 3.97370 |Train Accs: 0.09427 | Valid Accs: 0.20238 | Time: 0.61 seconds
# Epoch: 250 | Train Loss: 4.09851 | Valid Loss: 3.96756 |Train Accs: 0.09581 | Valid Accs: 0.20346 | Time: 1.00 seconds
# Epoch: 251 | Train Loss: 4.09098 | Valid Loss: 3.96867 |Train Accs: 0.09932 | Valid Accs: 0.20465 | Time: 0.66 seconds
# Epoch: 252 | Train Loss: 4.09532 | Valid Loss: 3.96555 |Train Accs: 0.09358 | Valid Accs: 0.20541 | Time: 0.83 seconds
# Epoch: 253 | Train Loss: 4.08729 | Valid Loss: 3.96083 |Train Accs: 0.09773 | Valid Accs: 0.20585 | Time: 0.83 seconds
# Epoch: 254 | Train Loss: 4.08055 | Valid Loss: 3.95852 |Train Accs: 0.09868 | Valid Accs: 0.20585 | Time: 0.81 seconds
# Epoch: 255 | Train Loss: 4.07345 | Valid Loss: 3.95724 |Train Accs: 0.10138 | Valid Accs: 0.20726 | Time: 0.75 seconds
# Epoch: 256 | Train Loss: 4.07303 | Valid Loss: 3.95133 |Train Accs: 0.10443 | Valid Accs: 0.20542 | Time: 0.74 seconds
# Epoch: 257 | Train Loss: 4.07925 | Valid Loss: 3.95128 |Train Accs: 0.09650 | Valid Accs: 0.20888 | Time: 0.75 seconds
# Epoch: 258 | Train Loss: 4.07486 | Valid Loss: 3.94871 |Train Accs: 0.10211 | Valid Accs: 0.20736 | Time: 1.36 seconds
# Epoch: 259 | Train Loss: 4.07448 | Valid Loss: 3.94498 |Train Accs: 0.09943 | Valid Accs: 0.20943 | Time: 0.77 seconds
# Epoch: 260 | Train Loss: 4.07306 | Valid Loss: 3.94449 |Train Accs: 0.10154 | Valid Accs: 0.20964 | Time: 0.85 seconds
# Epoch: 261 | Train Loss: 4.05489 | Valid Loss: 3.94157 |Train Accs: 0.10579 | Valid Accs: 0.20953 | Time: 0.74 seconds
# Epoch: 262 | Train Loss: 4.06628 | Valid Loss: 3.93925 |Train Accs: 0.09840 | Valid Accs: 0.21040 | Time: 0.74 seconds
# Epoch: 263 | Train Loss: 4.06614 | Valid Loss: 3.93387 |Train Accs: 0.10322 | Valid Accs: 0.20986 | Time: 1.37 seconds
# Epoch: 264 | Train Loss: 4.05782 | Valid Loss: 3.93078 |Train Accs: 0.10080 | Valid Accs: 0.20932 | Time: 1.13 seconds
# Epoch: 265 | Train Loss: 4.04750 | Valid Loss: 3.93039 |Train Accs: 0.10499 | Valid Accs: 0.21041 | Time: 0.75 seconds
# Epoch: 266 | Train Loss: 4.05405 | Valid Loss: 3.92835 |Train Accs: 0.10608 | Valid Accs: 0.21279 | Time: 0.75 seconds
# Epoch: 267 | Train Loss: 4.04974 | Valid Loss: 3.92468 |Train Accs: 0.10470 | Valid Accs: 0.21268 | Time: 0.74 seconds
# Epoch: 268 | Train Loss: 4.04820 | Valid Loss: 3.92188 |Train Accs: 0.10768 | Valid Accs: 0.21420 | Time: 0.85 seconds
# Epoch: 269 | Train Loss: 4.04132 | Valid Loss: 3.91686 |Train Accs: 0.10490 | Valid Accs: 0.21420 | Time: 0.76 seconds
# Epoch: 270 | Train Loss: 4.04426 | Valid Loss: 3.91217 |Train Accs: 0.10534 | Valid Accs: 0.21506 | Time: 1.36 seconds
# Epoch: 271 | Train Loss: 4.03803 | Valid Loss: 3.91408 |Train Accs: 0.10413 | Valid Accs: 0.21441 | Time: 0.62 seconds
# Epoch: 272 | Train Loss: 4.03667 | Valid Loss: 3.90915 |Train Accs: 0.10773 | Valid Accs: 0.21571 | Time: 0.73 seconds
# Epoch: 273 | Train Loss: 4.02745 | Valid Loss: 3.90592 |Train Accs: 0.10800 | Valid Accs: 0.21398 | Time: 0.73 seconds
# Epoch: 274 | Train Loss: 4.02375 | Valid Loss: 3.90741 |Train Accs: 0.10738 | Valid Accs: 0.21452 | Time: 0.63 seconds
# Epoch: 275 | Train Loss: 4.02832 | Valid Loss: 3.90045 |Train Accs: 0.10821 | Valid Accs: 0.21658 | Time: 0.85 seconds
# Epoch: 276 | Train Loss: 4.02746 | Valid Loss: 3.89519 |Train Accs: 0.10794 | Valid Accs: 0.21636 | Time: 1.11 seconds
# Epoch: 277 | Train Loss: 4.01916 | Valid Loss: 3.89276 |Train Accs: 0.11411 | Valid Accs: 0.21702 | Time: 0.74 seconds
# Epoch: 278 | Train Loss: 4.01890 | Valid Loss: 3.89440 |Train Accs: 0.11061 | Valid Accs: 0.21864 | Time: 0.61 seconds
# Epoch: 279 | Train Loss: 4.01488 | Valid Loss: 3.89290 |Train Accs: 0.10987 | Valid Accs: 0.21821 | Time: 0.59 seconds
# Epoch: 280 | Train Loss: 4.00843 | Valid Loss: 3.88596 |Train Accs: 0.11293 | Valid Accs: 0.21799 | Time: 0.74 seconds
# Epoch: 281 | Train Loss: 4.01374 | Valid Loss: 3.88392 |Train Accs: 0.11248 | Valid Accs: 0.21962 | Time: 0.78 seconds
# Epoch: 282 | Train Loss: 4.00524 | Valid Loss: 3.88417 |Train Accs: 0.11557 | Valid Accs: 0.22135 | Time: 0.62 seconds
# Epoch: 283 | Train Loss: 3.99941 | Valid Loss: 3.88072 |Train Accs: 0.11812 | Valid Accs: 0.22114 | Time: 0.82 seconds
# Epoch: 284 | Train Loss: 3.99868 | Valid Loss: 3.87336 |Train Accs: 0.11107 | Valid Accs: 0.22233 | Time: 0.79 seconds
# Epoch: 285 | Train Loss: 3.99291 | Valid Loss: 3.87388 |Train Accs: 0.11502 | Valid Accs: 0.22178 | Time: 0.61 seconds
# Epoch: 286 | Train Loss: 3.99465 | Valid Loss: 3.86961 |Train Accs: 0.11226 | Valid Accs: 0.22417 | Time: 0.72 seconds
# Epoch: 287 | Train Loss: 3.98725 | Valid Loss: 3.86978 |Train Accs: 0.11438 | Valid Accs: 0.22157 | Time: 0.62 seconds
# Epoch: 288 | Train Loss: 3.99166 | Valid Loss: 3.86560 |Train Accs: 0.11521 | Valid Accs: 0.22363 | Time: 0.74 seconds
# Epoch: 289 | Train Loss: 3.98909 | Valid Loss: 3.85935 |Train Accs: 0.11659 | Valid Accs: 0.22601 | Time: 0.73 seconds
# Epoch: 290 | Train Loss: 3.97598 | Valid Loss: 3.85835 |Train Accs: 0.12104 | Valid Accs: 0.22526 | Time: 0.89 seconds
# Epoch: 291 | Train Loss: 3.97610 | Valid Loss: 3.85566 |Train Accs: 0.11809 | Valid Accs: 0.22536 | Time: 1.32 seconds
# Epoch: 292 | Train Loss: 3.98565 | Valid Loss: 3.85132 |Train Accs: 0.11678 | Valid Accs: 0.22699 | Time: 0.75 seconds
# Epoch: 293 | Train Loss: 3.97897 | Valid Loss: 3.85132 |Train Accs: 0.11711 | Valid Accs: 0.22580 | Time: 0.74 seconds
# Epoch: 294 | Train Loss: 3.97491 | Valid Loss: 3.84606 |Train Accs: 0.11611 | Valid Accs: 0.22905 | Time: 0.75 seconds
# Epoch: 295 | Train Loss: 3.97026 | Valid Loss: 3.84227 |Train Accs: 0.12061 | Valid Accs: 0.22894 | Time: 0.76 seconds
# Epoch: 296 | Train Loss: 3.96864 | Valid Loss: 3.84504 |Train Accs: 0.12210 | Valid Accs: 0.23090 | Time: 0.63 seconds
# Epoch: 297 | Train Loss: 3.96534 | Valid Loss: 3.83648 |Train Accs: 0.11818 | Valid Accs: 0.23133 | Time: 0.75 seconds
# Epoch: 298 | Train Loss: 3.96142 | Valid Loss: 3.83708 |Train Accs: 0.12038 | Valid Accs: 0.22851 | Time: 0.73 seconds
# Epoch: 299 | Train Loss: 3.95890 | Valid Loss: 3.83300 |Train Accs: 0.12107 | Valid Accs: 0.23079 | Time: 0.77 seconds
# Epoch: 300 | Train Loss: 3.95117 | Valid Loss: 3.83315 |Train Accs: 0.12730 | Valid Accs: 0.23155 | Time: 0.62 seconds
# Epoch: 301 | Train Loss: 3.94788 | Valid Loss: 3.82844 |Train Accs: 0.12489 | Valid Accs: 0.23176 | Time: 0.74 seconds
# Epoch: 302 | Train Loss: 3.95799 | Valid Loss: 3.82326 |Train Accs: 0.11997 | Valid Accs: 0.23111 | Time: 0.75 seconds
# Epoch: 303 | Train Loss: 3.94969 | Valid Loss: 3.82319 |Train Accs: 0.12230 | Valid Accs: 0.23328 | Time: 0.75 seconds
# Epoch: 304 | Train Loss: 3.94896 | Valid Loss: 3.81928 |Train Accs: 0.12149 | Valid Accs: 0.23317 | Time: 0.73 seconds
# Epoch: 305 | Train Loss: 3.94509 | Valid Loss: 3.81661 |Train Accs: 0.12183 | Valid Accs: 0.23415 | Time: 1.63 seconds
# Epoch: 306 | Train Loss: 3.94120 | Valid Loss: 3.81281 |Train Accs: 0.12552 | Valid Accs: 0.23307 | Time: 0.77 seconds
# Epoch: 307 | Train Loss: 3.93666 | Valid Loss: 3.81317 |Train Accs: 0.12885 | Valid Accs: 0.23632 | Time: 0.60 seconds
# Epoch: 308 | Train Loss: 3.93502 | Valid Loss: 3.80691 |Train Accs: 0.12452 | Valid Accs: 0.23382 | Time: 0.77 seconds
# Epoch: 309 | Train Loss: 3.92956 | Valid Loss: 3.80819 |Train Accs: 0.13130 | Valid Accs: 0.23502 | Time: 0.61 seconds
# Epoch: 310 | Train Loss: 3.92987 | Valid Loss: 3.80296 |Train Accs: 0.12732 | Valid Accs: 0.23621 | Time: 0.85 seconds
# Epoch: 311 | Train Loss: 3.92308 | Valid Loss: 3.79971 |Train Accs: 0.13392 | Valid Accs: 0.23524 | Time: 0.78 seconds
# Epoch: 312 | Train Loss: 3.92576 | Valid Loss: 3.79353 |Train Accs: 0.12818 | Valid Accs: 0.23795 | Time: 0.77 seconds
# Epoch: 313 | Train Loss: 3.92070 | Valid Loss: 3.79377 |Train Accs: 0.12868 | Valid Accs: 0.23730 | Time: 0.71 seconds
# Epoch: 314 | Train Loss: 3.91801 | Valid Loss: 3.78999 |Train Accs: 0.12773 | Valid Accs: 0.23676 | Time: 0.75 seconds
# Epoch: 315 | Train Loss: 3.90846 | Valid Loss: 3.78440 |Train Accs: 0.13064 | Valid Accs: 0.23589 | Time: 0.74 seconds
# Epoch: 316 | Train Loss: 3.91040 | Valid Loss: 3.78370 |Train Accs: 0.13184 | Valid Accs: 0.23968 | Time: 0.74 seconds
# Epoch: 317 | Train Loss: 3.90507 | Valid Loss: 3.78073 |Train Accs: 0.13114 | Valid Accs: 0.24077 | Time: 0.74 seconds
# Epoch: 318 | Train Loss: 3.89884 | Valid Loss: 3.77875 |Train Accs: 0.13159 | Valid Accs: 0.23904 | Time: 1.44 seconds
# Epoch: 319 | Train Loss: 3.90223 | Valid Loss: 3.77926 |Train Accs: 0.13415 | Valid Accs: 0.24011 | Time: 0.72 seconds
# Epoch: 320 | Train Loss: 3.90097 | Valid Loss: 3.77396 |Train Accs: 0.12992 | Valid Accs: 0.24033 | Time: 0.74 seconds
# Epoch: 321 | Train Loss: 3.90114 | Valid Loss: 3.77207 |Train Accs: 0.13179 | Valid Accs: 0.23904 | Time: 0.73 seconds
# Epoch: 322 | Train Loss: 3.89336 | Valid Loss: 3.76791 |Train Accs: 0.13566 | Valid Accs: 0.24283 | Time: 0.81 seconds
# Epoch: 323 | Train Loss: 3.89143 | Valid Loss: 3.76411 |Train Accs: 0.13292 | Valid Accs: 0.24293 | Time: 0.77 seconds
# Epoch: 324 | Train Loss: 3.89699 | Valid Loss: 3.76484 |Train Accs: 0.13376 | Valid Accs: 0.24380 | Time: 0.63 seconds
# Epoch: 325 | Train Loss: 3.88598 | Valid Loss: 3.76277 |Train Accs: 0.13502 | Valid Accs: 0.24478 | Time: 0.71 seconds
# Epoch: 326 | Train Loss: 3.88865 | Valid Loss: 3.75448 |Train Accs: 0.13429 | Valid Accs: 0.24673 | Time: 0.73 seconds
# Epoch: 327 | Train Loss: 3.87600 | Valid Loss: 3.75688 |Train Accs: 0.13993 | Valid Accs: 0.24618 | Time: 0.61 seconds
# Epoch: 328 | Train Loss: 3.87255 | Valid Loss: 3.75342 |Train Accs: 0.13675 | Valid Accs: 0.24532 | Time: 0.84 seconds
# Epoch: 329 | Train Loss: 3.87628 | Valid Loss: 3.74575 |Train Accs: 0.13825 | Valid Accs: 0.24792 | Time: 0.73 seconds
# Epoch: 330 | Train Loss: 3.86958 | Valid Loss: 3.74324 |Train Accs: 0.13971 | Valid Accs: 0.24824 | Time: 0.74 seconds
# Epoch: 331 | Train Loss: 3.87215 | Valid Loss: 3.74025 |Train Accs: 0.13650 | Valid Accs: 0.24792 | Time: 1.10 seconds
# Epoch: 332 | Train Loss: 3.86905 | Valid Loss: 3.74196 |Train Accs: 0.14060 | Valid Accs: 0.24673 | Time: 0.75 seconds
# Epoch: 333 | Train Loss: 3.86722 | Valid Loss: 3.73614 |Train Accs: 0.13959 | Valid Accs: 0.24705 | Time: 0.79 seconds
# Epoch: 334 | Train Loss: 3.86178 | Valid Loss: 3.73544 |Train Accs: 0.14045 | Valid Accs: 0.24933 | Time: 0.87 seconds
# Epoch: 335 | Train Loss: 3.85781 | Valid Loss: 3.73076 |Train Accs: 0.14104 | Valid Accs: 0.25258 | Time: 0.74 seconds
# Epoch: 336 | Train Loss: 3.85349 | Valid Loss: 3.73108 |Train Accs: 0.14403 | Valid Accs: 0.25280 | Time: 0.61 seconds
# Epoch: 337 | Train Loss: 3.85618 | Valid Loss: 3.72697 |Train Accs: 0.13725 | Valid Accs: 0.25334 | Time: 0.74 seconds
# Epoch: 338 | Train Loss: 3.84747 | Valid Loss: 3.72128 |Train Accs: 0.14085 | Valid Accs: 0.25312 | Time: 1.05 seconds
# Epoch: 339 | Train Loss: 3.84853 | Valid Loss: 3.72007 |Train Accs: 0.14277 | Valid Accs: 0.25486 | Time: 0.74 seconds
# Epoch: 340 | Train Loss: 3.84269 | Valid Loss: 3.71634 |Train Accs: 0.14306 | Valid Accs: 0.25149 | Time: 0.73 seconds
# Epoch: 341 | Train Loss: 3.84018 | Valid Loss: 3.71527 |Train Accs: 0.14476 | Valid Accs: 0.25366 | Time: 0.74 seconds
# Epoch: 342 | Train Loss: 3.83316 | Valid Loss: 3.71120 |Train Accs: 0.14410 | Valid Accs: 0.25497 | Time: 0.73 seconds
# Epoch: 343 | Train Loss: 3.83375 | Valid Loss: 3.70680 |Train Accs: 0.14613 | Valid Accs: 0.25453 | Time: 0.88 seconds
# Epoch: 344 | Train Loss: 3.83380 | Valid Loss: 3.70830 |Train Accs: 0.14905 | Valid Accs: 0.25572 | Time: 0.59 seconds
# Epoch: 345 | Train Loss: 3.82993 | Valid Loss: 3.70517 |Train Accs: 0.14389 | Valid Accs: 0.25648 | Time: 0.75 seconds
# Epoch: 346 | Train Loss: 3.83314 | Valid Loss: 3.70086 |Train Accs: 0.14371 | Valid Accs: 0.25626 | Time: 1.33 seconds
# Epoch: 347 | Train Loss: 3.82898 | Valid Loss: 3.69749 |Train Accs: 0.14566 | Valid Accs: 0.25746 | Time: 1.04 seconds
# Epoch: 348 | Train Loss: 3.82340 | Valid Loss: 3.69435 |Train Accs: 0.14747 | Valid Accs: 0.25887 | Time: 0.76 seconds
# Epoch: 349 | Train Loss: 3.82294 | Valid Loss: 3.69131 |Train Accs: 0.15054 | Valid Accs: 0.25757 | Time: 0.86 seconds
# Epoch: 350 | Train Loss: 3.82278 | Valid Loss: 3.68928 |Train Accs: 0.14631 | Valid Accs: 0.25887 | Time: 0.73 seconds
# Epoch: 351 | Train Loss: 3.81816 | Valid Loss: 3.68772 |Train Accs: 0.14904 | Valid Accs: 0.25995 | Time: 0.76 seconds
# Epoch: 352 | Train Loss: 3.81465 | Valid Loss: 3.68189 |Train Accs: 0.14840 | Valid Accs: 0.25854 | Time: 1.03 seconds
# Epoch: 353 | Train Loss: 3.80079 | Valid Loss: 3.68213 |Train Accs: 0.15469 | Valid Accs: 0.26277 | Time: 0.62 seconds
# Epoch: 354 | Train Loss: 3.80309 | Valid Loss: 3.67623 |Train Accs: 0.15027 | Valid Accs: 0.26277 | Time: 0.73 seconds
# Epoch: 355 | Train Loss: 3.80451 | Valid Loss: 3.67796 |Train Accs: 0.15031 | Valid Accs: 0.26190 | Time: 0.61 seconds
# Epoch: 356 | Train Loss: 3.79588 | Valid Loss: 3.67464 |Train Accs: 0.15466 | Valid Accs: 0.26288 | Time: 0.74 seconds
# Epoch: 357 | Train Loss: 3.79921 | Valid Loss: 3.66906 |Train Accs: 0.15039 | Valid Accs: 0.26375 | Time: 0.74 seconds
# Epoch: 358 | Train Loss: 3.79008 | Valid Loss: 3.66745 |Train Accs: 0.15479 | Valid Accs: 0.26657 | Time: 0.89 seconds
# Epoch: 359 | Train Loss: 3.79138 | Valid Loss: 3.66584 |Train Accs: 0.15412 | Valid Accs: 0.26581 | Time: 1.12 seconds
# Epoch: 360 | Train Loss: 3.78918 | Valid Loss: 3.65955 |Train Accs: 0.15397 | Valid Accs: 0.26581 | Time: 0.83 seconds
# Epoch: 361 | Train Loss: 3.78125 | Valid Loss: 3.65735 |Train Accs: 0.15859 | Valid Accs: 0.26668 | Time: 0.81 seconds
# Epoch: 362 | Train Loss: 3.78698 | Valid Loss: 3.65235 |Train Accs: 0.15543 | Valid Accs: 0.26592 | Time: 0.76 seconds
# Epoch: 363 | Train Loss: 3.77666 | Valid Loss: 3.65252 |Train Accs: 0.15791 | Valid Accs: 0.26873 | Time: 0.61 seconds
# Epoch: 364 | Train Loss: 3.77076 | Valid Loss: 3.64671 |Train Accs: 0.15600 | Valid Accs: 0.26928 | Time: 0.86 seconds
# Epoch: 365 | Train Loss: 3.77953 | Valid Loss: 3.64449 |Train Accs: 0.15485 | Valid Accs: 0.26917 | Time: 0.75 seconds
# Epoch: 366 | Train Loss: 3.77207 | Valid Loss: 3.64178 |Train Accs: 0.15680 | Valid Accs: 0.27080 | Time: 0.78 seconds
# Epoch: 367 | Train Loss: 3.77334 | Valid Loss: 3.64010 |Train Accs: 0.15278 | Valid Accs: 0.27123 | Time: 0.75 seconds
# Epoch: 368 | Train Loss: 3.76504 | Valid Loss: 3.63668 |Train Accs: 0.15714 | Valid Accs: 0.27155 | Time: 0.74 seconds
# Epoch: 369 | Train Loss: 3.76347 | Valid Loss: 3.63411 |Train Accs: 0.16136 | Valid Accs: 0.27275 | Time: 0.73 seconds
# Epoch: 370 | Train Loss: 3.76356 | Valid Loss: 3.63653 |Train Accs: 0.15655 | Valid Accs: 0.27253 | Time: 0.62 seconds
# Epoch: 371 | Train Loss: 3.75191 | Valid Loss: 3.63170 |Train Accs: 0.16381 | Valid Accs: 0.27405 | Time: 0.74 seconds
# Epoch: 372 | Train Loss: 3.75212 | Valid Loss: 3.62648 |Train Accs: 0.16291 | Valid Accs: 0.27340 | Time: 1.34 seconds
# Epoch: 373 | Train Loss: 3.75536 | Valid Loss: 3.62275 |Train Accs: 0.16028 | Valid Accs: 0.27589 | Time: 0.94 seconds
# Epoch: 374 | Train Loss: 3.74524 | Valid Loss: 3.62092 |Train Accs: 0.16292 | Valid Accs: 0.27665 | Time: 0.75 seconds
# Epoch: 375 | Train Loss: 3.74162 | Valid Loss: 3.61788 |Train Accs: 0.16686 | Valid Accs: 0.27492 | Time: 0.74 seconds
# Epoch: 376 | Train Loss: 3.74435 | Valid Loss: 3.61426 |Train Accs: 0.16151 | Valid Accs: 0.27763 | Time: 0.73 seconds
# Epoch: 377 | Train Loss: 3.74131 | Valid Loss: 3.61215 |Train Accs: 0.16603 | Valid Accs: 0.27871 | Time: 0.75 seconds
# Epoch: 378 | Train Loss: 3.74071 | Valid Loss: 3.61265 |Train Accs: 0.16654 | Valid Accs: 0.27828 | Time: 0.63 seconds
# Epoch: 379 | Train Loss: 3.73539 | Valid Loss: 3.60572 |Train Accs: 0.15912 | Valid Accs: 0.28002 | Time: 0.88 seconds
# Epoch: 380 | Train Loss: 3.73200 | Valid Loss: 3.60325 |Train Accs: 0.16710 | Valid Accs: 0.27893 | Time: 0.75 seconds
# Epoch: 381 | Train Loss: 3.73397 | Valid Loss: 3.60376 |Train Accs: 0.16474 | Valid Accs: 0.28099 | Time: 0.59 seconds
# Epoch: 382 | Train Loss: 3.73176 | Valid Loss: 3.60083 |Train Accs: 0.16550 | Valid Accs: 0.28132 | Time: 0.75 seconds
# Epoch: 383 | Train Loss: 3.72454 | Valid Loss: 3.59312 |Train Accs: 0.16605 | Valid Accs: 0.28143 | Time: 0.74 seconds
# Epoch: 384 | Train Loss: 3.71214 | Valid Loss: 3.59228 |Train Accs: 0.17363 | Valid Accs: 0.28110 | Time: 0.72 seconds
# Epoch: 385 | Train Loss: 3.71806 | Valid Loss: 3.59077 |Train Accs: 0.16868 | Valid Accs: 0.28360 | Time: 1.08 seconds
# Epoch: 386 | Train Loss: 3.71719 | Valid Loss: 3.58905 |Train Accs: 0.16924 | Valid Accs: 0.28283 | Time: 0.78 seconds
# Epoch: 387 | Train Loss: 3.71419 | Valid Loss: 3.58547 |Train Accs: 0.16899 | Valid Accs: 0.28435 | Time: 1.42 seconds
# Epoch: 388 | Train Loss: 3.70754 | Valid Loss: 3.58192 |Train Accs: 0.17064 | Valid Accs: 0.28479 | Time: 0.90 seconds
# Epoch: 389 | Train Loss: 3.69915 | Valid Loss: 3.58215 |Train Accs: 0.17341 | Valid Accs: 0.28457 | Time: 0.60 seconds
# Epoch: 390 | Train Loss: 3.70574 | Valid Loss: 3.57422 |Train Accs: 0.16844 | Valid Accs: 0.28490 | Time: 0.74 seconds
# Epoch: 391 | Train Loss: 3.70184 | Valid Loss: 3.57474 |Train Accs: 0.17415 | Valid Accs: 0.28555 | Time: 0.62 seconds
# Epoch: 392 | Train Loss: 3.71144 | Valid Loss: 3.56839 |Train Accs: 0.16808 | Valid Accs: 0.28685 | Time: 0.75 seconds
# Epoch: 393 | Train Loss: 3.69825 | Valid Loss: 3.56534 |Train Accs: 0.17639 | Valid Accs: 0.28718 | Time: 0.78 seconds
# Epoch: 394 | Train Loss: 3.69137 | Valid Loss: 3.56470 |Train Accs: 0.17548 | Valid Accs: 0.28598 | Time: 0.85 seconds
# Epoch: 395 | Train Loss: 3.69092 | Valid Loss: 3.56490 |Train Accs: 0.17379 | Valid Accs: 0.28739 | Time: 0.60 seconds
# Epoch: 396 | Train Loss: 3.68235 | Valid Loss: 3.55819 |Train Accs: 0.17953 | Valid Accs: 0.28837 | Time: 0.75 seconds
# Epoch: 397 | Train Loss: 3.69269 | Valid Loss: 3.55393 |Train Accs: 0.17253 | Valid Accs: 0.29021 | Time: 0.75 seconds
# Epoch: 398 | Train Loss: 3.68242 | Valid Loss: 3.55168 |Train Accs: 0.17651 | Valid Accs: 0.28956 | Time: 1.05 seconds
# Epoch: 399 | Train Loss: 3.68145 | Valid Loss: 3.54669 |Train Accs: 0.17341 | Valid Accs: 0.29000 | Time: 0.74 seconds
# Epoch: 400 | Train Loss: 3.68339 | Valid Loss: 3.54897 |Train Accs: 0.17578 | Valid Accs: 0.29173 | Time: 0.68 seconds
# Epoch: 401 | Train Loss: 3.67337 | Valid Loss: 3.54393 |Train Accs: 0.17610 | Valid Accs: 0.29303 | Time: 0.92 seconds
# Epoch: 402 | Train Loss: 3.67268 | Valid Loss: 3.54196 |Train Accs: 0.17872 | Valid Accs: 0.29314 | Time: 0.88 seconds
# Epoch: 403 | Train Loss: 3.67704 | Valid Loss: 3.54168 |Train Accs: 0.17545 | Valid Accs: 0.29336 | Time: 0.75 seconds
# ...
# Epoch: 4872 | Train Loss: 0.25231 | Valid Loss: 0.83745 |Train Accs: 0.97577 | Valid Accs: 0.77566 | Time: 0.78 seconds
# Epoch: 4873 | Train Loss: 0.24853 | Valid Loss: 0.83817 |Train Accs: 0.97480 | Valid Accs: 0.77501 | Time: 0.62 seconds
# Epoch: 4874 | Train Loss: 0.25073 | Valid Loss: 0.83786 |Train Accs: 0.97540 | Valid Accs: 0.77317 | Time: 0.60 seconds
# Epoch: 4875 | Train Loss: 0.24873 | Valid Loss: 0.83979 |Train Accs: 0.97557 | Valid Accs: 0.77599 | Time: 0.60 seconds
# Epoch: 4876 | Train Loss: 0.25319 | Valid Loss: 0.83833 |Train Accs: 0.97354 | Valid Accs: 0.77631 | Time: 0.70 seconds
# Epoch: 4877 | Train Loss: 0.24830 | Valid Loss: 0.83947 |Train Accs: 0.97549 | Valid Accs: 0.77404 | Time: 0.85 seconds
# Epoch: 4878 | Train Loss: 0.24955 | Valid Loss: 0.83960 |Train Accs: 0.97418 | Valid Accs: 0.77469 | Time: 0.68 seconds
# Epoch: 4879 | Train Loss: 0.25052 | Valid Loss: 0.83818 |Train Accs: 0.97442 | Valid Accs: 0.77729 | Time: 0.61 seconds
# Epoch: 4880 | Train Loss: 0.25123 | Valid Loss: 0.84056 |Train Accs: 0.97604 | Valid Accs: 0.77653 | Time: 0.60 seconds
# Epoch: 4881 | Train Loss: 0.25014 | Valid Loss: 0.83861 |Train Accs: 0.97532 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 4882 | Train Loss: 0.24876 | Valid Loss: 0.84090 |Train Accs: 0.97524 | Valid Accs: 0.77403 | Time: 0.60 seconds
# Epoch: 4883 | Train Loss: 0.24963 | Valid Loss: 0.83878 |Train Accs: 0.97434 | Valid Accs: 0.77577 | Time: 0.77 seconds
# Epoch: 4884 | Train Loss: 0.24970 | Valid Loss: 0.83855 |Train Accs: 0.97571 | Valid Accs: 0.77393 | Time: 0.60 seconds
# Epoch: 4885 | Train Loss: 0.24978 | Valid Loss: 0.83816 |Train Accs: 0.97509 | Valid Accs: 0.77512 | Time: 0.70 seconds
# Epoch: 4886 | Train Loss: 0.24382 | Valid Loss: 0.83779 |Train Accs: 0.97718 | Valid Accs: 0.77469 | Time: 0.60 seconds
# Epoch: 4887 | Train Loss: 0.24644 | Valid Loss: 0.83951 |Train Accs: 0.97754 | Valid Accs: 0.77534 | Time: 0.60 seconds
# Epoch: 4888 | Train Loss: 0.25077 | Valid Loss: 0.83979 |Train Accs: 0.97679 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 4889 | Train Loss: 0.24975 | Valid Loss: 0.84016 |Train Accs: 0.97341 | Valid Accs: 0.77447 | Time: 0.60 seconds
# Epoch: 4890 | Train Loss: 0.24699 | Valid Loss: 0.83746 |Train Accs: 0.97546 | Valid Accs: 0.77403 | Time: 0.60 seconds
# Epoch: 4891 | Train Loss: 0.25152 | Valid Loss: 0.84038 |Train Accs: 0.97518 | Valid Accs: 0.77534 | Time: 0.60 seconds
# Epoch: 4892 | Train Loss: 0.25005 | Valid Loss: 0.83755 |Train Accs: 0.97538 | Valid Accs: 0.77642 | Time: 0.70 seconds
# Epoch: 4893 | Train Loss: 0.24843 | Valid Loss: 0.83796 |Train Accs: 0.97608 | Valid Accs: 0.77588 | Time: 0.60 seconds
# Epoch: 4894 | Train Loss: 0.24297 | Valid Loss: 0.84079 |Train Accs: 0.97612 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 4895 | Train Loss: 0.24618 | Valid Loss: 0.83764 |Train Accs: 0.97429 | Valid Accs: 0.77403 | Time: 0.60 seconds
# Epoch: 4896 | Train Loss: 0.24585 | Valid Loss: 0.83956 |Train Accs: 0.97436 | Valid Accs: 0.77534 | Time: 0.60 seconds
# Epoch: 4897 | Train Loss: 0.24714 | Valid Loss: 0.83964 |Train Accs: 0.97593 | Valid Accs: 0.77512 | Time: 0.59 seconds
# Epoch: 4898 | Train Loss: 0.25081 | Valid Loss: 0.83857 |Train Accs: 0.97401 | Valid Accs: 0.77512 | Time: 0.62 seconds
# Epoch: 4899 | Train Loss: 0.24917 | Valid Loss: 0.83724 |Train Accs: 0.97471 | Valid Accs: 0.77816 | Time: 0.77 seconds
# Epoch: 4900 | Train Loss: 0.24789 | Valid Loss: 0.83831 |Train Accs: 0.97708 | Valid Accs: 0.77555 | Time: 0.88 seconds
# Epoch: 4901 | Train Loss: 0.24933 | Valid Loss: 0.83701 |Train Accs: 0.97567 | Valid Accs: 0.77425 | Time: 0.77 seconds
# Epoch: 4902 | Train Loss: 0.24826 | Valid Loss: 0.83626 |Train Accs: 0.97501 | Valid Accs: 0.77382 | Time: 0.77 seconds
# Epoch: 4903 | Train Loss: 0.24229 | Valid Loss: 0.83782 |Train Accs: 0.97691 | Valid Accs: 0.77707 | Time: 0.60 seconds
# Epoch: 4904 | Train Loss: 0.24750 | Valid Loss: 0.83707 |Train Accs: 0.97441 | Valid Accs: 0.77447 | Time: 0.60 seconds
# Epoch: 4905 | Train Loss: 0.24873 | Valid Loss: 0.83879 |Train Accs: 0.97573 | Valid Accs: 0.77436 | Time: 0.61 seconds
# Epoch: 4906 | Train Loss: 0.24572 | Valid Loss: 0.83747 |Train Accs: 0.97643 | Valid Accs: 0.77404 | Time: 0.74 seconds
# Epoch: 4907 | Train Loss: 0.24709 | Valid Loss: 0.83800 |Train Accs: 0.97532 | Valid Accs: 0.77566 | Time: 0.60 seconds
# Epoch: 4908 | Train Loss: 0.24476 | Valid Loss: 0.83632 |Train Accs: 0.97568 | Valid Accs: 0.77653 | Time: 0.61 seconds
# Epoch: 4909 | Train Loss: 0.24392 | Valid Loss: 0.83788 |Train Accs: 0.97663 | Valid Accs: 0.77675 | Time: 0.60 seconds
# Epoch: 4910 | Train Loss: 0.24315 | Valid Loss: 0.83645 |Train Accs: 0.97827 | Valid Accs: 0.77512 | Time: 0.60 seconds
# Epoch: 4911 | Train Loss: 0.24634 | Valid Loss: 0.83791 |Train Accs: 0.97637 | Valid Accs: 0.77414 | Time: 0.60 seconds
# Epoch: 4912 | Train Loss: 0.24536 | Valid Loss: 0.83814 |Train Accs: 0.97613 | Valid Accs: 0.77490 | Time: 0.60 seconds
# Epoch: 4913 | Train Loss: 0.24354 | Valid Loss: 0.83622 |Train Accs: 0.97557 | Valid Accs: 0.77609 | Time: 0.78 seconds
# Epoch: 4914 | Train Loss: 0.24376 | Valid Loss: 0.83743 |Train Accs: 0.97733 | Valid Accs: 0.77512 | Time: 0.61 seconds
# Epoch: 4915 | Train Loss: 0.24385 | Valid Loss: 0.83751 |Train Accs: 0.97803 | Valid Accs: 0.77653 | Time: 0.70 seconds
# Epoch: 4916 | Train Loss: 0.24631 | Valid Loss: 0.83872 |Train Accs: 0.97372 | Valid Accs: 0.77696 | Time: 0.61 seconds
# Epoch: 4917 | Train Loss: 0.24145 | Valid Loss: 0.83793 |Train Accs: 0.97604 | Valid Accs: 0.77425 | Time: 0.75 seconds
# Epoch: 4918 | Train Loss: 0.24198 | Valid Loss: 0.83917 |Train Accs: 0.97710 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 4919 | Train Loss: 0.24130 | Valid Loss: 0.83790 |Train Accs: 0.97688 | Valid Accs: 0.77555 | Time: 0.60 seconds
# Epoch: 4920 | Train Loss: 0.24096 | Valid Loss: 0.83853 |Train Accs: 0.97612 | Valid Accs: 0.77393 | Time: 0.60 seconds
# Epoch: 4921 | Train Loss: 0.24175 | Valid Loss: 0.83619 |Train Accs: 0.97730 | Valid Accs: 0.77490 | Time: 0.88 seconds
# Epoch: 4922 | Train Loss: 0.24432 | Valid Loss: 0.83688 |Train Accs: 0.97661 | Valid Accs: 0.77436 | Time: 0.60 seconds
# Epoch: 4923 | Train Loss: 0.24344 | Valid Loss: 0.83798 |Train Accs: 0.97717 | Valid Accs: 0.77534 | Time: 0.61 seconds
# Epoch: 4924 | Train Loss: 0.24303 | Valid Loss: 0.83650 |Train Accs: 0.97605 | Valid Accs: 0.77544 | Time: 0.60 seconds
# Epoch: 4925 | Train Loss: 0.24456 | Valid Loss: 0.83746 |Train Accs: 0.97599 | Valid Accs: 0.77263 | Time: 0.60 seconds
# Epoch: 4926 | Train Loss: 0.24348 | Valid Loss: 0.83718 |Train Accs: 0.97649 | Valid Accs: 0.77273 | Time: 0.60 seconds
# Epoch: 4927 | Train Loss: 0.24235 | Valid Loss: 0.83793 |Train Accs: 0.97627 | Valid Accs: 0.77360 | Time: 0.59 seconds
# Epoch: 4928 | Train Loss: 0.24409 | Valid Loss: 0.83711 |Train Accs: 0.97630 | Valid Accs: 0.77393 | Time: 0.75 seconds
# Epoch: 4929 | Train Loss: 0.24491 | Valid Loss: 0.83761 |Train Accs: 0.97520 | Valid Accs: 0.77393 | Time: 1.17 seconds
# Epoch: 4930 | Train Loss: 0.24221 | Valid Loss: 0.83765 |Train Accs: 0.97574 | Valid Accs: 0.77306 | Time: 0.96 seconds
# Epoch: 4931 | Train Loss: 0.24046 | Valid Loss: 0.83793 |Train Accs: 0.97618 | Valid Accs: 0.77501 | Time: 0.83 seconds
# Epoch: 4932 | Train Loss: 0.23925 | Valid Loss: 0.83709 |Train Accs: 0.97751 | Valid Accs: 0.77675 | Time: 1.15 seconds
# Epoch: 4933 | Train Loss: 0.24075 | Valid Loss: 0.83735 |Train Accs: 0.97635 | Valid Accs: 0.77490 | Time: 0.83 seconds
# Epoch: 4934 | Train Loss: 0.24256 | Valid Loss: 0.83828 |Train Accs: 0.97618 | Valid Accs: 0.77371 | Time: 0.84 seconds
# Epoch: 4935 | Train Loss: 0.24036 | Valid Loss: 0.83784 |Train Accs: 0.97596 | Valid Accs: 0.77512 | Time: 0.83 seconds
# Epoch: 4936 | Train Loss: 0.24278 | Valid Loss: 0.83701 |Train Accs: 0.97421 | Valid Accs: 0.77501 | Time: 0.83 seconds
# Epoch: 4937 | Train Loss: 0.23870 | Valid Loss: 0.83740 |Train Accs: 0.97693 | Valid Accs: 0.77512 | Time: 0.97 seconds
# Epoch: 4938 | Train Loss: 0.24127 | Valid Loss: 0.83710 |Train Accs: 0.97794 | Valid Accs: 0.77501 | Time: 0.83 seconds
# Epoch: 4939 | Train Loss: 0.23958 | Valid Loss: 0.83596 |Train Accs: 0.97808 | Valid Accs: 0.77577 | Time: 1.07 seconds
# Epoch: 4940 | Train Loss: 0.24239 | Valid Loss: 0.83773 |Train Accs: 0.97498 | Valid Accs: 0.77566 | Time: 0.83 seconds
# Epoch: 4941 | Train Loss: 0.23742 | Valid Loss: 0.83749 |Train Accs: 0.97838 | Valid Accs: 0.77523 | Time: 0.84 seconds
# Epoch: 4942 | Train Loss: 0.23964 | Valid Loss: 0.83822 |Train Accs: 0.97635 | Valid Accs: 0.77371 | Time: 0.82 seconds
# Epoch: 4943 | Train Loss: 0.24133 | Valid Loss: 0.83732 |Train Accs: 0.97671 | Valid Accs: 0.77479 | Time: 0.82 seconds
# Epoch: 4944 | Train Loss: 0.23681 | Valid Loss: 0.83901 |Train Accs: 0.97878 | Valid Accs: 0.77414 | Time: 0.72 seconds
# Epoch: 4945 | Train Loss: 0.24181 | Valid Loss: 0.83821 |Train Accs: 0.97682 | Valid Accs: 0.77794 | Time: 0.83 seconds
# Epoch: 4946 | Train Loss: 0.24065 | Valid Loss: 0.83707 |Train Accs: 0.97607 | Valid Accs: 0.77425 | Time: 0.65 seconds
# Epoch: 4947 | Train Loss: 0.24006 | Valid Loss: 0.83453 |Train Accs: 0.97513 | Valid Accs: 0.77588 | Time: 0.79 seconds
# Epoch: 4948 | Train Loss: 0.23993 | Valid Loss: 0.83721 |Train Accs: 0.97665 | Valid Accs: 0.77599 | Time: 0.61 seconds
# Epoch: 4949 | Train Loss: 0.24007 | Valid Loss: 0.83992 |Train Accs: 0.97728 | Valid Accs: 0.77382 | Time: 0.64 seconds
# Epoch: 4950 | Train Loss: 0.24200 | Valid Loss: 0.83579 |Train Accs: 0.97593 | Valid Accs: 0.77490 | Time: 0.60 seconds
# Epoch: 4951 | Train Loss: 0.24134 | Valid Loss: 0.83521 |Train Accs: 0.97651 | Valid Accs: 0.77631 | Time: 0.70 seconds
# Epoch: 4952 | Train Loss: 0.23926 | Valid Loss: 0.83544 |Train Accs: 0.97611 | Valid Accs: 0.77534 | Time: 0.60 seconds
# Epoch: 4953 | Train Loss: 0.23860 | Valid Loss: 0.83616 |Train Accs: 0.97713 | Valid Accs: 0.77707 | Time: 0.59 seconds
# Epoch: 4954 | Train Loss: 0.23844 | Valid Loss: 0.83569 |Train Accs: 0.97861 | Valid Accs: 0.77404 | Time: 0.61 seconds
# Epoch: 4955 | Train Loss: 0.23857 | Valid Loss: 0.83759 |Train Accs: 0.97640 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 4956 | Train Loss: 0.23967 | Valid Loss: 0.83721 |Train Accs: 0.97501 | Valid Accs: 0.77338 | Time: 0.61 seconds
# Epoch: 4957 | Train Loss: 0.23618 | Valid Loss: 0.83531 |Train Accs: 0.97713 | Valid Accs: 0.77588 | Time: 0.60 seconds
# Epoch: 4958 | Train Loss: 0.23446 | Valid Loss: 0.83859 |Train Accs: 0.97875 | Valid Accs: 0.77371 | Time: 0.60 seconds
# Epoch: 4959 | Train Loss: 0.23457 | Valid Loss: 0.83524 |Train Accs: 0.97886 | Valid Accs: 0.77523 | Time: 0.59 seconds
# Epoch: 4960 | Train Loss: 0.24091 | Valid Loss: 0.83754 |Train Accs: 0.97644 | Valid Accs: 0.77512 | Time: 0.70 seconds
# Epoch: 4961 | Train Loss: 0.23558 | Valid Loss: 0.83679 |Train Accs: 0.97677 | Valid Accs: 0.77425 | Time: 0.62 seconds
# Epoch: 4962 | Train Loss: 0.23989 | Valid Loss: 0.83723 |Train Accs: 0.97599 | Valid Accs: 0.77469 | Time: 0.76 seconds
# Epoch: 4963 | Train Loss: 0.23613 | Valid Loss: 0.83820 |Train Accs: 0.97816 | Valid Accs: 0.77512 | Time: 0.59 seconds
# Epoch: 4964 | Train Loss: 0.23689 | Valid Loss: 0.83776 |Train Accs: 0.97707 | Valid Accs: 0.77393 | Time: 0.60 seconds
# Epoch: 4965 | Train Loss: 0.23729 | Valid Loss: 0.83511 |Train Accs: 0.97688 | Valid Accs: 0.77599 | Time: 0.59 seconds
# Epoch: 4966 | Train Loss: 0.23458 | Valid Loss: 0.83561 |Train Accs: 0.97881 | Valid Accs: 0.77534 | Time: 0.70 seconds
# Epoch: 4967 | Train Loss: 0.23477 | Valid Loss: 0.83666 |Train Accs: 0.97693 | Valid Accs: 0.77577 | Time: 0.60 seconds
# Epoch: 4968 | Train Loss: 0.23266 | Valid Loss: 0.83784 |Train Accs: 0.97841 | Valid Accs: 0.77490 | Time: 0.60 seconds
# Epoch: 4969 | Train Loss: 0.23822 | Valid Loss: 0.83547 |Train Accs: 0.97658 | Valid Accs: 0.77425 | Time: 0.60 seconds
# Epoch: 4970 | Train Loss: 0.23528 | Valid Loss: 0.83530 |Train Accs: 0.97729 | Valid Accs: 0.77577 | Time: 0.60 seconds
# Epoch: 4971 | Train Loss: 0.23730 | Valid Loss: 0.83672 |Train Accs: 0.97582 | Valid Accs: 0.77393 | Time: 0.60 seconds
# Epoch: 4972 | Train Loss: 0.23557 | Valid Loss: 0.83598 |Train Accs: 0.97758 | Valid Accs: 0.77414 | Time: 0.59 seconds
# Epoch: 4973 | Train Loss: 0.23497 | Valid Loss: 0.83469 |Train Accs: 0.97858 | Valid Accs: 0.77577 | Time: 0.62 seconds
# Epoch: 4974 | Train Loss: 0.23355 | Valid Loss: 0.83622 |Train Accs: 0.97850 | Valid Accs: 0.77545 | Time: 0.82 seconds
# Epoch: 4975 | Train Loss: 0.23343 | Valid Loss: 0.83659 |Train Accs: 0.97872 | Valid Accs: 0.77404 | Time: 0.78 seconds
# Epoch: 4976 | Train Loss: 0.23449 | Valid Loss: 0.83665 |Train Accs: 0.97858 | Valid Accs: 0.77382 | Time: 0.60 seconds
# Epoch: 4977 | Train Loss: 0.23574 | Valid Loss: 0.83547 |Train Accs: 0.97778 | Valid Accs: 0.77328 | Time: 0.61 seconds
# Epoch: 4978 | Train Loss: 0.23206 | Valid Loss: 0.83467 |Train Accs: 0.97847 | Valid Accs: 0.77631 | Time: 0.60 seconds
# Epoch: 4979 | Train Loss: 0.23382 | Valid Loss: 0.83613 |Train Accs: 0.97780 | Valid Accs: 0.77458 | Time: 0.76 seconds
# Epoch: 4980 | Train Loss: 0.23166 | Valid Loss: 0.83745 |Train Accs: 0.97705 | Valid Accs: 0.77512 | Time: 0.60 seconds
# Epoch: 4981 | Train Loss: 0.23289 | Valid Loss: 0.83361 |Train Accs: 0.97847 | Valid Accs: 0.77577 | Time: 0.78 seconds
# Epoch: 4982 | Train Loss: 0.23581 | Valid Loss: 0.83473 |Train Accs: 0.97630 | Valid Accs: 0.77696 | Time: 0.70 seconds
# Epoch: 4983 | Train Loss: 0.23358 | Valid Loss: 0.83297 |Train Accs: 0.97814 | Valid Accs: 0.77523 | Time: 0.78 seconds
# Epoch: 4984 | Train Loss: 0.23645 | Valid Loss: 0.83407 |Train Accs: 0.97674 | Valid Accs: 0.77501 | Time: 0.61 seconds
# Epoch: 4985 | Train Loss: 0.23309 | Valid Loss: 0.83340 |Train Accs: 0.97780 | Valid Accs: 0.77469 | Time: 0.60 seconds
# Epoch: 4986 | Train Loss: 0.23058 | Valid Loss: 0.83498 |Train Accs: 0.97809 | Valid Accs: 0.77425 | Time: 0.60 seconds
# Epoch: 4987 | Train Loss: 0.23087 | Valid Loss: 0.83383 |Train Accs: 0.97916 | Valid Accs: 0.77512 | Time: 0.60 seconds
# Epoch: 4988 | Train Loss: 0.23521 | Valid Loss: 0.83467 |Train Accs: 0.97649 | Valid Accs: 0.77393 | Time: 0.62 seconds
# Epoch: 4989 | Train Loss: 0.22974 | Valid Loss: 0.83655 |Train Accs: 0.97986 | Valid Accs: 0.77653 | Time: 0.60 seconds
# Epoch: 4990 | Train Loss: 0.23639 | Valid Loss: 0.83436 |Train Accs: 0.97819 | Valid Accs: 0.77609 | Time: 0.72 seconds
# Epoch: 4991 | Train Loss: 0.23083 | Valid Loss: 0.83515 |Train Accs: 0.97919 | Valid Accs: 0.77534 | Time: 0.60 seconds
# Epoch: 4992 | Train Loss: 0.23453 | Valid Loss: 0.83554 |Train Accs: 0.97557 | Valid Accs: 0.77436 | Time: 0.61 seconds
# Epoch: 4993 | Train Loss: 0.23276 | Valid Loss: 0.83528 |Train Accs: 0.97833 | Valid Accs: 0.77349 | Time: 0.60 seconds
# Epoch: 4994 | Train Loss: 0.23137 | Valid Loss: 0.83489 |Train Accs: 0.97858 | Valid Accs: 0.77349 | Time: 0.60 seconds
# Epoch: 4995 | Train Loss: 0.23570 | Valid Loss: 0.83307 |Train Accs: 0.97551 | Valid Accs: 0.77328 | Time: 0.60 seconds
# Epoch: 4996 | Train Loss: 0.23275 | Valid Loss: 0.83397 |Train Accs: 0.97716 | Valid Accs: 0.77306 | Time: 0.88 seconds
# Epoch: 4997 | Train Loss: 0.23002 | Valid Loss: 0.83275 |Train Accs: 0.97900 | Valid Accs: 0.77512 | Time: 0.77 seconds
# Epoch: 4998 | Train Loss: 0.22850 | Valid Loss: 0.83685 |Train Accs: 0.97850 | Valid Accs: 0.77414 | Time: 0.61 seconds
# Epoch: 4999 | Train Loss: 0.23186 | Valid Loss: 0.83466 |Train Accs: 0.97772 | Valid Accs: 0.77523 | Time: 0.60 seconds
# Epoch: 5000 | Train Loss: 0.23031 | Valid Loss: 0.83461 |Train Accs: 0.97747 | Valid Accs: 0.77414 | Time: 0.60 seconds
#
# **************************************************
#
# Best Validation Loss at Epoch 4997
#
# **************************************************
#
# Best Validation Accs at Epoch 4899
#
# **************************************************
#
# Time Taken [5000 Epochs] : 65.23 minutes
#
# **************************************************
# **************************************************
#
# Total Time Taken for 5-Fold CV : 315.33 minutes
#
# **************************************************

# %% [markdown]
# ### **Get SWIN Features for the Test Set**

# %%
# train_df = pd.read_csv("../input/sorghum-id-fgvc-9/train_cultivar_mapping.csv")
# ss_df = pd.read_csv("../input/sorghum-id-fgvc-9/sample_submission.csv")

# broken_images = [filename for filename in train_df.image if filename not in os.listdir("../input/sorghum-id-fgvc-9/train_images")]
# for broken_image in broken_images:
#     index = train_df.index[train_df.image == broken_image]
#     train_df = train_df.drop(index=index)
    
# filenames = train_df.image.copy().values
# labels    = train_df.cultivar.copy().values 

# labels = le.fit_transform(labels)

# ts_filenames = ss_df.filename.copy().values
# ts_features = np.zeros((len(ts_filenames), FV_LENGTH))

# %%
# model = timm.create_model("swin_base_patch4_window7_384_in22k", pretrained=True).to(DEVICE)
# model = torch.nn.Sequential(*[*model.children()][:-3])

# dataloader_setup = FEDS("../input/sorghum-id-fgvc-9/test", ts_filenames, TRANSFORM)
# dataloader = DL(dataloader_setup, batch_size=64, shuffle=False)

# ts_features = torch.zeros(1, FV_LENGTH).to(DEVICE)

# for X in dataloader:
#     X = X.to(DEVICE)
#     with torch.no_grad():
#         output = model(X).last_hidden_state
#     ts_features = torch.cat((ts_features, output[:, 0, :]), dim=0)

# ts_features = ts_features[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Submission**

# %%
# ts_data_setup = DS(ts_features, None, "test")
# ts_data = DL(ts_data_setup, batch_size=batch_size, shuffle=False)

# torch.manual_seed(SEED)
# model = Model(IL=ts_features.shape[1], HL=HL, DP=0.5, use_WN=True).to(DEVICE)

# best_model_fold = _____
# y_pred = predict(model=model, dataloader=ts_data, path=os.path.join(CLASSIFIER_HEAD_PATH, f"state_fold_{best_model_fold}.pt"))

# ss_df["cultivar"] = le.inverse_transform(y_pred.astype("uint8"))
# ss_df.to_csv("submission.csv", index=False)
