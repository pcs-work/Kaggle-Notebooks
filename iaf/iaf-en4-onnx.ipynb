# %%
# %%bash
# pip install timm onnx onnxruntime -q

# %%
import os
import sys
import cv2
import json
import onnx
import timm
import torch
import random as r
import numpy as np
import pandas as pd
import onnxruntime as ort
import matplotlib.pyplot as plt

from PIL import Image
from typing import Union
from torchvision import models
from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore")

if not os.path.exists("onnx"): os.makedirs("onnx")
    
ort.set_default_logger_severity(3)

# %%
labels: dict = json.load(open("/kaggle/input/iaf-dataframe/labels.json", "r"))
    
    
def breaker() -> None:
    print("\n" + 50*"*" + "\n")


def get_image(path: str, size: int=224) -> np.ndarray:
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
    return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_CUBIC)
    

def show_image(
    image: np.ndarray, 
    cmap: str="gnuplot2", 
    title: Union[str, None]=None
) -> None:
    plt.figure()
    plt.imshow(image, cmap=cmap)
    plt.axis("off")
    if title: plt.title(title)
    plt.show()

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        self.model = timm.create_model(model_name="efficientnet_b4", pretrained=False)
        self.model.classifier = torch.nn.Linear(in_features=self.model.classifier.in_features, out_features=135)

    def forward(self, x):
        return self.model(x)

    
class CFG(object):  
    def __init__(
        self, 
        in_channels: int=3, 
        size: int=256, 
        opset_version: int=9, 
        path: str=None
    ):
        self.in_channels = in_channels
        self.size = size
        self.dummy = torch.randn(1, self.in_channels, self.size, self.size)
        self.opset_version = opset_version
        self.path = path

# %%
# Fold 1 (BEST), Fold 2(SECOND BEST), Fold 3(THIRD BEST)

for fold in range(1, 6):
    for v in ["a", "l"]:
        cfg = CFG(
            in_channels=3, 
            size=224, 
            opset_version=15, 
            path=f"/kaggle/input/iaf-en4-a224-e25-f{fold}/saves/b{v}e_state_fold_{fold}.pt"
        )

        model = Model()
        model.load_state_dict(torch.load(cfg.path, map_location=torch.device("cpu"))["model_state_dict"])
        model.eval()

        clear_output()

        torch.onnx.export(
            model=model, 
            args=cfg.dummy, 
            f=f"onnx/b{v}e_model_f{fold}.onnx", 
            input_names=["input"], 
            output_names=["output"], 
            opset_version=cfg.opset_version,
            export_params=True,
            training=torch.onnx.TrainingMode.EVAL,
            operator_export_type=torch.onnx.OperatorExportTypes.ONNX_ATEN_FALLBACK,
            dynamic_axes={
              "input"  : {0 : "batch_size"},
              "output" : {0 : "batch_size"},
            }
        )
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
class OnnxModel(object):
    def __init__(self, path: str) -> None:
        self.size: int = 224
        
        self.mean: list = [0.59881, 0.44761, 0.38006]
        self.std: list  = [0.23384, 0.20223, 0.18433]
        
        self.path: str = path
    
        model = onnx.load(self.path)
        onnx.checker.check_model(model)
        self.ort_session = ort.InferenceSession(self.path)
        
    def infer(self, image: np.ndarray, labels: dict) -> np.ndarray:
        image = image / 255
        image = image.transpose(2, 0, 1)
        for i in range(image.shape[0]): image[i, :, :] = (image[i, :, :] - self.mean[i]) / self.std[i]
        image = np.expand_dims(image, axis=0)
        inputs = {self.ort_session.get_inputs()[0].name: image.astype("float32")}
        result = self.ort_session.run(None, inputs)
        odds = np.exp(np.max(result))
        return labels[str(np.argmax(result))], odds / (1 + odds)

# %%
df = pd.read_csv("/kaggle/input/iaf-dataframe/valid.csv")

breaker()
for model_name in sorted(os.listdir("onnx")):
    
    onnx_model = OnnxModel(f"onnx/{model_name}")
    
    print(f"{model_name.upper()}\n")
    
    count: int = 0
    
    for i in range(20):
        index = r.randint(0, len(df)-1)
        filepath = df.iloc[index, 0]
        y_true   = df.iloc[index, 1]

        image = get_image(filepath)

        y_pred, _ = onnx_model.infer(image, labels)
        
        if labels[str(y_true)] == y_pred:
            count += 1
        
        print(f"{labels[str(y_true)]}, {y_pred}")
        # show_image(image, title=y_pred)
    
    print(f"\n\nAccuracy : {count / 20:.5f}")

    breaker()
# Out:
# **************************************************
#
# BAE_MODEL_F1.ONNX
#
# prabhu_deva, arshad_warsi
# amitabh_bachchan, amitabh_bachchan
# zarina_wahab, dev_anand
# tabu, deepti_naval
# varun_dhawan, varun_dhawan
# rakhee_gulzar, rakhee_gulzar
# farida_jalal, farida_jalal
# varun_dhawan, varun_dhawan
# rahul_bose, rahul_bose
# huma_qureshi, huma_qureshi
# anushka_shetty, tabu
# prakash_raj, prakash_raj
# mita_vashisht, mita_vashisht
# deepika_padukone, deepika_padukone
# nagarjuna_akkineni, nagarjuna_akkineni
# shabana_azmi, shabana_azmi
# nargis, nargis
# adil_hussain, adil_hussain
# shah_rukh_khan, shah_rukh_khan
# nana_patekar, nana_patekar
#
#
# Accuracy : 0.80000
#
# **************************************************
#
# BAE_MODEL_F2.ONNX
#
# anushka_shetty, richa_chadha
# gulshan_grover, gulshan_grover
# lara_dutta, lara_dutta
# tabu, tabu
# nana_patekar, prabhas
# zarina_wahab, zarina_wahab
# salman_khan, ranvir_shorey
# rajinikanth, sanjay_mishra
# adil_hussain, adil_hussain
# hrithik_roshan, rajesh_khanna
# darsheel_safary, waheeda_rehman
# pran, pran
# randeep_hooda, randeep_hooda
# kay_kay_menon, hrithik_roshan
# prabhas, sunil_shetty
# rajat_kapoor, adil_hussain
# girish_karnad, girish_karnad
# varun_dhawan, varun_dhawan
# sunil_shetty, akshaye_khanna
# abhay_deol, abhay_deol
#
#
# Accuracy : 0.50000
#
# **************************************************
#
# BAE_MODEL_F3.ONNX
#
# adil_hussain, adil_hussain
# soumitra_chatterjee, kulbhushan_kharbanda
# shah_rukh_khan, shah_rukh_khan
# rajpal_yadav, rajpal_yadav
# rajat_kapoor, rajat_kapoor
# anupam_kher, anupam_kher
# irrfan_khan, irrfan_khan
# pran, pran
# amrish_puri, amrish_puri
# raj_babbar, raj_babbar
# pooja_bhatt, pooja_bhatt
# pawan_malhotra, pawan_malhotra
# johnny_lever, kamal_haasan
# dharmendra, dharmendra
# kay_kay_menon, varun_dhawan
# tinnu_anand, chunky_panday
# nana_patekar, nana_patekar
# ashish_vidyarthi, mithun_chakraborty
# shah_rukh_khan, shah_rukh_khan
# farooq_shaikh, farooq_shaikh
#
#
# Accuracy : 0.75000
#
# **************************************************
#
# BAE_MODEL_F4.ONNX
#
# dev_anand, dev_anand
# pran, pran
# pran, pran
# vinod_khanna, shashi_kapoor
# chiranjeevi, chiranjeevi
# boman_irani, boman_irani
# farhan_akhtar, naseeruddin_shah
# pankaj_tripathi, pankaj_tripathi
# prakash_raj, prakash_raj
# irrfan_khan, irrfan_khan
# mehmood, mehmood
# rakhee_gulzar, rakhee_gulzar
# amole_gupte, amole_gupte
# chunky_panday, chunky_panday
# mukul_dev, mukul_dev
# lara_dutta, lara_dutta
# rakhee_gulzar, rakhee_gulzar
# anushka_shetty, anushka_shetty
# annu_kapoor, annu_kapoor
# sharman_joshi, farhan_akhtar
#
#
# Accuracy : 0.85000
#
# **************************************************
#
# BAE_MODEL_F5.ONNX
#
# ashish_vidyarthi, soumitra_chatterjee
# zeenat_aman, zeenat_aman
# anil_kapoor, anil_kapoor
# shreyas_talpade, shreyas_talpade
# saeed_jaffrey, saeed_jaffrey
# tinnu_anand, johnny_lever
# manoj_bajpayee, manoj_bajpayee
# kamal_haasan, sunny_deol
# sharmila_tagore, sharmila_tagore
# mammootty, mammootty
# boman_irani, amitabh_bachchan
# pawan_malhotra, pawan_malhotra
# danny_denzongpa, johnny_lever
# rahul_bose, rahul_bose
# adil_hussain, johnny_lever
# hrithik_roshan, hrithik_roshan
# rajpal_yadav, rajpal_yadav
# prem_chopra, prem_chopra
# anil_kapoor, anil_kapoor
# dilip_kumar, raaj_kumar
#
#
# Accuracy : 0.65000
#
# **************************************************
#
# BLE_MODEL_F1.ONNX
#
# mukesh_khanna, dimple_kapadia
# dev_anand, dev_anand
# ranvir_shorey, ranvir_shorey
# shah_rukh_khan, shah_rukh_khan
# deepika_padukone, deepika_padukone
# nana_patekar, nana_patekar
# zarina_wahab, zarina_wahab
# konkona_sen_sharma, konkona_sen_sharma
# prem_chopra, prem_chopra
# nawazuddin_siddiqui, pankaj_tripathi
# nandita_das, zarina_wahab
# ayushmann_khurrana, ranvir_shorey
# adil_hussain, adil_hussain
# nargis, nargis
# madhavan, mukul_dev
# dev_anand, dev_anand
# akshaye_khanna, mukesh_khanna
# saif_ali_khan, saif_ali_khan
# akshaye_khanna, akshaye_khanna
# annu_kapoor, annu_kapoor
#
#
# Accuracy : 0.70000
#
# **************************************************
#
# BLE_MODEL_F2.ONNX
#
# adil_hussain, danny_denzongpa
# mohnish_bahl, mohnish_bahl
# mukesh_khanna, vinod_khanna
# rajit_kapoor, rajit_kapoor
# amrish_puri, amrish_puri
# nagarjuna_akkineni, nagarjuna_akkineni
# irrfan_khan, irrfan_khan
# mehmood, dharmendra
# dimple_kapadia, dimple_kapadia
# anushka_shetty, tabu
# mohnish_bahl, dharmendra
# shreyas_talpade, ranveer_singh
# sanjay_dutt, sanjay_dutt
# atul_kulkarni, atul_kulkarni
# arshad_warsi, arshad_warsi
# gulshan_grover, gulshan_grover
# sanjay_dutt, sanjay_dutt
# randeep_hooda, randeep_hooda
# huma_qureshi, richa_chadha
# shashi_kapoor, rajesh_khanna
#
#
# Accuracy : 0.60000
#
# **************************************************
#
# BLE_MODEL_F3.ONNX
#
# rani_mukerji, rani_mukerji
# anushka_shetty, radhika_apte
# kulbhushan_kharbanda, naseeruddin_shah
# nana_patekar, nana_patekar
# pankaj_tripathi, pawan_malhotra
# akshay_kumar, ranvir_shorey
# neeraj_kabi, neeraj_kabi
# sharman_joshi, sharman_joshi
# naseeruddin_shah, naseeruddin_shah
# raaj_kumar, raaj_kumar
# prabhu_deva, farhan_akhtar
# prabhas, prabhas
# farhan_akhtar, farhan_akhtar
# amol_palekar, amol_palekar
# kamal_haasan, paresh_rawal
# mukul_dev, madhavan
# sunil_shetty, sunil_shetty
# huma_qureshi, lara_dutta
# priyanka_chopra, richa_chadha
# om_puri, om_puri
#
#
# Accuracy : 0.55000
#
# **************************************************
#
# BLE_MODEL_F4.ONNX
#
# kader_khan, kader_khan
# govinda, govinda
# farooq_shaikh, farooq_shaikh
# rajit_kapoor, rajit_kapoor
# kulbhushan_kharbanda, naseeruddin_shah
# ratna_pathak_shah, ratna_pathak_shah
# manoj_bajpayee, manoj_bajpayee
# rekha, rekha
# raj_kapoor, raj_kapoor
# ramya_krishnan, ramya_krishnan
# rani_mukerji, rani_mukerji
# rajat_kapoor, rajat_kapoor
# rajinikanth, pran
# nandita_das, nandita_das
# raj_babbar, raj_babbar
# riteish_deshmukh, riteish_deshmukh
# randeep_hooda, randeep_hooda
# farida_jalal, rajesh_khanna
# utpal_dutt, amrish_puri
# rajat_kapoor, rajat_kapoor
#
#
# Accuracy : 0.80000
#
# **************************************************
#
# BLE_MODEL_F5.ONNX
#
# ranbir_kapoor, ranbir_kapoor
# sunny_deol, sunny_deol
# lara_dutta, lara_dutta
# utpal_dutt, utpal_dutt
# rajit_kapoor, rajit_kapoor
# chunky_panday, chunky_panday
# kajol, kajol
# abhay_deol, saif_ali_khan
# ranbir_kapoor, ranbir_kapoor
# govinda, govinda
# boman_irani, mohnish_bahl
# mita_vashisht, raaj_kumar
# sharmila_tagore, sharmila_tagore
# saeed_jaffrey, anupam_kher
# shashi_kapoor, shashi_kapoor
# amol_palekar, amol_palekar
# prem_chopra, prem_chopra
# raaj_kumar, raaj_kumar
# nirupa_roy, dimple_kapadia
# sanjay_dutt, sanjay_dutt
#
#
# Accuracy : 0.75000
#
# **************************************************
