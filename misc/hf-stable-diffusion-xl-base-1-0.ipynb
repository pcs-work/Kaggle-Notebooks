# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# # Version 3

# prompts: list = [
#     "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
#     "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
#     "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
#     "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
#     "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
#     "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
#     "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
#     "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
#     "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
#     "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
# ]

# %%
# # Version 4

# prompts: list = [
#     "A city at night, dark sky, people watching in wonder, very detailed, 8k, concept art",
#     "A city at night big moon and stars at the borders, concept art, dark, creepy, atmospheric, 8k, HD",
#     "A city at night, small lamp posts, burning church, street lamps, 4 k, concept art, sparse vegetation",
#     "A city at night, low green clouds, dark red sky, night, 4k, high details, fireflies, art by WLOP,",
#     "A city at night, dark moonlight, sky full of stars at the edges, concept art, 4k, octane render, digital painting,",
#     "A city at night, big moon on the right, meteor fall, trending on artstation, 8k, cinematic, soft, sharp focus, insanely",
#     "A city at night, huge moon, stars at the horizon, 4k, 8k, trending on Artstation",
#     "A city at night during a nuclear eruption, intricate Asteroid belt with huge rings in the sky, water and beautiful pink blobs, flying cars,",
#     "A city at night with cumulonimbus clouds in the sky, night colors, stars in the sky, painting by tyler edlin,",
#     "A city at night, moonlight, street lamps, falling leaves, wide angle, super highly detailed, professional digital painting, artstation, concept art",
# ]

# %%
# Version 5

prompts: list = [
    "A picturesque night sky over a full moon",
    "A picturesque night sky with planets visible in the background, stars in the sky",
    "A picturesque night sky, small waterfall, mist, candlelight, celestial highlights, painting in style of krenz cushart, ilya",
    "A picturesque night sky, low angle, dawn, stars in the night sky, realistic, detailed faces, moody, atmospheric, cinematic, wide",
    "A picturesque night sky overimpel forest",
    "A picturesque night sky over the sea, stars bloom in the background, natural, ultra detail. ethereal",
    "A picturesque night sky with constellations, small camp is built beside. In style of Yoji Shinkawa and Hyung-tae",
    "A picturesque night sky with constellations, stars Asteroid belt with huge rings and beautiful draped clouds, anime, fountain, statue, underwater,",
    "A picturesque night sky with stars visible through shattered clouds",
    "A picturesque night sky overland, low poly, isometric art",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 2.93MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 3.91MB/s]
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 1.84MB/s]
#
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 3.50MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:01,  8.60it/s]
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 2.86MB/s]
#
#
#
# Downloading model.fp16.safetensors:   0%|           | 0.00/1.39G [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 1.81MB/s]
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 9.03MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 3.01MB/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 3.54MB/s]
#
#
#
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 13.3MB/s]
#
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:03, 72.2MB/s]
# Downloading (…)1d8/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 8.59MB/s]
#
#
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:19, 72.4MB/s]
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)81d8/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 2.90MB/s]
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 5.88MB/s]
#
#
#
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 13.6MB/s]
#
#
# Downloading model.fp16.safetensors:   9%|▎  | 21.0M/246M [00:00<00:02, 75.8MB/s]
#
#
# Downloading model.fp16.safetensors:   2%|   | 31.5M/1.39G [00:00<00:12, 111MB/s]
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:07, 76.0MB/s]
#
#
# Downloading model.fp16.safetensors:   4%|   | 52.4M/1.39G [00:00<00:11, 121MB/s]
#
# Downloading model.fp16.safetensors:  17%|▌  | 41.9M/246M [00:00<00:02, 89.8MB/s]
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 64.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 61.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:04, 79.8MB/s]
#
#
# Downloading model.fp16.safetensors:   5%|▏  | 73.4M/1.39G [00:00<00:10, 127MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 72.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 73.7MB/s]
#
# Downloading model.fp16.safetensors:  26%|█   | 62.9M/246M [00:00<00:01, 102MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<00:51, 98.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▍ | 31.5M/167M [00:00<00:01, 83.5MB/s]
#
# Downloading model.fp16.safetensors:  30%|█▏  | 73.4M/246M [00:00<00:01, 101MB/s]
#
#
# Downloading model.fp16.safetensors:   7%|▏  | 94.4M/1.39G [00:00<00:10, 125MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 52.4M/5.14G [00:00<00:51, 99.6MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 92.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 99.6MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 92.5MB/s]
#
# Downloading model.fp16.safetensors:  38%|█▌  | 94.4M/246M [00:00<00:01, 109MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 73.4M/5.14G [00:00<00:50, 99.4MB/s]
#
#
# Downloading model.fp16.safetensors:   8%|▎   | 115M/1.39G [00:01<00:11, 109MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 92.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|█▎ | 73.4M/167M [00:00<00:00, 109MB/s]
#
# Downloading model.fp16.safetensors:  47%|██▎  | 115M/246M [00:01<00:01, 115MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%| | 83.9M/5.14G [00:00<00:54, 92.4MB/s]
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 102MB/s]
#
#
# Downloading model.fp16.safetensors:  10%|▍   | 136M/1.39G [00:01<00:11, 107MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█▋ | 94.4M/167M [00:00<00:00, 113MB/s]
#
# Downloading model.fp16.safetensors:  55%|██▊  | 136M/246M [00:01<00:00, 111MB/s]
# Downloading (…)del.fp16.safetensors:  56%|█▋ | 94.4M/167M [00:00<00:00, 102MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 105M/5.14G [00:01<00:50, 99.1MB/s]
#
#
# Downloading model.fp16.safetensors:  11%|▍   | 157M/1.39G [00:01<00:11, 107MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|██▊ | 115M/167M [00:01<00:00, 110MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 115M/5.14G [00:01<00:52, 96.1MB/s]
#
# Downloading model.fp16.safetensors:  64%|███▏ | 157M/246M [00:01<00:00, 112MB/s]
# Downloading (…)del.fp16.safetensors:  69%|██▊ | 115M/167M [00:01<00:00, 108MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 126M/5.14G [00:01<00:51, 97.6MB/s]
#
#
# Downloading model.fp16.safetensors:  13%|▌   | 178M/1.39G [00:01<00:11, 108MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|███▎| 136M/167M [00:01<00:00, 107MB/s]
#
# Downloading model.fp16.safetensors:  72%|███▌ | 178M/246M [00:01<00:00, 111MB/s]
# Downloading (…)del.fp16.safetensors:  81%|███▎| 136M/167M [00:01<00:00, 107MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|   | 147M/5.14G [00:01<00:47, 104MB/s]
#
#
# Downloading model.fp16.safetensors:  14%|▌   | 199M/1.39G [00:01<00:11, 108MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|   | 157M/5.14G [00:01<00:47, 104MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|███▊| 157M/167M [00:01<00:00, 106MB/s]
# Downloading (…)del.fp16.safetensors:  94%|███▊| 157M/167M [00:01<00:00, 108MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 102MB/s]
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 100MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|   | 178M/5.14G [00:01<00:45, 108MB/s]
#
#
# Downloading model.fp16.safetensors:  16%|▋   | 220M/1.39G [00:02<00:11, 104MB/s]
#
# Downloading model.fp16.safetensors:  89%|████▍| 220M/246M [00:02<00:00, 110MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 199M/5.14G [00:01<00:40, 123MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▋   | 241M/1.39G [00:02<00:09, 117MB/s]
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 110MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:10,  1.40it/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|▏  | 220M/5.14G [00:02<00:37, 132MB/s]
#
#
# Downloading model.fp16.safetensors:  20%|▊   | 273M/1.39G [00:02<00:07, 143MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 241M/5.14G [00:02<00:33, 145MB/s]
#
#
# Downloading model.fp16.safetensors:  22%|▉   | 304M/1.39G [00:02<00:06, 165MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 262M/5.14G [00:02<00:31, 154MB/s]
#
#
# Downloading model.fp16.safetensors:  24%|▉   | 336M/1.39G [00:02<00:05, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 283M/5.14G [00:02<00:30, 162MB/s]
#
#
# Downloading model.fp16.safetensors:  26%|█   | 367M/1.39G [00:02<00:05, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 304M/5.14G [00:02<00:28, 169MB/s]
#
#
# Downloading model.fp16.safetensors:  29%|█▏  | 398M/1.39G [00:02<00:04, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 325M/5.14G [00:02<00:27, 173MB/s]
#
#
# Downloading model.fp16.safetensors:  30%|█▏  | 419M/1.39G [00:02<00:04, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 346M/5.14G [00:02<00:27, 174MB/s]
#
#
# Downloading model.fp16.safetensors:  32%|█▎  | 440M/1.39G [00:03<00:04, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 367M/5.14G [00:02<00:28, 170MB/s]
#
#
# Downloading model.fp16.safetensors:  33%|█▎  | 461M/1.39G [00:03<00:05, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 388M/5.14G [00:03<00:29, 160MB/s]
#
#
# Downloading model.fp16.safetensors:  35%|█▍  | 482M/1.39G [00:03<00:04, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 409M/5.14G [00:03<00:28, 167MB/s]
#
#
# Downloading model.fp16.safetensors:  36%|█▍  | 503M/1.39G [00:03<00:04, 188MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▎  | 430M/5.14G [00:03<00:27, 174MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▌  | 535M/1.39G [00:03<00:04, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 451M/5.14G [00:03<00:26, 176MB/s]
#
#
# Downloading model.fp16.safetensors:  40%|█▌  | 556M/1.39G [00:03<00:04, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 472M/5.14G [00:03<00:27, 168MB/s]
#
#
# Downloading model.fp16.safetensors:  42%|█▋  | 577M/1.39G [00:03<00:04, 171MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 493M/5.14G [00:03<00:29, 158MB/s]
#
#
# Downloading model.fp16.safetensors:  43%|█▋  | 598M/1.39G [00:03<00:04, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 514M/5.14G [00:03<00:30, 152MB/s]
#
#
# Downloading model.fp16.safetensors:  45%|█▊  | 619M/1.39G [00:04<00:04, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 535M/5.14G [00:03<00:29, 156MB/s]
#
#
# Downloading model.fp16.safetensors:  46%|█▊  | 640M/1.39G [00:04<00:04, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 556M/5.14G [00:04<00:29, 157MB/s]
#
#
# Downloading model.fp16.safetensors:  48%|█▉  | 661M/1.39G [00:04<00:04, 165MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 577M/5.14G [00:04<00:28, 159MB/s]
#
#
# Downloading model.fp16.safetensors:  49%|█▉  | 682M/1.39G [00:04<00:04, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 598M/5.14G [00:04<00:28, 159MB/s]
#
#
# Downloading model.fp16.safetensors:  51%|██  | 703M/1.39G [00:04<00:04, 168MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 619M/5.14G [00:04<00:28, 160MB/s]
#
#
# Downloading model.fp16.safetensors:  52%|██  | 724M/1.39G [00:04<00:04, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 640M/5.14G [00:04<00:28, 158MB/s]
#
#
# Downloading model.fp16.safetensors:  54%|██▏ | 744M/1.39G [00:04<00:04, 160MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 661M/5.14G [00:04<00:30, 149MB/s]
#
#
# Downloading model.fp16.safetensors:  55%|██▏ | 765M/1.39G [00:05<00:03, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 682M/5.14G [00:04<00:29, 151MB/s]
#
#
# Downloading model.fp16.safetensors:  57%|██▎ | 786M/1.39G [00:05<00:03, 163MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 703M/5.14G [00:04<00:28, 155MB/s]
#
#
# Downloading model.fp16.safetensors:  58%|██▎ | 807M/1.39G [00:05<00:03, 170MB/s]
#
#
# Downloading model.fp16.safetensors:  60%|██▍ | 828M/1.39G [00:05<00:03, 169MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 724M/5.14G [00:05<00:30, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  61%|██▍ | 849M/1.39G [00:05<00:03, 175MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 744M/5.14G [00:05<00:30, 144MB/s]
#
#
# Downloading model.fp16.safetensors:  63%|██▌ | 870M/1.39G [00:05<00:03, 160MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 765M/5.14G [00:05<00:29, 148MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|██▌ | 891M/1.39G [00:05<00:03, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 786M/5.14G [00:05<00:29, 149MB/s]
#
#
# Downloading model.fp16.safetensors:  66%|██▋ | 912M/1.39G [00:05<00:02, 163MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 807M/5.14G [00:05<00:31, 139MB/s]
#
#
# Downloading model.fp16.safetensors:  67%|██▋ | 933M/1.39G [00:06<00:02, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 828M/5.14G [00:05<00:30, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  69%|██▋ | 954M/1.39G [00:06<00:02, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▍  | 849M/5.14G [00:06<00:31, 136MB/s]
#
#
# Downloading model.fp16.safetensors:  70%|██▊ | 975M/1.39G [00:06<00:02, 159MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 870M/5.14G [00:06<00:29, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|██▊ | 996M/1.39G [00:06<00:02, 155MB/s]
#
#
# Downloading model.fp16.safetensors:  73%|██▏| 1.02G/1.39G [00:06<00:02, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 891M/5.14G [00:06<00:30, 140MB/s]
#
#
# Downloading model.fp16.safetensors:  75%|██▏| 1.04G/1.39G [00:06<00:02, 160MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 912M/5.14G [00:06<00:30, 140MB/s]
#
#
# Downloading model.fp16.safetensors:  76%|██▎| 1.06G/1.39G [00:06<00:02, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 933M/5.14G [00:06<00:29, 140MB/s]
#
#
# Downloading model.fp16.safetensors:  78%|██▎| 1.08G/1.39G [00:06<00:01, 157MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 954M/5.14G [00:06<00:31, 134MB/s]
#
#
# Downloading model.fp16.safetensors:  79%|██▍| 1.10G/1.39G [00:07<00:01, 159MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 975M/5.14G [00:06<00:31, 130MB/s]
#
#
# Downloading model.fp16.safetensors:  81%|██▍| 1.12G/1.39G [00:07<00:01, 156MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 996M/5.14G [00:07<00:32, 128MB/s]
#
#
# Downloading model.fp16.safetensors:  82%|██▍| 1.14G/1.39G [00:07<00:01, 144MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.02G/5.14G [00:07<00:33, 123MB/s]
#
#
# Downloading model.fp16.safetensors:  84%|██▌| 1.16G/1.39G [00:07<00:01, 128MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.04G/5.14G [00:07<00:34, 117MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|██▌| 1.18G/1.39G [00:07<00:01, 127MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.06G/5.14G [00:07<00:37, 109MB/s]
#
#
# Downloading model.fp16.safetensors:  87%|██▌| 1.21G/1.39G [00:08<00:01, 115MB/s]
#
#
# Downloading model.fp16.safetensors:  88%|██▋| 1.23G/1.39G [00:08<00:01, 121MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.08G/5.14G [00:07<00:37, 107MB/s]
#
#
# Downloading model.fp16.safetensors:  90%|██▋| 1.25G/1.39G [00:08<00:01, 134MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.10G/5.14G [00:08<00:33, 119MB/s]
#
#
# Downloading model.fp16.safetensors:  92%|██▊| 1.28G/1.39G [00:08<00:00, 158MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.12G/5.14G [00:08<00:30, 130MB/s]
#
#
# Downloading model.fp16.safetensors:  94%|██▊| 1.31G/1.39G [00:08<00:00, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.14G/5.14G [00:08<00:29, 134MB/s]
#
#
# Downloading model.fp16.safetensors:  97%|██▉| 1.34G/1.39G [00:08<00:00, 188MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.16G/5.14G [00:08<00:27, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  99%|██▉| 1.37G/1.39G [00:08<00:00, 199MB/s]
#
#
#
# Downloading model.fp16.safetensors: 100%|███| 1.39G/1.39G [00:08<00:00, 155MB/s]
# Fetching 19 files:  32%|███████▉                 | 6/19 [00:09<00:24,  1.92s/it]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.21G/5.14G [00:08<00:27, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.23G/5.14G [00:08<00:27, 142MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.25G/5.14G [00:09<00:28, 139MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.27G/5.14G [00:09<00:27, 138MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 1.29G/5.14G [00:09<00:27, 138MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.31G/5.14G [00:09<00:27, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.33G/5.14G [00:09<00:26, 145MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.35G/5.14G [00:09<00:25, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.37G/5.14G [00:09<00:24, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.39G/5.14G [00:10<00:24, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.42G/5.14G [00:10<00:23, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.44G/5.14G [00:10<00:23, 156MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.46G/5.14G [00:10<00:23, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.48G/5.14G [00:10<00:24, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.50G/5.14G [00:10<00:24, 147MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.52G/5.14G [00:10<00:24, 146MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.54G/5.14G [00:11<00:25, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.56G/5.14G [00:11<00:26, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.58G/5.14G [00:11<00:26, 133MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.60G/5.14G [00:11<00:27, 131MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:
B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.77G/5.14G [00:35<00:01, 199MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.79G/5.14G [00:35<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.81G/5.14G [00:36<00:01, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.83G/5.14G [00:36<00:01, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.85G/5.14G [00:36<00:01, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.88G/5.14G [00:36<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.90G/5.14G [00:36<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.92G/5.14G [00:36<00:01, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.94G/5.14G [00:36<00:00, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.96G/5.14G [00:36<00:00, 199MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.98G/5.14G [00:36<00:00, 200MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 5.00G/5.14G [00:37<00:00, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.02G/5.14G [00:37<00:00, 202MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.04G/5.14G [00:37<00:00, 202MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.06G/5.14G [00:37<00:00, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.09G/5.14G [00:37<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.11G/5.14G [00:37<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:37<00:00, 136MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:38<00:00,  2.01s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.66it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:43<00:00,  1.15it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.33it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.68it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.04it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.94it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:49<00:00,  1.02it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.41it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.02it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.34it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.03it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.49it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.22it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.03it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.34it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.81it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
