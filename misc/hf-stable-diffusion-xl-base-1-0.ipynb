# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# # Version 3

# prompts: list = [
#     "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
#     "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
#     "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
#     "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
#     "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
#     "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
#     "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
#     "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
#     "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
#     "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
# ]

# %%
# Version 4

prompts: list = [
    "A city at night, dark sky, people watching in wonder, very detailed, 8k, concept art",
    "A city at night big moon and stars at the borders, concept art, dark, creepy, atmospheric, 8k, HD",
    "A city at night, small lamp posts, burning church, street lamps, 4 k, concept art, sparse vegetation",
    "A city at night, low green clouds, dark red sky, night, 4k, high details, fireflies, art by WLOP,",
    "A city at night, dark moonlight, sky full of stars at the edges, concept art, 4k, octane render, digital painting,",
    "A city at night, big moon on the right, meteor fall, trending on artstation, 8k, cinematic, soft, sharp focus, insanely",
    "A city at night, huge moon, stars at the horizon, 4k, 8k, trending on Artstation",
    "A city at night during a nuclear eruption, intricate Asteroid belt with huge rings in the sky, water and beautiful pink blobs, flying cars,",
    "A city at night with cumulonimbus clouds in the sky, night colors, stars in the sky, painting by tyler edlin,",
    "A city at night, moonlight, street lamps, falling leaves, wide angle, super highly detailed, professional digital painting, artstation, concept art",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.95MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 3.23MB/s]
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 3.25MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:02,  7.16it/s]
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.82MB/s]
#
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 4.71MB/s]
#
#
#
# Downloading model.fp16.safetensors:   0%|           | 0.00/1.39G [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.91MB/s]
#
#
#
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 4.22MB/s]
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 2.61MB/s]
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 4.59MB/s]
#
#
#
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 7.97MB/s]
#
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:05, 39.8MB/s]
# Downloading (…)1d8/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 8.07MB/s]
#
#
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:36, 37.3MB/s]
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
#
#
#
# Downloading (…)81d8/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 3.76MB/s]
#
#
#
#
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
# Downloading model.fp16.safetensors:   9%|▎  | 21.0M/246M [00:00<00:04, 48.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 69.0MB/s]
#
#
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 5.54MB/s]
#
#
#
# Downloading model.fp16.safetensors:   2%|  | 21.0M/1.39G [00:00<00:32, 41.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 70.3MB/s]
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<02:07, 40.3MB/s]
#
# Downloading model.fp16.safetensors:  13%|▍  | 31.5M/246M [00:00<00:04, 51.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 82.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 61.0MB/s]
# Downloading (…)del.fp16.safetensors:   1%| | 31.5M/5.14G [00:00<01:05, 77.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▍ | 31.5M/167M [00:00<00:01, 84.1MB/s]
#
#
# Downloading model.fp16.safetensors:   2%|  | 31.5M/1.39G [00:00<00:32, 42.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▍ | 31.5M/167M [00:00<00:02, 64.5MB/s]
#
# Downloading model.fp16.safetensors:  17%|▌  | 41.9M/246M [00:00<00:04, 49.6MB/s]
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<01:05, 77.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 79.5MB/s]
#
#
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:28, 46.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 67.1MB/s]
# Downloading (…)del.fp16.safetensors:   1%| | 52.4M/5.14G [00:00<01:03, 80.0MB/s]
#
# Downloading model.fp16.safetensors:  21%|▋  | 52.4M/246M [00:01<00:03, 50.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 74.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 71.6MB/s]
# Downloading (…)del.fp16.safetensors:   1%| | 62.9M/5.14G [00:00<01:02, 80.7MB/s]
#
#
# Downloading model.fp16.safetensors:   4%|  | 52.4M/1.39G [00:01<00:27, 48.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 74.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 75.2MB/s]
# Downloading (…)del.fp16.safetensors:   1%| | 73.4M/5.14G [00:00<01:01, 82.1MB/s]
#
# Downloading model.fp16.safetensors:  26%|▊  | 62.9M/246M [00:01<00:03, 48.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:00<00:01, 79.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:01<00:01, 78.8MB/s]
# Downloading (…)del.fp16.safetensors:   2%| | 83.9M/5.14G [00:01<00:59, 84.3MB/s]
#
#
# Downloading model.fp16.safetensors:   5%|  | 62.9M/1.39G [00:01<00:28, 47.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 83.9M/167M [00:01<00:01, 80.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 83.9M/167M [00:01<00:01, 79.8MB/s]
#
# Downloading model.fp16.safetensors:  30%|▉  | 73.4M/246M [00:01<00:03, 48.5MB/s]
# Downloading (…)del.fp16.safetensors:   2%| | 94.4M/5.14G [00:01<01:01, 82.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█▏| 94.4M/167M [00:01<00:00, 80.2MB/s]
# Downloading (…)del.fp16.safetensors:   2%|  | 105M/5.14G [00:01<00:58, 86.2MB/s]
#
#
# Downloading model.fp16.safetensors:   5%|  | 73.4M/1.39G [00:01<00:28, 46.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█▏| 94.4M/167M [00:01<00:00, 77.1MB/s]
#
# Downloading model.fp16.safetensors:  34%|█  | 83.9M/246M [00:01<00:03, 51.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 81.8MB/s]
# Downloading (…)del.fp16.safetensors:   2%|  | 115M/5.14G [00:01<00:59, 84.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 80.7MB/s]
#
#
# Downloading model.fp16.safetensors:   6%|  | 83.9M/1.39G [00:01<00:26, 49.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|██ | 115M/167M [00:01<00:00, 79.9MB/s]
# Downloading (…)del.fp16.safetensors:   2%|  | 126M/5.14G [00:01<00:57, 86.7MB/s]
#
# Downloading model.fp16.safetensors:  38%|█▏ | 94.4M/246M [00:01<00:02, 51.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|██ | 115M/167M [00:01<00:00, 79.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 79.8MB/s]
# Downloading (…)del.fp16.safetensors:   3%|  | 136M/5.14G [00:01<00:57, 86.6MB/s]
#
#
# Downloading model.fp16.safetensors:   7%|▏ | 94.4M/1.39G [00:01<00:25, 51.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 80.8MB/s]
#
# Downloading model.fp16.safetensors:  43%|█▋  | 105M/246M [00:02<00:02, 51.7MB/s]
# Downloading (…)del.fp16.safetensors:   3%|  | 147M/5.14G [00:01<00:57, 86.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|██▍| 136M/167M [00:01<00:00, 78.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|██▍| 136M/167M [00:01<00:00, 80.1MB/s]
#
#
# Downloading model.fp16.safetensors:   8%|▏  | 105M/1.39G [00:02<00:25, 50.3MB/s]
# Downloading (…)del.fp16.safetensors:   3%|  | 157M/5.14G [00:01<00:57, 86.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 75.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 82.6MB/s]
#
# Downloading model.fp16.safetensors:  47%|█▊  | 115M/246M [00:02<00:02, 51.9MB/s]
# Downloading (…)del.fp16.safetensors:   3%|  | 168M/5.14G [00:02<00:56, 87.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|██▊| 157M/167M [00:02<00:00, 82.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|██▊| 157M/167M [00:02<00:00, 76.0MB/s]
#
#
# Downloading model.fp16.safetensors:   8%|▏  | 115M/1.39G [00:02<00:25, 49.5MB/s]
#
# Downloading model.fp16.safetensors:  51%|██  | 126M/246M [00:02<00:02, 54.0MB/s]
# Downloading (…)del.fp16.safetensors:   3%|  | 178M/5.14G [00:02<00:57, 86.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:02<00:00, 82.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:02<00:00, 78.0MB/s]
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:02<00:00, 76.6MB/s]
#
# Downloading (…)del.fp16.safetensors:   4%|  | 189M/5.14G [00:02<00:58, 85.3MB/s]
#
# Downloading model.fp16.safetensors:  55%|██▏ | 136M/246M [00:02<00:02, 54.6MB/s]
#
#
# Downloading model.fp16.safetensors:   9%|▎  | 126M/1.39G [00:02<00:27, 46.0MB/s]
# Downloading (…)del.fp16.safetensors:   4%|  | 199M/5.14G [00:02<00:57, 86.0MB/s]
#
# Downloading model.fp16.safetensors:  60%|██▍ | 147M/246M [00:02<00:01, 55.2MB/s]
# Downloading (…)del.fp16.safetensors:   4%|  | 210M/5.14G [00:02<00:59, 83.5MB/s]
#
#
# Downloading model.fp16.safetensors:  10%|▎  | 136M/1.39G [00:02<00:27, 45.6MB/s]
# Downloading (…)del.fp16.safetensors:   4%|  | 220M/5.14G [00:02<01:01, 80.1MB/s]
#
# Downloading model.fp16.safetensors:  64%|██▌ | 157M/246M [00:03<00:01, 54.1MB/s]
# Downloading (…)del.fp16.safetensors:   4%|  | 231M/5.14G [00:02<01:03, 77.2MB/s]
#
# Downloading model.fp16.safetensors:  68%|██▋ | 168M/246M [00:03<00:01, 57.0MB/s]
#
#
# Downloading model.fp16.safetensors:  11%|▎  | 147M/1.39G [00:03<00:29, 41.8MB/s]
# Downloading (…)del.fp16.safetensors:   5%|  | 241M/5.14G [00:02<01:00, 80.5MB/s]
# Downloading (…)del.fp16.safetensors:   5%|  | 252M/5.14G [00:03<00:58, 83.1MB/s]
#
# Downloading model.fp16.safetensors:  72%|██▉ | 178M/246M [00:03<00:01, 55.0MB/s]
#
#
# Downloading model.fp16.safetensors:  11%|▎  | 157M/1.39G [00:03<00:27, 44.7MB/s]
# Downloading (…)del.fp16.safetensors:   5%|  | 262M/5.14G [00:03<00:57, 84.3MB/s]
#
# Downloading model.fp16.safetensors:  77%|███ | 189M/246M [00:03<00:01, 55.8MB/s]
# Downloading (…)del.fp16.safetensors:   5%|  | 273M/5.14G [00:03<00:59, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors:  12%|▎  | 168M/1.39G [00:03<00:28, 43.5MB/s]
# Downloading (…)del.fp16.safetensors:   6%|  | 283M/5.14G [00:03<00:58, 83.0MB/s]
#
# Downloading model.fp16.safetensors:  81%|███▏| 199M/246M [00:03<00:00, 54.0MB/s]
# Downloading (…)del.fp16.safetensors:   6%|  | 294M/5.14G [00:03<00:58, 82.3MB/s]
#
#
# Downloading model.fp16.safetensors:  13%|▍  | 178M/1.39G [00:03<00:26, 45.1MB/s]
#
# Downloading model.fp16.safetensors:  85%|███▍| 210M/246M [00:03<00:00, 54.9MB/s]
# Downloading (…)del.fp16.safetensors:   6%|  | 304M/5.14G [00:03<01:00, 79.4MB/s]
#
# Downloading model.fp16.safetensors:  89%|███▌| 220M/246M [00:04<00:00, 57.9MB/s]
# Downloading (…)del.fp16.safetensors:   6%|  | 315M/5.14G [00:03<01:00, 79.5MB/s]
#
#
# Downloading model.fp16.safetensors:  14%|▍  | 189M/1.39G [00:04<00:29, 41.1MB/s]
# Downloading (…)del.fp16.safetensors:   6%|▏ | 325M/5.14G [00:03<00:58, 82.2MB/s]
#
# Downloading model.fp16.safetensors:  94%|███▋| 231M/246M [00:04<00:00, 54.3MB/s]
# Downloading (…)del.fp16.safetensors:   7%|▏ | 336M/5.14G [00:04<00:58, 82.4MB/s]
#
#
# Downloading model.fp16.safetensors:  14%|▍  | 199M/1.39G [00:04<00:27, 43.4MB/s]
#
# Downloading model.fp16.safetensors:  98%|███▉| 241M/246M [00:04<00:00, 55.1MB/s]
# Downloading (…)del.fp16.safetensors:   7%|▏ | 346M/5.14G [00:04<00:58, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|████| 246M/246M [00:04<00:00, 53.2MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:04<00:21,  1.42s/it]
# Downloading (…)del.fp16.safetensors:   7%|▏ | 357M/5.14G [00:04<00:59, 80.2MB/s]
# Downloading (…)del.fp16.safetensors:   7%|▏ | 367M/5.14G [00:04<00:58, 81.7MB/s]
#
#
# Downloading model.fp16.safetensors:  16%|▍  | 220M/1.39G [00:04<00:24, 47.1MB/s]
# Downloading (…)del.fp16.safetensors:   7%|▏ | 377M/5.14G [00:04<00:57, 83.0MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▍  | 231M/1.39G [00:04<00:22, 51.1MB/s]
# Downloading (…)del.fp16.safetensors:   8%|▏ | 388M/5.14G [00:04<00:58, 81.8MB/s]
# Downloading (…)del.fp16.safetensors:   8%|▏ | 398M/5.14G [00:04<00:56, 83.5MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▌  | 241M/1.39G [00:05<00:23, 49.6MB/s]
# Downloading (…)del.fp16.safetensors:   8%|▏ | 409M/5.14G [00:04<00:57, 82.3MB/s]
#
#
# Downloading model.fp16.safetensors:  18%|▌  | 252M/1.39G [00:05<00:21, 51.8MB/s]
# Downloading (…)del.fp16.safetensors:   8%|▏ | 419M/5.14G [00:05<00:57, 82.4MB/s]
# Downloading (…)del.fp16.safetensors:   8%|▏ | 430M/5.14G [00:05<00:56, 82.7MB/s]
#
#
# Downloading model.fp16.safetensors:  19%|▌  | 262M/1.39G [00:05<00:22, 51.1MB/s]
# Downloading (…)del.fp16.safetensors:   9%|▏ | 440M/5.14G [00:05<00:59, 78.9MB/s]
#
#
# Downloading model.fp16.safetensors:  20%|▌  | 273M/1.39G [00:05<00:20, 53.8MB/s]
# Downloading (…)del.fp16.safetensors:   9%|▏ | 451M/5.14G [00:05<00:58, 80.7MB/s]
# Downloading (…)del.fp16.safetensors:   9%|▏ | 461M/5.14G [00:05<00:56, 82.5MB/s]
#
#
# Downloading model.fp16.safetensors:  20%|▌  | 283M/1.39G [00:05<00:19, 55.5MB/s]
# Downloading (…)del.fp16.safetensors:   9%|▏ | 472M/5.14G [00:05<00:55, 83.4MB/s]
#
#
# Downloading model.fp16.safetensors:  21%|▋  | 294M/1.39G [00:06<00:20, 53.5MB/s]
# Downloading (…)del.fp16.safetensors:   9%|▏ | 482M/5.14G [00:05<00:59, 78.0MB/s]
# Downloading (…)del.fp16.safetensors:  10%|▏ | 493M/5.14G [00:06<00:58, 79.5MB/s]
#
#
# Downloading model.fp16.safetensors:  22%|▋  | 304M/1.39G [00:06<00:20, 53.5MB/s]
# Downloading (…)del.fp16.safetensors:  10%|▏ | 503M/5.14G [00:06<00:56, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors:  23%|▋  | 315M/1.39G [00:06<00:19, 54.6MB/s]
# Downloading (…)del.fp16.safetensors:  10%|▏ | 514M/5.14G [00:06<00:55, 82.6MB/s]
# Downloading (…)del.fp16.safetensors:  10%|▏ | 524M/5.14G [00:06<00:54, 84.3MB/s]
#
#
# Downloading model.fp16.safetensors:  23%|▋  | 325M/1.39G [00:06<00:19, 55.5MB/s]
# Downloading (…)del.fp16.safetensors:  10%|▏ | 535M/5.14G [00:06<00:55, 83.2MB/s]
#
#
# Downloading model.fp16.safetensors:  24%|▋  | 336M/1.39G [00:06<00:19, 54.7MB/s]
# Downloading (…)del.fp16.safetensors:  11%|▏ | 545M/5.14G [00:06<00:54, 84.5MB/s]
# Downloading (…)del.fp16.safetensors:  11%|▏ | 556M/5.14G [00:06<00:54, 83.3MB/s]
#
#
# Downloading model.fp16.safetensors:  25%|▋  | 346M/1.39G [00:07<00:19, 53.2MB/s]
# Downloading (…)del.fp16.safetensors:  11%|▏ | 566M/5.14G [00:06<00:53, 84.8MB/s]
#
#
# Downloading model.fp16.safetensors:  26%|▊  | 357M/1.39G [00:07<00:18, 55.8MB/s]
# Downloading (…)del.fp16.safetensors:  11%|▏ | 577M/5.14G [00:07<00:54, 83.5MB/s]
# Downloading (…)del.fp16.safetensors:  11%|▏ | 587M/5.14G [00:07<00:54, 83.3MB/s]
#
#
# Downloading model.fp16.safetensors:  26%|▊  | 367M/1.39G [00:07<00:17, 57.6MB/s]
# Downloading (…)del.fp16.safetensors:  12%|▏ | 598M/5.14G [00:07<00:55, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors:  27%|▊  | 377M/1.39G [00:07<00:17, 56.5MB/s]
# Downloading (…)del.fp16.safetensors:  12%|▏ | 608M/5.14G [00:07<00:58, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  12%|▏ | 619M/5.14G [00:07<00:57, 78.1MB/s]
#
#
# Downloading model.fp16.safetensors:  28%|▊  | 388M/1.39G [00:07<00:18, 53.0MB/s]
# Downloading (…)del.fp16.safetensors:  12%|▏ | 629M/5.14G [00:07<00:56, 79.2MB/s]
#
#
# Downloading model.fp16.safetensors:  29%|▊  | 398M/1.39G [00:08<00:17, 56.2MB/s]
# Downloading (…)del.fp16.safetensors:  12%|▏ | 640M/5.14G [00:07<01:01, 73.3MB/s]
#
#
# Downloading model.fp16.safetensors:  29%|▉  | 409M/1.39G [00:08<00:19, 49.9MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 650M/5.14G [00:08<01:01, 72.4MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 661M/5.14G [00:08<01:00, 73.9MB/s]
#
#
# Downloading model.fp16.safetensors:  30%|▉  | 419M/1.39G [00:08<00:18, 52.3MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 671M/5.14G [00:08<01:01, 72.1MB/s]
#
#
# Downloading model.fp16.safetensors:  31%|▉  | 430M/1.39G [00:08<00:18, 52.7MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 682M/5.14G [00:08<01:00, 74.0MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 692M/5.14G [00:08<00:58, 75.9MB/s]
#
#
# Downloading model.fp16.safetensors:  32%|▉  | 440M/1.39G [00:08<00:19, 48.5MB/s]
# Downloading (…)del.fp16.safetensors:  14%|▎ | 703M/5.14G [00:08<00:57, 77.0MB/s]
# Downloading (…)del.fp16.safetensors:  14%|▎ | 713M/5.14G [00:08<00:56, 78.6MB/s]
#
#
# Downloading model.fp16.safetensors:  32%|▉  | 451M/1.39G [00:09<00:20, 45.6MB/s]
# Downloading (…)del.fp16.safetensors:  14%|▎ | 724M/5.14G [00:08<00:57, 76.7MB/s]
# Downloading (…)del.fp16.safetensors:  14%|▎ | 734M/5.14G [00:09<00:55, 79.3MB/s]
#
#
# Downloading model.fp16.safetensors:  33%|▉  | 461M/1.39G [00:09<00:19, 46.5MB/s]
# Downloading (…)del.fp16.safetensors:  14%|▎ | 744M/5.14G [00:09<00:53, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors:  34%|█  | 472M/1.39G [00:09<00:18, 49.1MB/s]
# Downloading (…)del.fp16.safetensors:  15%|▎ | 755M/5.14G [00:09<00:52, 83.5MB/s]
# Downloading (…)del.fp16.safetensors:  15%|▎ | 765M/5.14G [00:09<00:53, 81.3MB/s]
#
#
# Downloading model.fp16.safetensors:  35%|█  | 482M/1.39G [00:09<00:18, 49.0MB/s]
# Downloading (…)del.fp16.safetensors:  15%|▎ | 776M/5.14G [00:09<00:55, 78.7MB/s]
#
#
# Downloading model.fp16.safetensors:  35%|█  | 493M/1.39G [00:09<00:17, 51.4MB/s]
# Downloading (…)del.fp16.safetensors:  15%|▎ | 786M/5.14G [00:09<00:59, 73.0MB/s]
#
#
# Downloading model.fp16.safetensors:  36%|█  | 503M/1.39G [00:10<00:16, 52.8MB/s]
# Downloading (…)del.fp16.safetensors:  16%|▎ | 797M/5.14G [00:09<00:57, 75.5MB/s]
# Downloading (…)del.fp16.safetensors:  16%|▎ | 807M/5.14G [00:10<00:54, 79.8MB/s]
#
#
# Downloading model.fp16.safetensors:  37%|█  | 514M/1.39G [00:10<00:16, 51.6MB/s]
# Downloading (…)del.fp16.safetensors:  16%|▎ | 818M/5.14G [00:10<00:53, 81.2MB/s]
# Downloading (…)del.fp16.safetensors:  16%|▎ | 828M/5.14G [00:10<00:52, 81.5MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▏ | 524M/1.39G [00:10<00:17, 49.3MB/s]
# Downloading (…)del.fp16.safetensors:  16%|▎ | 839M/5.14G [00:10<00:54, 79.0MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▏ | 535M/1.39G [00:10<00:16, 50.8MB/s]
# Downloading (…)del.fp16.safetensors:  17%|▎ | 849M/5.14G [00:10<00:54, 78.2MB/s]
# Downloading (…)del.fp16.safetensors:  17%|▎ | 860M/5.14G [00:10<00:56, 75.6MB/s]
#
#
# Downloading model.fp16.safetensors:  39%|█▏ | 545M/1.39G [00:11<00:18, 46.2MB/s]
# Downloading (…)del.fp16.safetensors:  17%|▎ | 870M/5.14G [00:10<00:56, 75.5MB/s]
#
#
# Downloading model.fp16.safetensors:  40%|█▏ | 556M/1.39G [00:11<00:16, 50.5MB/s]
# Downloading (…)del.fp16.safetensors:  17%|▎ | 881M/5.14G [00:10<00:55, 76.7MB/s]
# Downloading (…)del.fp16.safetensors:  17%|▎ | 891M/5.14G [00:11<00:55, 76.1MB/s]
#
#
# Downloading model.fp16.safetensors:  41%|█▏ | 566M/1.39G [00:11<00:16, 49.1MB/s]
# Downloading (…)del.fp16.safetensors:  18%|▎ | 902M/5.14G [00:11<00:54, 77.2MB/s]
#
#
# Downloading model.fp16.safetensors:  42%|█▏ | 577M/1.39G [00:11<00:17, 47.2MB/s]
# Downloading (…)del.fp16.safetensors:  18%|▎ | 912M/5.14G [00:11<01:09, 61.1MB/s]
# Downloading (…)del.fp16.safetensors:  18%|▎ | 923M/5.14G [00:11<01:03, 66.1MB/s]
#
#
# Downloading model.fp16.safetensors:  42%|█▎ | 587M/1.39G [00:11<00:16, 47.7MB/s]
# Downloading (…)del.fp16.safetensors:  18%|▎ | 933M/5.14G [00:11<00:59, 70.7MB/s]
#
#
# Downloading model.fp16.safetensors:  43%|█▎ | 598M/1.39G [00:12<00:18, 43.7MB/s]
# Downloading (…)del.fp16.safetensors:  18%|▎ | 944M/5.14G [00:12<01:15, 55.2MB/s]
#
#
# Downloading model.fp16.safetensors:  44%|█▎ | 608M/1.39G [00:12<00:16, 47.0MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▍ | 965M/5.14G [00:12<01:00, 68.9MB/s]
#
#
# Downloading model.fp16.safetensors:  45%|█▎ | 619M/1.39G [00:12<00:15, 50.9MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▍ | 975M/5.14G [00:12<01:02, 66.9MB/s]
#
#
# Downloading model.fp16.safetensors:  45%|█▎ | 629M/1.39G [00:12<00:14, 50.7MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▍ | 986M/5.14G [00:12<01:02, 65.9MB/s]
#
#
# Downloading model.fp16.safetensors:  46%|█▍ | 640M/1.39G [00:12<00:14, 50.7MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▍ | 996M/5.14G [00:12<00:59, 69.3MB/s]
# Downloading (…)del.fp16.safetensors:  20%|▏| 1.01G/5.14G [00:12<00:57, 71.9MB/s]
#
#
# Downloading model.fp16.safetensors:  47%|█▍ | 650M/1.39G [00:13<00:15, 46.4MB/s]
# Downloading (…)del.fp16.safetensors:  20%|▏| 1.02G/5.14G [00:12<00:55, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  20%|▏| 1.03G/5.14G [00:13<00:55, 74.6MB/s]
#
#
# Downloading model.fp16.safetensors:  48%|█▍ | 661M/1.39G [00:13<00:16, 45.1MB/s]
# Downloading (…)del.fp16.safetensors:  20%|▏| 1.04G/5.14G [00:13<00:55, 74.2MB/s]
# Downloading (…)del.fp16.safetensors:  20%|▏| 1.05G/5.14G [00:13<00:56, 72.9MB/s]
#
#
# Downloading model.fp16.safetensors:  48%|█▍ | 671M/1.39G [00:13<00:16, 44.2MB/s]
# Downloading (…)del.fp16.safetensors:  21%|▏| 1.06G/5.14G [00:13<00:59, 68.3MB/s]
#
#
# Downloading model.fp16.safetensors:  49%|█▍ | 682M/1.39G [00:13<00:15, 46.0MB/s]
# Downloading (…)del.fp16.safetensors:  21%|▏| 1.07G/5.14G [00:13<00:57, 71.0MB/s]
# Downloading (…)del.fp16.safetensors:  21%|▏| 1.08G/5.14G [00:13<00:55, 72.5MB/s]
#
#
# Downloading model.fp16.safetensors:  50%|█▍ | 692M/1.39G [00:14<00:16, 42.2MB/s]
# Downloading (…)del.fp16.safetensors:  21%|▏| 1.09G/5.14G [00:13<00:53, 75.7MB/s]
# Downloading (…)del.fp16.safetensors:  21%|▏| 1.10G/5.14G [00:14<00:50, 79.2MB/s]
#
#
# Downloading model.fp16.safetensors:  51%|█▌ | 703M/1.39G [00:14<00:15, 44.8MB/s]
# Downloading (…)del.fp16.safetensors:  22%|▏| 1.11G/5.14G [00:14<00:50, 79.6MB/s]
#
#
# Downloading model.fp16.safetensors:  51%|█▌ | 713M/1.39G [00:14<00:14, 47.5MB/s]
# Downloading (…)del.fp16.safetensors:  22%|▏| 1.12G/5.14G [00:14<00:49, 80.7MB/s]
# Downloading (…)del.fp16.safetensors:  22%|▏| 1.13G/5.14G [00:14<00:48, 82.2MB/s]
#
#
# Downloading model.fp16.safetensors:  52%|█▌ | 724M/1.39G [00:14<00:13, 49.0MB/s]
# Downloading (…)del.fp16.safetensors:  22%|▏| 1.14G/5.14G [00:14<00:56, 70.6MB/s]
#
#
# Downloading model.fp16.safetensors:  53%|█▌ | 734M/1.39G [00:15<00:13, 47.5MB/s]
# Downloading (…)del.fp16.safetensors:  22%|▏| 1.15G/5.14G [00:14<00:53, 74.2MB/s]
# Downloading (…)del.fp16.safetensors:  23%|▏| 1.16G/5.14G [00:14<00:52, 75.8MB/s]
# Downloading (…)del.fp16.safetensors:  23%|▏| 1.17G/5.14G [00:15<00:51, 77.0MB/s]
#
#
# Downloading model.fp16.safetensors:  54%|█▌ | 744M/1.39G [00:15<00:15, 42.4MB/s]
# Downloading (…)del.fp16.safetensors:  23%|▏| 1.18G/5.14G [00:15<00:50, 77.7MB/s]
#
#
# Downloading model.fp16.safetensors:  54%|█▋ | 755M/1.39G [00:15<00:13, 47.4MB/s]
# Downloading (…)del.fp16.safetensors:  23%|▏| 1.20G/5.14G [00:15<00:49, 78.8MB/s]
# Downloading (…)del.fp16.safetensors:  23%|▏| 1.21G/5.14G [00:15<00:49, 79.3MB/s]
#
#
# Downloading model.fp16.safetensors:  55%|█▋ | 765M/1.39G [00:15<00:12, 48.2MB/s]
# Downloading (…)del.fp16.safetensors:  24%|▏| 1.22G/5.14G [00:15<00:49, 79.9MB/s]
#
#
# Downloading model.fp16.safetensors:  56%|█▋ | 776M/1.39G [00:15<00:12, 48.7MB/s]
# Downloading (…)del.fp16.safetensors:  24%|▏| 1.23G/5.14G [00:15<00:58, 67.0MB/s]
#
#
# Downloading model.fp16.safetensors:  57%|█▋ | 786M/1.39G [00:16<00:12, 48.4MB/s]
# Downloading (…)del.fp16.safetensors:  24%|▏| 1.24G/5.14G [00:15<01:01, 63.4MB/s]
#
#
# Downloading model.fp16.safetensors:  57%|█▋ | 797M/1.39G [00:16<00:12, 48.7MB/s]
# Downloading (…)del.fp16.safetensors:  24%|▏| 1.25G/5.14G [00:16<01:03, 61.1MB/s]
#
#
# Downloading model.fp16.safetensors:  58%|█▋ | 807M/1.39G [00:16<00:11, 52.7MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▏| 1.26G/5.14G [00:16<00:59, 64.7MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▏| 1.27G/5.14G [00:16<00:55, 69.7MB/s]
#
#
# Downloading model.fp16.safetensors:  59%|█▊ | 818M/1.39G [00:16<00:10, 53.9MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▏| 1.28G/5.14G [00:16<00:52, 73.3MB/s]
#
#
# Downloading model.fp16.safetensors:  60%|█▊ | 828M/1.39G [00:16<00:10, 52.8MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▎| 1.29G/5.14G [00:16<00:51, 75.3MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▎| 1.30G/5.14G [00:16<00:49, 77.8MB/s]
#
#
# Downloading model.fp16.safetensors:  60%|█▊ | 839M/1.39G [00:17<00:10, 52.5MB/s]
# Downloading (…)del.fp16.safetensors:  26%|▎| 1.31G/5.14G [00:17<00:58, 65.6MB/s]
#
#
# Downloading model.fp16.safetensors:  61%|█▊ | 849M/1.39G [00:17<00:10, 52.7MB/s]
# Downloading (…)del.fp16.safetensors:  26%|▎| 1.32G/5.14G [00:17<00:54, 69.9MB/s]
#
#
# Downloading model.fp16.safetensors:  62%|█▊ | 860M/1.39G [00:17<00:10, 51.1MB/s]
# Downloading (…)del.fp16.safetensors:  26%|▎| 1.33G/5.14G [00:17<00:55, 68.7MB/s]
# Downloading (…)del.fp16.safetensors:  26%|▎| 1.34G/5.14G [00:17<00:52, 72.6MB/s]
#
#
# Downloading model.fp16.safetensors:  63%|█▉ | 870M/1.39G [00:17<00:10, 48.1MB/s]
# Downloading (…)del.fp16.safetensors:  26%|▎| 1.35G/5.14G [00:17<00:51, 73.6MB/s]
# Downloading (…)del.fp16.safetensors:  27%|▎| 1.36G/5.14G [00:17<00:49, 76.1MB/s]
#
#
# Downloading model.fp16.safetensors:  63%|█▉ | 881M/1.39G [00:18<00:11, 44.3MB/s]
# Downloading (…)del.fp16.safetensors:  27%|▎| 1.37G/5.14G [00:17<00:50, 74.1MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|█▉ | 891M/1.39G [00:18<00:09, 50.3MB/s]
# Downloading (…)del.fp16.safetensors:  27%|▎| 1.38G/5.14G [00:18<00:52, 70.9MB/s]
#
#
# Downloading model.fp16.safetensors:  65%|█▉ | 902M/1.39G [00:18<00:09, 50.6MB/s]
# Downloading (…)del.fp16.safetensors:  27%|▎| 1.39G/5.14G [00:18<00:57, 64.6MB/s]
# Downloading (…)del.fp16.safetensors:  27%|▎| 1.41G/5.14G [00:18<00:55, 67.5MB/s]
#
#
# Downloading model.fp16.safetensors:  66%|█▉ | 912M/1.39G [00:18<00:10, 46.1MB/s]
# Downloading (…)del.fp16.safetensors:  28%|▎| 1.42G/5.14G [00:18<00:52, 71.4MB/s]
# Downloading (…)del.fp16.safetensors:  28%|▎| 1.43G/5.14G [00:18<00:48, 75.8MB/s]
#
#
# Downloading model.fp16.safetensors:  66%|█▉ | 923M/1.39G [00:18<00:10, 46.4MB/s]
# Downloading (…)del.fp16.safetensors:  28%|▎| 1.44G/5.14G [00:18<00:48, 76.8MB/s]
#
#
# Downloading model.fp16.safetensors:  67%|██ | 933M/1.39G [00:19<00:09, 47.6MB/s]
# Downloading (…)del.fp16.safetensors:  28%|▎| 1.45G/5.14G [00:18<00:47, 77.5MB/s]
# Downloading (…)del.fp16.safetensors:  28%|▎| 1.46G/5.14G [00:19<00:47, 77.1MB/s]
#
#
# Downloading model.fp16.safetensors:  68%|██ | 944M/1.39G [00:19<00:09, 46.9MB/s]
# Downloading (…)del.fp16.safetensors:  29%|▎| 1.47G/5.14G [00:19<00:46, 79.6MB/s]
#
#
# Downloading model.fp16.safetensors:  69%|██ | 954M/1.39G [00:19<00:08, 49.4MB/s]
# Downloading (…)del.fp16.safetensors:  29%|▎| 1.48G/5.14G [00:19<00:48, 75.5MB/s]
# Downloading (…)del.fp16.safetensors:  29%|▎| 1.49G/5.14G [00:19<00:49, 73.5MB/s]
#
#
# Downloading model.fp16.safetensors:  69%|██ | 965M/1.39G [00:19<00:08, 49.2MB/s]
# Downloading (…)del.fp16.safetensors:  29%|▎| 1.50G/5.14G [00:19<00:47, 76.9MB/s]
#
#
# Downloading model.fp16.safetensors:  70%|██ | 975M/1.39G [00:19<00:08, 51.0MB/s]
# Downloading (…)del.fp16.safetensors:  29%|▎| 1.51G/5.14G [00:19<00:47, 76.0MB/s]
# Downloading (…)del.fp16.safetensors:  30%|▎| 1.52G/5.14G [00:19<00:47, 75.6MB/s]
#
#
# Downloading model.fp16.safetensors:  71%|██▏| 986M/1.39G [00:20<00:08, 49.5MB/s]
# Downloading (…)del.fp16.safetensors:  30%|▎| 1.53G/5.14G [00:19<00:46, 78.2MB/s]
# Downloading (…)del.fp16.safetensors:  30%|▎| 1.54G/5.14G [00:20<00:46, 78.1MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|██▏| 996M/1.39G [00:20<00:07, 50.2MB/s]
# Downloading (…)del.fp16.safetensors:  30%|▎| 1.55G/5.14G [00:20<00:45, 78.1MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|█▍| 1.01G/1.39G [00:20<00:07, 50.5MB/s]
# Downloading (…)del.fp16.safetensors:  30%|▎| 1.56G/5.14G [00:20<00:44, 80.5MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▎| 1.57G/5.14G [00:20<00:43, 82.0MB/s]
#
#
# Downloading model.fp16.safetensors:  73%|█▍| 1.02G/1.39G [00:20<00:07, 52.1MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▎| 1.58G/5.14G [00:20<00:45, 78.0MB/s]
#
#
# Downloading model.fp16.safetensors:  74%|█▍| 1.03G/1.39G [00:20<00:06, 52.5MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▎| 1.59G/5.14G [00:20<00:51, 68.7MB/s]
#
#
# Downloading model.fp16.safetensors:  75%|█▍| 1.04G/1.39G [00:21<00:06, 51.2MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▎| 1.60G/5.14G [00:20<00:49, 71.8MB/s]
#
#
# Downloading model.fp16.safetensors:  75%|█▌| 1.05G/1.39G [00:21<00:06, 52.6MB/s]
# Downloading (…)del.fp16.safetensors:  31%|▎| 1.61G/5.14G [00:21<00:51, 69.0MB/s]
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.63G/5.14G [00:21<00:48, 72.1MB/s]
#
#
# Downloading model.fp16.safetensors:  76%|█▌| 1.06G/1.39G [00:21<00:06, 51.5MB/s]
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.64G/5.14G [00:21<00:47, 73.0MB/s]
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.65G/5.14G [00:21<00:45, 75.9MB/s]
#
#
# Downloading model.fp16.safetensors:  77%|█▌| 1.07G/1.39G [00:21<00:06, 48.5MB/s]
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.66G/5.14G [00:21<00:48, 71.7MB/s]
#
#
# Downloading model.fp16.safetensors:  78%|█▌| 1.08G/1.39G [00:22<00:05, 51.9MB/s]
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.67G/5.14G [00:21<00:53, 65.1MB/s]
#
#
# Downloading model.fp16.safetensors:  78%|█▌| 1.09G/1.39G [00:22<00:05, 49.8MB/s]
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.68G/5.14G [00:22<00:55, 62.4MB/s]
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.69G/5.14G [00:22<00:51, 67.5MB/s]
#
#
# Downloading model.fp16.safetensors:  79%|█▌| 1.10G/1.39G [00:22<00:06, 46.9MB/s]
#
#
# Downloading model.fp16.safetensors:  80%|█▌| 1.11G/1.39G [00:22<00:05, 49.7MB/s]
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.70G/5.14G [00:22<01:05, 52.6MB/s]
#
#
# Downloading model.fp16.safetensors:  81%|█▌| 1.12G/1.39G [00:22<00:05, 51.3MB/s]
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.72G/5.14G [00:22<00:48, 71.0MB/s]
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.73G/5.14G [00:22<00:48, 70.0MB/s]
#
#
# Downloading model.fp16.safetensors:  82%|█▋| 1.13G/1.39G [00:23<00:05, 48.9MB/s]
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.74G/5.14G [00:22<00:46, 72.9MB/s]
#
#
# Downloading model.fp16.safetensors:  82%|█▋| 1.14G/1.39G [00:23<00:05, 48.8MB/s]
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.75G/5.14G [00:23<00:49, 67.8MB/s]
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.76G/5.14G [00:23<00:47, 70.6MB/s]
#
#
# Downloading model.fp16.safetensors:  83%|█▋| 1.15G/1.39G [00:23<00:04, 47.3MB/s]
# Downloading (…)del.fp16.safetensors:  35%|▎| 1.77G/5.14G [00:23<00:46, 72.8MB/s]
#
#
# Downloading model.fp16.safetensors:  84%|█▋| 1.16G/1.39G [00:23<00:04, 49.5MB/s]
# Downloading (…)del.fp16.safetensors:  35%|▎| 1.78G/5.14G [00:23<00:44, 76.0MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|█▋| 1.17G/1.39G [00:23<00:04, 53.5MB/s]
# Downloading (…)del.fp16.safetensors:  35%|▎| 1.79G/5.14G [00:23<00:42, 78.8MB/s]
# Downloading (…)del.fp16.safetensors:  35%|▎| 1.80G/5.14G [00:23<00:42, 78.9MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|█▋| 1.18G/1.39G [00:24<00:04, 48.1MB/s]
# Downloading (…)del.fp16.safetensors:  35%|▎| 1.81G/5.14G [00:23<00:42, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  36%|▎| 1.82G/5.14G [00:24<00:42, 78.8MB/s]
#
#
# Downloading model.fp16.safetensors:  86%|█▋| 1.20G/1.39G [00:24<00:03, 49.7MB/s]
# Downloading (…)del.fp16.safetensors:  36%|▎| 1.84G/5.14G [00:24<00:40, 80.9MB/s]
#
#
# Downloading model.fp16.safetensors:  87%|█▋| 1.21G/1.39G [00:24<00:03, 49.3MB/s]
# Downloading (…)del.fp16.safetensors:  36%|▎| 1.85G/5.14G [00:24<00:45, 71.9MB/s]
# Downloading (…)del.fp16.safetensors:  36%|▎| 1.86G/5.14G [00:24<00:43, 75.1MB/s]
#
#
# Downloading model.fp16.safetensors:  88%|█▊| 1.22G/1.39G [00:24<00:03, 48.1MB/s]
# Downloading (…)del.fp16.safetensors:  36%|▎| 1.87G/5.14G [00:24<00:41, 78.1MB/s]
#
#
# Downloading model.fp16.safetensors:  88%|█▊| 1.23G/1.39G [00:24<00:03, 51.6MB/s]
# Downloading (…)del.fp16.safetensors:  37%|▎| 1.88G/5.14G [00:24<00:40, 80.0MB/s]
# Downloading (…)del.fp16.safetensors:  37%|▎| 1.89G/5.14G [00:24<00:41, 78.7MB/s]
#
#
# Downloading model.fp16.safetensors:  89%|█▊| 1.24G/1.39G [00:25<00:02, 51.4MB/s]
# Downloading (…)del.fp16.safetensors:  37%|▎| 1.90G/5.14G [00:24<00:42, 76.3MB/s]
#
#
# Downloading model.fp16.safetensors:  90%|█▊| 1.25G/1.39G [00:25<00:02, 53.8MB/s]
# Downloading (…)del.fp16.safetensors:  37%|▎| 1.91G/5.14G [00:25<00:41, 77.9MB/s]
# Downloading (…)del.fp16.safetensors:  37%|▎| 1.92G/5.14G [00:25<00:41, 76.7MB/s]
#
#
# Downloading model.fp16.safetensors:  91%|█▊| 1.26G/1.39G [00:25<00:02, 51.8MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▍| 1.93G/5.14G [00:25<00:40, 78.8MB/s]
#
#
# Downloading model.fp16.safetensors:  91%|█▊| 1.27G/1.39G [00:25<00:02, 52.1MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▍| 1.94G/5.14G [00:25<00:45, 69.8MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▍| 1.95G/5.14G [00:25<00:44, 71.6MB/s]
#
#
# Downloading model.fp16.safetensors:  92%|█▊| 1.28G/1.39G [00:26<00:02, 49.5MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▍| 1.96G/5.14G [00:25<00:45, 69.5MB/s]
#
#
# Downloading model.fp16.safetensors:  93%|█▊| 1.29G/1.39G [00:26<00:01, 50.8MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▍| 1.97G/5.14G [00:26<00:43, 72.1MB/s]
# Downloading (…)del.fp16.safetensors:  39%|▍| 1.98G/5.14G [00:26<00:42, 74.8MB/s]
#
#
# Downloading model.fp16.safetensors:  94%|█▊| 1.30G/1.39G [00:26<00:01, 47.5MB/s]
# Downloading (…)del.fp16.safetensors:  39%|▍| 1.99G/5.14G [00:26<00:40, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  39%|▍| 2.00G/5.14G [00:26<00:39, 80.1MB/s]
#
#
# Downloading model.fp16.safetensors:  94%|█▉| 1.31G/1.39G [00:26<00:01, 46.9MB/s]
# Downloading (…)del.fp16.safetensors:  39%|▍| 2.01G/5.14G [00:26<00:43, 71.8MB/s]
#
#
# Downloading model.fp16.safetensors:  95%|█▉| 1.32G/1.39G [00:26<00:01, 48.8MB/s]
# Downloading (…)del.fp16.safetensors:  39%|▍| 2.02G/5.14G [00:26<00:41, 75.4MB/s]
#
#
# Downloading model.fp16.safetensors:  96%|█▉| 1.33G/1.39G [00:27<00:01, 49.5MB/s]
# Downloading (…)del.fp16.safetensors:  40%|▍| 2.03G/5.14G [00:26<00:39, 78.0MB/s]
# Downloading (…)del.fp16.safetensors:  40%|▍| 2.04G/5.14G [00:26<00:38, 80.3MB/s]
#
#
# Downloading model.fp16.safetensors:  97%|█▉| 1.34G/1.39G [00:27<00:00, 49.1MB/s]
# Downloading (…)del.fp16.safetensors:  40%|▍| 2.06G/5.14G [00:27<00:37, 81.7MB/s]
# Downloading (…)del.fp16.safetensors:  40%|▍| 2.07G/5.14G [00:27<00:36, 83.2MB/s]
#
#
# Downloading model.fp16.safetensors:  97%|█▉| 1.35G/1.39G [00:27<00:00, 47.9MB/s]
# Downloading (…)del.fp16.safetensors:  40%|▍| 2.08G/5.14G [00:27<00:37, 82.4MB/s]
# Downloading (…)del.fp16.safetensors:  41%|▍| 2.09G/5.14G [00:27<00:36, 83.2MB/s]
#
#
# Downloading model.fp16.safetensors:  98%|█▉| 1.36G/1.39G [00:27<00:00, 49.6MB/s]
# Downloading (…)del.fp16.safetensors:  41%|▍| 2.10G/5.14G [00:27<00:38, 79.3MB/s]
#
#
# Downloading model.fp16.safetensors:  99%|█▉| 1.37G/1.39G [00:27<00:00, 50.3MB/s]
# Downloading (…)del.fp16.safetensors:  41%|▍| 2.11G/5.14G [00:27<00:45, 66.5MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|█▉| 1.38G/1.39G [00:28<00:00, 52.3MB/s]
# Downloading model.fp16.safetensors: 100%|██| 1.39G/1.39G [00:28<00:00, 49.2MB/s]
# Fetching 19 files:  32%|███████▉                 | 6/19 [00:28<01:20,  6.18s/it]
# Downloading (…)del.fp16.safetensors:  41%|▍| 2.13G/5.14G [00:28<00:41, 71.7MB/s]
# Downloading (…)del.fp16.safetensors:  42%|▍| 2.14G/5.14G [00:28<00:39, 75.1MB/s]
# Downloading (…)del.fp16.safetensors:  42%|▍| 2.15G/5.14G [00:28<00:40, 73.4MB/s]
# Downloading (…)del.fp16.safetensors:  42%|▍| 2.16G/5.14G [00:28<00:40, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  42%|▍| 2.17G/5.14G [00:28<00:40, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  42%|▍| 2.18G/5.14G [00:28<00:45, 65.6MB/s]
# Downloading (…)del.fp16.safetensors:  43%|▍| 2.19G/5.14G [00:28<00:42, 69.6MB/s]
# Downloading (…)del.fp16.safetensors:  43%|▍| 2.20G/5.14G [00:29<00:41, 71.0MB/s]
# Downloading (…)del.fp16.safetensors:  43%|▍| 2.21G/5.14G [00:29<00:38, 75.4MB/s]
# Downloading (…)del.fp16.safetensors:  43%|▍| 2.22G/5.14G [00:29<00:38, 75.8MB/s]
# Downloading (…)del.fp16.safetensors:  43%|▍| 2.23G/5.14G [00:29<00:37, 78.0MB/s]
# Downloading (…)del.fp16.safetensors:  44%|▍| 2.24G/5.14G [00:29<00:38, 75.3MB/s]
# Downloading (…)del.fp16.safetensors:  44%|▍| 2.25G/5.14G [00:29<00:39, 73.6MB/s]
# Downloading (…)del.fp16.safetensors:  44%|▍| 2.26G/5.14G [00:29<00:43, 65.9MB/s]
# Downloading (…)del.fp16.safetensors:  44%|▍| 2.28G/5.14G [00:30<00:40, 70.4MB/s]
# Downloading (…)del.fp16.safetensors:  45%|▍| 2.29G/5.14G [00:30<00:39, 71.6MB/s]
# Downloading (…)del.fp16.safetensors:  45%|▍| 2.30G/5.14G [00:30<00:37, 75.1MB/s]
# Downloading (…)del.fp16.safetensors:  45%|▍| 2.31G/5.14G [00:30<00:37, 76.2MB/s]
# Downloading (…)del.fp16.safetensors:  45%|▍| 2.32G/5.14G [00:30<00:35, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  45%|▍| 2.33G/5.14G [00:30<00:35, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  46%|▍| 2.34G/5.14G [00:30<00:34, 80.8MB/s]
# Downloading (…)del.fp16.safetensors:  46%|▍| 2.35G/5.14G [00:31<00:39, 69.8MB/s]
# Downloading (…)del.fp16.safetensors:  46%|▍| 2.36G/5.14G [00:31<00:38, 72.0MB/s]
# Downloading (…)del.fp16.safetensors:  46%|▍| 2.37G/5.14G [00:31<00:37, 74.1MB/s]
# Downloading (…)del.fp16.safetensors:  46%|▍| 2.38G/5.14G [00:31<00:36, 76.0MB/s]
# Downloading (…)del.fp16.safetensors:  47%|▍| 2.39G/5.14G [00:31<00:34, 78.5MB/s]
# Downloading (…)del.fp16.safetensors:  47%|▍| 2.40G/5.14G [00:31<00:34, 80.2MB/s]
# Downloading (…)del.fp16.safetensors:  47%|▍| 2.41G/5.14G [00:31<00:33, 81.3MB/s]
# Downloading (…)del.fp16.safetensors:  47%|▍| 2.42G/5.14G [00:32<00:35, 75.4MB/s]
# Downloading (…)del.fp16.safetensors:  47%|▍| 2.43G/5.14G [00:32<00:39, 68.9MB/s]
# Downloading (…)del.fp16.safetensors:  48%|▍| 2.44G/5.14G [00:32<00:38, 70.7MB/s]
# Downloading (…)del.fp16.safetensors:  48%|▍| 2.45G/5.14G [00:32<00:37, 71.6MB/s]
# Downloading (…)del.fp16.safetensors:  48%|▍| 2.46G/5.14G [00:32<00:36, 72.9MB/s]
# Downloading (…)del.fp16.safetensors:  48%|▍| 2.47G/5.14G [00:32<00:35, 74.1MB/s]
# Downloading (…)del.fp16.safetensors:  48%|▍| 2.49G/5.14G [00:32<00:34, 76.2MB/s]
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.50G/5.14G [00:33<00:34, 76.3MB/s]
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.51G/5.14G [00:33<00:33, 77.6MB/s]
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.52G/5.14G [00:33<00:37, 69.4MB/s]
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.53G/5.14G [00:33<00:38, 67.7MB/s]
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.54G/5.14G [00:33<00:37, 69.0MB/s]
# Downloading (…)del.fp16.safetensors:  50%|▍| 2.55G/5.14G [00:33<00:36, 70.9MB/s]
# Downloading (…)del.fp16.safetensors:  50%|▍| 2.56G/5.14G [00:33<00:34, 75.1MB/s]
# Downloading (…)del.fp16.safetensors:  50%|▌| 2.57G/5.14G [00:34<00:35, 73.2MB/s]
# Downloading (…)del.fp16.safetensors:  50%|▌| 2.58G/5.14G [00:34<00:33, 77.2MB/s]
# Downloading (…)del.fp16.safetensors:  50%|▌| 2.59G/5.14G [00:34<00:33, 75.7MB/s]
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.60G/5.14G [00:34<00:32, 78.8MB/s]
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.61G/5.14G [00:34<00:35, 71.4MB/s]
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.62G/5.14G [00:34<00:33, 74.0MB/s]
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.63G/5.14G [00:34<00:33, 75.6MB/s]
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.64G/5.14G [00:35<00:33, 73.6MB/s]
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.65G/5.14G [00:35<00:34, 71.8MB/s]
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.66G/5.14G [00:35<00:33, 73.4MB/s]
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.67G/5.14G [00:35<00:32, 75.8MB/s]
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.68G/5.14G [00:35<00:31, 76.6MB/s]
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.69G/5.14G [00:35<00:39, 62.4MB/s]
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.71G/5.14G [00:35<00:36, 67.2MB/s]
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.72G/5.14G [00:36<00:33, 71.6MB/s]
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.73G/5.14G [00:36<00:32, 74.9MB/s]
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.74G/5.14G [00:36<00:30, 77.5MB/s]
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.75G/5.14G [00:36<00:29, 80.1MB/s]
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.76G/5.14G [00:36<00:29, 80.4MB/s]
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.77G/5.14G [00:36<00:30, 77.7MB/s]
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.78G/5.14G [00:36<00:36, 65.1MB/s]
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.79G/5.14G [00:37<00:35, 65.9MB/s]
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.80G/5.14G [00:37<00:32, 70.8MB/s]
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.81G/5.14G [00:37<00:31, 74.1MB/s]
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.82G/5.14G [00:37<00:30, 75.5MB/s]
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.83G/5.14G [00:37<00:34, 67.6MB/s]
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.84G/5.14G [00:37<00:35, 64.1MB/s]
# Downloading (…)del.fp16.safetensors:  56%|▌| 2.85G/5.14G [00:38<00:38, 58.6MB/s]
# Downloading (…)del.fp16.safetensors:  56%|▌| 2.86G/5.14G [00:38<00:34, 65.6MB/s]
# Downloading (…)del.fp16.safetensors:  56%|▌| 2.87G/5.14G [00:38<00:32, 70.5MB/s]
# Downloading (…)del.fp16.safetensors:  56%|▌| 2.88G/5.14G [00:38<00:40, 55.3MB/s]
# Downloading (…)del.fp16.safetensors:  56%|▌| 2.89G/5.14G [00:40<02:09, 17.3MB/s]
# Downloading (…)del.fp16.safetensors:  57%|▌| 2.92G/5.14G [00:40<01:15, 29.4MB/s]
# Downloading (…)del.fp16.safetensors:  57%|▌| 2.93G/5.14G [00:40<01:03, 35.0MB/s]
# Downloading (…)del.fp16.safetensors:  57%|▌| 2.94G/5.14G [00:40<00:53, 41.1MB/s]
# Downloading (…)del.fp16.safetensors:  57%|▌| 2.95G/5.14G [00:40<00:46, 47.5MB/s]
# Downloading (…)del.fp16.safetensors:  58%|▌| 2.96G/5.14G [00:40<00:40, 54.0MB/s]
# Downloading (…)del.fp16.safetensors:  58%|▌| 2.97G/5.14G [00:40<00:36, 58.7MB/s]
# Downloading (…)del.fp16.safetensors:  58%|▌| 2.98G/5.14G [00:41<00:33, 63.8MB/s]
# Downloading (…)del.fp16.safetensors:  58%|▌| 2.99G/5.14G [00:41<00:32, 66.6MB/s]
# Downloading (…)del.fp16.safetensors:  58%|▌| 3.00G/5.14G [00:41<00:30, 70.3MB/s]
# Downloading (…)del.fp16.safetensors:  59%|▌| 3.01G/5.14G [00:41<00:29, 71.2MB/s]
# Downloading (…)del.fp16.safetensors:  59%|▌| 3.02G/5.14G [00:41<00:29, 72.9MB/s]
# Downloading (…)del.fp16.safetensors:  59%|▌| 3.03G/5.14G [00:41<00:27, 75.6MB/s]
# Downloading (…)del.fp16.safetensors:  59%|▌| 3.04G/5.14G [00:42<00:36, 57.2MB/s]
# Downloading (…)del.fp16.safetensors:  59%|▌| 3.05G/5.14G [00:42<00:33, 61.4MB/s]
# Downloading (…)del.fp16.safetensors:  60%|▌| 3.06G/5.14G [00:42<00:30, 67.3MB/s]
# Downloading (…)del.fp16.safetensors:  60%|▌| 3.07G/5.14G [00:42<00:29, 70.5MB/s]
# Downloading (…)del.fp16.safetensors:  60%|▌| 3.08G/5.14G [00:42<00:27, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  60%|▌| 3.09G/5.14G [00:42<00:26, 75.7MB/s]
# Downloading (…)del.fp16.safetensors:  60%|▌| 3.10G/5.14G [00:42<00:25, 78.5MB/s]
# Downloading (…)del.fp16.safetensors:  61%|▌| 3.11G/5.14G [00:42<00:25, 79.9MB/s]
# Downloading (…)del.fp16.safetensors:  61%|▌| 3.12G/5.14G [00:43<00:25, 80.0MB/s]
# Downloading (…)del.fp16.safetensors:  61%|▌| 3.14G/5.14G [00:43<00:25, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  61%|▌| 3.15G/5.14G [00:43<00:25, 77.6MB/s]
# Downloading (…)del.fp16.safetensors:  61%|▌| 3.16G/5.14G [00:43<00:24, 79.2MB/s]
# Downloading (…)del.fp16.safetensors:  62%|▌| 3.17G/5.14G [00:43<00:26, 75.6MB/s]
# Downloading (…)del.fp16.safetensors:  62%|▌| 3.18G/5.14G [00:43<00:25, 77.2MB/s]
# Downloading (…)del.fp16.safetensors:  62%|▌| 3.19G/5.14G [00:43<00:26, 73.3MB/s]
# Downloading (…)del.fp16.safetensors:  62%|▌| 3.20G/5.14G [00:44<00:28, 67.4MB/s]
# Downloading (…)del.fp16.safetensors:  62%|▌| 3.21G/5.14G [00:44<00:26, 71.7MB/s]
# Downloading (…)del.fp16.safetensors:  63%|▋| 3.22G/5.14G [00:44<00:25, 75.0MB/s]
# Downloading (…)del.fp16.safetensors:  63%|▋| 3.23G/5.14G [00:44<00:26, 71.8MB/s]
# Downloading (…)del.fp16.safetensors:  63%|▋| 3.24G/5.14G [00:44<00:25, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  63%|▋| 3.25G/5.14G [00:44<00:24, 77.9MB/s]
# Downloading (…)del.fp16.safetensors:  64%|▋| 3.26G/5.14G [00:44<00:24, 76.3MB/s]
# Downloading (…)del.fp16.safetensors:  64%|▋| 3.27G/5.14G [00:45<00:23, 78.5MB/s]
# Downloading (…)del.fp16.safetensors:  64%|▋| 3.28G/5.14G [00:45<00:24, 75.3MB/s]
# Downloading (…)del.fp16.safetensors:  64%|▋| 3.29G/5.14G [00:45<00:23, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  64%|▋| 3.30G/5.14G [00:45<00:24, 75.8MB/s]
# Downloading (…)del.fp16.safetensors:  65%|▋| 3.31G/5.14G [00:45<00:23, 78.2MB/s]
# Downloading (…)del.fp16.safetensors:  65%|▋| 3.32G/5.14G [00:45<00:23, 78.0MB/s]
# Downloading (…)del.fp16.safetensors:  65%|▋| 3.33G/5.14G [00:45<00:25, 70.8MB/s]
# Downloading (…)del.fp16.safetensors:  65%|▋| 3.34G/5.14G [00:46<00:25, 69.7MB/s]
# Downloading (…)del.fp16.safetensors:  65%|▋| 3.36G/5.14G [00:46<00:23, 74.3MB/s]
# Downloading (…)del.fp16.safetensors:  66%|▋| 3.37G/5.14G [00:46<00:23, 75.1MB/s]
# Downloading (…)del.fp16.safetensors:  66%|▋| 3.38G/5.14G [00:46<00:22, 76.5MB/s]
# Downloading (…)del.fp16.safetensors:  66%|▋| 3.39G/5.14G [00:46<00:22, 79.4MB/s]
# Downloading (…)del.fp16.safetensors:  66%|▋| 3.40G/5.14G [00:46<00:21, 79.3MB/s]
# Downloading (…)del.fp16.safetensors:  66%|▋| 3.41G/5.14G [00:46<00:21, 80.2MB/s]
# Downloading (…)del.fp16.safetensors:  67%|▋| 3.42G/5.14G [00:46<00:21, 78.9MB/s]
# Downloading (…)del.fp16.safetensors:  67%|▋| 3.43G/5.14G [00:47<00:22, 77.5MB/s]
# Downloading (…)del.fp16.safetensors:  67%|▋| 3.44G/5.14G [00:47<00:21, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  67%|▋| 3.45G/5.14G [00:47<00:22, 75.6MB/s]
# Downloading (…)del.fp16.safetensors:  67%|▋| 3.46G/5.14G [00:47<00:21, 77.3MB/s]
# Downloading (…)del.fp16.safetensors:  68%|▋| 3.47G/5.14G [00:47<00:22, 72.6MB/s]
# Downloading (…)del.fp16.safetensors:  68%|▋| 3.48G/5.14G [00:47<00:22, 75.0MB/s]
# Downloading (…)del.fp16.safetensors:  68%|▋| 3.49G/5.14G [00:47<00:20, 78.6MB/s]
# Downloading (…)del.fp16.safetensors:  68%|▋| 3.50G/5.14G [00:48<00:22, 73.1MB/s]
# Downloading (…)del.fp16.safetensors:  68%|▋| 3.51G/5.14G [00:48<00:21, 76.9MB/s]
# Downloading (…)del.fp16.safetensors:  69%|▋| 3.52G/5.14G [00:48<00:20, 80.4MB/s]
# Downloading (…)del.fp16.safetensors:  69%|▋| 3.53G/5.14G [00:48<00:19, 80.3MB/s]
# Downloading (…)del.fp16.safetensors:  69%|▋| 3.54G/5.14G [00:48<00:19, 79.7MB/s]
# Downloading (…)del.fp16.safetensors:  69%|▋| 3.55G/5.14G [00:48<00:19, 80.3MB/s]
# Downloading (…)del.fp16.safetensors:  69%|▋| 3.57G/5.14G [00:48<00:20, 76.0MB/s]
# Downloading (…)del.fp16.safetensors:  70%|▋| 3.58G/5.14G [00:48<00:19, 79.2MB/s]
# Downloading (…)del.fp16.safetensors:  70%|▋| 3.59G/5.14G [00:49<00:20, 75.8MB/s]
# Downloading (…)del.fp16.safetensors:  70%|▋| 3.60G/5.14G [00:49<00:20, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  70%|▋| 3.61G/5.14G [00:49<00:20, 75.9MB/s]
# Downloading (…)del.fp16.safetensors:  70%|▋| 3.62G/5.14G [00:49<00:19, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  71%|▋| 3.63G/5.14G [00:49<00:18, 80.0MB/s]
# Downloading (…)del.fp16.safetensors:  71%|▋| 3.64G/5.14G [00:49<00:18, 81.7MB/s]
# Downloading (…)del.fp16.safetensors:  71%|▋| 3.65G/5.14G [00:49<00:18, 79.6MB/s]
# Downloading (…)del.fp16.safetensors:  71%|▋| 3.66G/5.14G [00:50<00:18, 78.7MB/s]
# Downloading (…)del.fp16.safetensors:  71%|▋| 3.67G/5.14G [00:50<00:18, 80.5MB/s]
# Downloading (…)del.fp16.safetensors:  72%|▋| 3.68G/5.14G [00:50<00:18, 77.2MB/s]
# Downloading (…)del.fp16.safetensors:  72%|▋| 3.69G/5.14G [00:50<00:18, 79.9MB/s]
# Downloading (…)del.fp16.safetensors:  72%|▋| 3.70G/5.14G [00:50<00:18, 78.3MB/s]
# Downloading (…)del.fp16.safetensors:  72%|▋| 3.71G/5.14G [00:50<00:18, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  72%|▋| 3.72G/5.14G [00:50<00:17, 80.1MB/s]
# Downloading (…)del.fp16.safetensors:  73%|▋| 3.73G/5.14G [00:50<00:17, 79.8MB/s]
# Downloading (…)del.fp16.safetensors:  73%|▋| 3.74G/5.14G [00:51<00:17, 81.2MB/s]
# Downloading (…)del.fp16.safetensors:  73%|▋| 3.75G/5.14G [00:51<00:17, 78.2MB/s]
# Downloading (…)del.fp16.safetensors:  73%|▋| 3.76G/5.14G [00:51<00:17, 78.4MB/s]
# Downloading (…)del.fp16.safetensors:  74%|▋| 3.77G/5.14G [00:51<00:17, 79.6MB/s]
# ...
# Downloading (…)del.fp16.safetensors:  96%|▉| 4.92G/5.14G [01:06<00:02, 75.5MB/s]
# Downloading (…)del.fp16.safetensors:  96%|▉| 4.93G/5.14G [01:06<00:02, 73.5MB/s]
# Downloading (…)del.fp16.safetensors:  96%|▉| 4.94G/5.14G [01:06<00:02, 76.5MB/s]
# Downloading (…)del.fp16.safetensors:  96%|▉| 4.95G/5.14G [01:06<00:02, 78.5MB/s]
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.96G/5.14G [01:06<00:02, 79.7MB/s]
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.97G/5.14G [01:06<00:02, 79.8MB/s]
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.98G/5.14G [01:06<00:01, 78.7MB/s]
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.99G/5.14G [01:07<00:01, 80.2MB/s]
# Downloading (…)del.fp16.safetensors:  97%|▉| 5.00G/5.14G [01:07<00:01, 80.1MB/s]
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.01G/5.14G [01:07<00:01, 79.9MB/s]
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.02G/5.14G [01:07<00:01, 77.8MB/s]
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.03G/5.14G [01:07<00:01, 78.2MB/s]
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.04G/5.14G [01:07<00:01, 77.0MB/s]
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.05G/5.14G [01:07<00:01, 78.1MB/s]
# Downloading (…)del.fp16.safetensors:  99%|▉| 5.06G/5.14G [01:08<00:00, 79.0MB/s]
# Downloading (…)del.fp16.safetensors:  99%|▉| 5.08G/5.14G [01:08<00:00, 79.6MB/s]
# Downloading (…)del.fp16.safetensors:  99%|▉| 5.09G/5.14G [01:08<00:00, 82.8MB/s]
# Downloading (…)del.fp16.safetensors:  99%|▉| 5.10G/5.14G [01:08<00:00, 84.6MB/s]
# Downloading (…)del.fp16.safetensors:  99%|▉| 5.11G/5.14G [01:08<00:00, 83.4MB/s]
# Downloading (…)del.fp16.safetensors: 100%|▉| 5.12G/5.14G [01:08<00:00, 81.8MB/s]
# Downloading (…)del.fp16.safetensors: 100%|█| 5.14G/5.14G [01:08<00:00, 74.6MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [01:09<00:00,  3.66s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.53it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:42<00:00,  1.18it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.45it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.80it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.63it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.61it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.55it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.13it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.56it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.11it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.27it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.11it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.58it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.65it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.11it/s]
#
# **************************************************
