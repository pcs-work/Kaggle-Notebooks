# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# # Version 3

# prompts: list = [
#     "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
#     "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
#     "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
#     "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
#     "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
#     "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
#     "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
#     "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
#     "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
#     "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
# ]

# %%
# # Version 4

# prompts: list = [
#     "A city at night, dark sky, people watching in wonder, very detailed, 8k, concept art",
#     "A city at night big moon and stars at the borders, concept art, dark, creepy, atmospheric, 8k, HD",
#     "A city at night, small lamp posts, burning church, street lamps, 4 k, concept art, sparse vegetation",
#     "A city at night, low green clouds, dark red sky, night, 4k, high details, fireflies, art by WLOP,",
#     "A city at night, dark moonlight, sky full of stars at the edges, concept art, 4k, octane render, digital painting,",
#     "A city at night, big moon on the right, meteor fall, trending on artstation, 8k, cinematic, soft, sharp focus, insanely",
#     "A city at night, huge moon, stars at the horizon, 4k, 8k, trending on Artstation",
#     "A city at night during a nuclear eruption, intricate Asteroid belt with huge rings in the sky, water and beautiful pink blobs, flying cars,",
#     "A city at night with cumulonimbus clouds in the sky, night colors, stars in the sky, painting by tyler edlin,",
#     "A city at night, moonlight, street lamps, falling leaves, wide angle, super highly detailed, professional digital painting, artstation, concept art",
# ]

# %%
# # Version 5

# prompts: list = [
#     "A picturesque night sky over a full moon",
#     "A picturesque night sky with planets visible in the background, stars in the sky",
#     "A picturesque night sky, small waterfall, mist, candlelight, celestial highlights, painting in style of krenz cushart, ilya",
#     "A picturesque night sky, low angle, dawn, stars in the night sky, realistic, detailed faces, moody, atmospheric, cinematic, wide",
#     "A picturesque night sky overimpel forest",
#     "A picturesque night sky over the sea, stars bloom in the background, natural, ultra detail. ethereal",
#     "A picturesque night sky with constellations, small camp is built beside. In style of Yoji Shinkawa and Hyung-tae",
#     "A picturesque night sky with constellations, stars Asteroid belt with huge rings and beautiful draped clouds, anime, fountain, statue, underwater,",
#     "A picturesque night sky with stars visible through shattered clouds",
#     "A picturesque night sky overland, low poly, isometric art",
# ]

# %%
# Version 6

prompts: list = [
    "A car in a field at night illuminated by vibrant glowing lights in the distance.",
    "A car in a field at night with a moon and highly detailed",
    "A car in a field at night illuminated by glowing headlights",
    "A car in a field at night, a big moon in the background. Vibrant colors",
    "A car in a field at night illuminated by glowing headlights of organic matte liquid metal and shiny gold and a blue glow emanates from the metal",
    "A car in a field at night illuminated by a street lamp, camera flashes from behind, concept art, intricate, digital painting, cinematic lighting, dark",
    "A car in a field at night with moon in the lights, underexposed, desolated wasteland",
    "A car in a field at night illuminated by a street light, Asteroid belt, nebula in the distance, night colors, high - key lighting",
    "A car in a field at night with a moon with soft adventurous and atmospheric lighting",
    "A car in a field at night illuminated by flashes of lightning, pitchblack sky, extremly detailed digital photo",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.07MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.49MB/s]
#
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.30MB/s]
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 2.99MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:02,  7.96it/s]
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 4.68MB/s]
#
#
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 4.07MB/s]
#
#
# Downloading model.fp16.safetensors:   0%|           | 0.00/1.39G [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
#
#
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 6.68MB/s]
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 2.59MB/s]
#
# Downloading (…)kenizer_2/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 2.81MB/s]
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 13.2MB/s]
#
#
#
#
# Downloading (…)76f/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 8.29MB/s]
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 8.73MB/s]
#
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:03, 63.9MB/s]
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:25, 54.2MB/s]
#
#
#
# Downloading (…)d76f/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 2.96MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   9%|▎  | 21.0M/246M [00:00<00:02, 81.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 7.56MB/s]
#
#
# Downloading model.fp16.safetensors:   2%|  | 21.0M/1.39G [00:00<00:20, 67.4MB/s]
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:02, 82.6MB/s]
#
#
# Downloading model.fp16.safetensors:  13%|▍  | 31.5M/246M [00:00<00:02, 79.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 68.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:04, 79.5MB/s]
#
# Downloading model.fp16.safetensors:   2%|  | 31.5M/1.39G [00:00<00:21, 64.4MB/s]
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 66.6MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▌  | 41.9M/246M [00:00<00:02, 80.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 80.4MB/s]
#
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:18, 73.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 31.5M/5.14G [00:00<01:05, 77.9MB/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 68.2MB/s]
#
#
# Downloading model.fp16.safetensors:  21%|▋  | 52.4M/246M [00:00<00:02, 81.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<00:59, 85.1MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▍ | 31.5M/167M [00:00<00:01, 80.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 98.0MB/s]
#
#
# Downloading model.fp16.safetensors:  26%|▊  | 62.9M/246M [00:00<00:02, 82.4MB/s]
#
# Downloading model.fp16.safetensors:   5%|  | 62.9M/1.39G [00:00<00:15, 85.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 98.9MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 80.6MB/s]
#
#
# Downloading model.fp16.safetensors:  30%|▉  | 73.4M/246M [00:00<00:02, 84.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 62.9M/5.14G [00:00<00:52, 96.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 95.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 73.4M/5.14G [00:00<00:51, 97.7MB/s]
#
#
# Downloading model.fp16.safetensors:  34%|█  | 83.9M/246M [00:01<00:01, 85.8MB/s]
#
# Downloading model.fp16.safetensors:   6%|  | 83.9M/1.39G [00:01<00:14, 89.0MB/s]
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 94.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:00<00:00, 95.0MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▏ | 94.4M/246M [00:01<00:01, 89.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 83.9M/167M [00:00<00:00, 95.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 94.4M/5.14G [00:00<00:48, 104MB/s]
#
#
# Downloading model.fp16.safetensors:  43%|█▋  | 105M/246M [00:01<00:01, 91.7MB/s]
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 105MB/s]
#
# Downloading model.fp16.safetensors:   8%|▏  | 105M/1.39G [00:01<00:14, 90.3MB/s]
# Downloading (…)del.fp16.safetensors:  56%|█▋ | 94.4M/167M [00:01<00:00, 102MB/s]
#
# Downloading model.fp16.safetensors:   8%|▏  | 115M/1.39G [00:01<00:13, 91.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 95.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|   | 115M/5.14G [00:01<00:49, 102MB/s]
#
#
# Downloading model.fp16.safetensors:  51%|██  | 126M/246M [00:01<00:01, 96.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|██ | 115M/167M [00:01<00:00, 95.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 126M/5.14G [00:01<00:51, 96.7MB/s]
# Downloading (…)del.fp16.safetensors:  69%|██▊ | 115M/167M [00:01<00:00, 102MB/s]
#
# Downloading model.fp16.safetensors:  10%|▎  | 136M/1.39G [00:01<00:13, 94.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 96.9MB/s]
#
#
# Downloading model.fp16.safetensors:  60%|██▍ | 147M/246M [00:01<00:01, 97.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 136M/5.14G [00:01<00:54, 92.2MB/s]
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 98.1MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|██▌ | 157M/246M [00:01<00:00, 97.3MB/s]
#
# Downloading model.fp16.safetensors:  11%|▎  | 157M/1.39G [00:01<00:12, 98.5MB/s]
# Downloading (…)del.fp16.safetensors:  81%|██▍| 136M/167M [00:01<00:00, 99.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 105MB/s]
#
#
# Downloading model.fp16.safetensors:  68%|██▋ | 168M/246M [00:01<00:00, 97.5MB/s]
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 98.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 157M/5.14G [00:01<00:53, 93.0MB/s]
#
# Downloading model.fp16.safetensors:  12%|▎  | 168M/1.39G [00:01<00:13, 94.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 168M/5.14G [00:01<00:52, 95.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 96.7MB/s]
#
#
#
# Downloading model.fp16.safetensors:  77%|███▊ | 189M/246M [00:02<00:00, 107MB/s]
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 103MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 95.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 189M/5.14G [00:01<00:46, 107MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|████▎| 210M/246M [00:02<00:00, 118MB/s]
#
# Downloading model.fp16.safetensors:  15%|▌   | 210M/1.39G [00:02<00:10, 111MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 210M/5.14G [00:02<00:40, 122MB/s]
#
#
# Downloading model.fp16.safetensors:  94%|████▋| 231M/246M [00:02<00:00, 129MB/s]
#
# Downloading model.fp16.safetensors:  17%|▋   | 231M/1.39G [00:02<00:09, 129MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|▏  | 231M/5.14G [00:02<00:36, 134MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 101MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:11,  1.27it/s]
#
# Downloading model.fp16.safetensors:  18%|▋   | 252M/1.39G [00:02<00:08, 135MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 252M/5.14G [00:02<00:32, 148MB/s]
#
# Downloading model.fp16.safetensors:  20%|▊   | 273M/1.39G [00:02<00:07, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 273M/5.14G [00:02<00:30, 162MB/s]
#
# Downloading model.fp16.safetensors:  21%|▊   | 294M/1.39G [00:02<00:07, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 294M/5.14G [00:02<00:28, 168MB/s]
#
# Downloading model.fp16.safetensors:  23%|▉   | 315M/1.39G [00:02<00:07, 152MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 315M/5.14G [00:02<00:29, 163MB/s]
#
# Downloading model.fp16.safetensors:  24%|▉   | 336M/1.39G [00:02<00:06, 165MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 336M/5.14G [00:02<00:27, 172MB/s]
#
# Downloading model.fp16.safetensors:  26%|█   | 357M/1.39G [00:03<00:05, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 357M/5.14G [00:02<00:26, 179MB/s]
#
# Downloading model.fp16.safetensors:  27%|█   | 377M/1.39G [00:03<00:05, 179MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 377M/5.14G [00:02<00:25, 185MB/s]
#
# Downloading model.fp16.safetensors:  29%|█▏  | 398M/1.39G [00:03<00:05, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 409M/5.14G [00:03<00:24, 194MB/s]
#
# Downloading model.fp16.safetensors:  30%|█▏  | 419M/1.39G [00:03<00:05, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▎  | 430M/5.14G [00:03<00:24, 194MB/s]
#
# Downloading model.fp16.safetensors:  32%|█▎  | 440M/1.39G [00:03<00:04, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 451M/5.14G [00:03<00:23, 196MB/s]
#
# Downloading model.fp16.safetensors:  34%|█▎  | 472M/1.39G [00:03<00:04, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 472M/5.14G [00:03<00:23, 196MB/s]
#
# Downloading model.fp16.safetensors:  35%|█▍  | 493M/1.39G [00:03<00:04, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 493M/5.14G [00:03<00:25, 180MB/s]
#
# Downloading model.fp16.safetensors:  37%|█▍  | 514M/1.39G [00:03<00:05, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 514M/5.14G [00:03<00:27, 170MB/s]
#
# Downloading model.fp16.safetensors:  38%|█▌  | 535M/1.39G [00:04<00:05, 161MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 535M/5.14G [00:03<00:28, 163MB/s]
#
# Downloading model.fp16.safetensors:  40%|█▌  | 556M/1.39G [00:04<00:05, 156MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 556M/5.14G [00:04<00:28, 158MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 577M/5.14G [00:04<00:28, 159MB/s]
#
# Downloading model.fp16.safetensors:  42%|█▋  | 577M/1.39G [00:04<00:05, 152MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 598M/5.14G [00:04<00:30, 151MB/s]
#
# Downloading model.fp16.safetensors:  43%|█▋  | 598M/1.39G [00:04<00:05, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 619M/5.14G [00:04<00:29, 154MB/s]
#
# Downloading model.fp16.safetensors:  45%|█▊  | 619M/1.39G [00:04<00:05, 147MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 640M/5.14G [00:04<00:29, 154MB/s]
#
# Downloading model.fp16.safetensors:  46%|█▊  | 640M/1.39G [00:04<00:04, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 661M/5.14G [00:04<00:29, 152MB/s]
#
# Downloading model.fp16.safetensors:  48%|█▉  | 661M/1.39G [00:04<00:04, 152MB/s]
#
# Downloading model.fp16.safetensors:  49%|█▉  | 682M/1.39G [00:05<00:04, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 682M/5.14G [00:04<00:29, 149MB/s]
#
# Downloading model.fp16.safetensors:  51%|██  | 703M/1.39G [00:05<00:04, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 703M/5.14G [00:04<00:29, 150MB/s]
#
# Downloading model.fp16.safetensors:  52%|██  | 724M/1.39G [00:05<00:04, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 724M/5.14G [00:05<00:29, 152MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 744M/5.14G [00:05<00:28, 152MB/s]
#
# Downloading model.fp16.safetensors:  54%|██▏ | 744M/1.39G [00:05<00:04, 149MB/s]
#
# Downloading model.fp16.safetensors:  55%|██▏ | 765M/1.39G [00:05<00:04, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 765M/5.14G [00:05<00:28, 152MB/s]
#
# Downloading model.fp16.safetensors:  57%|██▎ | 786M/1.39G [00:05<00:03, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 786M/5.14G [00:05<00:28, 151MB/s]
#
# Downloading model.fp16.safetensors:  58%|██▎ | 807M/1.39G [00:05<00:03, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 807M/5.14G [00:05<00:28, 151MB/s]
#
# Downloading model.fp16.safetensors:  60%|██▍ | 828M/1.39G [00:06<00:03, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 828M/5.14G [00:05<00:28, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▍  | 849M/5.14G [00:05<00:28, 151MB/s]
#
# Downloading model.fp16.safetensors:  61%|██▍ | 849M/1.39G [00:06<00:03, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 870M/5.14G [00:06<00:27, 154MB/s]
#
# Downloading model.fp16.safetensors:  63%|██▌ | 870M/1.39G [00:06<00:03, 138MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 891M/5.14G [00:06<00:37, 114MB/s]
#
# Downloading model.fp16.safetensors:  64%|██▌ | 891M/1.39G [00:06<00:04, 107MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 912M/5.14G [00:06<00:36, 115MB/s]
#
# Downloading model.fp16.safetensors:  66%|██▋ | 912M/1.39G [00:06<00:04, 113MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 933M/5.14G [00:06<00:34, 122MB/s]
#
# Downloading model.fp16.safetensors:  67%|██▋ | 933M/1.39G [00:06<00:03, 123MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 954M/5.14G [00:06<00:34, 123MB/s]
#
# Downloading model.fp16.safetensors:  69%|██▋ | 954M/1.39G [00:07<00:03, 127MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 975M/5.14G [00:07<00:33, 125MB/s]
#
# Downloading model.fp16.safetensors:  70%|██▊ | 975M/1.39G [00:07<00:03, 129MB/s]
#
# Downloading model.fp16.safetensors:  72%|██▊ | 996M/1.39G [00:07<00:02, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 996M/5.14G [00:07<00:32, 128MB/s]
#
# Downloading model.fp16.safetensors:  73%|██▏| 1.02G/1.39G [00:07<00:02, 145MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.02G/5.14G [00:07<00:31, 130MB/s]
#
# Downloading model.fp16.safetensors:  75%|██▏| 1.04G/1.39G [00:07<00:02, 142MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.04G/5.14G [00:07<00:29, 140MB/s]
#
# Downloading model.fp16.safetensors:  76%|██▎| 1.06G/1.39G [00:07<00:02, 149MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.06G/5.14G [00:07<00:28, 141MB/s]
#
# Downloading model.fp16.safetensors:  78%|██▎| 1.08G/1.39G [00:07<00:02, 149MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.08G/5.14G [00:07<00:28, 142MB/s]
#
# Downloading model.fp16.safetensors:  79%|██▍| 1.10G/1.39G [00:08<00:01, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.10G/5.14G [00:07<00:27, 147MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.12G/5.14G [00:07<00:24, 161MB/s]
#
# Downloading model.fp16.safetensors:  81%|██▍| 1.12G/1.39G [00:08<00:01, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.14G/5.14G [00:08<00:23, 170MB/s]
#
# Downloading model.fp16.safetensors:  82%|██▍| 1.14G/1.39G [00:08<00:01, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.16G/5.14G [00:08<00:22, 178MB/s]
#
# Downloading model.fp16.safetensors:  84%|██▌| 1.16G/1.39G [00:08<00:01, 170MB/s]
#
# Downloading model.fp16.safetensors:  85%|██▌| 1.18G/1.39G [00:08<00:01, 177MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.18G/5.14G [00:08<00:22, 179MB/s]
#
# Downloading model.fp16.safetensors:  87%|██▌| 1.21G/1.39G [00:08<00:01, 183MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.21G/5.14G [00:08<00:21, 185MB/s]
#
# Downloading model.fp16.safetensors:  88%|██▋| 1.23G/1.39G [00:08<00:00, 189MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.23G/5.14G [00:08<00:20, 189MB/s]
#
# Downloading model.fp16.safetensors:  90%|██▋| 1.25G/1.39G [00:08<00:00, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.25G/5.14G [00:08<00:20, 194MB/s]
#
# Downloading model.fp16.safetensors:  91%|██▋| 1.27G/1.39G [00:08<00:00, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.27G/5.14G [00:08<00:19, 197MB/s]
#
# Downloading model.fp16.safetensors:  93%|██▊| 1.29G/1.39G [00:09<00:00, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 1.29G/5.14G [00:08<00:19, 195MB/s]
#
# Downloading model.fp16.safetensors:  94%|██▊| 1.31G/1.39G [00:09<00:00, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.31G/5.14G [00:08<00:19, 196MB/s]
#
# Downloading model.fp16.safetensors:  96%|██▉| 1.33G/1.39G [00:09<00:00, 202MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.33G/5.14G [00:09<00:19, 192MB/s]
#
# Downloading model.fp16.safetensors:  97%|██▉| 1.35G/1.39G [00:09<00:00, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.35G/5.14G [00:09<00:19, 192MB/s]
#
# Downloading model.fp16.safetensors:  99%|██▉| 1.37G/1.39G [00:09<00:00, 188MB/s]
#
#
#
# Downloading model.fp16.safetensors: 100%|███| 1.39G/1.39G [00:09<00:00, 145MB/s]
# Fetching 19 files:  32%|███████▉                 | 6/19 [00:09<00:26,  2.06s/it]
#
#
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.39G/5.14G [00:09<00:19, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.42G/5.14G [00:09<00:18, 200MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.45G/5.14G [00:09<00:17, 206MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.47G/5.14G [00:09<00:17, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.50G/5.14G [00:09<00:17, 208MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.52G/5.14G [00:09<00:17, 208MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.55G/5.14G [00:10<00:17, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.57G/5.14G [00:10<00:20, 171MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.59G/5.14G [00:10<00:24, 144MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 1.61G/5.14G [00:10<00:28, 126MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  32%|▋ | 1.64G/5.14G [00:10<00:31, 111MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.66G/5.14G [00:11<00:36, 95.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.68G/5.14G [00:11<00:42, 81.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.69G/5.14G [00:11<00:47, 72.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.70G/5.14G [00:12<00:53, 64.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.71G/5.14G [00:12<00:56, 61.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.72G/5.14G [00:12<00:56, 60.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.73G/5.14G [00:12<00:55, 61.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.74G/5.14G [00:12<00:52, 65.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.76G/5.14G [00:12<00:36, 91.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.79G/5.14G [00:13<00:26, 126MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.81G/5.14G [00:13<00:23, 144MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  36%|▋ | 1.84G/5.14G [00:13<00:20, 159MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  36%|▋ | 1.87G/5.14G [00:13<00:18, 175MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.89G/5.14G [00:13<00:18, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.91G/5.14G [00:13<00:18, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.93G/5.14G [00:13<00:25, 127MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.95G/5.14G [00:14<00:27, 116MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.97G/5.14G [00:14<00:26, 120MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  39%|▊ | 1.99G/5.14G [00:14<00:24, 127MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  39%|▊ | 2.01G/5.14G [00:14<00:23, 136MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.03G/5.14G [00:14<00:21, 142MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.06G/5.14G [00:14<00:20, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.08G/5.14G [00:14<00:19, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  41%|▊ | 2.10G/5.14G [00:15<00:19, 157MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  41%|▊ | 2.12G/5.14G [00:15<00:18, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  42%|▊ | 2.14G/5.14G [00:15<00:17, 172MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  42%|▊ | 2.16G/5.14G [00:15<00:17, 175MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  42%|▊ | 2.18G/5.14G [00:15<00:16, 181MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  43%|▊ | 2.20G/5.14G [00:15<00:16, 181MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  43%|▊ | 2.22G/5.14G [00:15<00:15, 185MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▊ | 2.24G/5.14G [00:15<00:15, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 2.26G/5.14G [00:15<00:15, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  45%|▉ | 2.29G/5.14G [00:16<00:14, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  45%|▉ | 2.31G/5.14G [00:16<00:15, 181MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  45%|▉ | 2.33G/5.14G [00:16<00:15, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  46%|▉ | 2.35G/5.14G [00:16<00:18, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  46%|▉ | 2.37G/5.14G [00:16<00:17, 160MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  47%|▉ | 2.39G/5.14G [00:16<00:16, 169MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  47%|▉ | 2.41G/5.14G [00:16<00:15, 177MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  47%|▉ | 2.43G/5.14G [00:16<00:14, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  48%|▉ | 2.45G/5.14G [00:17<00:14, 185MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  48%|▉ | 2.47G/5.14G [00:17<00:14, 188MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  49%|▉ | 2.50G/5.14G [00:17<00:13, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  49%|▉ | 2.52G/5.14G [00:17<00:13, 188MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  49%|▍| 2.54G/5.14G [00:19<01:42, 25.4MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|▍| 2.56G/5.14G [00:20<01:25, 30.2MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|▌| 2.58G/5.14G [00:21<01:53, 22.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|▌| 2.59G/5.14G [00:21<01:38, 25.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.61G/5.14G [00:22<01:11, 35.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  51%|▌| 2.63G/5.14G [00:22<00:52, 47.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.65G/5.14G [00:23<01:34, 26.2MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  52%|▌| 2.67G/5.14G [00:23<01:09, 35.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.71G/5.14G [00:23<00:45, 53.5MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.74G/5.14G [00:24<00:32, 73.4MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.76G/5.14G [00:24<00:27, 88.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  54%|█ | 2.79G/5.14G [00:24<00:21, 111MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  55%|█ | 2.81G/5.14G [00:24<00:18, 125MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  55%|█ | 2.84G/5.14G [00:24<00:15, 146MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█ | 2.87G/5.14G [00:24<00:14, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  57%|█▏| 2.90G/5.14G [00:24<00:12, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  57%|█▏| 2.93G/5.14G [00:25<00:12, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  57%|█▏| 2.95G/5.14G [00:25<00:12, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  58%|█▏| 2.97G/5.14G [00:25<00:11, 184MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  58%|█▏| 2.99G/5.14G [00:25<00:11, 184MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  59%|█▏| 3.01G/5.14G [00:25<00:11, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  59%|█▏| 3.04G/5.14G [00:25<00:10, 200MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  60%|█▏| 3.06G/5.14G [00:25<00:10, 202MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  60%|█▏| 3.09G/5.14G [00:25<00:09, 207MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  61%|█▏| 3.11G/5.14G [00:25<00:09, 206MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  61%|█▏| 3.14G/5.14G [00:26<00:09, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  61%|█▏| 3.16G/5.14G [00:26<00:09, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  62%|█▏| 3.18G/5.14G [00:26<00:09, 205MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  62%|█▏| 3.21G/5.14G [00:26<00:09, 208MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▎| 3.24G/5.14G [00:26<00:09, 207MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  64%|█▎| 3.27G/5.14G [00:26<00:08, 209MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  64%|█▎| 3.29G/5.14G [00:26<00:08, 209MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  65%|█▎| 3.31G/5.14G [00:26<00:08, 209MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  65%|█▎| 3.33G/5.14G [00:27<00:08, 207MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  66%|█▎| 3.37G/5.14G [00:27<00:08, 211MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  66%|█▎| 3.40G/5.14G [00:27<00:08, 212MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  67%|█▎| 3.43G/5.14G [00:27<00:08, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  67%|█▎| 3.46G/5.14G [00:27<00:07, 213MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  68%|█▎| 3.49G/5.14G [00:27<00:07, 212MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|█▎| 3.52G/5.14G [00:27<00:07, 213MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|█▍| 3.55G/5.14G [00:28<00:07, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  70%|█▍| 3.59G/5.14G [00:28<00:07, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  70%|█▍| 3.62G/5.14G [00:28<00:07, 213MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  71%|█▍| 3.65G/5.14G [00:28<00:07, 212MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  72%|█▍| 3.68G/5.14G [00:28<00:06, 214MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  72%|█▍| 3.71G/5.14G [00:28<00:06, 211MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  73%|█▍| 3.74G/5.14G [00:28<00:06, 214MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  74%|█▍| 3.77G/5.14G [00:29<00:06, 211MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  74%|█▍| 3.81G/5.14G [00:29<00:06, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|█▍| 3.84G/5.14G [00:29<00:06, 212MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|█▌| 3.87G/5.14G [00:29<00:05, 215MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  76%|█▌| 3.90G/5.14G [00:29<00:05, 211MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  77%|█▌| 3.93G/5.14G [00:29<00:05, 209MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  77%|█▌| 3.95G/5.14G [00:29<00:05, 198MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  77%|█▌| 3.97G/5.14G [00:30<00:06, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  78%|█▌| 4.00G/5.14G [00:30<00:05, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  78%|█▌| 4.02G/5.14G [00:30<00:05, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  79%|█▌| 4.04G/5.14G [00:30<00:05, 199MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  79%|█▌| 4.06G/5.14G [00:30<00:05, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.09G/5.14G [00:30<00:05, 206MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.11G/5.14G [00:30<00:04, 205MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.13G/5.14G [00:30<00:04, 206MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|█▌| 4.16G/5.14G [00:31<00:04, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  82%|█▋| 4.19G/5.14G [00:31<00:04, 211MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  82%|█▋| 4.23G/5.14G [00:31<00:04, 209MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  83%|█▋| 4.25G/5.14G [00:31<00:04, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  83%|█▋| 4.27G/5.14G [00:31<00:04, 199MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  84%|█▋| 4.29G/5.14G [00:31<00:04, 199MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  84%|█▋| 4.31G/5.14G [00:31<00:04, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  84%|█▋| 4.33G/5.14G [00:31<00:04, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  85%|█▋| 4.35G/5.14G [00:31<00:03, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  85%|█▋| 4.37G/5.14G [00:32<00:03, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  86%|█▋| 4.39G/5.14G [00:32<00:03, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  86%|█▋| 4.41G/5.14G [00:32<00:03, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  86%|█▋| 4.44G/5.14G [00:32<00:03, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  87%|█▋| 4.46G/5.14G [00:32<00:03, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  87%|█▋| 4.48G/5.14G [00:32<00:03, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|█▊| 4.50G/5.14G [00:32<00:03, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|█▊| 4.52G/5.14G [00:32<00:03, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|█▊| 4.54G/5.14G [00:32<00:03, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  89%|█▊| 4.56G/5.14G [00:33<00:02, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  89%|█▊| 4.58G/5.14G [00:33<00:02, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  90%|█▊| 4.60G/5.14G [00:33<00:02, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  90%|█▊| 4.62G/5.14G [00:33<00:02, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  90%|█▊| 4.65G/5.14G [00:33<00:02, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  91%|█▊| 4.67G/5.14G [00:33<00:02, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  91%|█▊| 4.69G/5.14G [00:33<00:02, 200MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.71G/5.14G [00:33<00:02, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.73G/5.14G [00:33<00:02, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.75G/5.14G [00:34<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.77G/5.14G [00:34<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.79G/5.14G [00:34<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.81G/5.14G [00:34<00:01, 198MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.83G/5.14G [00:34<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.85G/5.14G [00:34<00:01, 189MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.88G/5.14G [00:34<00:01, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.90G/5.14G [00:34<00:01, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.92G/5.14G [00:34<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.94G/5.14G [00:35<00:01, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.96G/5.14G [00:35<00:00, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.99G/5.14G [00:35<00:00, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.01G/5.14G [00:35<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.04G/5.14G [00:35<00:00, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.08G/5.14G [00:35<00:00, 204MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.10G/5.14G [00:35<00:00, 205MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:36<00:00, 143MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:36<00:00,  1.92s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.68it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:42<00:00,  1.18it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.52it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.64it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.30it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.49it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.59it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.53it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.60it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.64it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.62it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
