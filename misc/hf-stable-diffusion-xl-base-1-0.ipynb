# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


prompts = [
    "A car in a field at night",
    "Night sky with a mountain in the background",
    "A street in New York City at Night",
    "A view of the earth from space",
    "Breaking Bad in the style of Anime",
    "A person standing atop a mountain looking into the valley below with a red sunset in the background",
    "Concept art of what a futuristic city woul look like at night",
    "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
    "Agent 47 from Hitman 3 at a location in Saudi Arabia",
    "Abstract artwork which is extremely colorful using a tiger as the subject",
]


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.07MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.32MB/s]
#
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 3.29MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:02,  7.04it/s]
#
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 5.20MB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.25MB/s]
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 3.87MB/s]
#
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 5.35MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 2.90MB/s]
#
#
#
#
# Downloading (…)1d8/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 10.3MB/s]
#
#
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:16, 83.4MB/s]
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:02, 79.0MB/s]
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 4.11MB/s]
#
#
#
#
# Downloading (…)81d8/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 3.56MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   2%|  | 21.0M/1.39G [00:00<00:14, 93.1MB/s]
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 5.64MB/s]
#
#
# Downloading model.fp16.safetensors:  13%|▌   | 31.5M/246M [00:00<00:01, 117MB/s]
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:13, 69.5MB/s]
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 60.8MB/s]
#
#
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:16, 83.3MB/s]
#
# Downloading model.fp16.safetensors:  21%|▊   | 52.4M/246M [00:00<00:01, 101MB/s]
#
#
#
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 5.76MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:23, 61.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 71.5MB/s]
#
# Downloading model.fp16.safetensors:  30%|█▏  | 73.4M/246M [00:00<00:01, 112MB/s]
#
#
# Downloading model.fp16.safetensors:   5%|  | 62.9M/1.39G [00:00<00:13, 94.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<00:56, 89.4MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 94.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:03, 40.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 52.4M/5.14G [00:00<00:54, 93.1MB/s]
#
# Downloading model.fp16.safetensors:  38%|█▌  | 94.4M/246M [00:00<00:01, 115MB/s]
#
#
# Downloading model.fp16.safetensors:   6%|▏  | 83.9M/1.39G [00:00<00:12, 106MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 62.9M/5.14G [00:00<00:55, 92.1MB/s]
# Downloading (…)del.fp16.safetensors:  38%|█▏ | 62.9M/167M [00:00<00:00, 107MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 55.1MB/s]
#
# Downloading model.fp16.safetensors:  47%|██▎  | 115M/246M [00:01<00:01, 113MB/s]
#
#
# Downloading model.fp16.safetensors:   8%|▎   | 105M/1.39G [00:01<00:12, 101MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▍ | 31.5M/167M [00:00<00:01, 68.3MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 83.9M/5.14G [00:00<00:48, 104MB/s]
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 107MB/s]
#
#
# Downloading model.fp16.safetensors:   8%|▏  | 115M/1.39G [00:01<00:12, 99.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 75.8MB/s]
#
# Downloading model.fp16.safetensors:  55%|██▊  | 136M/246M [00:01<00:00, 113MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|   | 105M/5.14G [00:01<00:45, 111MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 79.2MB/s]
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 95.7MB/s]
#
#
# Downloading model.fp16.safetensors:  10%|▎  | 136M/1.39G [00:01<00:13, 93.1MB/s]
#
# Downloading model.fp16.safetensors:  64%|███▏ | 157M/246M [00:01<00:00, 103MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 71.4MB/s]
#
#
# Downloading model.fp16.safetensors:  11%|▎  | 147M/1.39G [00:01<00:13, 94.2MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 126M/5.14G [00:01<00:50, 98.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:01<00:01, 79.3MB/s]
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 99.5MB/s]
#
# Downloading model.fp16.safetensors:  72%|███▌ | 178M/246M [00:01<00:00, 108MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 136M/5.14G [00:01<00:53, 93.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 83.9M/167M [00:01<00:01, 80.8MB/s]
#
#
# Downloading model.fp16.safetensors:  12%|▎  | 168M/1.39G [00:01<00:12, 97.2MB/s]
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 104MB/s]
#
# Downloading model.fp16.safetensors:  81%|████ | 199M/246M [00:01<00:00, 109MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 157M/5.14G [00:01<00:51, 96.3MB/s]
#
#
# Downloading model.fp16.safetensors:  13%|▍  | 178M/1.39G [00:01<00:13, 89.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 87.1MB/s]
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 101MB/s]
#
#
# Downloading model.fp16.safetensors:  89%|████▍| 220M/246M [00:02<00:00, 109MB/s]
#
#
# Downloading model.fp16.safetensors:  14%|▌   | 199M/1.39G [00:02<00:11, 102MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|   | 178M/5.14G [00:01<00:47, 104MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 94.4MB/s]
#
# Downloading model.fp16.safetensors:  98%|████▉| 241M/246M [00:02<00:00, 118MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 199M/5.14G [00:01<00:43, 114MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 110MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:10,  1.36it/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 107MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|▏  | 220M/5.14G [00:02<00:38, 127MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▋   | 241M/1.39G [00:02<00:09, 122MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 90.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 241M/5.14G [00:02<00:35, 137MB/s]
#
#
# Downloading model.fp16.safetensors:  19%|▊   | 262M/1.39G [00:02<00:08, 133MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 262M/5.14G [00:02<00:34, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  21%|▊   | 294M/1.39G [00:02<00:06, 157MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 283M/5.14G [00:02<00:30, 157MB/s]
#
#
# Downloading model.fp16.safetensors:  23%|▉   | 315M/1.39G [00:02<00:06, 168MB/s]
#
#
# Downloading model.fp16.safetensors:  24%|▉   | 336M/1.39G [00:02<00:05, 177MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 315M/5.14G [00:02<00:27, 175MB/s]
#
#
# Downloading model.fp16.safetensors:  26%|█   | 357M/1.39G [00:02<00:05, 183MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 346M/5.14G [00:02<00:25, 189MB/s]
#
#
# Downloading model.fp16.safetensors:  27%|█   | 377M/1.39G [00:03<00:05, 188MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 377M/5.14G [00:02<00:24, 195MB/s]
#
#
# Downloading model.fp16.safetensors:  29%|█▏  | 409M/1.39G [00:03<00:04, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 398M/5.14G [00:03<00:23, 198MB/s]
#
#
# Downloading model.fp16.safetensors:  31%|█▏  | 430M/1.39G [00:03<00:04, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▎  | 430M/5.14G [00:03<00:23, 204MB/s]
#
#
# Downloading model.fp16.safetensors:  32%|█▎  | 451M/1.39G [00:03<00:04, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 451M/5.14G [00:03<00:23, 199MB/s]
#
#
# Downloading model.fp16.safetensors:  34%|█▎  | 472M/1.39G [00:03<00:05, 181MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 472M/5.14G [00:03<00:25, 182MB/s]
#
#
# Downloading model.fp16.safetensors:  35%|█▍  | 493M/1.39G [00:03<00:05, 166MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 493M/5.14G [00:03<00:27, 172MB/s]
#
#
# Downloading model.fp16.safetensors:  37%|█▍  | 514M/1.39G [00:03<00:05, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 514M/5.14G [00:03<00:29, 155MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▌  | 535M/1.39G [00:03<00:05, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 535M/5.14G [00:03<00:30, 153MB/s]
#
#
# Downloading model.fp16.safetensors:  40%|█▌  | 556M/1.39G [00:04<00:05, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 556M/5.14G [00:04<00:30, 149MB/s]
#
#
# Downloading model.fp16.safetensors:  42%|█▋  | 577M/1.39G [00:04<00:05, 147MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 577M/5.14G [00:04<00:30, 151MB/s]
#
#
# Downloading model.fp16.safetensors:  43%|█▋  | 598M/1.39G [00:04<00:05, 135MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 598M/5.14G [00:04<00:31, 146MB/s]
#
#
# Downloading model.fp16.safetensors:  45%|█▊  | 619M/1.39G [00:04<00:05, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 619M/5.14G [00:04<00:31, 145MB/s]
#
#
# Downloading model.fp16.safetensors:  46%|█▊  | 640M/1.39G [00:04<00:05, 139MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 640M/5.14G [00:04<00:31, 141MB/s]
#
#
# Downloading model.fp16.safetensors:  48%|█▉  | 661M/1.39G [00:04<00:05, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 661M/5.14G [00:04<00:31, 143MB/s]
#
#
# Downloading model.fp16.safetensors:  49%|█▉  | 682M/1.39G [00:05<00:04, 144MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 682M/5.14G [00:04<00:30, 146MB/s]
#
#
# Downloading model.fp16.safetensors:  51%|██  | 703M/1.39G [00:05<00:05, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 703M/5.14G [00:05<00:31, 142MB/s]
#
#
# Downloading model.fp16.safetensors:  52%|██  | 724M/1.39G [00:05<00:04, 140MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 724M/5.14G [00:05<00:31, 141MB/s]
#
#
# Downloading model.fp16.safetensors:  54%|██▏ | 744M/1.39G [00:05<00:04, 138MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 744M/5.14G [00:05<00:29, 147MB/s]
#
#
# Downloading model.fp16.safetensors:  55%|██▏ | 765M/1.39G [00:05<00:04, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 765M/5.14G [00:05<00:30, 145MB/s]
#
#
# Downloading model.fp16.safetensors:  57%|██▎ | 786M/1.39G [00:05<00:04, 136MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 786M/5.14G [00:05<00:29, 147MB/s]
#
#
# Downloading model.fp16.safetensors:  58%|██▎ | 807M/1.39G [00:05<00:04, 143MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 807M/5.14G [00:05<00:29, 149MB/s]
#
#
# Downloading model.fp16.safetensors:  60%|██▍ | 828M/1.39G [00:06<00:03, 142MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 828M/5.14G [00:05<00:29, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▍  | 849M/5.14G [00:06<00:27, 155MB/s]
#
#
# Downloading model.fp16.safetensors:  61%|██▍ | 849M/1.39G [00:06<00:03, 146MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 870M/5.14G [00:06<00:25, 167MB/s]
#
#
# Downloading model.fp16.safetensors:  63%|██▌ | 870M/1.39G [00:06<00:03, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 891M/5.14G [00:06<00:23, 178MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|██▌ | 891M/1.39G [00:06<00:03, 165MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 912M/5.14G [00:06<00:23, 184MB/s]
#
#
# Downloading model.fp16.safetensors:  66%|██▋ | 912M/1.39G [00:06<00:02, 174MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 933M/5.14G [00:06<00:22, 189MB/s]
#
#
# Downloading model.fp16.safetensors:  67%|██▋ | 933M/1.39G [00:06<00:02, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 954M/5.14G [00:06<00:22, 190MB/s]
#
#
# Downloading model.fp16.safetensors:  69%|██▋ | 954M/1.39G [00:06<00:02, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 975M/5.14G [00:06<00:21, 194MB/s]
#
#
# Downloading model.fp16.safetensors:  70%|██▊ | 975M/1.39G [00:06<00:02, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 996M/5.14G [00:06<00:21, 196MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|██▊ | 996M/1.39G [00:06<00:01, 197MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.02G/5.14G [00:06<00:21, 196MB/s]
#
#
# Downloading model.fp16.safetensors:  73%|██▏| 1.02G/1.39G [00:07<00:01, 199MB/s]
#
#
# Downloading model.fp16.safetensors:  75%|██▏| 1.04G/1.39G [00:07<00:01, 200MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.05G/5.14G [00:07<00:20, 200MB/s]
#
#
# Downloading model.fp16.safetensors:  76%|██▎| 1.06G/1.39G [00:07<00:01, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.07G/5.14G [00:07<00:20, 198MB/s]
#
#
# Downloading model.fp16.safetensors:  78%|██▎| 1.08G/1.39G [00:07<00:01, 201MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.09G/5.14G [00:07<00:20, 199MB/s]
#
#
# Downloading model.fp16.safetensors:  79%|██▍| 1.10G/1.39G [00:07<00:01, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.11G/5.14G [00:07<00:20, 198MB/s]
#
#
# Downloading model.fp16.safetensors:  81%|██▍| 1.12G/1.39G [00:07<00:01, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.13G/5.14G [00:07<00:20, 198MB/s]
#
#
# Downloading model.fp16.safetensors:  82%|██▍| 1.14G/1.39G [00:07<00:01, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.16G/5.14G [00:07<00:19, 204MB/s]
#
#
# Downloading model.fp16.safetensors:  84%|██▌| 1.16G/1.39G [00:07<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.18G/5.14G [00:07<00:19, 205MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|██▌| 1.18G/1.39G [00:07<00:01, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.21G/5.14G [00:07<00:19, 204MB/s]
#
#
# Downloading model.fp16.safetensors:  87%|██▌| 1.21G/1.39G [00:08<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.23G/5.14G [00:07<00:19, 205MB/s]
#
#
# Downloading model.fp16.safetensors:  88%|██▋| 1.23G/1.39G [00:08<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.25G/5.14G [00:07<00:19, 204MB/s]
#
#
# Downloading model.fp16.safetensors:  90%|██▋| 1.25G/1.39G [00:08<00:00, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.27G/5.14G [00:08<00:20, 189MB/s]
#
#
# Downloading model.fp16.safetensors:  91%|██▋| 1.27G/1.39G [00:08<00:00, 177MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 1.29G/5.14G [00:08<00:22, 170MB/s]
#
#
# Downloading model.fp16.safetensors:  93%|██▊| 1.29G/1.39G [00:08<00:00, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.31G/5.14G [00:08<00:27, 141MB/s]
#
#
# Downloading model.fp16.safetensors:  94%|██▊| 1.31G/1.39G [00:08<00:00, 133MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.33G/5.14G [00:08<00:29, 127MB/s]
#
#
# Downloading model.fp16.safetensors:  96%|██▉| 1.33G/1.39G [00:08<00:00, 122MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.35G/5.14G [00:08<00:31, 120MB/s]
#
#
# Downloading model.fp16.safetensors:  97%|██▉| 1.35G/1.39G [00:09<00:00, 114MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.37G/5.14G [00:09<00:32, 114MB/s]
#
#
# Downloading model.fp16.safetensors:  99%|██▉| 1.37G/1.39G [00:09<00:00, 115MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.39G/5.14G [00:09<00:34, 107MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|███| 1.39G/1.39G [00:09<00:00, 145MB/s]
# Fetching 19 files:  32%|███████▉                 | 6/19 [00:09<00:27,  2.08s/it]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.42G/5.14G [00:09<00:33, 111MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.44G/5.14G [00:09<00:32, 113MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.46G/5.14G [00:09<00:31, 117MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.48G/5.14G [00:10<00:31, 116MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.50G/5.14G [00:10<00:29, 122MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.52G/5.14G [00:10<00:30, 118MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.54G/5.14G [00:10<00:26, 135MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.56G/5.14G [00:10<00:23, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.58G/5.14G [00:10<00:22, 159MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.60G/5.14G [00:10<00:21, 164MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  32%|▋ | 1.63G/5.14G [00:10<00:20, 173MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  32%|▋ | 1.65G/5.14G [00:11<00:19, 178MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  32%|▋ | 1.67G/5.14G [00:11<00:18, 185MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▋ | 1.69G/5.14G [00:11<00:19, 178MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  33%|▋ | 1.72G/5.14G [00:11<00:17, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  34%|▋ | 1.75G/5.14G [00:11<00:16, 203MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.78G/5.14G [00:11<00:15, 210MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.81G/5.14G [00:11<00:15, 213MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  36%|▋ | 1.85G/5.14G [00:11<00:15, 216MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.88G/5.14G [00:12<00:14, 219MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.91G/5.14G [00:12<00:15, 214MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.94G/5.14G [00:12<00:14, 215MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:
B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.74G/5.14G [00:28<00:02, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.76G/5.14G [00:28<00:01, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.78G/5.14G [00:28<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.80G/5.14G [00:29<00:01, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.82G/5.14G [00:29<00:01, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.84G/5.14G [00:29<00:01, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.87G/5.14G [00:29<00:01, 189MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.89G/5.14G [00:29<00:01, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.91G/5.14G [00:29<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.93G/5.14G [00:29<00:01, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.95G/5.14G [00:29<00:00, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.97G/5.14G [00:29<00:00, 198MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.99G/5.14G [00:30<00:00, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.01G/5.14G [00:30<00:00, 183MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.03G/5.14G [00:30<00:00, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.05G/5.14G [00:30<00:00, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.08G/5.14G [00:30<00:00, 168MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.10G/5.14G [00:30<00:00, 175MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:30<00:00, 166MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:31<00:00,  1.66s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.49it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:42<00:00,  1.17it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.79it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.11it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.36it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.43it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:48<00:00,  1.04it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.95it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.45it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.60it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.58it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.64it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.19it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
