# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# # Version 3

# prompts: list = [
#     "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
#     "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
#     "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
#     "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
#     "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
#     "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
#     "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
#     "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
#     "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
#     "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
# ]

# %%
# # Version 4

# prompts: list = [
#     "A city at night, dark sky, people watching in wonder, very detailed, 8k, concept art",
#     "A city at night big moon and stars at the borders, concept art, dark, creepy, atmospheric, 8k, HD",
#     "A city at night, small lamp posts, burning church, street lamps, 4 k, concept art, sparse vegetation",
#     "A city at night, low green clouds, dark red sky, night, 4k, high details, fireflies, art by WLOP,",
#     "A city at night, dark moonlight, sky full of stars at the edges, concept art, 4k, octane render, digital painting,",
#     "A city at night, big moon on the right, meteor fall, trending on artstation, 8k, cinematic, soft, sharp focus, insanely",
#     "A city at night, huge moon, stars at the horizon, 4k, 8k, trending on Artstation",
#     "A city at night during a nuclear eruption, intricate Asteroid belt with huge rings in the sky, water and beautiful pink blobs, flying cars,",
#     "A city at night with cumulonimbus clouds in the sky, night colors, stars in the sky, painting by tyler edlin,",
#     "A city at night, moonlight, street lamps, falling leaves, wide angle, super highly detailed, professional digital painting, artstation, concept art",
# ]

# %%
# # Version 5

# prompts: list = [
#     "A picturesque night sky over a full moon",
#     "A picturesque night sky with planets visible in the background, stars in the sky",
#     "A picturesque night sky, small waterfall, mist, candlelight, celestial highlights, painting in style of krenz cushart, ilya",
#     "A picturesque night sky, low angle, dawn, stars in the night sky, realistic, detailed faces, moody, atmospheric, cinematic, wide",
#     "A picturesque night sky overimpel forest",
#     "A picturesque night sky over the sea, stars bloom in the background, natural, ultra detail. ethereal",
#     "A picturesque night sky with constellations, small camp is built beside. In style of Yoji Shinkawa and Hyung-tae",
#     "A picturesque night sky with constellations, stars Asteroid belt with huge rings and beautiful draped clouds, anime, fountain, statue, underwater,",
#     "A picturesque night sky with stars visible through shattered clouds",
#     "A picturesque night sky overland, low poly, isometric art",
# ]

# %%
# # Version 6

# prompts: list = [
#     "A car in a field at night illuminated by vibrant glowing lights in the distance.",
#     "A car in a field at night with a moon and highly detailed",
#     "A car in a field at night illuminated by glowing headlights",
#     "A car in a field at night, a big moon in the background. Vibrant colors",
#     "A car in a field at night illuminated by glowing headlights of organic matte liquid metal and shiny gold and a blue glow emanates from the metal",
#     "A car in a field at night illuminated by a street lamp, camera flashes from behind, concept art, intricate, digital painting, cinematic lighting, dark",
#     "A car in a field at night with moon in the lights, underexposed, desolated wasteland",
#     "A car in a field at night illuminated by a street light, Asteroid belt, nebula in the distance, night colors, high - key lighting",
#     "A car in a field at night with a moon with soft adventurous and atmospheric lighting",
#     "A car in a field at night illuminated by flashes of lightning, pitchblack sky, extremly detailed digital photo",
# ]

# %%
# # Version 7

# prompts: list = [
#     "A person standing atop a mountain staring into a valley, mountain landscape, mountains in the background, highly detailed, high quality",
#     "A person standing atop a mountain staring into a valley, a detailed matte painting",
#     "A person standing atop a mountain staring into a valley, a detailed realistic painting",
#     "A person standing atop a mountain staring into a valley, mountain landscape, view, blue haze, sunset, a dystopian view",
#     "A person standing atop a mountain staring into a valley",
#     "A person standing atop a mountain staring into a valley, the sun is on the background",
#     "A person standing atop a mountain staring into a valley",
#     "A person standing atop a mountain staring into a valley, the leaves are falling, Asteroid belt",
#     "A person standing atop a mountain staring into a valley with a sunset. The sun is setting. The sky is filled with stars",
#     "A person standing atop a mountain staring into a valley, concept art",
# ]

# %%
# Version 8

prompts: list = [
    "The night sky with stars forming the shape of a cougar, night time",
    "The night sky with planets in the light is a strange blur, it's hard to see the stars and the ground is ablaze with constellations",
    "The night sky with stars forming the shape of Lyraa",
    "The night sky with stars around it, stars in the iridescent light beams illuminating its face, stars in the iridescent sky",
    "The night sky with constellations. Blue sky with constellations.",
    "The night sky with stars in the outer reaches of the solar system beyond, with galaxies in the sky, cinematic",
    "The night sky with stars forming the shape of a heart, extremely saturated colors",
    "The night sky with constellations, stars Asteroid belt and comets in the background, natural, ultra detail",
    "The night sky with stars, desaturated, psychedelic",
    "The night sky with stars that are black around it, stars with big blue stripes and constellations",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.50MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 3.04MB/s]
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 2.33MB/s]
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 4.76MB/s]
#
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.74MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:02,  7.34it/s]
#
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.96MB/s]
#
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 8.25MB/s]
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 3.91MB/s]
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 14.2MB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 2.95MB/s]
#
#
# Downloading (…)kenizer_2/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
# Downloading (…)76f/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 9.54MB/s]
#
#
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:02, 88.7MB/s]
#
#
#
# Downloading (…)d76f/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 2.82MB/s]
#
#
#
#
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 7.82MB/s]
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 12.9MB/s]
#
#
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:   2%|  | 21.0M/1.39G [00:00<00:15, 86.4MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:  13%|▌   | 31.5M/246M [00:00<00:01, 108MB/s]
# Downloading model.fp16.safetensors:   2%|  | 31.5M/1.39G [00:00<00:14, 91.6MB/s]
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:17, 65.7MB/s]
#
#
# Downloading model.fp16.safetensors:  17%|▋   | 41.9M/246M [00:00<00:02, 101MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 66.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 63.6MB/s]
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:14, 91.2MB/s]
#
#
# Downloading model.fp16.safetensors:  21%|▋  | 52.4M/246M [00:00<00:01, 98.9MB/s]
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:11, 71.4MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 80.4MB/s]
# Downloading model.fp16.safetensors:   4%|  | 52.4M/1.39G [00:00<00:14, 92.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 67.3MB/s]
#
# Downloading (…)del.fp16.safetensors:   1%| | 31.5M/5.14G [00:00<01:03, 80.9MB/s]
#
#
# Downloading model.fp16.safetensors:  30%|█▏  | 73.4M/246M [00:00<00:01, 106MB/s]
# Downloading model.fp16.safetensors:   5%|  | 62.9M/1.39G [00:00<00:14, 91.5MB/s]
#
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<00:58, 86.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 89.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 86.6MB/s]
#
# Downloading (…)del.fp16.safetensors:   1%| | 52.4M/5.14G [00:00<00:58, 87.0MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 92.0MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▌  | 94.4M/246M [00:00<00:01, 111MB/s]
# Downloading model.fp16.safetensors:   6%|▏  | 83.9M/1.39G [00:00<00:12, 102MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 94.9MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 89.2MB/s]
# Downloading model.fp16.safetensors:   7%|▏  | 94.4M/1.39G [00:00<00:12, 101MB/s]
#
# Downloading (…)del.fp16.safetensors:   1%|  | 73.4M/5.14G [00:00<00:49, 101MB/s]
#
#
# Downloading model.fp16.safetensors:  47%|██▎  | 115M/246M [00:01<00:01, 111MB/s]
# Downloading model.fp16.safetensors:   8%|▏  | 105M/1.39G [00:01<00:12, 99.8MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:00<00:01, 90.4MB/s]
#
# Downloading (…)del.fp16.safetensors:   2%|  | 83.9M/5.14G [00:00<00:49, 102MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 105MB/s]
# Downloading model.fp16.safetensors:   8%|▏  | 115M/1.39G [00:01<00:12, 98.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 83.9M/167M [00:00<00:00, 90.1MB/s]
#
#
# Downloading model.fp16.safetensors:  55%|██▊  | 136M/246M [00:01<00:01, 109MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█▋ | 94.4M/167M [00:00<00:00, 102MB/s]
#
# Downloading (…)del.fp16.safetensors:   2%|   | 105M/5.14G [00:01<00:46, 109MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  56%|█▏| 94.4M/167M [00:01<00:00, 89.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|██▌ | 105M/167M [00:01<00:00, 102MB/s]
# Downloading model.fp16.safetensors:  10%|▍   | 136M/1.39G [00:01<00:12, 100MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|█▉ | 105M/167M [00:01<00:00, 92.5MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|███▏ | 157M/246M [00:01<00:00, 105MB/s]
# Downloading model.fp16.safetensors:  11%|▍   | 147M/1.39G [00:01<00:12, 101MB/s]
#
# Downloading (…)del.fp16.safetensors:   2%|   | 126M/5.14G [00:01<00:47, 105MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  69%|██ | 115M/167M [00:01<00:00, 94.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|███ | 126M/167M [00:01<00:00, 106MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|██▎| 126M/167M [00:01<00:00, 96.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|██▍| 136M/167M [00:01<00:00, 99.4MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|███▌ | 178M/246M [00:01<00:00, 101MB/s]
#
# Downloading (…)del.fp16.safetensors:   3%|   | 147M/5.14G [00:01<00:45, 109MB/s]
# Downloading model.fp16.safetensors:  12%|▍   | 168M/1.39G [00:01<00:12, 101MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  81%|██▍| 136M/167M [00:01<00:00, 96.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 98.5MB/s]
#
#
# Downloading model.fp16.safetensors:  77%|███▊ | 189M/246M [00:01<00:00, 101MB/s]
# Downloading model.fp16.safetensors:  13%|▍  | 178M/1.39G [00:01<00:12, 97.4MB/s]
#
# Downloading (…)del.fp16.safetensors:   3%|   | 168M/5.14G [00:01<00:43, 115MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 97.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|██▊| 157M/167M [00:01<00:00, 97.7MB/s]
#
#
# Downloading model.fp16.safetensors:  85%|████▎| 210M/246M [00:02<00:00, 103MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 96.0MB/s]
#
# Downloading model.fp16.safetensors:  14%|▌   | 199M/1.39G [00:02<00:11, 103MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 90.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:  94%|████▋| 231M/246M [00:02<00:00, 109MB/s]
#
# Downloading (…)del.fp16.safetensors:   4%|   | 210M/5.14G [00:01<00:39, 125MB/s]
# Downloading model.fp16.safetensors:  16%|▋   | 220M/1.39G [00:02<00:10, 112MB/s]
#
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 107MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:11,  1.33it/s]
#
# Downloading (…)del.fp16.safetensors:   4%|▏  | 231M/5.14G [00:02<00:34, 141MB/s]
# Downloading model.fp16.safetensors:  17%|▋   | 241M/1.39G [00:02<00:09, 126MB/s]
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 252M/5.14G [00:02<00:31, 156MB/s]
# Downloading model.fp16.safetensors:  19%|▊   | 262M/1.39G [00:02<00:08, 140MB/s]
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 273M/5.14G [00:02<00:29, 168MB/s]
# Downloading model.fp16.safetensors:  20%|▊   | 283M/1.39G [00:02<00:07, 154MB/s]
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 294M/5.14G [00:02<00:27, 174MB/s]
# Downloading model.fp16.safetensors:  22%|▉   | 304M/1.39G [00:02<00:06, 165MB/s]
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 315M/5.14G [00:02<00:26, 182MB/s]
# Downloading model.fp16.safetensors:  23%|▉   | 325M/1.39G [00:02<00:06, 174MB/s]
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 336M/5.14G [00:02<00:25, 186MB/s]
# Downloading model.fp16.safetensors:  25%|▉   | 346M/1.39G [00:02<00:05, 178MB/s]
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 357M/5.14G [00:02<00:25, 188MB/s]
# Downloading model.fp16.safetensors:  26%|█   | 367M/1.39G [00:02<00:05, 180MB/s]
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 377M/5.14G [00:02<00:24, 191MB/s]
# Downloading model.fp16.safetensors:  28%|█   | 388M/1.39G [00:03<00:05, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 398M/5.14G [00:02<00:24, 193MB/s]
# Downloading model.fp16.safetensors:  29%|█▏  | 409M/1.39G [00:03<00:05, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 419M/5.14G [00:03<00:24, 196MB/s]
# Downloading model.fp16.safetensors:  31%|█▏  | 430M/1.39G [00:03<00:05, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 440M/5.14G [00:03<00:23, 198MB/s]
# Downloading model.fp16.safetensors:  32%|█▎  | 451M/1.39G [00:03<00:05, 176MB/s]
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 461M/5.14G [00:03<00:28, 162MB/s]
# Downloading model.fp16.safetensors:  34%|█▎  | 472M/1.39G [00:03<00:07, 130MB/s]
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 482M/5.14G [00:03<00:42, 110MB/s]
# Downloading model.fp16.safetensors:  35%|█  | 493M/1.39G [00:04<00:10, 88.9MB/s]
#
# Downloading (…)del.fp16.safetensors:  10%|▏ | 503M/5.14G [00:03<00:53, 86.6MB/s]
# Downloading model.fp16.safetensors:  37%|█  | 514M/1.39G [00:04<00:11, 74.8MB/s]
#
# Downloading (…)del.fp16.safetensors:  10%|▏ | 524M/5.14G [00:04<01:00, 76.8MB/s]
#
# Downloading (…)del.fp16.safetensors:  10%|▏ | 535M/5.14G [00:04<00:58, 78.0MB/s]
# Downloading model.fp16.safetensors:  38%|█▏ | 535M/1.39G [00:04<00:11, 73.2MB/s]
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 545M/5.14G [00:04<01:00, 75.3MB/s]
# Downloading model.fp16.safetensors:  39%|█▏ | 545M/1.39G [00:04<00:11, 71.1MB/s]
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 556M/5.14G [00:04<01:01, 74.5MB/s]
# Downloading model.fp16.safetensors:  40%|█▏ | 556M/1.39G [00:05<00:11, 74.6MB/s]
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 566M/5.14G [00:04<01:03, 72.0MB/s]
# Downloading model.fp16.safetensors:  41%|█▏ | 566M/1.39G [00:05<00:10, 75.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 577M/5.14G [00:05<01:05, 70.0MB/s]
# Downloading model.fp16.safetensors:  42%|█▏ | 577M/1.39G [00:05<00:12, 64.9MB/s]
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 587M/5.14G [00:05<01:24, 53.9MB/s]
# Downloading model.fp16.safetensors:  42%|█▎ | 587M/1.39G [00:05<00:13, 58.8MB/s]
# Downloading model.fp16.safetensors:  43%|█▎ | 598M/1.39G [00:05<00:12, 65.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 598M/5.14G [00:05<01:19, 57.2MB/s]
# Downloading model.fp16.safetensors:  44%|█▎ | 608M/1.39G [00:05<00:10, 71.6MB/s]
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 608M/5.14G [00:05<01:19, 57.3MB/s]
# Downloading model.fp16.safetensors:  45%|█▎ | 619M/1.39G [00:05<00:10, 76.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 619M/5.14G [00:05<01:12, 62.7MB/s]
# Downloading model.fp16.safetensors:  45%|█▎ | 629M/1.39G [00:06<00:10, 74.6MB/s]
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 629M/5.14G [00:05<01:05, 68.7MB/s]
# Downloading model.fp16.safetensors:  46%|█▍ | 640M/1.39G [00:06<00:09, 79.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 640M/5.14G [00:06<01:04, 69.9MB/s]
# Downloading model.fp16.safetensors:  47%|█▍ | 650M/1.39G [00:06<00:09, 78.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 650M/5.14G [00:06<00:59, 75.7MB/s]
# Downloading model.fp16.safetensors:  48%|█▍ | 671M/1.39G [00:06<00:08, 83.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 661M/5.14G [00:06<01:02, 71.6MB/s]
# Downloading model.fp16.safetensors:  49%|█▍ | 682M/1.39G [00:06<00:08, 84.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 682M/5.14G [00:06<00:51, 86.9MB/s]
# Downloading model.fp16.safetensors:  50%|█▍ | 692M/1.39G [00:06<00:08, 87.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  14%|▎ | 703M/5.14G [00:06<00:46, 94.6MB/s]
# Downloading model.fp16.safetensors:  51%|██  | 713M/1.39G [00:07<00:06, 104MB/s]
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 724M/5.14G [00:06<00:43, 101MB/s]
# Downloading model.fp16.safetensors:  53%|██  | 734M/1.39G [00:07<00:06, 106MB/s]
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 744M/5.14G [00:07<00:41, 107MB/s]
# Downloading model.fp16.safetensors:  54%|██▏ | 755M/1.39G [00:07<00:05, 111MB/s]
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 765M/5.14G [00:07<00:40, 109MB/s]
# Downloading model.fp16.safetensors:  56%|██▏ | 776M/1.39G [00:07<00:05, 113MB/s]
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 786M/5.14G [00:07<00:39, 109MB/s]
# Downloading model.fp16.safetensors:  57%|██▎ | 797M/1.39G [00:07<00:05, 112MB/s]
# Downloading model.fp16.safetensors:  59%|██▎ | 818M/1.39G [00:07<00:04, 126MB/s]
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 807M/5.14G [00:07<00:37, 116MB/s]
# Downloading model.fp16.safetensors:  60%|██▍ | 839M/1.39G [00:07<00:04, 136MB/s]
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 828M/5.14G [00:07<00:34, 124MB/s]
# Downloading model.fp16.safetensors:  62%|██▍ | 860M/1.39G [00:08<00:03, 134MB/s]
#
# Downloading (…)del.fp16.safetensors:  17%|▍  | 849M/5.14G [00:07<00:31, 137MB/s]
# Downloading model.fp16.safetensors:  63%|██▌ | 881M/1.39G [00:08<00:03, 147MB/s]
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 870M/5.14G [00:08<00:28, 148MB/s]
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 891M/5.14G [00:08<00:26, 160MB/s]
# Downloading model.fp16.safetensors:  65%|██▌ | 902M/1.39G [00:08<00:03, 156MB/s]
# Downloading model.fp16.safetensors:  66%|██▋ | 923M/1.39G [00:08<00:02, 165MB/s]
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 912M/5.14G [00:08<00:26, 162MB/s]
# Downloading model.fp16.safetensors:  68%|██▋ | 944M/1.39G [00:08<00:02, 167MB/s]
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 933M/5.14G [00:08<00:24, 170MB/s]
# Downloading model.fp16.safetensors:  69%|██▊ | 965M/1.39G [00:08<00:02, 174MB/s]
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 954M/5.14G [00:08<00:23, 176MB/s]
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 975M/5.14G [00:08<00:23, 180MB/s]
# Downloading model.fp16.safetensors:  71%|██▊ | 986M/1.39G [00:08<00:02, 177MB/s]
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 996M/5.14G [00:08<00:22, 185MB/s]
# Downloading model.fp16.safetensors:  72%|██▏| 1.01G/1.39G [00:08<00:02, 181MB/s]
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.02G/5.14G [00:08<00:21, 189MB/s]
# Downloading model.fp16.safetensors:  74%|██▏| 1.03G/1.39G [00:09<00:02, 179MB/s]
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.04G/5.14G [00:08<00:21, 187MB/s]
# Downloading model.fp16.safetensors:  75%|██▎| 1.05G/1.39G [00:09<00:01, 179MB/s]
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.06G/5.14G [00:09<00:21, 192MB/s]
# Downloading model.fp16.safetensors:  77%|██▎| 1.07G/1.39G [00:09<00:01, 180MB/s]
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.08G/5.14G [00:09<00:20, 197MB/s]
# Downloading model.fp16.safetensors:  78%|██▎| 1.09G/1.39G [00:09<00:01, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.10G/5.14G [00:09<00:20, 198MB/s]
# Downloading model.fp16.safetensors:  80%|██▍| 1.11G/1.39G [00:09<00:01, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.12G/5.14G [00:09<00:20, 196MB/s]
# Downloading model.fp16.safetensors:  82%|██▍| 1.13G/1.39G [00:09<00:01, 187MB/s]
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.14G/5.14G [00:09<00:20, 195MB/s]
# Downloading model.fp16.safetensors:  83%|██▍| 1.15G/1.39G [00:09<00:01, 184MB/s]
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.16G/5.14G [00:09<00:20, 193MB/s]
# Downloading model.fp16.safetensors:  85%|██▌| 1.17G/1.39G [00:09<00:01, 184MB/s]
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.18G/5.14G [00:09<00:20, 194MB/s]
# Downloading model.fp16.safetensors:  86%|██▌| 1.20G/1.39G [00:09<00:01, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.21G/5.14G [00:09<00:20, 195MB/s]
# Downloading model.fp16.safetensors:  88%|██▋| 1.22G/1.39G [00:10<00:00, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.23G/5.14G [00:09<00:20, 194MB/s]
# Downloading model.fp16.safetensors:  89%|██▋| 1.24G/1.39G [00:10<00:00, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.25G/5.14G [00:10<00:20, 194MB/s]
# Downloading model.fp16.safetensors:  91%|██▋| 1.26G/1.39G [00:10<00:00, 190MB/s]
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.27G/5.14G [00:10<00:19, 197MB/s]
# Downloading model.fp16.safetensors:  92%|██▊| 1.28G/1.39G [00:10<00:00, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 1.29G/5.14G [00:10<00:19, 197MB/s]
# Downloading model.fp16.safetensors:  94%|██▊| 1.30G/1.39G [00:10<00:00, 187MB/s]
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.31G/5.14G [00:10<00:19, 198MB/s]
# Downloading model.fp16.safetensors:  95%|██▊| 1.32G/1.39G [00:10<00:00, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.33G/5.14G [00:10<00:19, 197MB/s]
# Downloading model.fp16.safetensors:  97%|██▉| 1.34G/1.39G [00:10<00:00, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  26%|▌ | 1.35G/5.14G [00:10<00:19, 197MB/s]
# Downloading model.fp16.safetensors:  98%|██▉| 1.36G/1.39G [00:10<00:00, 145MB/s]
#
# Downloading (…)del.fp16.safetensors:  27%|▌ | 1.37G/5.14G [00:10<00:28, 131MB/s]
# Downloading model.fp16.safetensors: 100%|██▉| 1.38G/1.39G [00:11<00:00, 126MB/s]
#
# Downloading model.fp16.safetensors: 100%|███| 1.39G/1.39G [00:11<00:00, 123MB/s]
# Fetching 19 files:  32%|███████▉                 | 6/19 [00:11<00:32,  2.46s/it]
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.42G/5.14G [00:11<00:31, 117MB/s]
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.44G/5.14G [00:11<00:30, 121MB/s]
#
# Downloading (…)del.fp16.safetensors:  28%|▌ | 1.46G/5.14G [00:11<00:29, 123MB/s]
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.48G/5.14G [00:11<00:28, 129MB/s]
#
# Downloading (…)del.fp16.safetensors:  29%|▌ | 1.50G/5.14G [00:11<00:27, 133MB/s]
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.52G/5.14G [00:11<00:26, 134MB/s]
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.54G/5.14G [00:12<00:26, 136MB/s]
#
# Downloading (…)del.fp16.safetensors:  30%|▌ | 1.56G/5.14G [00:12<00:27, 129MB/s]
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.58G/5.14G [00:12<00:28, 126MB/s]
#
# Downloading (…)del.fp16.safetensors:  31%|▌ | 1.60G/5.14G [00:12<00:29, 118MB/s]
#
# Downloading (…)del.fp16.safetensors:  32%|▋ | 1.63G/5.14G [00:12<00:34, 101MB/s]
#
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.65G/5.14G [00:13<00:41, 83.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.66G/5.14G [00:13<00:47, 73.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  32%|▎| 1.67G/5.14G [00:13<00:50, 69.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.68G/5.14G [00:13<00:51, 67.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.69G/5.14G [00:14<00:52, 66.1MB/s]
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.70G/5.14G [00:14<00:52, 65.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.71G/5.14G [00:14<00:50, 68.2MB/s]
#
# Downloading (…)del.fp16.safetensors:  33%|▎| 1.72G/5.14G [00:14<00:47, 72.5MB/s]
#
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.73G/5.14G [00:14<00:45, 74.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  34%|▎| 1.75G/5.14G [00:14<00:38, 87.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.77G/5.14G [00:14<00:29, 112MB/s]
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.79G/5.14G [00:15<00:25, 132MB/s]
#
# Downloading (…)del.fp16.safetensors:  35%|▋ | 1.81G/5.14G [00:15<00:22, 151MB/s]
#
# Downloading (…)del.fp16.safetensors:  36%|▋ | 1.84G/5.14G [00:15<00:20, 164MB/s]
#
# Downloading (…)del.fp16.safetensors:  36%|▋ | 1.87G/5.14G [00:15<00:18, 180MB/s]
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.89G/5.14G [00:15<00:17, 187MB/s]
#
# Downloading (…)del.fp16.safetensors:  37%|▋ | 1.92G/5.14G [00:15<00:16, 196MB/s]
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.94G/5.14G [00:15<00:16, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 1.96G/5.14G [00:15<00:15, 200MB/s]
#
# Downloading (…)del.fp16.safetensors:  39%|▊ | 1.99G/5.14G [00:15<00:15, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  39%|▊ | 2.01G/5.14G [00:16<00:15, 200MB/s]
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.03G/5.14G [00:16<00:15, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.06G/5.14G [00:16<00:15, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  40%|▊ | 2.08G/5.14G [00:16<00:15, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  41%|▊ | 2.11G/5.14G [00:16<00:14, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  41%|▊ | 2.13G/5.14G [00:16<00:15, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  42%|▊ | 2.15G/5.14G [00:16<00:15, 198MB/s]
#
# Downloading (…)del.fp16.safetensors:  42%|▊ | 2.17G/5.14G [00:16<00:14, 198MB/s]
#
# Downloading (…)del.fp16.safetensors:  43%|▊ | 2.19G/5.14G [00:16<00:14, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  43%|▊ | 2.21G/5.14G [00:17<00:16, 179MB/s]
#
# Downloading (…)del.fp16.safetensors:  43%|▊ | 2.23G/5.14G [00:17<00:20, 140MB/s]
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 2.25G/5.14G [00:17<00:21, 131MB/s]
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 2.28G/5.14G [00:17<00:20, 141MB/s]
#
# Downloading (…)del.fp16.safetensors:  45%|▉ | 2.30G/5.14G [00:17<00:18, 155MB/s]
#
# Downloading (…)del.fp16.safetensors:  45%|▉ | 2.32G/5.14G [00:17<00:17, 162MB/s]
#
# Downloading (…)del.fp16.safetensors:  46%|▉ | 2.34G/5.14G [00:17<00:16, 170MB/s]
#
# Downloading (…)del.fp16.safetensors:  46%|▉ | 2.36G/5.14G [00:18<00:15, 179MB/s]
#
# Downloading (…)del.fp16.safetensors:  46%|▉ | 2.38G/5.14G [00:18<00:14, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  47%|▉ | 2.40G/5.14G [00:18<00:14, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  47%|▉ | 2.42G/5.14G [00:18<00:14, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  48%|▉ | 2.44G/5.14G [00:18<00:14, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  48%|▉ | 2.46G/5.14G [00:18<00:13, 192MB/s]
#
# Downloading (…)del.fp16.safetensors:  48%|▉ | 2.49G/5.14G [00:18<00:13, 193MB/s]
#
# Downloading (…)del.fp16.safetensors:  49%|▉ | 2.51G/5.14G [00:18<00:13, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  49%|▉ | 2.53G/5.14G [00:18<00:13, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  50%|▉ | 2.55G/5.14G [00:19<00:13, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 2.57G/5.14G [00:19<00:13, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  50%|█ | 2.59G/5.14G [00:19<00:13, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  51%|█ | 2.61G/5.14G [00:19<00:13, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  51%|█ | 2.63G/5.14G [00:19<00:13, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  52%|█ | 2.65G/5.14G [00:19<00:13, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  52%|█ | 2.67G/5.14G [00:19<00:13, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  52%|█ | 2.69G/5.14G [00:19<00:13, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.72G/5.14G [00:22<01:37, 24.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  53%|▌| 2.74G/5.14G [00:22<01:14, 32.1MB/s]
#
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.76G/5.14G [00:22<00:55, 42.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  54%|▌| 2.78G/5.14G [00:22<00:42, 56.0MB/s]
#
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.80G/5.14G [00:22<00:32, 70.9MB/s]
#
# Downloading (…)del.fp16.safetensors:  55%|▌| 2.82G/5.14G [00:23<00:26, 88.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  56%|█ | 2.85G/5.14G [00:23<00:20, 114MB/s]
#
# Downloading (…)del.fp16.safetensors:  56%|█ | 2.87G/5.14G [00:23<00:17, 130MB/s]
#
# Downloading (…)del.fp16.safetensors:  56%|█▏| 2.89G/5.14G [00:23<00:15, 143MB/s]
#
# Downloading (…)del.fp16.safetensors:  57%|█▏| 2.92G/5.14G [00:23<00:14, 157MB/s]
#
# Downloading (…)del.fp16.safetensors:  57%|█▏| 2.95G/5.14G [00:23<00:12, 173MB/s]
#
# Downloading (…)del.fp16.safetensors:  58%|█▏| 2.98G/5.14G [00:23<00:11, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  58%|█▏| 3.00G/5.14G [00:23<00:11, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  59%|█▏| 3.02G/5.14G [00:24<00:11, 190MB/s]
#
# Downloading (…)del.fp16.safetensors:  59%|█▏| 3.05G/5.14G [00:24<00:10, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  60%|█▏| 3.07G/5.14G [00:24<00:10, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  60%|█▏| 3.09G/5.14G [00:24<00:10, 198MB/s]
#
# Downloading (…)del.fp16.safetensors:  61%|█▏| 3.11G/5.14G [00:24<00:10, 199MB/s]
#
# Downloading (…)del.fp16.safetensors:  61%|█▏| 3.15G/5.14G [00:24<00:09, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  62%|█▏| 3.17G/5.14G [00:24<00:09, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  62%|█▏| 3.19G/5.14G [00:24<00:09, 197MB/s]
#
# Downloading (…)del.fp16.safetensors:  63%|█▎| 3.22G/5.14G [00:24<00:09, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  63%|█▎| 3.24G/5.14G [00:25<00:09, 195MB/s]
#
# Downloading (…)del.fp16.safetensors:  64%|█▎| 3.26G/5.14G [00:25<00:09, 196MB/s]
#
# Downloading (…)del.fp16.safetensors:  64%|█▎| 3.28G/5.14G [00:25<00:09, 198MB/s]
#
# Downloading (…)del.fp16.safetensors:  64%|█▎| 3.30G/5.14G [00:25<00:09, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  65%|█▎| 3.32G/5.14G [00:25<00:08, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  65%|█▎| 3.34G/5.14G [00:25<00:08, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  66%|█▎| 3.37G/5.14G [00:25<00:08, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  66%|█▎| 3.39G/5.14G [00:25<00:08, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  66%|█▎| 3.41G/5.14G [00:25<00:08, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  67%|█▎| 3.43G/5.14G [00:26<00:08, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  67%|█▎| 3.45G/5.14G [00:26<00:08, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  68%|█▎| 3.47G/5.14G [00:26<00:08, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  68%|█▎| 3.49G/5.14G [00:26<00:08, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  68%|█▎| 3.51G/5.14G [00:26<00:08, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  69%|█▍| 3.53G/5.14G [00:26<00:07, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  69%|█▍| 3.57G/5.14G [00:26<00:07, 207MB/s]
#
# Downloading (…)del.fp16.safetensors:  70%|█▍| 3.59G/5.14G [00:26<00:07, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  70%|█▍| 3.61G/5.14G [00:26<00:07, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  71%|█▍| 3.64G/5.14G [00:27<00:07, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  71%|█▍| 3.66G/5.14G [00:27<00:07, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  72%|█▍| 3.69G/5.14G [00:27<00:07, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  72%|█▍| 3.71G/5.14G [00:27<00:06, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  73%|█▍| 3.73G/5.14G [00:27<00:06, 206MB/s]
#
# Downloading (…)del.fp16.safetensors:  73%|█▍| 3.75G/5.14G [00:27<00:06, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  74%|█▍| 3.77G/5.14G [00:27<00:06, 206MB/s]
#
# Downloading (…)del.fp16.safetensors:  74%|█▍| 3.81G/5.14G [00:27<00:06, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  75%|█▍| 3.83G/5.14G [00:27<00:06, 206MB/s]
#
# Downloading (…)del.fp16.safetensors:  75%|█▌| 3.86G/5.14G [00:28<00:06, 208MB/s]
#
# Downloading (…)del.fp16.safetensors:  76%|█▌| 3.88G/5.14G [00:28<00:06, 202MB/s]
#
# Downloading (…)del.fp16.safetensors:  76%|█▌| 3.90G/5.14G [00:28<00:06, 197MB/s]
#
# Downloading (…)del.fp16.safetensors:  76%|█▌| 3.92G/5.14G [00:28<00:06, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  77%|█▌| 3.94G/5.14G [00:28<00:06, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  77%|█▌| 3.96G/5.14G [00:28<00:06, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  78%|█▌| 3.98G/5.14G [00:28<00:06, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  78%|█▌| 4.01G/5.14G [00:28<00:05, 194MB/s]
#
# Downloading (…)del.fp16.safetensors:  78%|█▌| 4.03G/5.14G [00:29<00:05, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  79%|█▌| 4.05G/5.14G [00:29<00:05, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  79%|█▌| 4.07G/5.14G [00:29<00:05, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.09G/5.14G [00:29<00:05, 190MB/s]
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.11G/5.14G [00:29<00:05, 182MB/s]
#
# Downloading (…)del.fp16.safetensors:  80%|█▌| 4.13G/5.14G [00:29<00:05, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  81%|█▌| 4.15G/5.14G [00:29<00:05, 187MB/s]
#
# Downloading (…)del.fp16.safetensors:  81%|█▋| 4.17G/5.14G [00:29<00:05, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  82%|█▋| 4.19G/5.14G [00:29<00:05, 184MB/s]
#
# Downloading (…)del.fp16.safetensors:  82%|█▋| 4.22G/5.14G [00:30<00:05, 181MB/s]
#
# Downloading (…)del.fp16.safetensors:  82%|█▋| 4.24G/5.14G [00:30<00:05, 179MB/s]
#
# Downloading (…)del.fp16.safetensors:  83%|█▋| 4.26G/5.14G [00:30<00:04, 178MB/s]
#
# Downloading (…)del.fp16.safetensors:  83%|█▋| 4.28G/5.14G [00:30<00:04, 173MB/s]
#
# Downloading (…)del.fp16.safetensors:  84%|█▋| 4.30G/5.14G [00:30<00:04, 173MB/s]
#
# Downloading (…)del.fp16.safetensors:  84%|█▋| 4.32G/5.14G [00:30<00:04, 181MB/s]
#
# Downloading (…)del.fp16.safetensors:  85%|█▋| 4.34G/5.14G [00:30<00:04, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  85%|█▋| 4.36G/5.14G [00:30<00:04, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  85%|█▋| 4.38G/5.14G [00:30<00:03, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  86%|█▋| 4.40G/5.14G [00:31<00:03, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  86%|█▋| 4.42G/5.14G [00:31<00:03, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  87%|█▋| 4.45G/5.14G [00:31<00:03, 190MB/s]
#
# Downloading (…)del.fp16.safetensors:  87%|█▋| 4.47G/5.14G [00:31<00:03, 191MB/s]
#
# Downloading (…)del.fp16.safetensors:  87%|█▋| 4.49G/5.14G [00:31<00:03, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  88%|█▊| 4.51G/5.14G [00:31<00:03, 180MB/s]
#
# Downloading (…)del.fp16.safetensors:  88%|█▊| 4.53G/5.14G [00:31<00:03, 181MB/s]
#
# Downloading (…)del.fp16.safetensors:  89%|█▊| 4.55G/5.14G [00:31<00:03, 181MB/s]
#
# Downloading (…)del.fp16.safetensors:  89%|█▊| 4.57G/5.14G [00:32<00:03, 182MB/s]
#
# Downloading (…)del.fp16.safetensors:  89%|█▊| 4.59G/5.14G [00:32<00:02, 183MB/s]
#
# Downloading (…)del.fp16.safetensors:  90%|█▊| 4.61G/5.14G [00:32<00:02, 186MB/s]
#
# Downloading (…)del.fp16.safetensors:  90%|█▊| 4.63G/5.14G [00:32<00:02, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  91%|█▊| 4.66G/5.14G [00:32<00:02, 185MB/s]
#
# Downloading (…)del.fp16.safetensors:  91%|█▊| 4.68G/5.14G [00:32<00:02, 188MB/s]
#
# Downloading (…)del.fp16.safetensors:  91%|█▊| 4.70G/5.14G [00:32<00:02, 190MB/s]
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.72G/5.14G [00:32<00:02, 184MB/s]
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.74G/5.14G [00:32<00:02, 180MB/s]
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.76G/5.14G [00:33<00:02, 184MB/s]
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.78G/5.14G [00:33<00:01, 182MB/s]
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.80G/5.14G [00:33<00:01, 183MB/s]
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.82G/5.14G [00:33<00:01, 189MB/s]
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.85G/5.14G [00:33<00:01, 196MB/s]
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.88G/5.14G [00:33<00:01, 195MB/s]
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.91G/5.14G [00:33<00:01, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.93G/5.14G [00:33<00:01, 200MB/s]
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.95G/5.14G [00:33<00:00, 201MB/s]
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.98G/5.14G [00:34<00:00, 205MB/s]
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.01G/5.14G [00:34<00:00, 206MB/s]
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.04G/5.14G [00:34<00:00, 207MB/s]
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.06G/5.14G [00:34<00:00, 203MB/s]
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.09G/5.14G [00:34<00:00, 204MB/s]
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.11G/5.14G [00:34<00:00, 203MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:34<00:00, 147MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:35<00:00,  1.87s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:05<00:00,  1.30it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:42<00:00,  1.17it/s]
#
# **************************************************
#
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.02it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.07it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.91it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.07it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.54it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.57it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.52it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.65it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.07it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.65it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.64it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
