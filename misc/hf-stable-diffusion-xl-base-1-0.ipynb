# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# Version 3

prompts: list = [
    "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
    "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
    "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
    "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
    "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
    "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
    "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
    "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
    "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
    "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.93MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.18MB/s]
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 3.01MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:03,  5.44it/s]
#
#
# Downloading (…)ncoder_2/config.json:   0%|            | 0.00/575 [00:00<?, ?B/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.80MB/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 4.54MB/s]
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 92.7kB/s]
#
#
#
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
# Downloading model.fp16.safetensors:   0%|           | 0.00/1.39G [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 2.90MB/s]
#
#
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 2.54MB/s]
#
#
#
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 3.69MB/s]
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:04, 47.7MB/s]
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 5.59MB/s]
#
#
# Downloading (…)kenizer_2/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:19, 72.0MB/s]
#
#
# Downloading (…)1d8/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 9.98MB/s]
#
# Downloading model.fp16.safetensors:   9%|▎  | 21.0M/246M [00:00<00:03, 67.9MB/s]
#
#
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading model.fp16.safetensors:   2%|  | 21.0M/1.39G [00:00<00:16, 84.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
#
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 3.71MB/s]
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:  17%|▌  | 41.9M/246M [00:00<00:02, 95.5MB/s]
#
#
#
#
#
# Downloading (…)81d8/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 2.00MB/s]
#
#
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 5.77MB/s]
#
#
#
#
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:13, 97.4MB/s]
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 67.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:44, 48.9MB/s]
# Downloading model.fp16.safetensors:  26%|█   | 62.9M/246M [00:00<00:01, 113MB/s]
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 79.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:18, 65.3MB/s]
#
#
#
# Downloading model.fp16.safetensors:   5%|▏  | 62.9M/1.39G [00:00<00:11, 113MB/s]
# Downloading model.fp16.safetensors:  34%|█▎  | 83.9M/246M [00:00<00:01, 119MB/s]
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 62.5MB/s]
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 95.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 41.9M/5.14G [00:00<00:56, 90.5MB/s]
#
#
#
# Downloading model.fp16.safetensors:   6%|▏  | 83.9M/1.39G [00:00<00:12, 105MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:02, 65.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  31%|▋ | 52.4M/167M [00:00<00:01, 97.1MB/s]
# Downloading model.fp16.safetensors:  43%|██▏  | 105M/246M [00:01<00:01, 112MB/s]
#
#
#
# Downloading model.fp16.safetensors:   8%|▎   | 105M/1.39G [00:00<00:11, 114MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 62.9M/5.14G [00:00<00:52, 96.8MB/s]
#
# Downloading (…)del.fp16.safetensors:  38%|▊ | 62.9M/167M [00:00<00:01, 95.9MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 91.6MB/s]
# Downloading model.fp16.safetensors:  51%|██▌  | 126M/246M [00:01<00:01, 115MB/s]
#
# Downloading (…)del.fp16.safetensors:  44%|▉ | 73.4M/167M [00:00<00:00, 95.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 73.4M/5.14G [00:00<00:53, 94.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:   9%|▎   | 126M/1.39G [00:01<00:10, 120MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  38%|█▏ | 62.9M/167M [00:00<00:00, 109MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 94.4M/5.14G [00:00<00:45, 111MB/s]
#
# Downloading (…)del.fp16.safetensors:  56%|█▋ | 94.4M/167M [00:00<00:00, 110MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 118MB/s]
#
#
#
# Downloading model.fp16.safetensors:  11%|▍   | 147M/1.39G [00:01<00:12, 101MB/s]
#
# Downloading (…)del.fp16.safetensors:  69%|██▊ | 115M/167M [00:01<00:00, 117MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|   | 115M/5.14G [00:01<00:44, 114MB/s]
# Downloading model.fp16.safetensors:  60%|██▍ | 147M/246M [00:01<00:01, 79.7MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  63%|██▌ | 105M/167M [00:00<00:00, 122MB/s]
#
#
#
# Downloading model.fp16.safetensors:  12%|▍   | 168M/1.39G [00:01<00:10, 113MB/s]
# Downloading model.fp16.safetensors:  68%|██▋ | 168M/246M [00:01<00:00, 93.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  81%|███▎| 136M/167M [00:01<00:00, 102MB/s]
#
#
#
# Downloading model.fp16.safetensors:  14%|▌   | 189M/1.39G [00:01<00:09, 120MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  75%|███ | 126M/167M [00:01<00:00, 109MB/s]
# Downloading model.fp16.safetensors:  77%|███▊ | 189M/246M [00:01<00:00, 109MB/s]
#
#
#
# Downloading model.fp16.safetensors:  15%|▌   | 210M/1.39G [00:01<00:08, 132MB/s]
# Downloading model.fp16.safetensors:  85%|████▎| 210M/246M [00:02<00:00, 122MB/s]
#
#
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 117MB/s]
#
# Downloading (…)del.fp16.safetensors:  88%|██▋| 147M/167M [00:01<00:00, 75.6MB/s]
#
#
#
# Downloading model.fp16.safetensors:  17%|▋   | 231M/1.39G [00:01<00:08, 140MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 136M/5.14G [00:01<01:17, 64.6MB/s]
# Downloading model.fp16.safetensors:  94%|████▋| 231M/246M [00:02<00:00, 125MB/s]
#
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 108MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 147M/5.14G [00:01<01:11, 69.6MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 86.6MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|███| 167M/167M [00:01<00:00, 90.6MB/s]
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 107MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:11,  1.34it/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|  | 168M/5.14G [00:01<00:56, 88.0MB/s]
#
#
#
# Downloading model.fp16.safetensors:  20%|▊   | 273M/1.39G [00:02<00:07, 146MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 189M/5.14G [00:02<00:45, 109MB/s]
#
#
#
# Downloading model.fp16.safetensors:  21%|▊   | 294M/1.39G [00:02<00:07, 144MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 210M/5.14G [00:02<00:38, 129MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 241M/5.14G [00:02<00:31, 157MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 273M/5.14G [00:02<00:27, 175MB/s]
#
#
#
# Downloading model.fp16.safetensors:  23%|▉   | 315M/1.39G [00:02<00:10, 103MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 294M/5.14G [00:02<00:26, 181MB/s]
#
#
#
# Downloading model.fp16.safetensors:  24%|▉   | 336M/1.39G [00:02<00:08, 120MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 315M/5.14G [00:02<00:25, 188MB/s]
#
#
#
# Downloading model.fp16.safetensors:  26%|█   | 357M/1.39G [00:02<00:08, 124MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 336M/5.14G [00:02<00:25, 192MB/s]
#
#
#
# Downloading model.fp16.safetensors:  27%|█   | 377M/1.39G [00:03<00:07, 140MB/s]
#
#
#
# Downloading model.fp16.safetensors:  29%|█▏  | 409M/1.39G [00:03<00:05, 165MB/s]
#
#
#
# Downloading model.fp16.safetensors:  32%|█▎  | 440M/1.39G [00:03<00:05, 183MB/s]
#
#
#
# Downloading model.fp16.safetensors:  34%|█▎  | 472M/1.39G [00:03<00:04, 196MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏ | 357M/5.14G [00:03<00:55, 86.0MB/s]
#
#
#
# Downloading model.fp16.safetensors:  36%|█▍  | 503M/1.39G [00:03<00:04, 203MB/s]
#
#
#
# Downloading model.fp16.safetensors:  38%|█▌  | 535M/1.39G [00:03<00:04, 209MB/s]
#
#
#
# Downloading model.fp16.safetensors:  41%|█▋  | 566M/1.39G [00:03<00:04, 196MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏ | 377M/5.14G [00:03<01:13, 65.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏ | 398M/5.14G [00:04<01:06, 70.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:  42%|█▋  | 587M/1.39G [00:04<00:07, 114MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏ | 419M/5.14G [00:04<00:54, 85.8MB/s]
#
#
#
# Downloading model.fp16.safetensors:  44%|█▊  | 608M/1.39G [00:04<00:06, 118MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▏ | 440M/5.14G [00:04<00:50, 92.8MB/s]
#
#
#
# Downloading model.fp16.safetensors:  45%|█▊  | 629M/1.39G [00:04<00:06, 123MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 461M/5.14G [00:04<00:44, 104MB/s]
#
#
#
# Downloading model.fp16.safetensors:  47%|█▊  | 650M/1.39G [00:04<00:05, 127MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 482M/5.14G [00:04<00:42, 108MB/s]
#
#
#
# Downloading model.fp16.safetensors:  48%|█▉  | 671M/1.39G [00:05<00:05, 134MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 503M/5.14G [00:04<00:40, 115MB/s]
#
#
#
# Downloading model.fp16.safetensors:  50%|█▉  | 692M/1.39G [00:05<00:05, 131MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 524M/5.14G [00:05<00:38, 119MB/s]
#
#
#
# Downloading model.fp16.safetensors:  51%|██  | 713M/1.39G [00:05<00:04, 138MB/s]
#
#
#
# Downloading model.fp16.safetensors:  53%|██  | 734M/1.39G [00:05<00:04, 143MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 545M/5.14G [00:05<00:38, 120MB/s]
#
#
#
# Downloading model.fp16.safetensors:  54%|██▏ | 755M/1.39G [00:05<00:04, 155MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 566M/5.14G [00:05<01:03, 71.6MB/s]
#
#
#
# Downloading model.fp16.safetensors:  56%|█▋ | 776M/1.39G [00:06<00:08, 68.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▏ | 577M/5.14G [00:06<01:12, 62.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 598M/5.14G [00:06<00:56, 80.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:  57%|█▋ | 797M/1.39G [00:06<00:08, 71.8MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▏ | 619M/5.14G [00:06<00:47, 95.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 640M/5.14G [00:06<00:40, 111MB/s]
#
#
#
# Downloading model.fp16.safetensors:  59%|█▊ | 818M/1.39G [00:06<00:06, 82.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 661M/5.14G [00:06<00:36, 121MB/s]
#
#
#
# Downloading model.fp16.safetensors:  60%|█▊ | 839M/1.39G [00:06<00:05, 96.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 682M/5.14G [00:06<00:34, 128MB/s]
#
#
#
# Downloading model.fp16.safetensors:  62%|██▍ | 860M/1.39G [00:06<00:05, 106MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 703M/5.14G [00:06<00:33, 133MB/s]
#
#
#
# Downloading model.fp16.safetensors:  63%|██▌ | 881M/1.39G [00:07<00:04, 108MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 724M/5.14G [00:07<00:37, 119MB/s]
#
#
#
# Downloading model.fp16.safetensors:  65%|██▌ | 902M/1.39G [00:07<00:04, 101MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▎ | 744M/5.14G [00:07<00:46, 95.0MB/s]
#
#
#
# Downloading model.fp16.safetensors:  66%|█▉ | 923M/1.39G [00:07<00:05, 87.9MB/s]
#
#
#
# Downloading model.fp16.safetensors:  67%|██ | 933M/1.39G [00:07<00:05, 85.6MB/s]
#
#
#
# Downloading model.fp16.safetensors:  68%|██ | 944M/1.39G [00:08<00:06, 65.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▎ | 765M/5.14G [00:07<01:08, 63.5MB/s]
#
#
#
# Downloading model.fp16.safetensors:  69%|██ | 965M/1.39G [00:08<00:05, 82.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▎ | 786M/5.14G [00:08<00:56, 77.1MB/s]
#
#
#
# Downloading model.fp16.safetensors:  71%|██▏| 986M/1.39G [00:08<00:04, 99.0MB/s]
#
#
#
# Downloading model.fp16.safetensors:  72%|██▏| 1.01G/1.39G [00:08<00:03, 111MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▎ | 807M/5.14G [00:08<00:58, 74.1MB/s]
#
#
#
# Downloading model.fp16.safetensors:  74%|██▏| 1.03G/1.39G [00:08<00:02, 128MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▎ | 818M/5.14G [00:08<00:55, 77.8MB/s]
#
#
#
# Downloading model.fp16.safetensors:  75%|██▎| 1.05G/1.39G [00:08<00:02, 137MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▎ | 839M/5.14G [00:08<00:46, 92.6MB/s]
#
#
#
# Downloading model.fp16.safetensors:  77%|██▎| 1.07G/1.39G [00:08<00:02, 139MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 860M/5.14G [00:08<00:40, 106MB/s]
#
#
#
# Downloading model.fp16.safetensors:  78%|██▎| 1.09G/1.39G [00:09<00:02, 139MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 881M/5.14G [00:08<00:35, 121MB/s]
#
#
#
# Downloading model.fp16.safetensors:  80%|██▍| 1.11G/1.39G [00:09<00:01, 154MB/s]
#
#
#
# Downloading model.fp16.safetensors:  82%|█▋| 1.13G/1.39G [00:09<00:02, 93.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▎ | 912M/5.14G [00:09<00:47, 89.5MB/s]
#
#
#
# Downloading model.fp16.safetensors:  84%|██▌| 1.16G/1.39G [00:09<00:02, 105MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▎ | 933M/5.14G [00:09<00:54, 76.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 965M/5.14G [00:09<00:41, 101MB/s]
#
#
#
# Downloading model.fp16.safetensors:  85%|█▋| 1.18G/1.39G [00:10<00:02, 78.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 996M/5.14G [00:10<00:33, 124MB/s]
#
#
#
# Downloading model.fp16.safetensors:  87%|█▋| 1.21G/1.39G [00:10<00:01, 94.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.02G/5.14G [00:10<00:30, 136MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.04G/5.14G [00:10<00:27, 149MB/s]
#
#
#
# Downloading model.fp16.safetensors:  88%|██▋| 1.23G/1.39G [00:10<00:01, 111MB/s]
#
#
#
# Downloading model.fp16.safetensors:  90%|██▋| 1.25G/1.39G [00:10<00:01, 128MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.06G/5.14G [00:10<00:25, 158MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.08G/5.14G [00:10<00:24, 169MB/s]
#
#
#
# Downloading model.fp16.safetensors:  92%|██▊| 1.28G/1.39G [00:10<00:00, 151MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.10G/5.14G [00:10<00:22, 176MB/s]
#
#
#
# Downloading model.fp16.safetensors:  94%|██▊| 1.30G/1.39G [00:10<00:00, 160MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.12G/5.14G [00:10<00:22, 182MB/s]
#
#
#
# Downloading model.fp16.safetensors:  96%|██▉| 1.33G/1.39G [00:11<00:00, 175MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:
B/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  91%|▉| 4.68G/5.14G [00:42<00:05, 87.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  91%|▉| 4.70G/5.14G [00:42<00:05, 79.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  92%|▉| 4.72G/5.14G [00:43<00:05, 79.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.75G/5.14G [00:43<00:03, 104MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.77G/5.14G [00:43<00:03, 119MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.80G/5.14G [00:43<00:02, 142MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.83G/5.14G [00:43<00:01, 162MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.87G/5.14G [00:43<00:01, 179MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.89G/5.14G [00:43<00:01, 184MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.92G/5.14G [00:43<00:01, 195MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.94G/5.14G [00:44<00:01, 146MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.96G/5.14G [00:44<00:01, 97.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|▉| 4.98G/5.14G [00:44<00:01, 96.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.01G/5.14G [00:45<00:01, 91.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|▉| 5.03G/5.14G [00:45<00:01, 92.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.05G/5.14G [00:45<00:00, 109MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.08G/5.14G [00:45<00:00, 124MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.10G/5.14G [00:45<00:00, 137MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:46<00:00, 112MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:46<00:00,  2.46s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.46it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:41<00:00,  1.21it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.93it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.73it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.50it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.68it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.08it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.61it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:43<00:00,  1.15it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.47it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:43<00:00,  1.15it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.18it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:43<00:00,  1.15it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.58it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:43<00:00,  1.15it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.21it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.10it/s]
#
# **************************************************
