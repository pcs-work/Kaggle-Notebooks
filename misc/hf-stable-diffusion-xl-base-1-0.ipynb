# %% [markdown]
# ### **Setup**

# %%
# !pip install diffusers invisible_watermark transformers accelerate safetensors -q

# %%
# # Version 1

# prompts = [
#     "A car in a field at night",
#     "Night sky with a mountain in the background",
#     "A street in New York City at Night",
#     "A view of the earth from space",
#     "Breaking Bad in the style of Anime",
#     "A person standing atop a mountain looking into the valley below with a red sunset in the background",
#     "Concept art of what a futuristic city woul look like at night",
#     "Underwater photography of a coral reef, with diverse marine life, a shark in the shadows and a scuba diver for scale",
#     "Agent 47 from Hitman 3 at a location in Saudi Arabia",
#     "Abstract artwork which is extremely colorful using a tiger as the subject",
# ]

# %%
# # Version 2

# prompts: list = [
#     "Black and white street photography of a rainy night in New York, reflections on wet pavement",
#     "A minimalistic digital artwork of an abstract geometric pattern with a extremely colorful color palette",
#     "A person standing atop a mountain looking into the valley below with the moon in the background an a starry night sky",
#     "An offroad truck making a jump over a sand dune in the desert",
#     "A man atop a mountain watching a nuclear explosion mushroom cloud in the distance",
#     "A starry night sky with planets visible in the backgound aurora",
#     "A starry night sky with constellations like the moon casts long shadows over a cyberpunk city at night, sharp focus, wide shot",
#     "Landscape of modern atmospheric and cinematic royalty - based city architecture and building",
#     "Landscape of an abandoned post-apocalyptic sci-fi laboratory temple",
#     "An image of an eye-catching ominous floating flower with shimmering teal and black and orange and forest dragon pattern clothes is floating in a heavenly heavenly ocean with beautiful fish and luminous clouds in the background",
# ]

# %%
# # Version 3

# prompts: list = [
#     "Landscape of a cozy cabin in the woods, natural light, fantasy, natural light, concept art, by greg rutkowski and craig",
#     "Landscape of a Modern Atlantis temple, by Cedric Peyravernay, highly detailed, excellent composition, cinematic concept art, dramatic lighting,",
#     "Landscape of a cozy cabin in a frozen tundra, digital art, concept art, cgsociety, ue 5, rated by",
#     "Landscape of an izuku midoriya anime forest landscape, a magic portal inside izuku midoriya. Anime, cinematic, concept",
#     "Landscape of a majestic post-nuclear Tokyo at dusk, with neon signs, by Studio Ghibli, Makoto Shinkai, by Artger",
#     "Landscape of a Modern Atlantis temple, detailed, centered, digital painting, artstation, concept art, donato giancola, Joseph Christian",
#     "Landscape of a Modern Atlantis temple, surrounded by Limestone Hills. Ocean, waterfalls, airships, aerial perspective, detailed, concept art,",
#     "Landscape of a heavenly terrifying giant, intricate Asteroid belt nebula, by Greg Rutkowski, cumulonimbus clouds, Trending on",
#     "Landscape of a massive  empty gorgeous crystal temple on the snowy mountains in a gossamer purple sunset, flying cars and people walking by, no",
#     "Landscape of a!!!beautiful!! spaceship, intricate, elegant, highly detailed, digital painting, artstation,  concept art, smooth,",
# ]

# %%
# # Version 4

# prompts: list = [
#     "A city at night, dark sky, people watching in wonder, very detailed, 8k, concept art",
#     "A city at night big moon and stars at the borders, concept art, dark, creepy, atmospheric, 8k, HD",
#     "A city at night, small lamp posts, burning church, street lamps, 4 k, concept art, sparse vegetation",
#     "A city at night, low green clouds, dark red sky, night, 4k, high details, fireflies, art by WLOP,",
#     "A city at night, dark moonlight, sky full of stars at the edges, concept art, 4k, octane render, digital painting,",
#     "A city at night, big moon on the right, meteor fall, trending on artstation, 8k, cinematic, soft, sharp focus, insanely",
#     "A city at night, huge moon, stars at the horizon, 4k, 8k, trending on Artstation",
#     "A city at night during a nuclear eruption, intricate Asteroid belt with huge rings in the sky, water and beautiful pink blobs, flying cars,",
#     "A city at night with cumulonimbus clouds in the sky, night colors, stars in the sky, painting by tyler edlin,",
#     "A city at night, moonlight, street lamps, falling leaves, wide angle, super highly detailed, professional digital painting, artstation, concept art",
# ]

# %%
# # Version 5

# prompts: list = [
#     "A picturesque night sky over a full moon",
#     "A picturesque night sky with planets visible in the background, stars in the sky",
#     "A picturesque night sky, small waterfall, mist, candlelight, celestial highlights, painting in style of krenz cushart, ilya",
#     "A picturesque night sky, low angle, dawn, stars in the night sky, realistic, detailed faces, moody, atmospheric, cinematic, wide",
#     "A picturesque night sky overimpel forest",
#     "A picturesque night sky over the sea, stars bloom in the background, natural, ultra detail. ethereal",
#     "A picturesque night sky with constellations, small camp is built beside. In style of Yoji Shinkawa and Hyung-tae",
#     "A picturesque night sky with constellations, stars Asteroid belt with huge rings and beautiful draped clouds, anime, fountain, statue, underwater,",
#     "A picturesque night sky with stars visible through shattered clouds",
#     "A picturesque night sky overland, low poly, isometric art",
# ]

# %%
# # Version 6

# prompts: list = [
#     "A car in a field at night illuminated by vibrant glowing lights in the distance.",
#     "A car in a field at night with a moon and highly detailed",
#     "A car in a field at night illuminated by glowing headlights",
#     "A car in a field at night, a big moon in the background. Vibrant colors",
#     "A car in a field at night illuminated by glowing headlights of organic matte liquid metal and shiny gold and a blue glow emanates from the metal",
#     "A car in a field at night illuminated by a street lamp, camera flashes from behind, concept art, intricate, digital painting, cinematic lighting, dark",
#     "A car in a field at night with moon in the lights, underexposed, desolated wasteland",
#     "A car in a field at night illuminated by a street light, Asteroid belt, nebula in the distance, night colors, high - key lighting",
#     "A car in a field at night with a moon with soft adventurous and atmospheric lighting",
#     "A car in a field at night illuminated by flashes of lightning, pitchblack sky, extremly detailed digital photo",
# ]

# %%
# Version 7

prompts: list = [
    "A person standing atop a mountain staring into a valley, mountain landscape, mountains in the background, highly detailed, high quality",
    "A person standing atop a mountain staring into a valley, a detailed matte painting",
    "A person standing atop a mountain staring into a valley, a detailed realistic painting",
    "A person standing atop a mountain staring into a valley, mountain landscape, view, blue haze, sunset, a dystopian view",
    "A person standing atop a mountain staring into a valley",
    "A person standing atop a mountain staring into a valley, the sun is on the background",
    "A person standing atop a mountain staring into a valley",
    "A person standing atop a mountain staring into a valley, the leaves are falling, Asteroid belt",
    "A person standing atop a mountain staring into a valley with a sunset. The sun is setting. The sky is filled with stars",
    "A person standing atop a mountain staring into a valley, concept art",
]

# %% [markdown]
# ### **Generate**

# %%
import warnings
warnings.filterwarnings("ignore")


def breaker():
    print("\n" + 50*"*" + "\n")


breaker()
for prompt in prompts:
    prompt = ",".join(prompt.split(" "))
    # !python /kaggle/input/sdig-script/main.py --kaggle --prompt $prompt
    breaker()
# Out:
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)ain/model_index.json: 100%|█████| 609/609 [00:00<00:00, 3.27MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)_encoder/config.json: 100%|█████| 565/565 [00:00<00:00, 3.02MB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 3.65MB/s]
#
#
# Downloading (…)cheduler_config.json: 100%|█████| 479/479 [00:00<00:00, 3.25MB/s]
# Fetching 19 files:  11%|██▋                      | 2/19 [00:00<00:01,  9.01it/s]
#
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 3.08MB/s]
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 8.38MB/s]
#
# Downloading (…)ncoder_2/config.json: 100%|█████| 575/575 [00:00<00:00, 4.10MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 3.56MB/s]
#
#
# Downloading model.fp16.safetensors:   0%|           | 0.00/1.39G [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   0%|            | 0.00/246M [00:00<?, ?B/s]
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 5.48MB/s]
#
#
#
#
# Downloading (…)kenizer_2/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)76f/unet/config.json: 100%|█| 1.68k/1.68k [00:00<00:00, 10.8MB/s]
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 15.2MB/s]
#
# Downloading (…)d76f/vae/config.json: 100%|█████| 642/642 [00:00<00:00, 3.97MB/s]
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 8.00MB/s]
#
# Downloading (…)kenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   4%|▏  | 10.5M/246M [00:00<00:03, 71.8MB/s]
#
# Downloading model.fp16.safetensors:   1%|  | 10.5M/1.39G [00:00<00:20, 67.7MB/s]
#
#
#
# Downloading (…)kenizer_2/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 14.3MB/s]
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:  13%|▌   | 31.5M/246M [00:00<00:01, 111MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 10.5M/5.14G [00:00<01:09, 73.9MB/s]
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 77.0MB/s]
#
# Downloading model.fp16.safetensors:   2%|  | 31.5M/1.39G [00:00<00:15, 90.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏ | 10.5M/167M [00:00<00:02, 59.7MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   0%| | 21.0M/5.14G [00:00<01:05, 77.9MB/s]
#
#
# Downloading model.fp16.safetensors:  21%|▊   | 52.4M/246M [00:00<00:01, 112MB/s]
#
# Downloading model.fp16.safetensors:   3%|  | 41.9M/1.39G [00:00<00:15, 87.3MB/s]
# Downloading (…)del.fp16.safetensors:  19%|▌  | 31.5M/167M [00:00<00:01, 104MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▎ | 21.0M/167M [00:00<00:01, 73.4MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%| | 31.5M/5.14G [00:00<00:59, 85.4MB/s]
#
# Downloading model.fp16.safetensors:   4%|  | 52.4M/1.39G [00:00<00:14, 90.0MB/s]
# Downloading (…)del.fp16.safetensors:  25%|▊  | 41.9M/167M [00:00<00:01, 101MB/s]
#
#
# Downloading model.fp16.safetensors:  30%|█▏  | 73.4M/246M [00:00<00:01, 119MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 41.9M/167M [00:00<00:01, 94.1MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%|  | 52.4M/5.14G [00:00<00:49, 102MB/s]
#
# Downloading model.fp16.safetensors:   5%|▏  | 73.4M/1.39G [00:00<00:13, 101MB/s]
# Downloading (…)del.fp16.safetensors:  38%|█▏ | 62.9M/167M [00:00<00:00, 111MB/s]
#
#
# Downloading model.fp16.safetensors:  38%|█▌  | 94.4M/246M [00:00<00:01, 109MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38%|█▏ | 62.9M/167M [00:00<00:00, 109MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   1%|  | 73.4M/5.14G [00:00<00:45, 111MB/s]
#
# Downloading model.fp16.safetensors:   7%|▏  | 94.4M/1.39G [00:00<00:12, 102MB/s]
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 113MB/s]
#
#
# Downloading model.fp16.safetensors:  47%|██▎  | 115M/246M [00:01<00:01, 117MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50%|█▌ | 83.9M/167M [00:00<00:00, 108MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|  | 94.4M/5.14G [00:00<00:45, 111MB/s]
#
#
# Downloading model.fp16.safetensors:  55%|██▊  | 136M/246M [00:01<00:00, 121MB/s]
#
# Downloading model.fp16.safetensors:   8%|▎   | 115M/1.39G [00:01<00:12, 102MB/s]
# Downloading (…)del.fp16.safetensors:  63%|██▌ | 105M/167M [00:00<00:00, 110MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63%|██▌ | 105M/167M [00:01<00:00, 113MB/s]
#
# Downloading model.fp16.safetensors:   9%|▎   | 126M/1.39G [00:01<00:12, 103MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|   | 115M/5.14G [00:01<00:48, 103MB/s]
#
#
# Downloading model.fp16.safetensors:  64%|███▏ | 157M/246M [00:01<00:00, 124MB/s]
# Downloading (…)del.fp16.safetensors:  75%|███ | 126M/167M [00:01<00:00, 112MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75%|███ | 126M/167M [00:01<00:00, 124MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   2%|   | 126M/5.14G [00:01<00:48, 103MB/s]
#
# Downloading model.fp16.safetensors:  11%|▍   | 147M/1.39G [00:01<00:12, 102MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 132MB/s]
#
#
# Downloading model.fp16.safetensors:  72%|███▌ | 178M/246M [00:01<00:00, 117MB/s]
# Downloading (…)del.fp16.safetensors:  88%|███▌| 147M/167M [00:01<00:00, 114MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   3%|   | 147M/5.14G [00:01<00:46, 108MB/s]
#
# Downloading model.fp16.safetensors:  12%|▍   | 168M/1.39G [00:01<00:11, 108MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 126MB/s]
#
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 112MB/s]
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 109MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|████| 167M/167M [00:01<00:00, 107MB/s]
#
#
# Downloading model.fp16.safetensors:  14%|▌   | 189M/1.39G [00:01<00:10, 115MB/s]
#
#
# Downloading model.fp16.safetensors:  89%|████▍| 220M/246M [00:01<00:00, 127MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|   | 189M/5.14G [00:01<00:38, 129MB/s]
#
# Downloading model.fp16.safetensors:  15%|▌   | 210M/1.39G [00:01<00:09, 128MB/s]
#
#
# Downloading model.fp16.safetensors:  98%|████▉| 241M/246M [00:01<00:00, 136MB/s]
#
#
#
# Downloading model.fp16.safetensors: 100%|█████| 246M/246M [00:02<00:00, 121MB/s]
# Fetching 19 files:  21%|█████▎                   | 4/19 [00:02<00:10,  1.50it/s]
#
# Downloading model.fp16.safetensors:  17%|▋   | 231M/1.39G [00:02<00:08, 139MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   4%|▏  | 231M/5.14G [00:01<00:31, 154MB/s]
#
# Downloading model.fp16.safetensors:  18%|▋   | 252M/1.39G [00:02<00:07, 153MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 252M/5.14G [00:02<00:29, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   5%|▏  | 273M/5.14G [00:02<00:27, 176MB/s]
#
# Downloading model.fp16.safetensors:  20%|▊   | 283M/1.39G [00:02<00:06, 172MB/s]
#
# Downloading model.fp16.safetensors:  22%|▉   | 304M/1.39G [00:02<00:06, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 294M/5.14G [00:02<00:26, 183MB/s]
#
# Downloading model.fp16.safetensors:  23%|▉   | 325M/1.39G [00:02<00:05, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   6%|▏  | 315M/5.14G [00:02<00:25, 188MB/s]
#
# Downloading model.fp16.safetensors:  25%|▉   | 346M/1.39G [00:02<00:05, 191MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 336M/5.14G [00:02<00:24, 193MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 357M/5.14G [00:02<00:24, 197MB/s]
#
# Downloading model.fp16.safetensors:  27%|█   | 377M/1.39G [00:02<00:05, 195MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   7%|▏  | 377M/5.14G [00:02<00:25, 187MB/s]
#
# Downloading model.fp16.safetensors:  29%|█▏  | 398M/1.39G [00:02<00:05, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▏  | 409M/5.14G [00:02<00:24, 194MB/s]
#
# Downloading model.fp16.safetensors:  30%|█▏  | 419M/1.39G [00:03<00:05, 187MB/s]
#
# Downloading model.fp16.safetensors:  32%|█▎  | 440M/1.39G [00:03<00:05, 181MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   8%|▎  | 430M/5.14G [00:02<00:26, 180MB/s]
#
# Downloading model.fp16.safetensors:  33%|█▎  | 461M/1.39G [00:03<00:05, 180MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 451M/5.14G [00:03<00:26, 175MB/s]
#
# Downloading model.fp16.safetensors:  35%|█▍  | 482M/1.39G [00:03<00:05, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:   9%|▎  | 472M/5.14G [00:03<00:28, 166MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 493M/5.14G [00:03<00:27, 168MB/s]
#
# Downloading model.fp16.safetensors:  36%|█▍  | 503M/1.39G [00:03<00:05, 162MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 514M/5.14G [00:03<00:28, 163MB/s]
#
# Downloading model.fp16.safetensors:  38%|█▌  | 524M/1.39G [00:03<00:05, 160MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  10%|▎  | 535M/5.14G [00:03<00:28, 162MB/s]
#
# Downloading model.fp16.safetensors:  39%|█▌  | 545M/1.39G [00:03<00:05, 159MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 556M/5.14G [00:03<00:27, 166MB/s]
#
# Downloading model.fp16.safetensors:  41%|█▋  | 566M/1.39G [00:03<00:05, 161MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  11%|▎  | 577M/5.14G [00:03<00:26, 174MB/s]
#
# Downloading model.fp16.safetensors:  42%|█▋  | 587M/1.39G [00:04<00:04, 171MB/s]
#
# Downloading model.fp16.safetensors:  44%|█▊  | 608M/1.39G [00:04<00:04, 172MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 608M/5.14G [00:04<00:24, 187MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  12%|▎  | 629M/5.14G [00:04<00:23, 191MB/s]
#
# Downloading model.fp16.safetensors:  46%|█▊  | 640M/1.39G [00:04<00:04, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 650M/5.14G [00:04<00:23, 192MB/s]
#
# Downloading model.fp16.safetensors:  48%|█▉  | 661M/1.39G [00:04<00:03, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 671M/5.14G [00:04<00:23, 187MB/s]
#
# Downloading model.fp16.safetensors:  49%|█▉  | 682M/1.39G [00:04<00:03, 182MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  13%|▍  | 692M/5.14G [00:04<00:24, 180MB/s]
#
# Downloading model.fp16.safetensors:  51%|██  | 703M/1.39G [00:04<00:03, 173MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 713M/5.14G [00:04<00:25, 174MB/s]
#
# Downloading model.fp16.safetensors:  52%|██  | 724M/1.39G [00:04<00:03, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  14%|▍  | 734M/5.14G [00:04<00:25, 172MB/s]
#
# Downloading model.fp16.safetensors:  54%|██▏ | 744M/1.39G [00:04<00:04, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 755M/5.14G [00:04<00:25, 171MB/s]
#
# Downloading model.fp16.safetensors:  55%|██▏ | 765M/1.39G [00:05<00:04, 152MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  15%|▍  | 776M/5.14G [00:04<00:27, 161MB/s]
#
# Downloading model.fp16.safetensors:  57%|██▎ | 786M/1.39G [00:05<00:04, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 797M/5.14G [00:05<00:27, 157MB/s]
#
# Downloading model.fp16.safetensors:  58%|██▎ | 807M/1.39G [00:05<00:03, 154MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 818M/5.14G [00:05<00:26, 162MB/s]
#
# Downloading model.fp16.safetensors:  60%|██▍ | 828M/1.39G [00:05<00:03, 151MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  16%|▍  | 839M/5.14G [00:05<00:27, 158MB/s]
#
# Downloading model.fp16.safetensors:  61%|██▍ | 849M/1.39G [00:05<00:03, 150MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 860M/5.14G [00:05<00:28, 152MB/s]
#
# Downloading model.fp16.safetensors:  63%|██▌ | 870M/1.39G [00:05<00:03, 146MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  17%|▌  | 881M/5.14G [00:05<00:27, 156MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 902M/5.14G [00:05<00:26, 160MB/s]
#
# Downloading model.fp16.safetensors:  64%|██▌ | 891M/1.39G [00:05<00:03, 145MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 923M/5.14G [00:05<00:26, 157MB/s]
#
# Downloading model.fp16.safetensors:  66%|██▋ | 912M/1.39G [00:06<00:03, 135MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  18%|▌  | 944M/5.14G [00:06<00:27, 152MB/s]
#
# Downloading model.fp16.safetensors:  67%|██▋ | 933M/1.39G [00:06<00:03, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 965M/5.14G [00:06<00:27, 150MB/s]
#
# Downloading model.fp16.safetensors:  69%|██▋ | 954M/1.39G [00:06<00:03, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  19%|▌  | 986M/5.14G [00:06<00:28, 146MB/s]
#
# Downloading model.fp16.safetensors:  70%|██▊ | 975M/1.39G [00:06<00:03, 134MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.01G/5.14G [00:06<00:27, 152MB/s]
#
# Downloading model.fp16.safetensors:  72%|██▊ | 996M/1.39G [00:06<00:02, 137MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.03G/5.14G [00:06<00:27, 150MB/s]
#
# Downloading model.fp16.safetensors:  73%|██▏| 1.02G/1.39G [00:06<00:02, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  20%|▍ | 1.05G/5.14G [00:06<00:28, 146MB/s]
#
# Downloading model.fp16.safetensors:  75%|██▏| 1.04G/1.39G [00:07<00:02, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.07G/5.14G [00:06<00:27, 146MB/s]
#
# Downloading model.fp16.safetensors:  76%|██▎| 1.06G/1.39G [00:07<00:02, 148MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  21%|▍ | 1.09G/5.14G [00:07<00:26, 151MB/s]
#
# Downloading model.fp16.safetensors:  78%|██▎| 1.08G/1.39G [00:07<00:02, 149MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.11G/5.14G [00:07<00:28, 141MB/s]
#
# Downloading model.fp16.safetensors:  79%|██▍| 1.10G/1.39G [00:07<00:02, 141MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.13G/5.14G [00:07<00:28, 141MB/s]
#
# Downloading model.fp16.safetensors:  81%|██▍| 1.12G/1.39G [00:07<00:01, 136MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  22%|▍ | 1.15G/5.14G [00:07<00:29, 135MB/s]
#
# Downloading model.fp16.safetensors:  82%|██▍| 1.14G/1.39G [00:07<00:01, 132MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.17G/5.14G [00:07<00:29, 135MB/s]
#
# Downloading model.fp16.safetensors:  84%|██▌| 1.16G/1.39G [00:07<00:01, 138MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  23%|▍ | 1.20G/5.14G [00:07<00:27, 141MB/s]
#
# Downloading model.fp16.safetensors:  85%|██▌| 1.18G/1.39G [00:08<00:01, 134MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.22G/5.14G [00:07<00:28, 140MB/s]
#
# Downloading model.fp16.safetensors:  87%|██▌| 1.21G/1.39G [00:08<00:01, 131MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  24%|▍ | 1.24G/5.14G [00:08<00:27, 144MB/s]
#
# Downloading model.fp16.safetensors:  88%|██▋| 1.23G/1.39G [00:08<00:01, 142MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.26G/5.14G [00:08<00:27, 142MB/s]
#
# Downloading model.fp16.safetensors:  90%|██▋| 1.25G/1.39G [00:08<00:01, 140MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▍ | 1.28G/5.14G [00:08<00:28, 133MB/s]
#
# Downloading model.fp16.safetensors:  91%|██▋| 1.27G/1.39G [00:08<00:00, 149MB/s]
#
# Downloading model.fp16.safetensors:  93%|██▊| 1.29G/1.39G [00:08<00:00, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  25%|▌ | 1.30G/5.14G [00:08<00:30, 126MB/s]
#
# Downloading model.fp16.safetensors:  94%|██▊| 1.31G/1.39G [00:08<00:00, 155MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:
B/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  92%|█▊| 4.73G/5.14G [00:29<00:02, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.75G/5.14G [00:29<00:02, 178MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.77G/5.14G [00:29<00:02, 175MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  93%|█▊| 4.79G/5.14G [00:29<00:01, 172MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▊| 4.81G/5.14G [00:30<00:01, 167MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  94%|█▉| 4.83G/5.14G [00:30<00:01, 166MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.85G/5.14G [00:30<00:01, 173MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.88G/5.14G [00:30<00:01, 176MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  95%|█▉| 4.90G/5.14G [00:30<00:01, 183MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.92G/5.14G [00:30<00:01, 186MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  96%|█▉| 4.94G/5.14G [00:30<00:01, 190MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.96G/5.14G [00:30<00:00, 192MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 4.98G/5.14G [00:30<00:00, 194MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  97%|█▉| 5.00G/5.14G [00:31<00:00, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.02G/5.14G [00:31<00:00, 196MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  98%|█▉| 5.05G/5.14G [00:31<00:00, 202MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors:  99%|█▉| 5.09G/5.14G [00:31<00:00, 208MB/s]
#
#
#
# Downloading (…)del.fp16.safetensors: 100%|██| 5.14G/5.14G [00:31<00:00, 162MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:32<00:00,  1.70s/it]
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.76it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:41<00:00,  1.20it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.96it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.59it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:45<00:00,  1.09it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.54it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.75it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.07it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.73it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  2.26it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:46<00:00,  1.07it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.69it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.71it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
#
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  2.57it/s]
# 100%|███████████████████████████████████████████| 50/50 [00:47<00:00,  1.06it/s]
#
# **************************************************
