# %%
# !unzip -q /kaggle/input/the-nature-conservancy-fisheries-monitoring/train.zip -d /kaggle/working/train
# !unzip -q /kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg1.zip -d /kaggle/working/test_stg1
# !unzip -q /kaggle/input/the-nature-conservancy-fisheries-monitoring/sample_submission_stg1.csv.zip -d /kaggle/working/sample_submission_stg1.csv
# !unzip -q /kaggle/input/the-nature-conservancy-fisheries-monitoring/sample_submission_stg2.csv.zip -d /kaggle/working/sample_submission_stg2.csv

# %%
!7z e /kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg2.7z -o/kaggle/working/test_stg2
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=C.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1152137421 bytes (1099 MiB)
#
# Extracting archive: /kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg2.7z
# --
# Path = /kaggle/input/the-nature-conservancy-fisheries-monitoring/test_stg2.7z
# Type = 7z
# Physical Size = 1152137421
# Headers Size = 82081
# Method = LZMA:25
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 12153
# Size:       1169524391
# Compressed: 1152137421
