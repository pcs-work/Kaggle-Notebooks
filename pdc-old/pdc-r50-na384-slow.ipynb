# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import models, transforms

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **Utilities and Helpers**

# %%
SEED = 42
SIZE = 384
le = LabelEncoder()


def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def show_loss_graphs(A: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()

    
def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(L)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()


def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 ):
        
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize([0.485, 0.456, 0.406],
                                                     [0.229, 0.224, 0.225]),
                                ])
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
    
cfg = CFG(seed=SEED)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(self, images: np.ndarray, labels: np.ndarray = None, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is not None:
            return self.transform(self.images[idx]), torch.LongTensor(self.labels[idx])
        else:
            return self.transform(self.images[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        self.model = models.resnet50(pretrained=True, progress=True)
        self.freeze()
        self.model.fc = nn.Linear(in_features=self.model.fc.in_features, out_features=10)
    
    def freeze(self):
        for params in self.parameters(): params.requires_grad = False

    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helpers**

# %%
def fit(model=None, 
        optimizer=None, 
        scheduler_rlrop=None,
        scheduler_oclr=None,
        epochs=None, 
        early_stopping_patience=None, 
        dataloaders=None, 
        fold=None, 
        save_path=None,
        device=None,
        verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies, LRs = [], [], []
    if fold: name = f"state_fold_{fold}.pt"
    else: name = "state.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []

            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, BLE, BAE, name


def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.argmax(torch.exp(model(X)), dim=1)
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
images = np.load(f"../input/pdc-images-{SIZE}/images-{SIZE}.npy")
df = pd.read_csv("../input/paddy-disease-classification/train.csv")
labels = df.label.copy().values
labels = le.fit_transform(labels)

# %%
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(images, labels):
    break

tr_images, va_images, tr_labels, va_labels = images[tr_idx], images[va_idx], labels[tr_idx], labels[va_idx]

tr_data_setup = DS(tr_images, tr_labels.reshape(-1, 1), cfg.transform)
va_data_setup = DS(va_images, va_labels.reshape(-1, 1), cfg.transform)

dataloaders = {
    "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
    "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
}

cfg = CFG(lr=1e-5, wd=1e-4, epochs=500, early_stopping=50, batch_size=64, 
          steps_per_epoch=len(dataloaders["train"]))

torch.manual_seed(cfg.seed)
model = Model().to(cfg.device)
optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
scheduler_oclr = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, 
                                               max_lr=cfg.max_lr, 
                                               epochs=cfg.epochs, 
                                               steps_per_epoch=cfg.steps_per_epoch,
                                               pct_start=cfg.pct_start, 
                                               div_factor=cfg.div_factor, 
                                               final_div_factor=cfg.final_div_factor)
# scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
#                                                       patience=cfg.patience,
#                                                       eps=cfg.eps,
#                                                       verbose=True)

# scheduler_oclr = None
scheduler_rlrop = None

L, A, LR, BLE, BAE, name = fit(model=model, 
                               optimizer=optimizer, 
                               scheduler_oclr=scheduler_oclr,
                               scheduler_rlrop=scheduler_rlrop,
                               epochs=cfg.epochs, 
                               early_stopping_patience=cfg.early_stopping, 
                               dataloaders=dataloaders, 
                               device=cfg.device,
                               save_path=cfg.save_path,
                               fold=None,
                               verbose=True)

breaker()
show_loss_graphs(L)
breaker()
show_accuracy_graphs(A)
breaker()

if scheduler_oclr:
    show_lr_graph(LR)
    breaker()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# **************************************************
#
# Training ...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 2.31657 | Valid Loss: 2.24657 |Train Accs: 0.13594 | Valid Accs: 0.21279 | Time: 78.67 seconds
# Epoch: 2 | Train Loss: 2.20800 | Valid Loss: 2.16983 |Train Accs: 0.21886 | Valid Accs: 0.24189 | Time: 71.57 seconds
# Epoch: 3 | Train Loss: 2.15279 | Valid Loss: 2.13416 |Train Accs: 0.23455 | Valid Accs: 0.24380 | Time: 71.72 seconds
# Epoch: 4 | Train Loss: 2.12106 | Valid Loss: 2.10525 |Train Accs: 0.25780 | Valid Accs: 0.26574 | Time: 71.56 seconds
# Epoch: 5 | Train Loss: 2.09267 | Valid Loss: 2.07019 |Train Accs: 0.29153 | Valid Accs: 0.32156 | Time: 71.50 seconds
# Epoch: 6 | Train Loss: 2.05206 | Valid Loss: 2.02430 |Train Accs: 0.32615 | Valid Accs: 0.34781 | Time: 71.60 seconds
# Epoch: 7 | Train Loss: 2.00448 | Valid Loss: 1.96955 |Train Accs: 0.35310 | Valid Accs: 0.35687 | Time: 71.47 seconds
# Epoch: 8 | Train Loss: 1.94875 | Valid Loss: 1.91093 |Train Accs: 0.37630 | Valid Accs: 0.38836 | Time: 71.57 seconds
# Epoch: 9 | Train Loss: 1.88520 | Valid Loss: 1.84800 |Train Accs: 0.39535 | Valid Accs: 0.42032 | Time: 71.97 seconds
# Epoch: 10 | Train Loss: 1.82223 | Valid Loss: 1.77392 |Train Accs: 0.41571 | Valid Accs: 0.43034 | Time: 71.86 seconds
# Epoch: 11 | Train Loss: 1.75733 | Valid Loss: 1.71503 |Train Accs: 0.43896 | Valid Accs: 0.42987 | Time: 71.91 seconds
# Epoch: 12 | Train Loss: 1.69493 | Valid Loss: 1.64647 |Train Accs: 0.45749 | Valid Accs: 0.46565 | Time: 71.39 seconds
# Epoch: 13 | Train Loss: 1.63665 | Valid Loss: 1.58617 |Train Accs: 0.47452 | Valid Accs: 0.49141 | Time: 71.71 seconds
# Epoch: 14 | Train Loss: 1.58398 | Valid Loss: 1.54520 |Train Accs: 0.49717 | Valid Accs: 0.50048 | Time: 71.98 seconds
# Epoch: 15 | Train Loss: 1.52599 | Valid Loss: 1.47565 |Train Accs: 0.51444 | Valid Accs: 0.52815 | Time: 71.60 seconds
# Epoch: 16 | Train Loss: 1.47456 | Valid Loss: 1.42292 |Train Accs: 0.53186 | Valid Accs: 0.53721 | Time: 71.59 seconds
# Epoch: 17 | Train Loss: 1.43367 | Valid Loss: 1.37771 |Train Accs: 0.54287 | Valid Accs: 0.55677 | Time: 71.50 seconds
# Epoch: 18 | Train Loss: 1.39156 | Valid Loss: 1.32616 |Train Accs: 0.55031 | Valid Accs: 0.57109 | Time: 71.55 seconds
# Epoch: 19 | Train Loss: 1.34806 | Valid Loss: 1.29690 |Train Accs: 0.56775 | Valid Accs: 0.58874 | Time: 71.37 seconds
# Epoch: 20 | Train Loss: 1.30966 | Valid Loss: 1.25566 |Train Accs: 0.58064 | Valid Accs: 0.59494 | Time: 71.49 seconds
# Epoch: 21 | Train Loss: 1.27779 | Valid Loss: 1.21651 |Train Accs: 0.59028 | Valid Accs: 0.61641 | Time: 71.40 seconds
# Epoch: 22 | Train Loss: 1.23689 | Valid Loss: 1.18373 |Train Accs: 0.60348 | Valid Accs: 0.62118 | Time: 71.74 seconds
# Epoch: 23 | Train Loss: 1.20600 | Valid Loss: 1.17475 |Train Accs: 0.61156 | Valid Accs: 0.61975 | Time: 71.64 seconds
# Epoch: 24 | Train Loss: 1.17596 | Valid Loss: 1.13460 |Train Accs: 0.62654 | Valid Accs: 0.64504 | Time: 71.62 seconds
# Epoch: 25 | Train Loss: 1.15300 | Valid Loss: 1.09740 |Train Accs: 0.63429 | Valid Accs: 0.64695 | Time: 71.41 seconds
# Epoch: 26 | Train Loss: 1.12999 | Valid Loss: 1.07355 |Train Accs: 0.63649 | Valid Accs: 0.66221 | Time: 71.37 seconds
# Epoch: 27 | Train Loss: 1.10302 | Valid Loss: 1.04750 |Train Accs: 0.65254 | Valid Accs: 0.66508 | Time: 71.40 seconds
# Epoch: 28 | Train Loss: 1.07996 | Valid Loss: 1.03304 |Train Accs: 0.65312 | Valid Accs: 0.66794 | Time: 71.93 seconds
# Epoch: 29 | Train Loss: 1.06001 | Valid Loss: 1.00237 |Train Accs: 0.65794 | Valid Accs: 0.67987 | Time: 71.63 seconds
# Epoch: 30 | Train Loss: 1.04350 | Valid Loss: 0.99426 |Train Accs: 0.66399 | Valid Accs: 0.67223 | Time: 72.15 seconds
# Epoch: 31 | Train Loss: 1.01957 | Valid Loss: 0.96807 |Train Accs: 0.67594 | Valid Accs: 0.69561 | Time: 71.76 seconds
# Epoch: 32 | Train Loss: 1.01169 | Valid Loss: 0.95679 |Train Accs: 0.67378 | Valid Accs: 0.69847 | Time: 71.42 seconds
# Epoch: 33 | Train Loss: 0.98401 | Valid Loss: 0.94231 |Train Accs: 0.67963 | Valid Accs: 0.70277 | Time: 71.44 seconds
# Epoch: 34 | Train Loss: 0.96904 | Valid Loss: 0.98634 |Train Accs: 0.68472 | Valid Accs: 0.67271 | Time: 70.73 seconds
# Epoch: 35 | Train Loss: 0.96947 | Valid Loss: 0.90411 |Train Accs: 0.68539 | Valid Accs: 0.70992 | Time: 69.89 seconds
# Epoch: 36 | Train Loss: 0.94470 | Valid Loss: 0.89449 |Train Accs: 0.68983 | Valid Accs: 0.72519 | Time: 69.88 seconds
# Epoch: 37 | Train Loss: 0.93454 | Valid Loss: 0.95278 |Train Accs: 0.69839 | Valid Accs: 0.68321 | Time: 69.62 seconds
# Epoch: 38 | Train Loss: 0.91495 | Valid Loss: 0.88727 |Train Accs: 0.70621 | Valid Accs: 0.72424 | Time: 69.88 seconds
# Epoch: 39 | Train Loss: 0.90994 | Valid Loss: 0.86172 |Train Accs: 0.70703 | Valid Accs: 0.73092 | Time: 69.80 seconds
# Epoch: 40 | Train Loss: 0.89591 | Valid Loss: 0.86508 |Train Accs: 0.70857 | Valid Accs: 0.72662 | Time: 69.58 seconds
# Epoch: 41 | Train Loss: 0.88424 | Valid Loss: 0.85580 |Train Accs: 0.71432 | Valid Accs: 0.73139 | Time: 69.99 seconds
# Epoch: 42 | Train Loss: 0.88318 | Valid Loss: 0.89812 |Train Accs: 0.71142 | Valid Accs: 0.72281 | Time: 69.58 seconds
# Epoch: 43 | Train Loss: 0.85656 | Valid Loss: 0.83741 |Train Accs: 0.72546 | Valid Accs: 0.73473 | Time: 69.88 seconds
# Epoch: 44 | Train Loss: 0.86516 | Valid Loss: 0.81326 |Train Accs: 0.71178 | Valid Accs: 0.74905 | Time: 69.84 seconds
# Epoch: 45 | Train Loss: 0.84017 | Valid Loss: 0.83569 |Train Accs: 0.72788 | Valid Accs: 0.73760 | Time: 69.73 seconds
# Epoch: 46 | Train Loss: 0.83504 | Valid Loss: 0.86980 |Train Accs: 0.72411 | Valid Accs: 0.72185 | Time: 70.28 seconds
# Epoch: 47 | Train Loss: 0.82832 | Valid Loss: 0.81193 |Train Accs: 0.73529 | Valid Accs: 0.74427 | Time: 70.29 seconds
# Epoch: 48 | Train Loss: 0.82463 | Valid Loss: 0.78302 |Train Accs: 0.73124 | Valid Accs: 0.75143 | Time: 70.08 seconds
# Epoch: 49 | Train Loss: 0.81766 | Valid Loss: 0.79227 |Train Accs: 0.73333 | Valid Accs: 0.74237 | Time: 69.95 seconds
# Epoch: 50 | Train Loss: 0.81230 | Valid Loss: 0.84768 |Train Accs: 0.73162 | Valid Accs: 0.71040 | Time: 69.85 seconds
# Epoch: 51 | Train Loss: 0.79791 | Valid Loss: 0.76129 |Train Accs: 0.73568 | Valid Accs: 0.76145 | Time: 70.11 seconds
# Epoch: 52 | Train Loss: 0.80376 | Valid Loss: 0.78673 |Train Accs: 0.73220 | Valid Accs: 0.74809 | Time: 69.85 seconds
# Epoch: 53 | Train Loss: 0.79117 | Valid Loss: 0.76685 |Train Accs: 0.74026 | Valid Accs: 0.76145 | Time: 69.81 seconds
# Epoch: 54 | Train Loss: 0.77912 | Valid Loss: 0.79185 |Train Accs: 0.74165 | Valid Accs: 0.74905 | Time: 69.92 seconds
# Epoch: 55 | Train Loss: 0.76715 | Valid Loss: 0.86376 |Train Accs: 0.74815 | Valid Accs: 0.71183 | Time: 69.68 seconds
# Epoch: 56 | Train Loss: 0.75881 | Valid Loss: 0.80441 |Train Accs: 0.74998 | Valid Accs: 0.74475 | Time: 69.98 seconds
# Epoch: 57 | Train Loss: 0.74298 | Valid Loss: 0.79091 |Train Accs: 0.75403 | Valid Accs: 0.74523 | Time: 69.70 seconds
# Epoch: 58 | Train Loss: 0.75931 | Valid Loss: 0.75101 |Train Accs: 0.74659 | Valid Accs: 0.75859 | Time: 69.98 seconds
# Epoch: 59 | Train Loss: 0.74315 | Valid Loss: 0.79012 |Train Accs: 0.75828 | Valid Accs: 0.73426 | Time: 69.78 seconds
# Epoch: 60 | Train Loss: 0.73625 | Valid Loss: 0.73213 |Train Accs: 0.75789 | Valid Accs: 0.77242 | Time: 70.09 seconds
# Epoch: 61 | Train Loss: 0.74890 | Valid Loss: 0.79908 |Train Accs: 0.75403 | Valid Accs: 0.74237 | Time: 69.89 seconds
# Epoch: 62 | Train Loss: 0.73730 | Valid Loss: 0.71006 |Train Accs: 0.75823 | Valid Accs: 0.77433 | Time: 70.24 seconds
# Epoch: 63 | Train Loss: 0.71958 | Valid Loss: 0.72729 |Train Accs: 0.76255 | Valid Accs: 0.76622 | Time: 70.02 seconds
# Epoch: 64 | Train Loss: 0.72162 | Valid Loss: 0.71574 |Train Accs: 0.76099 | Valid Accs: 0.77195 | Time: 70.01 seconds
# Epoch: 65 | Train Loss: 0.70346 | Valid Loss: 0.82946 |Train Accs: 0.76466 | Valid Accs: 0.72662 | Time: 69.89 seconds
# Epoch: 66 | Train Loss: 0.71190 | Valid Loss: 0.69819 |Train Accs: 0.76840 | Valid Accs: 0.78006 | Time: 70.34 seconds
# Epoch: 67 | Train Loss: 0.69587 | Valid Loss: 0.70368 |Train Accs: 0.77056 | Valid Accs: 0.77242 | Time: 69.91 seconds
# Epoch: 68 | Train Loss: 0.70554 | Valid Loss: 0.69236 |Train Accs: 0.76807 | Valid Accs: 0.77385 | Time: 70.32 seconds
# Epoch: 69 | Train Loss: 0.68969 | Valid Loss: 0.69979 |Train Accs: 0.77243 | Valid Accs: 0.78769 | Time: 70.25 seconds
# Epoch: 70 | Train Loss: 0.69527 | Valid Loss: 0.69534 |Train Accs: 0.76891 | Valid Accs: 0.78340 | Time: 70.18 seconds
# Epoch: 71 | Train Loss: 0.67308 | Valid Loss: 0.71389 |Train Accs: 0.78030 | Valid Accs: 0.76908 | Time: 69.67 seconds
# Epoch: 72 | Train Loss: 0.68266 | Valid Loss: 0.71294 |Train Accs: 0.77277 | Valid Accs: 0.76670 | Time: 69.99 seconds
# Epoch: 73 | Train Loss: 0.67359 | Valid Loss: 0.84033 |Train Accs: 0.77625 | Valid Accs: 0.73426 | Time: 70.51 seconds
# Epoch: 74 | Train Loss: 0.67924 | Valid Loss: 0.69418 |Train Accs: 0.77685 | Valid Accs: 0.77385 | Time: 70.28 seconds
# Epoch: 75 | Train Loss: 0.63426 | Valid Loss: 0.74707 |Train Accs: 0.79043 | Valid Accs: 0.75429 | Time: 70.08 seconds
# Epoch: 76 | Train Loss: 0.67295 | Valid Loss: 0.68155 |Train Accs: 0.77514 | Valid Accs: 0.77910 | Time: 70.41 seconds
# Epoch: 77 | Train Loss: 0.66506 | Valid Loss: 0.68231 |Train Accs: 0.77668 | Valid Accs: 0.77863 | Time: 69.61 seconds
# Epoch: 78 | Train Loss: 0.65936 | Valid Loss: 0.66868 |Train Accs: 0.78023 | Valid Accs: 0.78244 | Time: 70.29 seconds
# Epoch: 79 | Train Loss: 0.65120 | Valid Loss: 0.68067 |Train Accs: 0.78237 | Valid Accs: 0.78817 | Time: 69.52 seconds
# Epoch: 80 | Train Loss: 0.64485 | Valid Loss: 0.65802 |Train Accs: 0.78827 | Valid Accs: 0.79103 | Time: 69.84 seconds
# Epoch: 81 | Train Loss: 0.63260 | Valid Loss: 0.71538 |Train Accs: 0.79376 | Valid Accs: 0.76718 | Time: 69.74 seconds
# Epoch: 82 | Train Loss: 0.63567 | Valid Loss: 0.68613 |Train Accs: 0.78462 | Valid Accs: 0.78292 | Time: 69.78 seconds
# Epoch: 83 | Train Loss: 0.62271 | Valid Loss: 0.77871 |Train Accs: 0.79290 | Valid Accs: 0.75095 | Time: 69.59 seconds
# Epoch: 84 | Train Loss: 0.63176 | Valid Loss: 0.68504 |Train Accs: 0.79244 | Valid Accs: 0.77672 | Time: 70.02 seconds
# Epoch: 85 | Train Loss: 0.61713 | Valid Loss: 0.63845 |Train Accs: 0.79434 | Valid Accs: 0.79914 | Time: 70.36 seconds
# Epoch: 86 | Train Loss: 0.63123 | Valid Loss: 0.63960 |Train Accs: 0.79040 | Valid Accs: 0.79342 | Time: 70.01 seconds
# Epoch: 87 | Train Loss: 0.63747 | Valid Loss: 0.67897 |Train Accs: 0.78923 | Valid Accs: 0.78244 | Time: 70.21 seconds
# Epoch: 88 | Train Loss: 0.60624 | Valid Loss: 0.66573 |Train Accs: 0.80084 | Valid Accs: 0.78483 | Time: 70.06 seconds
# Epoch: 89 | Train Loss: 0.61626 | Valid Loss: 0.62728 |Train Accs: 0.79340 | Valid Accs: 0.79342 | Time: 70.28 seconds
# Epoch: 90 | Train Loss: 0.58342 | Valid Loss: 0.69417 |Train Accs: 0.80717 | Valid Accs: 0.77147 | Time: 70.10 seconds
# Epoch: 91 | Train Loss: 0.60028 | Valid Loss: 0.66664 |Train Accs: 0.79746 | Valid Accs: 0.78053 | Time: 69.78 seconds
# Epoch: 92 | Train Loss: 0.59218 | Valid Loss: 0.66816 |Train Accs: 0.80549 | Valid Accs: 0.78721 | Time: 69.94 seconds
# Epoch: 93 | Train Loss: 0.58962 | Valid Loss: 0.66840 |Train Accs: 0.80278 | Valid Accs: 0.79151 | Time: 69.91 seconds
# Epoch: 94 | Train Loss: 0.59431 | Valid Loss: 0.64166 |Train Accs: 0.80250 | Valid Accs: 0.80105 | Time: 69.91 seconds
# Epoch: 95 | Train Loss: 0.57498 | Valid Loss: 0.77090 |Train Accs: 0.80854 | Valid Accs: 0.74905 | Time: 69.96 seconds
# Epoch: 96 | Train Loss: 0.59471 | Valid Loss: 0.65002 |Train Accs: 0.79746 | Valid Accs: 0.78674 | Time: 69.93 seconds
# Epoch: 97 | Train Loss: 0.58815 | Valid Loss: 0.61778 |Train Accs: 0.79935 | Valid Accs: 0.80057 | Time: 70.06 seconds
# Epoch: 98 | Train Loss: 0.57078 | Valid Loss: 0.68051 |Train Accs: 0.81164 | Valid Accs: 0.78292 | Time: 69.97 seconds
# Epoch: 99 | Train Loss: 0.56205 | Valid Loss: 0.61886 |Train Accs: 0.81377 | Valid Accs: 0.79771 | Time: 69.61 seconds
# Epoch: 100 | Train Loss: 0.55562 | Valid Loss: 0.64567 |Train Accs: 0.81953 | Valid Accs: 0.79198 | Time: 69.72 seconds
# Epoch: 101 | Train Loss: 0.56934 | Valid Loss: 0.60583 |Train Accs: 0.81221 | Valid Accs: 0.81393 | Time: 69.98 seconds
# Epoch: 102 | Train Loss: 0.56242 | Valid Loss: 0.59466 |Train Accs: 0.81279 | Valid Accs: 0.81202 | Time: 70.03 seconds
# Epoch: 103 | Train Loss: 0.56183 | Valid Loss: 0.65247 |Train Accs: 0.81392 | Valid Accs: 0.78769 | Time: 69.89 seconds
# Epoch: 104 | Train Loss: 0.54933 | Valid Loss: 0.72261 |Train Accs: 0.81574 | Valid Accs: 0.77338 | Time: 69.68 seconds
# Epoch: 105 | Train Loss: 0.55254 | Valid Loss: 0.58320 |Train Accs: 0.81843 | Valid Accs: 0.81584 | Time: 70.15 seconds
# Epoch: 106 | Train Loss: 0.56007 | Valid Loss: 0.59618 |Train Accs: 0.81341 | Valid Accs: 0.81107 | Time: 70.22 seconds
# Epoch: 107 | Train Loss: 0.55072 | Valid Loss: 0.64317 |Train Accs: 0.82006 | Valid Accs: 0.79437 | Time: 70.32 seconds
# Epoch: 108 | Train Loss: 0.55180 | Valid Loss: 0.65087 |Train Accs: 0.81380 | Valid Accs: 0.79389 | Time: 70.19 seconds
# Epoch: 109 | Train Loss: 0.53343 | Valid Loss: 0.64723 |Train Accs: 0.82469 | Valid Accs: 0.79389 | Time: 70.33 seconds
# Epoch: 110 | Train Loss: 0.53445 | Valid Loss: 0.62188 |Train Accs: 0.82222 | Valid Accs: 0.79676 | Time: 70.19 seconds
# Epoch: 111 | Train Loss: 0.54045 | Valid Loss: 0.65113 |Train Accs: 0.82222 | Valid Accs: 0.79819 | Time: 69.90 seconds
# Epoch: 112 | Train Loss: 0.52535 | Valid Loss: 0.71175 |Train Accs: 0.82663 | Valid Accs: 0.77624 | Time: 69.87 seconds
# Epoch: 113 | Train Loss: 0.53020 | Valid Loss: 0.62121 |Train Accs: 0.82414 | Valid Accs: 0.80391 | Time: 70.10 seconds
# Epoch: 114 | Train Loss: 0.53478 | Valid Loss: 0.64664 |Train Accs: 0.82399 | Valid Accs: 0.78721 | Time: 69.76 seconds
# Epoch: 115 | Train Loss: 0.51842 | Valid Loss: 0.57225 |Train Accs: 0.82841 | Valid Accs: 0.82300 | Time: 70.05 seconds
# Epoch: 116 | Train Loss: 0.53148 | Valid Loss: 0.68765 |Train Accs: 0.81536 | Valid Accs: 0.78387 | Time: 69.66 seconds
# Epoch: 117 | Train Loss: 0.51706 | Valid Loss: 0.68689 |Train Accs: 0.82579 | Valid Accs: 0.78149 | Time: 70.11 seconds
# Epoch: 118 | Train Loss: 0.53302 | Valid Loss: 0.64816 |Train Accs: 0.82351 | Valid Accs: 0.79294 | Time: 69.90 seconds
# Epoch: 119 | Train Loss: 0.50647 | Valid Loss: 0.71851 |Train Accs: 0.82965 | Valid Accs: 0.77958 | Time: 69.75 seconds
# Epoch: 120 | Train Loss: 0.51592 | Valid Loss: 0.58377 |Train Accs: 0.82738 | Valid Accs: 0.81059 | Time: 69.49 seconds
# Epoch: 121 | Train Loss: 0.51297 | Valid Loss: 0.56778 |Train Accs: 0.83047 | Valid Accs: 0.82013 | Time: 70.46 seconds
# Epoch: 122 | Train Loss: 0.49599 | Valid Loss: 0.60001 |Train Accs: 0.83421 | Valid Accs: 0.80439 | Time: 69.74 seconds
# Epoch: 123 | Train Loss: 0.51439 | Valid Loss: 0.67142 |Train Accs: 0.82826 | Valid Accs: 0.78387 | Time: 69.72 seconds
# Epoch: 124 | Train Loss: 0.50338 | Valid Loss: 0.65722 |Train Accs: 0.83023 | Valid Accs: 0.79198 | Time: 69.75 seconds
# Epoch: 125 | Train Loss: 0.50827 | Valid Loss: 0.59092 |Train Accs: 0.83510 | Valid Accs: 0.81679 | Time: 69.77 seconds
# Epoch: 126 | Train Loss: 0.49809 | Valid Loss: 0.53550 |Train Accs: 0.83644 | Valid Accs: 0.82252 | Time: 70.47 seconds
# Epoch: 127 | Train Loss: 0.49232 | Valid Loss: 0.59123 |Train Accs: 0.83997 | Valid Accs: 0.81107 | Time: 70.69 seconds
# Epoch: 128 | Train Loss: 0.48914 | Valid Loss: 0.59139 |Train Accs: 0.83455 | Valid Accs: 0.81823 | Time: 70.65 seconds
# Epoch: 129 | Train Loss: 0.48930 | Valid Loss: 0.60264 |Train Accs: 0.83719 | Valid Accs: 0.81632 | Time: 70.58 seconds
# Epoch: 130 | Train Loss: 0.49665 | Valid Loss: 0.58492 |Train Accs: 0.83623 | Valid Accs: 0.81489 | Time: 70.70 seconds
# Epoch: 131 | Train Loss: 0.48671 | Valid Loss: 0.55500 |Train Accs: 0.83824 | Valid Accs: 0.82443 | Time: 70.34 seconds
# Epoch: 132 | Train Loss: 0.47181 | Valid Loss: 0.67300 |Train Accs: 0.83815 | Valid Accs: 0.78101 | Time: 70.33 seconds
# Epoch: 133 | Train Loss: 0.49070 | Valid Loss: 0.61132 |Train Accs: 0.83604 | Valid Accs: 0.79723 | Time: 71.15 seconds
# Epoch: 134 | Train Loss: 0.47749 | Valid Loss: 0.60872 |Train Accs: 0.84064 | Valid Accs: 0.81011 | Time: 70.73 seconds
# Epoch: 135 | Train Loss: 0.48383 | Valid Loss: 0.59732 |Train Accs: 0.83944 | Valid Accs: 0.80868 | Time: 70.86 seconds
# Epoch: 136 | Train Loss: 0.48652 | Valid Loss: 0.61397 |Train Accs: 0.83575 | Valid Accs: 0.80534 | Time: 70.86 seconds
# Epoch: 137 | Train Loss: 0.47275 | Valid Loss: 0.57352 |Train Accs: 0.84655 | Valid Accs: 0.81632 | Time: 70.94 seconds
# Epoch: 138 | Train Loss: 0.47005 | Valid Loss: 0.57841 |Train Accs: 0.84218 | Valid Accs: 0.81632 | Time: 70.94 seconds
# Epoch: 139 | Train Loss: 0.47003 | Valid Loss: 0.55386 |Train Accs: 0.84362 | Valid Accs: 0.82490 | Time: 70.60 seconds
# Epoch: 140 | Train Loss: 0.47881 | Valid Loss: 0.57481 |Train Accs: 0.83464 | Valid Accs: 0.81441 | Time: 71.14 seconds
# Epoch: 141 | Train Loss: 0.46817 | Valid Loss: 0.59137 |Train Accs: 0.84520 | Valid Accs: 0.81727 | Time: 70.89 seconds
# Epoch: 142 | Train Loss: 0.48224 | Valid Loss: 0.55443 |Train Accs: 0.83932 | Valid Accs: 0.82538 | Time: 71.36 seconds
# Epoch: 143 | Train Loss: 0.44687 | Valid Loss: 0.69573 |Train Accs: 0.85110 | Valid Accs: 0.78387 | Time: 70.60 seconds
# Epoch: 144 | Train Loss: 0.46255 | Valid Loss: 0.55343 |Train Accs: 0.85034 | Valid Accs: 0.82252 | Time: 70.81 seconds
# Epoch: 145 | Train Loss: 0.45424 | Valid Loss: 0.57950 |Train Accs: 0.84825 | Valid Accs: 0.81727 | Time: 70.64 seconds
# Epoch: 146 | Train Loss: 0.46678 | Valid Loss: 0.62271 |Train Accs: 0.84357 | Valid Accs: 0.80105 | Time: 71.06 seconds
# Epoch: 147 | Train Loss: 0.46064 | Valid Loss: 0.61679 |Train Accs: 0.84614 | Valid Accs: 0.80487 | Time: 70.94 seconds
# Epoch: 148 | Train Loss: 0.44758 | Valid Loss: 0.52968 |Train Accs: 0.84724 | Valid Accs: 0.82681 | Time: 70.96 seconds
# Epoch: 149 | Train Loss: 0.44041 | Valid Loss: 0.57231 |Train Accs: 0.85336 | Valid Accs: 0.81679 | Time: 70.77 seconds
# Epoch: 150 | Train Loss: 0.46188 | Valid Loss: 0.55574 |Train Accs: 0.84376 | Valid Accs: 0.82395 | Time: 70.87 seconds
# Epoch: 151 | Train Loss: 0.45800 | Valid Loss: 0.59096 |Train Accs: 0.84472 | Valid Accs: 0.81679 | Time: 71.06 seconds
# Epoch: 152 | Train Loss: 0.45123 | Valid Loss: 0.59130 |Train Accs: 0.85345 | Valid Accs: 0.81727 | Time: 70.89 seconds
# Epoch: 153 | Train Loss: 0.44047 | Valid Loss: 0.54846 |Train Accs: 0.85497 | Valid Accs: 0.82443 | Time: 71.03 seconds
# Epoch: 154 | Train Loss: 0.44230 | Valid Loss: 0.54765 |Train Accs: 0.85317 | Valid Accs: 0.82968 | Time: 70.77 seconds
# Epoch: 155 | Train Loss: 0.43969 | Valid Loss: 0.54372 |Train Accs: 0.85557 | Valid Accs: 0.82681 | Time: 70.69 seconds
# Epoch: 156 | Train Loss: 0.45027 | Valid Loss: 0.63911 |Train Accs: 0.85036 | Valid Accs: 0.78865 | Time: 71.50 seconds
# Epoch: 157 | Train Loss: 0.44112 | Valid Loss: 0.56337 |Train Accs: 0.85137 | Valid Accs: 0.81679 | Time: 71.13 seconds
# Epoch: 158 | Train Loss: 0.45004 | Valid Loss: 0.58386 |Train Accs: 0.84580 | Valid Accs: 0.81107 | Time: 71.08 seconds
# Epoch: 159 | Train Loss: 0.43692 | Valid Loss: 0.53802 |Train Accs: 0.85482 | Valid Accs: 0.82729 | Time: 70.86 seconds
# Epoch: 160 | Train Loss: 0.44142 | Valid Loss: 0.58340 |Train Accs: 0.85120 | Valid Accs: 0.81202 | Time: 70.76 seconds
# Epoch: 161 | Train Loss: 0.44074 | Valid Loss: 0.57564 |Train Accs: 0.84894 | Valid Accs: 0.80868 | Time: 69.71 seconds
# Epoch: 162 | Train Loss: 0.43776 | Valid Loss: 0.54593 |Train Accs: 0.85017 | Valid Accs: 0.82109 | Time: 69.60 seconds
# Epoch: 163 | Train Loss: 0.42986 | Valid Loss: 0.54395 |Train Accs: 0.86020 | Valid Accs: 0.82681 | Time: 69.88 seconds
# Epoch: 164 | Train Loss: 0.43473 | Valid Loss: 0.52725 |Train Accs: 0.85672 | Valid Accs: 0.83540 | Time: 70.35 seconds
# Epoch: 165 | Train Loss: 0.41778 | Valid Loss: 0.53337 |Train Accs: 0.86276 | Valid Accs: 0.84017 | Time: 69.84 seconds
# Epoch: 166 | Train Loss: 0.44265 | Valid Loss: 0.52292 |Train Accs: 0.85290 | Valid Accs: 0.83206 | Time: 69.86 seconds
# Epoch: 167 | Train Loss: 0.43249 | Valid Loss: 0.55296 |Train Accs: 0.85432 | Valid Accs: 0.82109 | Time: 69.73 seconds
# Epoch: 168 | Train Loss: 0.42965 | Valid Loss: 0.52652 |Train Accs: 0.85684 | Valid Accs: 0.83302 | Time: 69.63 seconds
# Epoch: 169 | Train Loss: 0.42533 | Valid Loss: 0.59988 |Train Accs: 0.86012 | Valid Accs: 0.81011 | Time: 69.63 seconds
# Epoch: 170 | Train Loss: 0.42767 | Valid Loss: 0.56511 |Train Accs: 0.85948 | Valid Accs: 0.82300 | Time: 70.07 seconds
# Epoch: 171 | Train Loss: 0.42581 | Valid Loss: 0.56126 |Train Accs: 0.86137 | Valid Accs: 0.82061 | Time: 69.79 seconds
# Epoch: 172 | Train Loss: 0.42294 | Valid Loss: 0.56673 |Train Accs: 0.86108 | Valid Accs: 0.82300 | Time: 69.58 seconds
# Epoch: 173 | Train Loss: 0.42084 | Valid Loss: 0.54615 |Train Accs: 0.86024 | Valid Accs: 0.81775 | Time: 69.82 seconds
# Epoch: 174 | Train Loss: 0.42467 | Valid Loss: 0.52973 |Train Accs: 0.86092 | Valid Accs: 0.82538 | Time: 69.76 seconds
# Epoch: 175 | Train Loss: 0.40700 | Valid Loss: 0.54299 |Train Accs: 0.86655 | Valid Accs: 0.81823 | Time: 69.59 seconds
# Epoch: 176 | Train Loss: 0.43063 | Valid Loss: 0.55259 |Train Accs: 0.85557 | Valid Accs: 0.82443 | Time: 69.81 seconds
# Epoch: 177 | Train Loss: 0.40916 | Valid Loss: 0.51454 |Train Accs: 0.86660 | Valid Accs: 0.83445 | Time: 70.07 seconds
# Epoch: 178 | Train Loss: 0.41218 | Valid Loss: 0.56602 |Train Accs: 0.86653 | Valid Accs: 0.81870 | Time: 70.08 seconds
# Epoch: 179 | Train Loss: 0.40886 | Valid Loss: 0.57859 |Train Accs: 0.86130 | Valid Accs: 0.81775 | Time: 70.10 seconds
# Epoch: 180 | Train Loss: 0.41792 | Valid Loss: 0.68766 |Train Accs: 0.86610 | Valid Accs: 0.78006 | Time: 69.99 seconds
# Epoch: 181 | Train Loss: 0.41068 | Valid Loss: 0.55514 |Train Accs: 0.86053 | Valid Accs: 0.81918 | Time: 70.37 seconds
# Epoch: 182 | Train Loss: 0.41310 | Valid Loss: 0.51186 |Train Accs: 0.86353 | Valid Accs: 0.84256 | Time: 71.08 seconds
# Epoch: 183 | Train Loss: 0.41963 | Valid Loss: 0.50233 |Train Accs: 0.86284 | Valid Accs: 0.83683 | Time: 70.77 seconds
# Epoch: 184 | Train Loss: 0.41187 | Valid Loss: 0.56769 |Train Accs: 0.86096 | Valid Accs: 0.81536 | Time: 70.64 seconds
# Epoch: 185 | Train Loss: 0.40544 | Valid Loss: 0.52146 |Train Accs: 0.86312 | Valid Accs: 0.83492 | Time: 70.36 seconds
# Epoch: 186 | Train Loss: 0.42312 | Valid Loss: 0.52946 |Train Accs: 0.86089 | Valid Accs: 0.83922 | Time: 70.35 seconds
# Epoch: 187 | Train Loss: 0.40522 | Valid Loss: 0.52412 |Train Accs: 0.86809 | Valid Accs: 0.83063 | Time: 70.88 seconds
# Epoch: 188 | Train Loss: 0.40445 | Valid Loss: 0.60557 |Train Accs: 0.86778 | Valid Accs: 0.80916 | Time: 70.96 seconds
# Epoch: 189 | Train Loss: 0.39431 | Valid Loss: 0.52168 |Train Accs: 0.86895 | Valid Accs: 0.83874 | Time: 71.08 seconds
# Epoch: 190 | Train Loss: 0.40234 | Valid Loss: 0.51744 |Train Accs: 0.86238 | Valid Accs: 0.82586 | Time: 70.85 seconds
# Epoch: 191 | Train Loss: 0.38707 | Valid Loss: 0.50409 |Train Accs: 0.87042 | Valid Accs: 0.84065 | Time: 70.85 seconds
# Epoch: 192 | Train Loss: 0.40493 | Valid Loss: 0.55930 |Train Accs: 0.86802 | Valid Accs: 0.81966 | Time: 70.76 seconds
# Epoch: 193 | Train Loss: 0.40980 | Valid Loss: 0.53445 |Train Accs: 0.86670 | Valid Accs: 0.83969 | Time: 70.96 seconds
# Epoch: 194 | Train Loss: 0.38467 | Valid Loss: 0.50667 |Train Accs: 0.87476 | Valid Accs: 0.83635 | Time: 70.94 seconds
# Epoch: 195 | Train Loss: 0.39361 | Valid Loss: 0.54174 |Train Accs: 0.87222 | Valid Accs: 0.83302 | Time: 70.75 seconds
# Epoch: 196 | Train Loss: 0.39599 | Valid Loss: 0.49310 |Train Accs: 0.86526 | Valid Accs: 0.83969 | Time: 71.58 seconds
# Epoch: 197 | Train Loss: 0.38586 | Valid Loss: 0.50230 |Train Accs: 0.87440 | Valid Accs: 0.83779 | Time: 70.92 seconds
# Epoch: 198 | Train Loss: 0.39699 | Valid Loss: 0.54188 |Train Accs: 0.86835 | Valid Accs: 0.82729 | Time: 71.06 seconds
# Epoch: 199 | Train Loss: 0.39131 | Valid Loss: 0.47885 |Train Accs: 0.87375 | Valid Accs: 0.84113 | Time: 71.11 seconds
# Epoch: 200 | Train Loss: 0.38304 | Valid Loss: 0.60207 |Train Accs: 0.87774 | Valid Accs: 0.80057 | Time: 71.17 seconds
# Epoch: 201 | Train Loss: 0.39494 | Valid Loss: 0.53676 |Train Accs: 0.87030 | Valid Accs: 0.82634 | Time: 71.11 seconds
# Epoch: 202 | Train Loss: 0.38419 | Valid Loss: 0.55696 |Train Accs: 0.86934 | Valid Accs: 0.82109 | Time: 70.94 seconds
# Epoch: 203 | Train Loss: 0.38610 | Valid Loss: 0.52140 |Train Accs: 0.87620 | Valid Accs: 0.83540 | Time: 70.98 seconds
# Epoch: 204 | Train Loss: 0.39605 | Valid Loss: 0.51852 |Train Accs: 0.87018 | Valid Accs: 0.83540 | Time: 70.83 seconds
# Epoch: 205 | Train Loss: 0.39473 | Valid Loss: 0.50315 |Train Accs: 0.86706 | Valid Accs: 0.84351 | Time: 70.63 seconds
# Epoch: 206 | Train Loss: 0.38281 | Valid Loss: 0.50643 |Train Accs: 0.87330 | Valid Accs: 0.83969 | Time: 71.39 seconds
# Epoch: 207 | Train Loss: 0.38449 | Valid Loss: 0.59522 |Train Accs: 0.87512 | Valid Accs: 0.80200 | Time: 70.69 seconds
# Epoch: 208 | Train Loss: 0.37629 | Valid Loss: 0.50944 |Train Accs: 0.87488 | Valid Accs: 0.83588 | Time: 70.48 seconds
# Epoch: 209 | Train Loss: 0.37083 | Valid Loss: 0.49734 |Train Accs: 0.87819 | Valid Accs: 0.84637 | Time: 71.15 seconds
# Epoch: 210 | Train Loss: 0.38295 | Valid Loss: 0.50029 |Train Accs: 0.87630 | Valid Accs: 0.84208 | Time: 70.78 seconds
# Epoch: 211 | Train Loss: 0.37247 | Valid Loss: 0.59591 |Train Accs: 0.87560 | Valid Accs: 0.80725 | Time: 70.68 seconds
# Epoch: 212 | Train Loss: 0.37268 | Valid Loss: 0.49991 |Train Accs: 0.87889 | Valid Accs: 0.83731 | Time: 70.98 seconds
# Epoch: 213 | Train Loss: 0.37911 | Valid Loss: 0.51980 |Train Accs: 0.87702 | Valid Accs: 0.83158 | Time: 70.70 seconds
# Epoch: 214 | Train Loss: 0.37760 | Valid Loss: 0.50678 |Train Accs: 0.87884 | Valid Accs: 0.83635 | Time: 70.67 seconds
# Epoch: 215 | Train Loss: 0.37484 | Valid Loss: 0.54067 |Train Accs: 0.87399 | Valid Accs: 0.83302 | Time: 70.52 seconds
# Epoch: 216 | Train Loss: 0.37028 | Valid Loss: 0.52362 |Train Accs: 0.88121 | Valid Accs: 0.82586 | Time: 70.70 seconds
# Epoch: 217 | Train Loss: 0.37729 | Valid Loss: 0.50568 |Train Accs: 0.87699 | Valid Accs: 0.83540 | Time: 70.84 seconds
# Epoch: 218 | Train Loss: 0.37769 | Valid Loss: 0.48642 |Train Accs: 0.87366 | Valid Accs: 0.84256 | Time: 71.26 seconds
# Epoch: 219 | Train Loss: 0.36259 | Valid Loss: 0.59220 |Train Accs: 0.88263 | Valid Accs: 0.81345 | Time: 71.08 seconds
# Epoch: 220 | Train Loss: 0.37975 | Valid Loss: 0.48813 |Train Accs: 0.87522 | Valid Accs: 0.83969 | Time: 70.79 seconds
# Epoch: 221 | Train Loss: 0.36428 | Valid Loss: 0.49807 |Train Accs: 0.88172 | Valid Accs: 0.84065 | Time: 70.86 seconds
# Epoch: 222 | Train Loss: 0.36613 | Valid Loss: 0.51680 |Train Accs: 0.88071 | Valid Accs: 0.83158 | Time: 70.48 seconds
# Epoch: 223 | Train Loss: 0.37260 | Valid Loss: 0.50675 |Train Accs: 0.88217 | Valid Accs: 0.84208 | Time: 70.94 seconds
# Epoch: 224 | Train Loss: 0.36319 | Valid Loss: 0.52098 |Train Accs: 0.88052 | Valid Accs: 0.83254 | Time: 70.75 seconds
# Epoch: 225 | Train Loss: 0.37210 | Valid Loss: 0.49227 |Train Accs: 0.87615 | Valid Accs: 0.83492 | Time: 70.95 seconds
# Epoch: 226 | Train Loss: 0.37159 | Valid Loss: 0.50081 |Train Accs: 0.87483 | Valid Accs: 0.83779 | Time: 70.78 seconds
# Epoch: 227 | Train Loss: 0.35960 | Valid Loss: 0.48603 |Train Accs: 0.88157 | Valid Accs: 0.83588 | Time: 70.62 seconds
# Epoch: 228 | Train Loss: 0.36838 | Valid Loss: 0.50741 |Train Accs: 0.88021 | Valid Accs: 0.83826 | Time: 70.61 seconds
# Epoch: 229 | Train Loss: 0.36416 | Valid Loss: 0.48584 |Train Accs: 0.88021 | Valid Accs: 0.84256 | Time: 71.52 seconds
# Epoch: 230 | Train Loss: 0.36089 | Valid Loss: 0.49754 |Train Accs: 0.88601 | Valid Accs: 0.83922 | Time: 71.37 seconds
# Epoch: 231 | Train Loss: 0.35492 | Valid Loss: 0.54005 |Train Accs: 0.88431 | Valid Accs: 0.82634 | Time: 71.03 seconds
# Epoch: 232 | Train Loss: 0.36369 | Valid Loss: 0.56284 |Train Accs: 0.88292 | Valid Accs: 0.82395 | Time: 70.97 seconds
# Epoch: 233 | Train Loss: 0.36122 | Valid Loss: 0.51697 |Train Accs: 0.88349 | Valid Accs: 0.83302 | Time: 70.84 seconds
# Epoch: 234 | Train Loss: 0.35393 | Valid Loss: 0.51466 |Train Accs: 0.88784 | Valid Accs: 0.83254 | Time: 71.18 seconds
# Epoch: 235 | Train Loss: 0.35478 | Valid Loss: 0.53453 |Train Accs: 0.88683 | Valid Accs: 0.82395 | Time: 71.18 seconds
# Epoch: 236 | Train Loss: 0.35504 | Valid Loss: 0.57494 |Train Accs: 0.88472 | Valid Accs: 0.81918 | Time: 70.98 seconds
# Epoch: 237 | Train Loss: 0.35558 | Valid Loss: 0.46407 |Train Accs: 0.88551 | Valid Accs: 0.84733 | Time: 71.35 seconds
# Epoch: 238 | Train Loss: 0.35885 | Valid Loss: 0.52619 |Train Accs: 0.88443 | Valid Accs: 0.83397 | Time: 70.75 seconds
# Epoch: 239 | Train Loss: 0.35871 | Valid Loss: 0.53501 |Train Accs: 0.88472 | Valid Accs: 0.82061 | Time: 71.16 seconds
# Epoch: 240 | Train Loss: 0.35535 | Valid Loss: 0.46736 |Train Accs: 0.88325 | Valid Accs: 0.84971 | Time: 70.79 seconds
# Epoch: 241 | Train Loss: 0.36209 | Valid Loss: 0.51764 |Train Accs: 0.88469 | Valid Accs: 0.83635 | Time: 70.84 seconds
# Epoch: 242 | Train Loss: 0.36343 | Valid Loss: 0.53229 |Train Accs: 0.87977 | Valid Accs: 0.82538 | Time: 70.54 seconds
# Epoch: 243 | Train Loss: 0.35273 | Valid Loss: 0.52660 |Train Accs: 0.88277 | Valid Accs: 0.83540 | Time: 70.83 seconds
# Epoch: 244 | Train Loss: 0.34729 | Valid Loss: 0.47247 |Train Accs: 0.88839 | Valid Accs: 0.84447 | Time: 70.64 seconds
# Epoch: 245 | Train Loss: 0.35458 | Valid Loss: 0.49291 |Train Accs: 0.88644 | Valid Accs: 0.84017 | Time: 71.08 seconds
# Epoch: 246 | Train Loss: 0.35440 | Valid Loss: 0.51388 |Train Accs: 0.88551 | Valid Accs: 0.83445 | Time: 70.77 seconds
# Epoch: 247 | Train Loss: 0.34535 | Valid Loss: 0.48431 |Train Accs: 0.89064 | Valid Accs: 0.84590 | Time: 70.71 seconds
# Epoch: 248 | Train Loss: 0.35706 | Valid Loss: 0.53098 |Train Accs: 0.88779 | Valid Accs: 0.83111 | Time: 70.86 seconds
# Epoch: 249 | Train Loss: 0.35091 | Valid Loss: 0.49757 |Train Accs: 0.88505 | Valid Accs: 0.83683 | Time: 71.02 seconds
# Epoch: 250 | Train Loss: 0.34407 | Valid Loss: 0.55100 |Train Accs: 0.88700 | Valid Accs: 0.82490 | Time: 71.06 seconds
# Epoch: 251 | Train Loss: 0.35985 | Valid Loss: 0.47547 |Train Accs: 0.88165 | Valid Accs: 0.84971 | Time: 70.89 seconds
# Epoch: 252 | Train Loss: 0.34208 | Valid Loss: 0.46393 |Train Accs: 0.89247 | Valid Accs: 0.85067 | Time: 71.29 seconds
# Epoch: 253 | Train Loss: 0.34689 | Valid Loss: 0.49322 |Train Accs: 0.89043 | Valid Accs: 0.84208 | Time: 70.76 seconds
# Epoch: 254 | Train Loss: 0.35258 | Valid Loss: 0.51925 |Train Accs: 0.88361 | Valid Accs: 0.83206 | Time: 70.73 seconds
# Epoch: 255 | Train Loss: 0.34715 | Valid Loss: 0.47213 |Train Accs: 0.89019 | Valid Accs: 0.84685 | Time: 70.89 seconds
# Epoch: 256 | Train Loss: 0.35047 | Valid Loss: 0.51409 |Train Accs: 0.88877 | Valid Accs: 0.83445 | Time: 71.38 seconds
# Epoch: 257 | Train Loss: 0.33911 | Valid Loss: 0.49977 |Train Accs: 0.89393 | Valid Accs: 0.83731 | Time: 71.05 seconds
# Epoch: 258 | Train Loss: 0.34355 | Valid Loss: 0.45912 |Train Accs: 0.88827 | Valid Accs: 0.84971 | Time: 71.33 seconds
# Epoch: 259 | Train Loss: 0.34750 | Valid Loss: 0.49876 |Train Accs: 0.88817 | Valid Accs: 0.84256 | Time: 70.87 seconds
# Epoch: 260 | Train Loss: 0.34389 | Valid Loss: 0.46776 |Train Accs: 0.89095 | Valid Accs: 0.85067 | Time: 70.93 seconds
# Epoch: 261 | Train Loss: 0.34069 | Valid Loss: 0.46431 |Train Accs: 0.89273 | Valid Accs: 0.85067 | Time: 71.35 seconds
# Epoch: 262 | Train Loss: 0.34510 | Valid Loss: 0.49726 |Train Accs: 0.88853 | Valid Accs: 0.83969 | Time: 71.07 seconds
# Epoch: 263 | Train Loss: 0.33388 | Valid Loss: 0.48400 |Train Accs: 0.89839 | Valid Accs: 0.84781 | Time: 71.60 seconds
# Epoch: 264 | Train Loss: 0.34984 | Valid Loss: 0.48210 |Train Accs: 0.88668 | Valid Accs: 0.84351 | Time: 71.18 seconds
# Epoch: 265 | Train Loss: 0.34058 | Valid Loss: 0.49760 |Train Accs: 0.88808 | Valid Accs: 0.83635 | Time: 71.15 seconds
# Epoch: 266 | Train Loss: 0.34463 | Valid Loss: 0.47426 |Train Accs: 0.88944 | Valid Accs: 0.84542 | Time: 71.09 seconds
# Epoch: 267 | Train Loss: 0.34165 | Valid Loss: 0.48797 |Train Accs: 0.89122 | Valid Accs: 0.84351 | Time: 71.01 seconds
# Epoch: 268 | Train Loss: 0.33530 | Valid Loss: 0.50063 |Train Accs: 0.89175 | Valid Accs: 0.83397 | Time: 71.18 seconds
# Epoch: 269 | Train Loss: 0.33245 | Valid Loss: 0.49011 |Train Accs: 0.89429 | Valid Accs: 0.83922 | Time: 71.14 seconds
# Epoch: 270 | Train Loss: 0.32264 | Valid Loss: 0.51498 |Train Accs: 0.89559 | Valid Accs: 0.83445 | Time: 70.80 seconds
# Epoch: 271 | Train Loss: 0.33801 | Valid Loss: 0.48218 |Train Accs: 0.89323 | Valid Accs: 0.84590 | Time: 70.84 seconds
# Epoch: 272 | Train Loss: 0.32837 | Valid Loss: 0.46631 |Train Accs: 0.89738 | Valid Accs: 0.84781 | Time: 70.69 seconds
# Epoch: 273 | Train Loss: 0.33850 | Valid Loss: 0.47535 |Train Accs: 0.88961 | Valid Accs: 0.84447 | Time: 71.05 seconds
# Epoch: 274 | Train Loss: 0.34551 | Valid Loss: 0.48287 |Train Accs: 0.88695 | Valid Accs: 0.84542 | Time: 71.35 seconds
# Epoch: 275 | Train Loss: 0.33119 | Valid Loss: 0.49269 |Train Accs: 0.89225 | Valid Accs: 0.84160 | Time: 70.94 seconds
# Epoch: 276 | Train Loss: 0.32545 | Valid Loss: 0.56055 |Train Accs: 0.89882 | Valid Accs: 0.81298 | Time: 71.30 seconds
# Epoch: 277 | Train Loss: 0.31400 | Valid Loss: 0.47696 |Train Accs: 0.90221 | Valid Accs: 0.84781 | Time: 71.09 seconds
# Epoch: 278 | Train Loss: 0.33454 | Valid Loss: 0.45841 |Train Accs: 0.89621 | Valid Accs: 0.85735 | Time: 71.35 seconds
# Epoch: 279 | Train Loss: 0.33541 | Valid Loss: 0.48113 |Train Accs: 0.88947 | Valid Accs: 0.84590 | Time: 70.91 seconds
# Epoch: 280 | Train Loss: 0.32673 | Valid Loss: 0.50727 |Train Accs: 0.89702 | Valid Accs: 0.83445 | Time: 71.17 seconds
# Epoch: 281 | Train Loss: 0.33457 | Valid Loss: 0.48071 |Train Accs: 0.89146 | Valid Accs: 0.84542 | Time: 70.67 seconds
# Epoch: 282 | Train Loss: 0.32528 | Valid Loss: 0.47443 |Train Accs: 0.89986 | Valid Accs: 0.84781 | Time: 71.21 seconds
# Epoch: 283 | Train Loss: 0.33094 | Valid Loss: 0.47210 |Train Accs: 0.89705 | Valid Accs: 0.84637 | Time: 70.60 seconds
# Epoch: 284 | Train Loss: 0.32540 | Valid Loss: 0.47642 |Train Accs: 0.89523 | Valid Accs: 0.84781 | Time: 70.58 seconds
# Epoch: 285 | Train Loss: 0.32442 | Valid Loss: 0.47551 |Train Accs: 0.89748 | Valid Accs: 0.84733 | Time: 70.75 seconds
# Epoch: 286 | Train Loss: 0.33976 | Valid Loss: 0.45776 |Train Accs: 0.88925 | Valid Accs: 0.85592 | Time: 70.93 seconds
# Epoch: 287 | Train Loss: 0.33094 | Valid Loss: 0.49708 |Train Accs: 0.89681 | Valid Accs: 0.83779 | Time: 70.91 seconds
# Epoch: 288 | Train Loss: 0.31766 | Valid Loss: 0.46700 |Train Accs: 0.90055 | Valid Accs: 0.84542 | Time: 70.28 seconds
# Epoch: 289 | Train Loss: 0.32052 | Valid Loss: 0.47219 |Train Accs: 0.90031 | Valid Accs: 0.84685 | Time: 70.21 seconds
# Epoch: 290 | Train Loss: 0.31576 | Valid Loss: 0.49015 |Train Accs: 0.90086 | Valid Accs: 0.84733 | Time: 70.27 seconds
# Epoch: 291 | Train Loss: 0.32381 | Valid Loss: 0.48493 |Train Accs: 0.89451 | Valid Accs: 0.84160 | Time: 70.18 seconds
# Epoch: 292 | Train Loss: 0.32846 | Valid Loss: 0.46844 |Train Accs: 0.89583 | Valid Accs: 0.85115 | Time: 70.16 seconds
# Epoch: 293 | Train Loss: 0.31694 | Valid Loss: 0.45961 |Train Accs: 0.90281 | Valid Accs: 0.85735 | Time: 70.11 seconds
# Epoch: 294 | Train Loss: 0.32207 | Valid Loss: 0.46859 |Train Accs: 0.89712 | Valid Accs: 0.84542 | Time: 70.20 seconds
# Epoch: 295 | Train Loss: 0.31333 | Valid Loss: 0.47395 |Train Accs: 0.90077 | Valid Accs: 0.84303 | Time: 70.42 seconds
# Epoch: 296 | Train Loss: 0.32420 | Valid Loss: 0.49691 |Train Accs: 0.89849 | Valid Accs: 0.84685 | Time: 70.35 seconds
# Epoch: 297 | Train Loss: 0.30861 | Valid Loss: 0.45326 |Train Accs: 0.90605 | Valid Accs: 0.85115 | Time: 70.66 seconds
# Epoch: 298 | Train Loss: 0.32319 | Valid Loss: 0.46443 |Train Accs: 0.90031 | Valid Accs: 0.84685 | Time: 70.23 seconds
# Epoch: 299 | Train Loss: 0.32498 | Valid Loss: 0.49645 |Train Accs: 0.89868 | Valid Accs: 0.84351 | Time: 70.27 seconds
# Epoch: 300 | Train Loss: 0.31726 | Valid Loss: 0.46104 |Train Accs: 0.90139 | Valid Accs: 0.85115 | Time: 70.19 seconds
# Epoch: 301 | Train Loss: 0.31935 | Valid Loss: 0.48433 |Train Accs: 0.89928 | Valid Accs: 0.84351 | Time: 70.28 seconds
# Epoch: 302 | Train Loss: 0.32139 | Valid Loss: 0.45626 |Train Accs: 0.89954 | Valid Accs: 0.85067 | Time: 70.27 seconds
# Epoch: 303 | Train Loss: 0.31872 | Valid Loss: 0.49585 |Train Accs: 0.90185 | Valid Accs: 0.83731 | Time: 70.34 seconds
# Epoch: 304 | Train Loss: 0.31230 | Valid Loss: 0.47064 |Train Accs: 0.90146 | Valid Accs: 0.84828 | Time: 70.42 seconds
# Epoch: 305 | Train Loss: 0.31167 | Valid Loss: 0.47610 |Train Accs: 0.90271 | Valid Accs: 0.84637 | Time: 70.46 seconds
# Epoch: 306 | Train Loss: 0.31577 | Valid Loss: 0.46681 |Train Accs: 0.90125 | Valid Accs: 0.85162 | Time: 70.58 seconds
# Epoch: 307 | Train Loss: 0.32209 | Valid Loss: 0.46947 |Train Accs: 0.89465 | Valid Accs: 0.84828 | Time: 70.21 seconds
# Epoch: 308 | Train Loss: 0.30530 | Valid Loss: 0.46650 |Train Accs: 0.90487 | Valid Accs: 0.85162 | Time: 70.43 seconds
# Epoch: 309 | Train Loss: 0.31203 | Valid Loss: 0.45149 |Train Accs: 0.90204 | Valid Accs: 0.84876 | Time: 70.62 seconds
# Epoch: 310 | Train Loss: 0.31196 | Valid Loss: 0.48163 |Train Accs: 0.90050 | Valid Accs: 0.84017 | Time: 70.26 seconds
# Epoch: 311 | Train Loss: 0.30749 | Valid Loss: 0.45162 |Train Accs: 0.90439 | Valid Accs: 0.85735 | Time: 70.61 seconds
# Epoch: 312 | Train Loss: 0.30073 | Valid Loss: 0.46470 |Train Accs: 0.90964 | Valid Accs: 0.84351 | Time: 70.47 seconds
# Epoch: 313 | Train Loss: 0.31450 | Valid Loss: 0.47639 |Train Accs: 0.90113 | Valid Accs: 0.85019 | Time: 70.07 seconds
# Epoch: 314 | Train Loss: 0.29477 | Valid Loss: 0.44926 |Train Accs: 0.90919 | Valid Accs: 0.84971 | Time: 70.73 seconds
# Epoch: 315 | Train Loss: 0.31069 | Valid Loss: 0.48372 |Train Accs: 0.89993 | Valid Accs: 0.84590 | Time: 70.37 seconds
# Epoch: 316 | Train Loss: 0.30999 | Valid Loss: 0.46070 |Train Accs: 0.90149 | Valid Accs: 0.85258 | Time: 70.74 seconds
# Epoch: 317 | Train Loss: 0.31386 | Valid Loss: 0.45379 |Train Accs: 0.90230 | Valid Accs: 0.85401 | Time: 70.29 seconds
# Epoch: 318 | Train Loss: 0.30440 | Valid Loss: 0.47979 |Train Accs: 0.90415 | Valid Accs: 0.84971 | Time: 70.37 seconds
# Epoch: 319 | Train Loss: 0.30784 | Valid Loss: 0.49100 |Train Accs: 0.90746 | Valid Accs: 0.84256 | Time: 70.23 seconds
# Epoch: 320 | Train Loss: 0.31094 | Valid Loss: 0.45803 |Train Accs: 0.90413 | Valid Accs: 0.85401 | Time: 70.20 seconds
# Epoch: 321 | Train Loss: 0.30865 | Valid Loss: 0.45375 |Train Accs: 0.90446 | Valid Accs: 0.85401 | Time: 70.22 seconds
# Epoch: 322 | Train Loss: 0.30115 | Valid Loss: 0.46134 |Train Accs: 0.90701 | Valid Accs: 0.85353 | Time: 70.75 seconds
# Epoch: 323 | Train Loss: 0.30960 | Valid Loss: 0.46928 |Train Accs: 0.90605 | Valid Accs: 0.84733 | Time: 70.38 seconds
# Epoch: 324 | Train Loss: 0.30672 | Valid Loss: 0.45990 |Train Accs: 0.90513 | Valid Accs: 0.84590 | Time: 70.25 seconds
# Epoch: 325 | Train Loss: 0.29997 | Valid Loss: 0.45345 |Train Accs: 0.90497 | Valid Accs: 0.85115 | Time: 70.67 seconds
# Epoch: 326 | Train Loss: 0.30266 | Valid Loss: 0.46543 |Train Accs: 0.90893 | Valid Accs: 0.85115 | Time: 70.42 seconds
# Epoch: 327 | Train Loss: 0.30349 | Valid Loss: 0.45942 |Train Accs: 0.90593 | Valid Accs: 0.84876 | Time: 70.26 seconds
# Epoch: 328 | Train Loss: 0.29051 | Valid Loss: 0.48118 |Train Accs: 0.91048 | Valid Accs: 0.84590 | Time: 70.37 seconds
# Epoch: 329 | Train Loss: 0.30481 | Valid Loss: 0.47993 |Train Accs: 0.90749 | Valid Accs: 0.84447 | Time: 70.32 seconds
# Epoch: 330 | Train Loss: 0.29760 | Valid Loss: 0.44603 |Train Accs: 0.90691 | Valid Accs: 0.85353 | Time: 70.60 seconds
# Epoch: 331 | Train Loss: 0.30058 | Valid Loss: 0.47200 |Train Accs: 0.90914 | Valid Accs: 0.84256 | Time: 70.37 seconds
# Epoch: 332 | Train Loss: 0.29908 | Valid Loss: 0.46157 |Train Accs: 0.90883 | Valid Accs: 0.85258 | Time: 70.29 seconds
# Epoch: 333 | Train Loss: 0.30994 | Valid Loss: 0.44646 |Train Accs: 0.90636 | Valid Accs: 0.85592 | Time: 70.47 seconds
# Epoch: 334 | Train Loss: 0.30465 | Valid Loss: 0.46608 |Train Accs: 0.90458 | Valid Accs: 0.84494 | Time: 70.17 seconds
# Epoch: 335 | Train Loss: 0.30639 | Valid Loss: 0.45939 |Train Accs: 0.90427 | Valid Accs: 0.84733 | Time: 70.51 seconds
# Epoch: 336 | Train Loss: 0.30759 | Valid Loss: 0.47992 |Train Accs: 0.90938 | Valid Accs: 0.84113 | Time: 70.31 seconds
# Epoch: 337 | Train Loss: 0.28842 | Valid Loss: 0.45824 |Train Accs: 0.91363 | Valid Accs: 0.84351 | Time: 70.20 seconds
# Epoch: 338 | Train Loss: 0.29532 | Valid Loss: 0.47127 |Train Accs: 0.91048 | Valid Accs: 0.84828 | Time: 70.62 seconds
# Epoch: 339 | Train Loss: 0.29956 | Valid Loss: 0.46554 |Train Accs: 0.91144 | Valid Accs: 0.85067 | Time: 70.61 seconds
# Epoch: 340 | Train Loss: 0.29720 | Valid Loss: 0.45135 |Train Accs: 0.90797 | Valid Accs: 0.85353 | Time: 70.36 seconds
# Epoch: 341 | Train Loss: 0.30040 | Valid Loss: 0.46681 |Train Accs: 0.90917 | Valid Accs: 0.85305 | Time: 70.29 seconds
# Epoch: 342 | Train Loss: 0.29821 | Valid Loss: 0.45370 |Train Accs: 0.91120 | Valid Accs: 0.85639 | Time: 70.52 seconds
# Epoch: 343 | Train Loss: 0.29100 | Valid Loss: 0.45338 |Train Accs: 0.91324 | Valid Accs: 0.85496 | Time: 70.48 seconds
# Epoch: 344 | Train Loss: 0.29968 | Valid Loss: 0.44570 |Train Accs: 0.90905 | Valid Accs: 0.85544 | Time: 70.99 seconds
# Epoch: 345 | Train Loss: 0.29891 | Valid Loss: 0.44591 |Train Accs: 0.90463 | Valid Accs: 0.85353 | Time: 70.64 seconds
# Epoch: 346 | Train Loss: 0.29553 | Valid Loss: 0.45649 |Train Accs: 0.91356 | Valid Accs: 0.85258 | Time: 70.23 seconds
# Epoch: 347 | Train Loss: 0.29193 | Valid Loss: 0.46628 |Train Accs: 0.91488 | Valid Accs: 0.85448 | Time: 70.36 seconds
# Epoch: 348 | Train Loss: 0.28570 | Valid Loss: 0.44725 |Train Accs: 0.91528 | Valid Accs: 0.85401 | Time: 70.52 seconds
# Epoch: 349 | Train Loss: 0.28597 | Valid Loss: 0.44717 |Train Accs: 0.91639 | Valid Accs: 0.85639 | Time: 70.32 seconds
# Epoch: 350 | Train Loss: 0.30064 | Valid Loss: 0.47613 |Train Accs: 0.90950 | Valid Accs: 0.84256 | Time: 70.50 seconds
# Epoch: 351 | Train Loss: 0.29458 | Valid Loss: 0.46886 |Train Accs: 0.91207 | Valid Accs: 0.85067 | Time: 70.41 seconds
# Epoch: 352 | Train Loss: 0.28641 | Valid Loss: 0.46299 |Train Accs: 0.91783 | Valid Accs: 0.84494 | Time: 71.41 seconds
# Epoch: 353 | Train Loss: 0.30018 | Valid Loss: 0.45521 |Train Accs: 0.90854 | Valid Accs: 0.84590 | Time: 70.59 seconds
# Epoch: 354 | Train Loss: 0.29759 | Valid Loss: 0.44362 |Train Accs: 0.91183 | Valid Accs: 0.85162 | Time: 71.12 seconds
# Epoch: 355 | Train Loss: 0.29252 | Valid Loss: 0.44939 |Train Accs: 0.91171 | Valid Accs: 0.85258 | Time: 70.37 seconds
# Epoch: 356 | Train Loss: 0.28911 | Valid Loss: 0.45914 |Train Accs: 0.91603 | Valid Accs: 0.84971 | Time: 70.41 seconds
# Epoch: 357 | Train Loss: 0.28696 | Valid Loss: 0.46143 |Train Accs: 0.91444 | Valid Accs: 0.84924 | Time: 70.42 seconds
# Epoch: 358 | Train Loss: 0.28674 | Valid Loss: 0.46709 |Train Accs: 0.91670 | Valid Accs: 0.84590 | Time: 70.35 seconds
# Epoch: 359 | Train Loss: 0.28665 | Valid Loss: 0.45692 |Train Accs: 0.91543 | Valid Accs: 0.85448 | Time: 70.43 seconds
# Epoch: 360 | Train Loss: 0.29028 | Valid Loss: 0.45982 |Train Accs: 0.91310 | Valid Accs: 0.84924 | Time: 70.48 seconds
# Epoch: 361 | Train Loss: 0.28353 | Valid Loss: 0.45453 |Train Accs: 0.91473 | Valid Accs: 0.85544 | Time: 70.36 seconds
# Epoch: 362 | Train Loss: 0.28830 | Valid Loss: 0.45295 |Train Accs: 0.91276 | Valid Accs: 0.85496 | Time: 70.59 seconds
# Epoch: 363 | Train Loss: 0.28137 | Valid Loss: 0.44283 |Train Accs: 0.91912 | Valid Accs: 0.85830 | Time: 70.66 seconds
# Epoch: 364 | Train Loss: 0.28958 | Valid Loss: 0.44176 |Train Accs: 0.91308 | Valid Accs: 0.85592 | Time: 70.89 seconds
# Epoch: 365 | Train Loss: 0.28278 | Valid Loss: 0.44164 |Train Accs: 0.91835 | Valid Accs: 0.85735 | Time: 70.77 seconds
# Epoch: 366 | Train Loss: 0.29183 | Valid Loss: 0.44805 |Train Accs: 0.91612 | Valid Accs: 0.86450 | Time: 70.21 seconds
# Epoch: 367 | Train Loss: 0.27782 | Valid Loss: 0.46012 |Train Accs: 0.91900 | Valid Accs: 0.85258 | Time: 70.39 seconds
# Epoch: 368 | Train Loss: 0.28308 | Valid Loss: 0.44865 |Train Accs: 0.91691 | Valid Accs: 0.85305 | Time: 70.38 seconds
# Epoch: 369 | Train Loss: 0.28192 | Valid Loss: 0.45633 |Train Accs: 0.91816 | Valid Accs: 0.85258 | Time: 70.52 seconds
# Epoch: 370 | Train Loss: 0.28788 | Valid Loss: 0.43873 |Train Accs: 0.91456 | Valid Accs: 0.85878 | Time: 70.61 seconds
# Epoch: 371 | Train Loss: 0.28826 | Valid Loss: 0.45342 |Train Accs: 0.91240 | Valid Accs: 0.85735 | Time: 70.21 seconds
# Epoch: 372 | Train Loss: 0.28278 | Valid Loss: 0.44089 |Train Accs: 0.91687 | Valid Accs: 0.85592 | Time: 70.16 seconds
# Epoch: 373 | Train Loss: 0.28180 | Valid Loss: 0.44743 |Train Accs: 0.91586 | Valid Accs: 0.85353 | Time: 70.37 seconds
# Epoch: 374 | Train Loss: 0.28234 | Valid Loss: 0.44136 |Train Accs: 0.91828 | Valid Accs: 0.85592 | Time: 70.33 seconds
# Epoch: 375 | Train Loss: 0.28337 | Valid Loss: 0.45026 |Train Accs: 0.91670 | Valid Accs: 0.85210 | Time: 70.40 seconds
# Epoch: 376 | Train Loss: 0.29183 | Valid Loss: 0.45614 |Train Accs: 0.91420 | Valid Accs: 0.85019 | Time: 70.17 seconds
# Epoch: 377 | Train Loss: 0.28352 | Valid Loss: 0.45144 |Train Accs: 0.91636 | Valid Accs: 0.85115 | Time: 70.43 seconds
# Epoch: 378 | Train Loss: 0.28726 | Valid Loss: 0.46412 |Train Accs: 0.91694 | Valid Accs: 0.85258 | Time: 70.15 seconds
# Epoch: 379 | Train Loss: 0.28912 | Valid Loss: 0.44247 |Train Accs: 0.91231 | Valid Accs: 0.86116 | Time: 70.61 seconds
# Epoch: 380 | Train Loss: 0.27848 | Valid Loss: 0.44290 |Train Accs: 0.91735 | Valid Accs: 0.85639 | Time: 70.27 seconds
# Epoch: 381 | Train Loss: 0.27966 | Valid Loss: 0.45250 |Train Accs: 0.91720 | Valid Accs: 0.85305 | Time: 70.49 seconds
# Epoch: 382 | Train Loss: 0.27498 | Valid Loss: 0.44070 |Train Accs: 0.92083 | Valid Accs: 0.85258 | Time: 70.51 seconds
# Epoch: 383 | Train Loss: 0.28203 | Valid Loss: 0.45230 |Train Accs: 0.91720 | Valid Accs: 0.84876 | Time: 71.20 seconds
# Epoch: 384 | Train Loss: 0.27903 | Valid Loss: 0.43810 |Train Accs: 0.92051 | Valid Accs: 0.86021 | Time: 71.73 seconds
# Epoch: 385 | Train Loss: 0.28565 | Valid Loss: 0.45944 |Train Accs: 0.91783 | Valid Accs: 0.85496 | Time: 70.99 seconds
# Epoch: 386 | Train Loss: 0.27183 | Valid Loss: 0.45193 |Train Accs: 0.92258 | Valid Accs: 0.85592 | Time: 71.30 seconds
# Epoch: 387 | Train Loss: 0.27292 | Valid Loss: 0.45114 |Train Accs: 0.92332 | Valid Accs: 0.85210 | Time: 71.09 seconds
# Epoch: 388 | Train Loss: 0.27350 | Valid Loss: 0.43489 |Train Accs: 0.92128 | Valid Accs: 0.86116 | Time: 71.46 seconds
# Epoch: 389 | Train Loss: 0.28363 | Valid Loss: 0.45382 |Train Accs: 0.91924 | Valid Accs: 0.85115 | Time: 71.00 seconds
# Epoch: 390 | Train Loss: 0.28085 | Valid Loss: 0.43779 |Train Accs: 0.92080 | Valid Accs: 0.85926 | Time: 71.35 seconds
# Epoch: 391 | Train Loss: 0.27540 | Valid Loss: 0.43979 |Train Accs: 0.92202 | Valid Accs: 0.85544 | Time: 70.88 seconds
# Epoch: 392 | Train Loss: 0.28011 | Valid Loss: 0.43582 |Train Accs: 0.91795 | Valid Accs: 0.85878 | Time: 70.98 seconds
# Epoch: 393 | Train Loss: 0.28499 | Valid Loss: 0.43388 |Train Accs: 0.91492 | Valid Accs: 0.85878 | Time: 70.86 seconds
# Epoch: 394 | Train Loss: 0.27802 | Valid Loss: 0.44707 |Train Accs: 0.91759 | Valid Accs: 0.85639 | Time: 70.41 seconds
# Epoch: 395 | Train Loss: 0.27429 | Valid Loss: 0.43695 |Train Accs: 0.92174 | Valid Accs: 0.86594 | Time: 70.70 seconds
# Epoch: 396 | Train Loss: 0.28045 | Valid Loss: 0.45125 |Train Accs: 0.91591 | Valid Accs: 0.85115 | Time: 70.52 seconds
# Epoch: 397 | Train Loss: 0.27711 | Valid Loss: 0.43488 |Train Accs: 0.91900 | Valid Accs: 0.85639 | Time: 70.88 seconds
# Epoch: 398 | Train Loss: 0.27694 | Valid Loss: 0.43645 |Train Accs: 0.92128 | Valid Accs: 0.85496 | Time: 70.64 seconds
# Epoch: 399 | Train Loss: 0.28286 | Valid Loss: 0.44054 |Train Accs: 0.91672 | Valid Accs: 0.85687 | Time: 70.44 seconds
# Epoch: 400 | Train Loss: 0.27591 | Valid Loss: 0.44321 |Train Accs: 0.92116 | Valid Accs: 0.85735 | Time: 70.72 seconds
# Epoch: 401 | Train Loss: 0.27155 | Valid Loss: 0.43280 |Train Accs: 0.92330 | Valid Accs: 0.86116 | Time: 71.09 seconds
# Epoch: 402 | Train Loss: 0.28544 | Valid Loss: 0.43665 |Train Accs: 0.91699 | Valid Accs: 0.85496 | Time: 70.77 seconds
# Epoch: 403 | Train Loss: 0.26822 | Valid Loss: 0.43820 |Train Accs: 0.92514 | Valid Accs: 0.85926 | Time: 70.54 seconds
# Epoch: 404 | Train Loss: 0.27801 | Valid Loss: 0.44394 |Train Accs: 0.91696 | Valid Accs: 0.85973 | Time: 70.25 seconds
# Epoch: 405 | Train Loss: 0.28229 | Valid Loss: 0.45120 |Train Accs: 0.91819 | Valid Accs: 0.85782 | Time: 70.31 seconds
# Epoch: 406 | Train Loss: 0.27894 | Valid Loss: 0.43986 |Train Accs: 0.91624 | Valid Accs: 0.85926 | Time: 70.26 seconds
# Epoch: 407 | Train Loss: 0.27635 | Valid Loss: 0.44639 |Train Accs: 0.91936 | Valid Accs: 0.85973 | Time: 70.14 seconds
# Epoch: 408 | Train Loss: 0.26825 | Valid Loss: 0.44417 |Train Accs: 0.92543 | Valid Accs: 0.85401 | Time: 70.09 seconds
# Epoch: 409 | Train Loss: 0.27091 | Valid Loss: 0.44581 |Train Accs: 0.92560 | Valid Accs: 0.85973 | Time: 70.20 seconds
# Epoch: 410 | Train Loss: 0.27371 | Valid Loss: 0.43424 |Train Accs: 0.92186 | Valid Accs: 0.86498 | Time: 70.20 seconds
# Epoch: 411 | Train Loss: 0.27734 | Valid Loss: 0.44139 |Train Accs: 0.92020 | Valid Accs: 0.86355 | Time: 70.34 seconds
# Epoch: 412 | Train Loss: 0.27713 | Valid Loss: 0.42455 |Train Accs: 0.91874 | Valid Accs: 0.85592 | Time: 70.76 seconds
# Epoch: 413 | Train Loss: 0.27036 | Valid Loss: 0.43223 |Train Accs: 0.92524 | Valid Accs: 0.85878 | Time: 70.09 seconds
# Epoch: 414 | Train Loss: 0.27168 | Valid Loss: 0.44574 |Train Accs: 0.92522 | Valid Accs: 0.85592 | Time: 70.14 seconds
# Epoch: 415 | Train Loss: 0.27654 | Valid Loss: 0.44195 |Train Accs: 0.92212 | Valid Accs: 0.86069 | Time: 70.09 seconds
# Epoch: 416 | Train Loss: 0.26813 | Valid Loss: 0.43848 |Train Accs: 0.92368 | Valid Accs: 0.86021 | Time: 70.24 seconds
# Epoch: 417 | Train Loss: 0.27644 | Valid Loss: 0.44384 |Train Accs: 0.92308 | Valid Accs: 0.85448 | Time: 70.18 seconds
# Epoch: 418 | Train Loss: 0.26798 | Valid Loss: 0.43658 |Train Accs: 0.92270 | Valid Accs: 0.85592 | Time: 70.60 seconds
# Epoch: 419 | Train Loss: 0.27290 | Valid Loss: 0.45465 |Train Accs: 0.92267 | Valid Accs: 0.85878 | Time: 70.70 seconds
# Epoch: 420 | Train Loss: 0.27205 | Valid Loss: 0.45730 |Train Accs: 0.92224 | Valid Accs: 0.84733 | Time: 70.66 seconds
# Epoch: 421 | Train Loss: 0.26939 | Valid Loss: 0.44351 |Train Accs: 0.92450 | Valid Accs: 0.86021 | Time: 70.77 seconds
# Epoch: 422 | Train Loss: 0.26159 | Valid Loss: 0.43961 |Train Accs: 0.92610 | Valid Accs: 0.85973 | Time: 70.95 seconds
# Epoch: 423 | Train Loss: 0.26879 | Valid Loss: 0.43908 |Train Accs: 0.92090 | Valid Accs: 0.85926 | Time: 70.68 seconds
# Epoch: 424 | Train Loss: 0.27220 | Valid Loss: 0.43469 |Train Accs: 0.92286 | Valid Accs: 0.85973 | Time: 70.58 seconds
# Epoch: 425 | Train Loss: 0.25925 | Valid Loss: 0.43387 |Train Accs: 0.92656 | Valid Accs: 0.86403 | Time: 70.44 seconds
# Epoch: 426 | Train Loss: 0.27148 | Valid Loss: 0.43423 |Train Accs: 0.92392 | Valid Accs: 0.86212 | Time: 70.22 seconds
# Epoch: 427 | Train Loss: 0.26770 | Valid Loss: 0.43109 |Train Accs: 0.92344 | Valid Accs: 0.86069 | Time: 69.65 seconds
# Epoch: 428 | Train Loss: 0.27063 | Valid Loss: 0.44014 |Train Accs: 0.92092 | Valid Accs: 0.85830 | Time: 70.06 seconds
# Epoch: 429 | Train Loss: 0.27407 | Valid Loss: 0.44022 |Train Accs: 0.92608 | Valid Accs: 0.85544 | Time: 70.08 seconds
# Epoch: 430 | Train Loss: 0.27535 | Valid Loss: 0.42916 |Train Accs: 0.92207 | Valid Accs: 0.86164 | Time: 70.13 seconds
# Epoch: 431 | Train Loss: 0.26856 | Valid Loss: 0.43141 |Train Accs: 0.92536 | Valid Accs: 0.86355 | Time: 69.60 seconds
# Epoch: 432 | Train Loss: 0.26146 | Valid Loss: 0.43380 |Train Accs: 0.92572 | Valid Accs: 0.85782 | Time: 69.56 seconds
# Epoch: 433 | Train Loss: 0.26768 | Valid Loss: 0.45147 |Train Accs: 0.92368 | Valid Accs: 0.84876 | Time: 69.52 seconds
# Epoch: 434 | Train Loss: 0.26847 | Valid Loss: 0.43960 |Train Accs: 0.92584 | Valid Accs: 0.85496 | Time: 69.92 seconds
# Epoch: 435 | Train Loss: 0.27453 | Valid Loss: 0.43957 |Train Accs: 0.92200 | Valid Accs: 0.86116 | Time: 69.50 seconds
# Epoch: 436 | Train Loss: 0.27208 | Valid Loss: 0.43035 |Train Accs: 0.92414 | Valid Accs: 0.86069 | Time: 69.37 seconds
# Epoch: 437 | Train Loss: 0.26565 | Valid Loss: 0.43051 |Train Accs: 0.92632 | Valid Accs: 0.86260 | Time: 69.02 seconds
# Epoch: 438 | Train Loss: 0.26620 | Valid Loss: 0.43652 |Train Accs: 0.92594 | Valid Accs: 0.85544 | Time: 69.16 seconds
# Epoch: 439 | Train Loss: 0.27255 | Valid Loss: 0.43289 |Train Accs: 0.92236 | Valid Accs: 0.85878 | Time: 69.35 seconds
# Epoch: 440 | Train Loss: 0.26216 | Valid Loss: 0.44291 |Train Accs: 0.92694 | Valid Accs: 0.86212 | Time: 68.74 seconds
# Epoch: 441 | Train Loss: 0.26427 | Valid Loss: 0.42984 |Train Accs: 0.92680 | Valid Accs: 0.86021 | Time: 68.97 seconds
# Epoch: 442 | Train Loss: 0.27432 | Valid Loss: 0.43355 |Train Accs: 0.92095 | Valid Accs: 0.85687 | Time: 68.91 seconds
# Epoch: 443 | Train Loss: 0.26744 | Valid Loss: 0.43273 |Train Accs: 0.92824 | Valid Accs: 0.85926 | Time: 68.81 seconds
# Epoch: 444 | Train Loss: 0.27279 | Valid Loss: 0.43015 |Train Accs: 0.91943 | Valid Accs: 0.85782 | Time: 68.92 seconds
# Epoch: 445 | Train Loss: 0.27008 | Valid Loss: 0.44000 |Train Accs: 0.92447 | Valid Accs: 0.85496 | Time: 68.98 seconds
# Epoch: 446 | Train Loss: 0.27157 | Valid Loss: 0.44324 |Train Accs: 0.92390 | Valid Accs: 0.86355 | Time: 68.73 seconds
# Epoch: 447 | Train Loss: 0.26566 | Valid Loss: 0.43856 |Train Accs: 0.92570 | Valid Accs: 0.85687 | Time: 68.83 seconds
# Epoch: 448 | Train Loss: 0.26304 | Valid Loss: 0.44152 |Train Accs: 0.92932 | Valid Accs: 0.85592 | Time: 69.04 seconds
# Epoch: 449 | Train Loss: 0.26707 | Valid Loss: 0.43197 |Train Accs: 0.92574 | Valid Accs: 0.85926 | Time: 68.85 seconds
# Epoch: 450 | Train Loss: 0.26990 | Valid Loss: 0.43282 |Train Accs: 0.92646 | Valid Accs: 0.85687 | Time: 68.72 seconds
# Epoch: 451 | Train Loss: 0.26324 | Valid Loss: 0.43210 |Train Accs: 0.92644 | Valid Accs: 0.86116 | Time: 68.68 seconds
# Epoch: 452 | Train Loss: 0.27230 | Valid Loss: 0.43143 |Train Accs: 0.92044 | Valid Accs: 0.86116 | Time: 69.05 seconds
# Epoch: 453 | Train Loss: 0.26363 | Valid Loss: 0.43019 |Train Accs: 0.92483 | Valid Accs: 0.86498 | Time: 68.83 seconds
# Epoch: 454 | Train Loss: 0.27278 | Valid Loss: 0.43080 |Train Accs: 0.92020 | Valid Accs: 0.85878 | Time: 68.89 seconds
# Epoch: 455 | Train Loss: 0.27369 | Valid Loss: 0.43632 |Train Accs: 0.92167 | Valid Accs: 0.86116 | Time: 69.13 seconds
# Epoch: 456 | Train Loss: 0.26633 | Valid Loss: 0.43242 |Train Accs: 0.92666 | Valid Accs: 0.85878 | Time: 69.63 seconds
# Epoch: 457 | Train Loss: 0.26941 | Valid Loss: 0.44113 |Train Accs: 0.92462 | Valid Accs: 0.85401 | Time: 68.68 seconds
# Epoch: 458 | Train Loss: 0.26497 | Valid Loss: 0.43336 |Train Accs: 0.92790 | Valid Accs: 0.85973 | Time: 68.74 seconds
# Epoch: 459 | Train Loss: 0.27198 | Valid Loss: 0.43487 |Train Accs: 0.92526 | Valid Accs: 0.85830 | Time: 68.51 seconds
# Epoch: 460 | Train Loss: 0.26201 | Valid Loss: 0.44006 |Train Accs: 0.92740 | Valid Accs: 0.86212 | Time: 68.69 seconds
# Epoch: 461 | Train Loss: 0.26467 | Valid Loss: 0.43345 |Train Accs: 0.92622 | Valid Accs: 0.86069 | Time: 68.52 seconds
# Epoch: 462 | Train Loss: 0.26712 | Valid Loss: 0.43392 |Train Accs: 0.92488 | Valid Accs: 0.86021 | Time: 68.58 seconds
#
# Early Stopping at Epoch 463
#
# **************************************************
#
# Best Validation Loss at Epoch 412
#
# **************************************************
#
# Best Validation Accs at Epoch 395
#
# **************************************************
#
# Time Taken [463 Epochs] : 543.83 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
