# %% [markdown]
# ### **Library Imports**

# %%
import os
import re
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from torch import nn, optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as DL
from torchvision import models, transforms

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **Utilities and Helpers**

# %%
SEED = 42
SIZE = 224
le = LabelEncoder()


def breaker(num: int=50, char: str="*") -> None:
    print("\n" + num*char + "\n")

    
def show_loss_graphs(A: list) -> None:
    TL, VL = [], []
    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
    x_Axis = np.arange(1, len(TL) + 1)
    plt.figure()
    plt.plot(x_Axis, TL, "r", label="Train")
    plt.plot(x_Axis, VL, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Loss Graph")
    plt.show()

    
def show_accuracy_graphs(A: list) -> None:
    TA, VA = [], []
    for i in range(len(L)):
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])
    x_Axis = np.arange(1, len(TA) + 1)
    plt.figure()
    plt.plot(x_Axis, TA, "r", label="Train")
    plt.plot(x_Axis, VA, "b", label="Valid")
    plt.legend()
    plt.grid()
    plt.title("Accuracy Graph")
    plt.show()


def show_lr_graph(LR: list) -> None:
    x_Axis = [i+1 for i in range(len(LR))]
    plt.figure(figsize=(8, 6))
    plt.plot(x_Axis, LR, "rx")
    plt.grid()
    plt.show()

# %% [markdown]
# ### **Configuration**

# %%
class CFG(object):
    def __init__(self, 
                 seed: int = 42,
                 n_splits: int = 5,
                 batch_size: int = 16,
                 epochs: int = 25,
                 early_stopping: int = 5,
                 lr: float = 1e-4,
                 wd: float = 0.0,
                 max_lr: float = 1e-3,
                 pct_start: float = 0.2,
                 steps_per_epoch: int = 100,
                 div_factor: int = 1e3, 
                 final_div_factor: float = 1e3,
                 ):
        
        self.seed = seed
        self.n_splits = n_splits
        self.batch_size = batch_size
        self.epochs = epochs
        self.early_stopping = early_stopping
        self.lr = lr
        self.wd = wd
        self.max_lr = max_lr
        self.pct_start = pct_start
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.final_div_factor = final_div_factor
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize([0.485, 0.456, 0.406],
                                                     [0.229, 0.224, 0.225]),
                                ])
        self.save_path = "saves"
        if not os.path.exists(self.save_path): os.makedirs(self.save_path)
    
cfg = CFG(seed=SEED)

# %% [markdown]
# ### **Dataset Template**

# %%
class DS(Dataset):
    def __init__(self, images: np.ndarray, labels: np.ndarray = None, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, idx):
        if self.labels is not None:
            return self.transform(self.images[idx]), torch.LongTensor(self.labels[idx])
        else:
            return self.transform(self.images[idx])

# %% [markdown]
# ### **Model**

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        self.model = models.resnet50(pretrained=True, progress=True)
        self.freeze()
        self.model.fc = nn.Linear(in_features=self.model.fc.in_features, out_features=10)
    
    def freeze(self):
        for params in self.parameters(): params.requires_grad = False

    def forward(self, x):
        return nn.LogSoftmax(dim=1)(self.model(x))

# %% [markdown]
# ### **Fit and Predict Helpers**

# %%
def fit(model=None, 
        optimizer=None, 
        scheduler_rlrop=None,
        scheduler_oclr=None,
        epochs=None, 
        early_stopping_patience=None, 
        dataloaders=None, 
        fold=None, 
        save_path=None,
        device=None,
        verbose=False) -> tuple:
    
    def get_accuracy(y_pred, y_true):
        y_pred = torch.argmax(y_pred, dim=1)
        return torch.count_nonzero(y_pred == y_true).item() / len(y_pred)
    
    if verbose:
        breaker()
        if fold: print(f"Training Fold {fold}...")
        else: print("Training ...")
        breaker()
        
    bestLoss, bestAccs = {"train" : np.inf, "valid" : np.inf}, {"train" : 0.0, "valid" : 0.0}
    Losses, Accuracies, LRs = [], [], []
    if fold: name = f"state_fold_{fold}.pt"
    else: name = "state.pt"

    start_time = time()
    for e in range(epochs):
        e_st = time()
        epochLoss, epochAccs = {"train" : 0.0, "valid" : 0.0}, {"train" : 0.0, "valid" : 0.0}

        for phase in ["train", "valid"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
            
            lossPerPass, accsPerPass = [], []

            for X, y in dataloaders[phase]:
                X, y = X.to(device), y.to(device).view(-1)

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    output = model(X)
                    loss = torch.nn.NLLLoss()(output, y)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        if scheduler_oclr: scheduler_oclr.step()
                lossPerPass.append(loss.item())
                accsPerPass.append(get_accuracy(output, y))
            epochLoss[phase] = np.mean(np.array(lossPerPass))
            epochAccs[phase] = np.mean(np.array(accsPerPass))
        if scheduler_oclr: LRs.append(scheduler_oclr.get_last_lr())
        Losses.append(epochLoss)
        Accuracies.append(epochAccs)
        
        if scheduler_oclr:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_oclr.state_dict()}
        
        elif scheduler_rlrop:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict(),
                         "scheduler_state_dict" : scheduler_rlrop.state_dict()}
        
        else:
            save_dict = {"model_state_dict"     : model.state_dict(),
                         "optim_state_dict"     : optimizer.state_dict()}
        
        if early_stopping_patience:
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save(save_dict, os.path.join(save_path, name))
                early_stopping_step = 0
            else:
                early_stopping_step += 1
                if early_stopping_step > early_stopping_patience:
                    print("\nEarly Stopping at Epoch {}".format(e + 1))
                    break
        
        if epochLoss["valid"] < bestLoss["valid"]:
            bestLoss = epochLoss
            BLE = e + 1
            torch.save(save_dict,os.path.join(save_path, name))
        
        if epochAccs["valid"] > bestAccs["valid"]:
            bestAccs = epochAccs
            BAE = e + 1
        
        if scheduler_rlrop: scheduler_rlrop.step(epochLoss["valid"])
        
        if verbose:
            print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} |\
Train Accs: {:.5f} | Valid Accs: {:.5f} | Time: {:.2f} seconds".format(e+1, 
                                                                       epochLoss["train"], epochLoss["valid"], 
                                                                       epochAccs["train"], epochAccs["valid"], 
                                                                       time()-e_st))

    if verbose:                                           
        breaker()
        print(f"Best Validation Loss at Epoch {BLE}")
        breaker()
        print(f"Best Validation Accs at Epoch {BAE}")
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time()-start_time)/60))
    
    return Losses, Accuracies, LRs, BLE, BAE, name


def predict_batch(model=None, dataloader=None, path=None, device=None) -> np.ndarray:
    model.load_state_dict(torch.load(path, map_location=device)["model_state_dict"])
    model.to(device)    
    model.eval()
    
    y_pred = torch.zeros(1, 1).to(device)
    
    for X in dataloader:
        X = X.to(device)
        with torch.no_grad():
            output = torch.argmax(torch.exp(model(X)), dim=1)
        y_pred = torch.cat((y_pred, output.view(-1, 1)), dim=0)
    
    return y_pred[1:].detach().cpu().numpy()

# %% [markdown]
# ### **Train**

# %%
images = np.load(f"../input/pdc-images-{SIZE}/images-{SIZE}.npy")
df = pd.read_csv("../input/paddy-disease-classification/train.csv")
labels = df.label.copy().values
labels = le.fit_transform(labels)

# %%
for tr_idx, va_idx in StratifiedKFold(n_splits=cfg.n_splits, random_state=cfg.seed, shuffle=True).split(images, labels):
    break

tr_images, va_images, tr_labels, va_labels = images[tr_idx], images[va_idx], labels[tr_idx], labels[va_idx]

tr_data_setup = DS(tr_images, tr_labels.reshape(-1, 1), cfg.transform)
va_data_setup = DS(va_images, va_labels.reshape(-1, 1), cfg.transform)

dataloaders = {
    "train" : DL(tr_data_setup, batch_size=cfg.batch_size, shuffle=True, generator=torch.manual_seed(cfg.seed)),
    "valid" : DL(va_data_setup, batch_size=cfg.batch_size, shuffle=False),
}

cfg = CFG(lr=1e-5, wd=1e-4, epochs=500, early_stopping=50, batch_size=64, steps_per_epoch=len(dataloaders["train"]))

torch.manual_seed(cfg.seed)
model = Model().to(cfg.device)
optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=cfg.lr, weight_decay=cfg.wd)
scheduler_oclr = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, 
                                               max_lr=cfg.max_lr, 
                                               epochs=cfg.epochs, 
                                               steps_per_epoch=cfg.steps_per_epoch,
                                               pct_start=cfg.pct_start, 
                                               div_factor=cfg.div_factor, 
                                               final_div_factor=cfg.final_div_factor)
# scheduler_rlrop = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
#                                                       patience=cfg.patience,
#                                                       eps=cfg.eps,
#                                                       verbose=True)

# scheduler_oclr = None
scheduler_rlrop = None

L, A, LR, BLE, BAE, name = fit(model=model, 
                               optimizer=optimizer, 
                               scheduler_oclr=scheduler_oclr,
                               scheduler_rlrop=scheduler_rlrop,
                               epochs=cfg.epochs, 
                               early_stopping_patience=cfg.early_stopping, 
                               dataloaders=dataloaders, 
                               device=cfg.device,
                               save_path=cfg.save_path,
                               fold=None,
                               verbose=True)

breaker()
show_loss_graphs(L)
breaker()
show_accuracy_graphs(A)
breaker()

if scheduler_oclr:
    show_lr_graph(LR)
    breaker()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# **************************************************
#
# Training ...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 2.32526 | Valid Loss: 2.25824 |Train Accs: 0.12740 | Valid Accs: 0.18798 | Time: 32.99 seconds
# Epoch: 2 | Train Loss: 2.21781 | Valid Loss: 2.18252 |Train Accs: 0.19810 | Valid Accs: 0.20658 | Time: 27.22 seconds
# Epoch: 3 | Train Loss: 2.16035 | Valid Loss: 2.14203 |Train Accs: 0.21514 | Valid Accs: 0.23330 | Time: 27.32 seconds
# Epoch: 4 | Train Loss: 2.12650 | Valid Loss: 2.10980 |Train Accs: 0.24364 | Valid Accs: 0.26336 | Time: 27.28 seconds
# Epoch: 5 | Train Loss: 2.09313 | Valid Loss: 2.07054 |Train Accs: 0.27905 | Valid Accs: 0.30725 | Time: 27.32 seconds
# Epoch: 6 | Train Loss: 2.05056 | Valid Loss: 2.01822 |Train Accs: 0.31356 | Valid Accs: 0.32920 | Time: 27.31 seconds
# Epoch: 7 | Train Loss: 1.99735 | Valid Loss: 1.95897 |Train Accs: 0.34578 | Valid Accs: 0.35258 | Time: 27.21 seconds
# Epoch: 8 | Train Loss: 1.93665 | Valid Loss: 1.89204 |Train Accs: 0.37522 | Valid Accs: 0.38025 | Time: 27.13 seconds
# Epoch: 9 | Train Loss: 1.86659 | Valid Loss: 1.82316 |Train Accs: 0.39750 | Valid Accs: 0.41603 | Time: 27.07 seconds
# Epoch: 10 | Train Loss: 1.79903 | Valid Loss: 1.74863 |Train Accs: 0.42579 | Valid Accs: 0.44132 | Time: 27.50 seconds
# Epoch: 11 | Train Loss: 1.72954 | Valid Loss: 1.67817 |Train Accs: 0.44964 | Valid Accs: 0.45086 | Time: 27.47 seconds
# Epoch: 12 | Train Loss: 1.66280 | Valid Loss: 1.60486 |Train Accs: 0.47310 | Valid Accs: 0.49571 | Time: 27.56 seconds
# Epoch: 13 | Train Loss: 1.60160 | Valid Loss: 1.54152 |Train Accs: 0.49131 | Valid Accs: 0.51193 | Time: 27.39 seconds
# Epoch: 14 | Train Loss: 1.54363 | Valid Loss: 1.49901 |Train Accs: 0.51696 | Valid Accs: 0.51097 | Time: 27.37 seconds
# Epoch: 15 | Train Loss: 1.48446 | Valid Loss: 1.42490 |Train Accs: 0.53258 | Valid Accs: 0.54819 | Time: 27.37 seconds
# Epoch: 16 | Train Loss: 1.43006 | Valid Loss: 1.37278 |Train Accs: 0.54873 | Valid Accs: 0.56011 | Time: 27.24 seconds
# Epoch: 17 | Train Loss: 1.38656 | Valid Loss: 1.33476 |Train Accs: 0.56111 | Valid Accs: 0.57586 | Time: 27.40 seconds
# Epoch: 18 | Train Loss: 1.34718 | Valid Loss: 1.27616 |Train Accs: 0.56773 | Valid Accs: 0.58111 | Time: 27.04 seconds
# Epoch: 19 | Train Loss: 1.30053 | Valid Loss: 1.24332 |Train Accs: 0.58249 | Valid Accs: 0.60305 | Time: 27.12 seconds
# Epoch: 20 | Train Loss: 1.26226 | Valid Loss: 1.21871 |Train Accs: 0.59844 | Valid Accs: 0.61069 | Time: 27.28 seconds
# Epoch: 21 | Train Loss: 1.23046 | Valid Loss: 1.17348 |Train Accs: 0.60576 | Valid Accs: 0.62500 | Time: 27.05 seconds
# Epoch: 22 | Train Loss: 1.19532 | Valid Loss: 1.14380 |Train Accs: 0.62150 | Valid Accs: 0.63406 | Time: 27.06 seconds
# Epoch: 23 | Train Loss: 1.16507 | Valid Loss: 1.14916 |Train Accs: 0.63275 | Valid Accs: 0.63120 | Time: 27.05 seconds
# Epoch: 24 | Train Loss: 1.14074 | Valid Loss: 1.09062 |Train Accs: 0.63325 | Valid Accs: 0.64647 | Time: 27.35 seconds
# Epoch: 25 | Train Loss: 1.11980 | Valid Loss: 1.06235 |Train Accs: 0.64220 | Valid Accs: 0.65315 | Time: 27.30 seconds
# Epoch: 26 | Train Loss: 1.09678 | Valid Loss: 1.04629 |Train Accs: 0.64273 | Valid Accs: 0.66269 | Time: 27.18 seconds
# Epoch: 27 | Train Loss: 1.07272 | Valid Loss: 1.02201 |Train Accs: 0.65398 | Valid Accs: 0.66889 | Time: 27.15 seconds
# Epoch: 28 | Train Loss: 1.05547 | Valid Loss: 1.02122 |Train Accs: 0.65912 | Valid Accs: 0.66460 | Time: 27.05 seconds
# Epoch: 29 | Train Loss: 1.03496 | Valid Loss: 0.98916 |Train Accs: 0.66336 | Valid Accs: 0.68368 | Time: 27.11 seconds
# Epoch: 30 | Train Loss: 1.03108 | Valid Loss: 0.98977 |Train Accs: 0.66430 | Valid Accs: 0.67939 | Time: 26.98 seconds
# Epoch: 31 | Train Loss: 0.99968 | Valid Loss: 0.96003 |Train Accs: 0.67327 | Valid Accs: 0.68225 | Time: 27.67 seconds
# Epoch: 32 | Train Loss: 0.99395 | Valid Loss: 0.96263 |Train Accs: 0.67548 | Valid Accs: 0.69084 | Time: 26.74 seconds
# Epoch: 33 | Train Loss: 0.96796 | Valid Loss: 0.94524 |Train Accs: 0.68340 | Valid Accs: 0.69561 | Time: 27.30 seconds
# Epoch: 34 | Train Loss: 0.96243 | Valid Loss: 0.97520 |Train Accs: 0.68589 | Valid Accs: 0.67557 | Time: 26.98 seconds
# Epoch: 35 | Train Loss: 0.95792 | Valid Loss: 0.93055 |Train Accs: 0.68563 | Valid Accs: 0.69800 | Time: 27.67 seconds
# Epoch: 36 | Train Loss: 0.93877 | Valid Loss: 0.91269 |Train Accs: 0.69237 | Valid Accs: 0.70038 | Time: 27.27 seconds
# Epoch: 37 | Train Loss: 0.92679 | Valid Loss: 0.95244 |Train Accs: 0.69679 | Valid Accs: 0.68368 | Time: 26.92 seconds
# Epoch: 38 | Train Loss: 0.91321 | Valid Loss: 0.92640 |Train Accs: 0.69971 | Valid Accs: 0.69466 | Time: 26.67 seconds
# Epoch: 39 | Train Loss: 0.91124 | Valid Loss: 0.88518 |Train Accs: 0.70146 | Valid Accs: 0.71088 | Time: 27.15 seconds
# Epoch: 40 | Train Loss: 0.89533 | Valid Loss: 0.90218 |Train Accs: 0.70266 | Valid Accs: 0.69704 | Time: 26.83 seconds
# Epoch: 41 | Train Loss: 0.87929 | Valid Loss: 0.87736 |Train Accs: 0.71346 | Valid Accs: 0.71183 | Time: 27.39 seconds
# Epoch: 42 | Train Loss: 0.88360 | Valid Loss: 0.92004 |Train Accs: 0.70962 | Valid Accs: 0.69561 | Time: 26.76 seconds
# Epoch: 43 | Train Loss: 0.85609 | Valid Loss: 0.84898 |Train Accs: 0.71919 | Valid Accs: 0.71374 | Time: 27.14 seconds
# Epoch: 44 | Train Loss: 0.86043 | Valid Loss: 0.83903 |Train Accs: 0.71284 | Valid Accs: 0.72376 | Time: 26.82 seconds
# Epoch: 45 | Train Loss: 0.84717 | Valid Loss: 0.87644 |Train Accs: 0.72392 | Valid Accs: 0.71279 | Time: 26.75 seconds
# Epoch: 46 | Train Loss: 0.83845 | Valid Loss: 0.86660 |Train Accs: 0.72236 | Valid Accs: 0.71422 | Time: 27.01 seconds
# Epoch: 47 | Train Loss: 0.83681 | Valid Loss: 0.84931 |Train Accs: 0.72860 | Valid Accs: 0.73092 | Time: 26.98 seconds
# Epoch: 48 | Train Loss: 0.82677 | Valid Loss: 0.80429 |Train Accs: 0.73076 | Valid Accs: 0.72805 | Time: 27.12 seconds
# Epoch: 49 | Train Loss: 0.81613 | Valid Loss: 0.83028 |Train Accs: 0.73282 | Valid Accs: 0.72185 | Time: 26.52 seconds
# Epoch: 50 | Train Loss: 0.80663 | Valid Loss: 0.82398 |Train Accs: 0.73136 | Valid Accs: 0.72137 | Time: 26.94 seconds
# Epoch: 51 | Train Loss: 0.80350 | Valid Loss: 0.82453 |Train Accs: 0.73529 | Valid Accs: 0.72710 | Time: 26.72 seconds
# Epoch: 52 | Train Loss: 0.81685 | Valid Loss: 0.80331 |Train Accs: 0.72649 | Valid Accs: 0.73855 | Time: 27.17 seconds
# Epoch: 53 | Train Loss: 0.79648 | Valid Loss: 0.80937 |Train Accs: 0.73882 | Valid Accs: 0.74332 | Time: 26.72 seconds
# Epoch: 54 | Train Loss: 0.77983 | Valid Loss: 0.81525 |Train Accs: 0.74201 | Valid Accs: 0.72758 | Time: 26.42 seconds
# Epoch: 55 | Train Loss: 0.76682 | Valid Loss: 0.88159 |Train Accs: 0.74755 | Valid Accs: 0.71517 | Time: 26.74 seconds
# Epoch: 56 | Train Loss: 0.76505 | Valid Loss: 0.81613 |Train Accs: 0.74299 | Valid Accs: 0.73044 | Time: 26.86 seconds
# Epoch: 57 | Train Loss: 0.75736 | Valid Loss: 0.86034 |Train Accs: 0.74902 | Valid Accs: 0.70802 | Time: 26.80 seconds
# Epoch: 58 | Train Loss: 0.76221 | Valid Loss: 0.80762 |Train Accs: 0.74731 | Valid Accs: 0.73187 | Time: 26.93 seconds
# Epoch: 59 | Train Loss: 0.74290 | Valid Loss: 0.76117 |Train Accs: 0.75202 | Valid Accs: 0.74571 | Time: 27.00 seconds
# Epoch: 60 | Train Loss: 0.73767 | Valid Loss: 0.75150 |Train Accs: 0.75612 | Valid Accs: 0.74952 | Time: 26.92 seconds
# Epoch: 61 | Train Loss: 0.75487 | Valid Loss: 0.79183 |Train Accs: 0.75166 | Valid Accs: 0.73521 | Time: 26.71 seconds
# Epoch: 62 | Train Loss: 0.74007 | Valid Loss: 0.75854 |Train Accs: 0.75173 | Valid Accs: 0.74666 | Time: 26.88 seconds
# Epoch: 63 | Train Loss: 0.72255 | Valid Loss: 0.74332 |Train Accs: 0.75621 | Valid Accs: 0.75239 | Time: 27.24 seconds
# Epoch: 64 | Train Loss: 0.72270 | Valid Loss: 0.74154 |Train Accs: 0.76089 | Valid Accs: 0.75191 | Time: 27.24 seconds
# Epoch: 65 | Train Loss: 0.70572 | Valid Loss: 0.84456 |Train Accs: 0.76154 | Valid Accs: 0.71183 | Time: 26.63 seconds
# Epoch: 66 | Train Loss: 0.70180 | Valid Loss: 0.75774 |Train Accs: 0.76768 | Valid Accs: 0.74761 | Time: 26.88 seconds
# Epoch: 67 | Train Loss: 0.69612 | Valid Loss: 0.74097 |Train Accs: 0.76807 | Valid Accs: 0.76145 | Time: 27.07 seconds
# Epoch: 68 | Train Loss: 0.70280 | Valid Loss: 0.70901 |Train Accs: 0.76756 | Valid Accs: 0.76240 | Time: 27.35 seconds
# Epoch: 69 | Train Loss: 0.68374 | Valid Loss: 0.71802 |Train Accs: 0.77073 | Valid Accs: 0.76050 | Time: 27.15 seconds
# Epoch: 70 | Train Loss: 0.70152 | Valid Loss: 0.72517 |Train Accs: 0.76799 | Valid Accs: 0.76813 | Time: 27.05 seconds
# Epoch: 71 | Train Loss: 0.67915 | Valid Loss: 0.72480 |Train Accs: 0.77296 | Valid Accs: 0.76240 | Time: 26.88 seconds
# Epoch: 72 | Train Loss: 0.67748 | Valid Loss: 0.73128 |Train Accs: 0.77433 | Valid Accs: 0.76145 | Time: 27.18 seconds
# Epoch: 73 | Train Loss: 0.66615 | Valid Loss: 0.84620 |Train Accs: 0.77658 | Valid Accs: 0.72424 | Time: 27.12 seconds
# Epoch: 74 | Train Loss: 0.67678 | Valid Loss: 0.72998 |Train Accs: 0.76795 | Valid Accs: 0.76050 | Time: 26.71 seconds
# Epoch: 75 | Train Loss: 0.65680 | Valid Loss: 0.72765 |Train Accs: 0.78057 | Valid Accs: 0.76240 | Time: 26.92 seconds
# Epoch: 76 | Train Loss: 0.66917 | Valid Loss: 0.71839 |Train Accs: 0.77450 | Valid Accs: 0.76145 | Time: 26.49 seconds
# Epoch: 77 | Train Loss: 0.65257 | Valid Loss: 0.71195 |Train Accs: 0.78570 | Valid Accs: 0.76956 | Time: 27.19 seconds
# Epoch: 78 | Train Loss: 0.65572 | Valid Loss: 0.71683 |Train Accs: 0.78429 | Valid Accs: 0.76050 | Time: 26.94 seconds
# Epoch: 79 | Train Loss: 0.64540 | Valid Loss: 0.71336 |Train Accs: 0.78369 | Valid Accs: 0.76097 | Time: 27.20 seconds
# Epoch: 80 | Train Loss: 0.63708 | Valid Loss: 0.70626 |Train Accs: 0.78546 | Valid Accs: 0.77004 | Time: 27.21 seconds
# Epoch: 81 | Train Loss: 0.63240 | Valid Loss: 0.73597 |Train Accs: 0.78654 | Valid Accs: 0.76240 | Time: 27.16 seconds
# Epoch: 82 | Train Loss: 0.62664 | Valid Loss: 0.73694 |Train Accs: 0.78548 | Valid Accs: 0.76956 | Time: 26.65 seconds
# Epoch: 83 | Train Loss: 0.61614 | Valid Loss: 0.74968 |Train Accs: 0.79652 | Valid Accs: 0.75382 | Time: 27.21 seconds
# Epoch: 84 | Train Loss: 0.63317 | Valid Loss: 0.74343 |Train Accs: 0.78716 | Valid Accs: 0.74809 | Time: 27.08 seconds
# Epoch: 85 | Train Loss: 0.60927 | Valid Loss: 0.65599 |Train Accs: 0.79184 | Valid Accs: 0.78149 | Time: 26.81 seconds
# Epoch: 86 | Train Loss: 0.62729 | Valid Loss: 0.70349 |Train Accs: 0.78704 | Valid Accs: 0.77672 | Time: 27.13 seconds
# Epoch: 87 | Train Loss: 0.61591 | Valid Loss: 0.66840 |Train Accs: 0.79547 | Valid Accs: 0.77624 | Time: 26.95 seconds
# Epoch: 88 | Train Loss: 0.59963 | Valid Loss: 0.71367 |Train Accs: 0.79674 | Valid Accs: 0.76050 | Time: 27.17 seconds
# Epoch: 89 | Train Loss: 0.60820 | Valid Loss: 0.65124 |Train Accs: 0.79271 | Valid Accs: 0.78149 | Time: 27.21 seconds
# Epoch: 90 | Train Loss: 0.58564 | Valid Loss: 0.68397 |Train Accs: 0.80549 | Valid Accs: 0.77099 | Time: 27.02 seconds
# Epoch: 91 | Train Loss: 0.59499 | Valid Loss: 0.69272 |Train Accs: 0.79868 | Valid Accs: 0.77099 | Time: 26.71 seconds
# Epoch: 92 | Train Loss: 0.58574 | Valid Loss: 0.72407 |Train Accs: 0.80046 | Valid Accs: 0.75668 | Time: 27.01 seconds
# Epoch: 93 | Train Loss: 0.57510 | Valid Loss: 0.72628 |Train Accs: 0.80782 | Valid Accs: 0.76384 | Time: 26.59 seconds
# Epoch: 94 | Train Loss: 0.58903 | Valid Loss: 0.72941 |Train Accs: 0.79998 | Valid Accs: 0.76765 | Time: 26.77 seconds
# Epoch: 95 | Train Loss: 0.57031 | Valid Loss: 0.67393 |Train Accs: 0.80948 | Valid Accs: 0.78149 | Time: 27.10 seconds
# Epoch: 96 | Train Loss: 0.57869 | Valid Loss: 0.69877 |Train Accs: 0.80369 | Valid Accs: 0.77099 | Time: 27.05 seconds
# Epoch: 97 | Train Loss: 0.57489 | Valid Loss: 0.65008 |Train Accs: 0.80139 | Valid Accs: 0.78865 | Time: 27.30 seconds
# Epoch: 98 | Train Loss: 0.54614 | Valid Loss: 0.70003 |Train Accs: 0.81485 | Valid Accs: 0.76908 | Time: 26.67 seconds
# Epoch: 99 | Train Loss: 0.54755 | Valid Loss: 0.66634 |Train Accs: 0.81209 | Valid Accs: 0.79103 | Time: 26.87 seconds
# Epoch: 100 | Train Loss: 0.55076 | Valid Loss: 0.68616 |Train Accs: 0.81670 | Valid Accs: 0.78340 | Time: 26.71 seconds
# Epoch: 101 | Train Loss: 0.55370 | Valid Loss: 0.70309 |Train Accs: 0.80636 | Valid Accs: 0.77195 | Time: 27.06 seconds
# Epoch: 102 | Train Loss: 0.55528 | Valid Loss: 0.65318 |Train Accs: 0.81183 | Valid Accs: 0.79103 | Time: 26.94 seconds
# Epoch: 103 | Train Loss: 0.54935 | Valid Loss: 0.73239 |Train Accs: 0.81416 | Valid Accs: 0.76765 | Time: 26.85 seconds
# Epoch: 104 | Train Loss: 0.54128 | Valid Loss: 0.75543 |Train Accs: 0.81703 | Valid Accs: 0.76050 | Time: 27.19 seconds
# Epoch: 105 | Train Loss: 0.54807 | Valid Loss: 0.63221 |Train Accs: 0.81377 | Valid Accs: 0.79246 | Time: 27.17 seconds
# Epoch: 106 | Train Loss: 0.54179 | Valid Loss: 0.66361 |Train Accs: 0.81821 | Valid Accs: 0.78531 | Time: 27.17 seconds
# Epoch: 107 | Train Loss: 0.53692 | Valid Loss: 0.65968 |Train Accs: 0.81447 | Valid Accs: 0.78865 | Time: 26.88 seconds
# Epoch: 108 | Train Loss: 0.52072 | Valid Loss: 0.68224 |Train Accs: 0.82510 | Valid Accs: 0.78817 | Time: 27.26 seconds
# Epoch: 109 | Train Loss: 0.52549 | Valid Loss: 0.66885 |Train Accs: 0.81977 | Valid Accs: 0.78626 | Time: 26.87 seconds
# Epoch: 110 | Train Loss: 0.52115 | Valid Loss: 0.65120 |Train Accs: 0.82654 | Valid Accs: 0.78435 | Time: 27.05 seconds
# Epoch: 111 | Train Loss: 0.53315 | Valid Loss: 0.67406 |Train Accs: 0.81895 | Valid Accs: 0.77910 | Time: 26.83 seconds
# Epoch: 112 | Train Loss: 0.51325 | Valid Loss: 0.68594 |Train Accs: 0.82541 | Valid Accs: 0.77672 | Time: 26.85 seconds
# Epoch: 113 | Train Loss: 0.52175 | Valid Loss: 0.67416 |Train Accs: 0.82054 | Valid Accs: 0.78244 | Time: 26.80 seconds
# Epoch: 114 | Train Loss: 0.51000 | Valid Loss: 0.64508 |Train Accs: 0.82733 | Valid Accs: 0.79437 | Time: 26.63 seconds
# Epoch: 115 | Train Loss: 0.50663 | Valid Loss: 0.63606 |Train Accs: 0.82735 | Valid Accs: 0.80534 | Time: 26.85 seconds
# Epoch: 116 | Train Loss: 0.51530 | Valid Loss: 0.66626 |Train Accs: 0.82603 | Valid Accs: 0.77863 | Time: 26.83 seconds
# Epoch: 117 | Train Loss: 0.51603 | Valid Loss: 0.70794 |Train Accs: 0.82613 | Valid Accs: 0.76622 | Time: 26.83 seconds
# Epoch: 118 | Train Loss: 0.50570 | Valid Loss: 0.72498 |Train Accs: 0.82865 | Valid Accs: 0.77433 | Time: 26.59 seconds
# Epoch: 119 | Train Loss: 0.49530 | Valid Loss: 0.67264 |Train Accs: 0.83299 | Valid Accs: 0.79008 | Time: 27.00 seconds
# Epoch: 120 | Train Loss: 0.50323 | Valid Loss: 0.69294 |Train Accs: 0.83013 | Valid Accs: 0.78197 | Time: 26.53 seconds
# Epoch: 121 | Train Loss: 0.50081 | Valid Loss: 0.63825 |Train Accs: 0.83083 | Valid Accs: 0.79055 | Time: 27.03 seconds
# Epoch: 122 | Train Loss: 0.47345 | Valid Loss: 0.62052 |Train Accs: 0.83911 | Valid Accs: 0.79676 | Time: 27.15 seconds
# Epoch: 123 | Train Loss: 0.49864 | Valid Loss: 0.66077 |Train Accs: 0.83249 | Valid Accs: 0.78340 | Time: 26.75 seconds
# Epoch: 124 | Train Loss: 0.49368 | Valid Loss: 0.68793 |Train Accs: 0.83045 | Valid Accs: 0.77338 | Time: 26.77 seconds
# Epoch: 125 | Train Loss: 0.49607 | Valid Loss: 0.68347 |Train Accs: 0.83081 | Valid Accs: 0.78435 | Time: 26.83 seconds
# Epoch: 126 | Train Loss: 0.48750 | Valid Loss: 0.64087 |Train Accs: 0.84007 | Valid Accs: 0.78721 | Time: 26.75 seconds
# Epoch: 127 | Train Loss: 0.48986 | Valid Loss: 0.61061 |Train Accs: 0.83443 | Valid Accs: 0.80964 | Time: 27.01 seconds
# Epoch: 128 | Train Loss: 0.48694 | Valid Loss: 0.62389 |Train Accs: 0.83237 | Valid Accs: 0.80344 | Time: 26.89 seconds
# Epoch: 129 | Train Loss: 0.48360 | Valid Loss: 0.65849 |Train Accs: 0.83563 | Valid Accs: 0.78817 | Time: 26.74 seconds
# Epoch: 130 | Train Loss: 0.48050 | Valid Loss: 0.61430 |Train Accs: 0.84261 | Valid Accs: 0.80010 | Time: 26.80 seconds
# Epoch: 131 | Train Loss: 0.47681 | Valid Loss: 0.63632 |Train Accs: 0.83733 | Valid Accs: 0.79914 | Time: 26.86 seconds
# Epoch: 132 | Train Loss: 0.47017 | Valid Loss: 0.62124 |Train Accs: 0.84175 | Valid Accs: 0.79962 | Time: 26.74 seconds
# Epoch: 133 | Train Loss: 0.47956 | Valid Loss: 0.59756 |Train Accs: 0.83899 | Valid Accs: 0.80391 | Time: 27.03 seconds
# Epoch: 134 | Train Loss: 0.45772 | Valid Loss: 0.64198 |Train Accs: 0.84436 | Valid Accs: 0.79151 | Time: 26.53 seconds
# Epoch: 135 | Train Loss: 0.48682 | Valid Loss: 0.64084 |Train Accs: 0.83186 | Valid Accs: 0.79246 | Time: 26.86 seconds
# Epoch: 136 | Train Loss: 0.47149 | Valid Loss: 0.69878 |Train Accs: 0.84331 | Valid Accs: 0.78721 | Time: 26.64 seconds
# Epoch: 137 | Train Loss: 0.46589 | Valid Loss: 0.61635 |Train Accs: 0.84762 | Valid Accs: 0.79723 | Time: 26.87 seconds
# Epoch: 138 | Train Loss: 0.46233 | Valid Loss: 0.61173 |Train Accs: 0.84376 | Valid Accs: 0.80868 | Time: 26.88 seconds
# Epoch: 139 | Train Loss: 0.47148 | Valid Loss: 0.64326 |Train Accs: 0.83966 | Valid Accs: 0.78721 | Time: 26.91 seconds
# Epoch: 140 | Train Loss: 0.47195 | Valid Loss: 0.65367 |Train Accs: 0.84268 | Valid Accs: 0.79342 | Time: 26.84 seconds
# Epoch: 141 | Train Loss: 0.45519 | Valid Loss: 0.62400 |Train Accs: 0.84679 | Valid Accs: 0.80105 | Time: 26.82 seconds
# Epoch: 142 | Train Loss: 0.46639 | Valid Loss: 0.59699 |Train Accs: 0.84355 | Valid Accs: 0.80821 | Time: 26.98 seconds
# Epoch: 143 | Train Loss: 0.44878 | Valid Loss: 0.66016 |Train Accs: 0.84952 | Valid Accs: 0.78721 | Time: 26.88 seconds
# Epoch: 144 | Train Loss: 0.45956 | Valid Loss: 0.59300 |Train Accs: 0.84158 | Valid Accs: 0.80773 | Time: 27.18 seconds
# Epoch: 145 | Train Loss: 0.44995 | Valid Loss: 0.65594 |Train Accs: 0.84873 | Valid Accs: 0.79437 | Time: 26.75 seconds
# Epoch: 146 | Train Loss: 0.45627 | Valid Loss: 0.68032 |Train Accs: 0.84340 | Valid Accs: 0.79151 | Time: 26.98 seconds
# Epoch: 147 | Train Loss: 0.45026 | Valid Loss: 0.67631 |Train Accs: 0.84487 | Valid Accs: 0.77958 | Time: 26.81 seconds
# Epoch: 148 | Train Loss: 0.44771 | Valid Loss: 0.60831 |Train Accs: 0.84518 | Valid Accs: 0.80153 | Time: 26.74 seconds
# Epoch: 149 | Train Loss: 0.43761 | Valid Loss: 0.66605 |Train Accs: 0.85314 | Valid Accs: 0.78435 | Time: 26.84 seconds
# Epoch: 150 | Train Loss: 0.45523 | Valid Loss: 0.62939 |Train Accs: 0.84043 | Valid Accs: 0.79771 | Time: 26.76 seconds
# Epoch: 151 | Train Loss: 0.45387 | Valid Loss: 0.67039 |Train Accs: 0.84954 | Valid Accs: 0.79151 | Time: 26.93 seconds
# Epoch: 152 | Train Loss: 0.44794 | Valid Loss: 0.59607 |Train Accs: 0.84856 | Valid Accs: 0.80391 | Time: 26.71 seconds
# Epoch: 153 | Train Loss: 0.44173 | Valid Loss: 0.58499 |Train Accs: 0.84844 | Valid Accs: 0.81345 | Time: 27.15 seconds
# Epoch: 154 | Train Loss: 0.43968 | Valid Loss: 0.58660 |Train Accs: 0.85257 | Valid Accs: 0.81489 | Time: 26.84 seconds
# Epoch: 155 | Train Loss: 0.42896 | Valid Loss: 0.56488 |Train Accs: 0.85324 | Valid Accs: 0.82824 | Time: 27.51 seconds
# Epoch: 156 | Train Loss: 0.44029 | Valid Loss: 0.73333 |Train Accs: 0.85180 | Valid Accs: 0.76861 | Time: 26.95 seconds
# Epoch: 157 | Train Loss: 0.43318 | Valid Loss: 0.59583 |Train Accs: 0.85386 | Valid Accs: 0.81011 | Time: 26.55 seconds
# Epoch: 158 | Train Loss: 0.44158 | Valid Loss: 0.62893 |Train Accs: 0.84976 | Valid Accs: 0.79962 | Time: 26.88 seconds
# Epoch: 159 | Train Loss: 0.43184 | Valid Loss: 0.60278 |Train Accs: 0.85321 | Valid Accs: 0.80630 | Time: 26.69 seconds
# Epoch: 160 | Train Loss: 0.43432 | Valid Loss: 0.60645 |Train Accs: 0.85446 | Valid Accs: 0.80487 | Time: 26.76 seconds
# Epoch: 161 | Train Loss: 0.42833 | Valid Loss: 0.65982 |Train Accs: 0.85629 | Valid Accs: 0.78721 | Time: 26.79 seconds
# Epoch: 162 | Train Loss: 0.42997 | Valid Loss: 0.58071 |Train Accs: 0.85482 | Valid Accs: 0.81202 | Time: 26.87 seconds
# Epoch: 163 | Train Loss: 0.41834 | Valid Loss: 0.64018 |Train Accs: 0.85768 | Valid Accs: 0.80010 | Time: 26.85 seconds
# Epoch: 164 | Train Loss: 0.41851 | Valid Loss: 0.58764 |Train Accs: 0.85902 | Valid Accs: 0.81298 | Time: 27.02 seconds
# Epoch: 165 | Train Loss: 0.42050 | Valid Loss: 0.59604 |Train Accs: 0.85878 | Valid Accs: 0.80868 | Time: 26.90 seconds
# Epoch: 166 | Train Loss: 0.43293 | Valid Loss: 0.59403 |Train Accs: 0.85118 | Valid Accs: 0.81011 | Time: 26.94 seconds
# Epoch: 167 | Train Loss: 0.43643 | Valid Loss: 0.60181 |Train Accs: 0.85386 | Valid Accs: 0.80821 | Time: 27.12 seconds
# Epoch: 168 | Train Loss: 0.43811 | Valid Loss: 0.60944 |Train Accs: 0.85168 | Valid Accs: 0.80105 | Time: 27.00 seconds
# Epoch: 169 | Train Loss: 0.42612 | Valid Loss: 0.61122 |Train Accs: 0.85761 | Valid Accs: 0.80296 | Time: 26.96 seconds
# Epoch: 170 | Train Loss: 0.42383 | Valid Loss: 0.60206 |Train Accs: 0.86032 | Valid Accs: 0.80773 | Time: 26.78 seconds
# Epoch: 171 | Train Loss: 0.43249 | Valid Loss: 0.59653 |Train Accs: 0.85461 | Valid Accs: 0.81536 | Time: 26.84 seconds
# Epoch: 172 | Train Loss: 0.41366 | Valid Loss: 0.58170 |Train Accs: 0.86248 | Valid Accs: 0.80391 | Time: 26.86 seconds
# Epoch: 173 | Train Loss: 0.42683 | Valid Loss: 0.60960 |Train Accs: 0.85816 | Valid Accs: 0.79914 | Time: 27.04 seconds
# Epoch: 174 | Train Loss: 0.41070 | Valid Loss: 0.60434 |Train Accs: 0.86442 | Valid Accs: 0.80534 | Time: 26.77 seconds
# Epoch: 175 | Train Loss: 0.41545 | Valid Loss: 0.61435 |Train Accs: 0.86310 | Valid Accs: 0.80773 | Time: 26.75 seconds
# Epoch: 176 | Train Loss: 0.41924 | Valid Loss: 0.64131 |Train Accs: 0.85773 | Valid Accs: 0.79962 | Time: 26.80 seconds
# Epoch: 177 | Train Loss: 0.41878 | Valid Loss: 0.59849 |Train Accs: 0.85842 | Valid Accs: 0.81489 | Time: 26.82 seconds
# Epoch: 178 | Train Loss: 0.40733 | Valid Loss: 0.60944 |Train Accs: 0.85737 | Valid Accs: 0.80821 | Time: 26.72 seconds
# Epoch: 179 | Train Loss: 0.40272 | Valid Loss: 0.59558 |Train Accs: 0.85996 | Valid Accs: 0.80868 | Time: 26.81 seconds
# Epoch: 180 | Train Loss: 0.41806 | Valid Loss: 0.59387 |Train Accs: 0.86180 | Valid Accs: 0.81775 | Time: 26.69 seconds
# Epoch: 181 | Train Loss: 0.40378 | Valid Loss: 0.65618 |Train Accs: 0.86437 | Valid Accs: 0.79055 | Time: 26.75 seconds
# Epoch: 182 | Train Loss: 0.39956 | Valid Loss: 0.55794 |Train Accs: 0.86545 | Valid Accs: 0.82013 | Time: 27.16 seconds
# Epoch: 183 | Train Loss: 0.39425 | Valid Loss: 0.56631 |Train Accs: 0.86751 | Valid Accs: 0.81489 | Time: 26.28 seconds
# Epoch: 184 | Train Loss: 0.39619 | Valid Loss: 0.70876 |Train Accs: 0.86946 | Valid Accs: 0.77815 | Time: 26.30 seconds
# Epoch: 185 | Train Loss: 0.40549 | Valid Loss: 0.58381 |Train Accs: 0.86490 | Valid Accs: 0.81298 | Time: 26.90 seconds
# Epoch: 186 | Train Loss: 0.41672 | Valid Loss: 0.59120 |Train Accs: 0.86214 | Valid Accs: 0.81155 | Time: 26.69 seconds
# Epoch: 187 | Train Loss: 0.40403 | Valid Loss: 0.60162 |Train Accs: 0.86461 | Valid Accs: 0.80582 | Time: 26.76 seconds
# Epoch: 188 | Train Loss: 0.39257 | Valid Loss: 0.63746 |Train Accs: 0.86631 | Valid Accs: 0.80200 | Time: 26.60 seconds
# Epoch: 189 | Train Loss: 0.41498 | Valid Loss: 0.61042 |Train Accs: 0.85782 | Valid Accs: 0.80248 | Time: 26.60 seconds
# Epoch: 190 | Train Loss: 0.40573 | Valid Loss: 0.57275 |Train Accs: 0.86084 | Valid Accs: 0.81775 | Time: 26.69 seconds
# Epoch: 191 | Train Loss: 0.39338 | Valid Loss: 0.57319 |Train Accs: 0.87159 | Valid Accs: 0.81536 | Time: 26.89 seconds
# Epoch: 192 | Train Loss: 0.40321 | Valid Loss: 0.59274 |Train Accs: 0.86490 | Valid Accs: 0.80725 | Time: 26.77 seconds
# Epoch: 193 | Train Loss: 0.41016 | Valid Loss: 0.60736 |Train Accs: 0.86228 | Valid Accs: 0.80630 | Time: 26.54 seconds
# Epoch: 194 | Train Loss: 0.39551 | Valid Loss: 0.60931 |Train Accs: 0.86694 | Valid Accs: 0.80391 | Time: 26.63 seconds
# Epoch: 195 | Train Loss: 0.39343 | Valid Loss: 0.66222 |Train Accs: 0.86610 | Valid Accs: 0.79198 | Time: 26.61 seconds
# Epoch: 196 | Train Loss: 0.39555 | Valid Loss: 0.56665 |Train Accs: 0.87080 | Valid Accs: 0.81632 | Time: 26.56 seconds
# Epoch: 197 | Train Loss: 0.38130 | Valid Loss: 0.55415 |Train Accs: 0.86936 | Valid Accs: 0.82109 | Time: 26.98 seconds
# Epoch: 198 | Train Loss: 0.38526 | Valid Loss: 0.61105 |Train Accs: 0.86715 | Valid Accs: 0.80868 | Time: 26.56 seconds
# Epoch: 199 | Train Loss: 0.38995 | Valid Loss: 0.55316 |Train Accs: 0.86665 | Valid Accs: 0.82109 | Time: 26.72 seconds
# Epoch: 200 | Train Loss: 0.37509 | Valid Loss: 0.67256 |Train Accs: 0.87090 | Valid Accs: 0.79771 | Time: 26.76 seconds
# Epoch: 201 | Train Loss: 0.40151 | Valid Loss: 0.57264 |Train Accs: 0.86586 | Valid Accs: 0.81584 | Time: 26.72 seconds
# Epoch: 202 | Train Loss: 0.38304 | Valid Loss: 0.64480 |Train Accs: 0.86862 | Valid Accs: 0.79008 | Time: 26.56 seconds
# Epoch: 203 | Train Loss: 0.37435 | Valid Loss: 0.54834 |Train Accs: 0.87666 | Valid Accs: 0.82443 | Time: 26.93 seconds
# Epoch: 204 | Train Loss: 0.39039 | Valid Loss: 0.63811 |Train Accs: 0.87116 | Valid Accs: 0.80153 | Time: 26.59 seconds
# Epoch: 205 | Train Loss: 0.37757 | Valid Loss: 0.60386 |Train Accs: 0.87661 | Valid Accs: 0.80964 | Time: 26.56 seconds
# Epoch: 206 | Train Loss: 0.37666 | Valid Loss: 0.57382 |Train Accs: 0.87042 | Valid Accs: 0.81298 | Time: 26.79 seconds
# Epoch: 207 | Train Loss: 0.37807 | Valid Loss: 0.65005 |Train Accs: 0.87200 | Valid Accs: 0.78912 | Time: 26.60 seconds
# Epoch: 208 | Train Loss: 0.37730 | Valid Loss: 0.58145 |Train Accs: 0.86922 | Valid Accs: 0.82300 | Time: 26.75 seconds
# Epoch: 209 | Train Loss: 0.38321 | Valid Loss: 0.58421 |Train Accs: 0.86955 | Valid Accs: 0.81584 | Time: 26.67 seconds
# Epoch: 210 | Train Loss: 0.38087 | Valid Loss: 0.54491 |Train Accs: 0.86826 | Valid Accs: 0.82777 | Time: 26.95 seconds
# Epoch: 211 | Train Loss: 0.37533 | Valid Loss: 0.63106 |Train Accs: 0.87306 | Valid Accs: 0.80725 | Time: 26.62 seconds
# Epoch: 212 | Train Loss: 0.36935 | Valid Loss: 0.57976 |Train Accs: 0.87745 | Valid Accs: 0.81250 | Time: 26.66 seconds
# Epoch: 213 | Train Loss: 0.38478 | Valid Loss: 0.57912 |Train Accs: 0.87061 | Valid Accs: 0.81727 | Time: 26.68 seconds
# Epoch: 214 | Train Loss: 0.36964 | Valid Loss: 0.56823 |Train Accs: 0.87639 | Valid Accs: 0.81679 | Time: 26.34 seconds
# Epoch: 215 | Train Loss: 0.38219 | Valid Loss: 0.57944 |Train Accs: 0.87097 | Valid Accs: 0.82634 | Time: 26.72 seconds
# Epoch: 216 | Train Loss: 0.37594 | Valid Loss: 0.57363 |Train Accs: 0.87476 | Valid Accs: 0.82156 | Time: 26.39 seconds
# Epoch: 217 | Train Loss: 0.37052 | Valid Loss: 0.63204 |Train Accs: 0.87171 | Valid Accs: 0.80964 | Time: 26.57 seconds
# Epoch: 218 | Train Loss: 0.38506 | Valid Loss: 0.55312 |Train Accs: 0.87001 | Valid Accs: 0.82729 | Time: 26.78 seconds
# Epoch: 219 | Train Loss: 0.36590 | Valid Loss: 0.65067 |Train Accs: 0.87582 | Valid Accs: 0.78865 | Time: 26.58 seconds
# Epoch: 220 | Train Loss: 0.37275 | Valid Loss: 0.57182 |Train Accs: 0.87692 | Valid Accs: 0.81345 | Time: 26.89 seconds
# Epoch: 221 | Train Loss: 0.37535 | Valid Loss: 0.60218 |Train Accs: 0.87282 | Valid Accs: 0.81489 | Time: 26.73 seconds
# Epoch: 222 | Train Loss: 0.36879 | Valid Loss: 0.63164 |Train Accs: 0.87481 | Valid Accs: 0.79198 | Time: 26.77 seconds
# Epoch: 223 | Train Loss: 0.37149 | Valid Loss: 0.58511 |Train Accs: 0.87435 | Valid Accs: 0.81489 | Time: 26.61 seconds
# Epoch: 224 | Train Loss: 0.37059 | Valid Loss: 0.58840 |Train Accs: 0.87440 | Valid Accs: 0.81202 | Time: 26.45 seconds
# Epoch: 225 | Train Loss: 0.36750 | Valid Loss: 0.61306 |Train Accs: 0.87702 | Valid Accs: 0.81059 | Time: 26.56 seconds
# Epoch: 226 | Train Loss: 0.37134 | Valid Loss: 0.58622 |Train Accs: 0.87548 | Valid Accs: 0.81727 | Time: 26.72 seconds
# Epoch: 227 | Train Loss: 0.35540 | Valid Loss: 0.67112 |Train Accs: 0.88277 | Valid Accs: 0.79103 | Time: 26.71 seconds
# Epoch: 228 | Train Loss: 0.36468 | Valid Loss: 0.57086 |Train Accs: 0.87618 | Valid Accs: 0.81918 | Time: 26.59 seconds
# Epoch: 229 | Train Loss: 0.36090 | Valid Loss: 0.55929 |Train Accs: 0.87793 | Valid Accs: 0.82586 | Time: 26.41 seconds
# Epoch: 230 | Train Loss: 0.37701 | Valid Loss: 0.62731 |Train Accs: 0.87186 | Valid Accs: 0.80630 | Time: 26.54 seconds
# Epoch: 231 | Train Loss: 0.35839 | Valid Loss: 0.62933 |Train Accs: 0.88100 | Valid Accs: 0.79437 | Time: 26.62 seconds
# Epoch: 232 | Train Loss: 0.37108 | Valid Loss: 0.56863 |Train Accs: 0.87582 | Valid Accs: 0.81298 | Time: 26.63 seconds
# Epoch: 233 | Train Loss: 0.36141 | Valid Loss: 0.58007 |Train Accs: 0.88095 | Valid Accs: 0.81870 | Time: 26.58 seconds
# Epoch: 234 | Train Loss: 0.35760 | Valid Loss: 0.55468 |Train Accs: 0.88169 | Valid Accs: 0.82681 | Time: 26.64 seconds
# Epoch: 235 | Train Loss: 0.34985 | Valid Loss: 0.65288 |Train Accs: 0.88397 | Valid Accs: 0.78769 | Time: 26.45 seconds
# Epoch: 236 | Train Loss: 0.36929 | Valid Loss: 0.62319 |Train Accs: 0.87764 | Valid Accs: 0.80582 | Time: 26.56 seconds
# Epoch: 237 | Train Loss: 0.35258 | Valid Loss: 0.56245 |Train Accs: 0.88460 | Valid Accs: 0.82156 | Time: 26.75 seconds
# Epoch: 238 | Train Loss: 0.36020 | Valid Loss: 0.59138 |Train Accs: 0.88021 | Valid Accs: 0.81679 | Time: 26.50 seconds
# Epoch: 239 | Train Loss: 0.35741 | Valid Loss: 0.57174 |Train Accs: 0.88232 | Valid Accs: 0.82109 | Time: 26.48 seconds
# Epoch: 240 | Train Loss: 0.35489 | Valid Loss: 0.56029 |Train Accs: 0.88119 | Valid Accs: 0.82395 | Time: 26.65 seconds
# Epoch: 241 | Train Loss: 0.36216 | Valid Loss: 0.57733 |Train Accs: 0.87836 | Valid Accs: 0.82156 | Time: 26.52 seconds
# Epoch: 242 | Train Loss: 0.36467 | Valid Loss: 0.60485 |Train Accs: 0.87992 | Valid Accs: 0.81202 | Time: 26.54 seconds
# Epoch: 243 | Train Loss: 0.36006 | Valid Loss: 0.56342 |Train Accs: 0.87857 | Valid Accs: 0.82490 | Time: 26.70 seconds
# Epoch: 244 | Train Loss: 0.34458 | Valid Loss: 0.64591 |Train Accs: 0.88589 | Valid Accs: 0.79866 | Time: 26.60 seconds
# Epoch: 245 | Train Loss: 0.36203 | Valid Loss: 0.57947 |Train Accs: 0.87750 | Valid Accs: 0.81775 | Time: 26.60 seconds
# Epoch: 246 | Train Loss: 0.36228 | Valid Loss: 0.57087 |Train Accs: 0.87699 | Valid Accs: 0.82681 | Time: 26.44 seconds
# Epoch: 247 | Train Loss: 0.35635 | Valid Loss: 0.56227 |Train Accs: 0.88167 | Valid Accs: 0.82156 | Time: 26.62 seconds
# Epoch: 248 | Train Loss: 0.36287 | Valid Loss: 0.56188 |Train Accs: 0.87637 | Valid Accs: 0.82252 | Time: 26.50 seconds
# Epoch: 249 | Train Loss: 0.35394 | Valid Loss: 0.55265 |Train Accs: 0.88071 | Valid Accs: 0.82538 | Time: 26.57 seconds
# Epoch: 250 | Train Loss: 0.34792 | Valid Loss: 0.63158 |Train Accs: 0.88508 | Valid Accs: 0.79866 | Time: 26.48 seconds
# Epoch: 251 | Train Loss: 0.34884 | Valid Loss: 0.53992 |Train Accs: 0.88311 | Valid Accs: 0.83206 | Time: 26.74 seconds
# Epoch: 252 | Train Loss: 0.34064 | Valid Loss: 0.55322 |Train Accs: 0.88649 | Valid Accs: 0.81536 | Time: 26.46 seconds
# Epoch: 253 | Train Loss: 0.35157 | Valid Loss: 0.58575 |Train Accs: 0.88599 | Valid Accs: 0.81250 | Time: 26.59 seconds
# Epoch: 254 | Train Loss: 0.35017 | Valid Loss: 0.57885 |Train Accs: 0.88443 | Valid Accs: 0.81202 | Time: 26.60 seconds
# Epoch: 255 | Train Loss: 0.33798 | Valid Loss: 0.55438 |Train Accs: 0.89016 | Valid Accs: 0.82347 | Time: 26.49 seconds
# Epoch: 256 | Train Loss: 0.34173 | Valid Loss: 0.57741 |Train Accs: 0.89000 | Valid Accs: 0.81584 | Time: 26.71 seconds
# Epoch: 257 | Train Loss: 0.33586 | Valid Loss: 0.56449 |Train Accs: 0.89081 | Valid Accs: 0.81870 | Time: 26.63 seconds
# Epoch: 258 | Train Loss: 0.34698 | Valid Loss: 0.56979 |Train Accs: 0.88421 | Valid Accs: 0.82395 | Time: 26.68 seconds
# Epoch: 259 | Train Loss: 0.34911 | Valid Loss: 0.59131 |Train Accs: 0.88141 | Valid Accs: 0.81155 | Time: 26.51 seconds
# Epoch: 260 | Train Loss: 0.34288 | Valid Loss: 0.56378 |Train Accs: 0.88781 | Valid Accs: 0.82347 | Time: 26.23 seconds
# Epoch: 261 | Train Loss: 0.35190 | Valid Loss: 0.56476 |Train Accs: 0.88613 | Valid Accs: 0.82013 | Time: 26.71 seconds
# Epoch: 262 | Train Loss: 0.35645 | Valid Loss: 0.59491 |Train Accs: 0.87810 | Valid Accs: 0.81345 | Time: 26.51 seconds
# Epoch: 263 | Train Loss: 0.34423 | Valid Loss: 0.56013 |Train Accs: 0.88745 | Valid Accs: 0.82729 | Time: 26.60 seconds
# Epoch: 264 | Train Loss: 0.34068 | Valid Loss: 0.57293 |Train Accs: 0.88990 | Valid Accs: 0.82061 | Time: 26.55 seconds
# Epoch: 265 | Train Loss: 0.34579 | Valid Loss: 0.59216 |Train Accs: 0.88985 | Valid Accs: 0.80725 | Time: 26.33 seconds
# Epoch: 266 | Train Loss: 0.34806 | Valid Loss: 0.57249 |Train Accs: 0.88251 | Valid Accs: 0.81966 | Time: 26.61 seconds
# Epoch: 267 | Train Loss: 0.35238 | Valid Loss: 0.55847 |Train Accs: 0.88704 | Valid Accs: 0.82729 | Time: 26.52 seconds
# Epoch: 268 | Train Loss: 0.33348 | Valid Loss: 0.56914 |Train Accs: 0.89107 | Valid Accs: 0.81966 | Time: 26.75 seconds
# Epoch: 269 | Train Loss: 0.33924 | Valid Loss: 0.55501 |Train Accs: 0.88719 | Valid Accs: 0.82490 | Time: 26.81 seconds
# Epoch: 270 | Train Loss: 0.33354 | Valid Loss: 0.57565 |Train Accs: 0.89201 | Valid Accs: 0.82013 | Time: 26.51 seconds
# Epoch: 271 | Train Loss: 0.34357 | Valid Loss: 0.59522 |Train Accs: 0.88469 | Valid Accs: 0.81059 | Time: 26.65 seconds
# Epoch: 272 | Train Loss: 0.33345 | Valid Loss: 0.57061 |Train Accs: 0.88647 | Valid Accs: 0.81632 | Time: 26.68 seconds
# Epoch: 273 | Train Loss: 0.34284 | Valid Loss: 0.58679 |Train Accs: 0.88680 | Valid Accs: 0.81298 | Time: 26.64 seconds
# Epoch: 274 | Train Loss: 0.34647 | Valid Loss: 0.55389 |Train Accs: 0.88479 | Valid Accs: 0.81966 | Time: 26.57 seconds
# Epoch: 275 | Train Loss: 0.33326 | Valid Loss: 0.54959 |Train Accs: 0.89172 | Valid Accs: 0.82634 | Time: 26.42 seconds
# Epoch: 276 | Train Loss: 0.33740 | Valid Loss: 0.63261 |Train Accs: 0.89391 | Valid Accs: 0.79819 | Time: 26.52 seconds
# Epoch: 277 | Train Loss: 0.33297 | Valid Loss: 0.55812 |Train Accs: 0.89153 | Valid Accs: 0.82729 | Time: 26.52 seconds
# Epoch: 278 | Train Loss: 0.33047 | Valid Loss: 0.56949 |Train Accs: 0.89151 | Valid Accs: 0.81966 | Time: 26.75 seconds
# Epoch: 279 | Train Loss: 0.32930 | Valid Loss: 0.56212 |Train Accs: 0.88940 | Valid Accs: 0.82538 | Time: 26.66 seconds
# Epoch: 280 | Train Loss: 0.33690 | Valid Loss: 0.57746 |Train Accs: 0.88863 | Valid Accs: 0.81775 | Time: 26.56 seconds
# Epoch: 281 | Train Loss: 0.33567 | Valid Loss: 0.55474 |Train Accs: 0.88839 | Valid Accs: 0.82061 | Time: 26.78 seconds
# Epoch: 282 | Train Loss: 0.32817 | Valid Loss: 0.55208 |Train Accs: 0.89403 | Valid Accs: 0.82300 | Time: 26.53 seconds
# Epoch: 283 | Train Loss: 0.33798 | Valid Loss: 0.57960 |Train Accs: 0.89153 | Valid Accs: 0.81870 | Time: 26.55 seconds
# Epoch: 284 | Train Loss: 0.34178 | Valid Loss: 0.54794 |Train Accs: 0.88695 | Valid Accs: 0.82061 | Time: 26.40 seconds
# Epoch: 285 | Train Loss: 0.33450 | Valid Loss: 0.54914 |Train Accs: 0.89057 | Valid Accs: 0.82681 | Time: 26.47 seconds
# Epoch: 286 | Train Loss: 0.34248 | Valid Loss: 0.54404 |Train Accs: 0.88625 | Valid Accs: 0.82920 | Time: 26.64 seconds
# Epoch: 287 | Train Loss: 0.33700 | Valid Loss: 0.54658 |Train Accs: 0.88649 | Valid Accs: 0.82347 | Time: 26.49 seconds
# Epoch: 288 | Train Loss: 0.32521 | Valid Loss: 0.54983 |Train Accs: 0.88925 | Valid Accs: 0.82395 | Time: 26.65 seconds
# Epoch: 289 | Train Loss: 0.33344 | Valid Loss: 0.54877 |Train Accs: 0.89007 | Valid Accs: 0.82872 | Time: 26.37 seconds
# Epoch: 290 | Train Loss: 0.33082 | Valid Loss: 0.54445 |Train Accs: 0.88656 | Valid Accs: 0.82729 | Time: 26.73 seconds
# Epoch: 291 | Train Loss: 0.31775 | Valid Loss: 0.56868 |Train Accs: 0.89899 | Valid Accs: 0.81775 | Time: 26.48 seconds
# Epoch: 292 | Train Loss: 0.32895 | Valid Loss: 0.54702 |Train Accs: 0.89031 | Valid Accs: 0.82061 | Time: 26.67 seconds
# Epoch: 293 | Train Loss: 0.33729 | Valid Loss: 0.57080 |Train Accs: 0.89021 | Valid Accs: 0.81632 | Time: 26.73 seconds
# Epoch: 294 | Train Loss: 0.31953 | Valid Loss: 0.57623 |Train Accs: 0.89619 | Valid Accs: 0.81918 | Time: 26.43 seconds
# Epoch: 295 | Train Loss: 0.33094 | Valid Loss: 0.56122 |Train Accs: 0.89211 | Valid Accs: 0.81632 | Time: 26.78 seconds
# Epoch: 296 | Train Loss: 0.32199 | Valid Loss: 0.57250 |Train Accs: 0.89683 | Valid Accs: 0.82538 | Time: 26.83 seconds
# Epoch: 297 | Train Loss: 0.31385 | Valid Loss: 0.53648 |Train Accs: 0.90041 | Valid Accs: 0.82634 | Time: 26.95 seconds
# Epoch: 298 | Train Loss: 0.31738 | Valid Loss: 0.54709 |Train Accs: 0.89801 | Valid Accs: 0.82252 | Time: 26.50 seconds
# Epoch: 299 | Train Loss: 0.33087 | Valid Loss: 0.55863 |Train Accs: 0.89151 | Valid Accs: 0.82443 | Time: 26.92 seconds
# Epoch: 300 | Train Loss: 0.32926 | Valid Loss: 0.54956 |Train Accs: 0.89057 | Valid Accs: 0.82395 | Time: 26.57 seconds
# Epoch: 301 | Train Loss: 0.32602 | Valid Loss: 0.57152 |Train Accs: 0.89412 | Valid Accs: 0.82109 | Time: 26.85 seconds
# Epoch: 302 | Train Loss: 0.31830 | Valid Loss: 0.52901 |Train Accs: 0.89573 | Valid Accs: 0.83111 | Time: 27.13 seconds
# Epoch: 303 | Train Loss: 0.33062 | Valid Loss: 0.57112 |Train Accs: 0.89280 | Valid Accs: 0.81918 | Time: 26.78 seconds
# Epoch: 304 | Train Loss: 0.31265 | Valid Loss: 0.53104 |Train Accs: 0.89602 | Valid Accs: 0.82920 | Time: 27.02 seconds
# Epoch: 305 | Train Loss: 0.32066 | Valid Loss: 0.55405 |Train Accs: 0.89587 | Valid Accs: 0.82156 | Time: 26.72 seconds
# Epoch: 306 | Train Loss: 0.31644 | Valid Loss: 0.55372 |Train Accs: 0.89779 | Valid Accs: 0.82204 | Time: 26.93 seconds
# Epoch: 307 | Train Loss: 0.31953 | Valid Loss: 0.54193 |Train Accs: 0.89789 | Valid Accs: 0.82729 | Time: 26.87 seconds
# Epoch: 308 | Train Loss: 0.31562 | Valid Loss: 0.57336 |Train Accs: 0.89719 | Valid Accs: 0.82109 | Time: 26.83 seconds
# Epoch: 309 | Train Loss: 0.31522 | Valid Loss: 0.57658 |Train Accs: 0.89803 | Valid Accs: 0.81441 | Time: 26.83 seconds
# Epoch: 310 | Train Loss: 0.31479 | Valid Loss: 0.56943 |Train Accs: 0.89748 | Valid Accs: 0.82490 | Time: 26.44 seconds
# Epoch: 311 | Train Loss: 0.32015 | Valid Loss: 0.56561 |Train Accs: 0.89251 | Valid Accs: 0.81775 | Time: 26.84 seconds
# Epoch: 312 | Train Loss: 0.31375 | Valid Loss: 0.57208 |Train Accs: 0.89981 | Valid Accs: 0.82204 | Time: 26.95 seconds
# Epoch: 313 | Train Loss: 0.32500 | Valid Loss: 0.53795 |Train Accs: 0.89427 | Valid Accs: 0.83588 | Time: 26.98 seconds
# Epoch: 314 | Train Loss: 0.29540 | Valid Loss: 0.54591 |Train Accs: 0.91027 | Valid Accs: 0.82872 | Time: 26.92 seconds
# Epoch: 315 | Train Loss: 0.31435 | Valid Loss: 0.55250 |Train Accs: 0.89885 | Valid Accs: 0.82872 | Time: 26.95 seconds
# Epoch: 316 | Train Loss: 0.31287 | Valid Loss: 0.54422 |Train Accs: 0.89978 | Valid Accs: 0.83254 | Time: 26.43 seconds
# Epoch: 317 | Train Loss: 0.30787 | Valid Loss: 0.54453 |Train Accs: 0.90338 | Valid Accs: 0.82490 | Time: 26.76 seconds
# Epoch: 318 | Train Loss: 0.31517 | Valid Loss: 0.55777 |Train Accs: 0.89765 | Valid Accs: 0.82443 | Time: 27.09 seconds
# Epoch: 319 | Train Loss: 0.32325 | Valid Loss: 0.53833 |Train Accs: 0.89271 | Valid Accs: 0.82490 | Time: 26.86 seconds
# Epoch: 320 | Train Loss: 0.31534 | Valid Loss: 0.53742 |Train Accs: 0.89609 | Valid Accs: 0.82777 | Time: 26.89 seconds
# Epoch: 321 | Train Loss: 0.30760 | Valid Loss: 0.54545 |Train Accs: 0.89499 | Valid Accs: 0.82920 | Time: 26.54 seconds
# Epoch: 322 | Train Loss: 0.31812 | Valid Loss: 0.53637 |Train Accs: 0.89834 | Valid Accs: 0.83015 | Time: 26.98 seconds
# Epoch: 323 | Train Loss: 0.30946 | Valid Loss: 0.54359 |Train Accs: 0.89921 | Valid Accs: 0.82634 | Time: 26.74 seconds
# Epoch: 324 | Train Loss: 0.30976 | Valid Loss: 0.54916 |Train Accs: 0.90401 | Valid Accs: 0.82586 | Time: 26.87 seconds
# Epoch: 325 | Train Loss: 0.29436 | Valid Loss: 0.55953 |Train Accs: 0.90782 | Valid Accs: 0.81966 | Time: 26.95 seconds
# Epoch: 326 | Train Loss: 0.30732 | Valid Loss: 0.55036 |Train Accs: 0.90014 | Valid Accs: 0.82872 | Time: 26.54 seconds
# Epoch: 327 | Train Loss: 0.29552 | Valid Loss: 0.56554 |Train Accs: 0.90749 | Valid Accs: 0.81584 | Time: 26.71 seconds
# Epoch: 328 | Train Loss: 0.30729 | Valid Loss: 0.55826 |Train Accs: 0.90053 | Valid Accs: 0.82061 | Time: 26.63 seconds
# Epoch: 329 | Train Loss: 0.31272 | Valid Loss: 0.54623 |Train Accs: 0.89714 | Valid Accs: 0.82681 | Time: 26.76 seconds
# Epoch: 330 | Train Loss: 0.30100 | Valid Loss: 0.56088 |Train Accs: 0.90379 | Valid Accs: 0.81679 | Time: 26.82 seconds
# Epoch: 331 | Train Loss: 0.30311 | Valid Loss: 0.56661 |Train Accs: 0.90233 | Valid Accs: 0.82538 | Time: 26.59 seconds
# Epoch: 332 | Train Loss: 0.30733 | Valid Loss: 0.52097 |Train Accs: 0.90043 | Valid Accs: 0.82681 | Time: 26.81 seconds
# Epoch: 333 | Train Loss: 0.30839 | Valid Loss: 0.52211 |Train Accs: 0.90389 | Valid Accs: 0.82395 | Time: 26.57 seconds
# Epoch: 334 | Train Loss: 0.30575 | Valid Loss: 0.54409 |Train Accs: 0.90274 | Valid Accs: 0.82443 | Time: 26.59 seconds
# Epoch: 335 | Train Loss: 0.31296 | Valid Loss: 0.55262 |Train Accs: 0.89825 | Valid Accs: 0.83158 | Time: 26.53 seconds
# Epoch: 336 | Train Loss: 0.31167 | Valid Loss: 0.55488 |Train Accs: 0.89954 | Valid Accs: 0.82538 | Time: 26.65 seconds
# Epoch: 337 | Train Loss: 0.30385 | Valid Loss: 0.54960 |Train Accs: 0.90403 | Valid Accs: 0.82968 | Time: 26.38 seconds
# Epoch: 338 | Train Loss: 0.31086 | Valid Loss: 0.55416 |Train Accs: 0.90149 | Valid Accs: 0.82061 | Time: 26.54 seconds
# Epoch: 339 | Train Loss: 0.31093 | Valid Loss: 0.56065 |Train Accs: 0.89839 | Valid Accs: 0.82538 | Time: 26.61 seconds
# Epoch: 340 | Train Loss: 0.30459 | Valid Loss: 0.53362 |Train Accs: 0.90343 | Valid Accs: 0.82586 | Time: 26.56 seconds
# Epoch: 341 | Train Loss: 0.30588 | Valid Loss: 0.54678 |Train Accs: 0.89899 | Valid Accs: 0.82252 | Time: 26.59 seconds
# Epoch: 342 | Train Loss: 0.30024 | Valid Loss: 0.53995 |Train Accs: 0.90602 | Valid Accs: 0.82824 | Time: 26.35 seconds
# Epoch: 343 | Train Loss: 0.30567 | Valid Loss: 0.53021 |Train Accs: 0.90288 | Valid Accs: 0.82920 | Time: 26.98 seconds
# Epoch: 344 | Train Loss: 0.31061 | Valid Loss: 0.53104 |Train Accs: 0.89942 | Valid Accs: 0.82920 | Time: 26.55 seconds
# Epoch: 345 | Train Loss: 0.30797 | Valid Loss: 0.53091 |Train Accs: 0.90281 | Valid Accs: 0.82729 | Time: 26.59 seconds
# Epoch: 346 | Train Loss: 0.29564 | Valid Loss: 0.53737 |Train Accs: 0.90444 | Valid Accs: 0.82586 | Time: 26.65 seconds
# Epoch: 347 | Train Loss: 0.30376 | Valid Loss: 0.54484 |Train Accs: 0.90329 | Valid Accs: 0.82634 | Time: 26.43 seconds
# Epoch: 348 | Train Loss: 0.29471 | Valid Loss: 0.53553 |Train Accs: 0.90950 | Valid Accs: 0.82968 | Time: 26.62 seconds
# Epoch: 349 | Train Loss: 0.29860 | Valid Loss: 0.53236 |Train Accs: 0.90847 | Valid Accs: 0.82634 | Time: 26.44 seconds
# Epoch: 350 | Train Loss: 0.29657 | Valid Loss: 0.53443 |Train Accs: 0.90722 | Valid Accs: 0.83492 | Time: 26.64 seconds
# Epoch: 351 | Train Loss: 0.29309 | Valid Loss: 0.54157 |Train Accs: 0.90629 | Valid Accs: 0.82156 | Time: 26.47 seconds
# Epoch: 352 | Train Loss: 0.29027 | Valid Loss: 0.54382 |Train Accs: 0.90770 | Valid Accs: 0.82824 | Time: 26.47 seconds
# Epoch: 353 | Train Loss: 0.30067 | Valid Loss: 0.54802 |Train Accs: 0.90458 | Valid Accs: 0.82681 | Time: 26.49 seconds
# Epoch: 354 | Train Loss: 0.29480 | Valid Loss: 0.54204 |Train Accs: 0.90655 | Valid Accs: 0.82395 | Time: 26.51 seconds
# Epoch: 355 | Train Loss: 0.30667 | Valid Loss: 0.55790 |Train Accs: 0.90103 | Valid Accs: 0.82061 | Time: 26.81 seconds
# Epoch: 356 | Train Loss: 0.29331 | Valid Loss: 0.54613 |Train Accs: 0.90542 | Valid Accs: 0.82300 | Time: 26.82 seconds
# Epoch: 357 | Train Loss: 0.28814 | Valid Loss: 0.54077 |Train Accs: 0.91267 | Valid Accs: 0.82300 | Time: 26.27 seconds
# Epoch: 358 | Train Loss: 0.29152 | Valid Loss: 0.54996 |Train Accs: 0.90967 | Valid Accs: 0.82395 | Time: 26.72 seconds
# Epoch: 359 | Train Loss: 0.29735 | Valid Loss: 0.53126 |Train Accs: 0.90235 | Valid Accs: 0.83254 | Time: 26.52 seconds
# Epoch: 360 | Train Loss: 0.30308 | Valid Loss: 0.55226 |Train Accs: 0.90194 | Valid Accs: 0.82395 | Time: 26.59 seconds
# Epoch: 361 | Train Loss: 0.29349 | Valid Loss: 0.52340 |Train Accs: 0.90286 | Valid Accs: 0.83111 | Time: 26.53 seconds
# Epoch: 362 | Train Loss: 0.29134 | Valid Loss: 0.53022 |Train Accs: 0.90919 | Valid Accs: 0.82490 | Time: 26.39 seconds
# Epoch: 363 | Train Loss: 0.29885 | Valid Loss: 0.52794 |Train Accs: 0.90713 | Valid Accs: 0.83015 | Time: 26.70 seconds
# Epoch: 364 | Train Loss: 0.29432 | Valid Loss: 0.52980 |Train Accs: 0.90948 | Valid Accs: 0.83111 | Time: 26.55 seconds
# Epoch: 365 | Train Loss: 0.29023 | Valid Loss: 0.53115 |Train Accs: 0.90605 | Valid Accs: 0.82920 | Time: 26.54 seconds
# Epoch: 366 | Train Loss: 0.29373 | Valid Loss: 0.52287 |Train Accs: 0.90806 | Valid Accs: 0.83445 | Time: 26.61 seconds
# Epoch: 367 | Train Loss: 0.28589 | Valid Loss: 0.55895 |Train Accs: 0.91348 | Valid Accs: 0.81775 | Time: 26.34 seconds
# Epoch: 368 | Train Loss: 0.28122 | Valid Loss: 0.53487 |Train Accs: 0.91550 | Valid Accs: 0.82729 | Time: 26.66 seconds
# Epoch: 369 | Train Loss: 0.28960 | Valid Loss: 0.53698 |Train Accs: 0.90845 | Valid Accs: 0.82872 | Time: 26.58 seconds
# Epoch: 370 | Train Loss: 0.28668 | Valid Loss: 0.52740 |Train Accs: 0.91288 | Valid Accs: 0.82920 | Time: 26.94 seconds
# Epoch: 371 | Train Loss: 0.29286 | Valid Loss: 0.57064 |Train Accs: 0.90727 | Valid Accs: 0.82204 | Time: 26.84 seconds
# Epoch: 372 | Train Loss: 0.28842 | Valid Loss: 0.53844 |Train Accs: 0.90967 | Valid Accs: 0.83158 | Time: 26.88 seconds
# Epoch: 373 | Train Loss: 0.28997 | Valid Loss: 0.52835 |Train Accs: 0.90797 | Valid Accs: 0.82920 | Time: 26.35 seconds
# Epoch: 374 | Train Loss: 0.28742 | Valid Loss: 0.52324 |Train Accs: 0.91183 | Valid Accs: 0.83302 | Time: 26.93 seconds
# Epoch: 375 | Train Loss: 0.28714 | Valid Loss: 0.54330 |Train Accs: 0.90732 | Valid Accs: 0.82681 | Time: 26.70 seconds
# Epoch: 376 | Train Loss: 0.29253 | Valid Loss: 0.55218 |Train Accs: 0.90878 | Valid Accs: 0.83158 | Time: 26.87 seconds
# Epoch: 377 | Train Loss: 0.29179 | Valid Loss: 0.51747 |Train Accs: 0.90535 | Valid Accs: 0.83588 | Time: 26.97 seconds
# Epoch: 378 | Train Loss: 0.29327 | Valid Loss: 0.54090 |Train Accs: 0.90746 | Valid Accs: 0.82872 | Time: 26.06 seconds
# Epoch: 379 | Train Loss: 0.29348 | Valid Loss: 0.52524 |Train Accs: 0.90895 | Valid Accs: 0.83015 | Time: 26.43 seconds
# Epoch: 380 | Train Loss: 0.28410 | Valid Loss: 0.52012 |Train Accs: 0.90809 | Valid Accs: 0.83302 | Time: 26.65 seconds
# Epoch: 381 | Train Loss: 0.28344 | Valid Loss: 0.54387 |Train Accs: 0.91060 | Valid Accs: 0.81918 | Time: 26.58 seconds
# Epoch: 382 | Train Loss: 0.28262 | Valid Loss: 0.51231 |Train Accs: 0.91276 | Valid Accs: 0.84113 | Time: 27.08 seconds
# Epoch: 383 | Train Loss: 0.28274 | Valid Loss: 0.52403 |Train Accs: 0.91202 | Valid Accs: 0.82824 | Time: 26.35 seconds
# Epoch: 384 | Train Loss: 0.29606 | Valid Loss: 0.52532 |Train Accs: 0.90389 | Valid Accs: 0.82872 | Time: 26.95 seconds
# Epoch: 385 | Train Loss: 0.28685 | Valid Loss: 0.53534 |Train Accs: 0.91082 | Valid Accs: 0.82920 | Time: 26.72 seconds
# Epoch: 386 | Train Loss: 0.28504 | Valid Loss: 0.53770 |Train Accs: 0.91310 | Valid Accs: 0.82300 | Time: 26.96 seconds
# Epoch: 387 | Train Loss: 0.28341 | Valid Loss: 0.53732 |Train Accs: 0.91084 | Valid Accs: 0.83111 | Time: 26.77 seconds
# Epoch: 388 | Train Loss: 0.28260 | Valid Loss: 0.53811 |Train Accs: 0.91279 | Valid Accs: 0.82443 | Time: 26.62 seconds
# Epoch: 389 | Train Loss: 0.28767 | Valid Loss: 0.53459 |Train Accs: 0.90845 | Valid Accs: 0.82586 | Time: 26.50 seconds
# Epoch: 390 | Train Loss: 0.29803 | Valid Loss: 0.54602 |Train Accs: 0.90672 | Valid Accs: 0.82586 | Time: 26.63 seconds
# Epoch: 391 | Train Loss: 0.28181 | Valid Loss: 0.53403 |Train Accs: 0.91612 | Valid Accs: 0.83492 | Time: 26.89 seconds
# Epoch: 392 | Train Loss: 0.28868 | Valid Loss: 0.53446 |Train Accs: 0.90895 | Valid Accs: 0.82968 | Time: 26.49 seconds
# Epoch: 393 | Train Loss: 0.29877 | Valid Loss: 0.51850 |Train Accs: 0.90698 | Valid Accs: 0.83588 | Time: 26.43 seconds
# Epoch: 394 | Train Loss: 0.28264 | Valid Loss: 0.52820 |Train Accs: 0.91183 | Valid Accs: 0.83254 | Time: 26.30 seconds
# Epoch: 395 | Train Loss: 0.28645 | Valid Loss: 0.51852 |Train Accs: 0.90962 | Valid Accs: 0.83731 | Time: 26.45 seconds
# Epoch: 396 | Train Loss: 0.29231 | Valid Loss: 0.52315 |Train Accs: 0.90509 | Valid Accs: 0.82538 | Time: 26.46 seconds
# Epoch: 397 | Train Loss: 0.28191 | Valid Loss: 0.52510 |Train Accs: 0.91183 | Valid Accs: 0.82634 | Time: 26.41 seconds
# Epoch: 398 | Train Loss: 0.28418 | Valid Loss: 0.53148 |Train Accs: 0.91036 | Valid Accs: 0.82968 | Time: 26.34 seconds
# Epoch: 399 | Train Loss: 0.29442 | Valid Loss: 0.54874 |Train Accs: 0.91008 | Valid Accs: 0.82729 | Time: 26.32 seconds
# Epoch: 400 | Train Loss: 0.28078 | Valid Loss: 0.52503 |Train Accs: 0.91286 | Valid Accs: 0.83206 | Time: 26.30 seconds
# Epoch: 401 | Train Loss: 0.28787 | Valid Loss: 0.53070 |Train Accs: 0.91166 | Valid Accs: 0.82872 | Time: 26.34 seconds
# Epoch: 402 | Train Loss: 0.28849 | Valid Loss: 0.52569 |Train Accs: 0.91324 | Valid Accs: 0.82920 | Time: 26.32 seconds
# Epoch: 403 | Train Loss: 0.27222 | Valid Loss: 0.52495 |Train Accs: 0.91996 | Valid Accs: 0.83588 | Time: 26.57 seconds
# Epoch: 404 | Train Loss: 0.29113 | Valid Loss: 0.53091 |Train Accs: 0.91274 | Valid Accs: 0.83206 | Time: 26.48 seconds
# Epoch: 405 | Train Loss: 0.29257 | Valid Loss: 0.52677 |Train Accs: 0.90950 | Valid Accs: 0.83254 | Time: 26.39 seconds
# Epoch: 406 | Train Loss: 0.28380 | Valid Loss: 0.52072 |Train Accs: 0.91135 | Valid Accs: 0.82920 | Time: 26.65 seconds
# Epoch: 407 | Train Loss: 0.27441 | Valid Loss: 0.52951 |Train Accs: 0.91670 | Valid Accs: 0.82920 | Time: 26.64 seconds
# Epoch: 408 | Train Loss: 0.28023 | Valid Loss: 0.54186 |Train Accs: 0.91418 | Valid Accs: 0.82824 | Time: 26.45 seconds
# Epoch: 409 | Train Loss: 0.28492 | Valid Loss: 0.52945 |Train Accs: 0.91063 | Valid Accs: 0.82634 | Time: 26.63 seconds
# Epoch: 410 | Train Loss: 0.27933 | Valid Loss: 0.51948 |Train Accs: 0.91432 | Valid Accs: 0.83492 | Time: 26.59 seconds
# Epoch: 411 | Train Loss: 0.28386 | Valid Loss: 0.52474 |Train Accs: 0.91735 | Valid Accs: 0.83158 | Time: 26.52 seconds
# Epoch: 412 | Train Loss: 0.28892 | Valid Loss: 0.52608 |Train Accs: 0.91130 | Valid Accs: 0.83588 | Time: 26.64 seconds
# Epoch: 413 | Train Loss: 0.27862 | Valid Loss: 0.52704 |Train Accs: 0.91492 | Valid Accs: 0.82920 | Time: 26.49 seconds
# Epoch: 414 | Train Loss: 0.28344 | Valid Loss: 0.53041 |Train Accs: 0.91526 | Valid Accs: 0.82538 | Time: 26.49 seconds
# Epoch: 415 | Train Loss: 0.28721 | Valid Loss: 0.52963 |Train Accs: 0.91358 | Valid Accs: 0.83158 | Time: 26.49 seconds
# Epoch: 416 | Train Loss: 0.27080 | Valid Loss: 0.53377 |Train Accs: 0.91444 | Valid Accs: 0.82872 | Time: 26.62 seconds
# Epoch: 417 | Train Loss: 0.27619 | Valid Loss: 0.52858 |Train Accs: 0.91802 | Valid Accs: 0.83158 | Time: 26.41 seconds
# Epoch: 418 | Train Loss: 0.27667 | Valid Loss: 0.54392 |Train Accs: 0.91684 | Valid Accs: 0.82586 | Time: 26.80 seconds
# Epoch: 419 | Train Loss: 0.27583 | Valid Loss: 0.52446 |Train Accs: 0.91711 | Valid Accs: 0.83492 | Time: 26.62 seconds
# Epoch: 420 | Train Loss: 0.27689 | Valid Loss: 0.54312 |Train Accs: 0.92023 | Valid Accs: 0.82586 | Time: 26.78 seconds
# Epoch: 421 | Train Loss: 0.27449 | Valid Loss: 0.53379 |Train Accs: 0.91670 | Valid Accs: 0.82538 | Time: 26.65 seconds
# Epoch: 422 | Train Loss: 0.27324 | Valid Loss: 0.53654 |Train Accs: 0.91603 | Valid Accs: 0.82777 | Time: 26.56 seconds
# Epoch: 423 | Train Loss: 0.26579 | Valid Loss: 0.52176 |Train Accs: 0.92104 | Valid Accs: 0.83063 | Time: 26.50 seconds
# Epoch: 424 | Train Loss: 0.28322 | Valid Loss: 0.55423 |Train Accs: 0.91195 | Valid Accs: 0.82586 | Time: 26.54 seconds
# Epoch: 425 | Train Loss: 0.27362 | Valid Loss: 0.52075 |Train Accs: 0.91771 | Valid Accs: 0.82824 | Time: 26.56 seconds
# Epoch: 426 | Train Loss: 0.27702 | Valid Loss: 0.51661 |Train Accs: 0.91600 | Valid Accs: 0.83158 | Time: 26.60 seconds
# Epoch: 427 | Train Loss: 0.27872 | Valid Loss: 0.53275 |Train Accs: 0.91180 | Valid Accs: 0.82777 | Time: 26.58 seconds
# Epoch: 428 | Train Loss: 0.27468 | Valid Loss: 0.52431 |Train Accs: 0.91324 | Valid Accs: 0.83922 | Time: 26.68 seconds
# Epoch: 429 | Train Loss: 0.27383 | Valid Loss: 0.53559 |Train Accs: 0.91792 | Valid Accs: 0.82920 | Time: 26.69 seconds
# Epoch: 430 | Train Loss: 0.28180 | Valid Loss: 0.52793 |Train Accs: 0.91130 | Valid Accs: 0.83445 | Time: 26.55 seconds
# Epoch: 431 | Train Loss: 0.28581 | Valid Loss: 0.52711 |Train Accs: 0.91096 | Valid Accs: 0.83302 | Time: 26.51 seconds
# Epoch: 432 | Train Loss: 0.26728 | Valid Loss: 0.51710 |Train Accs: 0.91867 | Valid Accs: 0.83254 | Time: 26.47 seconds
#
# Early Stopping at Epoch 433
#
# **************************************************
#
# Best Validation Loss at Epoch 382
#
# **************************************************
#
# Best Validation Accs at Epoch 382
#
# **************************************************
#
# Time Taken [433 Epochs] : 193.30 minutes
#
# **************************************************
# **************************************************
# **************************************************
# **************************************************
