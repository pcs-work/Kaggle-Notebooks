# %%
# %%bash
# pip install timm onnx onnxruntime -q

# %%
import os
import sys
import cv2
import json
import onnx
import timm
import torch
import random as r
import numpy as np
import pandas as pd
import onnxruntime as ort
import matplotlib.pyplot as plt

from PIL import Image
from typing import Union
from torchvision import models
from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore")

if not os.path.exists("onnx"): os.makedirs("onnx")
    
ort.set_default_logger_severity(3)

# %%
labels: dict = json.load(open("/kaggle/input/pfei-dataframe/labels.json", "r"))
    
    
def breaker() -> None:
    print("\n" + 50*"*" + "\n")


def get_image(path: str, size: int=224) -> np.ndarray:
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)
    return cv2.resize(src=image, dsize=(size, size), interpolation=cv2.INTER_CUBIC)
    

def show_image(
    image: np.ndarray, 
    cmap: str="gnuplot2", 
    title: Union[str, None]=None
) -> None:
    plt.figure()
    plt.imshow(image, cmap=cmap)
    plt.axis("off")
    if title: plt.title(title)
    plt.show()

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        self.model = timm.create_model(model_name="efficientnet_b4", pretrained=False)
        self.model.classifier = torch.nn.Linear(in_features=self.model.classifier.in_features, out_features=4)

    def forward(self, x):
        return self.model(x)

    
class CFG(object):  
    def __init__(
        self, 
        in_channels: int=3, 
        size: int=256, 
        opset_version: int=9, 
        path: str=None
    ):
        self.in_channels = in_channels
        self.size = size
        self.dummy = torch.randn(1, self.in_channels, self.size, self.size)
        self.opset_version = opset_version
        self.path = path

# %%
# Fold 1 (BEST), Fold 5 (SECOND BEST)

for fold in range(1, 6):
    for v in ["a", "l"]:
        cfg = CFG(
            in_channels=3, 
            size=224, 
            opset_version=15, 
            path=f"/kaggle/input/pfei-en4-a224-e10-f{fold}/saves/b{v}e_state_fold_{fold}.pt"
        )

        model = Model()
        model.load_state_dict(torch.load(cfg.path, map_location=torch.device("cpu"))["model_state_dict"])
        model.eval()

        clear_output()

        torch.onnx.export(
            model=model, 
            args=cfg.dummy, 
            f=f"onnx/b{v}e_model_f{fold}.onnx", 
            input_names=["input"], 
            output_names=["output"], 
            opset_version=cfg.opset_version,
            export_params=True,
            training=torch.onnx.TrainingMode.EVAL,
            operator_export_type=torch.onnx.OperatorExportTypes.ONNX_ATEN_FALLBACK,
            dynamic_axes={
              "input"  : {0 : "batch_size"},
              "output" : {0 : "batch_size"},
            }
        )
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
class OnnxModel(object):
    def __init__(self, path: str) -> None:
        self.size: int = 224
        
        self.mean: list = [0.50523, 0.45941, 0.40959]
        self.std: list  = [0.21790, 0.21356, 0.21381]
        
        self.path: str = path
    
        model = onnx.load(self.path)
        onnx.checker.check_model(model)
        self.ort_session = ort.InferenceSession(self.path)
        
    def infer(self, image: np.ndarray, labels: dict) -> np.ndarray:
        image = image / 255
        image = image.transpose(2, 0, 1)
        for i in range(image.shape[0]): image[i, :, :] = (image[i, :, :] - self.mean[i]) / self.std[i]
        image = np.expand_dims(image, axis=0)
        inputs = {self.ort_session.get_inputs()[0].name: image.astype("float32")}
        result = self.ort_session.run(None, inputs)
        odds = np.exp(np.max(result))
        return labels[str(np.argmax(result))], odds / (1 + odds)

# %%
df = pd.read_csv("/kaggle/input/pfei-dataframe/test.csv")

breaker()
for model_name in sorted(os.listdir("onnx")):
    
    onnx_model = OnnxModel(f"onnx/{model_name}")
    
    print(f"{model_name.upper()}\n")
    
    count: int = 0
    
    for i in range(20):
        index = r.randint(0, len(df)-1)
        filepath = df.iloc[index, 0]
        y_true   = df.iloc[index, 1]

        image = get_image(filepath)

        y_pred, _ = onnx_model.infer(image, labels)
        
        if labels[str(y_true)] == y_pred:
            count += 1
        
        print(f"{labels[str(y_true)]}, {y_pred}")
        # show_image(image, title=y_pred)
    
    print(f"\n\nAccuracy : {count / 20:.5f}")

    breaker()
# Out:
# **************************************************
#
# BAE_MODEL_F1.ONNX
#
# Sad, Sad
# Happy, Happy
# Happy, Happy
# Happy, Happy
# Sad, Sad
# Other, Other
# Angry, Angry
# Angry, Angry
# Other, Other
# Happy, Happy
# Angry, Angry
# Angry, Angry
# Sad, Sad
# Happy, Happy
# Happy, Happy
# Sad, Sad
# Angry, Angry
# Sad, Sad
# Sad, Sad
# Other, Other
#
#
# Accuracy : 1.00000
#
# **************************************************
#
# BAE_MODEL_F2.ONNX
#
# Angry, Angry
# Happy, Happy
# Angry, Angry
# Sad, Happy
# Other, Other
# Angry, Angry
# Angry, Angry
# Angry, Angry
# Sad, Sad
# Sad, Sad
# Sad, Sad
# Happy, Angry
# Other, Other
# Sad, Sad
# Other, Other
# Happy, Sad
# Angry, Angry
# Angry, Angry
# Happy, Happy
# Happy, Happy
#
#
# Accuracy : 0.85000
#
# **************************************************
#
# BAE_MODEL_F3.ONNX
#
# Happy, Happy
# Sad, Sad
# Happy, Happy
# Other, Other
# Angry, Angry
# Happy, Happy
# Angry, Angry
# Sad, Sad
# Angry, Angry
# Angry, Angry
# Sad, Sad
# Other, Other
# Other, Other
# Sad, Sad
# Angry, Angry
# Sad, Sad
# Sad, Sad
# Happy, Happy
# Other, Other
# Angry, Angry
#
#
# Accuracy : 1.00000
#
# **************************************************
#
# BAE_MODEL_F4.ONNX
#
# Angry, Angry
# Sad, Sad
# Sad, Sad
# Angry, Angry
# Happy, Happy
# Angry, Angry
# Angry, Angry
# Happy, Happy
# Happy, Happy
# Happy, Sad
# Angry, Angry
# Sad, Sad
# Angry, Angry
# Sad, Sad
# Angry, Angry
# Happy, Happy
# Other, Other
# Happy, Happy
# Other, Other
# Other, Other
#
#
# Accuracy : 0.95000
#
# **************************************************
#
# BAE_MODEL_F5.ONNX
#
# Sad, Sad
# Angry, Angry
# Sad, Sad
# Other, Other
# Sad, Sad
# Other, Other
# Sad, Sad
# Sad, Sad
# Angry, Angry
# Angry, Angry
# Angry, Angry
# Other, Other
# Happy, Happy
# Sad, Sad
# Other, Other
# Other, Other
# Sad, Sad
# Happy, Happy
# Other, Other
# Other, Other
#
#
# Accuracy : 1.00000
#
# **************************************************
#
# BLE_MODEL_F1.ONNX
#
# Sad, Sad
# Angry, Angry
# Other, Other
# Sad, Happy
# Angry, Angry
# Sad, Sad
# Angry, Angry
# Happy, Happy
# Sad, Sad
# Happy, Happy
# Happy, Happy
# Sad, Sad
# Other, Sad
# Angry, Angry
# Sad, Sad
# Angry, Angry
# Happy, Happy
# Happy, Happy
# Sad, Sad
# Sad, Sad
#
#
# Accuracy : 0.90000
#
# **************************************************
#
# BLE_MODEL_F2.ONNX
#
# Angry, Angry
# Happy, Happy
# Angry, Angry
# Happy, Other
# Angry, Angry
# Other, Other
# Happy, Happy
# Sad, Sad
# Other, Other
# Other, Other
# Sad, Sad
# Angry, Angry
# Other, Other
# Happy, Other
# Angry, Angry
# Sad, Angry
# Other, Other
# Other, Other
# Other, Other
# Happy, Other
#
#
# Accuracy : 0.80000
#
# **************************************************
#
# BLE_MODEL_F3.ONNX
#
# Happy, Happy
# Angry, Angry
# Other, Other
# Other, Other
# Sad, Sad
# Happy, Happy
# Sad, Sad
# Sad, Sad
# Sad, Sad
# Happy, Happy
# Other, Other
# Other, Other
# Happy, Happy
# Sad, Happy
# Happy, Happy
# Angry, Sad
# Sad, Sad
# Other, Other
# Happy, Happy
# Other, Other
#
#
# Accuracy : 0.90000
#
# **************************************************
#
# BLE_MODEL_F4.ONNX
#
# Other, Other
# Happy, Happy
# Angry, Angry
# Sad, Sad
# Sad, Sad
# Sad, Sad
# Sad, Sad
# Other, Other
# Other, Other
# Sad, Sad
# Other, Sad
# Angry, Angry
# Other, Other
# Other, Other
# Happy, Happy
# Other, Other
# Other, Other
# Sad, Sad
# Angry, Angry
# Sad, Sad
#
#
# Accuracy : 0.95000
#
# **************************************************
#
# BLE_MODEL_F5.ONNX
#
# Angry, Happy
# Happy, Happy
# Happy, Happy
# Happy, Happy
# Sad, Sad
# Sad, Sad
# Other, Other
# Sad, Other
# Other, Other
# Sad, Sad
# Happy, Happy
# Sad, Sad
# Other, Other
# Sad, Sad
# Happy, Happy
# Sad, Sad
# Other, Other
# Angry, Angry
# Angry, Angry
# Happy, Happy
#
#
# Accuracy : 0.90000
#
# **************************************************
