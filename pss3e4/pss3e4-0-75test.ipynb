# %%
import pandas as pd

ss_df = pd.read_csv("/kaggle/input/playground-series-s3e4/sample_submission.csv")
ss_df.Class = [0.75] * ss_df.shape[0]
ss_df.to_csv("submision.csv", index=False)
